# %%
# !python train.py --dataset Norman2019 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3 \
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:4 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --no_gnn \
                 --exp_name no_gnn_no_perturb_emb \
                 --wandb \
                 --no_pert_emb
# Out:
# ---- Printing Arguments ----
# dataset: Norman2019
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:4
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: False
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: True
# no_pert_emb: True
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: no_gnn_no_perturb_emb
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run no_gnn_no_perturb_emb
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/1vxii28o
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211109_191554-1vxii28o
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_co-expression_100.0_64_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_sim_gnn
# Epoch 2 Step 801 Train Loss: 0.0335
# Epoch 2 Step 851 Train Loss: 0.0383
# Epoch 2 Step 901 Train Loss: 0.0364
# Epoch 2 Step 951 Train Loss: 0.0353
# Epoch 2 Step 1001 Train Loss: 0.0455
# Epoch 2 Step 1051 Train Loss: 0.0453
# Epoch 2 Step 1101 Train Loss: 0.0500
# Epoch 2 Step 1151 Train Loss: 0.0307
# Epoch 2 Step 1201 Train Loss: 0.0330
# Epoch 2 Step 1251 Train Loss: 0.0397
# Epoch 2 Step 1301 Train Loss: 0.0391
# Epoch 2 Step 1351 Train Loss: 0.0407
# Epoch 2 Step 1401 Train Loss: 0.0542
# Epoch 2 Step 1451 Train Loss: 0.0335
# Epoch 2 Step 1501 Train Loss: 0.0554
# Epoch 2 Step 1551 Train Loss: 0.0349
# Epoch 2 Step 1601 Train Loss: 0.0430
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 2: Train: 0.0218, R2 0.7910 Validation: 0.0220. R2 0.7866 Loss: 0.0417
# DE_Train: 0.3803, R2 -0.0699 DE_Validation: 0.3767. R2 -0.4657
# Epoch 3 Step 1 Train Loss: 0.0266
# Epoch 3 Step 51 Train Loss: 0.0392
# Epoch 3 Step 101 Train Loss: 0.0541
# Epoch 3 Step 151 Train Loss: 0.0415
# Epoch 3 Step 201 Train Loss: 0.0357
# Epoch 3 Step 251 Train Loss: 0.0565
# Epoch 3 Step 301 Train Loss: 0.0330
# Epoch 3 Step 351 Train Loss: 0.0330
# Epoch 3 Step 401 Train Loss: 0.0487
# Epoch 3 Step 451 Train Loss: 0.0415
# Epoch 3 Step 501 Train Loss: 0.0436
# Epoch 3 Step 551 Train Loss: 0.0255
# Epoch 3 Step 601 Train Loss: 0.0427
# Epoch 3 Step 651 Train Loss: 0.0251
# Epoch 3 Step 701 Train Loss: 0.0339
# Epoch 3 Step 751 Train Loss: 0.0271
# Epoch 3 Step 801 Train Loss: 0.0286
# Epoch 3 Step 851 Train Loss: 0.0509
# Epoch 3 Step 901 Train Loss: 0.0467
# Epoch 3 Step 951 Train Loss: 0.0373
# Epoch 3 Step 1001 Train Loss: 0.0426
# Epoch 3 Step 1051 Train Loss: 0.0466
# Epoch 3 Step 1101 Train Loss: 0.0344
# Epoch 3 Step 1151 Train Loss: 0.0406
# Epoch 3 Step 1201 Train Loss: 0.0469
# Epoch 3 Step 1251 Train Loss: 0.0302
# Epoch 3 Step 1301 Train Loss: 0.0294
# Epoch 3 Step 1351 Train Loss: 0.0250
# Epoch 3 Step 1401 Train Loss: 0.0483
# Epoch 3 Step 1451 Train Loss: 0.0386
# Epoch 3 Step 1501 Train Loss: 0.0379
# Epoch 3 Step 1551 Train Loss: 0.0507
# Epoch 3 Step 1601 Train Loss: 0.0469
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 5: Train: 0.0257, R2 0.7786 Validation: 0.0249. R2 0.7855 Loss: 0.0377
# DE_Train: 0.1926, R2 -0.4967 DE_Validation: 0.2375. R2 -2.0866
# Epoch 6 Step 1 Train Loss: 0.0336
# Epoch 6 Step 51 Train Loss: 0.0284
# Epoch 6 Step 101 Train Loss: 0.0510
# Epoch 6 Step 151 Train Loss: 0.0314
# Epoch 6 Step 201 Train Loss: 0.0374
# Epoch 6 Step 251 Train Loss: 0.0284
# Epoch 6 Step 301 Train Loss: 0.0337
# Epoch 6 Step 351 Train Loss: 0.0452
# Epoch 6 Step 401 Train Loss: 0.0302
# Epoch 6 Step 451 Train Loss: 0.0349
# Epoch 6 Step 501 Train Loss: 0.0317
# Epoch 6 Step 551 Train Loss: 0.0360
# Epoch 6 Step 601 Train Loss: 0.0333
# Epoch 6 Step 651 Train Loss: 0.0348
# Epoch 6 Step 701 Train Loss: 0.0425
# Epoch 6 Step 751 Train Loss: 0.0406
# Epoch 6 Step 801 Train Loss: 0.0401
# Epoch 6 Step 851 Train Loss: 0.0413
# Epoch 6 Step 901 Train Loss: 0.0469
# Epoch 6 Step 951 Train Loss: 0.0336
# Epoch 6 Step 1001 Train Loss: 0.0402
# Epoch 6 Step 1051 Train Loss: 0.0407
# Epoch 6 Step 1101 Train Loss: 0.0356
# Epoch 6 Step 1151 Train Loss: 0.0323
# Epoch 6 Step 1201 Train Loss: 0.0267
# Epoch 6 Step 1251 Train Loss: 0.0257
# Epoch 6 Step 1301 Train Loss: 0.0406
# Epoch 6 Step 1351 Train Loss: 0.0317
# Epoch 6 Step 1401 Train Loss: 0.0278
# Epoch 6 Step 1451 Train Loss: 0.0583
# Epoch 6 Step 1501 Train Loss: 0.0369
# Epoch 6 Step 1551 Train Loss: 0.0417
# Epoch 6 Step 1601 Train Loss: 0.0343
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 6: Train: 0.0138, R2 0.9203 Validation: 0.0145. R2 0.9170 Loss: 0.0374
# DE_Train: 0.1314, R2 0.2532 DE_Validation: 0.1948. R2 -0.5784
# Epoch 7 Step 1 Train Loss: 0.0333
# Epoch 7 Step 51 Train Loss: 0.0385
# Epoch 7 Step 101 Train Loss: 0.0446
# Epoch 7 Step 151 Train Loss: 0.0418
# Epoch 7 Step 201 Train Loss: 0.0376
# Epoch 7 Step 251 Train Loss: 0.0301
# Epoch 7 Step 301 Train Loss: 0.0370
# Epoch 7 Step 351 Train Loss: 0.0290
# Epoch 7 Step 401 Train Loss: 0.0416
# Epoch 7 Step 451 Train Loss: 0.0277
# Epoch 7 Step 501 Train Loss: 0.0348
# Epoch 7 Step 551 Train Loss: 0.0244
# Epoch 7 Step 601 Train Loss: 0.0381
# Epoch 7 Step 651 Train Loss: 0.0426
# Epoch 7 Step 701 Train Loss: 0.0323
# Epoch 7 Step 751 Train Loss: 0.0359
# Epoch 7 Step 801 Train Loss: 0.0268
# Epoch 7 Step 851 Train Loss: 0.0323
# Epoch 7 Step 901 Train Loss: 0.0366
# Epoch 7 Step 951 Train Loss: 0.0371
# Epoch 7 Step 1001 Train Loss: 0.0362
# Epoch 7 Step 1051 Train Loss: 0.0413
# Epoch 7 Step 1101 Train Loss: 0.0427
# Epoch 7 Step 1151 Train Loss: 0.0455
# Epoch 7 Step 1201 Train Loss: 0.0329
# Epoch 7 Step 1251 Train Loss: 0.0368
# Epoch 7 Step 1301 Train Loss: 0.0448
# Epoch 7 Step 1351 Train Loss: 0.0459
# Epoch 7 Step 1401 Train Loss: 0.0313
# Epoch 7 Step 1451 Train Loss: 0.0465
# Epoch 7 Step 1501 Train Loss: 0.0366
# Epoch 7 Step 1551 Train Loss: 0.0442
# Epoch 7 Step 1601 Train Loss: 0.0413
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 7: Train: 0.0167, R2 0.8788 Validation: 0.0163. R2 0.8794 Loss: 0.0371
# DE_Train: 0.1235, R2 -0.3602 DE_Validation: 0.1761. R2 -2.0512
# Epoch 8 Step 1 Train Loss: 0.0303
# Epoch 8 Step 51 Train Loss: 0.0395
# Epoch 8 Step 101 Train Loss: 0.0335
# Epoch 8 Step 151 Train Loss: 0.0303
# Epoch 8 Step 201 Train Loss: 0.0358
# Epoch 8 Step 251 Train Loss: 0.0450
# Epoch 8 Step 301 Train Loss: 0.0309
# Epoch 8 Step 351 Train Loss: 0.0282
# Epoch 8 Step 401 Train Loss: 0.0447
# Epoch 8 Step 451 Train Loss: 0.0495
# Epoch 8 Step 501 Train Loss: 0.0367
# Epoch 8 Step 551 Train Loss: 0.0455
# Epoch 8 Step 601 Train Loss: 0.0313
# Epoch 8 Step 651 Train Loss: 0.0437
# Epoch 8 Step 701 Train Loss: 0.0347
# Epoch 8 Step 751 Train Loss: 0.0420
# Epoch 8 Step 801 Train Loss: 0.0291
# Epoch 8 Step 851 Train Loss: 0.0448
# Epoch 8 Step 901 Train Loss: 0.0296
# Epoch 8 Step 951 Train Loss: 0.0737
# Epoch 8 Step 1001 Train Loss: 0.0535
# Epoch 8 Step 1051 Train Loss: 0.0484
# Epoch 8 Step 1101 Train Loss: 0.0265
# Epoch 8 Step 1151 Train Loss: 0.0432
# Epoch 8 Step 1201 Train Loss: 0.0417
# Epoch 8 Step 1251 Train Loss: 0.0333
# Epoch 8 Step 1301 Train Loss: 0.0411
# Epoch 8 Step 1351 Train Loss: 0.0302
# Epoch 8 Step 1401 Train Loss: 0.0329
# Epoch 8 Step 1451 Train Loss: 0.0296
# Epoch 8 Step 1501 Train Loss: 0.0351
# Epoch 8 Step 1551 Train Loss: 0.0366
# Epoch 8 Step 1601 Train Loss: 0.0478
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 8: Train: 0.0138, R2 0.9140 Validation: 0.0144. R2 0.9094 Loss: 0.0368
# DE_Train: 0.1198, R2 -0.4015 DE_Validation: 0.1743. R2 -1.1811
# Epoch 9 Step 1 Train Loss: 0.0280
# Epoch 9 Step 51 Train Loss: 0.0249
# Epoch 9 Step 101 Train Loss: 0.0264
# Epoch 9 Step 151 Train Loss: 0.0265
# Epoch 9 Step 201 Train Loss: 0.0456
# Epoch 9 Step 251 Train Loss: 0.0375
# Epoch 9 Step 301 Train Loss: 0.0400
# Epoch 9 Step 351 Train Loss: 0.0257
# Epoch 9 Step 401 Train Loss: 0.0308
# Epoch 9 Step 451 Train Loss: 0.0317
# Epoch 9 Step 501 Train Loss: 0.0239
# Epoch 9 Step 551 Train Loss: 0.0229
# Epoch 9 Step 601 Train Loss: 0.0317
# Epoch 9 Step 651 Train Loss: 0.0334
# Epoch 9 Step 701 Train Loss: 0.0307
# Epoch 9 Step 751 Train Loss: 0.0613
# Epoch 9 Step 801 Train Loss: 0.0349
# Epoch 9 Step 851 Train Loss: 0.0258
# Epoch 9 Step 901 Train Loss: 0.0293
# Epoch 9 Step 951 Train Loss: 0.0322
# Epoch 9 Step 1001 Train Loss: 0.0462
# Epoch 9 Step 1051 Train Loss: 0.0317
# Epoch 9 Step 1101 Train Loss: 0.0459
# Epoch 9 Step 1151 Train Loss: 0.0321
# Epoch 9 Step 1201 Train Loss: 0.0447
# Epoch 9 Step 1251 Train Loss: 0.0301
# Epoch 9 Step 1301 Train Loss: 0.0339
# Epoch 9 Step 1351 Train Loss: 0.0358
# Epoch 9 Step 1401 Train Loss: 0.0459
# Epoch 9 Step 1451 Train Loss: 0.0373
# Epoch 9 Step 1501 Train Loss: 0.0410
# Epoch 9 Step 1551 Train Loss: 0.0309
# Epoch 9 Step 1601 Train Loss: 0.0373
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 9: Train: 0.0157, R2 0.8900 Validation: 0.0159. R2 0.8869 Loss: 0.0368
# DE_Train: 0.1203, R2 -0.5387 DE_Validation: 0.1700. R2 -1.9098
# Epoch 10 Step 1 Train Loss: 0.0368
# Epoch 10 Step 51 Train Loss: 0.0355
# Epoch 10 Step 101 Train Loss: 0.0318
# Epoch 10 Step 151 Train Loss: 0.0409
# Epoch 10 Step 201 Train Loss: 0.0324
# Epoch 10 Step 251 Train Loss: 0.0559
# Epoch 10 Step 301 Train Loss: 0.0356
# Epoch 10 Step 351 Train Loss: 0.0301
# Epoch 10 Step 401 Train Loss: 0.0322
# Epoch 10 Step 451 Train Loss: 0.0424
# Epoch 10 Step 501 Train Loss: 0.0363
# Epoch 10 Step 551 Train Loss: 0.0624
# Epoch 10 Step 601 Train Loss: 0.0315
# Epoch 10 Step 651 Train Loss: 0.0245
# Epoch 10 Step 701 Train Loss: 0.0249
# Epoch 10 Step 751 Train Loss: 0.0402
# Epoch 10 Step 801 Train Loss: 0.0380
# Epoch 10 Step 851 Train Loss: 0.0326
# Epoch 10 Step 901 Train Loss: 0.0522
# Epoch 10 Step 951 Train Loss: 0.0370
# Epoch 10 Step 1001 Train Loss: 0.0462
# Epoch 10 Step 1051 Train Loss: 0.0324
# Epoch 10 Step 1101 Train Loss: 0.0664
# Epoch 10 Step 1151 Train Loss: 0.0593
# Epoch 10 Step 1201 Train Loss: 0.0285
# Epoch 10 Step 1251 Train Loss: 0.0465
# Epoch 10 Step 1301 Train Loss: 0.0289
# Epoch 10 Step 1351 Train Loss: 0.0372
# Epoch 10 Step 1401 Train Loss: 0.0578
# Epoch 10 Step 1451 Train Loss: 0.0297
# Epoch 10 Step 1501 Train Loss: 0.0346
# Epoch 10 Step 1551 Train Loss: 0.0235
# Epoch 10 Step 1601 Train Loss: 0.0603
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 10: Train: 0.0154, R2 0.8963 Validation: 0.0156. R2 0.8927 Loss: 0.0367
# DE_Train: 0.1149, R2 -0.4062 DE_Validation: 0.1679. R2 -1.9550
# Saving model....
# Start testing....
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Final best performing model: Test_DE: 0.1954, R2 -1.4839
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# ...
# wandb:              test_SYNERGY_DISSIMILAR_PHENO_mse_top50_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_fold_change_gap_all ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_40_60 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_45_55 ▁
# wandb:                   test_SYNERGY_SIMILAR_PHENO_mean_sigma ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top100_de ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top200_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top20_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top50_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:                    test_combo_seen0_fold_change_gap_all ▁
# wandb:            test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:               test_combo_seen0_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen0_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen0_frac_in_range ▁
# wandb:                    test_combo_seen0_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen0_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen0_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen0_mae ▁
# wandb:                                 test_combo_seen0_mae_de ▁
# wandb:                             test_combo_seen0_mean_sigma ▁
# wandb:                                    test_combo_seen0_mse ▁
# wandb:                                 test_combo_seen0_mse_de ▁
# wandb:                          test_combo_seen0_mse_top100_de ▁
# wandb:                          test_combo_seen0_mse_top200_de ▁
# wandb:                         test_combo_seen0_mse_top200_hvg ▁
# wandb:                           test_combo_seen0_mse_top20_de ▁
# wandb:                           test_combo_seen0_mse_top50_de ▁
# wandb:                                test_combo_seen0_pearson ▁
# wandb:                             test_combo_seen0_pearson_de ▁
# wandb:                          test_combo_seen0_pearson_delta ▁
# wandb:                       test_combo_seen0_pearson_delta_de ▁
# wandb:                test_combo_seen0_pearson_delta_top100_de ▁
# wandb:                test_combo_seen0_pearson_delta_top200_de ▁
# wandb:               test_combo_seen0_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen0_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen0_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen0_pearson_top100_de ▁
# wandb:                      test_combo_seen0_pearson_top200_de ▁
# wandb:                     test_combo_seen0_pearson_top200_hvg ▁
# wandb:                       test_combo_seen0_pearson_top20_de ▁
# wandb:                       test_combo_seen0_pearson_top50_de ▁
# wandb:                                     test_combo_seen0_r2 ▁
# wandb:                                  test_combo_seen0_r2_de ▁
# wandb:                               test_combo_seen0_spearman ▁
# wandb:                            test_combo_seen0_spearman_de ▁
# wandb:                              test_combo_seen0_std_sigma ▁
# wandb:                    test_combo_seen1_fold_change_gap_all ▁
# wandb:            test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen1_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen1_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen1_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen1_frac_in_range ▁
# wandb:                    test_combo_seen1_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen1_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen1_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen1_mae ▁
# wandb:                                 test_combo_seen1_mae_de ▁
# wandb:                             test_combo_seen1_mean_sigma ▁
# wandb:                                    test_combo_seen1_mse ▁
# wandb:                                 test_combo_seen1_mse_de ▁
# wandb:                          test_combo_seen1_mse_top100_de ▁
# wandb:                          test_combo_seen1_mse_top200_de ▁
# wandb:                         test_combo_seen1_mse_top200_hvg ▁
# wandb:                           test_combo_seen1_mse_top20_de ▁
# wandb:                           test_combo_seen1_mse_top50_de ▁
# wandb:                                test_combo_seen1_pearson ▁
# wandb:                             test_combo_seen1_pearson_de ▁
# wandb:                          test_combo_seen1_pearson_delta ▁
# wandb:                       test_combo_seen1_pearson_delta_de ▁
# wandb:                test_combo_seen1_pearson_delta_top100_de ▁
# wandb:                test_combo_seen1_pearson_delta_top200_de ▁
# wandb:               test_combo_seen1_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen1_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen1_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen1_pearson_top100_de ▁
# wandb:                      test_combo_seen1_pearson_top200_de ▁
# wandb:                     test_combo_seen1_pearson_top200_hvg ▁
# wandb:                       test_combo_seen1_pearson_top20_de ▁
# wandb:                       test_combo_seen1_pearson_top50_de ▁
# wandb:                                     test_combo_seen1_r2 ▁
# wandb:                                  test_combo_seen1_r2_de ▁
# wandb:                               test_combo_seen1_spearman ▁
# wandb:                            test_combo_seen1_spearman_de ▁
# wandb:                              test_combo_seen1_std_sigma ▁
# wandb:                    test_combo_seen2_fold_change_gap_all ▁
# wandb:            test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen2_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen2_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen2_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen2_frac_in_range ▁
# wandb:                    test_combo_seen2_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen2_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen2_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen2_mae ▁
# wandb:                                 test_combo_seen2_mae_de ▁
# wandb:                             test_combo_seen2_mean_sigma ▁
# wandb:                                    test_combo_seen2_mse ▁
# wandb:                                 test_combo_seen2_mse_de ▁
# wandb:                          test_combo_seen2_mse_top100_de ▁
# wandb:                          test_combo_seen2_mse_top200_de ▁
# wandb:                         test_combo_seen2_mse_top200_hvg ▁
# wandb:                           test_combo_seen2_mse_top20_de ▁
# wandb:                           test_combo_seen2_mse_top50_de ▁
# wandb:                                test_combo_seen2_pearson ▁
# wandb:                             test_combo_seen2_pearson_de ▁
# wandb:                          test_combo_seen2_pearson_delta ▁
# wandb:                       test_combo_seen2_pearson_delta_de ▁
# wandb:                test_combo_seen2_pearson_delta_top100_de ▁
# wandb:                test_combo_seen2_pearson_delta_top200_de ▁
# wandb:               test_combo_seen2_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen2_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen2_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen2_pearson_top100_de ▁
# wandb:                      test_combo_seen2_pearson_top200_de ▁
# wandb:                     test_combo_seen2_pearson_top200_hvg ▁
# wandb:                       test_combo_seen2_pearson_top20_de ▁
# wandb:                       test_combo_seen2_pearson_top50_de ▁
# wandb:                                     test_combo_seen2_r2 ▁
# wandb:                                  test_combo_seen2_r2_de ▁
# wandb:                               test_combo_seen2_spearman ▁
# wandb:                            test_combo_seen2_spearman_de ▁
# wandb:                              test_combo_seen2_std_sigma ▁
# wandb:                                             test_de_mae ▁
# wandb:                                             test_de_mse ▁
# wandb:                                         test_de_pearson ▁
# wandb:                                              test_de_r2 ▁
# wandb:                                        test_de_spearman ▁
# wandb:                                test_fold_change_gap_all ▁
# wandb:                        test_fold_change_gap_downreg_0.1
# wandb:                       test_fold_change_gap_downreg_0.33 ▁
# wandb:                           test_fold_change_gap_upreg_10 ▁
# wandb:                            test_fold_change_gap_upreg_3 ▁
# wandb:                                      test_frac_in_range ▁
# wandb:                                test_frac_in_range_25_75 ▁
# wandb:                                test_frac_in_range_40_60 ▁
# wandb:                                test_frac_in_range_45_55 ▁
# wandb:                                 test_frac_sigma_below_1 ▁
# wandb:                                 test_frac_sigma_below_2 ▁
# wandb:                                                test_mae ▁
# wandb:                                         test_mean_sigma ▁
# wandb:                                                test_mse ▁
# wandb:                                      test_mse_top100_de ▁
# wandb:                                      test_mse_top200_de ▁
# wandb:                                     test_mse_top200_hvg ▁
# wandb:                                       test_mse_top20_de ▁
# wandb:                                       test_mse_top50_de ▁
# wandb:                                            test_pearson ▁
# wandb:                                      test_pearson_delta ▁
# wandb:                                   test_pearson_delta_de ▁
# wandb:                            test_pearson_delta_top100_de ▁
# wandb:                            test_pearson_delta_top200_de ▁
# wandb:                           test_pearson_delta_top200_hvg ▁
# wandb:                             test_pearson_delta_top20_de ▁
# wandb:                             test_pearson_delta_top50_de ▁
# wandb:                                  test_pearson_top100_de ▁
# wandb:                                  test_pearson_top200_de ▁
# wandb:                                 test_pearson_top200_hvg ▁
# wandb:                                   test_pearson_top20_de ▁
# wandb:                                   test_pearson_top50_de ▁
# wandb:                                                 test_r2 ▁
# wandb:                                           test_spearman ▁
# wandb:                                          test_std_sigma ▁
# wandb:                  test_unseen_single_fold_change_gap_all ▁
# wandb:          test_unseen_single_fold_change_gap_downreg_0.1
# wandb:         test_unseen_single_fold_change_gap_downreg_0.33
# wandb:             test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:              test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                        test_unseen_single_frac_in_range ▁
# wandb:                  test_unseen_single_frac_in_range_25_75 ▁
# wandb:                  test_unseen_single_frac_in_range_40_60 ▁
# wandb:                  test_unseen_single_frac_in_range_45_55 ▁
# wandb:                   test_unseen_single_frac_sigma_below_1 ▁
# wandb:                   test_unseen_single_frac_sigma_below_2 ▁
# wandb:                                  test_unseen_single_mae ▁
# wandb:                               test_unseen_single_mae_de ▁
# wandb:                           test_unseen_single_mean_sigma ▁
# wandb:                                  test_unseen_single_mse ▁
# wandb:                               test_unseen_single_mse_de ▁
# wandb:                        test_unseen_single_mse_top100_de ▁
# wandb:                        test_unseen_single_mse_top200_de ▁
# wandb:                       test_unseen_single_mse_top200_hvg ▁
# wandb:                         test_unseen_single_mse_top20_de ▁
# wandb:                         test_unseen_single_mse_top50_de ▁
# wandb:                              test_unseen_single_pearson ▁
# wandb:                           test_unseen_single_pearson_de ▁
# wandb:                        test_unseen_single_pearson_delta ▁
# wandb:                     test_unseen_single_pearson_delta_de ▁
# wandb:              test_unseen_single_pearson_delta_top100_de ▁
# wandb:              test_unseen_single_pearson_delta_top200_de ▁
# wandb:             test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:               test_unseen_single_pearson_delta_top20_de ▁
# wandb:               test_unseen_single_pearson_delta_top50_de ▁
# wandb:                    test_unseen_single_pearson_top100_de ▁
# wandb:                    test_unseen_single_pearson_top200_de ▁
# wandb:                   test_unseen_single_pearson_top200_hvg ▁
# wandb:                     test_unseen_single_pearson_top20_de ▁
# wandb:                     test_unseen_single_pearson_top50_de ▁
# wandb:                                   test_unseen_single_r2 ▁
# wandb:                                test_unseen_single_r2_de ▁
# wandb:                             test_unseen_single_spearman ▁
# wandb:                          test_unseen_single_spearman_de ▁
# wandb:                            test_unseen_single_std_sigma ▁
# wandb:                                            train_de_mae ▅█▅▄▄▂▁▁▁▁
# wandb:                                            train_de_mse ▄█▆▄▃▁▁▁▁▁
# wandb:                                        train_de_pearson ▁▃▂▃▄▆▇▇██
# wandb:                                             train_de_r2 █▅▆▄▁█▃▂▁▂
# wandb:                                       train_de_spearman ▁▄▃▅▆▆▇▇██
# wandb:                                               train_mae ▅▃▃▅█▁▄▂▄▃
# wandb:                                               train_mse ▄▆▇▆█▁▃▁▂▂
# wandb:                                           train_pearson ▇▁▄▄▄▇▇█▇▇
# wandb:                                                train_r2 ▆▂▆▆▁█▆█▇▇
# wandb:                                          train_spearman ▁▅▆▇▇▇████
# wandb:                                           training_loss █▄▄▄▄▄▅█▇▂▂▂▅▄▅▄▄▅▆▆▃▃▃▃▆▂▃▃▂▆▂▂▄▂▆▄▂▁▆▃
# wandb:                                              val_de_mae ▅█▆▄▅▂▁▁▁▁
# wandb:                                              val_de_mse ▅█▇▄▃▂▁▁▁▁
# wandb:                                          val_de_pearson ▂▃▁▃▄▇▇███
# wandb:                                               val_de_r2 ▇▇█▅▁▇▁▄▂▂
# wandb:                                         val_de_spearman ▁▇▅▇▇▇█▇██
# wandb:                                                 val_mae ▄▃▃▅█▁▄▃▄▄
# wandb:                                                 val_mse ▂▆▆▆█▁▂▁▂▂
# wandb:                                             val_pearson █▁▄▅▅▇▇█▇▇
# wandb:                                                  val_r2 ▆▁▇▆▁█▆█▆▇
# wandb:                                            val_spearman ▁▅▆▇▇▇████
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced no_gnn_no_perturb_emb: https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/1vxii28o

# %%
# !python train.py --dataset Norman2019 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l2\
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:4 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --no_gnn \
                 --exp_name no_gnn_l2 \
                 --wandb
# Out:
# ---- Printing Arguments ----
# dataset: Norman2019
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:4
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: False
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: True
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l2
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: no_gnn_l2
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run no_gnn_l2
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/1n9z5y5w
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211109_205325-1n9z5y5w
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_co-expression_100.0_64_2_l2_Norman2019_gene_emb_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 24886 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:9
# combo_seen1:52
# combo_seen2:18
# unseen_single:37
# Creating dataloaders....
# Dataloaders created...
# Finished data setup, in total takes 0.951 min
# Initializing model...
# Start Training...
# Epoch 2 Step 1201 Train Loss: 0.0358
# Epoch 2 Step 1251 Train Loss: 0.0440
# Epoch 2 Step 1301 Train Loss: 0.0401
# Epoch 2 Step 1351 Train Loss: 0.0430
# Epoch 2 Step 1401 Train Loss: 0.0459
# Epoch 2 Step 1451 Train Loss: 0.0407
# Epoch 2 Step 1501 Train Loss: 0.0458
# Epoch 2 Step 1551 Train Loss: 0.0354
# Epoch 2 Step 1601 Train Loss: 0.0424
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 2: Train: 0.0307, R2 0.4634 Validation: 0.0296. R2 0.4822 Loss: 0.0416
# DE_Train: 0.7442, R2 -1.2817 DE_Validation: 0.5899. R2 -0.5980
# Epoch 3 Step 1 Train Loss: 0.0332
# Epoch 3 Step 51 Train Loss: 0.0446
# Epoch 3 Step 101 Train Loss: 0.0451
# Epoch 3 Step 151 Train Loss: 0.0355
# Epoch 3 Step 201 Train Loss: 0.0360
# Epoch 3 Step 251 Train Loss: 0.0438
# Epoch 3 Step 301 Train Loss: 0.0384
# Epoch 3 Step 351 Train Loss: 0.0371
# Epoch 3 Step 401 Train Loss: 0.0416
# Epoch 3 Step 451 Train Loss: 0.0423
# Epoch 3 Step 501 Train Loss: 0.0420
# Epoch 3 Step 551 Train Loss: 0.0352
# Epoch 3 Step 601 Train Loss: 0.0435
# Epoch 3 Step 651 Train Loss: 0.0332
# Epoch 3 Step 701 Train Loss: 0.0399
# Epoch 3 Step 751 Train Loss: 0.0350
# Epoch 3 Step 801 Train Loss: 0.0363
# Epoch 3 Step 851 Train Loss: 0.0457
# Epoch 3 Step 901 Train Loss: 0.0464
# Epoch 3 Step 951 Train Loss: 0.0400
# Epoch 3 Step 1001 Train Loss: 0.0434
# Epoch 3 Step 1051 Train Loss: 0.0476
# Epoch 3 Step 1101 Train Loss: 0.0404
# Epoch 3 Step 1151 Train Loss: 0.0424
# Epoch 3 Step 1201 Train Loss: 0.0472
# Epoch 3 Step 1251 Train Loss: 0.0348
# Epoch 3 Step 1301 Train Loss: 0.0374
# Epoch 3 Step 1351 Train Loss: 0.0363
# Epoch 3 Step 1401 Train Loss: 0.0491
# Epoch 3 Step 1451 Train Loss: 0.0463
# Epoch 3 Step 1501 Train Loss: 0.0395
# Epoch 3 Step 1551 Train Loss: 0.0481
# Epoch 3 Step 1601 Train Loss: 0.0475
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 3: Train: 0.0043, R2 0.9762 Validation: 0.0041. R2 0.9770 Loss: 0.0414
# DE_Train: 0.2933, R2 0.5958 DE_Validation: 0.2562. R2 0.6237
# Epoch 4 Step 1 Train Loss: 0.0369
# Epoch 4 Step 51 Train Loss: 0.0394
# Epoch 4 Step 101 Train Loss: 0.0367
# Epoch 4 Step 151 Train Loss: 0.0386
# Epoch 4 Step 201 Train Loss: 0.0386
# Epoch 4 Step 251 Train Loss: 0.0445
# Epoch 4 Step 301 Train Loss: 0.0344
# Epoch 4 Step 351 Train Loss: 0.0391
# Epoch 4 Step 401 Train Loss: 0.0399
# Epoch 4 Step 451 Train Loss: 0.0348
# Epoch 4 Step 501 Train Loss: 0.0412
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 5: Train: 0.0039, R2 0.9746 Validation: 0.0036. R2 0.9758 Loss: 0.0411
# DE_Train: 0.3143, R2 0.5362 DE_Validation: 0.2609. R2 0.5925
# Epoch 6 Step 1 Train Loss: 0.0421
# Epoch 6 Step 51 Train Loss: 0.0339
# Epoch 6 Step 101 Train Loss: 0.0522
# Epoch 6 Step 151 Train Loss: 0.0370
# Epoch 6 Step 201 Train Loss: 0.0443
# Epoch 6 Step 251 Train Loss: 0.0378
# Epoch 6 Step 301 Train Loss: 0.0393
# Epoch 6 Step 351 Train Loss: 0.0478
# Epoch 6 Step 401 Train Loss: 0.0355
# Epoch 6 Step 451 Train Loss: 0.0405
# Epoch 6 Step 501 Train Loss: 0.0397
# Epoch 6 Step 551 Train Loss: 0.0434
# Epoch 6 Step 601 Train Loss: 0.0402
# Epoch 6 Step 651 Train Loss: 0.0394
# Epoch 6 Step 701 Train Loss: 0.0431
# Epoch 6 Step 751 Train Loss: 0.0431
# Epoch 6 Step 801 Train Loss: 0.0426
# Epoch 6 Step 851 Train Loss: 0.0427
# Epoch 6 Step 901 Train Loss: 0.0431
# Epoch 6 Step 951 Train Loss: 0.0405
# Epoch 6 Step 1001 Train Loss: 0.0458
# Epoch 6 Step 1051 Train Loss: 0.0445
# Epoch 6 Step 1101 Train Loss: 0.0402
# Epoch 6 Step 1151 Train Loss: 0.0411
# Epoch 6 Step 1201 Train Loss: 0.0401
# Epoch 6 Step 1251 Train Loss: 0.0350
# Epoch 6 Step 1301 Train Loss: 0.0453
# Epoch 6 Step 1351 Train Loss: 0.0405
# Epoch 6 Step 1401 Train Loss: 0.0341
# Epoch 6 Step 1451 Train Loss: 0.0456
# Epoch 6 Step 1501 Train Loss: 0.0437
# Epoch 6 Step 1551 Train Loss: 0.0451
# Epoch 6 Step 1601 Train Loss: 0.0380
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 6: Train: 0.0065, R2 0.9461 Validation: 0.0061. R2 0.9486 Loss: 0.0412
# DE_Train: 0.3698, R2 0.3639 DE_Validation: 0.3001. R2 0.4619
# Epoch 7 Step 1 Train Loss: 0.0395
# Epoch 7 Step 51 Train Loss: 0.0439
# Epoch 7 Step 101 Train Loss: 0.0467
# Epoch 7 Step 151 Train Loss: 0.0426
# Epoch 7 Step 201 Train Loss: 0.0433
# Epoch 7 Step 251 Train Loss: 0.0402
# Epoch 7 Step 301 Train Loss: 0.0432
# Epoch 7 Step 351 Train Loss: 0.0370
# Epoch 7 Step 401 Train Loss: 0.0442
# Epoch 7 Step 451 Train Loss: 0.0361
# Epoch 7 Step 501 Train Loss: 0.0356
# Epoch 7 Step 551 Train Loss: 0.0361
# Epoch 7 Step 601 Train Loss: 0.0381
# Epoch 7 Step 651 Train Loss: 0.0471
# Epoch 7 Step 701 Train Loss: 0.0395
# Epoch 7 Step 751 Train Loss: 0.0402
# Epoch 7 Step 801 Train Loss: 0.0356
# Epoch 7 Step 851 Train Loss: 0.0390
# Epoch 7 Step 901 Train Loss: 0.0407
# Epoch 7 Step 951 Train Loss: 0.0416
# Epoch 7 Step 1001 Train Loss: 0.0405
# Epoch 7 Step 1051 Train Loss: 0.0499
# Epoch 7 Step 1101 Train Loss: 0.0442
# Epoch 7 Step 1151 Train Loss: 0.0418
# Epoch 7 Step 1201 Train Loss: 0.0389
# Epoch 7 Step 1251 Train Loss: 0.0367
# Epoch 7 Step 1301 Train Loss: 0.0457
# Epoch 7 Step 1351 Train Loss: 0.0454
# Epoch 7 Step 1401 Train Loss: 0.0360
# Epoch 7 Step 1451 Train Loss: 0.0480
# Epoch 7 Step 1501 Train Loss: 0.0370
# Epoch 7 Step 1551 Train Loss: 0.0468
# Epoch 7 Step 1601 Train Loss: 0.0435
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 7: Train: 0.0036, R2 0.9777 Validation: 0.0034. R2 0.9786 Loss: 0.0411
# DE_Train: 0.2984, R2 0.5459 DE_Validation: 0.2546. R2 0.5789
# Epoch 8 Step 1 Train Loss: 0.0367
# Epoch 8 Step 51 Train Loss: 0.0414
# Epoch 8 Step 101 Train Loss: 0.0389
# Epoch 8 Step 151 Train Loss: 0.0396
# Epoch 8 Step 201 Train Loss: 0.0468
# Epoch 8 Step 251 Train Loss: 0.0451
# Epoch 8 Step 301 Train Loss: 0.0401
# Epoch 8 Step 351 Train Loss: 0.0367
# Epoch 8 Step 401 Train Loss: 0.0482
# Epoch 8 Step 451 Train Loss: 0.0478
# Epoch 8 Step 501 Train Loss: 0.0416
# Epoch 8 Step 551 Train Loss: 0.0497
# Epoch 8 Step 601 Train Loss: 0.0426
# Epoch 8 Step 651 Train Loss: 0.0429
# Epoch 8 Step 701 Train Loss: 0.0396
# Epoch 8 Step 751 Train Loss: 0.0445
# Epoch 8 Step 801 Train Loss: 0.0390
# Epoch 8 Step 851 Train Loss: 0.0395
# Epoch 8 Step 901 Train Loss: 0.0396
# Epoch 8 Step 951 Train Loss: 0.0479
# Epoch 8 Step 1001 Train Loss: 0.0452
# Epoch 8 Step 1051 Train Loss: 0.0493
# Epoch 8 Step 1101 Train Loss: 0.0351
# Epoch 8 Step 1151 Train Loss: 0.0427
# Epoch 8 Step 1201 Train Loss: 0.0468
# Epoch 8 Step 1251 Train Loss: 0.0411
# Epoch 8 Step 1301 Train Loss: 0.0467
# Epoch 8 Step 1351 Train Loss: 0.0368
# Epoch 8 Step 1401 Train Loss: 0.0422
# Epoch 8 Step 1451 Train Loss: 0.0362
# Epoch 8 Step 1501 Train Loss: 0.0408
# Epoch 8 Step 1551 Train Loss: 0.0380
# Epoch 8 Step 1601 Train Loss: 0.0463
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 8: Train: 0.0037, R2 0.9765 Validation: 0.0034. R2 0.9777 Loss: 0.0411
# DE_Train: 0.3045, R2 0.5135 DE_Validation: 0.2576. R2 0.5515
# Epoch 9 Step 1 Train Loss: 0.0351
# Epoch 9 Step 51 Train Loss: 0.0354
# Epoch 9 Step 101 Train Loss: 0.0357
# Epoch 9 Step 151 Train Loss: 0.0369
# Epoch 9 Step 201 Train Loss: 0.0441
# Epoch 9 Step 251 Train Loss: 0.0416
# Epoch 9 Step 301 Train Loss: 0.0444
# Epoch 9 Step 351 Train Loss: 0.0348
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 10: Train: 0.0036, R2 0.9780 Validation: 0.0035. R2 0.9787 Loss: 0.0411
# DE_Train: 0.2973, R2 0.5593 DE_Validation: 0.2549. R2 0.5967
# Saving model....
# Start testing....
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Final best performing model: Test_DE: 0.3074, R2 0.3460
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# ...
# wandb:              test_SYNERGY_DISSIMILAR_PHENO_mse_top50_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_fold_change_gap_all ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_40_60 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_45_55 ▁
# wandb:                   test_SYNERGY_SIMILAR_PHENO_mean_sigma ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top100_de ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top200_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top20_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top50_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:                    test_combo_seen0_fold_change_gap_all ▁
# wandb:            test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:               test_combo_seen0_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen0_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen0_frac_in_range ▁
# wandb:                    test_combo_seen0_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen0_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen0_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen0_mae ▁
# wandb:                                 test_combo_seen0_mae_de ▁
# wandb:                             test_combo_seen0_mean_sigma ▁
# wandb:                                    test_combo_seen0_mse ▁
# wandb:                                 test_combo_seen0_mse_de ▁
# wandb:                          test_combo_seen0_mse_top100_de ▁
# wandb:                          test_combo_seen0_mse_top200_de ▁
# wandb:                         test_combo_seen0_mse_top200_hvg ▁
# wandb:                           test_combo_seen0_mse_top20_de ▁
# wandb:                           test_combo_seen0_mse_top50_de ▁
# wandb:                                test_combo_seen0_pearson ▁
# wandb:                             test_combo_seen0_pearson_de ▁
# wandb:                          test_combo_seen0_pearson_delta ▁
# wandb:                       test_combo_seen0_pearson_delta_de ▁
# wandb:                test_combo_seen0_pearson_delta_top100_de ▁
# wandb:                test_combo_seen0_pearson_delta_top200_de ▁
# wandb:               test_combo_seen0_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen0_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen0_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen0_pearson_top100_de ▁
# wandb:                      test_combo_seen0_pearson_top200_de ▁
# wandb:                     test_combo_seen0_pearson_top200_hvg ▁
# wandb:                       test_combo_seen0_pearson_top20_de ▁
# wandb:                       test_combo_seen0_pearson_top50_de ▁
# wandb:                                     test_combo_seen0_r2 ▁
# wandb:                                  test_combo_seen0_r2_de ▁
# wandb:                               test_combo_seen0_spearman ▁
# wandb:                            test_combo_seen0_spearman_de ▁
# wandb:                              test_combo_seen0_std_sigma ▁
# wandb:                    test_combo_seen1_fold_change_gap_all ▁
# wandb:            test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen1_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen1_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen1_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen1_frac_in_range ▁
# wandb:                    test_combo_seen1_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen1_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen1_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen1_mae ▁
# wandb:                                 test_combo_seen1_mae_de ▁
# wandb:                             test_combo_seen1_mean_sigma ▁
# wandb:                                    test_combo_seen1_mse ▁
# wandb:                                 test_combo_seen1_mse_de ▁
# wandb:                          test_combo_seen1_mse_top100_de ▁
# wandb:                          test_combo_seen1_mse_top200_de ▁
# wandb:                         test_combo_seen1_mse_top200_hvg ▁
# wandb:                           test_combo_seen1_mse_top20_de ▁
# wandb:                           test_combo_seen1_mse_top50_de ▁
# wandb:                                test_combo_seen1_pearson ▁
# wandb:                             test_combo_seen1_pearson_de ▁
# wandb:                          test_combo_seen1_pearson_delta ▁
# wandb:                       test_combo_seen1_pearson_delta_de ▁
# wandb:                test_combo_seen1_pearson_delta_top100_de ▁
# wandb:                test_combo_seen1_pearson_delta_top200_de ▁
# wandb:               test_combo_seen1_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen1_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen1_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen1_pearson_top100_de ▁
# wandb:                      test_combo_seen1_pearson_top200_de ▁
# wandb:                     test_combo_seen1_pearson_top200_hvg ▁
# wandb:                       test_combo_seen1_pearson_top20_de ▁
# wandb:                       test_combo_seen1_pearson_top50_de ▁
# wandb:                                     test_combo_seen1_r2 ▁
# wandb:                                  test_combo_seen1_r2_de ▁
# wandb:                               test_combo_seen1_spearman ▁
# wandb:                            test_combo_seen1_spearman_de ▁
# wandb:                              test_combo_seen1_std_sigma ▁
# wandb:                    test_combo_seen2_fold_change_gap_all ▁
# wandb:            test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen2_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen2_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen2_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen2_frac_in_range ▁
# wandb:                    test_combo_seen2_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen2_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen2_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen2_mae ▁
# wandb:                                 test_combo_seen2_mae_de ▁
# wandb:                             test_combo_seen2_mean_sigma ▁
# wandb:                                    test_combo_seen2_mse ▁
# wandb:                                 test_combo_seen2_mse_de ▁
# wandb:                          test_combo_seen2_mse_top100_de ▁
# wandb:                          test_combo_seen2_mse_top200_de ▁
# wandb:                         test_combo_seen2_mse_top200_hvg ▁
# wandb:                           test_combo_seen2_mse_top20_de ▁
# wandb:                           test_combo_seen2_mse_top50_de ▁
# wandb:                                test_combo_seen2_pearson ▁
# wandb:                             test_combo_seen2_pearson_de ▁
# wandb:                          test_combo_seen2_pearson_delta ▁
# wandb:                       test_combo_seen2_pearson_delta_de ▁
# wandb:                test_combo_seen2_pearson_delta_top100_de ▁
# wandb:                test_combo_seen2_pearson_delta_top200_de ▁
# wandb:               test_combo_seen2_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen2_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen2_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen2_pearson_top100_de ▁
# wandb:                      test_combo_seen2_pearson_top200_de ▁
# wandb:                     test_combo_seen2_pearson_top200_hvg ▁
# wandb:                       test_combo_seen2_pearson_top20_de ▁
# wandb:                       test_combo_seen2_pearson_top50_de ▁
# wandb:                                     test_combo_seen2_r2 ▁
# wandb:                                  test_combo_seen2_r2_de ▁
# wandb:                               test_combo_seen2_spearman ▁
# wandb:                            test_combo_seen2_spearman_de ▁
# wandb:                              test_combo_seen2_std_sigma ▁
# wandb:                                             test_de_mae ▁
# wandb:                                             test_de_mse ▁
# wandb:                                         test_de_pearson ▁
# wandb:                                              test_de_r2 ▁
# wandb:                                        test_de_spearman ▁
# wandb:                                test_fold_change_gap_all ▁
# wandb:                        test_fold_change_gap_downreg_0.1
# wandb:                       test_fold_change_gap_downreg_0.33 ▁
# wandb:                           test_fold_change_gap_upreg_10 ▁
# wandb:                            test_fold_change_gap_upreg_3 ▁
# wandb:                                      test_frac_in_range ▁
# wandb:                                test_frac_in_range_25_75 ▁
# wandb:                                test_frac_in_range_40_60 ▁
# wandb:                                test_frac_in_range_45_55 ▁
# wandb:                                 test_frac_sigma_below_1 ▁
# wandb:                                 test_frac_sigma_below_2 ▁
# wandb:                                                test_mae ▁
# wandb:                                         test_mean_sigma ▁
# wandb:                                                test_mse ▁
# wandb:                                      test_mse_top100_de ▁
# wandb:                                      test_mse_top200_de ▁
# wandb:                                     test_mse_top200_hvg ▁
# wandb:                                       test_mse_top20_de ▁
# wandb:                                       test_mse_top50_de ▁
# wandb:                                            test_pearson ▁
# wandb:                                      test_pearson_delta ▁
# wandb:                                   test_pearson_delta_de ▁
# wandb:                            test_pearson_delta_top100_de ▁
# wandb:                            test_pearson_delta_top200_de ▁
# wandb:                           test_pearson_delta_top200_hvg ▁
# wandb:                             test_pearson_delta_top20_de ▁
# wandb:                             test_pearson_delta_top50_de ▁
# wandb:                                  test_pearson_top100_de ▁
# wandb:                                  test_pearson_top200_de ▁
# wandb:                                 test_pearson_top200_hvg ▁
# wandb:                                   test_pearson_top20_de ▁
# wandb:                                   test_pearson_top50_de ▁
# wandb:                                                 test_r2 ▁
# wandb:                                           test_spearman ▁
# wandb:                                          test_std_sigma ▁
# wandb:                  test_unseen_single_fold_change_gap_all ▁
# wandb:          test_unseen_single_fold_change_gap_downreg_0.1
# wandb:         test_unseen_single_fold_change_gap_downreg_0.33
# wandb:             test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:              test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                        test_unseen_single_frac_in_range ▁
# wandb:                  test_unseen_single_frac_in_range_25_75 ▁
# wandb:                  test_unseen_single_frac_in_range_40_60 ▁
# wandb:                  test_unseen_single_frac_in_range_45_55 ▁
# wandb:                   test_unseen_single_frac_sigma_below_1 ▁
# wandb:                   test_unseen_single_frac_sigma_below_2 ▁
# wandb:                                  test_unseen_single_mae ▁
# wandb:                               test_unseen_single_mae_de ▁
# wandb:                           test_unseen_single_mean_sigma ▁
# wandb:                                  test_unseen_single_mse ▁
# wandb:                               test_unseen_single_mse_de ▁
# wandb:                        test_unseen_single_mse_top100_de ▁
# wandb:                        test_unseen_single_mse_top200_de ▁
# wandb:                       test_unseen_single_mse_top200_hvg ▁
# wandb:                         test_unseen_single_mse_top20_de ▁
# wandb:                         test_unseen_single_mse_top50_de ▁
# wandb:                              test_unseen_single_pearson ▁
# wandb:                           test_unseen_single_pearson_de ▁
# wandb:                        test_unseen_single_pearson_delta ▁
# wandb:                     test_unseen_single_pearson_delta_de ▁
# wandb:              test_unseen_single_pearson_delta_top100_de ▁
# wandb:              test_unseen_single_pearson_delta_top200_de ▁
# wandb:             test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:               test_unseen_single_pearson_delta_top20_de ▁
# wandb:               test_unseen_single_pearson_delta_top50_de ▁
# wandb:                    test_unseen_single_pearson_top100_de ▁
# wandb:                    test_unseen_single_pearson_top200_de ▁
# wandb:                   test_unseen_single_pearson_top200_hvg ▁
# wandb:                     test_unseen_single_pearson_top20_de ▁
# wandb:                     test_unseen_single_pearson_top50_de ▁
# wandb:                                   test_unseen_single_r2 ▁
# wandb:                                test_unseen_single_r2_de ▁
# wandb:                             test_unseen_single_spearman ▁
# wandb:                          test_unseen_single_spearman_de ▁
# wandb:                            test_unseen_single_std_sigma ▁
# wandb:                                            train_de_mae ▂█▁▂▁▂▁▁▁▁
# wandb:                                            train_de_mse ▂█▁▂▁▂▁▁▁▁
# wandb:                                        train_de_pearson ▁█▄▆▅▆▅▅▅▅
# wandb:                                             train_de_r2 ▇▁█▇█▇████
# wandb:                                       train_de_spearman ▁█▄▆▅▇▅▅▅▅
# wandb:                                               train_mae █▇▂▂▁▂▁▁▁▁
# wandb:                                               train_mse ▃█▁▂▁▂▁▁▁▁
# wandb:                                           train_pearson ▅▁▇▇▇█████
# wandb:                                                train_r2 █▁████████
# wandb:                                          train_spearman ▄▅█▁▆▄▇█▇█
# wandb:                                           training_loss ▅▄▃▄▄▅▅▇▅▂▂▃▅▄▅▄▅▆▇█▂▄▄▂▅▂▄▂▂▅▂▂▄▄▅▄▂▁█▃
# wandb:                                              val_de_mae ▄█▁▂▁▂▁▁▁▁
# wandb:                                              val_de_mse ▂█▁▂▁▂▁▁▁▁
# wandb:                                          val_de_pearson ▁▆▇▇▇█▇▇▇▇
# wandb:                                               val_de_r2 ▆▁█▇█▇████
# wandb:                                         val_de_spearman ▁▇▇█▇█▇▇▇▇
# wandb:                                                 val_mae █▇▂▂▁▂▁▁▁▁
# wandb:                                                 val_mse ▃█▁▂▁▂▁▁▁▁
# wandb:                                             val_pearson ▅▁█▇▇█████
# wandb:                                                  val_r2 █▁████████
# wandb:                                            val_spearman ▅▅█▁▆▄▆▇▇▇
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced no_gnn_l2: https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/1n9z5y5w

# %%
# !python train.py --dataset Adamson2016 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3 \
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:4 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --no_gnn \
                 --exp_name no_gnn \
                 --wandb
# Out:
# ---- Printing Arguments ----
# dataset: Adamson2016
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:4
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: False
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: True
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: no_gnn
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run no_gnn
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016/runs/1se9xojk
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_205208-1se9xojk
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_co-expression_100.0_64_2_l3_Adamson2016_gamma2_gene_emb_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 7054 edges in the PPI.
# Creating pyg object for each cell in the data...
# Processing dataset...
#   0%|                                                    | 0/87 [00:00<?, ?it/s]CREB1+ctrl
#   1%|▌                                           | 1/87 [00:01<02:34,  1.79s/it]ctrl
#   2%|█                                           | 2/87 [00:05<04:06,  2.90s/it]ZNF326+ctrl
#   3%|█▌                                          | 3/87 [00:06<03:10,  2.26s/it]BHLHE40+ctrl
#   5%|██                                          | 4/87 [00:08<02:41,  1.94s/it]DDIT3+ctrl
# OST4+ctrl
#   7%|███                                         | 6/87 [00:11<02:11,  1.62s/it]SEC61A1+ctrl
#   8%|███▌                                        | 7/87 [00:13<02:36,  1.96s/it]EIF2B4+ctrl
#   9%|████                                        | 8/87 [00:15<02:27,  1.87s/it]SRPR+ctrl
#  10%|████▌                                       | 9/87 [00:16<02:16,  1.74s/it]IER3IP1+ctrl
# Epoch 5 Step 901 Train Loss: 0.0771
# Epoch 5 Step 951 Train Loss: 0.0613
# Epoch 5 Step 1001 Train Loss: 0.0726
# Epoch 5 Step 1051 Train Loss: 0.0981
# Epoch 5 Step 1101 Train Loss: 0.0999
# Epoch 5 Step 1151 Train Loss: 0.0829
# Epoch 5 Step 1201 Train Loss: 0.0730
# Epoch 5 Step 1251 Train Loss: 0.0641
# Epoch 5 Step 1301 Train Loss: 0.0954
# Epoch 5 Step 1351 Train Loss: 0.1263
# Epoch 5 Step 1401 Train Loss: 0.0621
# Epoch 5 Step 1451 Train Loss: 0.0887
# Epoch 5 Step 1501 Train Loss: 0.0789
# Epoch 5 Step 1551 Train Loss: 0.1209
# Epoch 5 Step 1601 Train Loss: 0.1191
# Epoch 5 Step 1651 Train Loss: 0.1429
# Epoch 5: Train: 0.0321, R2 0.8862 Validation: 0.0308. R2 0.8892 Loss: 0.0831
# DE_Train: 0.2627, R2 0.8462 DE_Validation: 0.3062. R2 0.8347
# Epoch 6 Step 1 Train Loss: 0.0848
# Epoch 6 Step 51 Train Loss: 0.0796
# Epoch 6 Step 101 Train Loss: 0.0830
# Epoch 6 Step 151 Train Loss: 0.0741
# Epoch 6 Step 201 Train Loss: 0.0745
# Epoch 6 Step 251 Train Loss: 0.0885
# Epoch 6 Step 301 Train Loss: 0.0788
# Epoch 6 Step 351 Train Loss: 0.0838
# Epoch 6 Step 401 Train Loss: 0.0910
# Epoch 6 Step 451 Train Loss: 0.1046
# Epoch 6 Step 501 Train Loss: 0.0835
# Epoch 6 Step 551 Train Loss: 0.0940
# Epoch 6 Step 601 Train Loss: 0.0991
# Epoch 6 Step 651 Train Loss: 0.0898
# Epoch 6 Step 701 Train Loss: 0.0853
# Epoch 6 Step 751 Train Loss: 0.0569
# Epoch 6 Step 801 Train Loss: 0.0869
# Epoch 6 Step 851 Train Loss: 0.0886
# Epoch 6 Step 901 Train Loss: 0.0823
# Epoch 6 Step 951 Train Loss: 0.0929
# Epoch 6 Step 1001 Train Loss: 0.0602
# Epoch 6 Step 1051 Train Loss: 0.0696
# Epoch 6 Step 1101 Train Loss: 0.0727
# Epoch 6 Step 1151 Train Loss: 0.0905
# Epoch 6 Step 1201 Train Loss: 0.0778
# Epoch 6 Step 1251 Train Loss: 0.0730
# Epoch 6 Step 1301 Train Loss: 0.0832
# Epoch 6 Step 1351 Train Loss: 0.0706
# Epoch 6 Step 1401 Train Loss: 0.0791
# Epoch 6 Step 1451 Train Loss: 0.0949
# Epoch 6 Step 1501 Train Loss: 0.0806
# Epoch 6 Step 1551 Train Loss: 0.0860
# Epoch 6 Step 1601 Train Loss: 0.0615
# Epoch 6 Step 1651 Train Loss: 0.0831
# Epoch 6: Train: 0.0274, R2 0.8752 Validation: 0.0256. R2 0.8824 Loss: 0.0828
# DE_Train: 0.1439, R2 0.8823 DE_Validation: 0.2036. R2 0.8328
# Epoch 7 Step 1 Train Loss: 0.1068
# Epoch 7 Step 51 Train Loss: 0.0725
# Epoch 7 Step 101 Train Loss: 0.0659
# Epoch 7 Step 151 Train Loss: 0.0810
# Epoch 7 Step 201 Train Loss: 0.0657
# Epoch 7 Step 251 Train Loss: 0.1119
# Epoch 7 Step 301 Train Loss: 0.0729
# Epoch 7 Step 351 Train Loss: 0.0729
# Epoch 7 Step 401 Train Loss: 0.0855
# Epoch 7 Step 451 Train Loss: 0.0721
# Epoch 7 Step 501 Train Loss: 0.0907
# Epoch 7 Step 551 Train Loss: 0.0621
# Epoch 7 Step 601 Train Loss: 0.0720
# Epoch 7 Step 651 Train Loss: 0.0810
# Epoch 7 Step 701 Train Loss: 0.0909
# Epoch 7 Step 751 Train Loss: 0.0871
# Epoch 7 Step 801 Train Loss: 0.0679
# Epoch 7 Step 851 Train Loss: 0.0882
# Epoch 7 Step 901 Train Loss: 0.0811
# Epoch 7 Step 951 Train Loss: 0.0906
# Epoch 7 Step 1001 Train Loss: 0.0880
# Epoch 7 Step 1051 Train Loss: 0.0812
# Epoch 7 Step 1101 Train Loss: 0.0718
# Epoch 7 Step 1151 Train Loss: 0.0774
# Epoch 7 Step 1201 Train Loss: 0.0722
# Epoch 7 Step 1251 Train Loss: 0.0596
# Epoch 7 Step 1301 Train Loss: 0.0792
# Epoch 7 Step 1351 Train Loss: 0.0957
# Epoch 7 Step 1401 Train Loss: 0.1015
# Epoch 7 Step 1451 Train Loss: 0.0703
# Epoch 7 Step 1501 Train Loss: 0.1179
# Epoch 7 Step 1551 Train Loss: 0.0657
# Epoch 7 Step 1601 Train Loss: 0.0741
# Epoch 7 Step 1651 Train Loss: 0.1216
# Epoch 7: Train: 0.0269, R2 0.8613 Validation: 0.0255. R2 0.8674 Loss: 0.0829
# DE_Train: 0.1957, R2 0.8238 DE_Validation: 0.2811. R2 0.7584
# Epoch 8 Step 1 Train Loss: 0.0687
# Epoch 8 Step 51 Train Loss: 0.1289
# Epoch 8 Step 101 Train Loss: 0.0749
# Epoch 8 Step 151 Train Loss: 0.0753
# Epoch 8 Step 201 Train Loss: 0.0804
# Epoch 8 Step 251 Train Loss: 0.0779
# Epoch 8 Step 301 Train Loss: 0.0721
# Epoch 8 Step 351 Train Loss: 0.0783
# Epoch 8 Step 401 Train Loss: 0.0627
# Epoch 8 Step 451 Train Loss: 0.0688
# Epoch 8 Step 501 Train Loss: 0.0728
# Epoch 8 Step 551 Train Loss: 0.1105
# Epoch 8 Step 601 Train Loss: 0.0839
# Epoch 8 Step 651 Train Loss: 0.0889
# Epoch 8 Step 701 Train Loss: 0.0820
# Epoch 8 Step 751 Train Loss: 0.1021
# Epoch 8 Step 801 Train Loss: 0.1054
# Epoch 8 Step 851 Train Loss: 0.0600
# Epoch 8 Step 901 Train Loss: 0.0726
# Epoch 8 Step 951 Train Loss: 0.0816
# Epoch 8 Step 1001 Train Loss: 0.1013
# Epoch 8 Step 1051 Train Loss: 0.0904
# Epoch 8 Step 1101 Train Loss: 0.0773
# Epoch 8 Step 1151 Train Loss: 0.1030
# Epoch 8 Step 1201 Train Loss: 0.0586
# Epoch 8 Step 1251 Train Loss: 0.0751
# Epoch 10 Step 551 Train Loss: 0.0877
# Epoch 10 Step 601 Train Loss: 0.0816
# Epoch 10 Step 651 Train Loss: 0.0625
# Epoch 10 Step 701 Train Loss: 0.0894
# Epoch 10 Step 751 Train Loss: 0.0577
# Epoch 10 Step 801 Train Loss: 0.0609
# Epoch 10 Step 851 Train Loss: 0.0631
# Epoch 10 Step 901 Train Loss: 0.1042
# Epoch 10 Step 951 Train Loss: 0.0764
# Epoch 10 Step 1001 Train Loss: 0.0756
# Epoch 10 Step 1051 Train Loss: 0.1379
# Epoch 10 Step 1101 Train Loss: 0.0763
# Epoch 10 Step 1151 Train Loss: 0.0881
# Epoch 10 Step 1201 Train Loss: 0.0822
# Epoch 10 Step 1251 Train Loss: 0.0783
# Epoch 10 Step 1301 Train Loss: 0.0799
# Epoch 10 Step 1351 Train Loss: 0.0994
# Epoch 10 Step 1401 Train Loss: 0.0789
# Epoch 10 Step 1451 Train Loss: 0.0741
# Epoch 10 Step 1501 Train Loss: 0.0686
# Epoch 10 Step 1551 Train Loss: 0.0633
# Epoch 10 Step 1601 Train Loss: 0.0927
# Epoch 10 Step 1651 Train Loss: 0.0740
# Epoch 10: Train: 0.0239, R2 0.8934 Validation: 0.0220. R2 0.9009 Loss: 0.0827
# DE_Train: 0.1294, R2 0.9020 DE_Validation: 0.1994. R2 0.8504
# Saving model....
# Start testing....
# Final best performing model: Test_DE: 0.1489, R2 0.9060
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# test_combo_seen0_mse: nan
# test_combo_seen0_mae: nan
# test_combo_seen0_spearman: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_r2: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_mae_de: nan
# test_combo_seen0_spearman_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen0_r2_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_mae: nan
# test_combo_seen1_spearman: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_r2: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_mae_de: nan
# test_combo_seen1_spearman_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen1_r2_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_mae: nan
# test_combo_seen2_spearman: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_r2: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_mae_de: nan
# test_combo_seen2_spearman_de: nan
# test_combo_seen2_pearson_de: nan
# test_combo_seen2_r2_de: nan
# test_unseen_single_mse: 0.023640549
# test_unseen_single_mae: 0.1348053
# test_unseen_single_spearman: 0.9752850250077163
# test_unseen_single_pearson: 0.984106882736122
# test_unseen_single_r2: 0.8942426008944545
# test_unseen_single_mse_de: 0.14891326
# test_unseen_single_mae_de: 0.25173318
# test_unseen_single_spearman_de: 0.9609448753335638
# test_unseen_single_pearson_de: 0.9733303877231592
# test_unseen_single_r2_de: 0.9059994108297634
# test_combo_seen0_frac_in_range: nan
# test_combo_seen0_frac_in_range_45_55: nan
# test_combo_seen0_frac_in_range_40_60: nan
# test_combo_seen0_frac_in_range_25_75: nan
# test_combo_seen0_mean_sigma: nan
# test_combo_seen0_std_sigma: nan
# test_combo_seen0_frac_sigma_below_1: nan
# test_combo_seen0_frac_sigma_below_2: nan
# test_combo_seen0_pearson_delta: nan
# test_combo_seen0_pearson_delta_de: nan
# test_combo_seen0_fold_change_gap_all: nan
# test_combo_seen0_pearson_delta_top200_hvg: nan
# test_combo_seen0_fold_change_gap_upreg_3: nan
# test_combo_seen0_fold_change_gap_downreg_0.33: nan
# test_combo_seen0_fold_change_gap_downreg_0.1: nan
# test_combo_seen0_fold_change_gap_upreg_10: nan
# test_combo_seen0_pearson_top200_hvg: nan
# test_combo_seen0_pearson_top200_de: nan
# test_combo_seen0_pearson_top20_de: nan
# test_combo_seen0_pearson_delta_top200_de: nan
# test_combo_seen0_pearson_top100_de: nan
# test_combo_seen0_pearson_delta_top100_de: nan
# test_combo_seen0_pearson_delta_top50_de: nan
# test_combo_seen0_pearson_top50_de: nan
# test_combo_seen0_pearson_delta_top20_de: nan
# test_combo_seen0_mse_top200_hvg: nan
# test_combo_seen0_mse_top100_de: nan
# test_combo_seen0_mse_top200_de: nan
# test_combo_seen0_mse_top50_de: nan
# test_combo_seen0_mse_top20_de: nan
# test_combo_seen1_frac_in_range: nan
# test_combo_seen1_frac_in_range_45_55: nan
# test_combo_seen1_frac_in_range_40_60: nan
# test_combo_seen1_frac_in_range_25_75: nan
# test_combo_seen1_mean_sigma: nan
# test_combo_seen1_std_sigma: nan
# test_combo_seen1_frac_sigma_below_1: nan
# test_combo_seen1_frac_sigma_below_2: nan
# test_combo_seen1_pearson_delta: nan
# test_combo_seen1_pearson_delta_de: nan
# test_combo_seen1_fold_change_gap_all: nan
# test_combo_seen1_pearson_delta_top200_hvg: nan
# test_combo_seen1_fold_change_gap_upreg_3: nan
# test_combo_seen1_fold_change_gap_downreg_0.33: nan
# test_combo_seen1_fold_change_gap_downreg_0.1: nan
# test_combo_seen1_fold_change_gap_upreg_10: nan
# test_combo_seen1_pearson_top200_hvg: nan
# test_combo_seen1_pearson_top200_de: nan
# test_combo_seen1_pearson_top20_de: nan
# test_combo_seen1_pearson_delta_top200_de: nan
# test_combo_seen1_pearson_top100_de: nan
# test_combo_seen1_pearson_delta_top100_de: nan
# test_combo_seen1_pearson_delta_top50_de: nan
# test_combo_seen1_pearson_top50_de: nan
# test_combo_seen1_pearson_delta_top20_de: nan
# test_combo_seen1_mse_top200_hvg: nan
# test_combo_seen1_mse_top100_de: nan
# test_combo_seen1_mse_top200_de: nan
# test_combo_seen1_mse_top50_de: nan
# test_combo_seen1_mse_top20_de: nan
# test_combo_seen2_frac_in_range: nan
# test_combo_seen2_frac_in_range_45_55: nan
# test_combo_seen2_frac_in_range_40_60: nan
# test_combo_seen2_frac_in_range_25_75: nan
# test_combo_seen2_mean_sigma: nan
# test_combo_seen2_std_sigma: nan
# test_combo_seen2_frac_sigma_below_1: nan
# test_combo_seen2_frac_sigma_below_2: nan
# test_combo_seen2_pearson_delta: nan
# test_combo_seen2_pearson_delta_de: nan
# test_combo_seen2_fold_change_gap_all: nan
# test_combo_seen2_pearson_delta_top200_hvg: nan
# test_combo_seen2_fold_change_gap_upreg_3: nan
# test_combo_seen2_fold_change_gap_downreg_0.33: nan
# test_combo_seen2_fold_change_gap_downreg_0.1: nan
# test_combo_seen2_fold_change_gap_upreg_10: nan
# test_combo_seen2_pearson_top200_hvg: nan
# test_combo_seen2_pearson_top200_de: nan
# test_combo_seen2_pearson_top20_de: nan
# test_combo_seen2_pearson_delta_top200_de: nan
# test_combo_seen2_pearson_top100_de: nan
# test_combo_seen2_pearson_delta_top100_de: nan
# test_combo_seen2_pearson_delta_top50_de: nan
# test_combo_seen2_pearson_top50_de: nan
# test_combo_seen2_pearson_delta_top20_de: nan
# test_combo_seen2_mse_top200_hvg: nan
# test_combo_seen2_mse_top100_de: nan
# test_combo_seen2_mse_top200_de: nan
# test_combo_seen2_mse_top50_de: nan
# test_combo_seen2_mse_top20_de: nan
# test_unseen_single_frac_in_range: 0.9818181818181819
# test_unseen_single_frac_in_range_45_55: 0.16052631578947368
# test_unseen_single_frac_in_range_40_60: 0.29066985645933013
# test_unseen_single_frac_in_range_25_75: 0.6120215311004785
# test_unseen_single_mean_sigma: 0.74233687
# test_unseen_single_std_sigma: 0.48663846
# test_unseen_single_frac_sigma_below_1: 0.8573564593301435
# test_unseen_single_frac_sigma_below_2: 0.9151016746411483
# test_unseen_single_pearson_delta: 0.44299849835477634
# test_unseen_single_pearson_delta_de: 0.7546966055011107
# test_unseen_single_fold_change_gap_all: 0.124068856
# test_unseen_single_pearson_delta_top200_hvg: 0.5998858640980915
# test_unseen_single_fold_change_gap_upreg_3: 0.85428345
# test_unseen_single_fold_change_gap_downreg_0.33: 0.56321096
# test_unseen_single_fold_change_gap_downreg_0.1: nan
# test_unseen_single_fold_change_gap_upreg_10: 4.073269
# test_unseen_single_pearson_top200_hvg: 0.9655093820528553
# test_unseen_single_pearson_top200_de: 0.9842836225313915
# test_unseen_single_pearson_top20_de: 0.9733303877231592
# test_unseen_single_pearson_delta_top200_de: 0.7041614028053965
# test_unseen_single_pearson_top100_de: 0.9820904655080575
# test_unseen_single_pearson_delta_top100_de: 0.7325406394662246
# test_unseen_single_pearson_delta_top50_de: 0.7436537722468217
# test_unseen_single_pearson_top50_de: 0.9785825515404972
# test_unseen_single_pearson_delta_top20_de: 0.7546966055011107
# test_unseen_single_mse_top200_hvg: 0.07192702
# test_unseen_single_mse_top100_de: 0.08344162
# test_unseen_single_mse_top200_de: 0.059759043
# test_unseen_single_mse_top50_de: 0.11615235
# test_unseen_single_mse_top20_de: 0.14891326
# Done!
#
# wandb: Waiting for W&B process to finish, PID 27334
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_205208-1se9xojk/logs/debug.log
# wandb: Find internal logs for this run at: /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_205208-1se9xojk/logs/debug-internal.log
# wandb: Run summary:
# wandb:              test_combo_seen0_fold_change_gap_all nan
# wandb:      test_combo_seen0_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen0_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen0_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen0_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen0_frac_in_range nan
# wandb:              test_combo_seen0_frac_in_range_25_75 nan
# wandb:              test_combo_seen0_frac_in_range_40_60 nan
# wandb:              test_combo_seen0_frac_in_range_45_55 nan
# wandb:               test_combo_seen0_frac_sigma_below_1 nan
# wandb:               test_combo_seen0_frac_sigma_below_2 nan
# wandb:                              test_combo_seen0_mae nan
# wandb:                           test_combo_seen0_mae_de nan
# wandb:                       test_combo_seen0_mean_sigma nan
# wandb:                              test_combo_seen0_mse nan
# wandb:                           test_combo_seen0_mse_de nan
# wandb:                    test_combo_seen0_mse_top100_de nan
# wandb:                    test_combo_seen0_mse_top200_de nan
# wandb:                   test_combo_seen0_mse_top200_hvg nan
# wandb:                     test_combo_seen0_mse_top20_de nan
# wandb:                     test_combo_seen0_mse_top50_de nan
# wandb:                          test_combo_seen0_pearson nan
# wandb:                       test_combo_seen0_pearson_de nan
# wandb:                    test_combo_seen0_pearson_delta nan
# wandb:                 test_combo_seen0_pearson_delta_de nan
# wandb:          test_combo_seen0_pearson_delta_top100_de nan
# wandb:          test_combo_seen0_pearson_delta_top200_de nan
# wandb:         test_combo_seen0_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen0_pearson_delta_top20_de nan
# wandb:           test_combo_seen0_pearson_delta_top50_de nan
# wandb:                test_combo_seen0_pearson_top100_de nan
# wandb:                test_combo_seen0_pearson_top200_de nan
# wandb:               test_combo_seen0_pearson_top200_hvg nan
# wandb:                 test_combo_seen0_pearson_top20_de nan
# wandb:                 test_combo_seen0_pearson_top50_de nan
# wandb:                               test_combo_seen0_r2 nan
# wandb:                            test_combo_seen0_r2_de nan
# wandb:                         test_combo_seen0_spearman nan
# wandb:                      test_combo_seen0_spearman_de nan
# wandb:                        test_combo_seen0_std_sigma nan
# wandb:              test_combo_seen1_fold_change_gap_all nan
# wandb:      test_combo_seen1_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen1_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen1_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen1_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen1_frac_in_range nan
# wandb:              test_combo_seen1_frac_in_range_25_75 nan
# wandb:              test_combo_seen1_frac_in_range_40_60 nan
# wandb:              test_combo_seen1_frac_in_range_45_55 nan
# wandb:               test_combo_seen1_frac_sigma_below_1 nan
# wandb:               test_combo_seen1_frac_sigma_below_2 nan
# wandb:                              test_combo_seen1_mae nan
# wandb:                           test_combo_seen1_mae_de nan
# wandb:                       test_combo_seen1_mean_sigma nan
# wandb:                              test_combo_seen1_mse nan
# wandb:                           test_combo_seen1_mse_de nan
# wandb:                    test_combo_seen1_mse_top100_de nan
# wandb:                    test_combo_seen1_mse_top200_de nan
# wandb:                   test_combo_seen1_mse_top200_hvg nan
# wandb:                     test_combo_seen1_mse_top20_de nan
# wandb:                     test_combo_seen1_mse_top50_de nan
# wandb:                          test_combo_seen1_pearson nan
# wandb:                       test_combo_seen1_pearson_de nan
# wandb:                    test_combo_seen1_pearson_delta nan
# wandb:                 test_combo_seen1_pearson_delta_de nan
# wandb:          test_combo_seen1_pearson_delta_top100_de nan
# wandb:          test_combo_seen1_pearson_delta_top200_de nan
# wandb:         test_combo_seen1_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen1_pearson_delta_top20_de nan
# wandb:           test_combo_seen1_pearson_delta_top50_de nan
# wandb:                test_combo_seen1_pearson_top100_de nan
# wandb:                test_combo_seen1_pearson_top200_de nan
# wandb:               test_combo_seen1_pearson_top200_hvg nan
# wandb:                 test_combo_seen1_pearson_top20_de nan
# wandb:                 test_combo_seen1_pearson_top50_de nan
# wandb:                               test_combo_seen1_r2 nan
# wandb:                            test_combo_seen1_r2_de nan
# wandb:                         test_combo_seen1_spearman nan
# wandb:                      test_combo_seen1_spearman_de nan
# wandb:                        test_combo_seen1_std_sigma nan
# wandb:              test_combo_seen2_fold_change_gap_all nan
# wandb:      test_combo_seen2_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen2_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen2_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen2_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen2_frac_in_range nan
# wandb:              test_combo_seen2_frac_in_range_25_75 nan
# wandb:              test_combo_seen2_frac_in_range_40_60 nan
# wandb:              test_combo_seen2_frac_in_range_45_55 nan
# wandb:               test_combo_seen2_frac_sigma_below_1 nan
# wandb:               test_combo_seen2_frac_sigma_below_2 nan
# wandb:                              test_combo_seen2_mae nan
# wandb:                           test_combo_seen2_mae_de nan
# wandb:                       test_combo_seen2_mean_sigma nan
# wandb:                              test_combo_seen2_mse nan
# wandb:                           test_combo_seen2_mse_de nan
# wandb:                    test_combo_seen2_mse_top100_de nan
# wandb:                    test_combo_seen2_mse_top200_de nan
# wandb:                   test_combo_seen2_mse_top200_hvg nan
# wandb:                     test_combo_seen2_mse_top20_de nan
# wandb:                     test_combo_seen2_mse_top50_de nan
# wandb:                          test_combo_seen2_pearson nan
# wandb:                       test_combo_seen2_pearson_de nan
# wandb:                    test_combo_seen2_pearson_delta nan
# wandb:                 test_combo_seen2_pearson_delta_de nan
# wandb:          test_combo_seen2_pearson_delta_top100_de nan
# wandb:          test_combo_seen2_pearson_delta_top200_de nan
# wandb:         test_combo_seen2_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen2_pearson_delta_top20_de nan
# wandb:           test_combo_seen2_pearson_delta_top50_de nan
# wandb:                test_combo_seen2_pearson_top100_de nan
# wandb:                test_combo_seen2_pearson_top200_de nan
# wandb:               test_combo_seen2_pearson_top200_hvg nan
# wandb:                 test_combo_seen2_pearson_top20_de nan
# wandb:                 test_combo_seen2_pearson_top50_de nan
# wandb:                               test_combo_seen2_r2 nan
# wandb:                            test_combo_seen2_r2_de nan
# wandb:                         test_combo_seen2_spearman nan
# wandb:                      test_combo_seen2_spearman_de nan
# wandb:                        test_combo_seen2_std_sigma nan
# wandb:                                       test_de_mae 0.25173
# wandb:                                       test_de_mse 0.14891
# wandb:                                   test_de_pearson 0.97333
# wandb:                                        test_de_r2 0.906
# wandb:                                  test_de_spearman 0.96094
# wandb:                          test_fold_change_gap_all 0.12407
# wandb:                  test_fold_change_gap_downreg_0.1 nan
# wandb:                 test_fold_change_gap_downreg_0.33 0.56321
# wandb:                     test_fold_change_gap_upreg_10 4.07327
# wandb:                      test_fold_change_gap_upreg_3 0.85428
# wandb:                                test_frac_in_range 0.98182
# wandb:                          test_frac_in_range_25_75 0.61202
# wandb:                          test_frac_in_range_40_60 0.29067
# wandb:                          test_frac_in_range_45_55 0.16053
# wandb:                           test_frac_sigma_below_1 0.85736
# wandb:                           test_frac_sigma_below_2 0.9151
# wandb:                                          test_mae 0.13481
# wandb:                                   test_mean_sigma 0.74234
# wandb:                                          test_mse 0.02364
# wandb:                                test_mse_top100_de 0.08344
# wandb:                                test_mse_top200_de 0.05976
# wandb:                               test_mse_top200_hvg 0.07193
# wandb:                                 test_mse_top20_de 0.14891
# wandb:                                 test_mse_top50_de 0.11615
# wandb:                                      test_pearson 0.98411
# wandb:                                test_pearson_delta 0.443
# wandb:                             test_pearson_delta_de 0.7547
# wandb:                      test_pearson_delta_top100_de 0.73254
# wandb:                      test_pearson_delta_top200_de 0.70416
# wandb:                     test_pearson_delta_top200_hvg 0.59989
# wandb:                       test_pearson_delta_top20_de 0.7547
# wandb:                       test_pearson_delta_top50_de 0.74365
# wandb:                            test_pearson_top100_de 0.98209
# wandb:                            test_pearson_top200_de 0.98428
# wandb:                           test_pearson_top200_hvg 0.96551
# wandb:                             test_pearson_top20_de 0.97333
# wandb:                             test_pearson_top50_de 0.97858
# wandb:                                           test_r2 0.89424
# wandb:                                     test_spearman 0.97529
# wandb:                                    test_std_sigma 0.48664
# wandb:            test_unseen_single_fold_change_gap_all 0.12407
# wandb:    test_unseen_single_fold_change_gap_downreg_0.1 nan
# wandb:   test_unseen_single_fold_change_gap_downreg_0.33 0.56321
# wandb:       test_unseen_single_fold_change_gap_upreg_10 4.07327
# wandb:        test_unseen_single_fold_change_gap_upreg_3 0.85428
# wandb:                  test_unseen_single_frac_in_range 0.98182
# wandb:            test_unseen_single_frac_in_range_25_75 0.61202
# wandb:            test_unseen_single_frac_in_range_40_60 0.29067
# wandb:            test_unseen_single_frac_in_range_45_55 0.16053
# wandb:             test_unseen_single_frac_sigma_below_1 0.85736
# wandb:             test_unseen_single_frac_sigma_below_2 0.9151
# wandb:                            test_unseen_single_mae 0.13481
# wandb:                         test_unseen_single_mae_de 0.25173
# wandb:                     test_unseen_single_mean_sigma 0.74234
# wandb:                            test_unseen_single_mse 0.02364
# wandb:                         test_unseen_single_mse_de 0.14891
# wandb:                  test_unseen_single_mse_top100_de 0.08344
# wandb:                  test_unseen_single_mse_top200_de 0.05976
# wandb:                 test_unseen_single_mse_top200_hvg 0.07193
# wandb:                   test_unseen_single_mse_top20_de 0.14891
# wandb:                   test_unseen_single_mse_top50_de 0.11615
# wandb:                        test_unseen_single_pearson 0.98411
# wandb:                     test_unseen_single_pearson_de 0.97333
# wandb:                  test_unseen_single_pearson_delta 0.443
# wandb:               test_unseen_single_pearson_delta_de 0.7547
# wandb:        test_unseen_single_pearson_delta_top100_de 0.73254
# wandb:        test_unseen_single_pearson_delta_top200_de 0.70416
# wandb:       test_unseen_single_pearson_delta_top200_hvg 0.59989
# wandb:         test_unseen_single_pearson_delta_top20_de 0.7547
# wandb:         test_unseen_single_pearson_delta_top50_de 0.74365
# wandb:              test_unseen_single_pearson_top100_de 0.98209
# wandb:              test_unseen_single_pearson_top200_de 0.98428
# wandb:             test_unseen_single_pearson_top200_hvg 0.96551
# wandb:               test_unseen_single_pearson_top20_de 0.97333
# wandb:               test_unseen_single_pearson_top50_de 0.97858
# wandb:                             test_unseen_single_r2 0.89424
# wandb:                          test_unseen_single_r2_de 0.906
# wandb:                       test_unseen_single_spearman 0.97529
# wandb:                    test_unseen_single_spearman_de 0.96094
# wandb:                      test_unseen_single_std_sigma 0.48664
# wandb:                                      train_de_mae 0.23427
# wandb:                                      train_de_mse 0.12944
# wandb:                                  train_de_pearson 0.96899
# wandb:                                       train_de_r2 0.90204
# wandb:                                 train_de_spearman 0.93973
# wandb:                                         train_mae 0.13777
# wandb:                                         train_mse 0.02387
# wandb:                                     train_pearson 0.98574
# wandb:                                          train_r2 0.89339
# wandb:                                    train_spearman 0.97861
# wandb:                                     training_loss 0.07652
# wandb:                                        val_de_mae 0.3304
# wandb:                                        val_de_mse 0.19941
# wandb:                                    val_de_pearson 0.95584
# wandb:                                         val_de_r2 0.85038
# wandb:                                   val_de_spearman 0.92653
# wandb:                                           val_mae 0.13151
# wandb:                                           val_mse 0.02198
# wandb:                                       val_pearson 0.98622
# wandb:                                            val_r2 0.90088
# wandb:                                      val_spearman 0.97658
# wandb: Run history:
# wandb:              test_combo_seen0_fold_change_gap_all
# wandb:      test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen0_fold_change_gap_upreg_10
# wandb:          test_combo_seen0_fold_change_gap_upreg_3
# wandb:                    test_combo_seen0_frac_in_range
# wandb:              test_combo_seen0_frac_in_range_25_75
# wandb:              test_combo_seen0_frac_in_range_40_60
# wandb:              test_combo_seen0_frac_in_range_45_55
# wandb:               test_combo_seen0_frac_sigma_below_1
# wandb:               test_combo_seen0_frac_sigma_below_2
# wandb:                              test_combo_seen0_mae
# wandb:                           test_combo_seen0_mae_de
# wandb:                       test_combo_seen0_mean_sigma
# wandb:                              test_combo_seen0_mse
# wandb:                           test_combo_seen0_mse_de
# wandb:                    test_combo_seen0_mse_top100_de
# wandb:                    test_combo_seen0_mse_top200_de
# wandb:                   test_combo_seen0_mse_top200_hvg
# wandb:                     test_combo_seen0_mse_top20_de
# wandb:                     test_combo_seen0_mse_top50_de
# wandb:                          test_combo_seen0_pearson
# wandb:                       test_combo_seen0_pearson_de
# wandb:                    test_combo_seen0_pearson_delta
# wandb:                 test_combo_seen0_pearson_delta_de
# wandb:          test_combo_seen0_pearson_delta_top100_de
# wandb:          test_combo_seen0_pearson_delta_top200_de
# wandb:         test_combo_seen0_pearson_delta_top200_hvg
# wandb:           test_combo_seen0_pearson_delta_top20_de
# wandb:           test_combo_seen0_pearson_delta_top50_de
# wandb:                test_combo_seen0_pearson_top100_de
# wandb:                test_combo_seen0_pearson_top200_de
# wandb:               test_combo_seen0_pearson_top200_hvg
# wandb:                 test_combo_seen0_pearson_top20_de
# wandb:                 test_combo_seen0_pearson_top50_de
# wandb:                               test_combo_seen0_r2
# wandb:                            test_combo_seen0_r2_de
# wandb:                         test_combo_seen0_spearman
# wandb:                      test_combo_seen0_spearman_de
# wandb:                        test_combo_seen0_std_sigma
# wandb:              test_combo_seen1_fold_change_gap_all
# wandb:      test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen1_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen1_fold_change_gap_upreg_10
# wandb:          test_combo_seen1_fold_change_gap_upreg_3
# wandb:                    test_combo_seen1_frac_in_range
# wandb:              test_combo_seen1_frac_in_range_25_75
# wandb:              test_combo_seen1_frac_in_range_40_60
# wandb:              test_combo_seen1_frac_in_range_45_55
# wandb:               test_combo_seen1_frac_sigma_below_1
# wandb:               test_combo_seen1_frac_sigma_below_2
# wandb:                              test_combo_seen1_mae
# wandb:                           test_combo_seen1_mae_de
# wandb:                       test_combo_seen1_mean_sigma
# wandb:                              test_combo_seen1_mse
# wandb:                           test_combo_seen1_mse_de
# wandb:                    test_combo_seen1_mse_top100_de
# wandb:                    test_combo_seen1_mse_top200_de
# wandb:                   test_combo_seen1_mse_top200_hvg
# wandb:                     test_combo_seen1_mse_top20_de
# wandb:                     test_combo_seen1_mse_top50_de
# wandb:                          test_combo_seen1_pearson
# wandb:                       test_combo_seen1_pearson_de
# wandb:                    test_combo_seen1_pearson_delta
# wandb:                 test_combo_seen1_pearson_delta_de
# wandb:          test_combo_seen1_pearson_delta_top100_de
# wandb:          test_combo_seen1_pearson_delta_top200_de
# wandb:         test_combo_seen1_pearson_delta_top200_hvg
# wandb:           test_combo_seen1_pearson_delta_top20_de
# wandb:           test_combo_seen1_pearson_delta_top50_de
# wandb:                test_combo_seen1_pearson_top100_de
# wandb:                test_combo_seen1_pearson_top200_de
# wandb:               test_combo_seen1_pearson_top200_hvg
# wandb:                 test_combo_seen1_pearson_top20_de
# wandb:                 test_combo_seen1_pearson_top50_de
# wandb:                               test_combo_seen1_r2
# wandb:                            test_combo_seen1_r2_de
# wandb:                         test_combo_seen1_spearman
# wandb:                      test_combo_seen1_spearman_de
# wandb:                        test_combo_seen1_std_sigma
# wandb:              test_combo_seen2_fold_change_gap_all
# wandb:      test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen2_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen2_fold_change_gap_upreg_10
# wandb:          test_combo_seen2_fold_change_gap_upreg_3
# wandb:                    test_combo_seen2_frac_in_range
# wandb:              test_combo_seen2_frac_in_range_25_75
# wandb:              test_combo_seen2_frac_in_range_40_60
# wandb:              test_combo_seen2_frac_in_range_45_55
# wandb:               test_combo_seen2_frac_sigma_below_1
# wandb:               test_combo_seen2_frac_sigma_below_2
# wandb:                              test_combo_seen2_mae
# wandb:                           test_combo_seen2_mae_de
# wandb:                       test_combo_seen2_mean_sigma
# wandb:                              test_combo_seen2_mse
# wandb:                           test_combo_seen2_mse_de
# wandb:                    test_combo_seen2_mse_top100_de
# wandb:                    test_combo_seen2_mse_top200_de
# wandb:                   test_combo_seen2_mse_top200_hvg
# wandb:                     test_combo_seen2_mse_top20_de
# wandb:                     test_combo_seen2_mse_top50_de
# wandb:                          test_combo_seen2_pearson
# wandb:                       test_combo_seen2_pearson_de
# wandb:                    test_combo_seen2_pearson_delta
# wandb:                 test_combo_seen2_pearson_delta_de
# wandb:          test_combo_seen2_pearson_delta_top100_de
# wandb:          test_combo_seen2_pearson_delta_top200_de
# wandb:         test_combo_seen2_pearson_delta_top200_hvg
# wandb:           test_combo_seen2_pearson_delta_top20_de
# wandb:           test_combo_seen2_pearson_delta_top50_de
# wandb:                test_combo_seen2_pearson_top100_de
# wandb:                test_combo_seen2_pearson_top200_de
# wandb:               test_combo_seen2_pearson_top200_hvg
# wandb:                 test_combo_seen2_pearson_top20_de
# wandb:                 test_combo_seen2_pearson_top50_de
# wandb:                               test_combo_seen2_r2
# wandb:                            test_combo_seen2_r2_de
# wandb:                         test_combo_seen2_spearman
# wandb:                      test_combo_seen2_spearman_de
# wandb:                        test_combo_seen2_std_sigma
# wandb:                                       test_de_mae ▁
# wandb:                                       test_de_mse ▁
# wandb:                                   test_de_pearson ▁
# wandb:                                        test_de_r2 ▁
# wandb:                                  test_de_spearman ▁
# wandb:                          test_fold_change_gap_all ▁
# wandb:                  test_fold_change_gap_downreg_0.1
# wandb:                 test_fold_change_gap_downreg_0.33 ▁
# wandb:                     test_fold_change_gap_upreg_10 ▁
# wandb:                      test_fold_change_gap_upreg_3 ▁
# wandb:                                test_frac_in_range ▁
# wandb:                          test_frac_in_range_25_75 ▁
# wandb:                          test_frac_in_range_40_60 ▁
# wandb:                          test_frac_in_range_45_55 ▁
# wandb:                           test_frac_sigma_below_1 ▁
# wandb:                           test_frac_sigma_below_2 ▁
# wandb:                                          test_mae ▁
# wandb:                                   test_mean_sigma ▁
# wandb:                                          test_mse ▁
# wandb:                                test_mse_top100_de ▁
# wandb:                                test_mse_top200_de ▁
# wandb:                               test_mse_top200_hvg ▁
# wandb:                                 test_mse_top20_de ▁
# wandb:                                 test_mse_top50_de ▁
# wandb:                                      test_pearson ▁
# wandb:                                test_pearson_delta ▁
# wandb:                             test_pearson_delta_de ▁
# wandb:                      test_pearson_delta_top100_de ▁
# wandb:                      test_pearson_delta_top200_de ▁
# wandb:                     test_pearson_delta_top200_hvg ▁
# wandb:                       test_pearson_delta_top20_de ▁
# wandb:                       test_pearson_delta_top50_de ▁
# wandb:                            test_pearson_top100_de ▁
# wandb:                            test_pearson_top200_de ▁
# wandb:                           test_pearson_top200_hvg ▁
# wandb:                             test_pearson_top20_de ▁
# wandb:                             test_pearson_top50_de ▁
# wandb:                                           test_r2 ▁
# wandb:                                     test_spearman ▁
# wandb:                                    test_std_sigma ▁
# wandb:            test_unseen_single_fold_change_gap_all ▁
# wandb:    test_unseen_single_fold_change_gap_downreg_0.1
# wandb:   test_unseen_single_fold_change_gap_downreg_0.33 ▁
# wandb:       test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:        test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                  test_unseen_single_frac_in_range ▁
# wandb:            test_unseen_single_frac_in_range_25_75 ▁
# wandb:            test_unseen_single_frac_in_range_40_60 ▁
# wandb:            test_unseen_single_frac_in_range_45_55 ▁
# wandb:             test_unseen_single_frac_sigma_below_1 ▁
# wandb:             test_unseen_single_frac_sigma_below_2 ▁
# wandb:                            test_unseen_single_mae ▁
# wandb:                         test_unseen_single_mae_de ▁
# wandb:                     test_unseen_single_mean_sigma ▁
# wandb:                            test_unseen_single_mse ▁
# wandb:                         test_unseen_single_mse_de ▁
# wandb:                  test_unseen_single_mse_top100_de ▁
# wandb:                  test_unseen_single_mse_top200_de ▁
# wandb:                 test_unseen_single_mse_top200_hvg ▁
# wandb:                   test_unseen_single_mse_top20_de ▁
# wandb:                   test_unseen_single_mse_top50_de ▁
# wandb:                        test_unseen_single_pearson ▁
# wandb:                     test_unseen_single_pearson_de ▁
# wandb:                  test_unseen_single_pearson_delta ▁
# wandb:               test_unseen_single_pearson_delta_de ▁
# wandb:        test_unseen_single_pearson_delta_top100_de ▁
# wandb:        test_unseen_single_pearson_delta_top200_de ▁
# wandb:       test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:         test_unseen_single_pearson_delta_top20_de ▁
# wandb:         test_unseen_single_pearson_delta_top50_de ▁
# wandb:              test_unseen_single_pearson_top100_de ▁
# wandb:              test_unseen_single_pearson_top200_de ▁
# wandb:             test_unseen_single_pearson_top200_hvg ▁
# wandb:               test_unseen_single_pearson_top20_de ▁
# wandb:               test_unseen_single_pearson_top50_de ▁
# wandb:                             test_unseen_single_r2 ▁
# wandb:                          test_unseen_single_r2_de ▁
# wandb:                       test_unseen_single_spearman ▁
# wandb:                    test_unseen_single_spearman_de ▁
# wandb:                      test_unseen_single_std_sigma ▁
# wandb:                                      train_de_mae ▃█▇▄▂▁▂▁▁▁
# wandb:                                      train_de_mse ▂█▆▃▂▁▁▁▁▁
# wandb:                                  train_de_pearson ▁▆▇▂▂██▅▇▇
# wandb:                                       train_de_r2 █▁▃███████
# wandb:                                 train_de_spearman ▁██▁▂▆▆▄▆▆
# wandb:                                         train_mae █▅▄▄▂▂▁▁▁▁
# wandb:                                         train_mse ▇█▅▄▂▁▁▁▁▁
# wandb:                                     train_pearson ▇▁▃██▇▇███
# wandb:                                          train_r2 ▇▁▅███████
# wandb:                                    train_spearman ▁▅▇▇██████
# wandb:                                     training_loss ▅▆▃▁▆▄▅▃▂▇▃▅▂▃▄▃▃▄▇█▂▄▂▂▃▃▆▅▄▅▅▂▂▇▆▄▆▅▇▃
# wandb:                                        val_de_mae ▂█▆▃▂▁▂▁▁▁
# wandb:                                        val_de_mse ▂█▆▂▂▁▁▁▁▁
# wandb:                                    val_de_pearson ▁██▁▂▇▇▄▇▆
# wandb:                                         val_de_r2 █▁▃███████
# wandb:                                   val_de_spearman ▁█▇▁▁▅▆▃▅▄
# wandb:                                           val_mae █▅▄▄▂▂▁▁▁▁
# wandb:                                           val_mse ▇█▅▄▂▁▁▁▁▁
# wandb:                                       val_pearson ▇▁▃▇██▇███
# wandb:                                            val_r2 ▇▁▅███████
# wandb:                                      val_spearman ▁▅▇▇██████
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced no_gnn: https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016/runs/1se9xojk

# %%
# !python train.py --dataset Adamson2016 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model No_Perturb \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3 \
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:4 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --no_gnn \
                 --exp_name no_gnn \
                 --wandb
# Out:
# ---- Printing Arguments ----
# dataset: Adamson2016
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:4
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: No_Perturb
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: False
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: True
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: no_gnn
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run no_gnn
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016/runs/3pnzo93n
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_211953-3pnzo93n
# wandb: Run `wandb offline` to turn off syncing.
#
# Training No_Perturb_GAT_co-expression_100.0_64_2_l3_Adamson2016_gamma2_gene_emb_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 7054 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:22
# Creating dataloaders....
# Dataloaders created...
# Finished data setup, in total takes 0.436 min
# Initializing model...
# Saving model....
# Start testing....
# Final best performing model: Test_DE: 0.2977, R2 0.7995
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# test_combo_seen0_mse: nan
# test_combo_seen0_mae: nan
# test_combo_seen0_spearman: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_r2: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_mae_de: nan
# test_combo_seen0_spearman_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen0_r2_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_mae: nan
# test_combo_seen1_spearman: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_r2: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_mae_de: nan
# test_combo_seen1_spearman_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen1_r2_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_mae: nan
# test_combo_seen2_spearman: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_r2: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_mae_de: nan
# test_combo_seen2_spearman_de: nan
# test_combo_seen2_pearson_de: nan
# test_combo_seen2_r2_de: nan
# test_unseen_single_mse: 0.008721746
# test_unseen_single_mae: 0.045634445
# test_unseen_single_spearman: 0.9650467579117445
# test_unseen_single_pearson: 0.9858056894458724
# test_unseen_single_r2: 0.968778568258847
# test_unseen_single_mse_de: 0.29765046
# test_unseen_single_mae_de: 0.4890914
# test_unseen_single_spearman_de: 0.8937537128761149
# test_unseen_single_pearson_de: 0.9191112385493082
# test_unseen_single_r2_de: 0.7994616281440543
# test_combo_seen0_frac_in_range: nan
# test_combo_seen0_frac_in_range_45_55: nan
# test_combo_seen0_frac_in_range_40_60: nan
# test_combo_seen0_frac_in_range_25_75: nan
# test_combo_seen0_mean_sigma: nan
# test_combo_seen0_std_sigma: nan
# test_combo_seen0_frac_sigma_below_1: nan
# test_combo_seen0_frac_sigma_below_2: nan
# test_combo_seen0_pearson_delta: nan
# test_combo_seen0_pearson_delta_de: nan
# test_combo_seen0_fold_change_gap_all: nan
# test_combo_seen0_pearson_delta_top200_hvg: nan
# test_combo_seen0_fold_change_gap_upreg_3: nan
# test_combo_seen0_fold_change_gap_downreg_0.33: nan
# test_combo_seen0_fold_change_gap_downreg_0.1: nan
# test_combo_seen0_fold_change_gap_upreg_10: nan
# test_combo_seen0_pearson_top200_hvg: nan
# test_combo_seen0_pearson_top200_de: nan
# test_combo_seen0_pearson_top20_de: nan
# test_combo_seen0_pearson_delta_top200_de: nan
# test_combo_seen0_pearson_top100_de: nan
# test_combo_seen0_pearson_delta_top100_de: nan
# test_combo_seen0_pearson_delta_top50_de: nan
# test_combo_seen0_pearson_top50_de: nan
# test_combo_seen0_pearson_delta_top20_de: nan
# test_combo_seen0_mse_top200_hvg: nan
# test_combo_seen0_mse_top100_de: nan
# test_combo_seen0_mse_top200_de: nan
# test_combo_seen0_mse_top50_de: nan
# test_combo_seen0_mse_top20_de: nan
# test_combo_seen1_frac_in_range: nan
# test_combo_seen1_frac_in_range_45_55: nan
# test_combo_seen1_frac_in_range_40_60: nan
# test_combo_seen1_frac_in_range_25_75: nan
# test_combo_seen1_mean_sigma: nan
# test_combo_seen1_std_sigma: nan
# test_combo_seen1_frac_sigma_below_1: nan
# test_combo_seen1_frac_sigma_below_2: nan
# test_combo_seen1_pearson_delta: nan
# test_combo_seen1_pearson_delta_de: nan
# test_combo_seen1_fold_change_gap_all: nan
# test_combo_seen1_pearson_delta_top200_hvg: nan
# test_combo_seen1_fold_change_gap_upreg_3: nan
# test_combo_seen1_fold_change_gap_downreg_0.33: nan
# test_combo_seen1_fold_change_gap_downreg_0.1: nan
# test_combo_seen1_fold_change_gap_upreg_10: nan
# test_combo_seen1_pearson_top200_hvg: nan
# test_combo_seen1_pearson_top200_de: nan
# test_combo_seen1_pearson_top20_de: nan
# test_combo_seen1_pearson_delta_top200_de: nan
# test_combo_seen1_pearson_top100_de: nan
# test_combo_seen1_pearson_delta_top100_de: nan
# test_combo_seen1_pearson_delta_top50_de: nan
# test_combo_seen1_pearson_top50_de: nan
# test_combo_seen1_pearson_delta_top20_de: nan
# test_combo_seen1_mse_top200_hvg: nan
# test_combo_seen1_mse_top100_de: nan
# test_combo_seen1_mse_top200_de: nan
# test_combo_seen1_mse_top50_de: nan
# test_combo_seen1_mse_top20_de: nan
# test_combo_seen2_frac_in_range: nan
# test_combo_seen2_frac_in_range_45_55: nan
# test_combo_seen2_frac_in_range_40_60: nan
# test_combo_seen2_frac_in_range_25_75: nan
# test_combo_seen2_mean_sigma: nan
# test_combo_seen2_std_sigma: nan
# test_combo_seen2_frac_sigma_below_1: nan
# test_combo_seen2_frac_sigma_below_2: nan
# test_combo_seen2_pearson_delta: nan
# test_combo_seen2_pearson_delta_de: nan
# test_combo_seen2_fold_change_gap_all: nan
# test_combo_seen2_pearson_delta_top200_hvg: nan
# test_combo_seen2_fold_change_gap_upreg_3: nan
# test_combo_seen2_fold_change_gap_downreg_0.33: nan
# test_combo_seen2_fold_change_gap_downreg_0.1: nan
# test_combo_seen2_fold_change_gap_upreg_10: nan
# test_combo_seen2_pearson_top200_hvg: nan
# test_combo_seen2_pearson_top200_de: nan
# test_combo_seen2_pearson_top20_de: nan
# test_combo_seen2_pearson_delta_top200_de: nan
# test_combo_seen2_pearson_top100_de: nan
# test_combo_seen2_pearson_delta_top100_de: nan
# test_combo_seen2_pearson_delta_top50_de: nan
# test_combo_seen2_pearson_top50_de: nan
# test_combo_seen2_pearson_delta_top20_de: nan
# test_combo_seen2_mse_top200_hvg: nan
# test_combo_seen2_mse_top100_de: nan
# test_combo_seen2_mse_top200_de: nan
# test_combo_seen2_mse_top50_de: nan
# test_combo_seen2_mse_top20_de: nan
# test_unseen_single_frac_in_range: 0.9954545454545454
# test_unseen_single_frac_in_range_45_55: 0.0
# test_unseen_single_frac_in_range_40_60: 0.0
# test_unseen_single_frac_in_range_25_75: 0.0
# test_unseen_single_mean_sigma: 1.3717694
# test_unseen_single_std_sigma: 0.40393007
# test_unseen_single_frac_sigma_below_1: 0.144677033492823
# test_unseen_single_frac_sigma_below_2: 0.9310107655502392
# test_unseen_single_pearson_delta: -0.005095887305409003
# test_unseen_single_pearson_delta_de: -0.0381299814223088
# test_unseen_single_fold_change_gap_all: 0.20548654
# test_unseen_single_pearson_delta_top200_hvg: -0.014947578306056496
# test_unseen_single_fold_change_gap_upreg_3: 3.257904
# test_unseen_single_fold_change_gap_downreg_0.33: 0.70635796
# test_unseen_single_fold_change_gap_downreg_0.1: nan
# test_unseen_single_fold_change_gap_upreg_10: 17.901926
# test_unseen_single_pearson_top200_hvg: 0.9524519857525053
# test_unseen_single_pearson_top200_de: 0.9664358149647199
# test_unseen_single_pearson_top20_de: 0.9191112385493082
# test_unseen_single_pearson_delta_top200_de: -0.034816091715514
# test_unseen_single_pearson_top100_de: 0.956942343529758
# test_unseen_single_pearson_delta_top100_de: -0.04676510169011565
# test_unseen_single_pearson_delta_top50_de: -0.064621363702243
# test_unseen_single_pearson_top50_de: 0.9430040838836672
# test_unseen_single_pearson_delta_top20_de: -0.0381299814223088
# test_unseen_single_mse_top200_hvg: 0.090274476
# test_unseen_single_mse_top100_de: 0.1646241
# test_unseen_single_mse_top200_de: 0.11412172
# test_unseen_single_mse_top50_de: 0.2286427
# test_unseen_single_mse_top20_de: 0.29765046
# Done!
#
# wandb: Waiting for W&B process to finish, PID 38516
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_211953-3pnzo93n/logs/debug.log
# wandb: Find internal logs for this run at: /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_211953-3pnzo93n/logs/debug-internal.log
# wandb: Run summary:
# wandb:              test_combo_seen0_fold_change_gap_all nan
# wandb:      test_combo_seen0_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen0_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen0_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen0_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen0_frac_in_range nan
# wandb:              test_combo_seen0_frac_in_range_25_75 nan
# wandb:              test_combo_seen0_frac_in_range_40_60 nan
# wandb:              test_combo_seen0_frac_in_range_45_55 nan
# wandb:               test_combo_seen0_frac_sigma_below_1 nan
# wandb:               test_combo_seen0_frac_sigma_below_2 nan
# wandb:                              test_combo_seen0_mae nan
# wandb:                           test_combo_seen0_mae_de nan
# wandb:                       test_combo_seen0_mean_sigma nan
# wandb:                              test_combo_seen0_mse nan
# wandb:                           test_combo_seen0_mse_de nan
# wandb:                    test_combo_seen0_mse_top100_de nan
# wandb:                    test_combo_seen0_mse_top200_de nan
# wandb:                   test_combo_seen0_mse_top200_hvg nan
# wandb:                     test_combo_seen0_mse_top20_de nan
# wandb:                     test_combo_seen0_mse_top50_de nan
# wandb:                          test_combo_seen0_pearson nan
# wandb:                       test_combo_seen0_pearson_de nan
# wandb:                    test_combo_seen0_pearson_delta nan
# wandb:                 test_combo_seen0_pearson_delta_de nan
# wandb:          test_combo_seen0_pearson_delta_top100_de nan
# wandb:          test_combo_seen0_pearson_delta_top200_de nan
# wandb:         test_combo_seen0_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen0_pearson_delta_top20_de nan
# wandb:           test_combo_seen0_pearson_delta_top50_de nan
# wandb:                test_combo_seen0_pearson_top100_de nan
# wandb:                test_combo_seen0_pearson_top200_de nan
# wandb:               test_combo_seen0_pearson_top200_hvg nan
# wandb:                 test_combo_seen0_pearson_top20_de nan
# wandb:                 test_combo_seen0_pearson_top50_de nan
# wandb:                               test_combo_seen0_r2 nan
# wandb:                            test_combo_seen0_r2_de nan
# wandb:                         test_combo_seen0_spearman nan
# wandb:                      test_combo_seen0_spearman_de nan
# wandb:                        test_combo_seen0_std_sigma nan
# wandb:              test_combo_seen1_fold_change_gap_all nan
# wandb:      test_combo_seen1_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen1_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen1_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen1_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen1_frac_in_range nan
# wandb:              test_combo_seen1_frac_in_range_25_75 nan
# wandb:              test_combo_seen1_frac_in_range_40_60 nan
# wandb:              test_combo_seen1_frac_in_range_45_55 nan
# wandb:               test_combo_seen1_frac_sigma_below_1 nan
# wandb:               test_combo_seen1_frac_sigma_below_2 nan
# wandb:                              test_combo_seen1_mae nan
# wandb:                           test_combo_seen1_mae_de nan
# wandb:                       test_combo_seen1_mean_sigma nan
# wandb:                              test_combo_seen1_mse nan
# wandb:                           test_combo_seen1_mse_de nan
# wandb:                    test_combo_seen1_mse_top100_de nan
# wandb:                    test_combo_seen1_mse_top200_de nan
# wandb:                   test_combo_seen1_mse_top200_hvg nan
# wandb:                     test_combo_seen1_mse_top20_de nan
# wandb:                     test_combo_seen1_mse_top50_de nan
# wandb:                          test_combo_seen1_pearson nan
# wandb:                       test_combo_seen1_pearson_de nan
# wandb:                    test_combo_seen1_pearson_delta nan
# wandb:                 test_combo_seen1_pearson_delta_de nan
# wandb:          test_combo_seen1_pearson_delta_top100_de nan
# wandb:          test_combo_seen1_pearson_delta_top200_de nan
# wandb:         test_combo_seen1_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen1_pearson_delta_top20_de nan
# wandb:           test_combo_seen1_pearson_delta_top50_de nan
# wandb:                test_combo_seen1_pearson_top100_de nan
# wandb:                test_combo_seen1_pearson_top200_de nan
# wandb:               test_combo_seen1_pearson_top200_hvg nan
# wandb:                 test_combo_seen1_pearson_top20_de nan
# wandb:                 test_combo_seen1_pearson_top50_de nan
# wandb:                               test_combo_seen1_r2 nan
# wandb:                            test_combo_seen1_r2_de nan
# wandb:                         test_combo_seen1_spearman nan
# wandb:                      test_combo_seen1_spearman_de nan
# wandb:                        test_combo_seen1_std_sigma nan
# wandb:              test_combo_seen2_fold_change_gap_all nan
# wandb:      test_combo_seen2_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen2_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen2_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen2_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen2_frac_in_range nan
# wandb:              test_combo_seen2_frac_in_range_25_75 nan
# wandb:              test_combo_seen2_frac_in_range_40_60 nan
# wandb:              test_combo_seen2_frac_in_range_45_55 nan
# wandb:               test_combo_seen2_frac_sigma_below_1 nan
# wandb:               test_combo_seen2_frac_sigma_below_2 nan
# wandb:                              test_combo_seen2_mae nan
# wandb:                           test_combo_seen2_mae_de nan
# wandb:                       test_combo_seen2_mean_sigma nan
# wandb:                              test_combo_seen2_mse nan
# wandb:                           test_combo_seen2_mse_de nan
# wandb:                    test_combo_seen2_mse_top100_de nan
# wandb:                    test_combo_seen2_mse_top200_de nan
# wandb:                   test_combo_seen2_mse_top200_hvg nan
# wandb:                     test_combo_seen2_mse_top20_de nan
# wandb:                     test_combo_seen2_mse_top50_de nan
# wandb:                          test_combo_seen2_pearson nan
# wandb:                       test_combo_seen2_pearson_de nan
# wandb:                    test_combo_seen2_pearson_delta nan
# wandb:                 test_combo_seen2_pearson_delta_de nan
# wandb:          test_combo_seen2_pearson_delta_top100_de nan
# wandb:          test_combo_seen2_pearson_delta_top200_de nan
# wandb:         test_combo_seen2_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen2_pearson_delta_top20_de nan
# wandb:           test_combo_seen2_pearson_delta_top50_de nan
# wandb:                test_combo_seen2_pearson_top100_de nan
# wandb:                test_combo_seen2_pearson_top200_de nan
# wandb:               test_combo_seen2_pearson_top200_hvg nan
# wandb:                 test_combo_seen2_pearson_top20_de nan
# wandb:                 test_combo_seen2_pearson_top50_de nan
# wandb:                               test_combo_seen2_r2 nan
# wandb:                            test_combo_seen2_r2_de nan
# wandb:                         test_combo_seen2_spearman nan
# wandb:                      test_combo_seen2_spearman_de nan
# wandb:                        test_combo_seen2_std_sigma nan
# wandb:                                       test_de_mae 0.48909
# wandb:                                       test_de_mse 0.29765
# wandb:                                   test_de_pearson 0.91911
# wandb:                                        test_de_r2 0.79946
# wandb:                                  test_de_spearman 0.89375
# wandb:                          test_fold_change_gap_all 0.20549
# wandb:                  test_fold_change_gap_downreg_0.1 nan
# wandb:                 test_fold_change_gap_downreg_0.33 0.70636
# wandb:                     test_fold_change_gap_upreg_10 17.90193
# wandb:                      test_fold_change_gap_upreg_3 3.2579
# wandb:                                test_frac_in_range 0.99545
# wandb:                          test_frac_in_range_25_75 0.0
# wandb:                          test_frac_in_range_40_60 0.0
# wandb:                          test_frac_in_range_45_55 0.0
# wandb:                           test_frac_sigma_below_1 0.14468
# wandb:                           test_frac_sigma_below_2 0.93101
# wandb:                                          test_mae 0.04563
# wandb:                                   test_mean_sigma 1.37177
# wandb:                                          test_mse 0.00872
# wandb:                                test_mse_top100_de 0.16462
# wandb:                                test_mse_top200_de 0.11412
# wandb:                               test_mse_top200_hvg 0.09027
# wandb:                                 test_mse_top20_de 0.29765
# wandb:                                 test_mse_top50_de 0.22864
# wandb:                                      test_pearson 0.98581
# wandb:                                test_pearson_delta -0.0051
# wandb:                             test_pearson_delta_de -0.03813
# wandb:                      test_pearson_delta_top100_de -0.04677
# wandb:                      test_pearson_delta_top200_de -0.03482
# wandb:                     test_pearson_delta_top200_hvg -0.01495
# wandb:                       test_pearson_delta_top20_de -0.03813
# wandb:                       test_pearson_delta_top50_de -0.06462
# wandb:                            test_pearson_top100_de 0.95694
# wandb:                            test_pearson_top200_de 0.96644
# wandb:                           test_pearson_top200_hvg 0.95245
# wandb:                             test_pearson_top20_de 0.91911
# wandb:                             test_pearson_top50_de 0.943
# wandb:                                           test_r2 0.96878
# wandb:                                     test_spearman 0.96505
# wandb:                                    test_std_sigma 0.40393
# wandb:            test_unseen_single_fold_change_gap_all 0.20549
# wandb:    test_unseen_single_fold_change_gap_downreg_0.1 nan
# wandb:   test_unseen_single_fold_change_gap_downreg_0.33 0.70636
# wandb:       test_unseen_single_fold_change_gap_upreg_10 17.90193
# wandb:        test_unseen_single_fold_change_gap_upreg_3 3.2579
# wandb:                  test_unseen_single_frac_in_range 0.99545
# wandb:            test_unseen_single_frac_in_range_25_75 0.0
# wandb:            test_unseen_single_frac_in_range_40_60 0.0
# wandb:            test_unseen_single_frac_in_range_45_55 0.0
# wandb:             test_unseen_single_frac_sigma_below_1 0.14468
# wandb:             test_unseen_single_frac_sigma_below_2 0.93101
# wandb:                            test_unseen_single_mae 0.04563
# wandb:                         test_unseen_single_mae_de 0.48909
# wandb:                     test_unseen_single_mean_sigma 1.37177
# wandb:                            test_unseen_single_mse 0.00872
# wandb:                         test_unseen_single_mse_de 0.29765
# wandb:                  test_unseen_single_mse_top100_de 0.16462
# wandb:                  test_unseen_single_mse_top200_de 0.11412
# wandb:                 test_unseen_single_mse_top200_hvg 0.09027
# wandb:                   test_unseen_single_mse_top20_de 0.29765
# wandb:                   test_unseen_single_mse_top50_de 0.22864
# wandb:                        test_unseen_single_pearson 0.98581
# wandb:                     test_unseen_single_pearson_de 0.91911
# wandb:                  test_unseen_single_pearson_delta -0.0051
# wandb:               test_unseen_single_pearson_delta_de -0.03813
# wandb:        test_unseen_single_pearson_delta_top100_de -0.04677
# wandb:        test_unseen_single_pearson_delta_top200_de -0.03482
# wandb:       test_unseen_single_pearson_delta_top200_hvg -0.01495
# wandb:         test_unseen_single_pearson_delta_top20_de -0.03813
# wandb:         test_unseen_single_pearson_delta_top50_de -0.06462
# wandb:              test_unseen_single_pearson_top100_de 0.95694
# wandb:              test_unseen_single_pearson_top200_de 0.96644
# wandb:             test_unseen_single_pearson_top200_hvg 0.95245
# wandb:               test_unseen_single_pearson_top20_de 0.91911
# wandb:               test_unseen_single_pearson_top50_de 0.943
# wandb:                             test_unseen_single_r2 0.96878
# wandb:                          test_unseen_single_r2_de 0.79946
# wandb:                       test_unseen_single_spearman 0.96505
# wandb:                    test_unseen_single_spearman_de 0.89375
# wandb:                      test_unseen_single_std_sigma 0.40393
# wandb: Run history:
# wandb:              test_combo_seen0_fold_change_gap_all
# wandb:      test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen0_fold_change_gap_upreg_10
# wandb:          test_combo_seen0_fold_change_gap_upreg_3
# wandb:                    test_combo_seen0_frac_in_range
# wandb:              test_combo_seen0_frac_in_range_25_75
# wandb:              test_combo_seen0_frac_in_range_40_60
# wandb:              test_combo_seen0_frac_in_range_45_55
# wandb:               test_combo_seen0_frac_sigma_below_1
# wandb:               test_combo_seen0_frac_sigma_below_2
# wandb:                              test_combo_seen0_mae
# wandb:                           test_combo_seen0_mae_de
# wandb:                       test_combo_seen0_mean_sigma
# wandb:                              test_combo_seen0_mse
# wandb:                           test_combo_seen0_mse_de
# wandb:                    test_combo_seen0_mse_top100_de
# wandb:                    test_combo_seen0_mse_top200_de
# wandb:                   test_combo_seen0_mse_top200_hvg
# wandb:                     test_combo_seen0_mse_top20_de
# wandb:                     test_combo_seen0_mse_top50_de
# wandb:                          test_combo_seen0_pearson
# wandb:                       test_combo_seen0_pearson_de
# wandb:                    test_combo_seen0_pearson_delta
# wandb:                 test_combo_seen0_pearson_delta_de
# wandb:          test_combo_seen0_pearson_delta_top100_de
# wandb:          test_combo_seen0_pearson_delta_top200_de
# wandb:         test_combo_seen0_pearson_delta_top200_hvg
# wandb:           test_combo_seen0_pearson_delta_top20_de
# wandb:           test_combo_seen0_pearson_delta_top50_de
# wandb:                test_combo_seen0_pearson_top100_de
# wandb:                test_combo_seen0_pearson_top200_de
# wandb:               test_combo_seen0_pearson_top200_hvg
# wandb:                 test_combo_seen0_pearson_top20_de
# wandb:                 test_combo_seen0_pearson_top50_de
# wandb:                               test_combo_seen0_r2
# wandb:                            test_combo_seen0_r2_de
# wandb:                         test_combo_seen0_spearman
# wandb:                      test_combo_seen0_spearman_de
# wandb:                        test_combo_seen0_std_sigma
# wandb:              test_combo_seen1_fold_change_gap_all
# wandb:      test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen1_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen1_fold_change_gap_upreg_10
# wandb:          test_combo_seen1_fold_change_gap_upreg_3
# wandb:                    test_combo_seen1_frac_in_range
# wandb:              test_combo_seen1_frac_in_range_25_75
# wandb:              test_combo_seen1_frac_in_range_40_60
# wandb:              test_combo_seen1_frac_in_range_45_55
# wandb:               test_combo_seen1_frac_sigma_below_1
# wandb:               test_combo_seen1_frac_sigma_below_2
# wandb:                              test_combo_seen1_mae
# wandb:                           test_combo_seen1_mae_de
# wandb:                       test_combo_seen1_mean_sigma
# wandb:                              test_combo_seen1_mse
# wandb:                           test_combo_seen1_mse_de
# wandb:                    test_combo_seen1_mse_top100_de
# wandb:                    test_combo_seen1_mse_top200_de
# wandb:                   test_combo_seen1_mse_top200_hvg
# wandb:                     test_combo_seen1_mse_top20_de
# wandb:                     test_combo_seen1_mse_top50_de
# wandb:                          test_combo_seen1_pearson
# wandb:                       test_combo_seen1_pearson_de
# wandb:                    test_combo_seen1_pearson_delta
# wandb:                 test_combo_seen1_pearson_delta_de
# wandb:          test_combo_seen1_pearson_delta_top100_de
# wandb:          test_combo_seen1_pearson_delta_top200_de
# wandb:         test_combo_seen1_pearson_delta_top200_hvg
# wandb:           test_combo_seen1_pearson_delta_top20_de
# wandb:           test_combo_seen1_pearson_delta_top50_de
# wandb:                test_combo_seen1_pearson_top100_de
# wandb:                test_combo_seen1_pearson_top200_de
# wandb:               test_combo_seen1_pearson_top200_hvg
# wandb:                 test_combo_seen1_pearson_top20_de
# wandb:                 test_combo_seen1_pearson_top50_de
# wandb:                               test_combo_seen1_r2
# wandb:                            test_combo_seen1_r2_de
# wandb:                         test_combo_seen1_spearman
# wandb:                      test_combo_seen1_spearman_de
# wandb:                        test_combo_seen1_std_sigma
# wandb:              test_combo_seen2_fold_change_gap_all
# wandb:      test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen2_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen2_fold_change_gap_upreg_10
# wandb:          test_combo_seen2_fold_change_gap_upreg_3
# wandb:                    test_combo_seen2_frac_in_range
# wandb:              test_combo_seen2_frac_in_range_25_75
# wandb:              test_combo_seen2_frac_in_range_40_60
# wandb:              test_combo_seen2_frac_in_range_45_55
# wandb:               test_combo_seen2_frac_sigma_below_1
# wandb:               test_combo_seen2_frac_sigma_below_2
# wandb:                              test_combo_seen2_mae
# wandb:                           test_combo_seen2_mae_de
# wandb:                       test_combo_seen2_mean_sigma
# wandb:                              test_combo_seen2_mse
# wandb:                           test_combo_seen2_mse_de
# wandb:                    test_combo_seen2_mse_top100_de
# wandb:                    test_combo_seen2_mse_top200_de
# wandb:                   test_combo_seen2_mse_top200_hvg
# wandb:                     test_combo_seen2_mse_top20_de
# wandb:                     test_combo_seen2_mse_top50_de
# wandb:                          test_combo_seen2_pearson
# wandb:                       test_combo_seen2_pearson_de
# wandb:                    test_combo_seen2_pearson_delta
# wandb:                 test_combo_seen2_pearson_delta_de
# wandb:          test_combo_seen2_pearson_delta_top100_de
# wandb:          test_combo_seen2_pearson_delta_top200_de
# wandb:         test_combo_seen2_pearson_delta_top200_hvg
# wandb:           test_combo_seen2_pearson_delta_top20_de
# wandb:           test_combo_seen2_pearson_delta_top50_de
# wandb:                test_combo_seen2_pearson_top100_de
# wandb:                test_combo_seen2_pearson_top200_de
# wandb:               test_combo_seen2_pearson_top200_hvg
# wandb:                 test_combo_seen2_pearson_top20_de
# wandb:                 test_combo_seen2_pearson_top50_de
# wandb:                               test_combo_seen2_r2
# wandb:                            test_combo_seen2_r2_de
# wandb:                         test_combo_seen2_spearman
# wandb:                      test_combo_seen2_spearman_de
# wandb:                        test_combo_seen2_std_sigma
# wandb:                                       test_de_mae ▁
# wandb:                                       test_de_mse ▁
# wandb:                                   test_de_pearson ▁
# wandb:                                        test_de_r2 ▁
# wandb:                                  test_de_spearman ▁
# wandb:                          test_fold_change_gap_all ▁
# wandb:                  test_fold_change_gap_downreg_0.1
# wandb:                 test_fold_change_gap_downreg_0.33 ▁
# wandb:                     test_fold_change_gap_upreg_10 ▁
# wandb:                      test_fold_change_gap_upreg_3 ▁
# wandb:                                test_frac_in_range ▁
# wandb:                          test_frac_in_range_25_75 ▁
# wandb:                          test_frac_in_range_40_60 ▁
# wandb:                          test_frac_in_range_45_55 ▁
# wandb:                           test_frac_sigma_below_1 ▁
# wandb:                           test_frac_sigma_below_2 ▁
# wandb:                                          test_mae ▁
# wandb:                                   test_mean_sigma ▁
# wandb:                                          test_mse ▁
# wandb:                                test_mse_top100_de ▁
# wandb:                                test_mse_top200_de ▁
# wandb:                               test_mse_top200_hvg ▁
# wandb:                                 test_mse_top20_de ▁
# wandb:                                 test_mse_top50_de ▁
# wandb:                                      test_pearson ▁
# wandb:                                test_pearson_delta ▁
# wandb:                             test_pearson_delta_de ▁
# wandb:                      test_pearson_delta_top100_de ▁
# wandb:                      test_pearson_delta_top200_de ▁
# wandb:                     test_pearson_delta_top200_hvg ▁
# wandb:                       test_pearson_delta_top20_de ▁
# wandb:                       test_pearson_delta_top50_de ▁
# wandb:                            test_pearson_top100_de ▁
# wandb:                            test_pearson_top200_de ▁
# wandb:                           test_pearson_top200_hvg ▁
# wandb:                             test_pearson_top20_de ▁
# wandb:                             test_pearson_top50_de ▁
# wandb:                                           test_r2 ▁
# wandb:                                     test_spearman ▁
# wandb:                                    test_std_sigma ▁
# wandb:            test_unseen_single_fold_change_gap_all ▁
# wandb:    test_unseen_single_fold_change_gap_downreg_0.1
# wandb:   test_unseen_single_fold_change_gap_downreg_0.33 ▁
# wandb:       test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:        test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                  test_unseen_single_frac_in_range ▁
# wandb:            test_unseen_single_frac_in_range_25_75 ▁
# wandb:            test_unseen_single_frac_in_range_40_60 ▁
# wandb:            test_unseen_single_frac_in_range_45_55 ▁
# wandb:             test_unseen_single_frac_sigma_below_1 ▁
# wandb:             test_unseen_single_frac_sigma_below_2 ▁
# wandb:                            test_unseen_single_mae ▁
# wandb:                         test_unseen_single_mae_de ▁
# wandb:                     test_unseen_single_mean_sigma ▁
# wandb:                            test_unseen_single_mse ▁
# wandb:                         test_unseen_single_mse_de ▁
# wandb:                  test_unseen_single_mse_top100_de ▁
# wandb:                  test_unseen_single_mse_top200_de ▁
# wandb:                 test_unseen_single_mse_top200_hvg ▁
# wandb:                   test_unseen_single_mse_top20_de ▁
# wandb:                   test_unseen_single_mse_top50_de ▁
# wandb:                        test_unseen_single_pearson ▁
# wandb:                     test_unseen_single_pearson_de ▁
# wandb:                  test_unseen_single_pearson_delta ▁
# wandb:               test_unseen_single_pearson_delta_de ▁
# wandb:        test_unseen_single_pearson_delta_top100_de ▁
# wandb:        test_unseen_single_pearson_delta_top200_de ▁
# wandb:       test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:         test_unseen_single_pearson_delta_top20_de ▁
# wandb:         test_unseen_single_pearson_delta_top50_de ▁
# wandb:              test_unseen_single_pearson_top100_de ▁
# wandb:              test_unseen_single_pearson_top200_de ▁
# wandb:             test_unseen_single_pearson_top200_hvg ▁
# wandb:               test_unseen_single_pearson_top20_de ▁
# wandb:               test_unseen_single_pearson_top50_de ▁
# wandb:                             test_unseen_single_r2 ▁
# wandb:                          test_unseen_single_r2_de ▁
# wandb:                       test_unseen_single_spearman ▁
# wandb:                    test_unseen_single_spearman_de ▁
# wandb:                      test_unseen_single_std_sigma ▁
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced no_gnn: https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016/runs/3pnzo93n

# %%
# !python train.py --dataset Adamson2016 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3 \
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:4 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --no_gnn \
                 --exp_name no_gnn \
                 --wandb \
                 --delta_predict
# Out:
# ---- Printing Arguments ----
# dataset: Adamson2016
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:4
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: True
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: False
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: True
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: no_gnn
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run no_gnn
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016/runs/pxh58q0v
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_212056-pxh58q0v
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_co-expression_100.0_64_2_l3_Adamson2016_gamma2_gene_emb_delta_predict_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 7054 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:22
# Creating dataloaders....
# Dataloaders created...
# Finished data setup, in total takes 0.450 min
# Initializing model...
# Start Training...
# Epoch 1 Step 1 Train Loss: 0.7203
# Epoch 1 Step 51 Train Loss: 0.3000
# Epoch 1 Step 101 Train Loss: 0.2428
# Epoch 1 Step 151 Train Loss: 0.2951
# Epoch 1 Step 201 Train Loss: 0.3026
# Epoch 1 Step 251 Train Loss: 0.2926
# Epoch 1 Step 301 Train Loss: 0.3202
# Epoch 1 Step 351 Train Loss: 0.2997
# Epoch 1 Step 401 Train Loss: 0.2665
# Epoch 1 Step 451 Train Loss: 0.3752
# Epoch 6 Step 901 Train Loss: 0.2841
# Epoch 6 Step 951 Train Loss: 0.2612
# Epoch 6 Step 1001 Train Loss: 0.2565
# Epoch 6 Step 1051 Train Loss: 0.2879
# Epoch 6 Step 1101 Train Loss: 0.2701
# Epoch 6 Step 1151 Train Loss: 0.2727
# Epoch 6 Step 1201 Train Loss: 0.2781
# Epoch 6 Step 1251 Train Loss: 0.3309
# Epoch 6 Step 1301 Train Loss: 0.2035
# Epoch 6 Step 1351 Train Loss: 0.2968
# Epoch 6 Step 1401 Train Loss: 0.1747
# Epoch 6 Step 1451 Train Loss: 0.3273
# Epoch 6 Step 1501 Train Loss: 0.2349
# Epoch 6 Step 1551 Train Loss: 0.3256
# Epoch 6 Step 1601 Train Loss: 0.2478
# Epoch 6 Step 1651 Train Loss: 0.2885
# Epoch 6: Train: 0.0060, R2 0.9765 Validation: 0.0067. R2 0.9740 Loss: 0.2841
# DE_Train: 0.0723, R2 0.9541 DE_Validation: 0.1790. R2 0.8733
# Epoch 7 Step 1 Train Loss: 0.2684
# Epoch 7 Step 51 Train Loss: 0.3143
# Epoch 7 Step 101 Train Loss: 0.3552
# Epoch 7 Step 151 Train Loss: 0.2745
# Epoch 7 Step 201 Train Loss: 0.2188
# Epoch 7 Step 251 Train Loss: 0.4653
# Epoch 7 Step 301 Train Loss: 0.3611
# Epoch 7 Step 351 Train Loss: 0.2979
# Epoch 7 Step 401 Train Loss: 0.2519
# Epoch 7 Step 451 Train Loss: 0.2426
# Epoch 7 Step 501 Train Loss: 0.2167
# Epoch 7 Step 551 Train Loss: 0.3459
# Epoch 7 Step 601 Train Loss: 0.2270
# Epoch 7 Step 651 Train Loss: 0.2490
# Epoch 7 Step 701 Train Loss: 0.2149
# Epoch 7 Step 751 Train Loss: 0.3828
# Epoch 7 Step 801 Train Loss: 0.3017
# Epoch 7 Step 851 Train Loss: 0.2706
# Epoch 7 Step 901 Train Loss: 0.3572
# Epoch 7 Step 951 Train Loss: 0.3107
# Epoch 7 Step 1001 Train Loss: 0.2434
# Epoch 7 Step 1051 Train Loss: 0.2539
# Epoch 7 Step 1101 Train Loss: 0.3214
# Epoch 7 Step 1151 Train Loss: 0.2865
# Epoch 7 Step 1201 Train Loss: 0.2043
# Epoch 7 Step 1251 Train Loss: 0.3431
# Epoch 7 Step 1301 Train Loss: 0.2204
# Epoch 7 Step 1351 Train Loss: 0.2801
# Epoch 7 Step 1401 Train Loss: 0.3019
# Epoch 7 Step 1451 Train Loss: 0.2507
# Epoch 7 Step 1501 Train Loss: 0.2631
# Epoch 7 Step 1551 Train Loss: 0.2925
# Epoch 7 Step 1601 Train Loss: 0.2198
# Epoch 7 Step 1651 Train Loss: 0.2938
# Epoch 7: Train: 0.0076, R2 0.9703 Validation: 0.0078. R2 0.9698 Loss: 0.2832
# DE_Train: 0.0749, R2 0.9525 DE_Validation: 0.1879. R2 0.8692
# Epoch 8 Step 1 Train Loss: 0.2362
# Epoch 8 Step 51 Train Loss: 0.2351
# Epoch 8 Step 101 Train Loss: 0.2920
# Epoch 8 Step 151 Train Loss: 0.2487
# Epoch 8 Step 201 Train Loss: 0.2923
# Epoch 8 Step 251 Train Loss: 0.2559
# Epoch 8 Step 301 Train Loss: 0.2475
# Epoch 8 Step 351 Train Loss: 0.2695
# Epoch 8 Step 401 Train Loss: 0.2148
# Epoch 8 Step 451 Train Loss: 0.2636
# Epoch 8 Step 501 Train Loss: 0.3436
# Epoch 8 Step 551 Train Loss: 0.3145
# Epoch 8 Step 601 Train Loss: 0.3026
# Epoch 8 Step 651 Train Loss: 0.2013
# Epoch 8 Step 701 Train Loss: 0.2032
# Epoch 8 Step 751 Train Loss: 0.3452
# Epoch 8 Step 801 Train Loss: 0.2702
# Epoch 8 Step 851 Train Loss: 0.3006
# Epoch 8 Step 901 Train Loss: 0.2274
# Epoch 8 Step 951 Train Loss: 0.2646
# Epoch 8 Step 1001 Train Loss: 0.3055
# Epoch 8 Step 1051 Train Loss: 0.2947
# Epoch 8 Step 1101 Train Loss: 0.2817
# Epoch 8 Step 1151 Train Loss: 0.2644
# Epoch 8 Step 1201 Train Loss: 0.2732
# Epoch 8 Step 1251 Train Loss: 0.2543
# Epoch 8 Step 1301 Train Loss: 0.2456
# Epoch 8 Step 1351 Train Loss: 0.2862
# Epoch 8 Step 1401 Train Loss: 0.2822
# Epoch 8 Step 1451 Train Loss: 0.2683
# Epoch 8 Step 1501 Train Loss: 0.3139
# Epoch 8 Step 1551 Train Loss: 0.3009
# Epoch 8 Step 1601 Train Loss: 0.2407
# Epoch 8 Step 1651 Train Loss: 0.2392
# Epoch 9: Train: 0.0064, R2 0.9750 Validation: 0.0067. R2 0.9744 Loss: 0.2832
# DE_Train: 0.0736, R2 0.9529 DE_Validation: 0.1841. R2 0.8708
# Epoch 10 Step 1 Train Loss: 0.3146
# Epoch 10 Step 51 Train Loss: 0.2389
# Epoch 10 Step 101 Train Loss: 0.4029
# Epoch 10 Step 151 Train Loss: 0.2412
# Epoch 10 Step 201 Train Loss: 0.2691
# Epoch 10 Step 251 Train Loss: 0.3448
# Epoch 10 Step 301 Train Loss: 0.2440
# Epoch 10 Step 351 Train Loss: 0.3275
# Epoch 10 Step 401 Train Loss: 0.2515
# Epoch 10 Step 451 Train Loss: 0.2266
# Epoch 10 Step 501 Train Loss: 0.3728
# Epoch 10 Step 551 Train Loss: 0.2159
# Epoch 10 Step 601 Train Loss: 0.2749
# Epoch 10 Step 651 Train Loss: 0.2967
# Epoch 10 Step 701 Train Loss: 0.2265
# Epoch 10 Step 751 Train Loss: 0.3277
# Epoch 10 Step 801 Train Loss: 0.3254
# Epoch 10 Step 851 Train Loss: 0.2886
# Epoch 10 Step 901 Train Loss: 0.2525
# Epoch 10 Step 951 Train Loss: 0.3332
# Epoch 10 Step 1001 Train Loss: 0.3002
# Epoch 10 Step 1051 Train Loss: 0.2333
# Epoch 10 Step 1101 Train Loss: 0.3044
# Epoch 10 Step 1151 Train Loss: 0.2356
# Epoch 10 Step 1201 Train Loss: 0.2159
# Epoch 10 Step 1251 Train Loss: 0.3060
# Epoch 10 Step 1301 Train Loss: 0.2402
# Epoch 10 Step 1351 Train Loss: 0.2280
# Epoch 10 Step 1401 Train Loss: 0.2091
# Epoch 10 Step 1451 Train Loss: 0.3904
# Epoch 10 Step 1501 Train Loss: 0.2225
# Epoch 10 Step 1551 Train Loss: 0.2566
# Epoch 10 Step 1601 Train Loss: 0.2521
# Epoch 10 Step 1651 Train Loss: 0.2197
# Epoch 10: Train: 0.0065, R2 0.9745 Validation: 0.0067. R2 0.9741 Loss: 0.2832
# DE_Train: 0.0730, R2 0.9535 DE_Validation: 0.1816. R2 0.8724
# Saving model....
# Start testing....
# Final best performing model: Test_DE: 0.1615, R2 0.9120
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# test_combo_seen0_mse: nan
# test_combo_seen0_mae: nan
# test_combo_seen0_spearman: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_r2: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_mae_de: nan
# test_combo_seen0_spearman_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen0_r2_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_mae: nan
# test_combo_seen1_spearman: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_r2: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_mae_de: nan
# test_combo_seen1_spearman_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen1_r2_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_mae: nan
# test_combo_seen2_spearman: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_r2: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_mae_de: nan
# test_combo_seen2_spearman_de: nan
# test_combo_seen2_pearson_de: nan
# test_combo_seen2_r2_de: nan
# test_unseen_single_mse: 0.008079052
# test_unseen_single_mae: 0.0650318
# test_unseen_single_spearman: 0.9175897254372344
# test_unseen_single_pearson: 0.9897999597248156
# test_unseen_single_r2: 0.9695128458462289
# test_unseen_single_mse_de: 0.16147724
# test_unseen_single_mae_de: 0.2649612
# test_unseen_single_spearman_de: 0.9601249013576115
# test_unseen_single_pearson_de: 0.9709170113015115
# test_unseen_single_r2_de: 0.9120051188431101
# test_combo_seen0_frac_in_range: nan
# test_combo_seen0_frac_in_range_45_55: nan
# test_combo_seen0_frac_in_range_40_60: nan
# test_combo_seen0_frac_in_range_25_75: nan
# test_combo_seen0_mean_sigma: nan
# test_combo_seen0_std_sigma: nan
# test_combo_seen0_frac_sigma_below_1: nan
# test_combo_seen0_frac_sigma_below_2: nan
# test_combo_seen0_pearson_delta: nan
# test_combo_seen0_pearson_delta_de: nan
# test_combo_seen0_fold_change_gap_all: nan
# test_combo_seen0_pearson_delta_top200_hvg: nan
# test_combo_seen0_fold_change_gap_upreg_3: nan
# test_combo_seen0_fold_change_gap_downreg_0.33: nan
# test_combo_seen0_fold_change_gap_downreg_0.1: nan
# test_combo_seen0_fold_change_gap_upreg_10: nan
# test_combo_seen0_pearson_top200_hvg: nan
# test_combo_seen0_pearson_top200_de: nan
# test_combo_seen0_pearson_top20_de: nan
# test_combo_seen0_pearson_delta_top200_de: nan
# test_combo_seen0_pearson_top100_de: nan
# test_combo_seen0_pearson_delta_top100_de: nan
# test_combo_seen0_pearson_delta_top50_de: nan
# test_combo_seen0_pearson_top50_de: nan
# test_combo_seen0_pearson_delta_top20_de: nan
# test_combo_seen0_mse_top200_hvg: nan
# test_combo_seen0_mse_top100_de: nan
# test_combo_seen0_mse_top200_de: nan
# test_combo_seen0_mse_top50_de: nan
# test_combo_seen0_mse_top20_de: nan
# test_combo_seen1_frac_in_range: nan
# test_combo_seen1_frac_in_range_45_55: nan
# test_combo_seen1_frac_in_range_40_60: nan
# test_combo_seen1_frac_in_range_25_75: nan
# test_combo_seen1_mean_sigma: nan
# test_combo_seen1_std_sigma: nan
# test_combo_seen1_frac_sigma_below_1: nan
# test_combo_seen1_frac_sigma_below_2: nan
# test_combo_seen1_pearson_delta: nan
# test_combo_seen1_pearson_delta_de: nan
# test_combo_seen1_fold_change_gap_all: nan
# test_combo_seen1_pearson_delta_top200_hvg: nan
# test_combo_seen1_fold_change_gap_upreg_3: nan
# test_combo_seen1_fold_change_gap_downreg_0.33: nan
# test_combo_seen1_fold_change_gap_downreg_0.1: nan
# test_combo_seen1_fold_change_gap_upreg_10: nan
# test_combo_seen1_pearson_top200_hvg: nan
# test_combo_seen1_pearson_top200_de: nan
# test_combo_seen1_pearson_top20_de: nan
# test_combo_seen1_pearson_delta_top200_de: nan
# test_combo_seen1_pearson_top100_de: nan
# test_combo_seen1_pearson_delta_top100_de: nan
# test_combo_seen1_pearson_delta_top50_de: nan
# test_combo_seen1_pearson_top50_de: nan
# test_combo_seen1_pearson_delta_top20_de: nan
# test_combo_seen1_mse_top200_hvg: nan
# test_combo_seen1_mse_top100_de: nan
# test_combo_seen1_mse_top200_de: nan
# test_combo_seen1_mse_top50_de: nan
# test_combo_seen1_mse_top20_de: nan
# test_combo_seen2_frac_in_range: nan
# test_combo_seen2_frac_in_range_45_55: nan
# test_combo_seen2_frac_in_range_40_60: nan
# test_combo_seen2_frac_in_range_25_75: nan
# test_combo_seen2_mean_sigma: nan
# test_combo_seen2_std_sigma: nan
# test_combo_seen2_frac_sigma_below_1: nan
# test_combo_seen2_frac_sigma_below_2: nan
# test_combo_seen2_pearson_delta: nan
# test_combo_seen2_pearson_delta_de: nan
# test_combo_seen2_fold_change_gap_all: nan
# test_combo_seen2_pearson_delta_top200_hvg: nan
# test_combo_seen2_fold_change_gap_upreg_3: nan
# test_combo_seen2_fold_change_gap_downreg_0.33: nan
# test_combo_seen2_fold_change_gap_downreg_0.1: nan
# test_combo_seen2_fold_change_gap_upreg_10: nan
# test_combo_seen2_pearson_top200_hvg: nan
# test_combo_seen2_pearson_top200_de: nan
# test_combo_seen2_pearson_top20_de: nan
# test_combo_seen2_pearson_delta_top200_de: nan
# test_combo_seen2_pearson_top100_de: nan
# test_combo_seen2_pearson_delta_top100_de: nan
# test_combo_seen2_pearson_delta_top50_de: nan
# test_combo_seen2_pearson_top50_de: nan
# test_combo_seen2_pearson_delta_top20_de: nan
# test_combo_seen2_mse_top200_hvg: nan
# test_combo_seen2_mse_top100_de: nan
# test_combo_seen2_mse_top200_de: nan
# test_combo_seen2_mse_top50_de: nan
# test_combo_seen2_mse_top20_de: nan
# test_unseen_single_frac_in_range: 0.9541866028708132
# test_unseen_single_frac_in_range_45_55: 0.1182117224880383
# test_unseen_single_frac_in_range_40_60: 0.2241626794258373
# test_unseen_single_frac_in_range_25_75: 0.5922248803827751
# test_unseen_single_mean_sigma: 0.8408775
# test_unseen_single_std_sigma: 0.6970802
# test_unseen_single_frac_sigma_below_1: 0.8324461722488038
# test_unseen_single_frac_sigma_below_2: 0.9013456937799043
# test_unseen_single_pearson_delta: 0.5627102360776481
# test_unseen_single_pearson_delta_de: 0.7015602522203646
# test_unseen_single_fold_change_gap_all: 0.12650895
# test_unseen_single_pearson_delta_top200_hvg: 0.614266656779756
# test_unseen_single_fold_change_gap_upreg_3: 1.7336298
# test_unseen_single_fold_change_gap_downreg_0.33: 0.70019805
# test_unseen_single_fold_change_gap_downreg_0.1: nan
# test_unseen_single_fold_change_gap_upreg_10: 3.7928915
# test_unseen_single_pearson_top200_hvg: 0.9659741722231647
# test_unseen_single_pearson_top200_de: 0.9842810677188519
# test_unseen_single_pearson_top20_de: 0.9709170113015115
# test_unseen_single_pearson_delta_top200_de: 0.7076407616176599
# test_unseen_single_pearson_top100_de: 0.9824021970904361
# test_unseen_single_pearson_delta_top100_de: 0.7201755303696037
# test_unseen_single_pearson_delta_top50_de: 0.7180596776277487
# test_unseen_single_pearson_top50_de: 0.9787994751370731
# test_unseen_single_pearson_delta_top20_de: 0.7015602522203646
# test_unseen_single_mse_top200_hvg: 0.06577585
# test_unseen_single_mse_top100_de: 0.07617691
# test_unseen_single_mse_top200_de: 0.05393572
# test_unseen_single_mse_top50_de: 0.10970721
# test_unseen_single_mse_top20_de: 0.16147724
# Done!
#
# wandb: Waiting for W&B process to finish, PID 39307
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_212056-pxh58q0v/logs/debug.log
# wandb: Find internal logs for this run at: /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_212056-pxh58q0v/logs/debug-internal.log
# wandb: Run summary:
# wandb:              test_combo_seen0_fold_change_gap_all nan
# wandb:      test_combo_seen0_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen0_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen0_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen0_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen0_frac_in_range nan
# wandb:              test_combo_seen0_frac_in_range_25_75 nan
# wandb:              test_combo_seen0_frac_in_range_40_60 nan
# wandb:              test_combo_seen0_frac_in_range_45_55 nan
# wandb:               test_combo_seen0_frac_sigma_below_1 nan
# wandb:               test_combo_seen0_frac_sigma_below_2 nan
# wandb:                              test_combo_seen0_mae nan
# wandb:                           test_combo_seen0_mae_de nan
# wandb:                       test_combo_seen0_mean_sigma nan
# wandb:                              test_combo_seen0_mse nan
# wandb:                           test_combo_seen0_mse_de nan
# wandb:                    test_combo_seen0_mse_top100_de nan
# wandb:                    test_combo_seen0_mse_top200_de nan
# wandb:                   test_combo_seen0_mse_top200_hvg nan
# wandb:                     test_combo_seen0_mse_top20_de nan
# wandb:                     test_combo_seen0_mse_top50_de nan
# wandb:                          test_combo_seen0_pearson nan
# wandb:                       test_combo_seen0_pearson_de nan
# wandb:                    test_combo_seen0_pearson_delta nan
# wandb:                 test_combo_seen0_pearson_delta_de nan
# wandb:          test_combo_seen0_pearson_delta_top100_de nan
# wandb:          test_combo_seen0_pearson_delta_top200_de nan
# wandb:         test_combo_seen0_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen0_pearson_delta_top20_de nan
# wandb:           test_combo_seen0_pearson_delta_top50_de nan
# wandb:                test_combo_seen0_pearson_top100_de nan
# wandb:                test_combo_seen0_pearson_top200_de nan
# wandb:               test_combo_seen0_pearson_top200_hvg nan
# wandb:                 test_combo_seen0_pearson_top20_de nan
# wandb:                 test_combo_seen0_pearson_top50_de nan
# wandb:                               test_combo_seen0_r2 nan
# wandb:                            test_combo_seen0_r2_de nan
# wandb:                         test_combo_seen0_spearman nan
# wandb:                      test_combo_seen0_spearman_de nan
# wandb:                        test_combo_seen0_std_sigma nan
# wandb:              test_combo_seen1_fold_change_gap_all nan
# wandb:      test_combo_seen1_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen1_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen1_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen1_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen1_frac_in_range nan
# wandb:              test_combo_seen1_frac_in_range_25_75 nan
# wandb:              test_combo_seen1_frac_in_range_40_60 nan
# wandb:              test_combo_seen1_frac_in_range_45_55 nan
# wandb:               test_combo_seen1_frac_sigma_below_1 nan
# wandb:               test_combo_seen1_frac_sigma_below_2 nan
# wandb:                              test_combo_seen1_mae nan
# wandb:                           test_combo_seen1_mae_de nan
# wandb:                       test_combo_seen1_mean_sigma nan
# wandb:                              test_combo_seen1_mse nan
# wandb:                           test_combo_seen1_mse_de nan
# wandb:                    test_combo_seen1_mse_top100_de nan
# wandb:                    test_combo_seen1_mse_top200_de nan
# wandb:                   test_combo_seen1_mse_top200_hvg nan
# wandb:                     test_combo_seen1_mse_top20_de nan
# wandb:                     test_combo_seen1_mse_top50_de nan
# wandb:                          test_combo_seen1_pearson nan
# wandb:                       test_combo_seen1_pearson_de nan
# wandb:                    test_combo_seen1_pearson_delta nan
# wandb:                 test_combo_seen1_pearson_delta_de nan
# wandb:          test_combo_seen1_pearson_delta_top100_de nan
# wandb:          test_combo_seen1_pearson_delta_top200_de nan
# wandb:         test_combo_seen1_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen1_pearson_delta_top20_de nan
# wandb:           test_combo_seen1_pearson_delta_top50_de nan
# wandb:                test_combo_seen1_pearson_top100_de nan
# wandb:                test_combo_seen1_pearson_top200_de nan
# wandb:               test_combo_seen1_pearson_top200_hvg nan
# wandb:                 test_combo_seen1_pearson_top20_de nan
# wandb:                 test_combo_seen1_pearson_top50_de nan
# wandb:                               test_combo_seen1_r2 nan
# wandb:                            test_combo_seen1_r2_de nan
# wandb:                         test_combo_seen1_spearman nan
# wandb:                      test_combo_seen1_spearman_de nan
# wandb:                        test_combo_seen1_std_sigma nan
# wandb:              test_combo_seen2_fold_change_gap_all nan
# wandb:      test_combo_seen2_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen2_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen2_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen2_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen2_frac_in_range nan
# wandb:              test_combo_seen2_frac_in_range_25_75 nan
# wandb:              test_combo_seen2_frac_in_range_40_60 nan
# wandb:              test_combo_seen2_frac_in_range_45_55 nan
# wandb:               test_combo_seen2_frac_sigma_below_1 nan
# wandb:               test_combo_seen2_frac_sigma_below_2 nan
# wandb:                              test_combo_seen2_mae nan
# wandb:                           test_combo_seen2_mae_de nan
# wandb:                       test_combo_seen2_mean_sigma nan
# wandb:                              test_combo_seen2_mse nan
# wandb:                           test_combo_seen2_mse_de nan
# wandb:                    test_combo_seen2_mse_top100_de nan
# wandb:                    test_combo_seen2_mse_top200_de nan
# wandb:                   test_combo_seen2_mse_top200_hvg nan
# wandb:                     test_combo_seen2_mse_top20_de nan
# wandb:                     test_combo_seen2_mse_top50_de nan
# wandb:                          test_combo_seen2_pearson nan
# wandb:                       test_combo_seen2_pearson_de nan
# wandb:                    test_combo_seen2_pearson_delta nan
# wandb:                 test_combo_seen2_pearson_delta_de nan
# wandb:          test_combo_seen2_pearson_delta_top100_de nan
# wandb:          test_combo_seen2_pearson_delta_top200_de nan
# wandb:         test_combo_seen2_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen2_pearson_delta_top20_de nan
# wandb:           test_combo_seen2_pearson_delta_top50_de nan
# wandb:                test_combo_seen2_pearson_top100_de nan
# wandb:                test_combo_seen2_pearson_top200_de nan
# wandb:               test_combo_seen2_pearson_top200_hvg nan
# wandb:                 test_combo_seen2_pearson_top20_de nan
# wandb:                 test_combo_seen2_pearson_top50_de nan
# wandb:                               test_combo_seen2_r2 nan
# wandb:                            test_combo_seen2_r2_de nan
# wandb:                         test_combo_seen2_spearman nan
# wandb:                      test_combo_seen2_spearman_de nan
# wandb:                        test_combo_seen2_std_sigma nan
# wandb:                                       test_de_mae 0.26496
# wandb:                                       test_de_mse 0.16148
# wandb:                                   test_de_pearson 0.97092
# wandb:                                        test_de_r2 0.91201
# wandb:                                  test_de_spearman 0.96012
# wandb:                          test_fold_change_gap_all 0.12651
# wandb:                  test_fold_change_gap_downreg_0.1 nan
# wandb:                 test_fold_change_gap_downreg_0.33 0.7002
# wandb:                     test_fold_change_gap_upreg_10 3.79289
# wandb:                      test_fold_change_gap_upreg_3 1.73363
# wandb:                                test_frac_in_range 0.95419
# wandb:                          test_frac_in_range_25_75 0.59222
# wandb:                          test_frac_in_range_40_60 0.22416
# wandb:                          test_frac_in_range_45_55 0.11821
# wandb:                           test_frac_sigma_below_1 0.83245
# wandb:                           test_frac_sigma_below_2 0.90135
# wandb:                                          test_mae 0.06503
# wandb:                                   test_mean_sigma 0.84088
# wandb:                                          test_mse 0.00808
# wandb:                                test_mse_top100_de 0.07618
# wandb:                                test_mse_top200_de 0.05394
# wandb:                               test_mse_top200_hvg 0.06578
# wandb:                                 test_mse_top20_de 0.16148
# wandb:                                 test_mse_top50_de 0.10971
# wandb:                                      test_pearson 0.9898
# wandb:                                test_pearson_delta 0.56271
# wandb:                             test_pearson_delta_de 0.70156
# wandb:                      test_pearson_delta_top100_de 0.72018
# wandb:                      test_pearson_delta_top200_de 0.70764
# wandb:                     test_pearson_delta_top200_hvg 0.61427
# wandb:                       test_pearson_delta_top20_de 0.70156
# wandb:                       test_pearson_delta_top50_de 0.71806
# wandb:                            test_pearson_top100_de 0.9824
# wandb:                            test_pearson_top200_de 0.98428
# wandb:                           test_pearson_top200_hvg 0.96597
# wandb:                             test_pearson_top20_de 0.97092
# wandb:                             test_pearson_top50_de 0.9788
# wandb:                                           test_r2 0.96951
# wandb:                                     test_spearman 0.91759
# wandb:                                    test_std_sigma 0.69708
# wandb:            test_unseen_single_fold_change_gap_all 0.12651
# wandb:    test_unseen_single_fold_change_gap_downreg_0.1 nan
# wandb:   test_unseen_single_fold_change_gap_downreg_0.33 0.7002
# wandb:       test_unseen_single_fold_change_gap_upreg_10 3.79289
# wandb:        test_unseen_single_fold_change_gap_upreg_3 1.73363
# wandb:                  test_unseen_single_frac_in_range 0.95419
# wandb:            test_unseen_single_frac_in_range_25_75 0.59222
# wandb:            test_unseen_single_frac_in_range_40_60 0.22416
# wandb:            test_unseen_single_frac_in_range_45_55 0.11821
# wandb:             test_unseen_single_frac_sigma_below_1 0.83245
# wandb:             test_unseen_single_frac_sigma_below_2 0.90135
# wandb:                            test_unseen_single_mae 0.06503
# wandb:                         test_unseen_single_mae_de 0.26496
# wandb:                     test_unseen_single_mean_sigma 0.84088
# wandb:                            test_unseen_single_mse 0.00808
# wandb:                         test_unseen_single_mse_de 0.16148
# wandb:                  test_unseen_single_mse_top100_de 0.07618
# wandb:                  test_unseen_single_mse_top200_de 0.05394
# wandb:                 test_unseen_single_mse_top200_hvg 0.06578
# wandb:                   test_unseen_single_mse_top20_de 0.16148
# wandb:                   test_unseen_single_mse_top50_de 0.10971
# wandb:                        test_unseen_single_pearson 0.9898
# wandb:                     test_unseen_single_pearson_de 0.97092
# wandb:                  test_unseen_single_pearson_delta 0.56271
# wandb:               test_unseen_single_pearson_delta_de 0.70156
# wandb:        test_unseen_single_pearson_delta_top100_de 0.72018
# wandb:        test_unseen_single_pearson_delta_top200_de 0.70764
# wandb:       test_unseen_single_pearson_delta_top200_hvg 0.61427
# wandb:         test_unseen_single_pearson_delta_top20_de 0.70156
# wandb:         test_unseen_single_pearson_delta_top50_de 0.71806
# wandb:              test_unseen_single_pearson_top100_de 0.9824
# wandb:              test_unseen_single_pearson_top200_de 0.98428
# wandb:             test_unseen_single_pearson_top200_hvg 0.96597
# wandb:               test_unseen_single_pearson_top20_de 0.97092
# wandb:               test_unseen_single_pearson_top50_de 0.9788
# wandb:                             test_unseen_single_r2 0.96951
# wandb:                          test_unseen_single_r2_de 0.91201
# wandb:                       test_unseen_single_spearman 0.91759
# wandb:                    test_unseen_single_spearman_de 0.96012
# wandb:                      test_unseen_single_std_sigma 0.69708
# wandb:                                      train_de_mae 0.16073
# wandb:                                      train_de_mse 0.07297
# wandb:                                  train_de_pearson 0.98172
# wandb:                                       train_de_r2 0.95345
# wandb:                                 train_de_spearman 0.95554
# wandb:                                         train_mae 0.06562
# wandb:                                         train_mse 0.00652
# wandb:                                     train_pearson 0.99394
# wandb:                                          train_r2 0.97451
# wandb:                                    train_spearman 0.93571
# wandb:                                     training_loss 0.24202
# wandb:                                        val_de_mae 0.28115
# wandb:                                        val_de_mse 0.18157
# wandb:                                    val_de_pearson 0.95852
# wandb:                                         val_de_r2 0.87239
# wandb:                                   val_de_spearman 0.92739
# wandb:                                           val_mae 0.0653
# wandb:                                           val_mse 0.00675
# wandb:                                       val_pearson 0.99297
# wandb:                                            val_r2 0.97413
# wandb:                                      val_spearman 0.93844
# wandb: Run history:
# wandb:              test_combo_seen0_fold_change_gap_all
# wandb:      test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen0_fold_change_gap_upreg_10
# wandb:          test_combo_seen0_fold_change_gap_upreg_3
# wandb:                    test_combo_seen0_frac_in_range
# wandb:              test_combo_seen0_frac_in_range_25_75
# wandb:              test_combo_seen0_frac_in_range_40_60
# wandb:              test_combo_seen0_frac_in_range_45_55
# wandb:               test_combo_seen0_frac_sigma_below_1
# wandb:               test_combo_seen0_frac_sigma_below_2
# wandb:                              test_combo_seen0_mae
# wandb:                           test_combo_seen0_mae_de
# wandb:                       test_combo_seen0_mean_sigma
# wandb:                              test_combo_seen0_mse
# wandb:                           test_combo_seen0_mse_de
# wandb:                    test_combo_seen0_mse_top100_de
# wandb:                    test_combo_seen0_mse_top200_de
# wandb:                   test_combo_seen0_mse_top200_hvg
# wandb:                     test_combo_seen0_mse_top20_de
# wandb:                     test_combo_seen0_mse_top50_de
# wandb:                          test_combo_seen0_pearson
# wandb:                       test_combo_seen0_pearson_de
# wandb:                    test_combo_seen0_pearson_delta
# wandb:                 test_combo_seen0_pearson_delta_de
# wandb:          test_combo_seen0_pearson_delta_top100_de
# wandb:          test_combo_seen0_pearson_delta_top200_de
# wandb:         test_combo_seen0_pearson_delta_top200_hvg
# wandb:           test_combo_seen0_pearson_delta_top20_de
# wandb:           test_combo_seen0_pearson_delta_top50_de
# wandb:                test_combo_seen0_pearson_top100_de
# wandb:                test_combo_seen0_pearson_top200_de
# wandb:               test_combo_seen0_pearson_top200_hvg
# wandb:                 test_combo_seen0_pearson_top20_de
# wandb:                 test_combo_seen0_pearson_top50_de
# wandb:                               test_combo_seen0_r2
# wandb:                            test_combo_seen0_r2_de
# wandb:                         test_combo_seen0_spearman
# wandb:                      test_combo_seen0_spearman_de
# wandb:                        test_combo_seen0_std_sigma
# wandb:              test_combo_seen1_fold_change_gap_all
# wandb:      test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen1_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen1_fold_change_gap_upreg_10
# wandb:          test_combo_seen1_fold_change_gap_upreg_3
# wandb:                    test_combo_seen1_frac_in_range
# wandb:              test_combo_seen1_frac_in_range_25_75
# wandb:              test_combo_seen1_frac_in_range_40_60
# wandb:              test_combo_seen1_frac_in_range_45_55
# wandb:               test_combo_seen1_frac_sigma_below_1
# wandb:               test_combo_seen1_frac_sigma_below_2
# wandb:                              test_combo_seen1_mae
# wandb:                           test_combo_seen1_mae_de
# wandb:                       test_combo_seen1_mean_sigma
# wandb:                              test_combo_seen1_mse
# wandb:                           test_combo_seen1_mse_de
# wandb:                    test_combo_seen1_mse_top100_de
# wandb:                    test_combo_seen1_mse_top200_de
# wandb:                   test_combo_seen1_mse_top200_hvg
# wandb:                     test_combo_seen1_mse_top20_de
# wandb:                     test_combo_seen1_mse_top50_de
# wandb:                          test_combo_seen1_pearson
# wandb:                       test_combo_seen1_pearson_de
# wandb:                    test_combo_seen1_pearson_delta
# wandb:                 test_combo_seen1_pearson_delta_de
# wandb:          test_combo_seen1_pearson_delta_top100_de
# wandb:          test_combo_seen1_pearson_delta_top200_de
# wandb:         test_combo_seen1_pearson_delta_top200_hvg
# wandb:           test_combo_seen1_pearson_delta_top20_de
# wandb:           test_combo_seen1_pearson_delta_top50_de
# wandb:                test_combo_seen1_pearson_top100_de
# wandb:                test_combo_seen1_pearson_top200_de
# wandb:               test_combo_seen1_pearson_top200_hvg
# wandb:                 test_combo_seen1_pearson_top20_de
# wandb:                 test_combo_seen1_pearson_top50_de
# wandb:                               test_combo_seen1_r2
# wandb:                            test_combo_seen1_r2_de
# wandb:                         test_combo_seen1_spearman
# wandb:                      test_combo_seen1_spearman_de
# wandb:                        test_combo_seen1_std_sigma
# wandb:              test_combo_seen2_fold_change_gap_all
# wandb:      test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen2_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen2_fold_change_gap_upreg_10
# wandb:          test_combo_seen2_fold_change_gap_upreg_3
# wandb:                    test_combo_seen2_frac_in_range
# wandb:              test_combo_seen2_frac_in_range_25_75
# wandb:              test_combo_seen2_frac_in_range_40_60
# wandb:              test_combo_seen2_frac_in_range_45_55
# wandb:               test_combo_seen2_frac_sigma_below_1
# wandb:               test_combo_seen2_frac_sigma_below_2
# wandb:                              test_combo_seen2_mae
# wandb:                           test_combo_seen2_mae_de
# wandb:                       test_combo_seen2_mean_sigma
# wandb:                              test_combo_seen2_mse
# wandb:                           test_combo_seen2_mse_de
# wandb:                    test_combo_seen2_mse_top100_de
# wandb:                    test_combo_seen2_mse_top200_de
# wandb:                   test_combo_seen2_mse_top200_hvg
# wandb:                     test_combo_seen2_mse_top20_de
# wandb:                     test_combo_seen2_mse_top50_de
# wandb:                          test_combo_seen2_pearson
# wandb:                       test_combo_seen2_pearson_de
# wandb:                    test_combo_seen2_pearson_delta
# wandb:                 test_combo_seen2_pearson_delta_de
# wandb:          test_combo_seen2_pearson_delta_top100_de
# wandb:          test_combo_seen2_pearson_delta_top200_de
# wandb:         test_combo_seen2_pearson_delta_top200_hvg
# wandb:           test_combo_seen2_pearson_delta_top20_de
# wandb:           test_combo_seen2_pearson_delta_top50_de
# wandb:                test_combo_seen2_pearson_top100_de
# wandb:                test_combo_seen2_pearson_top200_de
# wandb:               test_combo_seen2_pearson_top200_hvg
# wandb:                 test_combo_seen2_pearson_top20_de
# wandb:                 test_combo_seen2_pearson_top50_de
# wandb:                               test_combo_seen2_r2
# wandb:                            test_combo_seen2_r2_de
# wandb:                         test_combo_seen2_spearman
# wandb:                      test_combo_seen2_spearman_de
# wandb:                        test_combo_seen2_std_sigma
# wandb:                                       test_de_mae ▁
# wandb:                                       test_de_mse ▁
# wandb:                                   test_de_pearson ▁
# wandb:                                        test_de_r2 ▁
# wandb:                                  test_de_spearman ▁
# wandb:                          test_fold_change_gap_all ▁
# wandb:                  test_fold_change_gap_downreg_0.1
# wandb:                 test_fold_change_gap_downreg_0.33 ▁
# wandb:                     test_fold_change_gap_upreg_10 ▁
# wandb:                      test_fold_change_gap_upreg_3 ▁
# wandb:                                test_frac_in_range ▁
# wandb:                          test_frac_in_range_25_75 ▁
# wandb:                          test_frac_in_range_40_60 ▁
# wandb:                          test_frac_in_range_45_55 ▁
# wandb:                           test_frac_sigma_below_1 ▁
# wandb:                           test_frac_sigma_below_2 ▁
# wandb:                                          test_mae ▁
# wandb:                                   test_mean_sigma ▁
# wandb:                                          test_mse ▁
# wandb:                                test_mse_top100_de ▁
# wandb:                                test_mse_top200_de ▁
# wandb:                               test_mse_top200_hvg ▁
# wandb:                                 test_mse_top20_de ▁
# wandb:                                 test_mse_top50_de ▁
# wandb:                                      test_pearson ▁
# wandb:                                test_pearson_delta ▁
# wandb:                             test_pearson_delta_de ▁
# wandb:                      test_pearson_delta_top100_de ▁
# wandb:                      test_pearson_delta_top200_de ▁
# wandb:                     test_pearson_delta_top200_hvg ▁
# wandb:                       test_pearson_delta_top20_de ▁
# wandb:                       test_pearson_delta_top50_de ▁
# wandb:                            test_pearson_top100_de ▁
# wandb:                            test_pearson_top200_de ▁
# wandb:                           test_pearson_top200_hvg ▁
# wandb:                             test_pearson_top20_de ▁
# wandb:                             test_pearson_top50_de ▁
# wandb:                                           test_r2 ▁
# wandb:                                     test_spearman ▁
# wandb:                                    test_std_sigma ▁
# wandb:            test_unseen_single_fold_change_gap_all ▁
# wandb:    test_unseen_single_fold_change_gap_downreg_0.1
# wandb:   test_unseen_single_fold_change_gap_downreg_0.33 ▁
# wandb:       test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:        test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                  test_unseen_single_frac_in_range ▁
# wandb:            test_unseen_single_frac_in_range_25_75 ▁
# wandb:            test_unseen_single_frac_in_range_40_60 ▁
# wandb:            test_unseen_single_frac_in_range_45_55 ▁
# wandb:             test_unseen_single_frac_sigma_below_1 ▁
# wandb:             test_unseen_single_frac_sigma_below_2 ▁
# wandb:                            test_unseen_single_mae ▁
# wandb:                         test_unseen_single_mae_de ▁
# wandb:                     test_unseen_single_mean_sigma ▁
# wandb:                            test_unseen_single_mse ▁
# wandb:                         test_unseen_single_mse_de ▁
# wandb:                  test_unseen_single_mse_top100_de ▁
# wandb:                  test_unseen_single_mse_top200_de ▁
# wandb:                 test_unseen_single_mse_top200_hvg ▁
# wandb:                   test_unseen_single_mse_top20_de ▁
# wandb:                   test_unseen_single_mse_top50_de ▁
# wandb:                        test_unseen_single_pearson ▁
# wandb:                     test_unseen_single_pearson_de ▁
# wandb:                  test_unseen_single_pearson_delta ▁
# wandb:               test_unseen_single_pearson_delta_de ▁
# wandb:        test_unseen_single_pearson_delta_top100_de ▁
# wandb:        test_unseen_single_pearson_delta_top200_de ▁
# wandb:       test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:         test_unseen_single_pearson_delta_top20_de ▁
# wandb:         test_unseen_single_pearson_delta_top50_de ▁
# wandb:              test_unseen_single_pearson_top100_de ▁
# wandb:              test_unseen_single_pearson_top200_de ▁
# wandb:             test_unseen_single_pearson_top200_hvg ▁
# wandb:               test_unseen_single_pearson_top20_de ▁
# wandb:               test_unseen_single_pearson_top50_de ▁
# wandb:                             test_unseen_single_r2 ▁
# wandb:                          test_unseen_single_r2_de ▁
# wandb:                       test_unseen_single_spearman ▁
# wandb:                    test_unseen_single_spearman_de ▁
# wandb:                      test_unseen_single_std_sigma ▁
# wandb:                                      train_de_mae ██▆▄▃▁▂▂▂▂
# wandb:                                      train_de_mse █▅▄▃▂▁▁▁▁▁
# wandb:                                  train_de_pearson ▁▄▄▆▇█▇▇▇▇
# wandb:                                       train_de_r2 ▁▄▄▆▇█████
# wandb:                                 train_de_spearman ▁▃▂▆▇█▇▇▇█
# wandb:                                         train_mae █▁▂▂▁▁▂▂▂▂
# wandb:                                         train_mse █▁▂▂▁▁▂▁▁▁
# wandb:                                     train_pearson ▁▅▆▇▇█████
# wandb:                                          train_r2 ▁█▇▇██▇███
# wandb:                                    train_spearman ▁▆▄▇▇█████
# wandb:                                     training_loss ▂▃▅▃▄▅▄▂▂▁▆▃▄▄▃▄▅▇▄▁█▅▄▄▂▅▆▄▃▁▄▃▂▃▄▃▃▂▂▃
# wandb:                                        val_de_mae ▂▅█▄▃▁▄▄▃▃
# wandb:                                        val_de_mse ▂▁█▄▄▄▆▆▅▅
# wandb:                                    val_de_pearson ▁█▄▆▅▄▁▁▂▂
# wandb:                                         val_de_r2 ██▁▄▄▅▄▃▄▅
# wandb:                                   val_de_spearman ▅▅▃█▆▆▁▂▂▂
# wandb:                                           val_mae █▂▂▂▁▂▃▂▂▂
# wandb:                                           val_mse █▁▂▂▁▁▂▂▁▁
# wandb:                                       val_pearson ▁▅▆▇██████
# wandb:                                            val_r2 ▁█▇▇██▇▇██
# wandb:                                      val_spearman ▁▆▄▇▇▇████
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced no_gnn: https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016/runs/pxh58q0v

# %%
# !python train.py --dataset Norman2019 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3\
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:5 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --exp_name gat_co-expression \
                 --wandb
# Out:
# ---- Printing Arguments ----
# dataset: Norman2019
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:5
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: False
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: False
# mlp_mixer: False
# mlp_mixer_num_layers: 2
# mlp_mixer_dropout: 0.3
# gene_sim_pos_emb: False
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: gat_co-expression
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run gat_co-expression
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/2xylskph
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211111_155510-2xylskph
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_co-expression_100.0_64_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 24886 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:9
# combo_seen1:52
# combo_seen2:18
# unseen_single:37
# Creating dataloaders....
# Dataloaders created...
# Finished data setup, in total takes 0.983 min
# Initializing model...
# Start Training...
# Epoch 1 Step 1 Train Loss: 11.4138
# Epoch 1 Step 51 Train Loss: 0.0863
# Epoch 1 Step 101 Train Loss: 0.0867
# Epoch 1 Step 151 Train Loss: 0.0724
# Epoch 1 Step 201 Train Loss: 0.0980
# Epoch 1 Step 251 Train Loss: 0.0714
# Epoch 1 Step 301 Train Loss: 0.0437
# Epoch 1 Step 351 Train Loss: 0.0677
# Epoch 1 Step 401 Train Loss: 0.0613
# Epoch 1 Step 451 Train Loss: 0.0384
# Epoch 1 Step 501 Train Loss: 0.0481
# Epoch 1 Step 551 Train Loss: 0.0507
# Epoch 1 Step 601 Train Loss: 0.0482
# Epoch 1 Step 651 Train Loss: 0.0349
# Epoch 1 Step 701 Train Loss: 0.0431
# Epoch 1 Step 751 Train Loss: 0.0394
# Epoch 1 Step 801 Train Loss: 0.0325
# Epoch 1 Step 851 Train Loss: 0.0421
# Epoch 1 Step 901 Train Loss: 0.0505
# Epoch 1 Step 951 Train Loss: 0.0535
# Epoch 1 Step 1001 Train Loss: 0.0673
# Epoch 1 Step 1051 Train Loss: 0.0387
# Epoch 1 Step 1101 Train Loss: 0.0383
# Epoch 1 Step 1151 Train Loss: 0.0384
# Epoch 1 Step 1201 Train Loss: 0.0417
# Epoch 1 Step 1251 Train Loss: 0.0441
# Epoch 1 Step 1301 Train Loss: 0.0468
# Epoch 1 Step 1351 Train Loss: 0.0569
# Epoch 1 Step 1401 Train Loss: 0.0342
# Epoch 1 Step 1451 Train Loss: 0.0455
# Epoch 1 Step 1501 Train Loss: 0.0385
# Epoch 1 Step 1551 Train Loss: 0.0248
# Epoch 1 Step 1601 Train Loss: 0.0506
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 1: Train: 0.0140, R2 0.9159 Validation: 0.0132. R2 0.9213 Loss: 0.0579
# DE_Train: 0.2069, R2 0.5169 DE_Validation: 0.2352. R2 0.5433
# Epoch 2 Step 1 Train Loss: 0.0535
# Epoch 2 Step 51 Train Loss: 0.0568
# Epoch 2 Step 101 Train Loss: 0.0304
# Epoch 2 Step 151 Train Loss: 0.0382
# Epoch 2 Step 201 Train Loss: 0.0400
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 6: Train: 0.0158, R2 0.8740 Validation: 0.0147. R2 0.8828 Loss: 0.0376
# DE_Train: 0.1647, R2 -0.1570 DE_Validation: 0.1799. R2 -0.7372
# Epoch 7 Step 1 Train Loss: 0.0418
# Epoch 7 Step 51 Train Loss: 0.0312
# Epoch 7 Step 101 Train Loss: 0.0326
# Epoch 7 Step 151 Train Loss: 0.0256
# Epoch 7 Step 201 Train Loss: 0.0371
# Epoch 7 Step 251 Train Loss: 0.0333
# Epoch 7 Step 301 Train Loss: 0.0398
# Epoch 7 Step 351 Train Loss: 0.0291
# Epoch 7 Step 401 Train Loss: 0.0362
# Epoch 7 Step 451 Train Loss: 0.0236
# Epoch 7 Step 501 Train Loss: 0.0419
# Epoch 7 Step 551 Train Loss: 0.0357
# Epoch 7 Step 601 Train Loss: 0.0276
# Epoch 7 Step 651 Train Loss: 0.0475
# Epoch 7 Step 701 Train Loss: 0.0388
# Epoch 7 Step 751 Train Loss: 0.0346
# Epoch 7 Step 801 Train Loss: 0.0393
# Epoch 7 Step 851 Train Loss: 0.0489
# Epoch 7 Step 901 Train Loss: 0.0327
# Epoch 7 Step 951 Train Loss: 0.0360
# Epoch 7 Step 1001 Train Loss: 0.0308
# Epoch 7 Step 1051 Train Loss: 0.0357
# Epoch 7 Step 1101 Train Loss: 0.0455
# Epoch 7 Step 1151 Train Loss: 0.0350
# Epoch 7 Step 1201 Train Loss: 0.0447
# Epoch 7 Step 1251 Train Loss: 0.0526
# Epoch 7 Step 1301 Train Loss: 0.0437
# Epoch 7 Step 1351 Train Loss: 0.0341
# Epoch 7 Step 1401 Train Loss: 0.0281
# Epoch 7 Step 1451 Train Loss: 0.0324
# Epoch 7 Step 1501 Train Loss: 0.0462
# Epoch 7 Step 1551 Train Loss: 0.0395
# Epoch 7 Step 1601 Train Loss: 0.0378
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 7: Train: 0.0158, R2 0.8865 Validation: 0.0155. R2 0.8882 Loss: 0.0373
# DE_Train: 0.1690, R2 -0.1690 DE_Validation: 0.1884. R2 -1.2732
# Epoch 8 Step 1 Train Loss: 0.0368
# Epoch 8 Step 51 Train Loss: 0.0413
# Epoch 8 Step 101 Train Loss: 0.0236
# Epoch 8 Step 151 Train Loss: 0.0319
# Epoch 8 Step 201 Train Loss: 0.0324
# Epoch 8 Step 251 Train Loss: 0.0266
# Epoch 8 Step 301 Train Loss: 0.0261
# Epoch 8 Step 351 Train Loss: 0.0267
# Epoch 8 Step 401 Train Loss: 0.0305
# Epoch 8 Step 451 Train Loss: 0.0344
# Epoch 8 Step 501 Train Loss: 0.0407
# Epoch 8 Step 551 Train Loss: 0.0307
# Epoch 8 Step 601 Train Loss: 0.0296
# Epoch 8 Step 651 Train Loss: 0.0297
# Epoch 8 Step 701 Train Loss: 0.0376
# Epoch 8 Step 751 Train Loss: 0.0426
# Epoch 8 Step 801 Train Loss: 0.0366
# Epoch 8 Step 851 Train Loss: 0.0308
# Epoch 8 Step 901 Train Loss: 0.0345
# Epoch 8 Step 951 Train Loss: 0.0396
# Epoch 8 Step 1001 Train Loss: 0.0485
# Epoch 8 Step 1051 Train Loss: 0.0414
# Epoch 8 Step 1101 Train Loss: 0.0303
# Epoch 8 Step 1151 Train Loss: 0.0542
# Epoch 8 Step 1201 Train Loss: 0.0522
# Epoch 8 Step 1251 Train Loss: 0.0344
# Epoch 8 Step 1301 Train Loss: 0.0343
# Epoch 8 Step 1351 Train Loss: 0.0469
# Epoch 8 Step 1401 Train Loss: 0.0407
# Epoch 8 Step 1451 Train Loss: 0.0421
# Epoch 8 Step 1501 Train Loss: 0.0304
# Epoch 8 Step 1551 Train Loss: 0.0414
# Epoch 8 Step 1601 Train Loss: 0.0420
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 8: Train: 0.0141, R2 0.9007 Validation: 0.0130. R2 0.9089 Loss: 0.0371
# DE_Train: 0.1157, R2 0.0708 DE_Validation: 0.1556. R2 -0.4264
# Epoch 9 Step 1 Train Loss: 0.0259
# Epoch 9 Step 51 Train Loss: 0.0464
# Epoch 9 Step 101 Train Loss: 0.0393
# Epoch 9 Step 151 Train Loss: 0.0289
# Epoch 9 Step 201 Train Loss: 0.0586
# Epoch 9 Step 251 Train Loss: 0.0473
# Epoch 9 Step 301 Train Loss: 0.0374
# Epoch 9 Step 351 Train Loss: 0.0517
# Epoch 9 Step 401 Train Loss: 0.0335
# Epoch 9 Step 451 Train Loss: 0.0243
# Epoch 9 Step 501 Train Loss: 0.0291
# Epoch 9 Step 551 Train Loss: 0.0270
# Epoch 9 Step 601 Train Loss: 0.0375
# Epoch 9 Step 651 Train Loss: 0.0555
# Epoch 9 Step 701 Train Loss: 0.0417
# Epoch 9 Step 751 Train Loss: 0.0452
# Epoch 9 Step 801 Train Loss: 0.0350
# Epoch 9 Step 851 Train Loss: 0.0458
# Epoch 9 Step 901 Train Loss: 0.0343
# Epoch 9 Step 951 Train Loss: 0.0333
# Epoch 9 Step 1001 Train Loss: 0.0398
# Epoch 9 Step 1051 Train Loss: 0.0250
# Epoch 9 Step 1101 Train Loss: 0.0239
# Epoch 9 Step 1151 Train Loss: 0.0403
# Epoch 9 Step 1201 Train Loss: 0.0464
# Epoch 9 Step 1251 Train Loss: 0.0316
# Epoch 9 Step 1301 Train Loss: 0.0370
# Epoch 9 Step 1351 Train Loss: 0.0340
# Epoch 9 Step 1401 Train Loss: 0.0282
# Epoch 9 Step 1451 Train Loss: 0.0247
# Epoch 9 Step 1501 Train Loss: 0.0382
# Epoch 9 Step 1551 Train Loss: 0.0431
# Epoch 9 Step 1601 Train Loss: 0.0453
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 9: Train: 0.0163, R2 0.8857 Validation: 0.0155. R2 0.8913 Loss: 0.0371
# DE_Train: 0.1185, R2 -0.1951 DE_Validation: 0.1566. R2 -1.4080
# Epoch 10 Step 1 Train Loss: 0.0367
# Epoch 10 Step 51 Train Loss: 0.0397
# Epoch 10 Step 101 Train Loss: 0.0348
# Epoch 10 Step 151 Train Loss: 0.0344
# Epoch 10 Step 201 Train Loss: 0.0359
# Epoch 10 Step 251 Train Loss: 0.0463
# Epoch 10 Step 301 Train Loss: 0.0454
# Epoch 10 Step 351 Train Loss: 0.0301
# Epoch 10 Step 401 Train Loss: 0.0371
# Epoch 10 Step 451 Train Loss: 0.0397
# Epoch 10 Step 501 Train Loss: 0.0316
# Epoch 10 Step 551 Train Loss: 0.0251
# Epoch 10 Step 601 Train Loss: 0.0330
# Epoch 10 Step 651 Train Loss: 0.0229
# Epoch 10 Step 701 Train Loss: 0.0240
# Epoch 10 Step 751 Train Loss: 0.0702
# Epoch 10 Step 801 Train Loss: 0.0357
# Epoch 10 Step 851 Train Loss: 0.0458
# Epoch 10 Step 901 Train Loss: 0.0384
# Epoch 10 Step 951 Train Loss: 0.0378
# Epoch 10 Step 1001 Train Loss: 0.0724
# Epoch 10 Step 1051 Train Loss: 0.0435
# Epoch 10 Step 1101 Train Loss: 0.0315
# Epoch 10 Step 1151 Train Loss: 0.0476
# Epoch 10 Step 1201 Train Loss: 0.0456
# Epoch 10 Step 1251 Train Loss: 0.0351
# Epoch 10 Step 1301 Train Loss: 0.0447
# Epoch 10 Step 1351 Train Loss: 0.0296
# Epoch 10 Step 1401 Train Loss: 0.0268
# Epoch 10 Step 1451 Train Loss: 0.0403
# Epoch 10 Step 1501 Train Loss: 0.0253
# Epoch 10 Step 1551 Train Loss: 0.0309
# Epoch 10 Step 1601 Train Loss: 0.0426
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 10: Train: 0.0151, R2 0.8949 Validation: 0.0144. R2 0.9002 Loss: 0.0371
# DE_Train: 0.1186, R2 -0.1424 DE_Validation: 0.1593. R2 -1.1873
# Saving model....
# Start testing....
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Final best performing model: Test_DE: 0.1815, R2 -0.8657
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# ...
# wandb:              test_SYNERGY_DISSIMILAR_PHENO_mse_top50_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_fold_change_gap_all ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_40_60 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_45_55 ▁
# wandb:                   test_SYNERGY_SIMILAR_PHENO_mean_sigma ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top100_de ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top200_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top20_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top50_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:                    test_combo_seen0_fold_change_gap_all ▁
# wandb:            test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:               test_combo_seen0_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen0_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen0_frac_in_range ▁
# wandb:                    test_combo_seen0_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen0_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen0_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen0_mae ▁
# wandb:                                 test_combo_seen0_mae_de ▁
# wandb:                             test_combo_seen0_mean_sigma ▁
# wandb:                                    test_combo_seen0_mse ▁
# wandb:                                 test_combo_seen0_mse_de ▁
# wandb:                          test_combo_seen0_mse_top100_de ▁
# wandb:                          test_combo_seen0_mse_top200_de ▁
# wandb:                         test_combo_seen0_mse_top200_hvg ▁
# wandb:                           test_combo_seen0_mse_top20_de ▁
# wandb:                           test_combo_seen0_mse_top50_de ▁
# wandb:                                test_combo_seen0_pearson ▁
# wandb:                             test_combo_seen0_pearson_de ▁
# wandb:                          test_combo_seen0_pearson_delta ▁
# wandb:                       test_combo_seen0_pearson_delta_de ▁
# wandb:                test_combo_seen0_pearson_delta_top100_de ▁
# wandb:                test_combo_seen0_pearson_delta_top200_de ▁
# wandb:               test_combo_seen0_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen0_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen0_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen0_pearson_top100_de ▁
# wandb:                      test_combo_seen0_pearson_top200_de ▁
# wandb:                     test_combo_seen0_pearson_top200_hvg ▁
# wandb:                       test_combo_seen0_pearson_top20_de ▁
# wandb:                       test_combo_seen0_pearson_top50_de ▁
# wandb:                                     test_combo_seen0_r2 ▁
# wandb:                                  test_combo_seen0_r2_de ▁
# wandb:                               test_combo_seen0_spearman ▁
# wandb:                            test_combo_seen0_spearman_de ▁
# wandb:                              test_combo_seen0_std_sigma ▁
# wandb:                    test_combo_seen1_fold_change_gap_all ▁
# wandb:            test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen1_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen1_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen1_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen1_frac_in_range ▁
# wandb:                    test_combo_seen1_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen1_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen1_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen1_mae ▁
# wandb:                                 test_combo_seen1_mae_de ▁
# wandb:                             test_combo_seen1_mean_sigma ▁
# wandb:                                    test_combo_seen1_mse ▁
# wandb:                                 test_combo_seen1_mse_de ▁
# wandb:                          test_combo_seen1_mse_top100_de ▁
# wandb:                          test_combo_seen1_mse_top200_de ▁
# wandb:                         test_combo_seen1_mse_top200_hvg ▁
# wandb:                           test_combo_seen1_mse_top20_de ▁
# wandb:                           test_combo_seen1_mse_top50_de ▁
# wandb:                                test_combo_seen1_pearson ▁
# wandb:                             test_combo_seen1_pearson_de ▁
# wandb:                          test_combo_seen1_pearson_delta ▁
# wandb:                       test_combo_seen1_pearson_delta_de ▁
# wandb:                test_combo_seen1_pearson_delta_top100_de ▁
# wandb:                test_combo_seen1_pearson_delta_top200_de ▁
# wandb:               test_combo_seen1_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen1_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen1_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen1_pearson_top100_de ▁
# wandb:                      test_combo_seen1_pearson_top200_de ▁
# wandb:                     test_combo_seen1_pearson_top200_hvg ▁
# wandb:                       test_combo_seen1_pearson_top20_de ▁
# wandb:                       test_combo_seen1_pearson_top50_de ▁
# wandb:                                     test_combo_seen1_r2 ▁
# wandb:                                  test_combo_seen1_r2_de ▁
# wandb:                               test_combo_seen1_spearman ▁
# wandb:                            test_combo_seen1_spearman_de ▁
# wandb:                              test_combo_seen1_std_sigma ▁
# wandb:                    test_combo_seen2_fold_change_gap_all ▁
# wandb:            test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen2_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen2_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen2_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen2_frac_in_range ▁
# wandb:                    test_combo_seen2_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen2_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen2_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen2_mae ▁
# wandb:                                 test_combo_seen2_mae_de ▁
# wandb:                             test_combo_seen2_mean_sigma ▁
# wandb:                                    test_combo_seen2_mse ▁
# wandb:                                 test_combo_seen2_mse_de ▁
# wandb:                          test_combo_seen2_mse_top100_de ▁
# wandb:                          test_combo_seen2_mse_top200_de ▁
# wandb:                         test_combo_seen2_mse_top200_hvg ▁
# wandb:                           test_combo_seen2_mse_top20_de ▁
# wandb:                           test_combo_seen2_mse_top50_de ▁
# wandb:                                test_combo_seen2_pearson ▁
# wandb:                             test_combo_seen2_pearson_de ▁
# wandb:                          test_combo_seen2_pearson_delta ▁
# wandb:                       test_combo_seen2_pearson_delta_de ▁
# wandb:                test_combo_seen2_pearson_delta_top100_de ▁
# wandb:                test_combo_seen2_pearson_delta_top200_de ▁
# wandb:               test_combo_seen2_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen2_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen2_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen2_pearson_top100_de ▁
# wandb:                      test_combo_seen2_pearson_top200_de ▁
# wandb:                     test_combo_seen2_pearson_top200_hvg ▁
# wandb:                       test_combo_seen2_pearson_top20_de ▁
# wandb:                       test_combo_seen2_pearson_top50_de ▁
# wandb:                                     test_combo_seen2_r2 ▁
# wandb:                                  test_combo_seen2_r2_de ▁
# wandb:                               test_combo_seen2_spearman ▁
# wandb:                            test_combo_seen2_spearman_de ▁
# wandb:                              test_combo_seen2_std_sigma ▁
# wandb:                                             test_de_mae ▁
# wandb:                                             test_de_mse ▁
# wandb:                                         test_de_pearson ▁
# wandb:                                              test_de_r2 ▁
# wandb:                                        test_de_spearman ▁
# wandb:                                test_fold_change_gap_all ▁
# wandb:                        test_fold_change_gap_downreg_0.1
# wandb:                       test_fold_change_gap_downreg_0.33 ▁
# wandb:                           test_fold_change_gap_upreg_10 ▁
# wandb:                            test_fold_change_gap_upreg_3 ▁
# wandb:                                      test_frac_in_range ▁
# wandb:                                test_frac_in_range_25_75 ▁
# wandb:                                test_frac_in_range_40_60 ▁
# wandb:                                test_frac_in_range_45_55 ▁
# wandb:                                 test_frac_sigma_below_1 ▁
# wandb:                                 test_frac_sigma_below_2 ▁
# wandb:                                                test_mae ▁
# wandb:                                         test_mean_sigma ▁
# wandb:                                                test_mse ▁
# wandb:                                      test_mse_top100_de ▁
# wandb:                                      test_mse_top200_de ▁
# wandb:                                     test_mse_top200_hvg ▁
# wandb:                                       test_mse_top20_de ▁
# wandb:                                       test_mse_top50_de ▁
# wandb:                                            test_pearson ▁
# wandb:                                      test_pearson_delta ▁
# wandb:                                   test_pearson_delta_de ▁
# wandb:                            test_pearson_delta_top100_de ▁
# wandb:                            test_pearson_delta_top200_de ▁
# wandb:                           test_pearson_delta_top200_hvg ▁
# wandb:                             test_pearson_delta_top20_de ▁
# wandb:                             test_pearson_delta_top50_de ▁
# wandb:                                  test_pearson_top100_de ▁
# wandb:                                  test_pearson_top200_de ▁
# wandb:                                 test_pearson_top200_hvg ▁
# wandb:                                   test_pearson_top20_de ▁
# wandb:                                   test_pearson_top50_de ▁
# wandb:                                                 test_r2 ▁
# wandb:                                           test_spearman ▁
# wandb:                                          test_std_sigma ▁
# wandb:                  test_unseen_single_fold_change_gap_all ▁
# wandb:          test_unseen_single_fold_change_gap_downreg_0.1
# wandb:         test_unseen_single_fold_change_gap_downreg_0.33
# wandb:             test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:              test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                        test_unseen_single_frac_in_range ▁
# wandb:                  test_unseen_single_frac_in_range_25_75 ▁
# wandb:                  test_unseen_single_frac_in_range_40_60 ▁
# wandb:                  test_unseen_single_frac_in_range_45_55 ▁
# wandb:                   test_unseen_single_frac_sigma_below_1 ▁
# wandb:                   test_unseen_single_frac_sigma_below_2 ▁
# wandb:                                  test_unseen_single_mae ▁
# wandb:                               test_unseen_single_mae_de ▁
# wandb:                           test_unseen_single_mean_sigma ▁
# wandb:                                  test_unseen_single_mse ▁
# wandb:                               test_unseen_single_mse_de ▁
# wandb:                        test_unseen_single_mse_top100_de ▁
# wandb:                        test_unseen_single_mse_top200_de ▁
# wandb:                       test_unseen_single_mse_top200_hvg ▁
# wandb:                         test_unseen_single_mse_top20_de ▁
# wandb:                         test_unseen_single_mse_top50_de ▁
# wandb:                              test_unseen_single_pearson ▁
# wandb:                           test_unseen_single_pearson_de ▁
# wandb:                        test_unseen_single_pearson_delta ▁
# wandb:                     test_unseen_single_pearson_delta_de ▁
# wandb:              test_unseen_single_pearson_delta_top100_de ▁
# wandb:              test_unseen_single_pearson_delta_top200_de ▁
# wandb:             test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:               test_unseen_single_pearson_delta_top20_de ▁
# wandb:               test_unseen_single_pearson_delta_top50_de ▁
# wandb:                    test_unseen_single_pearson_top100_de ▁
# wandb:                    test_unseen_single_pearson_top200_de ▁
# wandb:                   test_unseen_single_pearson_top200_hvg ▁
# wandb:                     test_unseen_single_pearson_top20_de ▁
# wandb:                     test_unseen_single_pearson_top50_de ▁
# wandb:                                   test_unseen_single_r2 ▁
# wandb:                                test_unseen_single_r2_de ▁
# wandb:                             test_unseen_single_spearman ▁
# wandb:                          test_unseen_single_spearman_de ▁
# wandb:                            test_unseen_single_std_sigma ▁
# wandb:                                            train_de_mae ▅█▄▆▂▃▄▁▁▁
# wandb:                                            train_de_mse ▅█▄▆▂▃▃▁▁▁
# wandb:                                        train_de_pearson ▂▁▄▃▅▇▆███
# wandb:                                             train_de_r2 ██▅▆▃▁▁▄▁▂
# wandb:                                       train_de_spearman ▂▁▄▄▆▇▇███
# wandb:                                               train_mae ▄█▅▁▅▄▅▃▅▄
# wandb:                                               train_mse ▁█▁▃▂▂▂▁▃▂
# wandb:                                           train_pearson ▇▄█▆▅▁▁▃▃▄
# wandb:                                                train_r2 ▇▃▆█▆▁▃▅▃▄
# wandb:                                          train_spearman ▁▃▄▆▇▇████
# wandb:                                           training_loss █▃▃▃▄▆▄▄▃▄▂▅▃▂▃▂▁▄▂▃▂▃▅▂▃▂▃▃▂▄▃▃▂▃▂▁▂▂▁▂
# wandb:                                              val_de_mae ▄█▃▆▃▂▃▁▁▂
# wandb:                                              val_de_mse ▅█▄▆▃▂▃▁▁▁
# wandb:                                          val_de_pearson ▁▁▄▄▄█▇███
# wandb:                                               val_de_r2 ███▇▁▆▅▆▄▅
# wandb:                                         val_de_spearman ▁▁▆▅▆████▇
# wandb:                                                 val_mae ▂█▆▁▆▄▅▁▅▄
# wandb:                                                 val_mse ▁█▂▄▃▂▃▁▃▂
# wandb:                                             val_pearson ▆▅█▆▅▁▁▃▂▃
# wandb:                                                  val_r2 █▃▅▇▄▁▂▆▃▄
# wandb:                                            val_spearman ▁▂▃▆▇▇████
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced gat_co-expression: https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/2xylskph
