# %%
import numpy as np
import torch
import scanpy as sc
from data import PertDataloader, Network


model_name = 'GNN_Disentangle_GAT_string_20.0_64_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_lambda_emission'
args = np.load('./saved_args/'+model_name+'.npy', allow_pickle = True).item()
args['device'] = 'cuda:4'

# %%
if args['network_name'] == 'string':
    args['network_path'] = '/dfs/project/perturb-gnn/graphs/STRING_full_9606.csv'

if args['dataset'] == 'Norman2019':
    data_path = '/dfs/project/perturb-gnn/datasets/Norman2019_hvg+perts.h5ad'

adata = sc.read_h5ad(data_path)
if 'gene_symbols' not in adata.var.columns.values:
    adata.var['gene_symbols'] = adata.var['gene_name']
gene_list = [f for f in adata.var.gene_symbols.values]
# Set up message passing network
network = Network(fname=args['network_path'], gene_list=args['gene_list'],
                  percentile=args['top_edge_percent'])

# Pertrubation dataloader
pertdl = PertDataloader(adata, network.G, network.weights, args)
# Out:
# There are 101013 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:9
# combo_seen1:52
# combo_seen2:18
# unseen_single:37
# Creating dataloaders....
# Dataloaders created...

# %%
model = torch.load('./saved_models/' + model_name)
#model.pert_emb_agg = 'constant'
#model.lambda_emission = False
model.sim_gnn = False
model.args = args
from inference import evaluate, compute_metrics

test_res = evaluate(pertdl.loaders['test_loader'],
                        pertdl.loaders['edge_index'],
                        pertdl.loaders['edge_attr'], model, args)

test_metrics, test_pert_res = compute_metrics(test_res)
# Out:
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
pert2pert_full_id = dict(adata.obs[['condition', 'cov_drug_dose_name']].values)
geneid2name = dict(zip(adata.var.index.values, adata.var['gene_name']))
de_names = [geneid2name[i] for i in adata.uns['rank_genes_groups_cov'][pert2pert_full_id[pert]]]

# %%
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(6, 2)})

def analyze(pert):

    print(pert)
    print(pert2group[pert])
    for i,j in test_pert_res[pert].items():
        if i[-2:] == 'de':
            print(i + ': ' + str(j))

    pert2pert_full_id = dict(adata.obs[['condition', 'cov_drug_dose_name']].values)
    geneid2name = dict(zip(adata.var.index.values, adata.var['gene_name']))
    de_names = [geneid2name[i] for i in adata.uns['rank_genes_groups_cov'][pert2pert_full_id[pert]]]

    pert_idx = np.where(test_res['pert_cat'] == pert)[0]
    pred_mean = np.mean(test_res['pred_de'][pert_idx], axis = 0).reshape(-1,)
    true_mean = np.mean(test_res['truth_de'][pert_idx], axis = 0).reshape(-1,)
    ax = sns.heatmap(np.vstack((true_mean.reshape(1,-1), pred_mean.reshape(1,-1))))
    t = ax.set_yticklabels(['True', 'Predicted'])
    t = ax.set_xticklabels(de_names, rotation = 90)

    mean = np.mean(test_res['truth_de'][pert_idx], axis = 0)
    std = np.std(test_res['truth_de'][pert_idx], axis = 0)
    min_ = np.min(test_res['truth_de'][pert_idx], axis = 0)
    max_ = np.max(test_res['truth_de'][pert_idx], axis = 0)

    in_range = (pred_mean >= min_) & (pred_mean <= max_)
    frac_in_range = sum(in_range)/20
    print(str(frac_in_range * 100) + '% of genes in the range')
    if frac_in_range != 1:
        false_ = np.where(in_range == False)[0]
        print('not in range genes:' + str(np.array(de_names)[false_]))
    
    zero_idx = np.where(std > 0)[0]
    print('there are ' + str(20 - len(zero_idx)) + ' genes with zero stds, removing them for calculation...')
    sigma = (np.abs(pred_mean[zero_idx] - mean[zero_idx]))/(std[zero_idx])
    print('average sigma: ' + str(np.mean(sigma)))
    print('frac of below 1 sigma: ' + str(1 - len(np.where(sigma > 1)[0])/len(zero_idx)))
    print('frac of below 2 sigma: ' + str(1 - len(np.where(sigma > 2)[0])/len(zero_idx)))
    print('above 2 sigma genes:' + str(np.array(de_names)[zero_idx][np.where(sigma > 2)[0]]))

# %%
def deeper_analysis(adata, test_res, pert_metric):
    metric2fct = {
           'spearman': spearmanr,
           'pearson': pearsonr
    }
    
    #pert_metric = {}
    
    ## in silico modeling and upperbounding
    pert2pert_full_id = dict(adata.obs[['condition', 'cov_drug_dose_name']].values)
    geneid2name = dict(zip(adata.var.index.values, adata.var['gene_name']))
    geneid2idx = dict(zip(adata.var.index.values, range(len(adata.var.index.values))))
    
    # calculate mean expression for each condition
    unique_conditions = adata.obs.condition.unique()
    conditions2index = {}
    for i in unique_conditions:
        conditions2index[i] = np.where(adata.obs.condition == i)[0]

    condition2mean_expression = {}
    for i, j in conditions2index.items():
        condition2mean_expression[i] = np.mean(adata.X[j], axis = 0)
    pert_list = np.array(list(condition2mean_expression.keys()))
    mean_expression = np.array(list(condition2mean_expression.values())).reshape(len(adata.obs.condition.unique()), adata.X.toarray().shape[1])
    ctrl = mean_expression[np.where(pert_list == 'ctrl')[0]]
    most_variable_genes = np.argsort(np.std(mean_expression, axis = 0))[-200:]
    gene_list = adata.var['gene_name'].values
    
    for pert in np.unique(test_res['pert_cat']):
        #pert_metric[pert] = {}
        #de_names = [geneid2name[i] for i in adata.uns['rank_genes_groups_cov'][pert2pert_full_id[pert]]]
        de_idx = [geneid2idx[i] for i in adata.uns['rank_genes_groups_cov'][pert2pert_full_id[pert]]]
        
        pert_idx = np.where(test_res['pert_cat'] == pert)[0]
        pred_mean = np.mean(test_res['pred_de'][pert_idx], axis = 0).reshape(-1,)
        true_mean = np.mean(test_res['truth_de'][pert_idx], axis = 0).reshape(-1,)
        
        mean = np.mean(test_res['truth_de'][pert_idx], axis = 0)
        std = np.std(test_res['truth_de'][pert_idx], axis = 0)
        min_ = np.min(test_res['truth_de'][pert_idx], axis = 0)
        max_ = np.max(test_res['truth_de'][pert_idx], axis = 0)
        zero_des = np.intersect1d(np.where(min_ == 0)[0], np.where(max_ == 0)[0])
        nonzero_des = np.setdiff1d(list(range(20)), zero_des)
        if len(nonzero_des) == 0:
            pass
            # there should be some errors in selecting DEs for this pert
        else:
            in_range = (pred_mean[nonzero_des] >= min_[nonzero_des]) & (pred_mean[nonzero_des] <= max_[nonzero_des])
            frac_in_range = sum(in_range)/len(nonzero_des)
            pert_metric[pert]['frac_in_range'] = frac_in_range

            zero_idx = np.where(std > 0)[0]
            sigma = (np.abs(pred_mean[zero_idx] - mean[zero_idx]))/(std[zero_idx])
            pert_metric[pert]['mean_sigma'] = np.mean(sigma)
            pert_metric[pert]['std_sigma'] = np.std(sigma)
            pert_metric[pert]['frac_sigma_below_1'] = 1 - len(np.where(sigma > 1)[0])/len(zero_idx)
            pert_metric[pert]['frac_sigma_below_2'] = 1 - len(np.where(sigma > 2)[0])/len(zero_idx)

        ## correlation on delta
        p_idx = np.where(test_res['pert_cat'] == pert)[0]

        for m, fct in metric2fct.items():
            val = fct(test_res['pred'][p_idx].mean(0)- ctrl[0], test_res['truth'][p_idx].mean(0)-ctrl[0])[0]
            if np.isnan(val):
                val = 0

            pert_metric[pert][m + '_delta'] = val
            
            val = fct(test_res['pred_de'][p_idx].mean(0)- ctrl[0][de_idx], test_res['truth_de'][p_idx].mean(0)-ctrl[0][de_idx])[0]
            if np.isnan(val):
                val = 0

            pert_metric[pert][m + '_delta_de'] = val
        
        ## up fold changes > 10?
        pert_mean = np.mean(test_res['truth'][p_idx], axis = 0).reshape(-1,)
        
        fold_change = pert_mean/ctrl
        fold_change[np.isnan(fold_change)] = 0
        fold_change[np.isinf(fold_change)] = 0
        ## this is to remove the ones that are super low and the fold change becomes unmeaningful
        fold_change[0][np.where(pert_mean < 0.5)[0]] = 0
        
        o =  np.where(fold_change[0] > 0)[0]
        
        pred_fc = test_res['pred'][p_idx].mean(0)[o]
        true_fc = test_res['truth'][p_idx].mean(0)[o]
        ctrl_fc = ctrl[0][o]
        
        if len(o) > 0:
            pert_metric[pert]['fold_change_gap_all'] = np.mean(np.abs(pred_fc/ctrl_fc - true_fc/ctrl_fc))
        
        
        o = np.intersect1d(np.where(fold_change[0] <0.333)[0], np.where(fold_change[0] > 0)[0])
        
        pred_fc = test_res['pred'][p_idx].mean(0)[o]
        true_fc = test_res['truth'][p_idx].mean(0)[o]
        ctrl_fc = ctrl[0][o]
        
        if len(o) > 0:
            pert_metric[pert]['fold_change_gap_downreg_0.33'] = np.mean(np.abs(pred_fc/ctrl_fc - true_fc/ctrl_fc))
        
        
        o = np.intersect1d(np.where(fold_change[0] <0.1)[0], np.where(fold_change[0] > 0)[0])
        
        pred_fc = test_res['pred'][p_idx].mean(0)[o]
        true_fc = test_res['truth'][p_idx].mean(0)[o]
        ctrl_fc = ctrl[0][o]
        
        if len(o) > 0:
            pert_metric[pert]['fold_change_gap_downreg_0.1'] = np.mean(np.abs(pred_fc/ctrl_fc - true_fc/ctrl_fc))

        o = np.where(fold_change[0] > 3)[0]
        
        pred_fc = test_res['pred'][p_idx].mean(0)[o]
        true_fc = test_res['truth'][p_idx].mean(0)[o]
        ctrl_fc = ctrl[0][o]
        
        if len(o) > 0:
            pert_metric[pert]['fold_change_gap_upreg_3'] = np.mean(np.abs(pred_fc/ctrl_fc - true_fc/ctrl_fc))
        
        o = np.where(fold_change[0] > 10)[0]
        
        pred_fc = test_res['pred'][p_idx].mean(0)[o]
        true_fc = test_res['truth'][p_idx].mean(0)[o]
        ctrl_fc = ctrl[0][o]
        
        if len(o) > 0:
            pert_metric[pert]['fold_change_gap_upreg_10'] = np.mean(np.abs(pred_fc/ctrl_fc - true_fc/ctrl_fc))

        ## most variable genes
        for m, fct in metric2fct.items():
            val = fct(test_res['pred'][p_idx].mean(0)[most_variable_genes] - ctrl[0][most_variable_genes], test_res['truth'][p_idx].mean(0)[most_variable_genes]-ctrl[0][most_variable_genes])[0]
            if np.isnan(val):
                val = 0
            pert_metric[pert][m + '_delta_top200_hvg'] = val

            
            val = fct(test_res['pred'][p_idx].mean(0)[most_variable_genes], test_res['truth'][p_idx].mean(0)[most_variable_genes])[0]
            if np.isnan(val):
                val = 0
            pert_metric[pert][m + '_top200_hvg'] = val

    return pert_metric


def GI_subgroup(pert_metric):
    GI_type2Score = {}
    test_pert_list = list(pert_metric.keys())
    for GI_type, gi_list in GIs.items():
        intersect = np.intersect1d(gi_list, test_pert_list)
        if len(intersect) != 0:
            GI_type2Score[GI_type] = {}

            for m in list(list(pert_metric.values())[0].keys()):
                GI_type2Score[GI_type][m] = np.mean([pert_metric[i][m] for i in intersect if m in pert_metric[i]])
                
    return GI_type2Score

# %%
out = deeper_analysis(adata, test_res, test_pert_res)
GI_subgroup(out)
# Out:
# /tmp/ipykernel_50634/3442456188.py:78: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_50634/3442456188.py:78: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# {'NEOMORPHIC': {'frac_in_range': 1.0,
#   'mean_sigma': 1.0047382,
#   'std_sigma': 1.1187395,
#   'frac_sigma_below_1': 0.7223691377135649,
#   'frac_sigma_below_2': 0.9016311202843711,
#   'spearman_delta': 0.022592210321319722,
#   'spearman_delta_de': 0.7563909774436091,
#   'pearson_delta': 0.34982917961411514,
#   'pearson_delta_de': 0.7690294987989904,
#   'fold_change_gap_all': 0.17500299,
#   'fold_change_gap_upreg_3': 5.0310636,
#   'spearman_delta_top200_hvg': 0.5028838220955525,
#   'spearman_top200_hvg': 0.9324448146428421,
#   'pearson_delta_top200_hvg': 0.460737114491091,
#   'pearson_top200_hvg': 0.9554292688818604},
#  'ADDITIVE': {'frac_in_range': 1.0,
#   'mean_sigma': 0.8927701,
#   'std_sigma': 0.6198561,
#   'frac_sigma_below_1': 0.6602274681802546,
#   'frac_sigma_below_2': 0.9548976608187134,
#   'spearman_delta': 0.15960641444954182,
#   'spearman_delta_de': 0.8735171261487049,
#   'pearson_delta': 0.5106381738818909,
#   'pearson_delta_de': 0.9024134469888412,
#   'fold_change_gap_all': 0.2688549,
#   'fold_change_gap_upreg_3': 2.3351004,
#   'spearman_delta_top200_hvg': 0.6667835029209064,
#   'spearman_top200_hvg': 0.9269378361189263,
#   'pearson_delta_top200_hvg': 0.6485868131389609,
#   'pearson_top200_hvg': 0.9520535977178733},
#  'EPISTASIS': {'frac_in_range': 1.0,
#   'mean_sigma': 0.8596537,
#   'std_sigma': 0.9969581,
#   'frac_sigma_below_1': 0.7250000000000001,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': 0.1072512672293257,
#   'spearman_delta_de': 0.9112781954887217,
#   'pearson_delta': 0.30971756784836724,
#   'pearson_delta_de': 0.9484607123953026,
#   'fold_change_gap_all': 0.17989951,
#   'fold_change_gap_upreg_3': 2.8534904,
#   'spearman_delta_top200_hvg': 0.32053326333158333,
#   'spearman_top200_hvg': 0.9457286432160805,
#   'pearson_delta_top200_hvg': 0.41288413023583986,
#   'pearson_top200_hvg': 0.9525141465749967},
#  'REDUNDANT': {'frac_in_range': 1.0,
#   'mean_sigma': 1.6183423,
#   'std_sigma': 1.3603987,
#   'frac_sigma_below_1': 0.5508771929824562,
#   'frac_sigma_below_2': 0.8778508771929825,
#   'spearman_delta': 0.21046216592541714,
#   'spearman_delta_de': 0.7781954887218044,
#   'pearson_delta': 0.6227420958050749,
#   'pearson_delta_de': 0.9193560657524364,
#   'fold_change_gap_all': 1.7922475,
#   'fold_change_gap_upreg_3': 12.597354,
#   'spearman_delta_top200_hvg': 0.7559847746193655,
#   'spearman_top200_hvg': 0.9289824051746369,
#   'pearson_delta_top200_hvg': 0.7286102336609891,
#   'pearson_top200_hvg': 0.9502011926404813},
#  'POTENTIATION': {'frac_in_range': 1.0,
#   'mean_sigma': 1.1260419,
#   'std_sigma': 0.82357776,
#   'frac_sigma_below_1': 0.5871428571428572,
#   'frac_sigma_below_2': 0.9334920634920636,
#   'spearman_delta': 0.07125243151145774,
#   'spearman_delta_de': 0.85593984962406,
#   'pearson_delta': 0.41063775553376203,
#   'pearson_delta_de': 0.9187744853105793,
#   'fold_change_gap_all': 0.2283229,
#   'fold_change_gap_upreg_3': 2.451792,
#   'spearman_delta_top200_hvg': 0.5336728418210457,
#   'spearman_top200_hvg': 0.9298436170720915,
#   'pearson_delta_top200_hvg': 0.5242822418039998,
#   'pearson_top200_hvg': 0.9479797422445356},
#  'SYNERGY_SIMILAR_PHENO': {'frac_in_range': 1.0,
#   'mean_sigma': 1.0145321,
#   'std_sigma': 0.59379125,
#   'frac_sigma_below_1': 0.6753289473684211,
#   'frac_sigma_below_2': 0.9305921052631579,
#   'spearman_delta': 0.025045986189676964,
#   'spearman_delta_de': 0.8112781954887218,
#   'pearson_delta': 0.4556557475639671,
#   'pearson_delta_de': 0.9356455938453907,
#   'fold_change_gap_all': 0.19398233,
#   'fold_change_gap_upreg_3': 1.8192484,
#   'spearman_delta_top200_hvg': 0.6427998199955,
#   'spearman_top200_hvg': 0.9350259563200971,
#   'pearson_delta_top200_hvg': 0.6330903519496576,
#   'pearson_top200_hvg': 0.951282522600541},
#  'SYNERGY_DISSIMILAR_PHENO': {'frac_in_range': 1.0,
#   'mean_sigma': 0.85977685,
#   'std_sigma': 0.72536045,
#   'frac_sigma_below_1': 0.7567918192918193,
#   'frac_sigma_below_2': 0.9491300366300367,
#   'spearman_delta': 0.1646958101624918,
#   'spearman_delta_de': 0.9465091299677766,
#   'pearson_delta': 0.48169338797972144,
#   'pearson_delta_de': 0.9802990576604192,
#   'fold_change_gap_all': 0.1884844,
#   'fold_change_gap_upreg_3': 1.4802063,
#   'spearman_delta_top200_hvg': 0.6037468793862705,
#   'spearman_top200_hvg': 0.935307015444115,
#   'pearson_delta_top200_hvg': 0.6254613450554045,
#   'pearson_top200_hvg': 0.9597116956600372},
#  'SUPPRESSOR': {'frac_in_range': 1.0,
#   'mean_sigma': 0.625074,
#   'std_sigma': 0.3664305,
#   'frac_sigma_below_1': 0.852704678362573,
#   'frac_sigma_below_2': 0.9885964912280704,
#   'spearman_delta': 0.1355548828038735,
#   'spearman_delta_de': 0.9102756892230575,
#   'pearson_delta': 0.4155004185910038,
#   'pearson_delta_de': 0.9607589671856456,
#   'fold_change_gap_all': 1.2901459,
#   'fold_change_gap_upreg_3': 113.980774,
#   'spearman_delta_top200_hvg': 0.5787861363200748,
#   'spearman_top200_hvg': 0.9380039066863858,
#   'pearson_delta_top200_hvg': 0.5450902218930739,
#   'pearson_top200_hvg': 0.9625587430532901}}

# %%
out
# Out:
# {'AHR+KLF1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.8931963,
#   'std_sigma': 1.6403185,
#   'frac_sigma_below_1': 0.8,
#   'frac_sigma_below_2': 0.9,
#   'spearman_delta': 0.024240095098284783,
#   'spearman_delta_de': 0.9428571428571428,
#   'pearson_delta': 0.27795797329465494,
#   'pearson_delta_de': 0.9468511331540121,
#   'fold_change_gap_all': 0.20037927,
#   'fold_change_gap_upreg_3': 1.1235406,
#   'spearman_delta_top200_hvg': 0.17930548263706597,
#   'spearman_top200_hvg': 0.9407395184879624,
#   'pearson_delta_top200_hvg': 0.3861890660215789,
#   'pearson_top200_hvg': 0.94319804209089},
#  'ARID1A+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 1.14268,
#   'std_sigma': 0.9115124,
#   'frac_sigma_below_1': 0.5714285714285714,
#   'frac_sigma_below_2': 0.8571428571428572,
#   'spearman_delta': 0.07556004638719059,
#   'spearman_delta_de': 0.9263157894736842,
#   'pearson_delta': 0.4506821097122015,
#   'pearson_delta_de': 0.9732283269712433,
#   'fold_change_gap_all': 0.18486646,
#   'fold_change_gap_upreg_3': 2.9545946,
#   'fold_change_gap_upreg_10': 8.328789,
#   'spearman_delta_top200_hvg': 0.6346493662341559,
#   'spearman_top200_hvg': 0.9322298057451437,
#   'pearson_delta_top200_hvg': 0.5939593327914214,
#   'pearson_top200_hvg': 0.9655510242853305},
#  'BCL2L11+BAK1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.84067315,
#   'std_sigma': 0.0,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': -0.25451321137486504,
#   'spearman_delta_de': 0.49624060150375937,
#   'pearson_delta': -0.08063080539785221,
#   'pearson_delta_de': 0.9743325667790819,
#   'fold_change_gap_all': 0.09732071,
#   'spearman_delta_top200_hvg': -0.2708662716567915,
#   'spearman_top200_hvg': 0.9875871896797421,
#   'pearson_delta_top200_hvg': -0.16535008186859115,
#   'pearson_top200_hvg': 0.9816419863256158},
#  'BCL2L11+TGFBR2': {'frac_in_range': 1.0,
#   'mean_sigma': 0.5360814,
#   'std_sigma': 0.32309803,
#   'frac_sigma_below_1': 0.9375,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': -0.14225675637990245,
#   'spearman_delta_de': 0.9819548872180449,
#   'pearson_delta': 0.1989475181460455,
#   'pearson_delta_de': 0.9877238542148954,
#   'fold_change_gap_all': 0.102461055,
#   'fold_change_gap_upreg_3': 1.2427344,
#   'spearman_delta_top200_hvg': 0.151308782719568,
#   'spearman_top200_hvg': 0.9802070051751295,
#   'pearson_delta_top200_hvg': 0.2810261743158186,
#   'pearson_top200_hvg': 0.9786610772244209},
#  'BCL2L11+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.39766482,
#   'std_sigma': 0.18022467,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': -0.1260020676251187,
#   'spearman_delta_de': 0.5864661654135337,
#   'pearson_delta': 0.09477362838424427,
#   'pearson_delta_de': 0.9889472252486197,
#   'fold_change_gap_all': 0.11510709,
#   'fold_change_gap_upreg_3': 1.5400431,
#   'spearman_delta_top200_hvg': 0.11653941348533715,
#   'spearman_top200_hvg': 0.9751833795844899,
#   'pearson_delta_top200_hvg': 0.12379990099027453,
#   'pearson_top200_hvg': 0.9744523242842363},
#  'BCORL1+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.89024395,
#   'std_sigma': 0.48820207,
#   'frac_sigma_below_1': 0.5,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': -0.03773351906503279,
#   'spearman_delta_de': 0.9458646616541352,
#   'pearson_delta': 0.17223645748161928,
#   'pearson_delta_de': 0.9814498401686294,
#   'fold_change_gap_all': 0.11110481,
#   'spearman_delta_top200_hvg': 0.33389184729618243,
#   'spearman_top200_hvg': 0.9731208280207007,
#   'pearson_delta_top200_hvg': 0.21477021406225175,
#   'pearson_top200_hvg': 0.9744418080991389},
#  'BPGM+SAMD1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.922324,
#   'std_sigma': 1.3689125,
#   'frac_sigma_below_1': 0.85,
#   'frac_sigma_below_2': 0.9,
#   'spearman_delta': 0.13577071029062318,
#   'spearman_delta_de': 0.9624060150375938,
#   'pearson_delta': 0.5433684648492153,
#   'pearson_delta_de': 0.976521530051545,
#   'fold_change_gap_all': 0.15988787,
#   'fold_change_gap_upreg_3': 0.99823517,
#   'spearman_delta_top200_hvg': 0.7512757818945474,
#   'spearman_top200_hvg': 0.9687602190054752,
#   'pearson_delta_top200_hvg': 0.6951239872711162,
#   'pearson_top200_hvg': 0.9736672539661108},
#  'BPGM+ZBTB1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.53257483,
#   'std_sigma': 0.31198004,
#   'frac_sigma_below_1': 0.85,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.12063351514498913,
#   'spearman_delta_de': 0.9052631578947368,
#   'pearson_delta': 0.5607718111594702,
#   'pearson_delta_de': 0.9660838248955315,
#   'fold_change_gap_all': 0.16801849,
#   'fold_change_gap_upreg_3': 2.3311534,
#   'fold_change_gap_upreg_10': 3.966505,
#   'spearman_delta_top200_hvg': 0.7143913597839947,
#   'spearman_top200_hvg': 0.9739098477461938,
#   'pearson_delta_top200_hvg': 0.7213245969624814,
#   'pearson_top200_hvg': 0.9780159707523819},
#  'BPGM+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.5071205,
#   'std_sigma': 0.35353354,
#   'frac_sigma_below_1': 0.9,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': -0.05265812410728731,
#   'spearman_delta_de': 0.9609022556390976,
#   'pearson_delta': 0.2721227522092492,
#   'pearson_delta_de': 0.9757688000325317,
#   'fold_change_gap_all': 0.13290039,
#   'fold_change_gap_upreg_3': 1.5181433,
#   'spearman_delta_top200_hvg': 0.41202580064501615,
#   'spearman_top200_hvg': 0.960819020475512,
#   'pearson_delta_top200_hvg': 0.32561862478902115,
#   'pearson_top200_hvg': 0.9664606623708213},
#  'C3orf72+FOXL2': {'spearman_delta': -0.06419075730191275,
#   'spearman_delta_de': -0.2781954887218045,
#   'pearson_delta': 0.45096167806543785,
#   'pearson_delta_de': -0.28378176380554976,
#   'fold_change_gap_all': 0.15642647,
#   'fold_change_gap_upreg_3': 0.6678438,
#   'spearman_delta_top200_hvg': 0.6061471536788421,
#   'spearman_top200_hvg': 0.9442621475433816,
#   'pearson_delta_top200_hvg': 0.6072723336115503,
#   'pearson_top200_hvg': 0.966747290956673},
#  'C3orf72+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.6666574,
#   'std_sigma': 0.39764035,
#   'frac_sigma_below_1': 0.8461538461538461,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.1598209776581004,
#   'spearman_delta_de': 0.9473684210526315,
#   'pearson_delta': 0.4524941775573794,
#   'pearson_delta_de': 0.9938360825283076,
#   'fold_change_gap_all': 0.12233835,
#   'fold_change_gap_upreg_3': 1.4080175,
#   'spearman_delta_top200_hvg': 0.6198964974124354,
#   'spearman_top200_hvg': 0.9564854121353035,
#   'pearson_delta_top200_hvg': 0.5918343873586045,
#   'pearson_top200_hvg': 0.9763328977050517},
#  'CBL+CNN1': {'frac_in_range': 1.0,
#   'mean_sigma': 1.0708641,
#   'std_sigma': 0.5279124,
#   'frac_sigma_below_1': 0.6,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': 0.008152682697240718,
#   'spearman_delta_de': 0.8466165413533834,
#   'pearson_delta': 0.5153428823969695,
#   'pearson_delta_de': 0.902038302378324,
#   'fold_change_gap_all': 0.24503057,
#   'fold_change_gap_upreg_3': 2.8571827,
#   'fold_change_gap_upreg_10': 4.8444753,
#   'spearman_delta_top200_hvg': 0.7358643966099153,
#   'spearman_top200_hvg': 0.944180604515113,
#   'pearson_delta_top200_hvg': 0.746939135566103,
#   'pearson_top200_hvg': 0.944356516900559},
#  'CBL+PTPN12': {'frac_in_range': 1.0,
#   'mean_sigma': 1.2220244,
#   'std_sigma': 0.54855174,
#   'frac_sigma_below_1': 0.4,
#   'frac_sigma_below_2': 0.9,
#   'spearman_delta': -0.07120893208298638,
#   'spearman_delta_de': 0.882706766917293,
#   'pearson_delta': 0.27375346358334673,
#   'pearson_delta_de': 0.8674009632916868,
#   'fold_change_gap_all': 0.2126771,
#   'fold_change_gap_upreg_3': 2.7930648,
#   'fold_change_gap_upreg_10': 3.9361343,
#   'spearman_delta_top200_hvg': 0.44663016575414394,
#   'spearman_top200_hvg': 0.9199234980874523,
#   'pearson_delta_top200_hvg': 0.3591818289935898,
#   'pearson_top200_hvg': 0.9341167935424267},
#  'CBL+PTPN9': {'frac_in_range': 1.0,
#   'mean_sigma': 0.8681536,
#   'std_sigma': 0.57066923,
#   'frac_sigma_below_1': 0.75,
#   'frac_sigma_below_2': 0.9,
#   'spearman_delta': -0.048943773695325384,
#   'spearman_delta_de': 0.9503759398496241,
#   'pearson_delta': 0.42596618224467764,
#   'pearson_delta_de': 0.960650726202239,
#   'fold_change_gap_all': 0.14326198,
#   'fold_change_gap_upreg_3': 1.357757,
#   'spearman_delta_top200_hvg': 0.6648031200780019,
#   'spearman_top200_hvg': 0.9576194404860123,
#   'pearson_delta_top200_hvg': 0.6040681972939205,
#   'pearson_top200_hvg': 0.964692404761706},
#  'CBL+TGFBR2': {'frac_in_range': 1.0,
#   'mean_sigma': 1.1408933,
#   'std_sigma': 0.71887183,
#   'frac_sigma_below_1': 0.4444444444444444,
#   'frac_sigma_below_2': 0.8888888888888888,
#   'spearman_delta': -0.06891901903700141,
#   'spearman_delta_de': 0.8285714285714285,
#   'pearson_delta': 0.3661978335131786,
#   'pearson_delta_de': 0.9565175974452267,
#   'fold_change_gap_all': 0.11926305,
#   'fold_change_gap_upreg_3': 1.59412,
#   'spearman_delta_top200_hvg': 0.5560174004350109,
#   'spearman_top200_hvg': 0.9669691742293558,
#   'pearson_delta_top200_hvg': 0.5131938805157348,
#   'pearson_top200_hvg': 0.969864561901858},
#  'CBL+UBASH3A': {'spearman_delta': -0.16490800187598922,
#   'spearman_delta_de': 0.23759398496240602,
#   'pearson_delta': 0.34527715738473025,
#   'pearson_delta_de': 0.29711621229473123,
#   'fold_change_gap_all': 0.16355115,
#   'fold_change_gap_upreg_3': 2.5418642,
#   'spearman_delta_top200_hvg': 0.5431620790519763,
#   'spearman_top200_hvg': 0.9418374586937152,
#   'pearson_delta_top200_hvg': 0.4683195550284153,
#   'pearson_top200_hvg': 0.9553350134449032},
#  'CBL+UBASH3B': {'frac_in_range': 1.0,
#   'mean_sigma': 0.9849208,
#   'std_sigma': 0.34216186,
#   'frac_sigma_below_1': 0.5789473684210527,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': -0.0024813744652224193,
#   'spearman_delta_de': 0.8285714285714285,
#   'pearson_delta': 0.4625906490276235,
#   'pearson_delta_de': 0.8886341203465529,
#   'fold_change_gap_all': 0.20469925,
#   'fold_change_gap_upreg_3': 2.272723,
#   'fold_change_gap_upreg_10': 6.2303023,
#   'spearman_delta_top200_hvg': 0.6908812720318008,
#   'spearman_top200_hvg': 0.9374994374859372,
#   'pearson_delta_top200_hvg': 0.6750148514625329,
#   'pearson_top200_hvg': 0.9422521894655836},
#  'CBL+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.7170322,
#   'std_sigma': 0.5256614,
#   'frac_sigma_below_1': 0.7,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': -0.013589973712197067,
#   'spearman_delta_de': 0.8075187969924811,
#   'pearson_delta': 0.2646781621354736,
#   'pearson_delta_de': 0.8625183882533118,
#   'fold_change_gap_all': 0.108363405,
#   'fold_change_gap_upreg_3': 0.17131853,
#   'spearman_delta_top200_hvg': 0.45581039525988154,
#   'spearman_top200_hvg': 0.9612150303757596,
#   'pearson_delta_top200_hvg': 0.3526938070427378,
#   'pearson_top200_hvg': 0.9717748068646601},
#  'CDKN1A+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.5712656,
#   'std_sigma': 0.27112997,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.12508540680187005,
#   'spearman_delta_de': 0.8436090225563909,
#   'pearson_delta': 0.45057081387715797,
#   'pearson_delta_de': 0.9870900144570742,
#   'fold_change_gap_all': 0.18016204,
#   'fold_change_gap_upreg_3': 10.717345,
#   'fold_change_gap_upreg_10': 20.568092,
#   'spearman_delta_top200_hvg': 0.6662626565664143,
#   'spearman_top200_hvg': 0.9680567014175355,
#   'pearson_delta_top200_hvg': 0.6193796773898455,
#   'pearson_top200_hvg': 0.9772658377620439},
#  'CDKN1B+CDKN1A': {'frac_in_range': 1.0,
#   'mean_sigma': 0.73084885,
#   'std_sigma': 0.11940979,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.04711421975222826,
#   'spearman_delta_de': 0.7864661654135338,
#   'pearson_delta': 0.4489967009436488,
#   'pearson_delta_de': 0.9805046698067853,
#   'fold_change_gap_all': 0.2569929,
#   'fold_change_gap_upreg_3': 7.1329145,
#   'fold_change_gap_upreg_10': 30.347946,
#   'spearman_delta_top200_hvg': 0.6553498837470938,
#   'spearman_top200_hvg': 0.9477926948173705,
#   'pearson_delta_top200_hvg': 0.6183004212618525,
#   'pearson_top200_hvg': 0.963534611566688},
#  'CDKN1B+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.21228495,
#   'std_sigma': 0.12511547,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.16157678716547125,
#   'spearman_delta_de': 0.9894736842105262,
#   'pearson_delta': 0.4581683426496686,
#   'pearson_delta_de': 0.9915034673255899,
#   'fold_change_gap_all': 0.12182917,
#   'fold_change_gap_upreg_3': 2.0659914,
#   'spearman_delta_top200_hvg': 0.6795214880372011,
#   'spearman_top200_hvg': 0.9730068251706294,
#   'pearson_delta_top200_hvg': 0.6391919485922379,
#   'pearson_top200_hvg': 0.9808247846230304},
#  'CDKN1C+CDKN1A': {'frac_in_range': 1.0,
#   'mean_sigma': 1.0935639,
#   'std_sigma': 0.29639092,
#   'frac_sigma_below_1': 0.4,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.04859513076519977,
#   'spearman_delta_de': 0.8812030075187969,
#   'pearson_delta': 0.4293213701643653,
#   'pearson_delta_de': 0.9686289198901856,
#   'fold_change_gap_all': 0.25760743,
#   'fold_change_gap_upreg_3': 8.455816,
#   'fold_change_gap_upreg_10': 27.037773,
#   'spearman_delta_top200_hvg': 0.6231605790144754,
#   'spearman_top200_hvg': 0.9429126764092303,
#   'pearson_delta_top200_hvg': 0.5785826364347553,
#   'pearson_top200_hvg': 0.9546775603530273},
#  'CDKN1C+CDKN1B': {'frac_in_range': 1.0,
#   'mean_sigma': 0.9013438,
#   'std_sigma': 0.15040454,
#   'frac_sigma_below_1': 0.6666666666666667,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.07635678492358239,
#   'spearman_delta_de': 0.6240601503759398,
#   'pearson_delta': 0.4585017498643401,
#   'pearson_delta_de': 0.9772862791768375,
#   'fold_change_gap_all': 0.15399127,
#   'fold_change_gap_upreg_3': 2.0885932,
#   'spearman_delta_top200_hvg': 0.6380124503112579,
#   'spearman_top200_hvg': 0.9554023850596266,
#   'pearson_delta_top200_hvg': 0.6105686930292834,
#   'pearson_top200_hvg': 0.9637594407124196},
#  'CDKN1C+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.8362297,
#   'std_sigma': 1.2117194,
#   'frac_sigma_below_1': 0.7222222222222222,
#   'frac_sigma_below_2': 0.9444444444444444,
#   'spearman_delta': 0.18621788826872546,
#   'spearman_delta_de': 0.9759398496240601,
#   'pearson_delta': 0.45931431573859927,
#   'pearson_delta_de': 0.9906897666834784,
#   'fold_change_gap_all': 0.12445007,
#   'fold_change_gap_upreg_3': 1.2248393,
#   'spearman_delta_top200_hvg': 0.6461906547663694,
#   'spearman_top200_hvg': 0.9652216305407637,
#   'pearson_delta_top200_hvg': 0.6215741026198047,
#   'pearson_top200_hvg': 0.9735456036399046},
#  'CEBPB+CEBPA': {'frac_in_range': 1.0,
#   'mean_sigma': 3.0016062,
#   'std_sigma': 3.584905,
#   'frac_sigma_below_1': 0.6666666666666667,
#   'frac_sigma_below_2': 0.6666666666666667,
#   'spearman_delta': 0.24565822594106854,
#   'spearman_delta_de': 0.6601503759398496,
#   'pearson_delta': 0.8599782795564734,
#   'pearson_delta_de': 0.9908159760131001,
#   'fold_change_gap_all': 4.404288,
#   'fold_change_gap_upreg_3': 23.19109,
#   'fold_change_gap_upreg_10': 61.431686,
#   'spearman_delta_top200_hvg': 0.9592754818870473,
#   'spearman_top200_hvg': 0.9836417099084581,
#   'pearson_delta_top200_hvg': 0.9541227842478011,
#   'pearson_top200_hvg': 0.983248867295854},
#  'CEBPB+MAPK1': {'frac_in_range': 1.0,
#   'mean_sigma': 1.0826983,
#   'std_sigma': 0.55935746,
#   'frac_sigma_below_1': 0.4,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': 0.2751901769271709,
#   'spearman_delta_de': 0.8120300751879698,
#   'pearson_delta': 0.47061222098750427,
#   'pearson_delta_de': 0.883656393730552,
#   'fold_change_gap_all': 0.2478132,
#   'fold_change_gap_downreg_0.33': 0.68761885,
#   'fold_change_gap_upreg_3': 2.0608857,
#   'fold_change_gap_upreg_10': 4.4162717,
#   'spearman_delta_top200_hvg': 0.6385284632115804,
#   'spearman_top200_hvg': 0.8968184204605116,
#   'pearson_delta_top200_hvg': 0.5950041751905366,
#   'pearson_top200_hvg': 0.9373370098750619},
#  'CEBPB+OSR2': {'frac_in_range': 1.0,
#   'mean_sigma': 0.6851821,
#   'std_sigma': 0.24010314,
#   'frac_sigma_below_1': 0.8823529411764706,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.3435616163443602,
#   'spearman_delta_de': 0.900751879699248,
#   'pearson_delta': 0.6146663691003139,
#   'pearson_delta_de': 0.9520418959219172,
#   'fold_change_gap_all': 0.25464234,
#   'fold_change_gap_upreg_3': 1.9068656,
#   'fold_change_gap_upreg_10': 4.490022,
#   'spearman_delta_top200_hvg': 0.8068191704792621,
#   'spearman_top200_hvg': 0.9138783469586741,
#   'pearson_delta_top200_hvg': 0.8008714940175395,
#   'pearson_top200_hvg': 0.9541606028348102},
#  'CEBPB+PTPN12': {'frac_in_range': 1.0,
#   'mean_sigma': 0.5986319,
#   'std_sigma': 0.29418135,
#   'frac_sigma_below_1': 0.8947368421052632,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.20111618580733284,
#   'spearman_delta_de': 0.9699248120300751,
#   'pearson_delta': 0.4609694488057942,
#   'pearson_delta_de': 0.9830937071848855,
#   'fold_change_gap_all': 4.56421,
#   'fold_change_gap_upreg_3': 442.72046,
#   'fold_change_gap_upreg_10': 1323.5994,
#   'spearman_delta_top200_hvg': 0.677290932273307,
#   'spearman_top200_hvg': 0.9553888847221182,
#   'pearson_delta_top200_hvg': 0.634511566111265,
#   'pearson_top200_hvg': 0.9755124407598718},
#  'CEBPB+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.77337545,
#   'std_sigma': 0.24161595,
#   'frac_sigma_below_1': 0.7,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.2553060748395937,
#   'spearman_delta_de': 0.8225563909774435,
#   'pearson_delta': 0.45725876734827525,
#   'pearson_delta_de': 0.9454006594272734,
#   'fold_change_gap_all': 4.5524125,
#   'fold_change_gap_upreg_3': 98.89226,
#   'fold_change_gap_upreg_10': 455.8916,
#   'spearman_delta_top200_hvg': 0.6147858696467412,
#   'spearman_top200_hvg': 0.8784279606990175,
#   'pearson_delta_top200_hvg': 0.6027072393481326,
#   'pearson_top200_hvg': 0.9413050109853093},
#  'CEBPE+CEBPB': {'frac_in_range': 1.0,
#   'mean_sigma': 0.91649544,
#   'std_sigma': 0.935,
#   'frac_sigma_below_1': 0.75,
#   'frac_sigma_below_2': 0.75,
#   'spearman_delta': 0.3193112852685347,
#   'spearman_delta_de': 0.7834586466165413,
#   'pearson_delta': 0.8125256389696347,
#   'pearson_delta_de': 0.9566778607187252,
#   'fold_change_gap_all': 0.6190389,
#   'fold_change_gap_upreg_3': 4.1467237,
#   'fold_change_gap_upreg_10': 11.303622,
#   'spearman_delta_top200_hvg': 0.9396474911872797,
#   'spearman_top200_hvg': 0.9496362409060228,
#   'pearson_delta_top200_hvg': 0.9265976522037213,
#   'pearson_top200_hvg': 0.9683403472088876},
#  'CEBPE+PTPN12': {'frac_in_range': 1.0,
#   'mean_sigma': 0.662481,
#   'std_sigma': 0.5282722,
#   'frac_sigma_below_1': 0.8,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': 0.25464746123707177,
#   'spearman_delta_de': 0.9383458646616539,
#   'pearson_delta': 0.5805129450199913,
#   'pearson_delta_de': 0.9612152922583754,
#   'fold_change_gap_all': 0.28660947,
#   'fold_change_gap_upreg_3': 14.810444,
#   'fold_change_gap_upreg_10': 20.845146,
#   'spearman_delta_top200_hvg': 0.7013665341633543,
#   'spearman_top200_hvg': 0.8190954773869348,
#   'pearson_delta_top200_hvg': 0.6833818199313617,
#   'pearson_top200_hvg': 0.9081568570811541},
#  'CEBPE+RUNX1T1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.19841146,
#   'std_sigma': 0.17343979,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.4355173299477806,
#   'spearman_delta_de': 0.9804511278195487,
#   'pearson_delta': 0.7082359239072902,
#   'pearson_delta_de': 0.9959559013431083,
#   'fold_change_gap_all': 0.24485181,
#   'fold_change_gap_upreg_3': 7.1188617,
#   'fold_change_gap_upreg_10': 20.031288,
#   'spearman_delta_top200_hvg': 0.8585539638490963,
#   'spearman_top200_hvg': 0.9061876546913674,
#   'pearson_delta_top200_hvg': 0.8325862259749562,
#   'pearson_top200_hvg': 0.9462777169650135},
#  'CEBPE+SPI1': {'frac_in_range': 1.0,
#   'mean_sigma': 1.1065799,
#   'std_sigma': 1.072863,
#   'frac_sigma_below_1': 0.736842105263158,
#   'frac_sigma_below_2': 0.8947368421052632,
#   'spearman_delta': 0.3524648441212443,
#   'spearman_delta_de': 0.7999999999999999,
#   'pearson_delta': 0.7959850526409488,
#   'pearson_delta_de': 0.8994191457644033,
#   'fold_change_gap_all': 2.1482038,
#   'fold_change_gap_downreg_0.33': 0.3462286,
#   'fold_change_gap_upreg_3': 15.384776,
#   'fold_change_gap_upreg_10': 41.82492,
#   'spearman_delta_top200_hvg': 0.9159828995724894,
#   'spearman_top200_hvg': 0.9174454361359035,
#   'pearson_delta_top200_hvg': 0.9003723376101842,
#   'pearson_top200_hvg': 0.9441597113009081},
#  'CELF2+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.44782227,
#   'std_sigma': 0.5107225,
#   'frac_sigma_below_1': 0.8947368421052632,
#   'frac_sigma_below_2': 0.9473684210526316,
#   'spearman_delta': 0.20044663093208198,
#   'spearman_delta_de': 0.9624060150375938,
#   'pearson_delta': 0.3369998084303362,
#   'pearson_delta_de': 0.9737949480001985,
#   'fold_change_gap_all': 0.10799758,
#   'fold_change_gap_upreg_3': 1.5389609,
#   'spearman_delta_top200_hvg': 0.5308467711692793,
#   'spearman_top200_hvg': 0.9656746418660468,
#   'pearson_delta_top200_hvg': 0.4770447849631796,
#   'pearson_top200_hvg': 0.9756277267700816},
#  'CKS1B+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 1.1114286,
#   'std_sigma': 1.0164609,
#   'frac_sigma_below_1': 0.6666666666666667,
#   'frac_sigma_below_2': 0.8666666666666667,
#   'spearman_delta': 0.06494026706256158,
#   'spearman_delta_de': 0.9593984962406013,
#   'pearson_delta': 0.3444295415658877,
#   'pearson_delta_de': 0.9525058215095759,
#   'fold_change_gap_all': 0.20296004,
#   'fold_change_gap_upreg_3': 2.9551597,
#   'fold_change_gap_upreg_10': 10.88895,
#   'spearman_delta_top200_hvg': 0.5829220730518264,
#   'spearman_top200_hvg': 0.9579333075577466,
#   'pearson_delta_top200_hvg': 0.4519736431125411,
#   'pearson_top200_hvg': 0.970549407362802},
#  'CNN1+MAPK1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.6231511,
#   'std_sigma': 0.2521051,
#   'frac_sigma_below_1': 0.95,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.07957447789071732,
#   'spearman_delta_de': 0.7804511278195487,
#   'pearson_delta': 0.2909859513800046,
#   'pearson_delta_de': 0.9511824647098883,
#   'fold_change_gap_all': 0.14994496,
#   'fold_change_gap_upreg_3': 2.0732136,
#   'fold_change_gap_upreg_10': 1.9909191,
#   'spearman_delta_top200_hvg': 0.4353783844596116,
#   'spearman_top200_hvg': 0.9379704492612316,
#   'pearson_delta_top200_hvg': 0.38655806025474826,
#   'pearson_top200_hvg': 0.9602396998806808},
#  'CNN1+UBASH3A': {'frac_in_range': 1.0,
#   'mean_sigma': 0.88741446,
#   'std_sigma': 0.49133897,
#   'frac_sigma_below_1': 0.7857142857142857,
#   'frac_sigma_below_2': 0.9285714285714286,
#   'spearman_delta': -0.02992862855372783,
#   'spearman_delta_de': 0.9789473684210527,
#   'pearson_delta': 0.535869120591442,
#   'pearson_delta_de': 0.9713802191353849,
#   'fold_change_gap_all': 0.21744968,
#   'fold_change_gap_upreg_3': 2.4637158,
#   'fold_change_gap_upreg_10': 4.174629,
#   'spearman_delta_top200_hvg': 0.7754128853221331,
#   'spearman_top200_hvg': 0.946422015458709,
#   'pearson_delta_top200_hvg': 0.7727762541974281,
#   'pearson_top200_hvg': 0.9492376475211578},
#  'COL2A1+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.89065486,
#   'std_sigma': 0.47868592,
#   'frac_sigma_below_1': 0.7,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': 0.0807726135150494,
#   'spearman_delta_de': 0.6962406015037594,
#   'pearson_delta': 0.2282064632109367,
#   'pearson_delta_de': 0.7967232846217671,
#   'fold_change_gap_all': 0.209081,
#   'fold_change_gap_upreg_3': 2.9626288,
#   'spearman_delta_top200_hvg': 0.30364209105227635,
#   'spearman_top200_hvg': 0.9200000000000002,
#   'pearson_delta_top200_hvg': 0.2943037054191124,
#   'pearson_top200_hvg': 0.9405762195363951},
#  'DUSP9+ETS2': {'frac_in_range': 1.0,
#   'mean_sigma': 0.8261112,
#   'std_sigma': 0.35359767,
#   'frac_sigma_below_1': 0.65,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.1902624393603666,
#   'spearman_delta_de': 0.8796992481203006,
#   'pearson_delta': 0.34147716240207954,
#   'pearson_delta_de': 0.950070291636593,
#   'fold_change_gap_all': 0.15941978,
#   'fold_change_gap_upreg_3': 4.58344,
#   'fold_change_gap_upreg_10': 6.9935284,
#   'spearman_delta_top200_hvg': 0.4617610440261007,
#   'spearman_top200_hvg': 0.9507177679441987,
#   'pearson_delta_top200_hvg': 0.43957919445010085,
#   'pearson_top200_hvg': 0.9618302510591034},
#  'DUSP9+IGDCC3': {'frac_in_range': 1.0,
#   'mean_sigma': 1.0831199,
#   'std_sigma': 0.5903843,
#   'frac_sigma_below_1': 0.44999999999999996,
#   'frac_sigma_below_2': 0.9,
#   'spearman_delta': 0.2192122883978027,
#   'spearman_delta_de': 0.9233082706766916,
#   'pearson_delta': 0.5743313314649992,
#   'pearson_delta_de': 0.9516608930470324,
#   'fold_change_gap_all': 0.2067608,
#   'fold_change_gap_upreg_3': 2.9709258,
#   'fold_change_gap_upreg_10': 5.834961,
#   'spearman_delta_top200_hvg': 0.7159168979224483,
#   'spearman_top200_hvg': 0.9447026175654393,
#   'pearson_delta_top200_hvg': 0.7275643678116831,
#   'pearson_top200_hvg': 0.9591972491965222},
#  'DUSP9+KLF1': {'frac_in_range': 1.0,
#   'mean_sigma': 1.8353093,
#   'std_sigma': 1.8938885,
#   'frac_sigma_below_1': 0.19999999999999996,
#   'frac_sigma_below_2': 0.8,
#   'spearman_delta': 0.08087038843026371,
#   'spearman_delta_de': 0.9338345864661652,
#   'pearson_delta': 0.4372382212885348,
#   'pearson_delta_de': 0.9266816886028246,
#   'fold_change_gap_all': 0.2898144,
#   'fold_change_gap_upreg_3': 3.74648,
#   'fold_change_gap_upreg_10': 8.262439,
#   'spearman_delta_top200_hvg': 0.5316132903322583,
#   'spearman_top200_hvg': 0.9318232955823897,
#   'pearson_delta_top200_hvg': 0.635932720604705,
#   'pearson_top200_hvg': 0.9420234854002137},
#  'DUSP9+MAPK1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.76010334,
#   'std_sigma': 0.53398186,
#   'frac_sigma_below_1': 0.6875,
#   'frac_sigma_below_2': 0.9375,
#   'spearman_delta': 0.06962366271001005,
#   'spearman_delta_de': 0.9383458646616539,
#   'pearson_delta': 0.2738513487756157,
#   'pearson_delta_de': 0.9587666118218837,
#   'fold_change_gap_all': 0.1590726,
#   'fold_change_gap_upreg_3': 4.924856,
#   'fold_change_gap_upreg_10': 6.7318287,
#   'spearman_delta_top200_hvg': 0.30883072076801926,
#   'spearman_top200_hvg': 0.9510912772819322,
#   'pearson_delta_top200_hvg': 0.3464808833335996,
#   'pearson_top200_hvg': 0.9645553397846536},
#  'DUSP9+PRTG': {'frac_in_range': 1.0,
#   'mean_sigma': 1.3807102,
#   'std_sigma': 0.80107844,
#   'frac_sigma_below_1': 0.368421052631579,
#   'frac_sigma_below_2': 0.8947368421052632,
#   'spearman_delta': 0.1847083391235492,
#   'spearman_delta_de': 0.9052631578947368,
#   'pearson_delta': 0.590591866875895,
#   'pearson_delta_de': 0.9440972946092422,
#   'fold_change_gap_all': 0.21550032,
#   'fold_change_gap_upreg_3': 3.069672,
#   'fold_change_gap_upreg_10': 5.938509,
#   'spearman_delta_top200_hvg': 0.7218465461636543,
#   'spearman_top200_hvg': 0.9460402557715568,
#   'pearson_delta_top200_hvg': 0.752387108748572,
#   'pearson_top200_hvg': 0.9613695294806844},
#  'DUSP9+SNAI1': {'frac_in_range': 1.0,
#   'mean_sigma': 1.0709949,
#   'std_sigma': 0.39982492,
#   'frac_sigma_below_1': 0.38888888888888884,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.2100058347336054,
#   'spearman_delta_de': 0.8345864661654135,
#   'pearson_delta': 0.4687812130388132,
#   'pearson_delta_de': 0.9707249468266739,
#   'fold_change_gap_all': 0.36660218,
#   'fold_change_gap_upreg_3': 3.328932,
#   'fold_change_gap_upreg_10': 10.988617,
#   'spearman_delta_top200_hvg': 0.5844581114527865,
#   'spearman_top200_hvg': 0.8623385584639617,
#   'pearson_delta_top200_hvg': 0.596416665078909,
#   'pearson_top200_hvg': 0.9198035618325122},
#  'DUSP9+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 1.0600799,
#   'std_sigma': 0.37650776,
#   'frac_sigma_below_1': 0.5,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.1495033971989791,
#   'spearman_delta_de': 0.8812030075187969,
#   'pearson_delta': 0.31451474103931143,
#   'pearson_delta_de': 0.9051937678509018,
#   'fold_change_gap_all': 0.19212797,
#   'fold_change_gap_upreg_3': 6.3426456,
#   'fold_change_gap_upreg_10': 9.747816,
#   'spearman_delta_top200_hvg': 0.4506067651691293,
#   'spearman_top200_hvg': 0.9305677641941049,
#   'pearson_delta_top200_hvg': 0.4135907595503162,
#   'pearson_top200_hvg': 0.947557659619706},
#  'EGR1+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.4880069,
#   'std_sigma': 0.25282878,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.09484450228226239,
#   'spearman_delta_de': 0.9759398496240601,
#   'pearson_delta': 0.3599009734531236,
#   'pearson_delta_de': 0.9904426531734773,
#   'fold_change_gap_all': 0.097980805,
#   'spearman_delta_top200_hvg': 0.49636690917272935,
#   'spearman_top200_hvg': 0.9731283282082054,
#   'pearson_delta_top200_hvg': 0.48428786362590526,
#   'pearson_top200_hvg': 0.9819560970593946},
#  'ETS2+CNN1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.42654866,
#   'std_sigma': 0.27914196,
#   'frac_sigma_below_1': 0.95,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.13758565045209778,
#   'spearman_delta_de': 0.9864661654135337,
#   'pearson_delta': 0.4348252236985183,
#   'pearson_delta_de': 0.985991440225313,
#   'fold_change_gap_all': 0.108405754,
#   'fold_change_gap_upreg_3': 1.0624161,
#   'fold_change_gap_upreg_10': 1.0624161,
#   'spearman_delta_top200_hvg': 0.5896437410935275,
#   'spearman_top200_hvg': 0.9656626415660393,
#   'pearson_delta_top200_hvg': 0.6306026487483755,
#   'pearson_top200_hvg': 0.975615008976924},
#  'ETS2+IKZF3': {'frac_in_range': 1.0,
#   'mean_sigma': 0.4822947,
#   'std_sigma': 0.26388454,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.23479831493242015,
#   'spearman_delta_de': 0.9819548872180449,
#   'pearson_delta': 0.7018567140170088,
#   'pearson_delta_de': 0.9894840573155546,
#   'fold_change_gap_all': 0.32683554,
#   'fold_change_gap_upreg_3': 6.596073,
#   'fold_change_gap_upreg_10': 27.652649,
#   'spearman_delta_top200_hvg': 0.7835610890272258,
#   'spearman_top200_hvg': 0.9618135453386336,
#   'pearson_delta_top200_hvg': 0.8683211454500449,
#   'pearson_top200_hvg': 0.9782461199929343},
#  'ETS2+MAP7D1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.9000864,
#   'std_sigma': 0.38153124,
#   'frac_sigma_below_1': 0.65,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.07785797043157597,
#   'spearman_delta_de': 0.8421052631578947,
#   'pearson_delta': 0.1940350759953206,
#   'pearson_delta_de': 0.9339697311988449,
#   'fold_change_gap_all': 0.19236785,
#   'fold_change_gap_upreg_3': 1.4297032,
#   'spearman_delta_top200_hvg': 0.22536713417835447,
#   'spearman_top200_hvg': 0.9236825920648019,
#   'pearson_delta_top200_hvg': 0.19822943710068613,
#   'pearson_top200_hvg': 0.9412276525217242},
#  'ETS2+MAPK1': {'frac_in_range': 1.0,
#   'mean_sigma': 1.2716194,
#   'std_sigma': 0.48743585,
#   'frac_sigma_below_1': 0.4,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': 0.19513046287415606,
#   'spearman_delta_de': 0.7714285714285714,
#   'pearson_delta': 0.40568368085851225,
#   'pearson_delta_de': 0.8185602213420571,
#   'fold_change_gap_all': 0.35889092,
#   'fold_change_gap_downreg_0.33': 0.69644976,
#   'fold_change_gap_upreg_3': 3.3577337,
#   'fold_change_gap_upreg_10': 7.6269174,
#   'spearman_delta_top200_hvg': 0.5255201380034502,
#   'spearman_top200_hvg': 0.8719297982449563,
#   'pearson_delta_top200_hvg': 0.48136317635121584,
#   'pearson_top200_hvg': 0.9187186316121357},
#  'FEV+ISL2': {'frac_in_range': 1.0,
#   'mean_sigma': 1.1549971,
#   'std_sigma': 0.72844577,
#   'frac_sigma_below_1': 0.5,
#   'frac_sigma_below_2': 0.85,
#   'spearman_delta': 0.1887873569089453,
#   'spearman_delta_de': 0.9067669172932331,
#   'pearson_delta': 0.5274439352007464,
#   'pearson_delta_de': 0.9725646078356635,
#   'fold_change_gap_all': 0.3082184,
#   'fold_change_gap_upreg_3': 3.8456428,
#   'fold_change_gap_upreg_10': 15.040761,
#   'spearman_delta_top200_hvg': 0.6089642241056027,
#   'spearman_top200_hvg': 0.9241311032775821,
#   'pearson_delta_top200_hvg': 0.6387113766813751,
#   'pearson_top200_hvg': 0.9555727818174544},
#  'FEV+MAP7D1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.884423,
#   'std_sigma': 0.48349395,
#   'frac_sigma_below_1': 0.6666666666666667,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.16235508874249788,
#   'spearman_delta_de': 0.8180451127819548,
#   'pearson_delta': 0.4706136671372492,
#   'pearson_delta_de': 0.889067162416226,
#   'fold_change_gap_all': 0.22496526,
#   'fold_change_gap_upreg_3': 2.420144,
#   'fold_change_gap_upreg_10': 8.2679,
#   'spearman_delta_top200_hvg': 0.5159123978099454,
#   'spearman_top200_hvg': 0.9362964074101855,
#   'pearson_delta_top200_hvg': 0.5790298815609324,
#   'pearson_top200_hvg': 0.9583206245544167},
#  'FOSB+CEBPB': {'frac_in_range': 1.0,
#   'mean_sigma': 1.4354948,
#   'std_sigma': 0.84413236,
#   'frac_sigma_below_1': 0.33333333333333337,
#   'frac_sigma_below_2': 0.8333333333333334,
#   'spearman_delta': 0.20028217347115843,
#   'spearman_delta_de': 0.956390977443609,
#   'pearson_delta': 0.7205953519409984,
#   'pearson_delta_de': 0.9527902097091722,
#   'fold_change_gap_all': 0.7457506,
#   'fold_change_gap_upreg_3': 5.7428517,
#   'fold_change_gap_upreg_10': 14.813633,
#   'spearman_delta_top200_hvg': 0.8735603390084753,
#   'spearman_top200_hvg': 0.8462011550288758,
#   'pearson_delta_top200_hvg': 0.8641999751454532,
#   'pearson_top200_hvg': 0.9076506406282627},
#  'FOSB+IKZF3': {'frac_in_range': 1.0,
#   'mean_sigma': 0.8004607,
#   'std_sigma': 0.9955179,
#   'frac_sigma_below_1': 0.7647058823529411,
#   'frac_sigma_below_2': 0.8823529411764706,
#   'spearman_delta': 0.18705691037483138,
#   'spearman_delta_de': 0.9819548872180449,
#   'pearson_delta': 0.6471075863995743,
#   'pearson_delta_de': 0.9939039446674542,
#   'fold_change_gap_all': 0.14254764,
#   'fold_change_gap_upreg_3': 1.2534118,
#   'fold_change_gap_upreg_10': 4.0908613,
#   'spearman_delta_top200_hvg': 0.7677101927548189,
#   'spearman_top200_hvg': 0.9499197479936999,
#   'pearson_delta_top200_hvg': 0.8116090229012776,
#   'pearson_top200_hvg': 0.9716785023432817},
#  'FOSB+PTPN12': {'frac_in_range': 1.0,
#   'mean_sigma': 1.7765031,
#   'std_sigma': 2.9306889,
#   'frac_sigma_below_1': 0.75,
#   'frac_sigma_below_2': 0.8125,
#   'spearman_delta': 0.03251871348212841,
#   'spearman_delta_de': 0.9503759398496241,
#   'pearson_delta': 0.25371837818714826,
#   'pearson_delta_de': 0.9278488226738063,
#   'fold_change_gap_all': 0.18130581,
#   'fold_change_gap_upreg_3': 3.805128,
#   'spearman_delta_top200_hvg': 0.4168604215105378,
#   'spearman_top200_hvg': 0.8936818420460512,
#   'pearson_delta_top200_hvg': 0.280868851890978,
#   'pearson_top200_hvg': 0.9350455931500948},
#  'FOSB+UBASH3B': {'frac_in_range': 1.0,
#   'mean_sigma': 0.36155725,
#   'std_sigma': 0.2436357,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.17610352645725763,
#   'spearman_delta_de': 0.9428571428571428,
#   'pearson_delta': 0.4513458065422695,
#   'pearson_delta_de': 0.9822503331126877,
#   'fold_change_gap_all': 0.10460083,
#   'spearman_delta_top200_hvg': 0.6828065701642542,
#   'spearman_top200_hvg': 0.9726963174079353,
#   'pearson_delta_top200_hvg': 0.6191713859038129,
#   'pearson_top200_hvg': 0.9775199654175607},
#  'FOXA1+FOXL2': {'frac_in_range': 1.0,
#   'mean_sigma': 0.6159312,
#   'std_sigma': 0.27418387,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.1756012165245149,
#   'spearman_delta_de': 0.9669172932330825,
#   'pearson_delta': 0.4788163534958917,
#   'pearson_delta_de': 0.9849112113854668,
#   'fold_change_gap_all': 0.15483485,
#   'fold_change_gap_upreg_3': 0.99097663,
#   'spearman_delta_top200_hvg': 0.6088877221930549,
#   'spearman_top200_hvg': 0.9438209494566588,
#   'pearson_delta_top200_hvg': 0.6177313261950339,
#   'pearson_top200_hvg': 0.966440247861238},
#  'FOXA1+HOXB9': {'frac_in_range': 1.0,
#   'mean_sigma': 0.7539121,
#   'std_sigma': 0.9631236,
#   'frac_sigma_below_1': 0.75,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': 0.2769262338052559,
#   'spearman_delta_de': 0.9654135338345864,
#   'pearson_delta': 0.5398623746664137,
#   'pearson_delta_de': 0.984444162487265,
#   'fold_change_gap_all': 0.16687611,
#   'fold_change_gap_upreg_3': 0.636408,
#   'spearman_delta_top200_hvg': 0.6186349658741469,
#   'spearman_top200_hvg': 0.9575969399234983,
#   'pearson_delta_top200_hvg': 0.6746042756344723,
#   'pearson_top200_hvg': 0.9659167858261954},
#  'FOXA3+FOXL2': {'frac_in_range': 1.0,
#   'mean_sigma': 1.0686392,
#   'std_sigma': 0.6774734,
#   'frac_sigma_below_1': 0.6,
#   'frac_sigma_below_2': 0.8,
#   'spearman_delta': 0.1757477694695404,
#   'spearman_delta_de': 0.5984962406015037,
#   'pearson_delta': 0.5082018248118696,
#   'pearson_delta_de': 0.9929706406600364,
#   'fold_change_gap_all': 0.25154567,
#   'fold_change_gap_upreg_3': 1.7777774,
#   'spearman_delta_top200_hvg': 0.6181189529738245,
#   'spearman_top200_hvg': 0.8878702797084101,
#   'pearson_delta_top200_hvg': 0.6504332689123498,
#   'pearson_top200_hvg': 0.9364178973349933},
#  'FOXF1+FOXL2': {'frac_in_range': 1.0,
#   'mean_sigma': 0.7104111,
#   'std_sigma': 0.50399303,
#   'frac_sigma_below_1': 0.8333333333333334,
#   'frac_sigma_below_2': 0.9444444444444444,
#   'spearman_delta': 0.19737372805844303,
#   'spearman_delta_de': 0.9669172932330825,
#   'pearson_delta': 0.4943370087359928,
#   'pearson_delta_de': 0.9864768151596549,
#   'fold_change_gap_all': 0.20142724,
#   'fold_change_gap_upreg_3': 0.80367243,
#   'spearman_delta_top200_hvg': 0.6343148578714468,
#   'spearman_top200_hvg': 0.9155313882847071,
#   'pearson_delta_top200_hvg': 0.6598075191862829,
#   'pearson_top200_hvg': 0.9533127640858804},
#  'FOXL2+HOXB9': {'frac_in_range': 1.0,
#   'mean_sigma': 0.9495882,
#   'std_sigma': 0.0,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.10823777393111396,
#   'spearman_delta_de': 0.47518796992481205,
#   'pearson_delta': 0.5074258611156973,
#   'pearson_delta_de': 0.9661658405261659,
#   'fold_change_gap_all': 0.20904686,
#   'fold_change_gap_upreg_3': 0.9820528,
#   'spearman_delta_top200_hvg': 0.6214265356633918,
#   'spearman_top200_hvg': 0.9111778711385442,
#   'pearson_delta_top200_hvg': 0.6632191290440922,
#   'pearson_top200_hvg': 0.9506517464078471},
#  'FOXL2+MEIS1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.8355741,
#   'std_sigma': 0.60111237,
#   'frac_sigma_below_1': 0.8461538461538461,
#   'frac_sigma_below_2': 0.9230769230769231,
#   'spearman_delta': 0.14720339568473,
#   'spearman_delta_de': 0.9593984962406013,
#   'pearson_delta': 0.4037927371766367,
#   'pearson_delta_de': 0.9906006486041168,
#   'fold_change_gap_all': 0.153082,
#   'fold_change_gap_upreg_3': 0.9696405,
#   'spearman_delta_top200_hvg': 0.5285712142803571,
#   'spearman_top200_hvg': 0.950325864518879,
#   'pearson_delta_top200_hvg': 0.5546166306744166,
#   'pearson_top200_hvg': 0.9705948168009226},
#  'FOXL2+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.60362136,
#   'std_sigma': 0.623738,
#   'frac_sigma_below_1': 0.7894736842105263,
#   'frac_sigma_below_2': 0.9473684210526316,
#   'spearman_delta': 0.18609772425555404,
#   'spearman_delta_de': 0.9609022556390976,
#   'pearson_delta': 0.40986728804684347,
#   'pearson_delta_de': 0.990140196524448,
#   'fold_change_gap_all': 0.11164595,
#   'fold_change_gap_upreg_3': 0.35065603,
#   'spearman_delta_top200_hvg': 0.5691772294307358,
#   'spearman_top200_hvg': 0.9595724893122329,
#   'pearson_delta_top200_hvg': 0.4970151665450404,
#   'pearson_top200_hvg': 0.9747667847867761},
#  'IGDCC3+MAPK1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.72274905,
#   'std_sigma': 0.4832099,
#   'frac_sigma_below_1': 0.8421052631578947,
#   'frac_sigma_below_2': 0.9473684210526316,
#   'spearman_delta': 0.05297312681316179,
#   'spearman_delta_de': 0.8210526315789473,
#   'pearson_delta': 0.3426788989475959,
#   'pearson_delta_de': 0.8768022884725887,
#   'fold_change_gap_all': 0.1480373,
#   'fold_change_gap_upreg_3': 1.8131312,
#   'fold_change_gap_upreg_10': 2.2525864,
#   'spearman_delta_top200_hvg': 0.47817745443636095,
#   'spearman_top200_hvg': 0.9455291382284559,
#   'pearson_delta_top200_hvg': 0.4374392479712522,
#   'pearson_top200_hvg': 0.9629524544218384},
#  'IRF1+SET': {'frac_in_range': 1.0,
#   'mean_sigma': 1.2516546,
#   'std_sigma': 0.37529933,
#   'frac_sigma_below_1': 0.4,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': 0.1654960208707767,
#   'spearman_delta_de': 0.7849624060150376,
#   'pearson_delta': 0.2994022866616278,
#   'pearson_delta_de': 0.9404684636729619,
#   'fold_change_gap_all': 0.6923751,
#   'fold_change_gap_upreg_3': 7.2717185,
#   'fold_change_gap_upreg_10': 13.268663,
#   'spearman_delta_top200_hvg': 0.4539158478961975,
#   'spearman_top200_hvg': 0.8894412360309009,
#   'pearson_delta_top200_hvg': 0.3484879304747343,
#   'pearson_top200_hvg': 0.9286477184766667},
#  'ISL2+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 2.5000708,
#   'std_sigma': 2.4489682,
#   'frac_sigma_below_1': 0.25,
#   'frac_sigma_below_2': 0.5,
#   'spearman_delta': -0.0007321954655986639,
#   'spearman_delta_de': 0.6766917293233082,
#   'pearson_delta': 0.15976261950349727,
#   'pearson_delta_de': 0.9365805100867642,
#   'fold_change_gap_all': 0.10181377,
#   'spearman_delta_top200_hvg': 0.24536563414085355,
#   'spearman_top200_hvg': 0.9707942698567466,
#   'pearson_delta_top200_hvg': 0.15362119846723127,
#   'pearson_top200_hvg': 0.9724943761734405},
#  'JUN+CEBPB': {'spearman_delta': 0.13764741542997472,
#   'spearman_delta_de': 0.5428571428571428,
#   'pearson_delta': 0.6013797781500255,
#   'pearson_delta_de': 0.4191324958892706,
#   'fold_change_gap_all': 4.0544443,
#   'fold_change_gap_upreg_3': 69.603195,
#   'fold_change_gap_upreg_10': 218.81848,
#   'spearman_delta_top200_hvg': 0.7702692567314184,
#   'spearman_top200_hvg': 0.8783992775818441,
#   'pearson_delta_top200_hvg': 0.7779479331355804,
#   'pearson_top200_hvg': 0.9342021186122025},
#  'KLF1+COL2A1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.94387895,
#   'std_sigma': 0.48007697,
#   'frac_sigma_below_1': 0.55,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': 0.04752040223371981,
#   'spearman_delta_de': 0.8872180451127819,
#   'pearson_delta': 0.24577811428161023,
#   'pearson_delta_de': 0.9656124818733666,
#   'fold_change_gap_all': 0.23955986,
#   'fold_change_gap_upreg_3': 3.2772446,
#   'fold_change_gap_upreg_10': 7.219694,
#   'spearman_delta_top200_hvg': 0.3087752193804846,
#   'spearman_top200_hvg': 0.9244007066679968,
#   'pearson_delta_top200_hvg': 0.3048363886866479,
#   'pearson_top200_hvg': 0.9419282057235948},
#  'LYL1+CEBPB': {'frac_in_range': 1.0,
#   'mean_sigma': 0.8858966,
#   'std_sigma': 0.40401104,
#   'frac_sigma_below_1': 0.75,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.17265731528411077,
#   'spearman_delta_de': 0.9157894736842105,
#   'pearson_delta': 0.45392307037552343,
#   'pearson_delta_de': 0.9696703689565375,
#   'fold_change_gap_all': 5.554411,
#   'fold_change_gap_upreg_3': 404.57053,
#   'fold_change_gap_upreg_10': 1611.1461,
#   'spearman_delta_top200_hvg': 0.6495612390309758,
#   'spearman_top200_hvg': 0.9456176404410112,
#   'pearson_delta_top200_hvg': 0.6138186259848332,
#   'pearson_top200_hvg': 0.9674599373373912},
#  'LYL1+IER5L': {'frac_in_range': 1.0,
#   'mean_sigma': 0.6283216,
#   'std_sigma': 0.44318804,
#   'frac_sigma_below_1': 0.85,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.27504164269723846,
#   'spearman_delta_de': 0.9518796992481202,
#   'pearson_delta': 0.5247687184669831,
#   'pearson_delta_de': 0.9803786318735098,
#   'fold_change_gap_all': 0.15462117,
#   'fold_change_gap_upreg_3': 1.9557767,
#   'fold_change_gap_upreg_10': 3.4080982,
#   'spearman_delta_top200_hvg': 0.6623040576014401,
#   'spearman_top200_hvg': 0.9491952298807471,
#   'pearson_delta_top200_hvg': 0.6664841738850669,
#   'pearson_top200_hvg': 0.9704995895003246},
#  'MAP2K6+SPI1': {'frac_in_range': 1.0,
#   'mean_sigma': 1.430739,
#   'std_sigma': 1.6971831,
#   'frac_sigma_below_1': 0.5882352941176471,
#   'frac_sigma_below_2': 0.8235294117647058,
#   'spearman_delta': -0.05064810467969117,
#   'spearman_delta_de': 0.9293233082706768,
#   'pearson_delta': 0.2426192507950376,
#   'pearson_delta_de': 0.9481339627559808,
#   'fold_change_gap_all': 0.14266206,
#   'fold_change_gap_upreg_3': 2.7044759,
#   'spearman_delta_top200_hvg': 0.46154503862596574,
#   'spearman_top200_hvg': 0.952196804920123,
#   'pearson_delta_top200_hvg': 0.422777822856878,
#   'pearson_top200_hvg': 0.9749387887195229},
#  'MAP7D1+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.6040027,
#   'std_sigma': 0.0,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': -0.059165728800635746,
#   'spearman_delta_de': 0.2421052631578947,
#   'pearson_delta': 0.05240469495040576,
#   'pearson_delta_de': 0.9885569719917254,
#   'fold_change_gap_all': 0.11794942,
#   'fold_change_gap_upreg_3': 0.71382093,
#   'spearman_delta_top200_hvg': -0.04791119777994451,
#   'spearman_top200_hvg': 0.9741288532213306,
#   'pearson_delta_top200_hvg': -0.06747523024510324,
#   'pearson_top200_hvg': 0.9707205889165099},
#  'MAPK1+PRTG': {'frac_in_range': 1.0,
#   'mean_sigma': 0.65209186,
#   'std_sigma': 0.36038703,
#   'frac_sigma_below_1': 0.8,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.07571492946299324,
#   'spearman_delta_de': 0.8526315789473683,
#   'pearson_delta': 0.34262294540955546,
#   'pearson_delta_de': 0.94929106245829,
#   'fold_change_gap_all': 0.59501725,
#   'fold_change_gap_upreg_3': 44.789047,
#   'fold_change_gap_upreg_10': 133.07965,
#   'spearman_delta_top200_hvg': 0.45371484287107183,
#   'spearman_top200_hvg': 0.941945548638716,
#   'pearson_delta_top200_hvg': 0.4158029481078468,
#   'pearson_top200_hvg': 0.9592328729124083},
#  'NCL+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.14709167,
#   'std_sigma': 0.0,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': -0.0443084933150206,
#   'spearman_delta_de': 0.6676691729323309,
#   'pearson_delta': 0.26962370807555813,
#   'pearson_delta_de': 0.9994107047229818,
#   'fold_change_gap_all': 0.10723261,
#   'spearman_delta_top200_hvg': 0.374551863796595,
#   'spearman_top200_hvg': 0.9710147753693844,
#   'pearson_delta_top200_hvg': 0.34564623586802723,
#   'pearson_top200_hvg': 0.9764265175248193},
#  'PLK4+STIL': {'spearman_delta': 0.07228638248544844,
#   'spearman_delta_de': 0.2796992481203007,
#   'pearson_delta': 0.4729526222802974,
#   'pearson_delta_de': 0.1558213652180521,
#   'fold_change_gap_all': 0.12161627,
#   'fold_change_gap_upreg_3': 0.097596645,
#   'spearman_delta_top200_hvg': 0.5864801620040502,
#   'spearman_top200_hvg': 0.9744599769219829,
#   'pearson_delta_top200_hvg': 0.6072968555043299,
#   'pearson_top200_hvg': 0.9786765300196404},
#  'PLK4+ctrl': {'spearman_delta': -0.021988497999855697,
#   'spearman_delta_de': 0.46917293233082696,
#   'pearson_delta': 0.41343671229750034,
#   'pearson_delta_de': 0.2684802398807242,
#   'fold_change_gap_all': 0.09925151,
#   'spearman_delta_top200_hvg': 0.636020400510013,
#   'spearman_top200_hvg': 0.978765836183162,
#   'pearson_delta_top200_hvg': 0.6453756401409728,
#   'pearson_top200_hvg': 0.9823277462319527},
#  'POU3F2+CBFA2T3': {'frac_in_range': 1.0,
#   'mean_sigma': 0.88970786,
#   'std_sigma': 1.426082,
#   'frac_sigma_below_1': 0.8125,
#   'frac_sigma_below_2': 0.9375,
#   'spearman_delta': 0.17888812490944292,
#   'spearman_delta_de': 0.9774436090225563,
#   'pearson_delta': 0.4699927824986117,
#   'pearson_delta_de': 0.9919429183605702,
#   'fold_change_gap_all': 0.13779446,
#   'fold_change_gap_upreg_3': 2.4516907,
#   'fold_change_gap_upreg_10': 2.4516907,
#   'spearman_delta_top200_hvg': 0.563627090677267,
#   'spearman_top200_hvg': 0.9533799420160958,
#   'pearson_delta_top200_hvg': 0.5723767265514862,
#   'pearson_top200_hvg': 0.9716938735578229},
#  'POU3F2+FOXL2': {'frac_in_range': 1.0,
#   'mean_sigma': 0.72696495,
#   'std_sigma': 0.37353373,
#   'frac_sigma_below_1': 0.8,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.20936113471383055,
#   'spearman_delta_de': 0.9864661654135337,
#   'pearson_delta': 0.479107195606319,
#   'pearson_delta_de': 0.9781252757735078,
#   'fold_change_gap_all': 0.19423886,
#   'fold_change_gap_upreg_3': 1.6565468,
#   'fold_change_gap_upreg_10': 3.3922129,
#   'spearman_delta_top200_hvg': 0.6145743643591091,
#   'spearman_top200_hvg': 0.922689567239181,
#   'pearson_delta_top200_hvg': 0.6079158152389371,
#   'pearson_top200_hvg': 0.9569190201358039},
#  'POU3F2+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.793676,
#   'std_sigma': 1.5082178,
#   'frac_sigma_below_1': 0.9411764705882353,
#   'frac_sigma_below_2': 0.9411764705882353,
#   'spearman_delta': 0.04866970592475067,
#   'spearman_delta_de': 0.9894736842105262,
#   'pearson_delta': 0.3479183560718561,
#   'pearson_delta_de': 0.9930716906961056,
#   'fold_change_gap_all': 0.10238292,
#   'fold_change_gap_upreg_3': 1.8047485,
#   'fold_change_gap_upreg_10': 1.8047485,
#   'spearman_delta_top200_hvg': 0.4836165904147604,
#   'spearman_top200_hvg': 0.9687917197929949,
#   'pearson_delta_top200_hvg': 0.44006531574328067,
#   'pearson_top200_hvg': 0.9777127764459081},
#  'PTPN1+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.8388642,
#   'std_sigma': 0.60169375,
#   'frac_sigma_below_1': 0.65,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': 0.023813298637649673,
#   'spearman_delta_de': 0.9774436090225563,
#   'pearson_delta': 0.3793889904376524,
# ...
#   'spearman_delta': 0.0971984920717325,
#   'spearman_delta_de': 0.9684210526315788,
#   'pearson_delta': 0.5397348329244395,
#   'pearson_delta_de': 0.9768845646573203,
#   'fold_change_gap_all': 0.1498579,
#   'fold_change_gap_upreg_3': 0.4249091,
#   'fold_change_gap_upreg_10': 0.053396225,
#   'spearman_delta_top200_hvg': 0.7678856971424287,
#   'spearman_top200_hvg': 0.9674337986327083,
#   'pearson_delta_top200_hvg': 0.7144782638192487,
#   'pearson_top200_hvg': 0.9738980583738787},
#  'SAMD1+ZBTB1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.44534463,
#   'std_sigma': 0.43161848,
#   'frac_sigma_below_1': 0.9411764705882353,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.1429432538909223,
#   'spearman_delta_de': 0.9729323308270676,
#   'pearson_delta': 0.6021142029732636,
#   'pearson_delta_de': 0.9873129886457713,
#   'fold_change_gap_all': 0.22157484,
#   'fold_change_gap_upreg_3': 1.1390369,
#   'fold_change_gap_upreg_10': 1.5228148,
#   'spearman_delta_top200_hvg': 0.8294232355808896,
#   'spearman_top200_hvg': 0.966513525280772,
#   'pearson_delta_top200_hvg': 0.8433720534647301,
#   'pearson_top200_hvg': 0.9805949768086821},
#  'SET+CEBPE': {'frac_in_range': 1.0,
#   'mean_sigma': 0.5452392,
#   'std_sigma': 0.4697271,
#   'frac_sigma_below_1': 0.85,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.2918989473856542,
#   'spearman_delta_de': 0.8857142857142858,
#   'pearson_delta': 0.4709959360451779,
#   'pearson_delta_de': 0.9724515550576013,
#   'fold_change_gap_all': 0.2818424,
#   'fold_change_gap_upreg_3': 4.430626,
#   'fold_change_gap_upreg_10': 17.029503,
#   'spearman_delta_top200_hvg': 0.6114587864696618,
#   'spearman_top200_hvg': 0.7728868221705544,
#   'pearson_delta_top200_hvg': 0.5584157290517723,
#   'pearson_top200_hvg': 0.8914365326545701},
#  'SET+KLF1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.9698164,
#   'std_sigma': 0.4262654,
#   'frac_sigma_below_1': 0.55,
#   'frac_sigma_below_2': 0.9,
#   'spearman_delta': 0.0604300099111545,
#   'spearman_delta_de': 0.9293233082706768,
#   'pearson_delta': 0.3601465471601489,
#   'pearson_delta_de': 0.9683672341068779,
#   'fold_change_gap_all': 0.14700918,
#   'fold_change_gap_upreg_3': 1.2332814,
#   'spearman_delta_top200_hvg': 0.4691067276681918,
#   'spearman_top200_hvg': 0.9541303532588317,
#   'pearson_delta_top200_hvg': 0.5412363962093776,
#   'pearson_top200_hvg': 0.9633432606694643},
#  'SET+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 1.0390468,
#   'std_sigma': 0.5520972,
#   'frac_sigma_below_1': 0.65,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': 0.09018783776231869,
#   'spearman_delta_de': 0.9428571428571428,
#   'pearson_delta': 0.2976321577415058,
#   'pearson_delta_de': 0.9593152907296653,
#   'fold_change_gap_all': 0.31446865,
#   'fold_change_gap_upreg_3': 8.003673,
#   'fold_change_gap_upreg_10': 18.325325,
#   'spearman_delta_top200_hvg': 0.5108947723693094,
#   'spearman_top200_hvg': 0.9119942998574966,
#   'pearson_delta_top200_hvg': 0.38449333411532943,
#   'pearson_top200_hvg': 0.9516245007581094},
#  'SPI1+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 1.8995657,
#   'std_sigma': 2.2962263,
#   'frac_sigma_below_1': 0.4117647058823529,
#   'frac_sigma_below_2': 0.8823529411764706,
#   'spearman_delta': 0.07625624924715697,
#   'spearman_delta_de': 0.8992481203007519,
#   'pearson_delta': 0.49191568054430745,
#   'pearson_delta_de': 0.9587516188199731,
#   'fold_change_gap_all': 0.5990362,
#   'fold_change_gap_upreg_3': 7.681978,
#   'fold_change_gap_upreg_10': 36.587357,
#   'spearman_delta_top200_hvg': 0.640555013875347,
#   'spearman_top200_hvg': 0.8539611692647302,
#   'pearson_delta_top200_hvg': 0.6672510938050075,
#   'pearson_top200_hvg': 0.9286851424743606},
#  'TBX3+TBX2': {'frac_in_range': 1.0,
#   'mean_sigma': 0.67026806,
#   'std_sigma': 0.47408763,
#   'frac_sigma_below_1': 0.8,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.1329544754909087,
#   'spearman_delta_de': 0.9654135338345864,
#   'pearson_delta': 0.6256329210611536,
#   'pearson_delta_de': 0.9667002153641197,
#   'fold_change_gap_all': 0.12586063,
#   'fold_change_gap_upreg_3': 1.6190494,
#   'fold_change_gap_upreg_10': 1.997118,
#   'spearman_delta_top200_hvg': 0.6482532063301583,
#   'spearman_top200_hvg': 0.9643666091652293,
#   'pearson_delta_top200_hvg': 0.7493879022238107,
#   'pearson_top200_hvg': 0.9715695898577792},
#  'UBASH3B+PTPN12': {'frac_in_range': 1.0,
#   'mean_sigma': 0.9874665,
#   'std_sigma': 0.66507864,
#   'frac_sigma_below_1': 0.6842105263157895,
#   'frac_sigma_below_2': 0.9473684210526316,
#   'spearman_delta': -0.018144285114375446,
#   'spearman_delta_de': 0.9293233082706768,
#   'pearson_delta': 0.4345525257353125,
#   'pearson_delta_de': 0.9346752076963194,
#   'fold_change_gap_all': 0.16167162,
#   'fold_change_gap_upreg_3': 1.5608965,
#   'fold_change_gap_upreg_10': 1.3169556,
#   'spearman_delta_top200_hvg': 0.6235925898147455,
#   'spearman_top200_hvg': 0.9567197767644027,
#   'pearson_delta_top200_hvg': 0.6267437511043926,
#   'pearson_top200_hvg': 0.9622813199051906},
#  'UBASH3B+PTPN9': {'frac_in_range': 1.0,
#   'mean_sigma': 0.9645996,
#   'std_sigma': 1.4184823,
#   'frac_sigma_below_1': 0.7894736842105263,
#   'frac_sigma_below_2': 0.9473684210526316,
#   'spearman_delta': 0.049008028777430275,
#   'spearman_delta_de': 0.9789473684210527,
#   'pearson_delta': 0.51741259159624,
#   'pearson_delta_de': 0.9726289496618016,
#   'fold_change_gap_all': 0.123925604,
#   'fold_change_gap_upreg_3': 0.9525337,
#   'spearman_delta_top200_hvg': 0.7410815270381761,
#   'spearman_top200_hvg': 0.9652167423749056,
#   'pearson_delta_top200_hvg': 0.7391226532202795,
#   'pearson_top200_hvg': 0.9754913124860219},
#  'ZBTB10+DLX2': {'spearman_delta': 0.09822024055094276,
#   'spearman_delta_de': 0.4857142857142857,
#   'pearson_delta': 0.46958108047556074,
#   'pearson_delta_de': 0.3177047876257847,
#   'fold_change_gap_all': 0.8036368,
#   'fold_change_gap_upreg_3': 6.2606936,
#   'fold_change_gap_upreg_10': 21.228853,
#   'spearman_delta_top200_hvg': 0.656905422635566,
#   'spearman_top200_hvg': 0.7945578435435888,
#   'pearson_delta_top200_hvg': 0.6408329542719747,
#   'pearson_top200_hvg': 0.8814246154953563},
#  'ZBTB10+ELMSAN1': {'frac_in_range': 1.0,
#   'mean_sigma': 1.0481727,
#   'std_sigma': 0.8402927,
#   'frac_sigma_below_1': 0.7058823529411764,
#   'frac_sigma_below_2': 0.8823529411764706,
#   'spearman_delta': 0.16027676918758432,
#   'spearman_delta_de': 0.9819548872180449,
#   'pearson_delta': 0.4012456833035357,
#   'pearson_delta_de': 0.9682603259671634,
#   'fold_change_gap_all': 0.25507945,
#   'fold_change_gap_upreg_3': 2.5136433,
#   'spearman_delta_top200_hvg': 0.5027480687017176,
#   'spearman_top200_hvg': 0.8955328883222082,
#   'pearson_delta_top200_hvg': 0.495632169418592,
#   'pearson_top200_hvg': 0.9337879049354437},
#  'ZBTB10+PTPN12': {'frac_in_range': 1.0,
#   'mean_sigma': 1.9402913,
#   'std_sigma': 2.035823,
#   'frac_sigma_below_1': 0.5294117647058824,
#   'frac_sigma_below_2': 0.6470588235294117,
#   'spearman_delta': 0.1346303713975909,
#   'spearman_delta_de': 0.9624060150375938,
#   'pearson_delta': 0.44813359264085617,
#   'pearson_delta_de': 0.9677407800855281,
#   'fold_change_gap_all': 0.2447533,
#   'fold_change_gap_upreg_3': 29.713896,
#   'fold_change_gap_upreg_10': 29.713896,
#   'spearman_delta_top200_hvg': 0.5601755043876098,
#   'spearman_top200_hvg': 0.9331759293392727,
#   'pearson_delta_top200_hvg': 0.554261447242557,
#   'pearson_top200_hvg': 0.9616632353893798},
#  'ZBTB10+SNAI1': {'spearman_delta': 0.0928351266663622,
#   'spearman_delta_de': 0.5037593984962406,
#   'pearson_delta': 0.44517957299760086,
#   'pearson_delta_de': 0.4679542963945506,
#   'fold_change_gap_all': 0.4125853,
#   'fold_change_gap_upreg_3': 2.7758474,
#   'fold_change_gap_upreg_10': 7.3179655,
#   'spearman_delta_top200_hvg': 0.575348383709593,
#   'spearman_top200_hvg': 0.8203768934840027,
#   'pearson_delta_top200_hvg': 0.531124081818962,
#   'pearson_top200_hvg': 0.8844792224861937},
#  'ZBTB10+ctrl': {'frac_in_range': 1.0,
#   'mean_sigma': 0.9413277,
#   'std_sigma': 0.74882185,
#   'frac_sigma_below_1': 0.7,
#   'frac_sigma_below_2': 0.8,
#   'spearman_delta': 0.14564034024754133,
#   'spearman_delta_de': 0.9894736842105262,
#   'pearson_delta': 0.4292372273036752,
#   'pearson_delta_de': 0.9934352881997298,
#   'fold_change_gap_all': 0.18768993,
#   'fold_change_gap_upreg_3': 2.2422721,
#   'spearman_delta_top200_hvg': 0.5343553588839722,
#   'spearman_top200_hvg': 0.910243347425005,
#   'pearson_delta_top200_hvg': 0.5167626723041517,
#   'pearson_top200_hvg': 0.9463675978774354},
#  'ZC3HAV1+CEBPE': {'frac_in_range': 1.0,
#   'mean_sigma': 0.53270227,
#   'std_sigma': 0.47672078,
#   'frac_sigma_below_1': 0.9473684210526316,
#   'frac_sigma_below_2': 0.9473684210526316,
#   'spearman_delta': 0.16300049547276563,
#   'spearman_delta_de': 0.9233082706766916,
#   'pearson_delta': 0.5153854448718878,
#   'pearson_delta_de': 0.9627254289762318,
#   'fold_change_gap_all': 0.35388938,
#   'fold_change_gap_upreg_3': 21.389408,
#   'fold_change_gap_upreg_10': 34.6146,
#   'spearman_delta_top200_hvg': 0.6804665116627916,
#   'spearman_top200_hvg': 0.8255126378159455,
#   'pearson_delta_top200_hvg': 0.6440698648565297,
#   'pearson_top200_hvg': 0.8993777155439101},
#  'ZC3HAV1+HOXC13': {'frac_in_range': 1.0,
#   'mean_sigma': 0.46335536,
#   'std_sigma': 0.37810686,
#   'frac_sigma_below_1': 0.9,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.19763352364645573,
#   'spearman_delta_de': 0.9864661654135337,
#   'pearson_delta': 0.4609482133392491,
#   'pearson_delta_de': 0.9885446354720324,
#   'fold_change_gap_all': 0.14654037,
#   'spearman_delta_top200_hvg': 0.6044521113027826,
#   'spearman_top200_hvg': 0.9552898822470564,
#   'pearson_delta_top200_hvg': 0.560810052923682,
#   'pearson_top200_hvg': 0.9667290078848514},
#  'ZNF318+FOXL2': {'frac_in_range': 1.0,
#   'mean_sigma': 0.680418,
#   'std_sigma': 0.7312062,
#   'frac_sigma_below_1': 0.9230769230769231,
#   'frac_sigma_below_2': 0.9230769230769231,
#   'spearman_delta': 0.10309468751639901,
#   'spearman_delta_de': 0.9804511278195487,
#   'pearson_delta': 0.45497958783748466,
#   'pearson_delta_de': 0.9957412983393665,
#   'fold_change_gap_all': 0.09917421,
#   'fold_change_gap_upreg_3': 0.44810295,
#   'spearman_delta_top200_hvg': 0.672583814595365,
#   'spearman_top200_hvg': 0.9773344333608341,
#   'pearson_delta_top200_hvg': 0.6622117594101674,
#   'pearson_top200_hvg': 0.9858422776364835},
#  'ctrl+CDKN1A': {'frac_in_range': 1.0,
#   'mean_sigma': 0.5297106,
#   'std_sigma': 0.24527074,
#   'frac_sigma_below_1': 0.875,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.06883677686544318,
#   'spearman_delta_de': 0.9458646616541352,
#   'pearson_delta': 0.4312460464562542,
#   'pearson_delta_de': 0.967488521952153,
#   'fold_change_gap_all': 0.26780716,
#   'fold_change_gap_upreg_3': 20.418726,
#   'fold_change_gap_upreg_10': 39.790276,
#   'spearman_delta_top200_hvg': 0.6142668566714169,
#   'spearman_top200_hvg': 0.9601110027750694,
#   'pearson_delta_top200_hvg': 0.6025304840115002,
#   'pearson_top200_hvg': 0.973007117153961},
#  'ctrl+CDKN1B': {'spearman_delta': 0.03318560312578567,
#   'spearman_delta_de': 0.23909774436090225,
#   'pearson_delta': 0.43634131934625026,
#   'pearson_delta_de': 0.06835232364893509,
#   'fold_change_gap_all': 0.10823936,
#   'fold_change_gap_upreg_3': 0.8253521,
#   'spearman_delta_top200_hvg': 0.6599489987249683,
#   'spearman_top200_hvg': 0.9750468761719044,
#   'pearson_delta_top200_hvg': 0.6344291947202192,
#   'pearson_top200_hvg': 0.9830172494738153},
#  'ctrl+CEBPB': {'frac_in_range': 1.0,
#   'mean_sigma': 0.8652002,
#   'std_sigma': 0.43827966,
#   'frac_sigma_below_1': 0.7,
#   'frac_sigma_below_2': 0.95,
#   'spearman_delta': 0.1977979791874692,
#   'spearman_delta_de': 0.8526315789473683,
#   'pearson_delta': 0.45885819806872485,
#   'pearson_delta_de': 0.9244437460079447,
#   'fold_change_gap_all': 4.5403028,
#   'fold_change_gap_upreg_3': 79.271614,
#   'fold_change_gap_upreg_10': 281.09186,
#   'spearman_delta_top200_hvg': 0.6144633615840397,
#   'spearman_top200_hvg': 0.8550453761344033,
#   'pearson_delta_top200_hvg': 0.6051729946425544,
#   'pearson_top200_hvg': 0.9282137794647688},
#  'ctrl+COL2A1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.84040666,
#   'std_sigma': 0.34550846,
#   'frac_sigma_below_1': 0.736842105263158,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.08844165466409241,
#   'spearman_delta_de': 0.8436090225563909,
#   'pearson_delta': 0.2602905821034664,
#   'pearson_delta_de': 0.8692299659176486,
#   'fold_change_gap_all': 0.20768031,
#   'fold_change_gap_upreg_3': 2.8749416,
#   'spearman_delta_top200_hvg': 0.35213830345758645,
#   'spearman_top200_hvg': 0.9213875346883672,
#   'pearson_delta_top200_hvg': 0.3314726669341532,
#   'pearson_top200_hvg': 0.9451646312569135},
#  'ctrl+FOXL2': {'frac_in_range': 1.0,
#   'mean_sigma': 0.53854185,
#   'std_sigma': 0.51675093,
#   'frac_sigma_below_1': 0.7692307692307692,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.1512852657280304,
#   'spearman_delta_de': 0.9924812030075187,
#   'pearson_delta': 0.422533066211963,
#   'pearson_delta_de': 0.9877852185431654,
#   'fold_change_gap_all': 0.10941365,
#   'fold_change_gap_upreg_3': 0.2573614,
#   'spearman_delta_top200_hvg': 0.5755688892222307,
#   'spearman_top200_hvg': 0.9607125178129454,
#   'pearson_delta_top200_hvg': 0.5306015464069604,
#   'pearson_top200_hvg': 0.9768112315469348},
#  'ctrl+ISL2': {'frac_in_range': 1.0,
#   'mean_sigma': 0.69038326,
#   'std_sigma': 0.5544042,
#   'frac_sigma_below_1': 0.5,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': -0.010768921304017888,
#   'spearman_delta_de': 0.4947368421052631,
#   'pearson_delta': 0.14508550406975887,
#   'pearson_delta_de': 0.9649133601574984,
#   'fold_change_gap_all': 0.10541183,
#   'spearman_delta_top200_hvg': 0.23818645466136656,
#   'spearman_top200_hvg': 0.9701792544813621,
#   'pearson_delta_top200_hvg': 0.15470956401256042,
#   'pearson_top200_hvg': 0.971185079003114},
#  'ctrl+MAP7D1': {'frac_in_range': 1.0,
#   'mean_sigma': 1.5909371,
#   'std_sigma': 2.0793417,
#   'frac_sigma_below_1': 0.8,
#   'frac_sigma_below_2': 0.8,
#   'spearman_delta': -0.081605985268963,
#   'spearman_delta_de': 0.7684210526315788,
#   'pearson_delta': -0.010609052670167807,
#   'pearson_delta_de': 0.9955535272638815,
#   'fold_change_gap_all': 0.124169536,
#   'fold_change_gap_upreg_3': 0.771276,
#   'spearman_delta_top200_hvg': -0.19060526513162834,
#   'spearman_top200_hvg': 0.9739368484212106,
#   'pearson_delta_top200_hvg': -0.18629690140965177,
#   'pearson_top200_hvg': 0.9708175217337826},
#  'ctrl+PTPN12': {'frac_in_range': 1.0,
#   'mean_sigma': 2.2322338,
#   'std_sigma': 2.0835118,
#   'frac_sigma_below_1': 0.4285714285714286,
#   'frac_sigma_below_2': 0.5714285714285714,
#   'spearman_delta': -0.13523569488734336,
#   'spearman_delta_de': 0.9443609022556391,
#   'pearson_delta': 0.20281310701399505,
#   'pearson_delta_de': 0.9786386508331685,
#   'fold_change_gap_all': 0.12485527,
#   'spearman_delta_top200_hvg': 0.33572039300982526,
#   'spearman_top200_hvg': 0.9592090899307246,
#   'pearson_delta_top200_hvg': 0.27306739982205575,
#   'pearson_top200_hvg': 0.969268414443476},
#  'ctrl+SET': {'frac_in_range': 1.0,
#   'mean_sigma': 0.9261614,
#   'std_sigma': 0.5524176,
#   'frac_sigma_below_1': 0.75,
#   'frac_sigma_below_2': 0.9,
#   'spearman_delta': 0.0518661163352179,
#   'spearman_delta_de': 0.9654135338345864,
#   'pearson_delta': 0.2913138610320968,
#   'pearson_delta_de': 0.9533080082848978,
#   'fold_change_gap_all': 0.329734,
#   'fold_change_gap_upreg_3': 8.584425,
#   'fold_change_gap_upreg_10': 14.894555,
#   'spearman_delta_top200_hvg': 0.4922853071326784,
#   'spearman_top200_hvg': 0.9077686942173556,
#   'pearson_delta_top200_hvg': 0.34839268890743225,
#   'pearson_top200_hvg': 0.9461268382293936},
#  'ctrl+SPI1': {'frac_in_range': 1.0,
#   'mean_sigma': 0.74939966,
#   'std_sigma': 0.37902424,
#   'frac_sigma_below_1': 0.8,
#   'frac_sigma_below_2': 1.0,
#   'spearman_delta': 0.1561511025108511,
#   'spearman_delta_de': 0.8887218045112781,
#   'pearson_delta': 0.47412822017509526,
#   'pearson_delta_de': 0.9408087124050857,
#   'fold_change_gap_all': 0.21115178,
#   'fold_change_gap_upreg_3': 2.747097,
#   'fold_change_gap_upreg_10': 5.9820147,
#   'spearman_delta_top200_hvg': 0.6316987924698118,
#   'spearman_top200_hvg': 0.9124608115202881,
#   'pearson_delta_top200_hvg': 0.6479946189361758,
#   'pearson_top200_hvg': 0.9597121721921028}}

# %%
analyze(list(test_pert_res.keys())[i])
i+=1
# Out:
# AHR+KLF1
# combo_seen2
# mse_de: 0.2098773
# mae_de: 0.3267787
# spearman_de: 0.7969924812030074
# pearson_de: 0.9219436194773751
# r2_de: 0.6219090845186681
# 100.0% of genes in the range
# there are 0 genes with zero stds, removing them for calculation...
# average sigma: 0.8931963
# frac of below 1 sigma: 0.8
# frac of below 2 sigma: 0.9
# above 2 sigma genes:['HBA1' 'LGALS1']

# %%
analyze(list(test_pert_res.keys())[i])
i+=1
# Out:
# ARID1A+ctrl
# unseen_single
# mse_de: 0.2253922
# mae_de: 0.41007867
# spearman_de: 0.9151289674603723
# pearson_de: 0.9333854539097096
# r2_de: 0.7934088507702576
# 70.0% of genes in the range
# not in range genes:['TUBB2B' 'SEMA6B' 'TEX30' 'KCNH2' 'DDX21' 'PRDX1']
# there are 6 genes with zero stds, removing them for calculation...
# average sigma: 1.14268
# frac of below 1 sigma: 0.5714285714285714
# frac of below 2 sigma: 0.8571428571428572
# above 2 sigma genes:['TMSB10' 'VIM']

# %%
analyze(list(test_pert_res.keys())[i])
i+=1
# Out:
# BCL2L11+BAK1
# combo_seen1
# mse_de: 0.028922627
# mae_de: 0.16328989
# spearman_de: 0.37796447300922725
# pearson_de: 0.9864382692780493
# r2_de: -1.2911260202751471
# 5.0% of genes in the range
# not in range genes:['ECM1' 'IKZF2' 'BISPR' 'NOX5' 'LINC01305' 'IFI30' 'CTSL' 'ABTB1' 'PTH2'
#  'RP11-212I21.4' 'TESK2' 'LPXN' 'POLD4' 'RASGRP3' 'ICOSLG' 'EPB42'
#  'RP11-1398P2.1' 'RP11-355B11.2' 'PRRT2']
# there are 19 genes with zero stds, removing them for calculation...
# average sigma: 0.84067315
# frac of below 1 sigma: 1.0
# frac of below 2 sigma: 1.0
# above 2 sigma genes:[]

# %%
analyze(list(test_pert_res.keys())[i])
i+=1
# Out:
# BCL2L11+TGFBR2
# combo_seen1
# mse_de: 0.055616103
# mae_de: 0.22110891
# spearman_de: 0.9841579505977515
# pearson_de: 0.9765927375871464
# r2_de: 0.9023527544836009
# 80.0% of genes in the range
# not in range genes:['TMSB10' 'IRF7' 'MT1G' 'LCA5']
# there are 4 genes with zero stds, removing them for calculation...
# average sigma: 0.5360814
# frac of below 1 sigma: 0.9375
# frac of below 2 sigma: 1.0
# above 2 sigma genes:[]

# %%
analyze(list(test_pert_res.keys())[i])
i+=1
# Out:
# BCL2L11+ctrl
# unseen_single
# mse_de: 0.023406755
# mae_de: 0.14449443
# spearman_de: 0.5209880722517277
# pearson_de: 0.9819634019972169
# r2_de: 0.8150883400623465
# 10.0% of genes in the range
# not in range genes:['BCL2L11' 'GYPB' 'SLC2A6' 'MCEMP1' 'LOXL2' 'ACSL5' 'NFASC' 'CTB-13F3.1'
#  'RP3-406P24.3' 'RP11-55K13.1' 'RP5-1024G6.5' 'CLNK' 'EWSAT1' 'SLC15A2'
#  'RP11-421M1.8' 'C1orf228' 'MMP9' 'OTUD1']
# there are 18 genes with zero stds, removing them for calculation...
# average sigma: 0.39766482
# frac of below 1 sigma: 1.0
# frac of below 2 sigma: 1.0
# above 2 sigma genes:[]

# %%
analyze(list(test_pert_res.keys())[i])
i+=1
# Out:
# BCORL1+ctrl
# unseen_single
# mse_de: 0.1045298
# mae_de: 0.26133913
# spearman_de: 0.9259582676757693
# pearson_de: 0.9626769366133556
# r2_de: 0.88615513999374
# 60.0% of genes in the range
# not in range genes:['KRT18' 'GAL' 'FEV' 'KRT8' 'RP11-160O5.1' 'ARHGEF26' 'TP53INP2' 'SEMA3B']
# there are 8 genes with zero stds, removing them for calculation...
# average sigma: 0.89024395
# frac of below 1 sigma: 0.5
# frac of below 2 sigma: 1.0
# above 2 sigma genes:[]

# %%
adata.var
# Out:
#                     gene_name       mean        std          cv      fano  \
# gene_id
# ENSG00000239945  RP11-34P13.8   0.000085   0.009242  108.196003  0.999925
# ENSG00000223764   RP11-54O7.3   0.007912   0.091792   11.602000  1.064974
# ENSG00000187634        SAMD11   0.021280   0.167784    7.884765  1.322939
# ENSG00000187642         PERM1   0.000149   0.012225   81.785870  0.999861
# ENSG00000188290          HES4   0.349986   0.699442    1.998485  1.397825
# ...                       ...        ...        ...         ...       ...
# ENSG00000198786        MT-ND5   8.054528   4.540736    0.563749  2.559837
# ENSG00000198695        MT-ND6   4.522379   4.105639    0.907849  3.727301
# ENSG00000198727        MT-CYB  42.826667  19.762921    0.461463  9.119856
# ENSG00000273554    AC136616.1   0.001505   0.039858   26.475197  1.055243
# ENSG00000278633    AC023491.2   0.000011   0.003268  306.035946  1.000000
#
#                  in_matrix  highly_variable     means  dispersions  \
# gene_id
# ENSG00000239945       True             True  0.000145     0.837956
# ENSG00000223764       True             True  0.009702     0.547203
# ENSG00000187634       True             True  0.028434     0.937234
# ENSG00000187642       True             True  0.000212     0.538653
# ENSG00000188290       True             True  0.285414     0.483443
# ...                    ...              ...       ...          ...
# ENSG00000198786       True             True  2.207500     0.953207
# ENSG00000198695       True             True  1.666242     1.267892
# ENSG00000198727       True             True  3.775564     1.874488
# ENSG00000273554       True             True  0.001598     0.427236
# ENSG00000278633       True             True  0.000026     0.847273
#
#                  dispersions_norm  gene_symbols
# gene_id
# ENSG00000239945          1.663704  RP11-34P13.8
# ENSG00000223764          0.776219   RP11-54O7.3
# ENSG00000187634          1.966738        SAMD11
# ENSG00000187642          0.750123         PERM1
# ENSG00000188290          0.663183          HES4
# ...                           ...           ...
# ENSG00000198786          0.605198        MT-ND5
# ENSG00000198695          4.019786        MT-ND6
# ENSG00000198727          0.820883        MT-CYB
# ENSG00000273554          0.410037    AC136616.1
# ENSG00000278633          1.692144    AC023491.2
#
# [5045 rows x 11 columns]

# %%
import scanpy as sc
import pandas as pd

def rank_genes_groups_by_cov(
    adata,
    groupby,
    control_group,
    covariate,
    pool_doses=False,
    n_genes=50,
    rankby_abs=True,
    key_added='rank_genes_groups_cov',
    return_dict=False,
):

    """
    Function that generates a list of differentially expressed genes computed
    separately for each covariate category, and using the respective control
    cells as reference.

    Usage example:

    rank_genes_groups_by_cov(
        adata,
        groupby='cov_product_dose',
        covariate_key='cell_type',
        control_group='Vehicle_0'
    )

    Parameters
    ----------
    adata : AnnData
        AnnData dataset
    groupby : str
        Obs column that defines the groups, should be
        cartesian product of covariate_perturbation_cont_var,
        it is important that this format is followed.
    control_group : str
        String that defines the control group in the groupby obs
    covariate : str
        Obs column that defines the main covariate by which we
        want to separate DEG computation (eg. cell type, species, etc.)
    n_genes : int (default: 50)
        Number of DEGs to include in the lists
    rankby_abs : bool (default: True)
        If True, rank genes by absolute values of the score, thus including
        top downregulated genes in the top N genes. If False, the ranking will
        have only upregulated genes at the top.
    key_added : str (default: 'rank_genes_groups_cov')
        Key used when adding the dictionary to adata.uns
    return_dict : str (default: False)
        Signals whether to return the dictionary or not

    Returns
    -------
    Adds the DEG dictionary to adata.uns

    If return_dict is True returns:
    gene_dict : dict
        Dictionary where groups are stored as keys, and the list of DEGs
        are the corresponding values

    """

    gene_dict = {}
    cov_categories = adata.obs[covariate].unique()
    for cov_cat in cov_categories:
        print(cov_cat)
        #name of the control group in the groupby obs column
        control_group_cov = '_'.join([cov_cat, control_group])

        #subset adata to cells belonging to a covariate category
        adata_cov = adata[adata.obs[covariate]==cov_cat]

        #compute DEGs
        sc.tl.rank_genes_groups(
            adata_cov,
            groupby=groupby,
            reference=control_group_cov,
            rankby_abs=rankby_abs,
            n_genes=n_genes
        )

        #add entries to dictionary of gene sets
        de_genes = pd.DataFrame(adata_cov.uns['rank_genes_groups']['names'])
        for group in de_genes:
            gene_dict[group] = de_genes[group].tolist()

    adata.uns[key_added] = gene_dict

    if return_dict:
        return gene_dict

# %%
rank_genes_groups_by_cov(adata, 
                         groupby='cov_drug_dose_name', 
                         covariate='cell_type', 
                         control_group='ctrl_1', 
                         n_genes=200,
                         key_added = 'rank_genes_groups_cov_top200')
# Out:
# A549
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# Trying to set attribute `.uns` of view, copying.
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:394: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:399: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:409: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:420: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(

# %%
rank_genes_groups_by_cov(adata, 
                         groupby='cov_drug_dose_name', 
                         covariate='cell_type', 
                         control_group='ctrl_1', 
                         n_genes=100,
                         key_added = 'rank_genes_groups_cov_top100')
# Out:
# A549
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# Trying to set attribute `.uns` of view, copying.

# %%
adata.write_h5ad('/dfs/project/perturb-gnn/datasets/Norman2019_hvg+perts_more_de.h5ad')

# %%
GIs = {
    'NEOMORPHIC': ['CBL+TGFBR2',
                  'KLF1+TGFBR2',
                  'MAP2K6+SPI1',
                  'SAMD1+TGFBR2',
                  'TGFBR2+CBARP',
                  'TGFBR2+ETS2',
                  'CBL+UBASH3A',
                  'CEBPE+KLF1',
                  'DUSP9+MAPK1',
                  'FOSB+PTPN12',
                  'PLK4+STIL',
                  'PTPN12+OSR2',
                  'ZC3HAV1+CEBPE'],
    'ADDITIVE': ['BPGM+SAMD1',
                'CEBPB+MAPK1',
                'CEBPE+OSR2',
                'DUSP9+PRTG',
                'FOSB+OSR2',
                'IRF1+SET',
                'MAP2K3+ELMSAN1',
                'MAP2K6+ELMSAN1',
                'POU3F2+FOXL2',
                'RHOXF2B+SET',
                'SAMD1+PTPN12',
                'SAMD1+UBASH3B',
                'SAMD1+ZBTB1',
                'SGK1+TBX2',
                'TBX3+TBX2',
                'ZBTB10+SNAI1'],
    'EPISTASIS': ['AHR+KLF1',
                 'MAPK1+TGFBR2',
                 'TGFBR2+IGDCC3',
                 'TGFBR2+PRTG',
                 'UBASH3B+OSR2',
                 'DUSP9+ETS2',
                 'KLF1+CEBPA',
                 'MAP2K6+IKZF3',
                 'ZC3HAV1+CEBPA'],
    'REDUNDANT': ['CDKN1C+CDKN1A',
                 'MAP2K3+MAP2K6',
                 'CEBPB+CEBPA',
                 'CEBPE+CEBPA',
                 'CEBPE+SPI1',
                 'ETS2+MAPK1',
                 'FOSB+CEBPE',
                 'FOXA3+FOXA1'],
    'POTENTIATION': ['CNN1+UBASH3A',
                    'ETS2+MAP7D1',
                    'FEV+CBFA2T3',
                    'FEV+ISL2',
                    'FEV+MAP7D1',
                    'PTPN12+UBASH3A'],
    'SYNERGY_SIMILAR_PHENO':['CBL+CNN1',
                            'CBL+PTPN12',
                            'CBL+PTPN9',
                            'CBL+UBASH3B',
                            'FOXA3+FOXL2',
                            'FOXA3+HOXB9',
                            'FOXL2+HOXB9',
                            'UBASH3B+CNN1',
                            'UBASH3B+PTPN12',
                            'UBASH3B+PTPN9',
                            'UBASH3B+ZBTB25'],
    'SYNERGY_DISSIMILAR_PHENO': ['AHR+FEV',
                                'DUSP9+SNAI1',
                                'FOXA1+FOXF1',
                                'FOXA1+FOXL2',
                                'FOXA1+HOXB9',
                                'FOXF1+FOXL2',
                                'FOXF1+HOXB9',
                                'FOXL2+MEIS1',
                                'IGDCC3+ZBTB25',
                                'POU3F2+CBFA2T3',
                                'PTPN12+ZBTB25',
                                'SNAI1+DLX2',
                                'SNAI1+UBASH3B'],
    'SUPPRESSOR': ['CEBPB+PTPN12',
                  'CEBPE+CNN1',
                  'CEBPE+PTPN12',
                  'CNN1+MAPK1',
                  'ETS2+CNN1',
                  'ETS2+IGDCC3',
                  'ETS2+PRTG',
                  'FOSB+UBASH3B',
                  'IGDCC3+MAPK1',
                  'LYL1+CEBPB',
                  'MAPK1+PRTG',
                  'PTPN12+SNAI1']
}

# %%
import pickle
pickle.dump(GIs, open('GIs.pkl', 'wb'))

# %%
GI_type2Score = {}
test_pert_list = list(test_pert_res.keys())
for GI_type, gi_list in GIs.items():
    intersect = np.intersect1d(gi_list, test_pert_list)
    if len(intersect) != 0:
        GI_type2Score[GI_type] = {}
        for metric in ['mse_de','mae_de','spearman_de','pearson_de']:
            GI_type2Score[GI_type][metric] = np.mean([test_pert_res[i][metric] for i in intersect])
        GI_type2Score[GI_type]['spearman_delta'] = np.mean([metrics_pert_delta[i]['spearman'] for i in intersect])
        GI_type2Score[GI_type]['pearson_delta'] = np.mean([metrics_pert_delta[i]['pearson'] for i in intersect])

# %%
GI_type2Score
# Out:
# {'NEOMORPHIC': {'mse_de': 0.12941988,
#   'mae_de': 0.2903899,
#   'spearman_de': 0.6574643750743108,
#   'pearson_de': 0.697350411647083,
#   'spearman_delta': 0.022592210321319722,
#   'pearson_delta': 0.34982917961411514},
#  'ADDITIVE': {'mse_de': 0.28212306,
#   'mae_de': 0.43237478,
#   'spearman_de': 0.7879227954680315,
#   'pearson_de': 0.8333688993592533,
#   'spearman_delta': 0.15960641444954182,
#   'pearson_delta': 0.5106381738818909},
#  'EPISTASIS': {'mse_de': 0.2625154,
#   'mae_de': 0.413961,
#   'spearman_de': 0.8300751879699246,
#   'pearson_de': 0.9206864497015774,
#   'spearman_delta': 0.1072512672293257,
#   'pearson_delta': 0.30971756784836724},
#  'REDUNDANT': {'mse_de': 0.31345636,
#   'mae_de': 0.4750586,
#   'spearman_de': 0.7026792879480943,
#   'pearson_de': 0.8941020217427124,
#   'spearman_delta': 0.21046216592541714,
#   'pearson_delta': 0.6227420958050749},
#  'POTENTIATION': {'mse_de': 0.38493425,
#   'mae_de': 0.53428775,
#   'spearman_de': 0.8975669402689463,
#   'pearson_de': 0.8984220776899547,
#   'spearman_delta': 0.07125243151145774,
#   'pearson_delta': 0.41063775553376203},
#  'SYNERGY_SIMILAR_PHENO': {'mse_de': 0.3787827,
#   'mae_de': 0.50004303,
#   'spearman_de': 0.8175442678325506,
#   'pearson_de': 0.9150715456953358,
#   'spearman_delta': 0.025045986189676964,
#   'pearson_delta': 0.4556557475639671},
#  'SYNERGY_DISSIMILAR_PHENO': {'mse_de': 0.18914361,
#   'mae_de': 0.36971337,
#   'spearman_de': 0.9175525671496734,
#   'pearson_de': 0.9646194612947433,
#   'spearman_delta': 0.1646958101624918,
#   'pearson_delta': 0.48169338797972144},
#  'SUPPRESSOR': {'mse_de': 0.13676852,
#   'mae_de': 0.31607473,
#   'spearman_de': 0.8333172598854798,
#   'pearson_de': 0.9377536128770176,
#   'spearman_delta': 0.1355548828038735,
#   'pearson_delta': 0.4155004185910038}}

# %%
import pandas as pd
df_pert_status = pd.read_excel('./perturbation_status.xlsx')[['gene_name', 'gene type']]

# %%
df_pert_status['gene type'].value_counts()
# Out:
# transcription factor          49
# signaling                     21
# metabolism                     5
# mitotic spindle                5
# solute channel                 4
# poorly characterized           3
# extracellular matrix           3
# CDK inhibitor                  3
# chromatin remodeling           2
# immunoglobulin DCC subtype     2
# BCL2 family pro-apoptotic      2
# RNA binding                    1
# actin/calcium binding          1
# metal ion binding              1
# ubiquitin ligase               1
# ribosome maturation            1
# cytoskeleton                   1
# Name: gene type, dtype: int64

# %%
df_pert_status = df_pert_status[df_pert_status['gene type'] != 'poorly characterized']

# %%
df_pert_status.to_csv('gene2type.csv', index = False)

# %%
gene2status = dict(df_pert_status.values)

# %%
form_AB_C = [('BCL2L11+BAK1', 'MAML2+ctrl', 0.3523299818794149),
 ('BCL2L11+TGFBR2', 'ctrl+PRTG', 0.6857607274776449),
 ('CDKN1C+CDKN1B', 'CDKN1A+ctrl', 0.8779019780110475),
 ('CEBPB+MAPK1', 'ctrl+ETS2', 0.8337438300302283),
 ('CEBPE+CEBPB', 'CEBPA+ctrl', 0.9459044940236668),
 ('CEBPE+CEBPB', 'ctrl+CEBPA', 0.9450568814100481),
 ('CEBPE+SPI1', 'CEBPA+ctrl', 0.9265882308117831),
 ('CEBPE+SPI1', 'ctrl+CEBPA', 0.9262205916083754),
 ('DUSP9+ETS2', 'ATL1+ctrl', 0.7880293527700989),
 ('DUSP9+IGDCC3', 'ATL1+ctrl', 0.8570524822236342),
 ('DUSP9+SNAI1', 'HOXA13+ctrl', 0.7996935838759098),
 ('DUSP9+SNAI1', 'ZBTB10+ctrl', 0.7995353929762368),
 ('ETS2+MAP7D1', 'ctrl+MAPK1', 0.7841776025156834),
 ('ETS2+MAP7D1', 'MAPK1+ctrl', 0.7803504300888134),
 ('FOSB+CEBPB', 'CEBPA+ctrl', 0.9354845938615464),
 ('FOSB+CEBPB', 'ctrl+CEBPA', 0.9354176324036135),
 ('FOSB+OSR2', 'CEBPE+ctrl', 0.8154604060988084),
 ('FOSB+UBASH3B', 'CEBPB+ctrl', 0.6317409516808135),
 ('FOXF1+FOXL2', 'C3orf72+ctrl', 0.8889870382378344),
 ('FOXL2+MEIS1', 'C3orf72+ctrl', 0.8846717759603488),
 ('KLF1+COL2A1', 'COL1A1+ctrl', 0.5541335212725205),
 ('LYL1+IER5L', 'ATL1+ctrl', 0.7404815124117897),
 ('MAP2K3+SLC38A2', 'ctrl+MAP2K6', 0.7593659002942127),
 ('MAP2K3+SLC38A2', 'MAP2K6+ctrl', 0.7391185919257972),
 ('MAP2K6+SPI1', 'ctrl+CEBPB', 0.558469704875895),
 ('MAPK1+TGFBR2', 'ctrl+ETS2', 0.9314792135449927),
 ('MAPK1+TGFBR2', 'ETS2+ctrl', 0.9204283415329652),
 ('PLK4+STIL', 'HOXA13+ctrl', 0.674186951565633),
 ('POU3F2+FOXL2', 'C3orf72+ctrl', 0.874822568078057),
 ('SGK1+S1PR2', 'SAMD1+ctrl', 0.6937735420993153),
 ('SGK1+TBX3', 'TP73+ctrl', 0.6898264549412313),
 ('TGFBR2+C19orf26', 'ATL1+ctrl', 0.8749178401903432),
 ('TGFBR2+ETS2', 'MAPK1+ctrl', 0.8111119211411146),
 ('TGFBR2+ETS2', 'ctrl+MAPK1', 0.8036455728715278),
 ('UBASH3B+PTPN9', 'PTPN1+ctrl', 0.9243948368096824),
 ('ZBTB10+PTPN12', 'HOXA13+ctrl', 0.720459826421656),
 ('ZC3HAV1+CEBPE', 'FOSB+ctrl', 0.6923524330291644),
 ('ZC3HAV1+HOXC13', 'HOXA13+ctrl', 0.8100287557856198),
 ('ZC3HAV1+HOXC13', 'RHOXF2BB+ctrl', 0.6674925920417053),
 ('ZNF318+FOXL2', 'C3orf72+ctrl', 0.8372164786681434)]

# %%
# calculate mean expression for each condition
unique_conditions = adata.obs.condition.unique()
conditions2index = {}
for i in unique_conditions:
    conditions2index[i] = np.where(adata.obs.condition == i)[0]
    
condition2mean_expression = {}
for i, j in conditions2index.items():
    condition2mean_expression[i] = np.mean(adata.X[j], axis = 0)

# %%
pert_list = np.array(list(condition2mean_expression.keys()))
mean_expression = np.array(list(condition2mean_expression.values())).reshape(len(adata.obs.condition.unique()), adata.X.toarray().shape[1])

# %%
ctrl = mean_expression[np.where(pert_list == 'ctrl')[0]]
most_variable_genes = np.argsort(np.std(mean_expression, axis = 0))[-200:]
gene_list = adata.var['gene_name'].values

# %%
c1 = mean_expression[np.where(pert_list == 'MAPK1+TGFBR2')[0], most_variable_genes[-20:]].reshape(1,-1)
c2 =  mean_expression[np.where(pert_list == 'ctrl+ETS2')[0], most_variable_genes[-20:]].reshape(1,-1)
sns.heatmap(np.concatenate((c1, c2, ctrl[:, most_variable_genes[-20:]])))
# Out:
# <AxesSubplot:>

# %%
i = np.where(pert_list == 'MAPK1+TGFBR2')[0]
pert = mean_expression[i]
print(pert_list[i])
# Out:
# ['MAPK1+TGFBR2']

# %%
k = 20
fold_change = pert/ctrl
fold_change[np.isnan(fold_change)] = 0
fold_change[np.isinf(fold_change)] = 0

fold_change[0][np.where(pert[0] < 0.1)[0]] = 0

topk_fold_changes = np.argsort(fold_change)[0][-k:]
c1 = pert[:, topk_fold_changes].reshape(1,-1)
c2 = ctrl[:, topk_fold_changes].reshape(1,-1)
ax = sns.heatmap(np.concatenate((c1, c2)))
ax.set_xticklabels(gene_list[topk_fold_changes])
ax.set_yticklabels([pert_list[i][0], 'ctrl'], rotation = 30)
# Out:
# /tmp/ipykernel_50634/3688433631.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert/ctrl
# /tmp/ipykernel_50634/3688433631.py:2: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert/ctrl
# [Text(0, 0.5, 'MAPK1+TGFBR2'), Text(0, 1.5, 'ctrl')]

# %%
c1
# Out:
# array([[0.22934388, 0.20902088, 0.5396299 , 0.7442049 , 0.4133687 ,
#         0.34723297, 0.36835185, 0.14924966, 0.26437858, 0.69880736,
#         0.39396968, 0.11326563, 0.15087591, 0.19014075, 0.583543  ,
#         0.5586877 , 0.17929384, 0.16862294, 0.15308279, 0.2853028 ]],
#       dtype=float32)

# %%
c2
# Out:
# array([[0.07148891, 0.06264847, 0.15848711, 0.2167206 , 0.11968527,
#         0.09913544, 0.08083089, 0.03265094, 0.05432282, 0.14158419,
#         0.07052477, 0.02021107, 0.02495943, 0.03111862, 0.08861561,
#         0.07508859, 0.02218506, 0.02042141, 0.01106856, 0.00307668]],
#       dtype=float32)

# %%
fold_change[0][np.where(gene_list == 'ETS2')[0]]
# Out:
# array([7.4403806], dtype=float32)

# %%
gene2status['MAPK1']
# Out:
# 'signaling'

# %%
gene2status['TGFBR2']
# Out:
# 'signaling'

# %%
gene2status['ETS2']
# Out:
# 'transcription factor'

# %%
gene2status['BCL2L11']
# Out:
# 'BCL2 family pro-apoptotic'

# %%
gene2status['DUSP9']
# Out:
# 'signaling'

# %%
gene2status['IGDCC3']
# Out:
# 'immunoglobulin DCC subtype'

# %%
gene2status['SNAI1']
# Out:
# 'transcription factor'

# %%
from utils import parse_single_pert, parse_any_pert

# %%
corr_fold_changes = []
for c in form_AB_C:
    q1 = c[0]
    q2 = c[1]
    
    i = np.where(pert_list == q1)[0]
    pert = mean_expression[i]
    
    fold_change = pert/ctrl
    fold_change[np.isnan(fold_change)] = 0
    fold_change[np.isinf(fold_change)] = 0

    fold_change[0][np.where(pert[0] < 0.1)[0]] = 0
    fc = fold_change[0][np.where(gene_list == parse_single_pert(q2))[0]]
    
    corr_fold_changes.append((fc[0], c[2]))
# Out:
# /tmp/ipykernel_50634/1744984347.py:9: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert/ctrl
# /tmp/ipykernel_50634/1744984347.py:9: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert/ctrl

# %%
corr_fold_changes
# Out:
# [(0.0, 0.3523299818794149),
#  (0.0, 0.6857607274776449),
#  (0.0, 0.8779019780110475),
#  (6.228314, 0.8337438300302283),
#  (0.0, 0.9459044940236668),
#  (0.0, 0.9450568814100481),
#  (0.0, 0.9265882308117831),
#  (0.0, 0.9262205916083754),
#  (0.0, 0.7880293527700989),
#  (0.0, 0.8570524822236342),
#  (0.0, 0.7996935838759098),
#  (0.0, 0.7995353929762368),
#  (0.8855235, 0.7841776025156834),
#  (0.8855235, 0.7803504300888134),
#  (3.0527685, 0.9354845938615464),
#  (3.0527685, 0.9354176324036135),
#  (23.761322, 0.8154604060988084),
#  (1.6325972, 0.6317409516808135),
#  (0.0, 0.8889870382378344),
#  (0.0, 0.8846717759603488),
#  (0.0, 0.5541335212725205),
#  (0.0, 0.7404815124117897),
#  (0.0, 0.7593659002942127),
#  (0.0, 0.7391185919257972),
#  (0.984871, 0.558469704875895),
#  (7.4403806, 0.9314792135449927),
#  (7.4403806, 0.9204283415329652),
#  (0.0, 0.674186951565633),
#  (0.0, 0.874822568078057),
#  (1.1026132, 0.6937735420993153),
#  (0.0, 0.6898264549412313),
#  (0.0, 0.8749178401903432),
#  (0.9332959, 0.8111119211411146),
#  (0.9332959, 0.8036455728715278),
#  (0.79368937, 0.9243948368096824),
#  (0.0, 0.720459826421656),
#  (0.0, 0.6923524330291644),
#  (0.0, 0.8100287557856198),
#  (0.0, 0.6674925920417053),
#  (0.0, 0.8372164786681434)]

# %%
from scipy import stats

def get_fc_AB_C(c):    

    i = np.where(pert_list == c)[0]
    pert = mean_expression[i]
    
    fold_change = pert/ctrl
    fold_change[np.isnan(fold_change)] = 0
    fold_change[np.isinf(fold_change)] = 0

    fold_change[0][np.where(pert[0] < 0.5)[0]] = 0
    
    topk_fold_changes = np.argsort(fold_change)[0][-k:]
    c1 = pert[:, topk_fold_changes].reshape(1,-1)
    c2 = ctrl[:, topk_fold_changes].reshape(1,-1)
    topk_fc_genes = gene_list[topk_fold_changes]
    
    for x in topk_fc_genes:
        for c2 in pert_list:
            if c!=c2 and c2 != 'ctrl' and len(np.intersect1d(parse_any_pert(c), parse_any_pert(c2)))==0:
                parse = parse_any_pert(c2)
                if x in parse and len(parse) == 1:
                    c2_exp = mean_expression[np.where(pert_list == c2)[0]]
                    fc = fold_change[0][np.where(gene_list == parse[0])[0]]
                    if fc[0] > 5:
                        corr_fc.append((c, c2, fc[0], 
                                    stats.pearsonr(c2_exp[:, most_variable_genes][0] - ctrl[:, most_variable_genes][0], 
                                                   pert[:, most_variable_genes][0] - ctrl[:, most_variable_genes][0])[0],
                                    stats.spearmanr(c2_exp[:, most_variable_genes][0] - ctrl[:, most_variable_genes][0], 
                                                    pert[:, most_variable_genes][0] - ctrl[:, most_variable_genes][0])[0]))
                    
    return corr_fc

# %%
from tqdm import tqdm
corr_fc = []
for c in tqdm(pert_list):
    if c!='ctrl':
        a = get_fc_AB_C(c)
# Out:
#   0%|                                                                                                                                                                                                       | 0/284 [00:00<?, ?it/s]/tmp/ipykernel_50634/1485303386.py:8: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert/ctrl
# /tmp/ipykernel_50634/1485303386.py:8: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert/ctrl
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 284/284 [00:38<00:00,  7.37it/s]

# %%
sns.set(rc={'figure.figsize':(10, 4)})
import matplotlib.pyplot as plt
corr = pd.DataFrame(mean_expression[:, most_variable_genes] - ctrl[:, most_variable_genes]).T.corr('pearson').values
sns.distplot(corr.reshape(-1,), hist = False, label = 'all pairs')
ax = sns.distplot([i[3] for i in corr_fc], hist = False, label = 'partners')
#ax.set_xlim(0, 1)
plt.legend(loc='lower left', labels=['all pairs', 'partners'])
# Out:
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
df_corr_fc = pd.DataFrame(corr_fc)

# %%
df_corr_fc = df_corr_fc.rename(columns = {0: 'query_pert', 1: 'act_pert', 
                             2: 'fold_change', 3: 'pearson', 4: 'spearman'})

# %%
def gene2type(c):
    out = []
    o = parse_any_pert(c)
    for i in o:
        if i in gene2status:
            out.append(gene2status[i])
        else:
            out.append('N/A')
            
    return '+'.join(out)

# %%
df_corr_fc['query_type'] = df_corr_fc.query_pert.apply(lambda x: gene2type(x))
df_corr_fc['act_type'] = df_corr_fc.act_pert.apply(lambda x: gene2type(x))

# %%
df_corr_fc
# Out:
#        query_pert    act_pert  fold_change   pearson  spearman  \
# 0     DUSP9+MAPK1   ctrl+ETS2     7.202773  0.224872  0.367251
# 1     DUSP9+MAPK1   ETS2+ctrl     7.202773  0.211482  0.334171
# 2    IGDCC3+MAPK1   ctrl+ETS2     6.974825  0.531236  0.601059
# 3    IGDCC3+MAPK1   ETS2+ctrl     6.974825  0.515201  0.570700
# 4       JUN+CEBPA  ctrl+CEBPE    46.594349  0.910482  0.939818
# 5       JUN+CEBPA  CEBPE+ctrl    46.594349  0.890260  0.926303
# 6     MAPK1+IKZF3   ctrl+ETS2     6.793534  0.120023  0.401845
# 7     MAPK1+IKZF3   ETS2+ctrl     6.793534  0.101036  0.370752
# 8     CEBPB+CEBPA  ctrl+CEBPE    57.989193  0.904909  0.939067
# 9     CEBPB+CEBPA  CEBPE+ctrl    57.989193  0.886019  0.926767
# 10     CNN1+MAPK1   ctrl+ETS2     6.910108  0.756301  0.760887
# 11     CNN1+MAPK1   ETS2+ctrl     6.910108  0.742593  0.742114
# 12   MAPK1+TGFBR2   ctrl+ETS2     7.440381  0.968662  0.949005
# 13   MAPK1+TGFBR2   ETS2+ctrl     7.440381  0.961755  0.938389
# 14     ctrl+CEBPA  ctrl+CEBPE    53.700356  0.913127  0.946195
# 15     ctrl+CEBPA  CEBPE+ctrl    53.700356  0.893753  0.934687
# 16     FOSB+CEBPB  ctrl+CEBPE    40.490284  0.921957  0.951876
# 17     FOSB+CEBPB  CEBPE+ctrl    40.490284  0.905453  0.941701
# 18     KLF1+CEBPA  ctrl+CEBPE    51.129608  0.916002  0.941068
# 19     KLF1+CEBPA  CEBPE+ctrl    51.129608  0.906525  0.938786
# 20      ctrl+BAK1   LHX1+ctrl    10.089656  0.359677 -0.198618
# 21     CEBPA+ctrl  ctrl+CEBPE    64.802803  0.914496  0.946839
# 22     CEBPA+ctrl  CEBPE+ctrl    64.802803  0.896001  0.935422
# 23     ctrl+MAPK1   ctrl+ETS2     7.225889  0.979134  0.975174
# 24     ctrl+MAPK1   ETS2+ctrl     7.225889  0.973590  0.963599
# 25  ZC3HAV1+CEBPA  ctrl+CEBPE    42.153671  0.899761  0.939622
# 26  ZC3HAV1+CEBPA  CEBPE+ctrl    42.153671  0.882835  0.930835
#
#                                    query_type              act_type
# 0                         signaling+signaling  transcription factor
# 1                         signaling+signaling  transcription factor
# 2        immunoglobulin DCC subtype+signaling  transcription factor
# 3        immunoglobulin DCC subtype+signaling  transcription factor
# 4   transcription factor+transcription factor  transcription factor
# 5   transcription factor+transcription factor  transcription factor
# 6              signaling+transcription factor  transcription factor
# 7              signaling+transcription factor  transcription factor
# 8   transcription factor+transcription factor  transcription factor
# 9   transcription factor+transcription factor  transcription factor
# 10            actin/calcium binding+signaling  transcription factor
# 11            actin/calcium binding+signaling  transcription factor
# 12                        signaling+signaling  transcription factor
# 13                        signaling+signaling  transcription factor
# 14                       transcription factor  transcription factor
# 15                       transcription factor  transcription factor
# 16  transcription factor+transcription factor  transcription factor
# 17  transcription factor+transcription factor  transcription factor
# 18  transcription factor+transcription factor  transcription factor
# 19  transcription factor+transcription factor  transcription factor
# 20                  BCL2 family pro-apoptotic  transcription factor
# 21                       transcription factor  transcription factor
# 22                       transcription factor  transcription factor
# 23                                  signaling  transcription factor
# 24                                  signaling  transcription factor
# 25  transcription factor+transcription factor  transcription factor
# 26  transcription factor+transcription factor  transcription factor

# %% [markdown]
# ## Can two perturbations lead to the same surprise genes?

# %%
fold_change_all = []
for c in pert_list:
    i = np.where(pert_list == c)[0]
    pert = mean_expression[i]

    fold_change = pert/ctrl
    fold_change[np.isnan(fold_change)] = 0
    fold_change[np.isinf(fold_change)] = 0

    fold_change[0][np.where(pert[0] < 0.5)[0]] = 0
    fold_change_all.append(fold_change[0])
    
fold_change_all = np.stack(fold_change_all)
# Out:
# /tmp/ipykernel_50634/283273026.py:6: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert/ctrl
# /tmp/ipykernel_50634/283273026.py:6: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert/ctrl

# %%
surprise2pert = {}
for gene in range(len(gene_list)):
    #Q1 = np.percentile(fold_change_all[:, gene], 25)
    #Q3 = np.percentile(fold_change_all[:, gene], 75)
    #IQR = Q3 - Q1
    #upper = Q3 + 10*IQR
    upper = 5
    perts = pert_list[np.where(fold_change_all[:, gene] > upper)[0]]
    if len(perts) != 0:
        surprise2pert[gene_list[gene]] = perts

# %%
gene2corr_group = {}
for s, pert in surprise2pert.items():
    if len(pert) > 1:
        m_exp = mean_expression[np.isin(pert_list, pert)]
        m = np.sum(pd.DataFrame(m_exp[:, most_variable_genes] - ctrl[:, most_variable_genes]).T.corr('pearson').values.reshape(-1,))
        m = (m - len(pert))/(len(pert)*len(pert)-len(pert))
        gene2corr_group[s] = m

# %%
pert
# Out:
# array(['JUN+CEBPA', 'CEBPB+CEBPA', 'FOSB+CEBPE', 'ctrl+CEBPA',
#        'FOSB+CEBPB', 'KLF1+CEBPA', 'CEBPE+CEBPA', 'CEBPA+ctrl',
#        'CEBPE+SPI1', 'CEBPE+CEBPB', 'ZC3HAV1+CEBPA'], dtype='<U15')

# %%
sns.set(rc={'figure.figsize':(10, 4)})
corr = pd.DataFrame(mean_expression[:, most_variable_genes] - ctrl[:, most_variable_genes]).T.corr('pearson').values
sns.distplot(corr.reshape(-1,), hist = False, label = 'all pairs')
ax = sns.distplot(list(gene2corr_group.values()), hist = False, label = 'partners')
#ax.set_xlim(0, 1)
plt.legend(loc='lower left', labels=['all pairs', 'surprises partners'])
# Out:
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## for each perturbation, look at high fold changes genes => the high fold change genes correspond to the unseen perturbations that perfrom well?

# %%
fold_change_all = []
for c in pert_list:
    i = np.where(pert_list == c)[0]
    pert = mean_expression[i]

    fold_change = pert/ctrl
    fold_change[np.isnan(fold_change)] = 0
    fold_change[np.isinf(fold_change)] = 0

    #fold_change[0][np.where(pert[0] < 0.5)[0]] = 0
    fold_change_all.append(fold_change[0])
    
fold_change_all = np.stack(fold_change_all)
# Out:
# /tmp/ipykernel_50634/1466758563.py:6: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert/ctrl
# /tmp/ipykernel_50634/1466758563.py:6: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert/ctrl

# %%
combo_seen0 = pertdl.subgroup['test_subgroup']['combo_seen0']
unseen_single = pertdl.subgroup['test_subgroup']['unseen_single']

# %%
train_perts = pertdl.set2conditions['train']

# %%
train_pert = train_perts[0]
pert2high_folds_up = {}
pert2low_folds_down = {}

for train_pert in train_perts:
    temp = np.where(pert_list == train_pert)[0]
    o = np.intersect1d(np.where(fold_change_all[temp][0] <0.333)[0], np.where(fold_change_all[temp][0] > 0)[0])
    if len(o) > 0:
        pert2low_folds_down[train_pert] = gene_list[o].tolist()
        
    o = np.where(fold_change_all[np.where(pert_list == train_pert)[0]][0] >3)[0]
    if len(o) > 0:
        pert2high_folds_up[train_pert] = gene_list[o].tolist()

# %%
all_high_folds = []
for i in pert2high_folds_up.values():
    all_high_folds = all_high_folds + i
    
all_high_folds_down = []
for i in pert2low_folds_down.values():
    all_high_folds_down = all_high_folds_down + i

# %%
all_high_folds = np.unique(all_high_folds)
all_high_folds_down = np.unique(all_high_folds_down)

# %%
unseen_single_gene = [parse_single_pert(i) for i in unseen_single]
genesymbol2pert = dict(zip(unseen_single_gene, unseen_single))

# %%
len(np.unique(np.intersect1d(unseen_single_gene, all_high_folds)))
# Out:
# 5

# %%
len(np.unique(np.intersect1d(unseen_single_gene, all_high_folds_down)))
# Out:
# 7

# %%
len(np.unique(unseen_single_gene))
# Out:
# 27

# %%
up_overlap = np.intersect1d(unseen_single_gene, all_high_folds)
down_overlap = np.intersect1d(unseen_single_gene, all_high_folds_down)

# %%
non_overlap = np.setdiff1d(unseen_single_gene, up_overlap.tolist() + down_overlap.tolist())

# %%
ax = sns.distplot([test_pert_res[genesymbol2pert[i]]['spearman_de'] for i in non_overlap], hist = False, label = 'partners')
ax = sns.distplot([test_pert_res[genesymbol2pert[i]]['spearman_de'] for i in up_overlap], hist = False, label = 'partners')
ax = sns.distplot([test_pert_res[genesymbol2pert[i]]['spearman_de'] for i in down_overlap], hist = False, label = 'partners')
plt.legend(loc='upper left', labels=['non overlap', 'fold-up>3', 'fold-down<0.3'])
# Out:
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.distplot([test_pert_res[genesymbol2pert[i]]['pearson_de'] for i in non_overlap], hist = False, label = 'partners')
ax = sns.distplot([test_pert_res[genesymbol2pert[i]]['pearson_de'] for i in up_overlap], hist = False, label = 'partners')
ax = sns.distplot([test_pert_res[genesymbol2pert[i]]['pearson_de'] for i in down_overlap], hist = False, label = 'partners')
plt.legend(loc='upper left', labels=['non overlap', 'fold-up>3', 'fold-down<0.3'])
# Out:
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.distplot([metrics_pert_delta[genesymbol2pert[i]]['pearson'] for i in non_overlap], hist = False, label = 'partners')
ax = sns.distplot([metrics_pert_delta[genesymbol2pert[i]]['pearson'] for i in up_overlap], hist = False, label = 'partners')
ax = sns.distplot([metrics_pert_delta[genesymbol2pert[i]]['pearson'] for i in down_overlap], hist = False, label = 'partners')
plt.legend(loc='upper left', labels=['non overlap', 'fold-up>3', 'fold-down<0.3'])
# Out:
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
## calculate the MSE on the most fold-changed genes

# %%
fold_change_all = []
for c in pert_list:
    i = np.where(pert_list == c)[0]
    pert = mean_expression[i]

    fold_change = pert/ctrl
    fold_change[np.isnan(fold_change)] = 0
    fold_change[np.isinf(fold_change)] = 0

    #fold_change[0][np.where(pert[0] < 0.5)[0]] = 0
    fold_change_all.append(fold_change[0])
    
fold_change_all = np.stack(fold_change_all)
# Out:
# /tmp/ipykernel_50634/1129557839.py:6: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert/ctrl
# /tmp/ipykernel_50634/1129557839.py:6: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert/ctrl

# %%
most_up_fold_changes = np.argsort(fold_change_all, axis = 1)[:, -20:]

# %%
metrics_pert = {}
metric2fct = {
           'mse': mse,
           'mae': mae,
           'spearman': spearmanr,
           'pearson': pearsonr,
           'r2': r2_score
    }

for pert in np.unique(results['pert_cat']):
    pert_idx = np.where(pert_list == pert)[0]
    metrics_pert[pert] = {}
    p_idx = np.where(results['pert_cat'] == pert)[0]
    for m, fct in metric2fct.items():
        if m in ['spearman', 'pearson']:
            val = fct(results['pred'][p_idx].mean(0)[most_up_fold_changes[pert_idx]][0], results['truth'][p_idx].mean(0)[most_up_fold_changes[pert_idx]][0])[0]
            if np.isnan(val):
                val = 0
        else:
            val = fct(results['pred'][p_idx].mean(0)[most_up_fold_changes[pert_idx]][0], results['truth'][p_idx].mean(0)[most_up_fold_changes[pert_idx]][0])

        metrics_pert[pert][m] = val

# %%
metrics_pert
# Out:
# {'AHR+KLF1': {'mse': 0.042373978,
#   'mae': 0.18955599,
#   'spearman': 0.8330827067669173,
#   'pearson': 0.9239012904010555,
#   'r2': -1.7569045346711367},
#  'ARID1A+ctrl': {'mse': 0.0051933294,
#   'mae': 0.0662009,
#   'spearman': 0.6992481203007518,
#   'pearson': 0.7758224239258439,
#   'r2': -4.019838323613244},
#  'BCL2L11+BAK1': {'mse': 0.0025984803,
#   'mae': 0.049365528,
#   'spearman': 0.07148233776770777,
#   'pearson': 0.2786967434534955,
#   'r2': -14.426605948791185},
#  'BCL2L11+TGFBR2': {'mse': 0.007240744,
#   'mae': 0.072874166,
#   'spearman': 0.0781954887218045,
#   'pearson': 0.9806478090285488,
#   'r2': -0.09910390652131751},
#  'BCL2L11+ctrl': {'mse': 0.004988016,
#   'mae': 0.06974552,
#   'spearman': 0.5979692036263639,
#   'pearson': 0.32822068093687573,
#   'r2': -37.19572514672425},
#  'BCORL1+ctrl': {'mse': 0.004505083,
#   'mae': 0.06689688,
#   'spearman': 0.4300751879699248,
#   'pearson': 0.6161351026963698,
#   'r2': -96.12192780031025},
#  'BPGM+SAMD1': {'mse': 0.008383729,
#   'mae': 0.07667846,
#   'spearman': 0.6872180451127818,
#   'pearson': 0.4039477918780518,
#   'r2': -1.4611408062870277},
#  'BPGM+ZBTB1': {'mse': 0.004209922,
#   'mae': 0.06177634,
#   'spearman': 0.18832425109220438,
#   'pearson': 0.9000608840493054,
#   'r2': -2.379112682958611},
#  'BPGM+ctrl': {'mse': 0.007134144,
#   'mae': 0.07641616,
#   'spearman': 0.3087352898818145,
#   'pearson': 0.7223696982156244,
#   'r2': -7.104873289738849},
#  'C3orf72+FOXL2': {'mse': 0.002476843,
#   'mae': 0.047505524,
#   'spearman': 0.5814216281800998,
#   'pearson': 0.8553213195965624,
#   'r2': -1.7421325484270218},
#  'C3orf72+ctrl': {'mse': 0.0058245156,
#   'mae': 0.07260233,
#   'spearman': 0.464836437535966,
#   'pearson': 0.7655627157403039,
#   'r2': -6.285693718787351},
#  'CBL+CNN1': {'mse': 0.0013425844,
#   'mae': 0.027543133,
#   'spearman': 0.512781954887218,
#   'pearson': 0.798495925136436,
#   'r2': 0.16300471292620422},
#  'CBL+PTPN12': {'mse': 0.0061735185,
#   'mae': 0.074787036,
#   'spearman': 0.1835276549494752,
#   'pearson': 0.25429036480890127,
#   'r2': -8.468520866550127},
#  'CBL+PTPN9': {'mse': 0.0018038036,
#   'mae': 0.04077808,
#   'spearman': -0.05864661654135337,
#   'pearson': 0.03706647535123947,
#   'r2': -11.93998896144545},
#  'CBL+TGFBR2': {'mse': 0.008775289,
#   'mae': 0.0793943,
#   'spearman': 0.5806964581113735,
#   'pearson': 0.8818777113201168,
#   'r2': -0.24075493244624613},
#  'CBL+UBASH3A': {'mse': 0.0037304864,
#   'mae': 0.060262628,
#   'spearman': 0.5113145436357288,
#   'pearson': 0.6842815930285432,
#   'r2': -24.505254014553014},
#  'CBL+UBASH3B': {'mse': 0.0012693423,
#   'mae': 0.034086026,
#   'spearman': -0.17593984962406017,
#   'pearson': -0.15044469268478441,
#   'r2': -12.583981684012807},
#  'CBL+ctrl': {'mse': 0.004340234,
#   'mae': 0.064434655,
#   'spearman': 0.4270676691729323,
#   'pearson': 0.6468314893394689,
#   'r2': -16.30113183040871},
#  'CDKN1A+ctrl': {'mse': 0.005414377,
#   'mae': 0.07078533,
#   'spearman': 0.16240601503759397,
#   'pearson': 0.9980739916896015,
#   'r2': 0.6239083904337788},
#  'CDKN1B+CDKN1A': {'mse': 0.0063818395,
#   'mae': 0.07110078,
#   'spearman': 0.3157894736842105,
#   'pearson': 0.9972019866292796,
#   'r2': 0.5763714636999879},
#  'CDKN1B+ctrl': {'mse': 0.006113156,
#   'mae': 0.07273391,
#   'spearman': 0.3699248120300751,
#   'pearson': 0.6073087258648411,
#   'r2': -4.072302346224179},
#  'CDKN1C+CDKN1A': {'mse': 0.0054758983,
#   'mae': 0.06727558,
#   'spearman': 0.4937903034636812,
#   'pearson': 0.9990307862258994,
#   'r2': 0.6185507918971529},
#  'CDKN1C+CDKN1B': {'mse': 0.0035672723,
#   'mae': 0.05931086,
#   'spearman': 0.4067803823591614,
#   'pearson': 0.49450761686228883,
#   'r2': -54.197415809653094},
#  'CDKN1C+ctrl': {'mse': 0.004365291,
#   'mae': 0.06539966,
#   'spearman': 0.27861477379578375,
#   'pearson': 0.5625232885902488,
#   'r2': -34.56941636428529},
#  'CEBPB+CEBPA': {'mse': 0.102600254,
#   'mae': 0.2772184,
#   'spearman': 0.8992481203007519,
#   'pearson': 0.8786412922979393,
#   'r2': 0.14729875161595052},
#  'CEBPB+MAPK1': {'mse': 0.016435917,
#   'mae': 0.11030097,
#   'spearman': 0.2045112781954887,
#   'pearson': 0.12593810662952762,
#   'r2': -3.2425811490745353},
#  'CEBPB+OSR2': {'mse': 0.017342359,
#   'mae': 0.10626797,
#   'spearman': 0.5684210526315789,
#   'pearson': 0.46352536237345165,
#   'r2': -1.0090193107187155},
#  'CEBPB+PTPN12': {'mse': 0.02557081,
#   'mae': 0.12113889,
#   'spearman': 0.7037593984962407,
#   'pearson': 0.01986052473170967,
#   'r2': -10.886691396853726},
#  'CEBPB+ctrl': {'mse': 0.03168528,
#   'mae': 0.13399336,
#   'spearman': 0.5729323308270676,
#   'pearson': 0.07477202758588658,
#   'r2': -4.182894790570992},
#  'CEBPE+CEBPB': {'mse': 0.055299215,
#   'mae': 0.19665219,
#   'spearman': 0.7037593984962407,
#   'pearson': 0.667104394513845,
#   'r2': -0.2816142278873366},
#  'CEBPE+PTPN12': {'mse': 0.049354047,
#   'mae': 0.17742336,
#   'spearman': 0.849624060150376,
#   'pearson': 0.9349302448162444,
#   'r2': 0.599609778352662},
#  'CEBPE+RUNX1T1': {'mse': 0.050306343,
#   'mae': 0.18728064,
#   'spearman': 0.8887218045112781,
#   'pearson': 0.9445483360907423,
#   'r2': 0.5916564999435874},
#  'CEBPE+SPI1': {'mse': 0.037230693,
#   'mae': 0.16595663,
#   'spearman': 0.7969924812030074,
#   'pearson': 0.767046477387052,
#   'r2': -0.20424440176385117},
#  'CELF2+ctrl': {'mse': 0.0155031625,
#   'mae': 0.112073645,
#   'spearman': 0.8661654135338346,
#   'pearson': 0.8346291728308789,
#   'r2': -1.9611447688361947},
#  'CKS1B+ctrl': {'mse': 0.0051085367,
#   'mae': 0.06817128,
#   'spearman': 0.3670553098989504,
#   'pearson': 0.43210394012210074,
#   'r2': -8.281894598720719},
#  'CNN1+MAPK1': {'mse': 0.0014064094,
#   'mae': 0.03483986,
#   'spearman': 0.6596465302897122,
#   'pearson': 0.8861735409570911,
#   'r2': -1.8533568067643809},
#  'CNN1+UBASH3A': {'mse': 0.00048614098,
#   'mae': 0.020527974,
#   'spearman': 0.5084618637124805,
#   'pearson': 0.9715559403850501,
#   'r2': 0.5156358986499177},
#  'COL2A1+ctrl': {'mse': 0.005465728,
#   'mae': 0.06900418,
#   'spearman': 0.436254261765146,
#   'pearson': 0.673744837577935,
#   'r2': -3.57088431817004},
#  'DUSP9+ETS2': {'mse': 0.01243232,
#   'mae': 0.08228105,
#   'spearman': 0.8165413533834586,
#   'pearson': 0.9899975640862594,
#   'r2': 0.689463373704686},
#  'DUSP9+IGDCC3': {'mse': 0.0044986987,
#   'mae': 0.060941488,
#   'spearman': 0.5969924812030075,
#   'pearson': 0.9953054164827513,
#   'r2': 0.9025894910572503},
#  'DUSP9+KLF1': {'mse': 0.0052002263,
#   'mae': 0.06742004,
#   'spearman': 0.7401279199601788,
#   'pearson': 0.7742381300432227,
#   'r2': -1.513216969821316},
#  'DUSP9+MAPK1': {'mse': 0.0054507493,
#   'mae': 0.069139436,
#   'spearman': 0.5235051141181752,
#   'pearson': 0.4174127417974484,
#   'r2': -5.937255034935118},
#  'DUSP9+PRTG': {'mse': 0.005451503,
#   'mae': 0.061498147,
#   'spearman': 0.5684210526315789,
#   'pearson': 0.8876537070127233,
#   'r2': 0.6620852194347221},
#  'DUSP9+SNAI1': {'mse': 0.0036413954,
#   'mae': 0.05999896,
#   'spearman': 0.6581422052491426,
#   'pearson': 0.8205436035642071,
#   'r2': -4.7066795570271465},
#  'DUSP9+ctrl': {'mse': 0.022830945,
#   'mae': 0.10213518,
#   'spearman': 0.7278195488721804,
#   'pearson': 0.964913110379051,
#   'r2': 0.4368376569603519},
#  'EGR1+ctrl': {'mse': 0.0047396896,
#   'mae': 0.067940295,
#   'spearman': 0.1413533834586466,
#   'pearson': 0.07461530257185497,
#   'r2': -37.430802099766154},
#  'ETS2+CNN1': {'mse': 0.0022978801,
#   'mae': 0.040789895,
#   'spearman': 0.4842105263157894,
#   'pearson': 0.9943972740542704,
#   'r2': 0.956431892320681},
#  'ETS2+IKZF3': {'mse': 0.0122844,
#   'mae': 0.1052614,
#   'spearman': 0.6526315789473683,
#   'pearson': 0.9609486220123777,
#   'r2': -2.7456639385711283},
#  'ETS2+MAP7D1': {'mse': 0.0052173566,
#   'mae': 0.06838209,
#   'spearman': 0.27518796992481204,
#   'pearson': 0.5444918371582863,
#   'r2': -6.132120618882653},
#  'ETS2+MAPK1': {'mse': 0.0046644504,
#   'mae': 0.059546262,
#   'spearman': 0.23308270676691725,
#   'pearson': 0.39866609646531165,
#   'r2': -4.2622206101688365},
#  'FEV+ISL2': {'mse': 0.0076206154,
#   'mae': 0.08197348,
#   'spearman': 0.8649868983274446,
#   'pearson': 0.7916458356903582,
#   'r2': -1.212652803884136},
#  'FEV+MAP7D1': {'mse': 0.0081388485,
#   'mae': 0.085183285,
#   'spearman': 0.6100038039509197,
#   'pearson': 0.8438532759712882,
#   'r2': -4.784672974334683},
#  'FOSB+CEBPB': {'mse': 0.020889884,
#   'mae': 0.121732295,
#   'spearman': 0.6932330827067669,
#   'pearson': 0.7254671569495157,
#   'r2': -0.061849968424716684},
#  'FOSB+IKZF3': {'mse': 0.003029035,
#   'mae': 0.034848772,
#   'spearman': 0.6867243810199625,
#   'pearson': 0.6978298843501315,
#   'r2': 0.10515286787664746},
#  'FOSB+PTPN12': {'mse': 0.007832858,
#   'mae': 0.08703524,
#   'spearman': 0.19104928015232256,
#   'pearson': 0.028017362538718896,
#   'r2': -32.00746309838225},
#  'FOSB+UBASH3B': {'mse': 0.01013344,
#   'mae': 0.08871557,
#   'spearman': 0.6225563909774435,
#   'pearson': 0.35828283147933176,
#   'r2': -3.218577510468317},
#  'FOXA1+FOXL2': {'mse': 0.005845143,
#   'mae': 0.073190905,
#   'spearman': 0.801503759398496,
#   'pearson': 0.6554429914544464,
#   'r2': -3.461007638853687},
#  'FOXA1+HOXB9': {'mse': 0.0017771547,
#   'mae': 0.04157777,
#   'spearman': 0.18045112781954886,
#   'pearson': 0.27883150578603166,
#   'r2': -33.11327296493072},
#  'FOXA3+FOXL2': {'mse': 0.007484378,
#   'mae': 0.066946626,
#   'spearman': 0.5024445635502026,
#   'pearson': 0.6795277876611461,
#   'r2': -1.1545641217038445},
#  'FOXF1+FOXL2': {'mse': 0.0049047386,
#   'mae': 0.063573666,
#   'spearman': 0.7894736842105263,
#   'pearson': 0.7618546918416449,
#   'r2': -1.4057360160457564},
#  'FOXL2+HOXB9': {'mse': 0.0032979704,
#   'mae': 0.05172489,
#   'spearman': 0.8389769116946755,
#   'pearson': 0.5667612426282991,
#   'r2': -1.776441536316404},
#  'FOXL2+MEIS1': {'mse': 0.0042875563,
#   'mae': 0.058232676,
#   'spearman': 0.5909774436090225,
#   'pearson': 0.8417819804227634,
#   'r2': -1.9474857104878835},
#  'FOXL2+ctrl': {'mse': 0.0047759907,
#   'mae': 0.06795589,
#   'spearman': 0.36479882233809624,
#   'pearson': 0.8136873653220741,
#   'r2': -20.673351224133494},
#  'IGDCC3+MAPK1': {'mse': 0.00539051,
#   'mae': 0.070786625,
#   'spearman': 0.5233082706766917,
#   'pearson': 0.9959114976182674,
#   'r2': 0.8833440973034008},
#  'IRF1+SET': {'mse': 0.0059324433,
#   'mae': 0.06372987,
#   'spearman': 0.58796992481203,
#   'pearson': 0.6678677644575836,
#   'r2': -2.0526940885225256},
#  'ISL2+ctrl': {'mse': 0.004695347,
#   'mae': 0.06813876,
#   'spearman': 0.30526315789473685,
#   'pearson': 0.4155966827398418,
#   'r2': -78.13032957844564},
#  'JUN+CEBPB': {'mse': 0.017376246,
#   'mae': 0.09216161,
#   'spearman': 0.6746897806954069,
#   'pearson': 0.5381211291144131,
#   'r2': -1.1655323640816984},
#  'KLF1+COL2A1': {'mse': 0.0035252173,
#   'mae': 0.057174582,
#   'spearman': 0.6781954887218045,
#   'pearson': 0.8258139899868613,
#   'r2': -1.7303539708482507},
#  'LYL1+CEBPB': {'mse': 0.028458154,
#   'mae': 0.12114438,
#   'spearman': 0.6586466165413534,
#   'pearson': 0.027152809553718932,
#   'r2': -9.77287379061355},
#  'LYL1+IER5L': {'mse': 0.0031057731,
#   'mae': 0.04101322,
#   'spearman': 0.6045112781954887,
#   'pearson': 0.669788158816825,
#   'r2': -0.2623974890827967},
#  'MAP2K6+SPI1': {'mse': 0.006396296,
#   'mae': 0.07048021,
#   'spearman': 0.7984962406015037,
#   'pearson': 0.6126374778566985,
#   'r2': -1.0467942407766722},
#  'MAP7D1+ctrl': {'mse': 0.004364885,
#   'mae': 0.06558677,
#   'spearman': -0.05039488885907721,
#   'pearson': 0.02883685062731515,
#   'r2': -69.24491694264024},
#  'MAPK1+PRTG': {'mse': 0.0060460046,
#   'mae': 0.07345921,
#   'spearman': 0.819548872180451,
#   'pearson': 0.980678323669465,
#   'r2': 0.5987107792975215},
#  'NCL+ctrl': {'mse': 0.0053740107,
#   'mae': 0.070179455,
#   'spearman': 0.16647863796550869,
#   'pearson': 0.18286618008845984,
#   'r2': -10.66872603184646},
#  'PLK4+STIL': {'mse': 0.0030937954,
#   'mae': 0.052322853,
#   'spearman': -0.04596846713204587,
#   'pearson': 0.07199504417873583,
#   'r2': -8.00116370512167},
#  'PLK4+ctrl': {'mse': 0.0043827305,
#   'mae': 0.06490708,
#   'spearman': 0.2643075286549192,
#   'pearson': 0.3774099335383434,
#   'r2': -24.73927297581681},
#  'POU3F2+CBFA2T3': {'mse': 0.0044479067,
#   'mae': 0.06548376,
#   'spearman': 0.5829259532206692,
#   'pearson': 0.7656960501593549,
#   'r2': -17.271260575627196},
#  'POU3F2+FOXL2': {'mse': 0.0052995225,
#   'mae': 0.07041153,
#   'spearman': 0.38496240601503756,
#   'pearson': 0.7314465914106724,
#   'r2': -1.7197782279399565},
#  'POU3F2+ctrl': {'mse': 0.004511012,
#   'mae': 0.06514907,
#   'spearman': 0.312781954887218,
#   'pearson': 0.7433187092781645,
#   'r2': -17.49455614287162},
#  'PTPN1+ctrl': {'mse': 0.005122346,
#   'mae': 0.07076586,
#   'spearman': -0.026325688209965708,
#   'pearson': -0.06529370372442214,
#   'r2': -45.98525914111692},
#  'PTPN12+OSR2': {'mse': 0.0060532414,
#   'mae': 0.07314708,
#   'spearman': 0.2721804511278195,
#   'pearson': 0.8836470566612784,
#   'r2': -0.9846891449185498},
#  'PTPN12+PTPN9': {'mse': 0.0016599789,
#   'mae': 0.039463643,
#   'spearman': 0.3699248120300751,
#   'pearson': -0.12486804300081053,
#   'r2': -23.002339713601817},
#  'PTPN12+SNAI1': {'mse': 0.00477715,
#   'mae': 0.06828801,
#   'spearman': 0.16842105263157892,
#   'pearson': 0.4587388190059815,
#   'r2': -34.05799380354433},
#  'PTPN12+UBASH3A': {'mse': 0.0047864215,
#   'mae': 0.06707444,
#   'spearman': 0.3008650081138938,
#   'pearson': 0.3267562877419721,
#   'r2': -7.5681044418712595},
#  'PTPN12+ZBTB25': {'mse': 0.003626163,
#   'mae': 0.054629244,
#   'spearman': 0.20751879699248119,
#   'pearson': -0.2098469687532695,
#   'r2': -21.950676341326577},
#  'PTPN12+ctrl': {'mse': 0.0046784305,
#   'mae': 0.06735841,
#   'spearman': 0.00902934792855256,
#   'pearson': -0.28910993856094175,
#   'r2': -134.8713917976761},
#  'RHOXF2BB+SET': {'mse': 0.003917037,
#   'mae': 0.06041162,
#   'spearman': 0.6874765435402473,
#   'pearson': 0.8134558473966709,
#   'r2': -6.359114404170548},
#  'RHOXF2BB+ZBTB25': {'mse': 0.0026095067,
#   'mae': 0.04919692,
#   'spearman': 0.3053779832356022,
#   'pearson': 0.30984485594292943,
#   'r2': -3.163188855224246},
#  'RHOXF2BB+ctrl': {'mse': 0.004882061,
#   'mae': 0.06905887,
#   'spearman': 0.6857142857142857,
#   'pearson': 0.9142107050519089,
#   'r2': -7.874149260144939},
#  'SAMD1+PTPN12': {'mse': 0.00911475,
#   'mae': 0.081887566,
#   'spearman': 0.5082706766917292,
#   'pearson': 0.6543020945631961,
#   'r2': -1.7450727593677056},
#  'SAMD1+ZBTB1': {'mse': 0.017358406,
#   'mae': 0.12346156,
#   'spearman': 0.5370440394833004,
#   'pearson': 0.735875715401204,
#   'r2': -3.1704165700011595},
#  'SET+CEBPE': {'mse': 0.026710067,
#   'mae': 0.14114553,
#   'spearman': 0.5385483645238699,
#   'pearson': 0.945216034868234,
#   'r2': 0.759438992892067},
#  'SET+KLF1': {'mse': 0.0065709827,
#   'mae': 0.073291525,
#   'spearman': 0.6285714285714286,
#   'pearson': 0.6300673182401877,
#   'r2': -2.229729394694062},
#  'SET+ctrl': {'mse': 0.019990694,
#   'mae': 0.09012562,
#   'spearman': 0.6451127819548872,
#   'pearson': 0.728430818799566,
#   'r2': -30.77069105915439},
#  'SPI1+ctrl': {'mse': 0.012493957,
#   'mae': 0.08779292,
#   'spearman': 0.900751879699248,
#   'pearson': 0.7967806517988479,
#   'r2': -0.8674079154384726},
#  'TBX3+TBX2': {'mse': 0.024555037,
#   'mae': 0.13926819,
#   'spearman': 0.7624060150375939,
#   'pearson': 0.9929552173525791,
#   'r2': 0.9372964731221821},
#  'UBASH3B+PTPN12': {'mse': 0.0011450958,
#   'mae': 0.03237661,
#   'spearman': -0.13484016378201832,
#   'pearson': 0.03871451937404901,
#   'r2': -2.8249046826381594},
#  'UBASH3B+PTPN9': {'mse': 0.0005511097,
#   'mae': 0.015387736,
#   'spearman': 0.13082706766917293,
#   'pearson': 0.9719105499081294,
#   'r2': 0.643948502118275},
#  'ZBTB10+DLX2': {'mse': 0.0027187965,
#   'mae': 0.03955125,
#   'spearman': 0.5654135338345864,
#   'pearson': 0.4127238795005694,
#   'r2': -3.162000609880768},
#  'ZBTB10+ELMSAN1': {'mse': 0.0024251067,
#   'mae': 0.043194886,
#   'spearman': 0.7002633063850878,
#   'pearson': 0.7057828193408673,
#   'r2': -1.875963093623851},
#  'ZBTB10+PTPN12': {'mse': 0.004884024,
#   'mae': 0.06839011,
#   'spearman': 0.2685220197416502,
#   'pearson': 0.913554774863671,
#   'r2': -5.264448568704199},
#  'ZBTB10+SNAI1': {'mse': 0.0028135567,
#   'mae': 0.04822614,
#   'spearman': 0.5834586466165413,
#   'pearson': 0.5380795442704985,
#   'r2': -3.3766087130067675},
#  'ZBTB10+ctrl': {'mse': 0.004247675,
#   'mae': 0.06297689,
#   'spearman': 0.4039112733929024,
#   'pearson': 0.7404465776298522,
#   'r2': -6.202595302354811},
#  'ZC3HAV1+CEBPE': {'mse': 0.10011282,
#   'mae': 0.26037896,
#   'spearman': 0.825563909774436,
#   'pearson': 0.8908891273758264,
#   'r2': 0.18042421442409295},
#  'ZC3HAV1+HOXC13': {'mse': 0.008770453,
#   'mae': 0.08689549,
#   'spearman': 0.8364047225566248,
#   'pearson': 0.9463388024017816,
#   'r2': 0.1958566097203316},
#  'ZNF318+FOXL2': {'mse': 0.0035452456,
#   'mae': 0.048514344,
#   'spearman': 0.19849624060150375,
#   'pearson': 0.8779220252396319,
#   'r2': -3.097572566759271},
#  'ctrl+CDKN1A': {'mse': 0.0083957715,
#   'mae': 0.07632546,
#   'spearman': 0.21100279995037452,
#   'pearson': 0.9977101953808264,
#   'r2': 0.42313307941861367},
#  'ctrl+CDKN1B': {'mse': 0.0041732118,
#   'mae': 0.06046053,
#   'spearman': 0.12034600324555753,
#   'pearson': 0.5428010452552819,
#   'r2': -6.437654947074245},
#  'ctrl+CEBPB': {'mse': 0.026167566,
#   'mae': 0.11859463,
#   'spearman': 0.5227529515978905,
#   'pearson': 0.1280393840710395,
#   'r2': -3.3367083272503493},
#  'ctrl+COL2A1': {'mse': 0.0060511874,
#   'mae': 0.075111076,
#   'spearman': 0.38345864661654133,
#   'pearson': 0.5499016446448327,
#   'r2': -6.145233746679919},
#  'ctrl+FOXL2': {'mse': 0.0073213885,
#   'mae': 0.08143317,
#   'spearman': 0.544360902255639,
#   'pearson': 0.8940509692628024,
#   'r2': -2.7414849779549746},
#  'ctrl+ISL2': {'mse': 0.0045276387,
#   'mae': 0.067004696,
#   'spearman': 0.3569281156194635,
#   'pearson': 0.4829670763547914,
#   'r2': -91.6087724645432},
#  'ctrl+MAP7D1': {'mse': 0.005109407,
#   'mae': 0.070001826,
#   'spearman': -0.29001934668199475,
#   'pearson': -0.3110457343502856,
#   'r2': -25.16401499625148},
#  'ctrl+PTPN12': {'mse': 0.005066432,
#   'mae': 0.07040999,
#   'spearman': -0.026325688209965708,
#   'pearson': -0.34539641623087564,
#   'r2': -50.72754607034628},
#  'ctrl+SET': {'mse': 0.006729958,
#   'mae': 0.06236259,
#   'spearman': 0.5533834586466165,
#   'pearson': 0.7150426905045545,
#   'r2': -12.9466546590845},
#  'ctrl+SPI1': {'mse': 0.008867554,
#   'mae': 0.09033216,
#   'spearman': 0.9203007518796992,
#   'pearson': 0.8165337558842689,
#   'r2': -0.7406713937829912}}

# %%
most_up_fold_changes
# Out:
# array([[1501,  777, 4270, ..., 4679,  305,  808],
#        [4745, 2006,  212, ..., 2032, 2836, 4259],
#        [2425, 2426, 2427, ..., 2443, 2430, 2522],
#        ...,
#        [2736, 3815, 2009, ..., 2339, 4710,  830],
#        [2844,  916, 3339, ..., 1699, 2339, 1855],
#        [2532, 4387, 1399, ..., 1953, 2925, 4775]])

# %%
want = {}

for i in ['CBL+CNN1', 'DUSP9+ETS2']:
    query_idx = np.where(test_res['pert_cat'] == i)[0]
    want[i] = {"query": i, 
            "pred_de": test_res['pred_de'][query_idx],
            "truth_de": test_res['truth_de'][query_idx]
              }

# %%
import pickle
pickle.dump(want, open('viz_interaction.pkl', 'wb'))

# %%
for i in ['CBL+CNN1', 'DUSP9+ETS2']:

    print(test_pert_res[i])
# Out:
# {'mse': 0.015092794, 'mae': 0.08204727, 'spearman': 0.8261467992690825, 'pearson': 0.9683605728653688, 'r2': 0.8981752308562897, 'mse_de': 0.69507796, 'mae_de': 0.7207664, 'spearman_de': 0.9067669172932331, 'pearson_de': 0.9121423201945077, 'r2_de': -0.21185414728369056}
# {'mse': 0.016402414, 'mae': 0.10711804, 'spearman': 0.8687508292518453, 'pearson': 0.979097807082659, 'r2': 0.8844600659445081, 'mse_de': 0.31558293, 'mae_de': 0.50120467, 'spearman_de': 0.8616541353383457, 'pearson_de': 0.9191062556783037, 'r2_de': 0.7264653755145475}

# %%
pickle.dump(test_pert_res, open('./gnn_disentangle_test_pert_res.pkl', 'wb'))
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
cpa_test_pert_res = pickle.load(open('./CPA/cpa_test_pert_res.pkl', 'rb'))

# %%
res_cpa = {}
for i,j in cpa_test_pert_res.items():
    res_cpa[i] = {'mse_de_cpa': j['mse_de']}
    
res_gnn = {}
for i,j in test_pert_res.items():
    res_gnn[i] = {'mse_de_gnn': j['mse_de']}

# %%
import pandas as pd
df_eval = pd.DataFrame(res_cpa).T

# %%
df_eval['mse_de_gnn'] = pd.DataFrame(res_gnn).T['mse_de_gnn'].values

# %%
df_eval
# Out:
#                 mse_de_cpa  mse_de_gnn
# AHR+KLF1          0.357695    0.368303
# ARID1A+ctrl       0.258422    0.211488
# BCL2L11+BAK1      0.004903    0.038742
# BCL2L11+TGFBR2    0.052947    0.062958
# BCL2L11+ctrl      0.014018    0.017545
# ...                    ...         ...
# ctrl+ISL2         0.030616    0.088716
# ctrl+MAP7D1       0.059880    0.041222
# ctrl+PTPN12       0.137781    0.125480
# ctrl+SET          0.464519    0.356826
# ctrl+SPI1         0.485387    0.198741
#
# [116 rows x 2 columns]

# %%
subgroup = pickle.load(open('./splits/Norman2019_simulation_1_0.1_subgroup.pkl', 'rb'))

# %%
subgroup = subgroup['test_subgroup']

# %%
pert2group = {}
for i,j in subgroup.items():
    for x in j:
        pert2group[x] = i

# %%
df_eval['group'] = [pert2group[x] for x in df_eval.index.values]

# %%
df_eval[df_eval.group == 'combo_seen2']
# Out:
#                 mse_de_cpa  mse_de_gnn        group
# AHR+KLF1          0.357695    0.368303  combo_seen2
# CEBPE+RUNX1T1     0.100133    0.339434  combo_seen2
# CNN1+MAPK1        0.078004    0.113659  combo_seen2
# CNN1+UBASH3A      0.783318    0.708051  combo_seen2
# ETS2+CNN1         0.133394    0.093787  combo_seen2
# ETS2+IKZF3        0.310006    0.968617  combo_seen2
# ETS2+MAPK1        0.355581    0.954693  combo_seen2
# FOSB+IKZF3        0.356463    0.507040  combo_seen2
# FOSB+UBASH3B      0.050452    0.069400  combo_seen2
# FOXA1+HOXB9       0.180823    0.211096  combo_seen2
# IGDCC3+MAPK1      0.086858    0.127221  combo_seen2
# LYL1+IER5L        0.253240    0.247038  combo_seen2
# MAPK1+PRTG        0.076250    0.142495  combo_seen2
# SAMD1+ZBTB1       0.257489    0.424606  combo_seen2
# TBX3+TBX2         0.430185    0.536733  combo_seen2
# UBASH3B+PTPN9     0.297899    0.282023  combo_seen2
# ZC3HAV1+CEBPE     0.080642    0.226491  combo_seen2
# ZC3HAV1+HOXC13    0.151680    0.145023  combo_seen2

# %%
df_eval.to_csv('./cpa_gnn_comparison.csv', index = False)
