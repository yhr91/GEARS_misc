# %%
# !python train.py --dataset Norman2019 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 10 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GCN \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3\
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:4 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --exp_name gcn_expression \
                 --wandb
# Out:
# ---- Printing Arguments ----
# dataset: Norman2019
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 10.0
# randomize_network: False
# device: cuda:4
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GCN
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# ...
