# %%
# !python train.py --dataset Norman2019 \
                 --split simulation \
                 --seed 1 \
                 --network_name string \
                 --top_edge_percent 20 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3 \
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:7 \
                 --gene_emb \
                 --pert_emb \
                 --pert_emb_lambda 0.2 \
                 --sim_gnn \
                 --sim_graph knn_go_pathway \
                 --wandb \
                 --uncertainty
# Out:
# ---- Printing Arguments ----
# dataset: Norman2019
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: True
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: string
# top_edge_percent: 20.0
# device: cuda:7
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: True
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: N/A
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run GNN_Disentangle_GAT_string_20.0_64_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_sim_gnn
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation/runs/2qqhvafc
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211102_141952-2qqhvafc
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_string_20.0_64_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 101013 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:9
# combo_seen1:52
# combo_seen2:18
# unseen_single:37
# Creating dataloaders....
# Dataloaders created...
# Finished data setup, in total takes 0.907 min
# Initializing model...
# Start Training...
# Epoch 1 Step 1 Train Loss: 0.7315
# Epoch 1 Step 51 Train Loss: -0.0045
# Epoch 1 Step 101 Train Loss: -0.0495
# Epoch 1 Step 151 Train Loss: -0.0945
# Epoch 1 Step 201 Train Loss: -0.1065
# Epoch 1 Step 251 Train Loss: -0.1432
# Epoch 1 Step 301 Train Loss: -0.1738
# Epoch 1 Step 351 Train Loss: 0.1945
# Epoch 1 Step 401 Train Loss: -0.0961
# Epoch 1 Step 451 Train Loss: -0.1536
# Epoch 1 Step 501 Train Loss: -0.1658
# Epoch 1 Step 551 Train Loss: -0.1518
# Epoch 1 Step 601 Train Loss: -0.1249
# Epoch 1 Step 651 Train Loss: -0.1438
# Epoch 1 Step 701 Train Loss: -0.1805
# Epoch 1 Step 751 Train Loss: -0.1703
# Epoch 1 Step 801 Train Loss: -0.1538
# Epoch 1 Step 851 Train Loss: -0.1837
# Epoch 1 Step 901 Train Loss: -0.1128
# Epoch 1 Step 951 Train Loss: -0.1337
# Epoch 1 Step 1001 Train Loss: -0.1240
# Epoch 1 Step 1051 Train Loss: -0.1785
# Epoch 1 Step 1101 Train Loss: -0.1703
# Epoch 1 Step 1151 Train Loss: -0.0878
# Epoch 1 Step 1201 Train Loss: -0.1481
# Epoch 1 Step 1251 Train Loss: -0.1496
# Epoch 1 Step 1301 Train Loss: -0.1555
# Epoch 1 Step 1351 Train Loss: -0.1362
# Epoch 1 Step 1401 Train Loss: -0.1883
# Epoch 1 Step 1451 Train Loss: -0.1609
# Epoch 1 Step 1501 Train Loss: -0.1968
# Epoch 1 Step 1551 Train Loss: -0.1715
# Epoch 1 Step 1601 Train Loss: -0.1656
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 1: Train: 0.0307, R2 0.7559 Validation: 0.0317. R2 0.7461 Loss: -0.1447
# DE_Train: 0.4791, R2 -0.1156 DE_Validation: 0.4728. R2 -0.4126
# Epoch 2 Step 1 Train Loss: -0.1811
# Epoch 2 Step 51 Train Loss: -0.1998
# Epoch 2 Step 101 Train Loss: -0.2033
# Epoch 2 Step 151 Train Loss: -0.1921
# Epoch 2 Step 201 Train Loss: -0.1922
# Epoch 2 Step 251 Train Loss: -0.1369
# Epoch 2 Step 301 Train Loss: -0.2068
# Epoch 2 Step 351 Train Loss: -0.1917
# Epoch 2 Step 401 Train Loss: -0.2007
# Epoch 2 Step 451 Train Loss: -0.1826
# Epoch 2 Step 501 Train Loss: -0.1995
# Epoch 2 Step 551 Train Loss: -0.2164
# Epoch 2 Step 601 Train Loss: -0.1899
# Epoch 2 Step 651 Train Loss: -0.2071
# Epoch 2 Step 701 Train Loss: -0.1883
# Epoch 2 Step 751 Train Loss: -0.2003
# Epoch 2 Step 801 Train Loss: -0.1915
# Epoch 2 Step 851 Train Loss: -0.2136
# Epoch 2 Step 901 Train Loss: -0.2039
# Epoch 2 Step 951 Train Loss: -0.1940
# Epoch 2 Step 1001 Train Loss: -0.2167
# Epoch 2 Step 1051 Train Loss: -0.1671
# Epoch 2 Step 1101 Train Loss: -0.1962
# Epoch 2 Step 1151 Train Loss: -0.1814
# Epoch 2 Step 1201 Train Loss: -0.2030
# Epoch 2 Step 1251 Train Loss: -0.1628
# Epoch 2 Step 1301 Train Loss: -0.2013
# Epoch 2 Step 1351 Train Loss: -0.2050
# Epoch 2 Step 1401 Train Loss: -0.1907
# Epoch 2 Step 1451 Train Loss: -0.1712
# Epoch 2 Step 1501 Train Loss: -0.1958
# Epoch 2 Step 1551 Train Loss: -0.1467
# Epoch 2 Step 1601 Train Loss: -0.1871
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 2: Train: 0.0215, R2 0.8493 Validation: 0.0208. R2 0.8513 Loss: -0.1811
# DE_Train: 0.2628, R2 -0.7229 DE_Validation: 0.2775. R2 -0.6594
# Epoch 3 Step 1 Train Loss: -0.1958
# Epoch 3 Step 51 Train Loss: -0.1905
# Epoch 3 Step 101 Train Loss: -0.2137
# Epoch 3 Step 151 Train Loss: -0.2014
# Epoch 3 Step 201 Train Loss: -0.2088
# Epoch 3 Step 251 Train Loss: -0.2257
# Epoch 3 Step 301 Train Loss: -0.1960
# Epoch 3 Step 351 Train Loss: -0.1973
# Epoch 3 Step 401 Train Loss: -0.1863
# Epoch 3 Step 451 Train Loss: -0.2086
# Epoch 3 Step 501 Train Loss: -0.2153
# Epoch 3 Step 551 Train Loss: -0.2185
# Epoch 3 Step 601 Train Loss: -0.2339
# Epoch 3 Step 651 Train Loss: -0.1467
# Epoch 3 Step 701 Train Loss: -0.2003
# Epoch 3 Step 751 Train Loss: -0.1439
# Epoch 3 Step 801 Train Loss: -0.1983
# Epoch 3 Step 851 Train Loss: -0.2228
# Epoch 3 Step 901 Train Loss: -0.1603
# Epoch 3 Step 951 Train Loss: -0.2218
# Epoch 3 Step 1001 Train Loss: -0.1772
# Epoch 3 Step 1051 Train Loss: -0.1853
# Epoch 3 Step 1101 Train Loss: -0.2153
# Epoch 3 Step 1151 Train Loss: -0.1937
# Epoch 3 Step 1201 Train Loss: -0.1750
# Epoch 3 Step 1251 Train Loss: -0.2196
# Epoch 3 Step 1301 Train Loss: -0.2005
# Epoch 3 Step 1351 Train Loss: -0.2208
# Epoch 3 Step 1401 Train Loss: -0.2201
# Epoch 3 Step 1451 Train Loss: -0.2152
# Epoch 3 Step 1501 Train Loss: -0.1541
# Epoch 3 Step 1551 Train Loss: -0.2063
# Epoch 3 Step 1601 Train Loss: -0.1999
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 3: Train: 0.0395, R2 0.3811 Validation: 0.0391. R2 0.3732 Loss: -0.1965
# DE_Train: 0.6239, R2 -1.8674 DE_Validation: 0.5327. R2 -1.6026
# Epoch 4 Step 1 Train Loss: -0.2088
# Epoch 4 Step 51 Train Loss: -0.2186
# Epoch 4 Step 101 Train Loss: -0.2346
# Epoch 4 Step 151 Train Loss: -0.1633
# Epoch 4 Step 201 Train Loss: -0.1592
# Epoch 4 Step 251 Train Loss: -0.2324
# Epoch 4 Step 301 Train Loss: -0.2167
# Epoch 4 Step 351 Train Loss: -0.2442
# Epoch 4 Step 401 Train Loss: -0.2348
# Epoch 4 Step 451 Train Loss: -0.2045
# Epoch 4 Step 501 Train Loss: -0.2244
# Epoch 4 Step 551 Train Loss: -0.2320
# Epoch 4 Step 601 Train Loss: -0.2265
# Epoch 4 Step 651 Train Loss: -0.2173
# Epoch 4 Step 701 Train Loss: -0.2358
# Epoch 4 Step 751 Train Loss: -0.2170
# Epoch 4 Step 801 Train Loss: -0.2198
# Epoch 4 Step 851 Train Loss: -0.2359
# Epoch 4 Step 901 Train Loss: -0.1868
# Epoch 4 Step 951 Train Loss: -0.2378
# Epoch 4 Step 1001 Train Loss: -0.1953
# Epoch 4 Step 1051 Train Loss: -0.2384
# Epoch 4 Step 1101 Train Loss: -0.2035
# Epoch 4 Step 1151 Train Loss: -0.1815
# Epoch 4 Step 1201 Train Loss: -0.2052
# Epoch 4 Step 1251 Train Loss: -0.2192
# Epoch 4 Step 1301 Train Loss: -0.2349
# Epoch 4 Step 1351 Train Loss: -0.2235
# Epoch 4 Step 1401 Train Loss: -0.1998
# Epoch 4 Step 1451 Train Loss: -0.2345
# Epoch 4 Step 1501 Train Loss: -0.2090
# Epoch 4 Step 1551 Train Loss: -0.1876
# Epoch 4 Step 1601 Train Loss: -0.2123
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 4: Train: 0.0406, R2 0.3357 Validation: 0.0419. R2 0.2851 Loss: -0.2098
# DE_Train: 0.6841, R2 -2.5736 DE_Validation: 0.5858. R2 -2.1080
# Epoch 5 Step 1 Train Loss: -0.2326
# Epoch 5 Step 51 Train Loss: -0.2302
# Epoch 5 Step 101 Train Loss: -0.2240
# Epoch 5 Step 151 Train Loss: -0.1786
# Epoch 5 Step 201 Train Loss: -0.2304
# Epoch 5 Step 251 Train Loss: -0.2301
# Epoch 5 Step 301 Train Loss: -0.2076
# Epoch 5 Step 351 Train Loss: -0.2020
# Epoch 5 Step 401 Train Loss: -0.2405
# Epoch 5 Step 451 Train Loss: -0.2201
# Epoch 5 Step 501 Train Loss: -0.2228
# Epoch 5 Step 551 Train Loss: -0.2383
# Epoch 5 Step 601 Train Loss: -0.2286
# Epoch 5 Step 651 Train Loss: -0.2132
# Epoch 5 Step 701 Train Loss: -0.2296
# Epoch 5 Step 751 Train Loss: -0.2493
# Epoch 5 Step 801 Train Loss: -0.2343
# Epoch 5 Step 851 Train Loss: -0.2362
# Epoch 5 Step 901 Train Loss: -0.2214
# Epoch 5 Step 951 Train Loss: -0.1846
# Epoch 5 Step 1001 Train Loss: -0.2230
# Epoch 5 Step 1051 Train Loss: -0.2289
# Epoch 5 Step 1101 Train Loss: -0.1988
# Epoch 5 Step 1151 Train Loss: -0.2556
# Epoch 5 Step 1201 Train Loss: -0.1018
# Epoch 5 Step 1251 Train Loss: -0.2442
# Epoch 5 Step 1301 Train Loss: -0.2418
# Epoch 5 Step 1351 Train Loss: -0.2387
# Epoch 5 Step 1401 Train Loss: -0.2350
# Epoch 5 Step 1451 Train Loss: -0.2344
# Epoch 5 Step 1501 Train Loss: -0.2130
# Epoch 5 Step 1551 Train Loss: -0.2474
# Epoch 5 Step 1601 Train Loss: -0.2136
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 5: Train: 0.0180, R2 0.8702 Validation: 0.0185. R2 0.8630 Loss: -0.2200
# DE_Train: 0.2791, R2 -0.5770 DE_Validation: 0.2688. R2 -0.4215
# Epoch 6 Step 1 Train Loss: -0.2477
# Epoch 6 Step 51 Train Loss: -0.2243
# Epoch 6 Step 101 Train Loss: -0.1101
# Epoch 6 Step 151 Train Loss: -0.2487
# Epoch 6 Step 201 Train Loss: -0.2466
# Epoch 6 Step 251 Train Loss: -0.2297
# Epoch 6 Step 301 Train Loss: -0.2394
# Epoch 6 Step 351 Train Loss: -0.2195
# Epoch 6 Step 401 Train Loss: -0.2081
# Epoch 6 Step 451 Train Loss: -0.2193
# Epoch 6 Step 501 Train Loss: -0.2527
# Epoch 6 Step 551 Train Loss: -0.2405
# Epoch 6 Step 601 Train Loss: -0.2492
# Epoch 6 Step 651 Train Loss: -0.2415
# Epoch 6 Step 701 Train Loss: -0.2544
# Epoch 6 Step 751 Train Loss: -0.2541
# Epoch 6 Step 801 Train Loss: -0.2229
# Epoch 6 Step 851 Train Loss: -0.2307
# Epoch 6 Step 901 Train Loss: -0.2543
# Epoch 6 Step 951 Train Loss: -0.2500
# Epoch 6 Step 1001 Train Loss: -0.2538
# Epoch 6 Step 1051 Train Loss: -0.2453
# Epoch 6 Step 1101 Train Loss: -0.2075
# Epoch 6 Step 1151 Train Loss: -0.2345
# Epoch 6 Step 1201 Train Loss: -0.2555
# Epoch 6 Step 1251 Train Loss: -0.2293
# Epoch 6 Step 1301 Train Loss: -0.2413
# Epoch 6 Step 1351 Train Loss: -0.2484
# Epoch 6 Step 1401 Train Loss: -0.2596
# Epoch 6 Step 1451 Train Loss: -0.2390
# Epoch 6 Step 1501 Train Loss: -0.2139
# Epoch 6 Step 1551 Train Loss: -0.2250
# Epoch 6 Step 1601 Train Loss: -0.2021
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 6: Train: 0.0215, R2 0.8118 Validation: 0.0219. R2 0.8025 Loss: -0.2331
# DE_Train: 0.3345, R2 -0.7201 DE_Validation: 0.3068. R2 -0.5960
# Epoch 7 Step 1 Train Loss: -0.2009
# Epoch 7 Step 51 Train Loss: -0.2529
# Epoch 7 Step 101 Train Loss: -0.1862
# Epoch 7 Step 151 Train Loss: -0.2532
# Epoch 7 Step 201 Train Loss: -0.2639
# Epoch 7 Step 251 Train Loss: -0.2489
# Epoch 7 Step 301 Train Loss: -0.2186
# Epoch 7 Step 351 Train Loss: -0.2582
# Epoch 7 Step 401 Train Loss: -0.2341
# Epoch 7 Step 451 Train Loss: -0.2474
# Epoch 7 Step 501 Train Loss: -0.2599
# Epoch 7 Step 551 Train Loss: -0.2593
# Epoch 7 Step 601 Train Loss: -0.2481
# Epoch 7 Step 651 Train Loss: -0.2692
# Epoch 7 Step 701 Train Loss: -0.2662
# Epoch 7 Step 751 Train Loss: -0.2026
# Epoch 7 Step 801 Train Loss: -0.2653
# Epoch 7 Step 851 Train Loss: -0.2687
# Epoch 7 Step 901 Train Loss: -0.2271
# Epoch 7 Step 951 Train Loss: -0.2635
# Epoch 7 Step 1001 Train Loss: -0.2616
# Epoch 7 Step 1051 Train Loss: -0.2384
# Epoch 7 Step 1101 Train Loss: -0.2414
# Epoch 7 Step 1151 Train Loss: -0.2628
# Epoch 7 Step 1201 Train Loss: -0.1932
# Epoch 7 Step 1251 Train Loss: -0.2597
# Epoch 7 Step 1301 Train Loss: -0.2581
# Epoch 7 Step 1351 Train Loss: -0.2474
# Epoch 7 Step 1401 Train Loss: -0.2458
# Epoch 7 Step 1451 Train Loss: -0.2580
# Epoch 7 Step 1501 Train Loss: -0.1963
# Epoch 7 Step 1551 Train Loss: -0.2686
# Epoch 7 Step 1601 Train Loss: -0.2650
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 7: Train: 0.0196, R2 0.8974 Validation: 0.0201. R2 0.8928 Loss: -0.2434
# DE_Train: 0.2643, R2 -0.3699 DE_Validation: 0.2819. R2 -0.4953
# Epoch 8 Step 1 Train Loss: -0.2378
# Epoch 8 Step 51 Train Loss: -0.2742
# Epoch 8 Step 101 Train Loss: -0.2467
# Epoch 8 Step 151 Train Loss: -0.2311
# Epoch 8 Step 201 Train Loss: -0.2081
# Epoch 8 Step 251 Train Loss: -0.2532
# Epoch 8 Step 301 Train Loss: -0.2520
# Epoch 8 Step 351 Train Loss: -0.2360
# Epoch 8 Step 401 Train Loss: -0.2616
# Epoch 8 Step 451 Train Loss: -0.2639
# Epoch 8 Step 501 Train Loss: -0.1941
# Epoch 8 Step 551 Train Loss: -0.2190
# Epoch 8 Step 601 Train Loss: -0.2511
# Epoch 8 Step 651 Train Loss: -0.2436
# Epoch 8 Step 701 Train Loss: -0.2332
# Epoch 8 Step 751 Train Loss: -0.2539
# Epoch 8 Step 801 Train Loss: -0.2460
# Epoch 8 Step 851 Train Loss: -0.2079
# Epoch 8 Step 901 Train Loss: -0.2065
# Epoch 8 Step 951 Train Loss: -0.2765
# Epoch 8 Step 1001 Train Loss: -0.2728
# Epoch 8 Step 1051 Train Loss: -0.2681
# Epoch 8 Step 1101 Train Loss: -0.2665
# Epoch 8 Step 1151 Train Loss: -0.2679
# Epoch 8 Step 1201 Train Loss: -0.2428
# Epoch 8 Step 1251 Train Loss: -0.2493
# Epoch 8 Step 1301 Train Loss: -0.2583
# Epoch 8 Step 1351 Train Loss: -0.2527
# Epoch 8 Step 1401 Train Loss: -0.2355
# Epoch 8 Step 1451 Train Loss: -0.2555
# Epoch 8 Step 1501 Train Loss: -0.2693
# Epoch 8 Step 1551 Train Loss: -0.2453
# Epoch 8 Step 1601 Train Loss: -0.2748
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 8: Train: 0.0171, R2 0.8820 Validation: 0.0175. R2 0.8764 Loss: -0.2479
# DE_Train: 0.2661, R2 -0.4704 DE_Validation: 0.2611. R2 -0.4583
# Epoch 9 Step 1 Train Loss: -0.2665
# Epoch 9 Step 51 Train Loss: -0.2535
# Epoch 9 Step 101 Train Loss: -0.2396
# Epoch 9 Step 151 Train Loss: -0.2694
# Epoch 9 Step 201 Train Loss: -0.2660
# Epoch 9 Step 251 Train Loss: -0.2724
# Epoch 9 Step 301 Train Loss: -0.2547
# Epoch 9 Step 351 Train Loss: -0.2141
# Epoch 9 Step 401 Train Loss: -0.2517
# Epoch 9 Step 451 Train Loss: -0.2583
# Epoch 9 Step 501 Train Loss: -0.2563
# Epoch 9 Step 551 Train Loss: -0.2388
# Epoch 9 Step 601 Train Loss: -0.1355
# Epoch 9 Step 651 Train Loss: -0.2239
# Epoch 9 Step 701 Train Loss: -0.2651
# Epoch 9 Step 751 Train Loss: -0.2497
# Epoch 9 Step 801 Train Loss: -0.2570
# Epoch 9 Step 851 Train Loss: -0.2554
# Epoch 9 Step 901 Train Loss: -0.2603
# Epoch 9 Step 951 Train Loss: -0.2481
# Epoch 9 Step 1001 Train Loss: -0.2773
# Epoch 9 Step 1051 Train Loss: -0.2503
# Epoch 9 Step 1101 Train Loss: -0.2602
# Epoch 9 Step 1151 Train Loss: -0.2286
# Epoch 9 Step 1201 Train Loss: -0.2761
# Epoch 9 Step 1251 Train Loss: -0.2550
# Epoch 9 Step 1301 Train Loss: -0.2009
# Epoch 9 Step 1351 Train Loss: -0.2289
# Epoch 9 Step 1401 Train Loss: -0.2522
# Epoch 9 Step 1451 Train Loss: -0.2638
# Epoch 9 Step 1501 Train Loss: -0.2718
# Epoch 9 Step 1551 Train Loss: -0.2333
# Epoch 9 Step 1601 Train Loss: -0.2716
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 9: Train: 0.0169, R2 0.8792 Validation: 0.0172. R2 0.8736 Loss: -0.2507
# DE_Train: 0.2712, R2 -0.4465 DE_Validation: 0.2635. R2 -0.4171
# Epoch 10 Step 1 Train Loss: -0.2374
# Epoch 10 Step 51 Train Loss: -0.2291
# Epoch 10 Step 101 Train Loss: -0.2505
# Epoch 10 Step 151 Train Loss: -0.1998
# Epoch 10 Step 201 Train Loss: -0.2527
# Epoch 10 Step 251 Train Loss: -0.2685
# Epoch 10 Step 301 Train Loss: -0.2716
# Epoch 10 Step 351 Train Loss: -0.0711
# Epoch 10 Step 401 Train Loss: -0.2796
# Epoch 10 Step 451 Train Loss: -0.2715
# Epoch 10 Step 501 Train Loss: -0.2525
# Epoch 10 Step 551 Train Loss: -0.2654
# Epoch 10 Step 601 Train Loss: -0.2696
# Epoch 10 Step 651 Train Loss: -0.2640
# Epoch 10 Step 701 Train Loss: -0.2325
# Epoch 10 Step 751 Train Loss: -0.2752
# Epoch 10 Step 801 Train Loss: -0.2664
# Epoch 10 Step 851 Train Loss: -0.2727
# Epoch 10 Step 901 Train Loss: -0.2708
# Epoch 10 Step 951 Train Loss: -0.2749
# Epoch 10 Step 1001 Train Loss: -0.2618
# Epoch 10 Step 1051 Train Loss: -0.2251
# Epoch 10 Step 1101 Train Loss: -0.2398
# Epoch 10 Step 1151 Train Loss: -0.2706
# Epoch 10 Step 1201 Train Loss: -0.2457
# Epoch 10 Step 1251 Train Loss: -0.2287
# Epoch 10 Step 1301 Train Loss: -0.2778
# Epoch 10 Step 1351 Train Loss: -0.2196
# Epoch 10 Step 1401 Train Loss: -0.2295
# Epoch 10 Step 1451 Train Loss: -0.2429
# Epoch 10 Step 1501 Train Loss: -0.2620
# Epoch 10 Step 1551 Train Loss: -0.2714
# Epoch 10 Step 1601 Train Loss: -0.2329
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 10: Train: 0.0172, R2 0.8814 Validation: 0.0175. R2 0.8762 Loss: -0.2523
# DE_Train: 0.2625, R2 -0.4233 DE_Validation: 0.2593. R2 -0.4207
# Saving model....
# Start testing....
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Final best performing model: Test_DE: 0.2883, R2 -0.8699
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# ...
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_fold_change_gap_all ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_40_60 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_45_55 ▁
# wandb:                   test_SYNERGY_SIMILAR_PHENO_mean_sigma ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top100_de ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top200_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top20_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top50_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:                    test_combo_seen0_fold_change_gap_all ▁
# wandb:            test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:               test_combo_seen0_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen0_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen0_frac_in_range ▁
# wandb:                    test_combo_seen0_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen0_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen0_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen0_mae ▁
# wandb:                                 test_combo_seen0_mae_de ▁
# wandb:                             test_combo_seen0_mean_sigma ▁
# wandb:                                    test_combo_seen0_mse ▁
# wandb:                                 test_combo_seen0_mse_de ▁
# wandb:                          test_combo_seen0_mse_top100_de ▁
# wandb:                          test_combo_seen0_mse_top200_de ▁
# wandb:                         test_combo_seen0_mse_top200_hvg ▁
# wandb:                           test_combo_seen0_mse_top20_de ▁
# wandb:                           test_combo_seen0_mse_top50_de ▁
# wandb:                                test_combo_seen0_pearson ▁
# wandb:                             test_combo_seen0_pearson_de ▁
# wandb:                          test_combo_seen0_pearson_delta ▁
# wandb:                       test_combo_seen0_pearson_delta_de ▁
# wandb:                test_combo_seen0_pearson_delta_top100_de ▁
# wandb:                test_combo_seen0_pearson_delta_top200_de ▁
# wandb:               test_combo_seen0_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen0_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen0_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen0_pearson_top100_de ▁
# wandb:                      test_combo_seen0_pearson_top200_de ▁
# wandb:                     test_combo_seen0_pearson_top200_hvg ▁
# wandb:                       test_combo_seen0_pearson_top20_de ▁
# wandb:                       test_combo_seen0_pearson_top50_de ▁
# wandb:                                     test_combo_seen0_r2 ▁
# wandb:                                  test_combo_seen0_r2_de ▁
# wandb:                               test_combo_seen0_spearman ▁
# wandb:                            test_combo_seen0_spearman_de ▁
# wandb:                              test_combo_seen0_std_sigma ▁
# wandb:                    test_combo_seen1_fold_change_gap_all ▁
# wandb:            test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen1_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen1_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen1_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen1_frac_in_range ▁
# wandb:                    test_combo_seen1_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen1_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen1_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen1_mae ▁
# wandb:                                 test_combo_seen1_mae_de ▁
# wandb:                             test_combo_seen1_mean_sigma ▁
# wandb:                                    test_combo_seen1_mse ▁
# wandb:                                 test_combo_seen1_mse_de ▁
# wandb:                          test_combo_seen1_mse_top100_de ▁
# wandb:                          test_combo_seen1_mse_top200_de ▁
# wandb:                         test_combo_seen1_mse_top200_hvg ▁
# wandb:                           test_combo_seen1_mse_top20_de ▁
# wandb:                           test_combo_seen1_mse_top50_de ▁
# wandb:                                test_combo_seen1_pearson ▁
# wandb:                             test_combo_seen1_pearson_de ▁
# wandb:                          test_combo_seen1_pearson_delta ▁
# wandb:                       test_combo_seen1_pearson_delta_de ▁
# wandb:                test_combo_seen1_pearson_delta_top100_de ▁
# wandb:                test_combo_seen1_pearson_delta_top200_de ▁
# wandb:               test_combo_seen1_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen1_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen1_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen1_pearson_top100_de ▁
# wandb:                      test_combo_seen1_pearson_top200_de ▁
# wandb:                     test_combo_seen1_pearson_top200_hvg ▁
# wandb:                       test_combo_seen1_pearson_top20_de ▁
# wandb:                       test_combo_seen1_pearson_top50_de ▁
# wandb:                                     test_combo_seen1_r2 ▁
# wandb:                                  test_combo_seen1_r2_de ▁
# wandb:                               test_combo_seen1_spearman ▁
# wandb:                            test_combo_seen1_spearman_de ▁
# wandb:                              test_combo_seen1_std_sigma ▁
# wandb:                    test_combo_seen2_fold_change_gap_all ▁
# wandb:            test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen2_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen2_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen2_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen2_frac_in_range ▁
# wandb:                    test_combo_seen2_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen2_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen2_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen2_mae ▁
# wandb:                                 test_combo_seen2_mae_de ▁
# wandb:                             test_combo_seen2_mean_sigma ▁
# wandb:                                    test_combo_seen2_mse ▁
# wandb:                                 test_combo_seen2_mse_de ▁
# wandb:                          test_combo_seen2_mse_top100_de ▁
# wandb:                          test_combo_seen2_mse_top200_de ▁
# wandb:                         test_combo_seen2_mse_top200_hvg ▁
# wandb:                           test_combo_seen2_mse_top20_de ▁
# wandb:                           test_combo_seen2_mse_top50_de ▁
# wandb:                                test_combo_seen2_pearson ▁
# wandb:                             test_combo_seen2_pearson_de ▁
# wandb:                          test_combo_seen2_pearson_delta ▁
# wandb:                       test_combo_seen2_pearson_delta_de ▁
# wandb:                test_combo_seen2_pearson_delta_top100_de ▁
# wandb:                test_combo_seen2_pearson_delta_top200_de ▁
# wandb:               test_combo_seen2_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen2_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen2_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen2_pearson_top100_de ▁
# wandb:                      test_combo_seen2_pearson_top200_de ▁
# wandb:                     test_combo_seen2_pearson_top200_hvg ▁
# wandb:                       test_combo_seen2_pearson_top20_de ▁
# wandb:                       test_combo_seen2_pearson_top50_de ▁
# wandb:                                     test_combo_seen2_r2 ▁
# wandb:                                  test_combo_seen2_r2_de ▁
# wandb:                               test_combo_seen2_spearman ▁
# wandb:                            test_combo_seen2_spearman_de ▁
# wandb:                              test_combo_seen2_std_sigma ▁
# wandb:                                             test_de_mae ▁
# wandb:                                             test_de_mse ▁
# wandb:                                         test_de_pearson ▁
# wandb:                                              test_de_r2 ▁
# wandb:                                        test_de_spearman ▁
# wandb:                                test_fold_change_gap_all ▁
# wandb:                        test_fold_change_gap_downreg_0.1
# wandb:                       test_fold_change_gap_downreg_0.33 ▁
# wandb:                           test_fold_change_gap_upreg_10 ▁
# wandb:                            test_fold_change_gap_upreg_3 ▁
# wandb:                                      test_frac_in_range ▁
# wandb:                                test_frac_in_range_25_75 ▁
# wandb:                                test_frac_in_range_40_60 ▁
# wandb:                                test_frac_in_range_45_55 ▁
# wandb:                                 test_frac_sigma_below_1 ▁
# wandb:                                 test_frac_sigma_below_2 ▁
# wandb:                                                test_mae ▁
# wandb:                                         test_mean_sigma ▁
# wandb:                                                test_mse ▁
# wandb:                                      test_mse_top100_de ▁
# wandb:                                      test_mse_top200_de ▁
# wandb:                                     test_mse_top200_hvg ▁
# wandb:                                       test_mse_top20_de ▁
# wandb:                                       test_mse_top50_de ▁
# wandb:                                            test_pearson ▁
# wandb:                                      test_pearson_delta ▁
# wandb:                                   test_pearson_delta_de ▁
# wandb:                            test_pearson_delta_top100_de ▁
# wandb:                            test_pearson_delta_top200_de ▁
# wandb:                           test_pearson_delta_top200_hvg ▁
# wandb:                             test_pearson_delta_top20_de ▁
# wandb:                             test_pearson_delta_top50_de ▁
# wandb:                                  test_pearson_top100_de ▁
# wandb:                                  test_pearson_top200_de ▁
# wandb:                                 test_pearson_top200_hvg ▁
# wandb:                                   test_pearson_top20_de ▁
# wandb:                                   test_pearson_top50_de ▁
# wandb:                                                 test_r2 ▁
# wandb:                                           test_spearman ▁
# wandb:                                          test_std_sigma ▁
# wandb:                  test_unseen_single_fold_change_gap_all ▁
# wandb:          test_unseen_single_fold_change_gap_downreg_0.1
# wandb:         test_unseen_single_fold_change_gap_downreg_0.33
# wandb:             test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:              test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                        test_unseen_single_frac_in_range ▁
# wandb:                  test_unseen_single_frac_in_range_25_75 ▁
# wandb:                  test_unseen_single_frac_in_range_40_60 ▁
# wandb:                  test_unseen_single_frac_in_range_45_55 ▁
# wandb:                   test_unseen_single_frac_sigma_below_1 ▁
# wandb:                   test_unseen_single_frac_sigma_below_2 ▁
# wandb:                                  test_unseen_single_mae ▁
# wandb:                               test_unseen_single_mae_de ▁
# wandb:                           test_unseen_single_mean_sigma ▁
# wandb:                                  test_unseen_single_mse ▁
# wandb:                               test_unseen_single_mse_de ▁
# wandb:                        test_unseen_single_mse_top100_de ▁
# wandb:                        test_unseen_single_mse_top200_de ▁
# wandb:                       test_unseen_single_mse_top200_hvg ▁
# wandb:                         test_unseen_single_mse_top20_de ▁
# wandb:                         test_unseen_single_mse_top50_de ▁
# wandb:                              test_unseen_single_pearson ▁
# wandb:                           test_unseen_single_pearson_de ▁
# wandb:                        test_unseen_single_pearson_delta ▁
# wandb:                     test_unseen_single_pearson_delta_de ▁
# wandb:              test_unseen_single_pearson_delta_top100_de ▁
# wandb:              test_unseen_single_pearson_delta_top200_de ▁
# wandb:             test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:               test_unseen_single_pearson_delta_top20_de ▁
# wandb:               test_unseen_single_pearson_delta_top50_de ▁
# wandb:                    test_unseen_single_pearson_top100_de ▁
# wandb:                    test_unseen_single_pearson_top200_de ▁
# wandb:                   test_unseen_single_pearson_top200_hvg ▁
# wandb:                     test_unseen_single_pearson_top20_de ▁
# wandb:                     test_unseen_single_pearson_top50_de ▁
# wandb:                                   test_unseen_single_r2 ▁
# wandb:                                test_unseen_single_r2_de ▁
# wandb:                             test_unseen_single_spearman ▁
# wandb:                          test_unseen_single_spearman_de ▁
# wandb:                            test_unseen_single_std_sigma ▁
# wandb:                                            train_de_mae ▅▁▇█▁▃▁▁▁▁
# wandb:                                            train_de_mse ▅▁▇█▁▂▁▁▁▁
# wandb:                                        train_de_pearson ▁█████▇███
# wandb:                                             train_de_r2 █▆▃▁▇▆▇▇▇▇
# wandb:                                       train_de_spearman ▁▆██▇█▇▇▇▇
# wandb:                                               train_mae █▇▇█▂▄▃▁▁▁
# wandb:                                               train_mse ▅▂██▁▂▂▁▁▁
# wandb:                                           train_pearson ▁▆▁▁▇▅█▇▇▇
# wandb:                                                train_r2 ▆▇▂▁█▇████
# wandb:                                          train_spearman ▁▄▅▆█▇████
# wandb:                                           training_loss █▅▅▅▅▄▄▃▃▂▃▄▃▂▂▃▂▂▂▃▂▂▃▂▁▁▁▂▂▂▁▁▃▁▁▂▁▃▁▁
# wandb:                                              val_de_mae ▇▂▇█▁▃▂▁▁▁
# wandb:                                              val_de_mse ▆▁▇█▁▂▁▁▁▁
# wandb:                                          val_de_pearson ▁▇▆▆██████
# wandb:                                               val_de_r2 █▇▃▁█▇████
# wandb:                                         val_de_spearman ▁▇▆▇▇█▆▇██
# wandb:                                                 val_mae █▆▆█▂▄▄▁▁▁
# wandb:                                                 val_mse ▅▂▇█▁▂▂▁▁▁
# wandb:                                             val_pearson ▂▇▂▁▇▆█▇▇▇
# wandb:                                                  val_r2 ▆█▂▁█▇████
# wandb:                                            val_spearman ▁▅▆▇█▇████
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced GNN_Disentangle_GAT_string_20.0_64_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_sim_gnn: https://wandb.ai/kexinhuang/pert_gnn_simulation/runs/2qqhvafc
