# %%
# !python train.py --dataset Norman2019 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 128 \
                 --gnn_num_layers 2 \
                 --loss_mode l3 \
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:5 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --no_gnn \
                 --wandb \
                 --exp_name no_gnn
# Out:
# ---- Printing Arguments ----
# dataset: Norman2019
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:5
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 128
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: True
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: no_gnn
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run no_gnn
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/1khbhghr
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211107_095303-1khbhghr
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_co-expression_100.0_128_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 24886 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Epoch 2 Step 951 Train Loss: 0.0439
# Epoch 2 Step 1001 Train Loss: 0.0506
# Epoch 2 Step 1051 Train Loss: 0.0482
# Epoch 2 Step 1101 Train Loss: 0.0423
# Epoch 2 Step 1151 Train Loss: 0.0378
# Epoch 2 Step 1201 Train Loss: 0.0368
# Epoch 2 Step 1251 Train Loss: 0.0408
# Epoch 2 Step 1301 Train Loss: 0.0555
# Epoch 2 Step 1351 Train Loss: 0.0845
# Epoch 2 Step 1401 Train Loss: 0.0358
# Epoch 2 Step 1451 Train Loss: 0.0647
# Epoch 2 Step 1501 Train Loss: 0.0523
# Epoch 2 Step 1551 Train Loss: 0.0832
# Epoch 2 Step 1601 Train Loss: 0.0372
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 2: Train: 0.0553, R2 0.8173 Validation: 0.0552. R2 0.8179 Loss: 0.0440
# DE_Train: 0.5700, R2 0.1268 DE_Validation: 0.6074. R2 0.1264
# Epoch 3 Step 1 Train Loss: 0.0375
# Epoch 3 Step 51 Train Loss: 0.0517
# Epoch 3 Step 101 Train Loss: 0.0483
# Epoch 3 Step 151 Train Loss: 0.0293
# Epoch 3 Step 201 Train Loss: 0.0367
# Epoch 3 Step 251 Train Loss: 0.0364
# Epoch 3 Step 301 Train Loss: 0.0662
# Epoch 3 Step 351 Train Loss: 0.0285
# Epoch 3 Step 401 Train Loss: 0.0367
# Epoch 3 Step 451 Train Loss: 0.0380
# Epoch 3 Step 501 Train Loss: 0.0273
# Epoch 3 Step 551 Train Loss: 0.0352
# Epoch 3 Step 601 Train Loss: 0.0516
# Epoch 3 Step 651 Train Loss: 0.0254
# Epoch 3 Step 701 Train Loss: 0.0316
# Epoch 3 Step 751 Train Loss: 0.0409
# Epoch 3 Step 801 Train Loss: 0.0424
# Epoch 3 Step 851 Train Loss: 0.0453
# Epoch 3 Step 901 Train Loss: 0.0456
# Epoch 3 Step 951 Train Loss: 0.0401
# Epoch 3 Step 1001 Train Loss: 0.0511
# Epoch 3 Step 1051 Train Loss: 0.0321
# Epoch 3 Step 1101 Train Loss: 0.0392
# Epoch 3 Step 1151 Train Loss: 0.0395
# Epoch 3 Step 1201 Train Loss: 0.0297
# Epoch 3 Step 1251 Train Loss: 0.0326
# Epoch 3 Step 1301 Train Loss: 0.0548
# Epoch 3 Step 1351 Train Loss: 0.0497
# Epoch 3 Step 1401 Train Loss: 0.0311
# Epoch 3 Step 1451 Train Loss: 0.0304
# Epoch 3 Step 1501 Train Loss: 0.0415
# Epoch 3 Step 1551 Train Loss: 0.0280
# Epoch 3 Step 1601 Train Loss: 0.0370
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 3: Train: 0.0209, R2 0.8905 Validation: 0.0174. R2 0.9037 Loss: 0.0418
# DE_Train: 0.3280, R2 0.4577 DE_Validation: 0.3251. R2 0.4509
# Epoch 4 Step 1 Train Loss: 0.0396
# Epoch 4 Step 51 Train Loss: 0.0482
# Epoch 4 Step 101 Train Loss: 0.0252
# Epoch 4 Step 151 Train Loss: 0.0367
# Epoch 4 Step 201 Train Loss: 0.0339
# Epoch 4 Step 251 Train Loss: 0.0331
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 5: Train: 0.0171, R2 0.8542 Validation: 0.0166. R2 0.8632 Loss: 0.0405
# DE_Train: 0.2473, R2 -0.4821 DE_Validation: 0.2624. R2 0.0027
# Epoch 6 Step 1 Train Loss: 0.0324
# Epoch 6 Step 51 Train Loss: 0.0395
# Epoch 6 Step 101 Train Loss: 0.0418
# Epoch 6 Step 151 Train Loss: 0.0448
# Epoch 6 Step 201 Train Loss: 0.0323
# Epoch 6 Step 251 Train Loss: 0.0413
# Epoch 6 Step 301 Train Loss: 0.0453
# Epoch 6 Step 351 Train Loss: 0.0447
# Epoch 6 Step 401 Train Loss: 0.0321
# Epoch 6 Step 451 Train Loss: 0.0395
# Epoch 6 Step 501 Train Loss: 0.0449
# Epoch 6 Step 551 Train Loss: 0.0450
# Epoch 6 Step 601 Train Loss: 0.0327
# Epoch 6 Step 651 Train Loss: 0.0291
# Epoch 6 Step 701 Train Loss: 0.0529
# Epoch 6 Step 751 Train Loss: 0.0426
# Epoch 6 Step 801 Train Loss: 0.0415
# Epoch 6 Step 851 Train Loss: 0.0442
# Epoch 6 Step 901 Train Loss: 0.0323
# Epoch 6 Step 951 Train Loss: 0.0443
# Epoch 6 Step 1001 Train Loss: 0.0265
# Epoch 6 Step 1051 Train Loss: 0.0398
# Epoch 6 Step 1101 Train Loss: 0.0382
# Epoch 6 Step 1151 Train Loss: 0.0277
# Epoch 6 Step 1201 Train Loss: 0.0425
# Epoch 6 Step 1251 Train Loss: 0.0406
# Epoch 6 Step 1301 Train Loss: 0.0470
# Epoch 6 Step 1351 Train Loss: 0.0455
# Epoch 6 Step 1401 Train Loss: 0.0363
# Epoch 6 Step 1451 Train Loss: 0.0320
# Epoch 6 Step 1501 Train Loss: 0.0342
# Epoch 6 Step 1551 Train Loss: 0.0396
# Epoch 6 Step 1601 Train Loss: 0.0285
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 6: Train: 0.0167, R2 0.8860 Validation: 0.0150. R2 0.8974 Loss: 0.0401
# DE_Train: 0.1929, R2 -0.4358 DE_Validation: 0.2249. R2 -0.2385
# Epoch 7 Step 1 Train Loss: 0.0564
# Epoch 7 Step 51 Train Loss: 0.0351
# Epoch 7 Step 101 Train Loss: 0.0357
# Epoch 7 Step 151 Train Loss: 0.0517
# Epoch 7 Step 201 Train Loss: 0.0520
# Epoch 7 Step 251 Train Loss: 0.0297
# Epoch 7 Step 301 Train Loss: 0.0236
# Epoch 7 Step 351 Train Loss: 0.0428
# Epoch 7 Step 401 Train Loss: 0.0388
# Epoch 7 Step 451 Train Loss: 0.0361
# Epoch 7 Step 501 Train Loss: 0.0322
# Epoch 7 Step 551 Train Loss: 0.0451
# Epoch 7 Step 601 Train Loss: 0.0428
# Epoch 7 Step 651 Train Loss: 0.0336
# Epoch 7 Step 701 Train Loss: 0.0512
# Epoch 7 Step 751 Train Loss: 0.0399
# Epoch 7 Step 801 Train Loss: 0.0441
# Epoch 7 Step 851 Train Loss: 0.0330
# Epoch 7 Step 901 Train Loss: 0.0541
# Epoch 7 Step 951 Train Loss: 0.0405
# Epoch 7 Step 1001 Train Loss: 0.0447
# Epoch 7 Step 1051 Train Loss: 0.0436
# Epoch 7 Step 1101 Train Loss: 0.0550
# Epoch 7 Step 1151 Train Loss: 0.0242
# Epoch 7 Step 1201 Train Loss: 0.0438
# Epoch 7 Step 1251 Train Loss: 0.0366
# Epoch 7 Step 1301 Train Loss: 0.0425
# Epoch 7 Step 1351 Train Loss: 0.0382
# Epoch 7 Step 1401 Train Loss: 0.0629
# Epoch 7 Step 1451 Train Loss: 0.0522
# Epoch 7 Step 1501 Train Loss: 0.0365
# Epoch 7 Step 1551 Train Loss: 0.0273
# Epoch 7 Step 1601 Train Loss: 0.0254
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 7: Train: 0.0197, R2 0.8804 Validation: 0.0181. R2 0.8863 Loss: 0.0395
# DE_Train: 0.1726, R2 -0.3426 DE_Validation: 0.2136. R2 -0.2719
# Epoch 8 Step 1 Train Loss: 0.0432
# Epoch 8 Step 51 Train Loss: 0.0348
# Epoch 8 Step 101 Train Loss: 0.0587
# Epoch 8 Step 151 Train Loss: 0.0294
# Epoch 8 Step 201 Train Loss: 0.0786
# Epoch 8 Step 251 Train Loss: 0.0341
# Epoch 8 Step 301 Train Loss: 0.0412
# Epoch 8 Step 351 Train Loss: 0.0338
# Epoch 8 Step 401 Train Loss: 0.0444
# Epoch 8 Step 451 Train Loss: 0.0406
# Epoch 8 Step 501 Train Loss: 0.0427
# Epoch 8 Step 551 Train Loss: 0.0339
# Epoch 8 Step 601 Train Loss: 0.0307
# Epoch 8 Step 651 Train Loss: 0.0384
# Epoch 8 Step 701 Train Loss: 0.0543
# Epoch 8 Step 751 Train Loss: 0.0259
# Epoch 8 Step 801 Train Loss: 0.0407
# Epoch 8 Step 851 Train Loss: 0.0410
# Epoch 8 Step 901 Train Loss: 0.0333
# Epoch 8 Step 951 Train Loss: 0.0462
# Epoch 8 Step 1001 Train Loss: 0.0484
# Epoch 8 Step 1051 Train Loss: 0.0287
# Epoch 8 Step 1101 Train Loss: 0.0334
# Epoch 8 Step 1151 Train Loss: 0.0435
# Epoch 8 Step 1201 Train Loss: 0.0411
# Epoch 8 Step 1251 Train Loss: 0.0335
# Epoch 8 Step 1301 Train Loss: 0.0430
# Epoch 8 Step 1351 Train Loss: 0.0479
# Epoch 8 Step 1401 Train Loss: 0.0426
# Epoch 8 Step 1451 Train Loss: 0.0460
# Epoch 8 Step 1501 Train Loss: 0.0249
# Epoch 8 Step 1551 Train Loss: 0.0319
# Epoch 8 Step 1601 Train Loss: 0.0502
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 8: Train: 0.0165, R2 0.8819 Validation: 0.0162. R2 0.8838 Loss: 0.0391
# DE_Train: 0.1774, R2 -0.3011 DE_Validation: 0.1979. R2 -0.2553
# Epoch 9 Step 1 Train Loss: 0.0284
# Epoch 9 Step 51 Train Loss: 0.0307
# Epoch 9 Step 101 Train Loss: 0.0311
# Epoch 9 Step 151 Train Loss: 0.0382
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 10: Train: 0.0162, R2 0.8898 Validation: 0.0160. R2 0.8884 Loss: 0.0387
# DE_Train: 0.1536, R2 -0.3774 DE_Validation: 0.1904. R2 -0.1130
# Saving model....
# Start testing....
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Final best performing model: Test_DE: 0.2076, R2 -1.4700
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
# ...
# wandb:              test_SYNERGY_DISSIMILAR_PHENO_mse_top20_de ▁
# wandb:              test_SYNERGY_DISSIMILAR_PHENO_mse_top50_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_fold_change_gap_all ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_40_60 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_45_55 ▁
# wandb:                   test_SYNERGY_SIMILAR_PHENO_mean_sigma ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top100_de ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top200_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top20_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top50_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:                    test_combo_seen0_fold_change_gap_all ▁
# wandb:            test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:               test_combo_seen0_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen0_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen0_frac_in_range ▁
# wandb:                    test_combo_seen0_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen0_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen0_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen0_mae ▁
# wandb:                                 test_combo_seen0_mae_de ▁
# wandb:                             test_combo_seen0_mean_sigma ▁
# wandb:                                    test_combo_seen0_mse ▁
# wandb:                                 test_combo_seen0_mse_de ▁
# wandb:                          test_combo_seen0_mse_top100_de ▁
# wandb:                          test_combo_seen0_mse_top200_de ▁
# wandb:                         test_combo_seen0_mse_top200_hvg ▁
# wandb:                           test_combo_seen0_mse_top20_de ▁
# wandb:                           test_combo_seen0_mse_top50_de ▁
# wandb:                                test_combo_seen0_pearson ▁
# wandb:                             test_combo_seen0_pearson_de ▁
# wandb:                          test_combo_seen0_pearson_delta ▁
# wandb:                       test_combo_seen0_pearson_delta_de ▁
# wandb:                test_combo_seen0_pearson_delta_top100_de ▁
# wandb:                test_combo_seen0_pearson_delta_top200_de ▁
# wandb:               test_combo_seen0_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen0_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen0_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen0_pearson_top100_de ▁
# wandb:                      test_combo_seen0_pearson_top200_de ▁
# wandb:                     test_combo_seen0_pearson_top200_hvg ▁
# wandb:                       test_combo_seen0_pearson_top20_de ▁
# wandb:                       test_combo_seen0_pearson_top50_de ▁
# wandb:                                     test_combo_seen0_r2 ▁
# wandb:                                  test_combo_seen0_r2_de ▁
# wandb:                               test_combo_seen0_spearman ▁
# wandb:                            test_combo_seen0_spearman_de ▁
# wandb:                              test_combo_seen0_std_sigma ▁
# wandb:                    test_combo_seen1_fold_change_gap_all ▁
# wandb:            test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen1_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen1_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen1_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen1_frac_in_range ▁
# wandb:                    test_combo_seen1_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen1_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen1_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen1_mae ▁
# wandb:                                 test_combo_seen1_mae_de ▁
# wandb:                             test_combo_seen1_mean_sigma ▁
# wandb:                                    test_combo_seen1_mse ▁
# wandb:                                 test_combo_seen1_mse_de ▁
# wandb:                          test_combo_seen1_mse_top100_de ▁
# wandb:                          test_combo_seen1_mse_top200_de ▁
# wandb:                         test_combo_seen1_mse_top200_hvg ▁
# wandb:                           test_combo_seen1_mse_top20_de ▁
# wandb:                           test_combo_seen1_mse_top50_de ▁
# wandb:                                test_combo_seen1_pearson ▁
# wandb:                             test_combo_seen1_pearson_de ▁
# wandb:                          test_combo_seen1_pearson_delta ▁
# wandb:                       test_combo_seen1_pearson_delta_de ▁
# wandb:                test_combo_seen1_pearson_delta_top100_de ▁
# wandb:                test_combo_seen1_pearson_delta_top200_de ▁
# wandb:               test_combo_seen1_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen1_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen1_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen1_pearson_top100_de ▁
# wandb:                      test_combo_seen1_pearson_top200_de ▁
# wandb:                     test_combo_seen1_pearson_top200_hvg ▁
# wandb:                       test_combo_seen1_pearson_top20_de ▁
# wandb:                       test_combo_seen1_pearson_top50_de ▁
# wandb:                                     test_combo_seen1_r2 ▁
# wandb:                                  test_combo_seen1_r2_de ▁
# wandb:                               test_combo_seen1_spearman ▁
# wandb:                            test_combo_seen1_spearman_de ▁
# wandb:                              test_combo_seen1_std_sigma ▁
# wandb:                    test_combo_seen2_fold_change_gap_all ▁
# wandb:            test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen2_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen2_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen2_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen2_frac_in_range ▁
# wandb:                    test_combo_seen2_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen2_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen2_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen2_mae ▁
# wandb:                                 test_combo_seen2_mae_de ▁
# wandb:                             test_combo_seen2_mean_sigma ▁
# wandb:                                    test_combo_seen2_mse ▁
# wandb:                                 test_combo_seen2_mse_de ▁
# wandb:                          test_combo_seen2_mse_top100_de ▁
# wandb:                          test_combo_seen2_mse_top200_de ▁
# wandb:                         test_combo_seen2_mse_top200_hvg ▁
# wandb:                           test_combo_seen2_mse_top20_de ▁
# wandb:                           test_combo_seen2_mse_top50_de ▁
# wandb:                                test_combo_seen2_pearson ▁
# wandb:                             test_combo_seen2_pearson_de ▁
# wandb:                          test_combo_seen2_pearson_delta ▁
# wandb:                       test_combo_seen2_pearson_delta_de ▁
# wandb:                test_combo_seen2_pearson_delta_top100_de ▁
# wandb:                test_combo_seen2_pearson_delta_top200_de ▁
# wandb:               test_combo_seen2_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen2_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen2_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen2_pearson_top100_de ▁
# wandb:                      test_combo_seen2_pearson_top200_de ▁
# wandb:                     test_combo_seen2_pearson_top200_hvg ▁
# wandb:                       test_combo_seen2_pearson_top20_de ▁
# wandb:                       test_combo_seen2_pearson_top50_de ▁
# wandb:                                     test_combo_seen2_r2 ▁
# wandb:                                  test_combo_seen2_r2_de ▁
# wandb:                               test_combo_seen2_spearman ▁
# wandb:                            test_combo_seen2_spearman_de ▁
# wandb:                              test_combo_seen2_std_sigma ▁
# wandb:                                             test_de_mae ▁
# wandb:                                             test_de_mse ▁
# wandb:                                         test_de_pearson ▁
# wandb:                                              test_de_r2 ▁
# wandb:                                        test_de_spearman ▁
# wandb:                                test_fold_change_gap_all ▁
# wandb:                        test_fold_change_gap_downreg_0.1
# wandb:                       test_fold_change_gap_downreg_0.33 ▁
# wandb:                           test_fold_change_gap_upreg_10 ▁
# wandb:                            test_fold_change_gap_upreg_3 ▁
# wandb:                                      test_frac_in_range ▁
# wandb:                                test_frac_in_range_25_75 ▁
# wandb:                                test_frac_in_range_40_60 ▁
# wandb:                                test_frac_in_range_45_55 ▁
# wandb:                                 test_frac_sigma_below_1 ▁
# wandb:                                 test_frac_sigma_below_2 ▁
# wandb:                                                test_mae ▁
# wandb:                                         test_mean_sigma ▁
# wandb:                                                test_mse ▁
# wandb:                                      test_mse_top100_de ▁
# wandb:                                      test_mse_top200_de ▁
# wandb:                                     test_mse_top200_hvg ▁
# wandb:                                       test_mse_top20_de ▁
# wandb:                                       test_mse_top50_de ▁
# wandb:                                            test_pearson ▁
# wandb:                                      test_pearson_delta ▁
# wandb:                                   test_pearson_delta_de ▁
# wandb:                            test_pearson_delta_top100_de ▁
# wandb:                            test_pearson_delta_top200_de ▁
# wandb:                           test_pearson_delta_top200_hvg ▁
# wandb:                             test_pearson_delta_top20_de ▁
# wandb:                             test_pearson_delta_top50_de ▁
# wandb:                                  test_pearson_top100_de ▁
# wandb:                                  test_pearson_top200_de ▁
# wandb:                                 test_pearson_top200_hvg ▁
# wandb:                                   test_pearson_top20_de ▁
# wandb:                                   test_pearson_top50_de ▁
# wandb:                                                 test_r2 ▁
# wandb:                                           test_spearman ▁
# wandb:                                          test_std_sigma ▁
# wandb:                  test_unseen_single_fold_change_gap_all ▁
# wandb:          test_unseen_single_fold_change_gap_downreg_0.1
# wandb:         test_unseen_single_fold_change_gap_downreg_0.33
# wandb:             test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:              test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                        test_unseen_single_frac_in_range ▁
# wandb:                  test_unseen_single_frac_in_range_25_75 ▁
# wandb:                  test_unseen_single_frac_in_range_40_60 ▁
# wandb:                  test_unseen_single_frac_in_range_45_55 ▁
# wandb:                   test_unseen_single_frac_sigma_below_1 ▁
# wandb:                   test_unseen_single_frac_sigma_below_2 ▁
# wandb:                                  test_unseen_single_mae ▁
# wandb:                               test_unseen_single_mae_de ▁
# wandb:                           test_unseen_single_mean_sigma ▁
# wandb:                                  test_unseen_single_mse ▁
# wandb:                               test_unseen_single_mse_de ▁
# wandb:                        test_unseen_single_mse_top100_de ▁
# wandb:                        test_unseen_single_mse_top200_de ▁
# wandb:                       test_unseen_single_mse_top200_hvg ▁
# wandb:                         test_unseen_single_mse_top20_de ▁
# wandb:                         test_unseen_single_mse_top50_de ▁
# wandb:                              test_unseen_single_pearson ▁
# wandb:                           test_unseen_single_pearson_de ▁
# wandb:                        test_unseen_single_pearson_delta ▁
# wandb:                     test_unseen_single_pearson_delta_de ▁
# wandb:              test_unseen_single_pearson_delta_top100_de ▁
# wandb:              test_unseen_single_pearson_delta_top200_de ▁
# wandb:             test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:               test_unseen_single_pearson_delta_top20_de ▁
# wandb:               test_unseen_single_pearson_delta_top50_de ▁
# wandb:                    test_unseen_single_pearson_top100_de ▁
# wandb:                    test_unseen_single_pearson_top200_de ▁
# wandb:                   test_unseen_single_pearson_top200_hvg ▁
# wandb:                     test_unseen_single_pearson_top20_de ▁
# wandb:                     test_unseen_single_pearson_top50_de ▁
# wandb:                                   test_unseen_single_r2 ▁
# wandb:                                test_unseen_single_r2_de ▁
# wandb:                             test_unseen_single_spearman ▁
# wandb:                          test_unseen_single_spearman_de ▁
# wandb:                            test_unseen_single_std_sigma ▁
# wandb:                                            train_de_mae ▅█▄▃▃▂▂▂▁▁
# wandb:                                            train_de_mse ▃█▄▂▃▂▁▁▁▁
# wandb:                                        train_de_pearson ▁▁▁▅▄▆▇███
# wandb:                                             train_de_r2 ▁▆█▅▃▃▄▄▄▄
# wandb:                                       train_de_spearman ▁▁▃▅▅▆▇███
# wandb:                                               train_mae █▅▁▄▂▂▃▂▂▂
# wandb:                                               train_mse █▇▂▃▁▁▂▁▁▁
# wandb:                                           train_pearson ▄█▁▆▅▇▆▆▆▆
# wandb:                                                train_r2 ▁▆█▆▇█████
# wandb:                                          train_spearman ▁▃▆▇▇█████
# wandb:                                           training_loss ▅▂▄▂▂▃▂▃▂▃█▂▃▁▂▄▃▁▄▃▂▃▂▂▃▁▃▂▃▆▁▄▃▁▂▂▆▅▁▄
# wandb:                                              val_de_mae ▅█▃▂▂▂▁▁▁▁
# wandb:                                              val_de_mse ▃█▃▂▂▂▁▁▁▁
# wandb:                                          val_de_pearson ▃▃▃▅▁▆▇███
# wandb:                                               val_de_r2 ▁▆█▄▅▃▃▃▄▄
# wandb:                                         val_de_spearman ▃▁▃▅▃▅▇███
# wandb:                                                 val_mae █▅▁▄▂▂▃▂▂▂
# wandb:                                                 val_mse █▇▁▃▁▁▁▁▁▁
# wandb:                                             val_pearson ▅█▁▅▄▆▆▆▆▆
# wandb:                                                  val_r2 ▁▆█▆▇█████
# wandb:                                            val_spearman ▁▃▆▇▇█████
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced no_gnn: https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/1khbhghr

# %%
# !python train.py --dataset Norman2019 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3 \
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:5 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --no_gnn \
                 --wandb \
                 --exp_name no_gnn_coexp_0.4_thr_with_recomb \
                 --sim_gnn_gene
# Out:
# ---- Printing Arguments ----
# dataset: Norman2019
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:5
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: True
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: True
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: no_gnn_coexp_0.4_thr_with_recomb
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run no_gnn_coexp_0.4_thr_with_recomb
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/2o3sry0i
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_200331-2o3sry0i
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_co-expression_100.0_64_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 24886 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:9
# combo_seen1:52
# combo_seen2:18
# unseen_single:37
# Creating dataloaders....
# Dataloaders created...
# /dfs/user/kexinh/perturb_GNN/kexin/utils.py:29: RuntimeWarning: invalid value encountered in true_divide
# Epoch 2 Step 1101 Train Loss: 0.0365
# Epoch 2 Step 1151 Train Loss: 0.0509
# Epoch 2 Step 1201 Train Loss: 0.0315
# Epoch 2 Step 1251 Train Loss: 0.0701
# Epoch 2 Step 1301 Train Loss: 0.0386
# Epoch 2 Step 1351 Train Loss: 0.0272
# Epoch 2 Step 1401 Train Loss: 0.0650
# Epoch 2 Step 1451 Train Loss: 0.0542
# Epoch 2 Step 1501 Train Loss: 0.0541
# Epoch 2 Step 1551 Train Loss: 0.0297
# Epoch 2 Step 1601 Train Loss: 0.0275
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 2: Train: 0.0224, R2 0.7862 Validation: 0.0227. R2 0.7840 Loss: 0.0452
# DE_Train: 0.3297, R2 -0.0225 DE_Validation: 0.2928. R2 0.2276
# Epoch 3 Step 1 Train Loss: 0.0271
# Epoch 3 Step 51 Train Loss: 0.0315
# Epoch 3 Step 101 Train Loss: 0.0287
# Epoch 3 Step 151 Train Loss: 0.0328
# Epoch 3 Step 201 Train Loss: 0.0333
# Epoch 3 Step 251 Train Loss: 0.0403
# Epoch 3 Step 301 Train Loss: 0.0315
# Epoch 3 Step 351 Train Loss: 0.0277
# Epoch 3 Step 401 Train Loss: 0.0377
# Epoch 3 Step 451 Train Loss: 0.0611
# Epoch 3 Step 501 Train Loss: 0.0229
# Epoch 3 Step 551 Train Loss: 0.0497
# Epoch 3 Step 601 Train Loss: 0.0415
# Epoch 3 Step 651 Train Loss: 0.0339
# Epoch 3 Step 701 Train Loss: 0.0702
# Epoch 3 Step 751 Train Loss: 0.0431
# Epoch 3 Step 801 Train Loss: 0.0328
# Epoch 3 Step 851 Train Loss: 0.0720
# Epoch 3 Step 901 Train Loss: 0.0436
# Epoch 3 Step 951 Train Loss: 0.0409
# Epoch 3 Step 1001 Train Loss: 0.0468
# Epoch 3 Step 1051 Train Loss: 0.0531
# Epoch 3 Step 1101 Train Loss: 0.0309
# Epoch 3 Step 1151 Train Loss: 0.0373
# Epoch 3 Step 1201 Train Loss: 0.0339
# Epoch 3 Step 1251 Train Loss: 0.0435
# Epoch 3 Step 1301 Train Loss: 0.0612
# Epoch 3 Step 1351 Train Loss: 0.0316
# Epoch 3 Step 1401 Train Loss: 0.0326
# Epoch 3 Step 1451 Train Loss: 0.0430
# Epoch 3 Step 1501 Train Loss: 0.0383
# Epoch 3 Step 1551 Train Loss: 0.0282
# Epoch 3 Step 1601 Train Loss: 0.0383
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 3: Train: 0.0215, R2 0.8648 Validation: 0.0222. R2 0.8617 Loss: 0.0445
# DE_Train: 0.2400, R2 -0.1015 DE_Validation: 0.2543. R2 0.3076
# Epoch 4 Step 1 Train Loss: 0.0476
# Epoch 4 Step 51 Train Loss: 0.0338
# Epoch 4 Step 101 Train Loss: 0.0307
# Epoch 4 Step 151 Train Loss: 0.0470
# Epoch 4 Step 201 Train Loss: 0.0714
# Epoch 4 Step 251 Train Loss: 0.0649
# Epoch 4 Step 301 Train Loss: 0.0357
# Epoch 4 Step 351 Train Loss: 0.0597
# Epoch 4 Step 401 Train Loss: 0.0385
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 5: Train: 0.0158, R2 0.9057 Validation: 0.0141. R2 0.9155 Loss: 0.0425
# DE_Train: 0.2200, R2 0.0104 DE_Validation: 0.2528. R2 0.0598
# Epoch 6 Step 1 Train Loss: 0.0337
# Epoch 6 Step 51 Train Loss: 0.0468
# Epoch 6 Step 101 Train Loss: 0.0540
# Epoch 6 Step 151 Train Loss: 0.0376
# Epoch 6 Step 201 Train Loss: 0.0439
# Epoch 6 Step 251 Train Loss: 0.0268
# Epoch 6 Step 301 Train Loss: 0.0372
# Epoch 6 Step 351 Train Loss: 0.0303
# Epoch 6 Step 401 Train Loss: 0.0413
# Epoch 6 Step 451 Train Loss: 0.0469
# Epoch 6 Step 501 Train Loss: 0.0407
# Epoch 6 Step 551 Train Loss: 0.0581
# Epoch 6 Step 601 Train Loss: 0.0258
# Epoch 6 Step 651 Train Loss: 0.0314
# Epoch 6 Step 701 Train Loss: 0.0427
# Epoch 6 Step 751 Train Loss: 0.0334
# Epoch 6 Step 801 Train Loss: 0.0333
# Epoch 6 Step 851 Train Loss: 0.0241
# Epoch 6 Step 901 Train Loss: 0.0346
# Epoch 6 Step 951 Train Loss: 0.0401
# Epoch 6 Step 1001 Train Loss: 0.0666
# Epoch 6 Step 1051 Train Loss: 0.0319
# Epoch 6 Step 1101 Train Loss: 0.0365
# Epoch 6 Step 1151 Train Loss: 0.0332
# Epoch 6 Step 1201 Train Loss: 0.0291
# Epoch 6 Step 1251 Train Loss: 0.0540
# Epoch 6 Step 1301 Train Loss: 0.0472
# Epoch 6 Step 1351 Train Loss: 0.0494
# Epoch 6 Step 1401 Train Loss: 0.0417
# Epoch 6 Step 1451 Train Loss: 0.0351
# Epoch 6 Step 1501 Train Loss: 0.0494
# Epoch 6 Step 1551 Train Loss: 0.0392
# Epoch 6 Step 1601 Train Loss: 0.0570
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 6: Train: 0.0150, R2 0.8861 Validation: 0.0133. R2 0.8984 Loss: 0.0415
# DE_Train: 0.2370, R2 -0.0385 DE_Validation: 0.2475. R2 -0.1118
# Epoch 7 Step 1 Train Loss: 0.0260
# Epoch 7 Step 51 Train Loss: 0.0321
# Epoch 7 Step 101 Train Loss: 0.0301
# Epoch 7 Step 151 Train Loss: 0.0330
# Epoch 7 Step 201 Train Loss: 0.0319
# Epoch 7 Step 251 Train Loss: 0.0342
# Epoch 7 Step 301 Train Loss: 0.0562
# Epoch 7 Step 351 Train Loss: 0.0433
# Epoch 7 Step 401 Train Loss: 0.0393
# Epoch 7 Step 451 Train Loss: 0.0462
# Epoch 7 Step 501 Train Loss: 0.0661
# Epoch 7 Step 551 Train Loss: 0.0280
# Epoch 7 Step 601 Train Loss: 0.0448
# Epoch 7 Step 651 Train Loss: 0.0379
# Epoch 7 Step 701 Train Loss: 0.0233
# Epoch 7 Step 751 Train Loss: 0.0304
# Epoch 7 Step 801 Train Loss: 0.0404
# Epoch 7 Step 851 Train Loss: 0.0746
# Epoch 7 Step 901 Train Loss: 0.0370
# Epoch 7 Step 951 Train Loss: 0.0388
# Epoch 7 Step 1001 Train Loss: 0.0448
# Epoch 7 Step 1051 Train Loss: 0.0318
# Epoch 7 Step 1101 Train Loss: 0.0352
# Epoch 7 Step 1151 Train Loss: 0.0492
# Epoch 7 Step 1201 Train Loss: 0.0440
# Epoch 7 Step 1251 Train Loss: 0.0419
# Epoch 7 Step 1301 Train Loss: 0.0271
# Epoch 7 Step 1351 Train Loss: 0.0297
# Epoch 7 Step 1401 Train Loss: 0.0327
# Epoch 7 Step 1451 Train Loss: 0.0221
# Epoch 7 Step 1501 Train Loss: 0.0385
# Epoch 7 Step 1551 Train Loss: 0.0439
# Epoch 7 Step 1601 Train Loss: 0.0480
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 7: Train: 0.0161, R2 0.8907 Validation: 0.0146. R2 0.9016 Loss: 0.0412
# DE_Train: 0.2202, R2 -0.1342 DE_Validation: 0.2414. R2 -0.3461
# Epoch 8 Step 1 Train Loss: 0.0427
# Epoch 8 Step 51 Train Loss: 0.0400
# Epoch 8 Step 101 Train Loss: 0.0282
# Epoch 8 Step 151 Train Loss: 0.0445
# Epoch 8 Step 201 Train Loss: 0.0394
# Epoch 8 Step 251 Train Loss: 0.0412
# Epoch 8 Step 301 Train Loss: 0.0499
# Epoch 8 Step 351 Train Loss: 0.0423
# Epoch 8 Step 401 Train Loss: 0.0427
# Epoch 8 Step 451 Train Loss: 0.0435
# Epoch 8 Step 501 Train Loss: 0.0352
# Epoch 8 Step 551 Train Loss: 0.0307
# Epoch 8 Step 601 Train Loss: 0.0635
# Epoch 8 Step 651 Train Loss: 0.0485
# Epoch 8 Step 701 Train Loss: 0.0443
# Epoch 8 Step 751 Train Loss: 0.0370
# Epoch 8 Step 801 Train Loss: 0.0440
# Epoch 8 Step 851 Train Loss: 0.0632
# Epoch 8 Step 901 Train Loss: 0.0310
# Epoch 8 Step 951 Train Loss: 0.0349
# Epoch 8 Step 1001 Train Loss: 0.0383
# Epoch 8 Step 1051 Train Loss: 0.0343
# Epoch 8 Step 1101 Train Loss: 0.0389
# Epoch 8 Step 1151 Train Loss: 0.0399
# Epoch 8 Step 1201 Train Loss: 0.0385
# Epoch 8 Step 1251 Train Loss: 0.0404
# Epoch 8 Step 1301 Train Loss: 0.0374
# Epoch 8 Step 1351 Train Loss: 0.0489
# Epoch 8 Step 1401 Train Loss: 0.0390
# Epoch 8 Step 1451 Train Loss: 0.0355
# Epoch 8 Step 1501 Train Loss: 0.0316
# Epoch 8 Step 1551 Train Loss: 0.0392
# Epoch 8 Step 1601 Train Loss: 0.0382
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 8: Train: 0.0161, R2 0.8887 Validation: 0.0147. R2 0.8986 Loss: 0.0410
# DE_Train: 0.2183, R2 -0.2847 DE_Validation: 0.2405. R2 -1.0716
# Epoch 9 Step 1 Train Loss: 0.0441
# Epoch 9 Step 51 Train Loss: 0.0303
# Epoch 9 Step 101 Train Loss: 0.0346
# Epoch 9 Step 151 Train Loss: 0.0437
# Epoch 9 Step 201 Train Loss: 0.0390
# Epoch 9 Step 251 Train Loss: 0.0325
# Epoch 9 Step 301 Train Loss: 0.0515
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 10: Train: 0.0164, R2 0.8873 Validation: 0.0149. R2 0.8978 Loss: 0.0409
# DE_Train: 0.2145, R2 -0.1881 DE_Validation: 0.2393. R2 -0.8442
# Saving model....
# Start testing....
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Final best performing model: Test_DE: 0.2483, R2 -1.1857
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# ...
# wandb:              test_SYNERGY_DISSIMILAR_PHENO_mse_top50_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_fold_change_gap_all ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_40_60 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_45_55 ▁
# wandb:                   test_SYNERGY_SIMILAR_PHENO_mean_sigma ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top100_de ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top200_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top20_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top50_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:                    test_combo_seen0_fold_change_gap_all ▁
# wandb:            test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:               test_combo_seen0_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen0_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen0_frac_in_range ▁
# wandb:                    test_combo_seen0_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen0_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen0_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen0_mae ▁
# wandb:                                 test_combo_seen0_mae_de ▁
# wandb:                             test_combo_seen0_mean_sigma ▁
# wandb:                                    test_combo_seen0_mse ▁
# wandb:                                 test_combo_seen0_mse_de ▁
# wandb:                          test_combo_seen0_mse_top100_de ▁
# wandb:                          test_combo_seen0_mse_top200_de ▁
# wandb:                         test_combo_seen0_mse_top200_hvg ▁
# wandb:                           test_combo_seen0_mse_top20_de ▁
# wandb:                           test_combo_seen0_mse_top50_de ▁
# wandb:                                test_combo_seen0_pearson ▁
# wandb:                             test_combo_seen0_pearson_de ▁
# wandb:                          test_combo_seen0_pearson_delta ▁
# wandb:                       test_combo_seen0_pearson_delta_de ▁
# wandb:                test_combo_seen0_pearson_delta_top100_de ▁
# wandb:                test_combo_seen0_pearson_delta_top200_de ▁
# wandb:               test_combo_seen0_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen0_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen0_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen0_pearson_top100_de ▁
# wandb:                      test_combo_seen0_pearson_top200_de ▁
# wandb:                     test_combo_seen0_pearson_top200_hvg ▁
# wandb:                       test_combo_seen0_pearson_top20_de ▁
# wandb:                       test_combo_seen0_pearson_top50_de ▁
# wandb:                                     test_combo_seen0_r2 ▁
# wandb:                                  test_combo_seen0_r2_de ▁
# wandb:                               test_combo_seen0_spearman ▁
# wandb:                            test_combo_seen0_spearman_de ▁
# wandb:                              test_combo_seen0_std_sigma ▁
# wandb:                    test_combo_seen1_fold_change_gap_all ▁
# wandb:            test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen1_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen1_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen1_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen1_frac_in_range ▁
# wandb:                    test_combo_seen1_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen1_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen1_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen1_mae ▁
# wandb:                                 test_combo_seen1_mae_de ▁
# wandb:                             test_combo_seen1_mean_sigma ▁
# wandb:                                    test_combo_seen1_mse ▁
# wandb:                                 test_combo_seen1_mse_de ▁
# wandb:                          test_combo_seen1_mse_top100_de ▁
# wandb:                          test_combo_seen1_mse_top200_de ▁
# wandb:                         test_combo_seen1_mse_top200_hvg ▁
# wandb:                           test_combo_seen1_mse_top20_de ▁
# wandb:                           test_combo_seen1_mse_top50_de ▁
# wandb:                                test_combo_seen1_pearson ▁
# wandb:                             test_combo_seen1_pearson_de ▁
# wandb:                          test_combo_seen1_pearson_delta ▁
# wandb:                       test_combo_seen1_pearson_delta_de ▁
# wandb:                test_combo_seen1_pearson_delta_top100_de ▁
# wandb:                test_combo_seen1_pearson_delta_top200_de ▁
# wandb:               test_combo_seen1_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen1_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen1_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen1_pearson_top100_de ▁
# wandb:                      test_combo_seen1_pearson_top200_de ▁
# wandb:                     test_combo_seen1_pearson_top200_hvg ▁
# wandb:                       test_combo_seen1_pearson_top20_de ▁
# wandb:                       test_combo_seen1_pearson_top50_de ▁
# wandb:                                     test_combo_seen1_r2 ▁
# wandb:                                  test_combo_seen1_r2_de ▁
# wandb:                               test_combo_seen1_spearman ▁
# wandb:                            test_combo_seen1_spearman_de ▁
# wandb:                              test_combo_seen1_std_sigma ▁
# wandb:                    test_combo_seen2_fold_change_gap_all ▁
# wandb:            test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen2_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen2_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen2_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen2_frac_in_range ▁
# wandb:                    test_combo_seen2_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen2_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen2_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen2_mae ▁
# wandb:                                 test_combo_seen2_mae_de ▁
# wandb:                             test_combo_seen2_mean_sigma ▁
# wandb:                                    test_combo_seen2_mse ▁
# wandb:                                 test_combo_seen2_mse_de ▁
# wandb:                          test_combo_seen2_mse_top100_de ▁
# wandb:                          test_combo_seen2_mse_top200_de ▁
# wandb:                         test_combo_seen2_mse_top200_hvg ▁
# wandb:                           test_combo_seen2_mse_top20_de ▁
# wandb:                           test_combo_seen2_mse_top50_de ▁
# wandb:                                test_combo_seen2_pearson ▁
# wandb:                             test_combo_seen2_pearson_de ▁
# wandb:                          test_combo_seen2_pearson_delta ▁
# wandb:                       test_combo_seen2_pearson_delta_de ▁
# wandb:                test_combo_seen2_pearson_delta_top100_de ▁
# wandb:                test_combo_seen2_pearson_delta_top200_de ▁
# wandb:               test_combo_seen2_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen2_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen2_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen2_pearson_top100_de ▁
# wandb:                      test_combo_seen2_pearson_top200_de ▁
# wandb:                     test_combo_seen2_pearson_top200_hvg ▁
# wandb:                       test_combo_seen2_pearson_top20_de ▁
# wandb:                       test_combo_seen2_pearson_top50_de ▁
# wandb:                                     test_combo_seen2_r2 ▁
# wandb:                                  test_combo_seen2_r2_de ▁
# wandb:                               test_combo_seen2_spearman ▁
# wandb:                            test_combo_seen2_spearman_de ▁
# wandb:                              test_combo_seen2_std_sigma ▁
# wandb:                                             test_de_mae ▁
# wandb:                                             test_de_mse ▁
# wandb:                                         test_de_pearson ▁
# wandb:                                              test_de_r2 ▁
# wandb:                                        test_de_spearman ▁
# wandb:                                test_fold_change_gap_all ▁
# wandb:                        test_fold_change_gap_downreg_0.1
# wandb:                       test_fold_change_gap_downreg_0.33 ▁
# wandb:                           test_fold_change_gap_upreg_10 ▁
# wandb:                            test_fold_change_gap_upreg_3 ▁
# wandb:                                      test_frac_in_range ▁
# wandb:                                test_frac_in_range_25_75 ▁
# wandb:                                test_frac_in_range_40_60 ▁
# wandb:                                test_frac_in_range_45_55 ▁
# wandb:                                 test_frac_sigma_below_1 ▁
# wandb:                                 test_frac_sigma_below_2 ▁
# wandb:                                                test_mae ▁
# wandb:                                         test_mean_sigma ▁
# wandb:                                                test_mse ▁
# wandb:                                      test_mse_top100_de ▁
# wandb:                                      test_mse_top200_de ▁
# wandb:                                     test_mse_top200_hvg ▁
# wandb:                                       test_mse_top20_de ▁
# wandb:                                       test_mse_top50_de ▁
# wandb:                                            test_pearson ▁
# wandb:                                      test_pearson_delta ▁
# wandb:                                   test_pearson_delta_de ▁
# wandb:                            test_pearson_delta_top100_de ▁
# wandb:                            test_pearson_delta_top200_de ▁
# wandb:                           test_pearson_delta_top200_hvg ▁
# wandb:                             test_pearson_delta_top20_de ▁
# wandb:                             test_pearson_delta_top50_de ▁
# wandb:                                  test_pearson_top100_de ▁
# wandb:                                  test_pearson_top200_de ▁
# wandb:                                 test_pearson_top200_hvg ▁
# wandb:                                   test_pearson_top20_de ▁
# wandb:                                   test_pearson_top50_de ▁
# wandb:                                                 test_r2 ▁
# wandb:                                           test_spearman ▁
# wandb:                                          test_std_sigma ▁
# wandb:                  test_unseen_single_fold_change_gap_all ▁
# wandb:          test_unseen_single_fold_change_gap_downreg_0.1
# wandb:         test_unseen_single_fold_change_gap_downreg_0.33
# wandb:             test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:              test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                        test_unseen_single_frac_in_range ▁
# wandb:                  test_unseen_single_frac_in_range_25_75 ▁
# wandb:                  test_unseen_single_frac_in_range_40_60 ▁
# wandb:                  test_unseen_single_frac_in_range_45_55 ▁
# wandb:                   test_unseen_single_frac_sigma_below_1 ▁
# wandb:                   test_unseen_single_frac_sigma_below_2 ▁
# wandb:                                  test_unseen_single_mae ▁
# wandb:                               test_unseen_single_mae_de ▁
# wandb:                           test_unseen_single_mean_sigma ▁
# wandb:                                  test_unseen_single_mse ▁
# wandb:                               test_unseen_single_mse_de ▁
# wandb:                        test_unseen_single_mse_top100_de ▁
# wandb:                        test_unseen_single_mse_top200_de ▁
# wandb:                       test_unseen_single_mse_top200_hvg ▁
# wandb:                         test_unseen_single_mse_top20_de ▁
# wandb:                         test_unseen_single_mse_top50_de ▁
# wandb:                              test_unseen_single_pearson ▁
# wandb:                           test_unseen_single_pearson_de ▁
# wandb:                        test_unseen_single_pearson_delta ▁
# wandb:                     test_unseen_single_pearson_delta_de ▁
# wandb:              test_unseen_single_pearson_delta_top100_de ▁
# wandb:              test_unseen_single_pearson_delta_top200_de ▁
# wandb:             test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:               test_unseen_single_pearson_delta_top20_de ▁
# wandb:               test_unseen_single_pearson_delta_top50_de ▁
# wandb:                    test_unseen_single_pearson_top100_de ▁
# wandb:                    test_unseen_single_pearson_top200_de ▁
# wandb:                   test_unseen_single_pearson_top200_hvg ▁
# wandb:                     test_unseen_single_pearson_top20_de ▁
# wandb:                     test_unseen_single_pearson_top50_de ▁
# wandb:                                   test_unseen_single_r2 ▁
# wandb:                                test_unseen_single_r2_de ▁
# wandb:                             test_unseen_single_spearman ▁
# wandb:                          test_unseen_single_spearman_de ▁
# wandb:                            test_unseen_single_std_sigma ▁
# wandb:                                            train_de_mae ▇█▃▃▂▂▁▁▁▁
# wandb:                                            train_de_mse ▅█▃▃▁▂▁▁▁▁
# wandb:                                        train_de_pearson ▁▄▃▄▅▇▇▇██
# wandb:                                             train_de_r2 █▅▄▅▅▅▃▁▂▂
# wandb:                                       train_de_spearman ▁▄▃▃▅▇▇███
# wandb:                                               train_mae █▂▃▃▁▁▁▁▁▁
# wandb:                                               train_mse █▂▂▂▁▁▁▁▁▁
# wandb:                                           train_pearson █▁▆▆█▆▆▇▅▆
# wandb:                                                train_r2 ▁▄▇▆█▇▇▇▇▇
# wandb:                                          train_spearman ▁▆▇▇██████
# wandb:                                           training_loss █▃▇▄▄▄▃▄▅▂▆▃█▃▄▄▄▅▄▃▄▂▅▄▃▅▄▃▃▅▁▃▃▆▃▄▄▄▂▂
# wandb:                                              val_de_mae █▄▂▁▁▁▁▁▁▁
# wandb:                                              val_de_mse █▅▂▂▂▂▁▁▁▁
# wandb:                                          val_de_pearson ▁▇▇▆▆▆▇▇██
# wandb:                                               val_de_r2 ▄███▇▆▅▁▂▂
# wandb:                                         val_de_spearman ▁█▇▄▄▆▅▅▆▆
# wandb:                                                 val_mae █▂▃▂▁▁▁▁▁▁
# wandb:                                                 val_mse █▂▂▂▁▁▁▁▁▁
# wandb:                                             val_pearson ▇▁▅▆█▇▇▇▆▆
# wandb:                                                  val_r2 ▁▄▆▇████▇▇
# wandb:                                            val_spearman ▁▇▇▇██████
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced no_gnn_coexp_0.4_thr_with_recomb: https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/2o3sry0i

# %%
# !python train.py --dataset Norman2019 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3 \
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:4 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --no_gnn \
                 --exp_name no_gnn_coexp_0.95_thr \
                 --sim_gnn_gene \
                 --sim_gnn_gene_k 10 \
                 --sim_gnn_gene_threshold 0.95 \
                 --wandb
# Out:
# ---- Printing Arguments ----
# dataset: Norman2019
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:4
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: True
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.95
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: True
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: no_gnn_coexp_0.95_thr
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run no_gnn_coexp_0.95_thr
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/1b31ibzc
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_123829-1b31ibzc
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_co-expression_100.0_64_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 24886 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:9
# combo_seen1:52
# combo_seen2:18
# unseen_single:37
# Creating dataloaders....
# Dataloaders created...
# /dfs/user/kexinh/perturb_GNN/kexin/utils.py:29: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Finished data setup, in total takes 0.919 min
# Initializing model...
# Start Training...
# Epoch 1 Step 1 Train Loss: 0.2029
# Epoch 1 Step 51 Train Loss: 0.0516
# Epoch 1 Step 101 Train Loss: 0.0539
# Epoch 1 Step 151 Train Loss: 0.0780
# Epoch 1 Step 201 Train Loss: 0.0665
# Epoch 1 Step 251 Train Loss: 0.0409
# Epoch 1 Step 301 Train Loss: 0.0394
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 2: Train: 0.0330, R2 0.8538 Validation: 0.0351. R2 0.8446 Loss: 0.0454
# DE_Train: 0.4294, R2 0.2357 DE_Validation: 0.3943. R2 0.2137
# Epoch 3 Step 1 Train Loss: 0.0285
# Epoch 3 Step 51 Train Loss: 0.0313
# Epoch 3 Step 101 Train Loss: 0.0290
# Epoch 3 Step 151 Train Loss: 0.0325
# Epoch 3 Step 201 Train Loss: 0.0334
# Epoch 3 Step 251 Train Loss: 0.0406
# Epoch 3 Step 301 Train Loss: 0.0322
# Epoch 3 Step 351 Train Loss: 0.0275
# Epoch 3 Step 401 Train Loss: 0.0375
# Epoch 3 Step 451 Train Loss: 0.0616
# Epoch 3 Step 501 Train Loss: 0.0230
# Epoch 3 Step 551 Train Loss: 0.0497
# Epoch 3 Step 601 Train Loss: 0.0419
# Epoch 3 Step 651 Train Loss: 0.0329
# Epoch 3 Step 701 Train Loss: 0.0687
# Epoch 3 Step 751 Train Loss: 0.0432
# Epoch 3 Step 801 Train Loss: 0.0332
# Epoch 3 Step 851 Train Loss: 0.0729
# Epoch 3 Step 901 Train Loss: 0.0439
# Epoch 3 Step 951 Train Loss: 0.0406
# Epoch 3 Step 1001 Train Loss: 0.0466
# Epoch 3 Step 1051 Train Loss: 0.0532
# Epoch 3 Step 1101 Train Loss: 0.0318
# Epoch 3 Step 1151 Train Loss: 0.0371
# Epoch 3 Step 1201 Train Loss: 0.0334
# Epoch 3 Step 1251 Train Loss: 0.0434
# Epoch 3 Step 1301 Train Loss: 0.0609
# Epoch 3 Step 1351 Train Loss: 0.0319
# Epoch 3 Step 1401 Train Loss: 0.0317
# Epoch 3 Step 1451 Train Loss: 0.0422
# Epoch 3 Step 1501 Train Loss: 0.0382
# Epoch 3 Step 1551 Train Loss: 0.0285
# Epoch 3 Step 1601 Train Loss: 0.0390
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 3: Train: 0.0356, R2 0.5250 Validation: 0.0335. R2 0.5535 Loss: 0.0445
# DE_Train: 0.4766, R2 -1.0316 DE_Validation: 0.4313. R2 -0.3470
# Epoch 4 Step 1 Train Loss: 0.0475
# Epoch 4 Step 51 Train Loss: 0.0337
# Epoch 4 Step 101 Train Loss: 0.0310
# Epoch 4 Step 151 Train Loss: 0.0463
# Epoch 4 Step 201 Train Loss: 0.0703
# Epoch 4 Step 251 Train Loss: 0.0643
# Epoch 4 Step 301 Train Loss: 0.0361
# Epoch 4 Step 351 Train Loss: 0.0590
# Epoch 4 Step 401 Train Loss: 0.0387
# Epoch 4 Step 451 Train Loss: 0.0581
# Epoch 4 Step 501 Train Loss: 0.0631
# Epoch 4 Step 551 Train Loss: 0.0501
# Epoch 4 Step 601 Train Loss: 0.0717
# Epoch 4 Step 651 Train Loss: 0.0423
# Epoch 4 Step 701 Train Loss: 0.0488
# Epoch 4 Step 751 Train Loss: 0.0301
# Epoch 4 Step 801 Train Loss: 0.0739
# Epoch 4 Step 851 Train Loss: 0.0638
# Epoch 4 Step 901 Train Loss: 0.0532
# Epoch 6 Step 251 Train Loss: 0.0274
# Epoch 6 Step 301 Train Loss: 0.0378
# Epoch 6 Step 351 Train Loss: 0.0312
# Epoch 6 Step 401 Train Loss: 0.0421
# Epoch 6 Step 451 Train Loss: 0.0477
# Epoch 6 Step 501 Train Loss: 0.0449
# Epoch 6 Step 551 Train Loss: 0.0600
# Epoch 6 Step 601 Train Loss: 0.0262
# Epoch 6 Step 651 Train Loss: 0.0322
# Epoch 6 Step 701 Train Loss: 0.0436
# Epoch 6 Step 751 Train Loss: 0.0338
# Epoch 6 Step 801 Train Loss: 0.0332
# Epoch 6 Step 851 Train Loss: 0.0246
# Epoch 6 Step 901 Train Loss: 0.0353
# Epoch 6 Step 951 Train Loss: 0.0425
# Epoch 6 Step 1001 Train Loss: 0.0655
# Epoch 6 Step 1051 Train Loss: 0.0323
# Epoch 6 Step 1101 Train Loss: 0.0361
# Epoch 6 Step 1151 Train Loss: 0.0343
# Epoch 6 Step 1201 Train Loss: 0.0294
# Epoch 6 Step 1251 Train Loss: 0.0529
# Epoch 6 Step 1301 Train Loss: 0.0471
# Epoch 6 Step 1351 Train Loss: 0.0525
# Epoch 6 Step 1401 Train Loss: 0.0459
# Epoch 6 Step 1451 Train Loss: 0.0356
# Epoch 6 Step 1501 Train Loss: 0.0516
# Epoch 6 Step 1551 Train Loss: 0.0401
# Epoch 6 Step 1601 Train Loss: 0.0598
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 6: Train: 0.0172, R2 0.8652 Validation: 0.0149. R2 0.8804 Loss: 0.0426
# DE_Train: 0.2638, R2 -0.2842 DE_Validation: 0.2564. R2 -1.1541
# Epoch 7 Step 1 Train Loss: 0.0260
# Epoch 7 Step 51 Train Loss: 0.0332
# Epoch 7 Step 101 Train Loss: 0.0304
# Epoch 7 Step 151 Train Loss: 0.0329
# Epoch 7 Step 201 Train Loss: 0.0323
# Epoch 7 Step 251 Train Loss: 0.0379
# Epoch 7 Step 301 Train Loss: 0.0568
# Epoch 7 Step 351 Train Loss: 0.0440
# Epoch 7 Step 401 Train Loss: 0.0402
# Epoch 7 Step 451 Train Loss: 0.0470
# Epoch 7 Step 501 Train Loss: 0.0678
# Epoch 7 Step 551 Train Loss: 0.0283
# Epoch 7 Step 601 Train Loss: 0.0477
# Epoch 7 Step 651 Train Loss: 0.0402
# Epoch 7 Step 701 Train Loss: 0.0234
# Epoch 7 Step 751 Train Loss: 0.0308
# Epoch 7 Step 801 Train Loss: 0.0410
# Epoch 7 Step 851 Train Loss: 0.0782
# Epoch 7 Step 901 Train Loss: 0.0376
# Epoch 7 Step 951 Train Loss: 0.0395
# Epoch 7 Step 1001 Train Loss: 0.0456
# Epoch 7 Step 1051 Train Loss: 0.0327
# Epoch 7 Step 1101 Train Loss: 0.0367
# Epoch 7 Step 1151 Train Loss: 0.0527
# Epoch 7 Step 1201 Train Loss: 0.0482
# Epoch 7 Step 1251 Train Loss: 0.0411
# Epoch 7 Step 1301 Train Loss: 0.0279
# Epoch 7 Step 1351 Train Loss: 0.0295
# Epoch 7 Step 1401 Train Loss: 0.0332
# Epoch 7 Step 1451 Train Loss: 0.0226
# Epoch 7 Step 1501 Train Loss: 0.0382
# Epoch 7 Step 1551 Train Loss: 0.0477
# Epoch 7 Step 1601 Train Loss: 0.0484
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 7: Train: 0.0178, R2 0.8648 Validation: 0.0154. R2 0.8805 Loss: 0.0425
# DE_Train: 0.2519, R2 -0.3319 DE_Validation: 0.2549. R2 -1.5688
# Epoch 8 Step 1 Train Loss: 0.0420
# Epoch 8 Step 51 Train Loss: 0.0428
# Epoch 8 Step 101 Train Loss: 0.0285
# Epoch 8 Step 151 Train Loss: 0.0473
# Epoch 8 Step 201 Train Loss: 0.0414
# Epoch 8 Step 251 Train Loss: 0.0444
# Epoch 8 Step 301 Train Loss: 0.0483
# Epoch 8 Step 351 Train Loss: 0.0422
# Epoch 8 Step 401 Train Loss: 0.0438
# Epoch 8 Step 451 Train Loss: 0.0460
# Epoch 8 Step 501 Train Loss: 0.0365
# Epoch 8 Step 551 Train Loss: 0.0311
# Epoch 8 Step 601 Train Loss: 0.0663
# Epoch 8 Step 651 Train Loss: 0.0503
# Epoch 8 Step 701 Train Loss: 0.0463
# Epoch 8 Step 751 Train Loss: 0.0376
# Epoch 8 Step 801 Train Loss: 0.0448
# Epoch 8 Step 851 Train Loss: 0.0636
# Epoch 8 Step 901 Train Loss: 0.0322
# Epoch 8 Step 951 Train Loss: 0.0361
# Epoch 8 Step 1001 Train Loss: 0.0396
# Epoch 8 Step 1051 Train Loss: 0.0345
# Epoch 8 Step 1101 Train Loss: 0.0401
# Epoch 8 Step 1151 Train Loss: 0.0419
# Epoch 8 Step 1201 Train Loss: 0.0415
# Epoch 8 Step 1251 Train Loss: 0.0409
# Epoch 8 Step 1301 Train Loss: 0.0377
# Epoch 8 Step 1351 Train Loss: 0.0503
# Epoch 8 Step 1401 Train Loss: 0.0396
# Epoch 8 Step 1451 Train Loss: 0.0365
# Epoch 8 Step 1501 Train Loss: 0.0316
# Epoch 8 Step 1551 Train Loss: 0.0417
# Epoch 8 Step 1601 Train Loss: 0.0402
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 8: Train: 0.0150, R2 0.9029 Validation: 0.0128. R2 0.9151 Loss: 0.0423
# DE_Train: 0.2280, R2 -0.2565 DE_Validation: 0.2422. R2 -1.4412
# Epoch 9 Step 1 Train Loss: 0.0441
# Epoch 9 Step 51 Train Loss: 0.0310
# Epoch 9 Step 101 Train Loss: 0.0353
# Epoch 9 Step 151 Train Loss: 0.0466
# Epoch 9 Step 201 Train Loss: 0.0398
# Epoch 9 Step 251 Train Loss: 0.0330
# Epoch 9 Step 301 Train Loss: 0.0546
# Epoch 9 Step 351 Train Loss: 0.0558
# Epoch 9 Step 401 Train Loss: 0.0822
# Epoch 9 Step 451 Train Loss: 0.0537
# Epoch 9 Step 501 Train Loss: 0.0316
# Epoch 9 Step 551 Train Loss: 0.0554
# Epoch 9 Step 601 Train Loss: 0.0298
# Epoch 9 Step 651 Train Loss: 0.0376
# Epoch 9 Step 701 Train Loss: 0.0415
# Epoch 9 Step 751 Train Loss: 0.0522
# Epoch 9 Step 801 Train Loss: 0.0556
# Epoch 9 Step 851 Train Loss: 0.0325
# Epoch 9 Step 901 Train Loss: 0.0463
# Epoch 9 Step 951 Train Loss: 0.0509
# Epoch 9 Step 1001 Train Loss: 0.0525
# Epoch 9 Step 1051 Train Loss: 0.0341
# Epoch 9 Step 1101 Train Loss: 0.0706
# Epoch 9 Step 1151 Train Loss: 0.0346
# Epoch 9 Step 1201 Train Loss: 0.0387
# Epoch 9 Step 1251 Train Loss: 0.0376
# Epoch 9 Step 1301 Train Loss: 0.0242
# Epoch 9 Step 1351 Train Loss: 0.0451
# Epoch 9 Step 1401 Train Loss: 0.0271
# Epoch 9 Step 1451 Train Loss: 0.0456
# Epoch 9 Step 1501 Train Loss: 0.0401
# Epoch 9 Step 1551 Train Loss: 0.0634
# Epoch 9 Step 1601 Train Loss: 0.0676
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 9: Train: 0.0170, R2 0.8827 Validation: 0.0145. R2 0.8977 Loss: 0.0423
# DE_Train: 0.2325, R2 -0.3115 DE_Validation: 0.2446. R2 -1.5134
# Epoch 10 Step 1 Train Loss: 0.0538
# Epoch 10 Step 51 Train Loss: 0.0540
# Epoch 10 Step 101 Train Loss: 0.0344
# Epoch 10 Step 151 Train Loss: 0.0474
# Epoch 10 Step 201 Train Loss: 0.0622
# Epoch 10 Step 251 Train Loss: 0.0927
# Epoch 10 Step 301 Train Loss: 0.0418
# Epoch 10 Step 351 Train Loss: 0.0665
# Epoch 10 Step 401 Train Loss: 0.0273
# Epoch 10 Step 451 Train Loss: 0.0369
# Epoch 10 Step 501 Train Loss: 0.0308
# Epoch 10 Step 551 Train Loss: 0.0515
# Epoch 10 Step 601 Train Loss: 0.0309
# Epoch 10 Step 651 Train Loss: 0.0420
# Epoch 10 Step 701 Train Loss: 0.0314
# Epoch 10 Step 751 Train Loss: 0.0630
# Epoch 10 Step 801 Train Loss: 0.0270
# Epoch 10 Step 851 Train Loss: 0.0711
# Epoch 10 Step 901 Train Loss: 0.0314
# Epoch 10 Step 951 Train Loss: 0.0394
# Epoch 10 Step 1001 Train Loss: 0.0351
# Epoch 10 Step 1051 Train Loss: 0.0550
# Epoch 10 Step 1101 Train Loss: 0.0521
# Epoch 10 Step 1151 Train Loss: 0.0529
# Epoch 10 Step 1201 Train Loss: 0.0452
# Epoch 10 Step 1251 Train Loss: 0.0521
# Epoch 10 Step 1301 Train Loss: 0.0400
# Epoch 10 Step 1351 Train Loss: 0.0246
# Epoch 10 Step 1401 Train Loss: 0.0419
# Epoch 10 Step 1451 Train Loss: 0.0521
# Epoch 10 Step 1501 Train Loss: 0.0647
# Epoch 10 Step 1551 Train Loss: 0.0582
# Epoch 10 Step 1601 Train Loss: 0.0493
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 10: Train: 0.0169, R2 0.8856 Validation: 0.0147. R2 0.8988 Loss: 0.0423
# DE_Train: 0.2289, R2 -0.3293 DE_Validation: 0.2442. R2 -1.5576
# Saving model....
# Start testing....
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Final best performing model: Test_DE: 0.2602, R2 -1.2345
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
# ...
# wandb:              test_SYNERGY_DISSIMILAR_PHENO_mse_top50_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_fold_change_gap_all ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_40_60 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_45_55 ▁
# wandb:                   test_SYNERGY_SIMILAR_PHENO_mean_sigma ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top100_de ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top200_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top20_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top50_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:                    test_combo_seen0_fold_change_gap_all ▁
# wandb:            test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:               test_combo_seen0_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen0_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen0_frac_in_range ▁
# wandb:                    test_combo_seen0_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen0_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen0_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen0_mae ▁
# wandb:                                 test_combo_seen0_mae_de ▁
# wandb:                             test_combo_seen0_mean_sigma ▁
# wandb:                                    test_combo_seen0_mse ▁
# wandb:                                 test_combo_seen0_mse_de ▁
# wandb:                          test_combo_seen0_mse_top100_de ▁
# wandb:                          test_combo_seen0_mse_top200_de ▁
# wandb:                         test_combo_seen0_mse_top200_hvg ▁
# wandb:                           test_combo_seen0_mse_top20_de ▁
# wandb:                           test_combo_seen0_mse_top50_de ▁
# wandb:                                test_combo_seen0_pearson ▁
# wandb:                             test_combo_seen0_pearson_de ▁
# wandb:                          test_combo_seen0_pearson_delta ▁
# wandb:                       test_combo_seen0_pearson_delta_de ▁
# wandb:                test_combo_seen0_pearson_delta_top100_de ▁
# wandb:                test_combo_seen0_pearson_delta_top200_de ▁
# wandb:               test_combo_seen0_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen0_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen0_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen0_pearson_top100_de ▁
# wandb:                      test_combo_seen0_pearson_top200_de ▁
# wandb:                     test_combo_seen0_pearson_top200_hvg ▁
# wandb:                       test_combo_seen0_pearson_top20_de ▁
# wandb:                       test_combo_seen0_pearson_top50_de ▁
# wandb:                                     test_combo_seen0_r2 ▁
# wandb:                                  test_combo_seen0_r2_de ▁
# wandb:                               test_combo_seen0_spearman ▁
# wandb:                            test_combo_seen0_spearman_de ▁
# wandb:                              test_combo_seen0_std_sigma ▁
# wandb:                    test_combo_seen1_fold_change_gap_all ▁
# wandb:            test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen1_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen1_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen1_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen1_frac_in_range ▁
# wandb:                    test_combo_seen1_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen1_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen1_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen1_mae ▁
# wandb:                                 test_combo_seen1_mae_de ▁
# wandb:                             test_combo_seen1_mean_sigma ▁
# wandb:                                    test_combo_seen1_mse ▁
# wandb:                                 test_combo_seen1_mse_de ▁
# wandb:                          test_combo_seen1_mse_top100_de ▁
# wandb:                          test_combo_seen1_mse_top200_de ▁
# wandb:                         test_combo_seen1_mse_top200_hvg ▁
# wandb:                           test_combo_seen1_mse_top20_de ▁
# wandb:                           test_combo_seen1_mse_top50_de ▁
# wandb:                                test_combo_seen1_pearson ▁
# wandb:                             test_combo_seen1_pearson_de ▁
# wandb:                          test_combo_seen1_pearson_delta ▁
# wandb:                       test_combo_seen1_pearson_delta_de ▁
# wandb:                test_combo_seen1_pearson_delta_top100_de ▁
# wandb:                test_combo_seen1_pearson_delta_top200_de ▁
# wandb:               test_combo_seen1_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen1_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen1_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen1_pearson_top100_de ▁
# wandb:                      test_combo_seen1_pearson_top200_de ▁
# wandb:                     test_combo_seen1_pearson_top200_hvg ▁
# wandb:                       test_combo_seen1_pearson_top20_de ▁
# wandb:                       test_combo_seen1_pearson_top50_de ▁
# wandb:                                     test_combo_seen1_r2 ▁
# wandb:                                  test_combo_seen1_r2_de ▁
# wandb:                               test_combo_seen1_spearman ▁
# wandb:                            test_combo_seen1_spearman_de ▁
# wandb:                              test_combo_seen1_std_sigma ▁
# wandb:                    test_combo_seen2_fold_change_gap_all ▁
# wandb:            test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen2_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen2_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen2_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen2_frac_in_range ▁
# wandb:                    test_combo_seen2_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen2_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen2_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen2_mae ▁
# wandb:                                 test_combo_seen2_mae_de ▁
# wandb:                             test_combo_seen2_mean_sigma ▁
# wandb:                                    test_combo_seen2_mse ▁
# wandb:                                 test_combo_seen2_mse_de ▁
# wandb:                          test_combo_seen2_mse_top100_de ▁
# wandb:                          test_combo_seen2_mse_top200_de ▁
# wandb:                         test_combo_seen2_mse_top200_hvg ▁
# wandb:                           test_combo_seen2_mse_top20_de ▁
# wandb:                           test_combo_seen2_mse_top50_de ▁
# wandb:                                test_combo_seen2_pearson ▁
# wandb:                             test_combo_seen2_pearson_de ▁
# wandb:                          test_combo_seen2_pearson_delta ▁
# wandb:                       test_combo_seen2_pearson_delta_de ▁
# wandb:                test_combo_seen2_pearson_delta_top100_de ▁
# wandb:                test_combo_seen2_pearson_delta_top200_de ▁
# wandb:               test_combo_seen2_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen2_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen2_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen2_pearson_top100_de ▁
# wandb:                      test_combo_seen2_pearson_top200_de ▁
# wandb:                     test_combo_seen2_pearson_top200_hvg ▁
# wandb:                       test_combo_seen2_pearson_top20_de ▁
# wandb:                       test_combo_seen2_pearson_top50_de ▁
# wandb:                                     test_combo_seen2_r2 ▁
# wandb:                                  test_combo_seen2_r2_de ▁
# wandb:                               test_combo_seen2_spearman ▁
# wandb:                            test_combo_seen2_spearman_de ▁
# wandb:                              test_combo_seen2_std_sigma ▁
# wandb:                                             test_de_mae ▁
# wandb:                                             test_de_mse ▁
# wandb:                                         test_de_pearson ▁
# wandb:                                              test_de_r2 ▁
# wandb:                                        test_de_spearman ▁
# wandb:                                test_fold_change_gap_all ▁
# wandb:                        test_fold_change_gap_downreg_0.1
# wandb:                       test_fold_change_gap_downreg_0.33 ▁
# wandb:                           test_fold_change_gap_upreg_10 ▁
# wandb:                            test_fold_change_gap_upreg_3 ▁
# wandb:                                      test_frac_in_range ▁
# wandb:                                test_frac_in_range_25_75 ▁
# wandb:                                test_frac_in_range_40_60 ▁
# wandb:                                test_frac_in_range_45_55 ▁
# wandb:                                 test_frac_sigma_below_1 ▁
# wandb:                                 test_frac_sigma_below_2 ▁
# wandb:                                                test_mae ▁
# wandb:                                         test_mean_sigma ▁
# wandb:                                                test_mse ▁
# wandb:                                      test_mse_top100_de ▁
# wandb:                                      test_mse_top200_de ▁
# wandb:                                     test_mse_top200_hvg ▁
# wandb:                                       test_mse_top20_de ▁
# wandb:                                       test_mse_top50_de ▁
# wandb:                                            test_pearson ▁
# wandb:                                      test_pearson_delta ▁
# wandb:                                   test_pearson_delta_de ▁
# wandb:                            test_pearson_delta_top100_de ▁
# wandb:                            test_pearson_delta_top200_de ▁
# wandb:                           test_pearson_delta_top200_hvg ▁
# wandb:                             test_pearson_delta_top20_de ▁
# wandb:                             test_pearson_delta_top50_de ▁
# wandb:                                  test_pearson_top100_de ▁
# wandb:                                  test_pearson_top200_de ▁
# wandb:                                 test_pearson_top200_hvg ▁
# wandb:                                   test_pearson_top20_de ▁
# wandb:                                   test_pearson_top50_de ▁
# wandb:                                                 test_r2 ▁
# wandb:                                           test_spearman ▁
# wandb:                                          test_std_sigma ▁
# wandb:                  test_unseen_single_fold_change_gap_all ▁
# wandb:          test_unseen_single_fold_change_gap_downreg_0.1
# wandb:         test_unseen_single_fold_change_gap_downreg_0.33
# wandb:             test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:              test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                        test_unseen_single_frac_in_range ▁
# wandb:                  test_unseen_single_frac_in_range_25_75 ▁
# wandb:                  test_unseen_single_frac_in_range_40_60 ▁
# wandb:                  test_unseen_single_frac_in_range_45_55 ▁
# wandb:                   test_unseen_single_frac_sigma_below_1 ▁
# wandb:                   test_unseen_single_frac_sigma_below_2 ▁
# wandb:                                  test_unseen_single_mae ▁
# wandb:                               test_unseen_single_mae_de ▁
# wandb:                           test_unseen_single_mean_sigma ▁
# wandb:                                  test_unseen_single_mse ▁
# wandb:                               test_unseen_single_mse_de ▁
# wandb:                        test_unseen_single_mse_top100_de ▁
# wandb:                        test_unseen_single_mse_top200_de ▁
# wandb:                       test_unseen_single_mse_top200_hvg ▁
# wandb:                         test_unseen_single_mse_top20_de ▁
# wandb:                         test_unseen_single_mse_top50_de ▁
# wandb:                              test_unseen_single_pearson ▁
# wandb:                           test_unseen_single_pearson_de ▁
# wandb:                        test_unseen_single_pearson_delta ▁
# wandb:                     test_unseen_single_pearson_delta_de ▁
# wandb:              test_unseen_single_pearson_delta_top100_de ▁
# wandb:              test_unseen_single_pearson_delta_top200_de ▁
# wandb:             test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:               test_unseen_single_pearson_delta_top20_de ▁
# wandb:               test_unseen_single_pearson_delta_top50_de ▁
# wandb:                    test_unseen_single_pearson_top100_de ▁
# wandb:                    test_unseen_single_pearson_top200_de ▁
# wandb:                   test_unseen_single_pearson_top200_hvg ▁
# wandb:                     test_unseen_single_pearson_top20_de ▁
# wandb:                     test_unseen_single_pearson_top50_de ▁
# wandb:                                   test_unseen_single_r2 ▁
# wandb:                                test_unseen_single_r2_de ▁
# wandb:                             test_unseen_single_spearman ▁
# wandb:                          test_unseen_single_spearman_de ▁
# wandb:                            test_unseen_single_std_sigma ▁
# wandb:                                            train_de_mae ▆▇█▄▂▂▂▁▁▁
# wandb:                                            train_de_mse ▆▇█▃▁▂▂▁▁▁
# wandb:                                        train_de_pearson ▁▁▆▇▇█████
# wandb:                                             train_de_r2 ▄█▁▃▅▅▅▅▅▅
# wandb:                                       train_de_spearman ▁▂▆▆▇██▇██
# wandb:                                               train_mae ▄▄▅█▄▂▂▁▂▂
# wandb:                                               train_mse ▅▆▆█▄▂▂▁▂▂
# wandb:                                           train_pearson ▁▅▁▂▆▆▇█▇▇
# wandb:                                                train_r2 ▄▇▁▃▇▇▇███
# wandb:                                          train_spearman ▁▅▆▇██████
# wandb:                                           training_loss █▂▇▄▃▄▃▄▅▂▆▃▇▃▄▄▄▅▄▄▄▂▅▄▃▅▄▃▃▅▁▃▃▆▄▄▄▄▂▂
# wandb:                                              val_de_mae ▇▇█▅▂▂▂▁▁▁
# wandb:                                              val_de_mse ▇▇█▃▁▂▁▁▁▁
# wandb:                                          val_de_pearson ▁▅▄▇█▇▇███
# wandb:                                               val_de_r2 ▄█▆▃▂▃▁▂▁▁
# wandb:                                         val_de_spearman ▁▅▅███▇▇██
# wandb:                                                 val_mae ▆▆▅█▄▂▂▁▂▂
# wandb:                                                 val_mse ▇█▇█▃▂▂▁▂▂
# wandb:                                             val_pearson ▁▆▂▃▇▇▇█▇▇
# wandb:                                                  val_r2 ▃▇▁▃▇▇▇███
# wandb:                                            val_spearman ▁▆▆▇██████
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced no_gnn_coexp_0.95_thr: https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/1b31ibzc

# %%
# !python train.py --dataset Norman2019 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3 \
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:4 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --no_gnn \
                 --exp_name no_gnn_delta_predict \
                 --delta_predict \
                 --wandb
# Out:
# ---- Printing Arguments ----
# dataset: Norman2019
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:4
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: True
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: False
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: True
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: no_gnn_delta_predict
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run no_gnn_delta_predict
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/1ifm8y6r
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_164137-1ifm8y6r
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_co-expression_100.0_64_2_l3_Norman2019_gamma2_gene_emb_delta_predict_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 24886 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:9
# combo_seen1:52
# combo_seen2:18
# unseen_single:37
# Creating dataloaders....
# Dataloaders created...
# Finished data setup, in total takes 0.839 min
# Initializing model...
# Start Training...
# Epoch 1 Step 1 Train Loss: 0.1799
# Epoch 1 Step 51 Train Loss: 0.1300
# Epoch 1 Step 101 Train Loss: 0.1327
# Epoch 1 Step 151 Train Loss: 0.1231
# Epoch 1 Step 201 Train Loss: 0.1126
# Epoch 1 Step 251 Train Loss: 0.1250
# Epoch 1 Step 301 Train Loss: 0.1265
# Epoch 1 Step 351 Train Loss: 0.1248
# Epoch 1 Step 401 Train Loss: 0.1184
# Epoch 1 Step 451 Train Loss: 0.1315
# Epoch 1 Step 501 Train Loss: 0.1148
# Epoch 1 Step 551 Train Loss: 0.0978
# Epoch 1 Step 601 Train Loss: 0.1146
# Epoch 1 Step 651 Train Loss: 0.1110
# Epoch 1 Step 701 Train Loss: 0.1573
# Epoch 1 Step 751 Train Loss: 0.1292
# Epoch 1 Step 801 Train Loss: 0.0906
# Epoch 1 Step 851 Train Loss: 0.1218
# Epoch 1 Step 901 Train Loss: 0.1176
# Epoch 1 Step 951 Train Loss: 0.1389
# Epoch 1 Step 1001 Train Loss: 0.1265
# Epoch 6 Step 1001 Train Loss: 0.1192
# Epoch 6 Step 1051 Train Loss: 0.1144
# Epoch 6 Step 1101 Train Loss: 0.1175
# Epoch 6 Step 1151 Train Loss: 0.1076
# Epoch 6 Step 1201 Train Loss: 0.1338
# Epoch 6 Step 1251 Train Loss: 0.1203
# Epoch 6 Step 1301 Train Loss: 0.1763
# Epoch 6 Step 1351 Train Loss: 0.1303
# Epoch 6 Step 1401 Train Loss: 0.1231
# Epoch 6 Step 1451 Train Loss: 0.1499
# Epoch 6 Step 1501 Train Loss: 0.1268
# Epoch 6 Step 1551 Train Loss: 0.1272
# Epoch 6 Step 1601 Train Loss: 0.1115
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 6: Train: 0.0050, R2 0.9674 Validation: 0.0053. R2 0.9658 Loss: 0.1162
# DE_Train: 0.0749, R2 0.7991 DE_Validation: 0.1348. R2 0.5327
# Epoch 7 Step 1 Train Loss: 0.1427
# Epoch 7 Step 51 Train Loss: 0.1079
# Epoch 7 Step 101 Train Loss: 0.1095
# Epoch 7 Step 151 Train Loss: 0.1325
# Epoch 7 Step 201 Train Loss: 0.1175
# Epoch 7 Step 251 Train Loss: 0.1043
# Epoch 7 Step 301 Train Loss: 0.1389
# Epoch 7 Step 351 Train Loss: 0.0967
# Epoch 7 Step 401 Train Loss: 0.1069
# Epoch 7 Step 451 Train Loss: 0.1577
# Epoch 7 Step 501 Train Loss: 0.0964
# Epoch 7 Step 551 Train Loss: 0.1584
# Epoch 7 Step 601 Train Loss: 0.1057
# Epoch 7 Step 651 Train Loss: 0.1019
# Epoch 7 Step 701 Train Loss: 0.0906
# Epoch 7 Step 751 Train Loss: 0.1147
# Epoch 7 Step 801 Train Loss: 0.1228
# Epoch 7 Step 851 Train Loss: 0.1063
# Epoch 7 Step 901 Train Loss: 0.1170
# Epoch 7 Step 951 Train Loss: 0.1085
# Epoch 7 Step 1001 Train Loss: 0.1184
# Epoch 7 Step 1051 Train Loss: 0.1049
# Epoch 7 Step 1101 Train Loss: 0.1323
# Epoch 7 Step 1151 Train Loss: 0.0992
# Epoch 7 Step 1201 Train Loss: 0.1202
# Epoch 7 Step 1251 Train Loss: 0.1296
# Epoch 7 Step 1301 Train Loss: 0.1350
# Epoch 7 Step 1351 Train Loss: 0.0977
# Epoch 7 Step 1401 Train Loss: 0.1201
# Epoch 7 Step 1451 Train Loss: 0.1233
# Epoch 7 Step 1501 Train Loss: 0.1037
# Epoch 7 Step 1551 Train Loss: 0.1324
# Epoch 7 Step 1601 Train Loss: 0.1136
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 7: Train: 0.0044, R2 0.9704 Validation: 0.0054. R2 0.9650 Loss: 0.1158
# DE_Train: 0.0715, R2 0.7745 DE_Validation: 0.1330. R2 0.4908
# Epoch 8 Step 1 Train Loss: 0.1008
# Epoch 8 Step 51 Train Loss: 0.1273
# Epoch 8 Step 101 Train Loss: 0.0995
# Epoch 8 Step 151 Train Loss: 0.1184
# Epoch 8 Step 201 Train Loss: 0.1088
# Epoch 8 Step 251 Train Loss: 0.1073
# Epoch 8 Step 301 Train Loss: 0.0939
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 9: Train: 0.0051, R2 0.9661 Validation: 0.0060. R2 0.9608 Loss: 0.1158
# DE_Train: 0.0648, R2 0.7597 DE_Validation: 0.1326. R2 0.4947
# Epoch 10 Step 1 Train Loss: 0.1229
# Epoch 10 Step 51 Train Loss: 0.1075
# Epoch 10 Step 101 Train Loss: 0.1182
# Epoch 10 Step 151 Train Loss: 0.1187
# Epoch 10 Step 201 Train Loss: 0.1033
# Epoch 10 Step 251 Train Loss: 0.1005
# Epoch 10 Step 301 Train Loss: 0.1254
# Epoch 10 Step 351 Train Loss: 0.1264
# Epoch 10 Step 401 Train Loss: 0.1626
# Epoch 10 Step 451 Train Loss: 0.1304
# Epoch 10 Step 501 Train Loss: 0.1111
# Epoch 10 Step 551 Train Loss: 0.1423
# Epoch 10 Step 601 Train Loss: 0.1113
# Epoch 10 Step 651 Train Loss: 0.1115
# Epoch 10 Step 701 Train Loss: 0.1619
# Epoch 10 Step 751 Train Loss: 0.1090
# Epoch 10 Step 801 Train Loss: 0.1054
# Epoch 10 Step 851 Train Loss: 0.1244
# Epoch 10 Step 901 Train Loss: 0.1431
# Epoch 10 Step 951 Train Loss: 0.1099
# Epoch 10 Step 1001 Train Loss: 0.1159
# Epoch 10 Step 1051 Train Loss: 0.1160
# Epoch 10 Step 1101 Train Loss: 0.1332
# Epoch 10 Step 1151 Train Loss: 0.1561
# Epoch 10 Step 1201 Train Loss: 0.0990
# Epoch 10 Step 1251 Train Loss: 0.1130
# Epoch 10 Step 1301 Train Loss: 0.1063
# Epoch 10 Step 1351 Train Loss: 0.1052
# Epoch 10 Step 1401 Train Loss: 0.1387
# Epoch 10 Step 1451 Train Loss: 0.1392
# Epoch 10 Step 1501 Train Loss: 0.1312
# Epoch 10 Step 1551 Train Loss: 0.1039
# Epoch 10 Step 1601 Train Loss: 0.1127
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 10: Train: 0.0052, R2 0.9651 Validation: 0.0060. R2 0.9603 Loss: 0.1158
# DE_Train: 0.0658, R2 0.7542 DE_Validation: 0.1335. R2 0.4594
# Saving model....
# Start testing....
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Final best performing model: Test_DE: 0.1483, R2 0.3773
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# ...
# wandb:              test_SYNERGY_DISSIMILAR_PHENO_mse_top50_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_fold_change_gap_all ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_40_60 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_45_55 ▁
# wandb:                   test_SYNERGY_SIMILAR_PHENO_mean_sigma ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top100_de ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top200_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top20_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top50_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:                    test_combo_seen0_fold_change_gap_all ▁
# wandb:            test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:               test_combo_seen0_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen0_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen0_frac_in_range ▁
# wandb:                    test_combo_seen0_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen0_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen0_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen0_mae ▁
# wandb:                                 test_combo_seen0_mae_de ▁
# wandb:                             test_combo_seen0_mean_sigma ▁
# wandb:                                    test_combo_seen0_mse ▁
# wandb:                                 test_combo_seen0_mse_de ▁
# wandb:                          test_combo_seen0_mse_top100_de ▁
# wandb:                          test_combo_seen0_mse_top200_de ▁
# wandb:                         test_combo_seen0_mse_top200_hvg ▁
# wandb:                           test_combo_seen0_mse_top20_de ▁
# wandb:                           test_combo_seen0_mse_top50_de ▁
# wandb:                                test_combo_seen0_pearson ▁
# wandb:                             test_combo_seen0_pearson_de ▁
# wandb:                          test_combo_seen0_pearson_delta ▁
# wandb:                       test_combo_seen0_pearson_delta_de ▁
# wandb:                test_combo_seen0_pearson_delta_top100_de ▁
# wandb:                test_combo_seen0_pearson_delta_top200_de ▁
# wandb:               test_combo_seen0_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen0_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen0_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen0_pearson_top100_de ▁
# wandb:                      test_combo_seen0_pearson_top200_de ▁
# wandb:                     test_combo_seen0_pearson_top200_hvg ▁
# wandb:                       test_combo_seen0_pearson_top20_de ▁
# wandb:                       test_combo_seen0_pearson_top50_de ▁
# wandb:                                     test_combo_seen0_r2 ▁
# wandb:                                  test_combo_seen0_r2_de ▁
# wandb:                               test_combo_seen0_spearman ▁
# wandb:                            test_combo_seen0_spearman_de ▁
# wandb:                              test_combo_seen0_std_sigma ▁
# wandb:                    test_combo_seen1_fold_change_gap_all ▁
# wandb:            test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen1_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen1_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen1_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen1_frac_in_range ▁
# wandb:                    test_combo_seen1_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen1_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen1_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen1_mae ▁
# wandb:                                 test_combo_seen1_mae_de ▁
# wandb:                             test_combo_seen1_mean_sigma ▁
# wandb:                                    test_combo_seen1_mse ▁
# wandb:                                 test_combo_seen1_mse_de ▁
# wandb:                          test_combo_seen1_mse_top100_de ▁
# wandb:                          test_combo_seen1_mse_top200_de ▁
# wandb:                         test_combo_seen1_mse_top200_hvg ▁
# wandb:                           test_combo_seen1_mse_top20_de ▁
# wandb:                           test_combo_seen1_mse_top50_de ▁
# wandb:                                test_combo_seen1_pearson ▁
# wandb:                             test_combo_seen1_pearson_de ▁
# wandb:                          test_combo_seen1_pearson_delta ▁
# wandb:                       test_combo_seen1_pearson_delta_de ▁
# wandb:                test_combo_seen1_pearson_delta_top100_de ▁
# wandb:                test_combo_seen1_pearson_delta_top200_de ▁
# wandb:               test_combo_seen1_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen1_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen1_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen1_pearson_top100_de ▁
# wandb:                      test_combo_seen1_pearson_top200_de ▁
# wandb:                     test_combo_seen1_pearson_top200_hvg ▁
# wandb:                       test_combo_seen1_pearson_top20_de ▁
# wandb:                       test_combo_seen1_pearson_top50_de ▁
# wandb:                                     test_combo_seen1_r2 ▁
# wandb:                                  test_combo_seen1_r2_de ▁
# wandb:                               test_combo_seen1_spearman ▁
# wandb:                            test_combo_seen1_spearman_de ▁
# wandb:                              test_combo_seen1_std_sigma ▁
# wandb:                    test_combo_seen2_fold_change_gap_all ▁
# wandb:            test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen2_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen2_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen2_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen2_frac_in_range ▁
# wandb:                    test_combo_seen2_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen2_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen2_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen2_mae ▁
# wandb:                                 test_combo_seen2_mae_de ▁
# wandb:                             test_combo_seen2_mean_sigma ▁
# wandb:                                    test_combo_seen2_mse ▁
# wandb:                                 test_combo_seen2_mse_de ▁
# wandb:                          test_combo_seen2_mse_top100_de ▁
# wandb:                          test_combo_seen2_mse_top200_de ▁
# wandb:                         test_combo_seen2_mse_top200_hvg ▁
# wandb:                           test_combo_seen2_mse_top20_de ▁
# wandb:                           test_combo_seen2_mse_top50_de ▁
# wandb:                                test_combo_seen2_pearson ▁
# wandb:                             test_combo_seen2_pearson_de ▁
# wandb:                          test_combo_seen2_pearson_delta ▁
# wandb:                       test_combo_seen2_pearson_delta_de ▁
# wandb:                test_combo_seen2_pearson_delta_top100_de ▁
# wandb:                test_combo_seen2_pearson_delta_top200_de ▁
# wandb:               test_combo_seen2_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen2_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen2_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen2_pearson_top100_de ▁
# wandb:                      test_combo_seen2_pearson_top200_de ▁
# wandb:                     test_combo_seen2_pearson_top200_hvg ▁
# wandb:                       test_combo_seen2_pearson_top20_de ▁
# wandb:                       test_combo_seen2_pearson_top50_de ▁
# wandb:                                     test_combo_seen2_r2 ▁
# wandb:                                  test_combo_seen2_r2_de ▁
# wandb:                               test_combo_seen2_spearman ▁
# wandb:                            test_combo_seen2_spearman_de ▁
# wandb:                              test_combo_seen2_std_sigma ▁
# wandb:                                             test_de_mae ▁
# wandb:                                             test_de_mse ▁
# wandb:                                         test_de_pearson ▁
# wandb:                                              test_de_r2 ▁
# wandb:                                        test_de_spearman ▁
# wandb:                                test_fold_change_gap_all ▁
# wandb:                        test_fold_change_gap_downreg_0.1
# wandb:                       test_fold_change_gap_downreg_0.33 ▁
# wandb:                           test_fold_change_gap_upreg_10 ▁
# wandb:                            test_fold_change_gap_upreg_3 ▁
# wandb:                                      test_frac_in_range ▁
# wandb:                                test_frac_in_range_25_75 ▁
# wandb:                                test_frac_in_range_40_60 ▁
# wandb:                                test_frac_in_range_45_55 ▁
# wandb:                                 test_frac_sigma_below_1 ▁
# wandb:                                 test_frac_sigma_below_2 ▁
# wandb:                                                test_mae ▁
# wandb:                                         test_mean_sigma ▁
# wandb:                                                test_mse ▁
# wandb:                                      test_mse_top100_de ▁
# wandb:                                      test_mse_top200_de ▁
# wandb:                                     test_mse_top200_hvg ▁
# wandb:                                       test_mse_top20_de ▁
# wandb:                                       test_mse_top50_de ▁
# wandb:                                            test_pearson ▁
# wandb:                                      test_pearson_delta ▁
# wandb:                                   test_pearson_delta_de ▁
# wandb:                            test_pearson_delta_top100_de ▁
# wandb:                            test_pearson_delta_top200_de ▁
# wandb:                           test_pearson_delta_top200_hvg ▁
# wandb:                             test_pearson_delta_top20_de ▁
# wandb:                             test_pearson_delta_top50_de ▁
# wandb:                                  test_pearson_top100_de ▁
# wandb:                                  test_pearson_top200_de ▁
# wandb:                                 test_pearson_top200_hvg ▁
# wandb:                                   test_pearson_top20_de ▁
# wandb:                                   test_pearson_top50_de ▁
# wandb:                                                 test_r2 ▁
# wandb:                                           test_spearman ▁
# wandb:                                          test_std_sigma ▁
# wandb:                  test_unseen_single_fold_change_gap_all ▁
# wandb:          test_unseen_single_fold_change_gap_downreg_0.1
# wandb:         test_unseen_single_fold_change_gap_downreg_0.33
# wandb:             test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:              test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                        test_unseen_single_frac_in_range ▁
# wandb:                  test_unseen_single_frac_in_range_25_75 ▁
# wandb:                  test_unseen_single_frac_in_range_40_60 ▁
# wandb:                  test_unseen_single_frac_in_range_45_55 ▁
# wandb:                   test_unseen_single_frac_sigma_below_1 ▁
# wandb:                   test_unseen_single_frac_sigma_below_2 ▁
# wandb:                                  test_unseen_single_mae ▁
# wandb:                               test_unseen_single_mae_de ▁
# wandb:                           test_unseen_single_mean_sigma ▁
# wandb:                                  test_unseen_single_mse ▁
# wandb:                               test_unseen_single_mse_de ▁
# wandb:                        test_unseen_single_mse_top100_de ▁
# wandb:                        test_unseen_single_mse_top200_de ▁
# wandb:                       test_unseen_single_mse_top200_hvg ▁
# wandb:                         test_unseen_single_mse_top20_de ▁
# wandb:                         test_unseen_single_mse_top50_de ▁
# wandb:                              test_unseen_single_pearson ▁
# wandb:                           test_unseen_single_pearson_de ▁
# wandb:                        test_unseen_single_pearson_delta ▁
# wandb:                     test_unseen_single_pearson_delta_de ▁
# wandb:              test_unseen_single_pearson_delta_top100_de ▁
# wandb:              test_unseen_single_pearson_delta_top200_de ▁
# wandb:             test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:               test_unseen_single_pearson_delta_top20_de ▁
# wandb:               test_unseen_single_pearson_delta_top50_de ▁
# wandb:                    test_unseen_single_pearson_top100_de ▁
# wandb:                    test_unseen_single_pearson_top200_de ▁
# wandb:                   test_unseen_single_pearson_top200_hvg ▁
# wandb:                     test_unseen_single_pearson_top20_de ▁
# wandb:                     test_unseen_single_pearson_top50_de ▁
# wandb:                                   test_unseen_single_r2 ▁
# wandb:                                test_unseen_single_r2_de ▁
# wandb:                             test_unseen_single_spearman ▁
# wandb:                          test_unseen_single_spearman_de ▁
# wandb:                            test_unseen_single_std_sigma ▁
# wandb:                                            train_de_mae █▆▇▆▂▂▂▁▁▁
# wandb:                                            train_de_mse █▅▇▅▁▁▁▁▁▁
# wandb:                                        train_de_pearson ▃▄▁▂▇█████
# wandb:                                             train_de_r2 ▇█▁▆▇█████
# wandb:                                       train_de_spearman ▄▄▁▂▇█████
# wandb:                                               train_mae ▂▁██▃▁▁▁▂▂
# wandb:                                               train_mse ▂▁▅█▂▁▁▁▁▁
# wandb:                                           train_pearson ▁▆▃▄▆█████
# wandb:                                                train_r2 ▇█▄▁▇█████
# wandb:                                          train_spearman ▁▁▂▆▆█▇█▇▇
# wandb:                                           training_loss █▄█▁▁▅▃▄▃▂▆▆▄▂▅▅▂▄▅▄▅▃▇▃▇▁▃▂▂▅▂▄▂▇▂▄▇▂▃▁
# wandb:                                              val_de_mae ▄▅█▇▁▁▁▁▁▁
# wandb:                                              val_de_mse ▄▄██▁▁▁▁▁▁
# wandb:                                          val_de_pearson █▇▁▁██████
# wandb:                                               val_de_r2 ▇█▁▆▇▇▇▇▇▇
# wandb:                                         val_de_spearman ▇▇▁▂██████
# wandb:                                                 val_mae ▄▁█▆▄▂▂▂▃▃
# wandb:                                                 val_mse ▃▁██▂▂▂▁▂▂
# wandb:                                             val_pearson ▁▇▁▁▆▇██▇█
# wandb:                                                  val_r2 ▆█▁▁▇▇▇█▇▇
# wandb:                                            val_spearman ▁▁▃▇▇███▇▇
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced no_gnn_delta_predict: https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/1ifm8y6r

# %%
# !python train.py --dataset Adamson2016 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3 \
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:2 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --no_gnn \
                 --exp_name no_gnn_uncertainty \
                 --wandb \
                 --uncertainty
# Out:
# ---- Printing Arguments ----
# dataset: Adamson2016
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:2
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: False
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: True
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: True
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: no_gnn_uncertainty
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run no_gnn_uncertainty
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016/runs/e1hq3fxk
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_211306-e1hq3fxk
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_co-expression_100.0_64_2_l3_Adamson2016_gamma2_gene_emb_pert_emb_constant_sim_gnn_uncertainty_1_1
# Building cell graph...
# There are 7054 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:22
# Creating dataloaders....
# Dataloaders created...
# Finished data setup, in total takes 0.480 min
# Initializing model...
# Start Training...
# Epoch 1 Step 1 Train Loss: 10.8807
# Epoch 1 Step 51 Train Loss: 0.2239
# Epoch 1 Step 101 Train Loss: 0.1633
# Epoch 1 Step 151 Train Loss: 0.1487
# Epoch 1 Step 201 Train Loss: 0.1137
# Epoch 1 Step 251 Train Loss: 0.0856
# Epoch 1 Step 301 Train Loss: 0.0964
# Epoch 1 Step 351 Train Loss: 0.0846
# Epoch 1 Step 401 Train Loss: 0.1216
# Epoch 1 Step 451 Train Loss: 0.0875
# Epoch 1 Step 501 Train Loss: 0.1306
# Epoch 1 Step 551 Train Loss: 0.0984
# Epoch 1 Step 601 Train Loss: 0.0969
# Epoch 1 Step 651 Train Loss: 0.1022
# Epoch 1 Step 701 Train Loss: 0.0804
# Epoch 1 Step 751 Train Loss: 0.1062
# Epoch 1 Step 801 Train Loss: 0.0918
# Epoch 1 Step 851 Train Loss: 0.0778
# Epoch 1 Step 901 Train Loss: 0.1195
# Epoch 1 Step 951 Train Loss: 0.0818
# Epoch 1 Step 1001 Train Loss: 0.1167
# Epoch 1 Step 1051 Train Loss: 0.0962
# Epoch 1 Step 1101 Train Loss: 0.1355
# Epoch 1 Step 1151 Train Loss: 0.0815
# Epoch 1 Step 1201 Train Loss: 0.1189
# Epoch 1 Step 1251 Train Loss: 0.0837
# Epoch 1 Step 1301 Train Loss: 0.1480
# Epoch 1 Step 1351 Train Loss: 0.0773
# Epoch 1 Step 1401 Train Loss: 0.0762
# Epoch 1 Step 1451 Train Loss: 0.0944
# Epoch 1 Step 1501 Train Loss: 0.0692
# Epoch 1 Step 1551 Train Loss: 0.1226
# Epoch 1 Step 1601 Train Loss: 0.0642
RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# test_combo_seen0_mse: nan
# test_combo_seen0_mae: nan
# test_combo_seen0_spearman: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_r2: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_mae_de: nan
# test_combo_seen0_spearman_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen0_r2_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_mae: nan
# test_combo_seen1_spearman: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_r2: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_mae_de: nan
# test_combo_seen1_spearman_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen1_r2_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_mae: nan
# test_combo_seen2_spearman: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_r2: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_mae_de: nan
# test_combo_seen2_spearman_de: nan
# test_combo_seen2_pearson_de: nan
# test_combo_seen2_r2_de: nan
# test_unseen_single_mse: 0.029190348
# test_unseen_single_mae: 0.15297998
# test_unseen_single_spearman: 0.9731900192996182
# test_unseen_single_pearson: 0.9835802897873035
# test_unseen_single_r2: 0.8773860063483672
# test_unseen_single_mse_de: 0.14892001
# test_unseen_single_mae_de: 0.26754928
# test_unseen_single_spearman_de: 0.957936581266888
# test_unseen_single_pearson_de: 0.972034861082233
# test_unseen_single_r2_de: 0.9137039688477905
# test_combo_seen0_frac_in_range: nan
# test_combo_seen0_frac_in_range_45_55: nan
# test_combo_seen0_frac_in_range_40_60: nan
# test_combo_seen0_frac_in_range_25_75: nan
# test_combo_seen0_mean_sigma: nan
# test_combo_seen0_std_sigma: nan
# test_combo_seen0_frac_sigma_below_1: nan
# test_combo_seen0_frac_sigma_below_2: nan
# test_combo_seen0_pearson_delta: nan
# test_combo_seen0_pearson_delta_de: nan
# test_combo_seen0_fold_change_gap_all: nan
# test_combo_seen0_pearson_delta_top200_hvg: nan
# test_combo_seen0_fold_change_gap_upreg_3: nan
# test_combo_seen0_fold_change_gap_downreg_0.33: nan
# test_combo_seen0_fold_change_gap_downreg_0.1: nan
# test_combo_seen0_fold_change_gap_upreg_10: nan
# test_combo_seen0_pearson_top200_hvg: nan
# test_combo_seen0_pearson_top200_de: nan
# test_combo_seen0_pearson_top20_de: nan
# test_combo_seen0_pearson_delta_top200_de: nan
# test_combo_seen0_pearson_top100_de: nan
# test_combo_seen0_pearson_delta_top100_de: nan
# test_combo_seen0_pearson_delta_top50_de: nan
# test_combo_seen0_pearson_top50_de: nan
# test_combo_seen0_pearson_delta_top20_de: nan
# test_combo_seen0_mse_top200_hvg: nan
# test_combo_seen0_mse_top100_de: nan
# test_combo_seen0_mse_top200_de: nan
# test_combo_seen0_mse_top50_de: nan
# test_combo_seen0_mse_top20_de: nan
# test_combo_seen1_frac_in_range: nan
# test_combo_seen1_frac_in_range_45_55: nan
# test_combo_seen1_frac_in_range_40_60: nan
# test_combo_seen1_frac_in_range_25_75: nan
# test_combo_seen1_mean_sigma: nan
# test_combo_seen1_std_sigma: nan
# test_combo_seen1_frac_sigma_below_1: nan
# test_combo_seen1_frac_sigma_below_2: nan
# test_combo_seen1_pearson_delta: nan
# test_combo_seen1_pearson_delta_de: nan
# test_combo_seen1_fold_change_gap_all: nan
# test_combo_seen1_pearson_delta_top200_hvg: nan
# test_combo_seen1_fold_change_gap_upreg_3: nan
# test_combo_seen1_fold_change_gap_downreg_0.33: nan
# test_combo_seen1_fold_change_gap_downreg_0.1: nan
# test_combo_seen1_fold_change_gap_upreg_10: nan
# test_combo_seen1_pearson_top200_hvg: nan
# test_combo_seen1_pearson_top200_de: nan
# test_combo_seen1_pearson_top20_de: nan
# test_combo_seen1_pearson_delta_top200_de: nan
# test_combo_seen1_pearson_top100_de: nan
# test_combo_seen1_pearson_delta_top100_de: nan
# test_combo_seen1_pearson_delta_top50_de: nan
# test_combo_seen1_pearson_top50_de: nan
# test_combo_seen1_pearson_delta_top20_de: nan
# test_combo_seen1_mse_top200_hvg: nan
# test_combo_seen1_mse_top100_de: nan
# test_combo_seen1_mse_top200_de: nan
# test_combo_seen1_mse_top50_de: nan
# test_combo_seen1_mse_top20_de: nan
# test_combo_seen2_frac_in_range: nan
# test_combo_seen2_frac_in_range_45_55: nan
# test_combo_seen2_frac_in_range_40_60: nan
# test_combo_seen2_frac_in_range_25_75: nan
# test_combo_seen2_mean_sigma: nan
# test_combo_seen2_std_sigma: nan
# test_combo_seen2_frac_sigma_below_1: nan
# test_combo_seen2_frac_sigma_below_2: nan
# test_combo_seen2_pearson_delta: nan
# test_combo_seen2_pearson_delta_de: nan
# test_combo_seen2_fold_change_gap_all: nan
# test_combo_seen2_pearson_delta_top200_hvg: nan
# test_combo_seen2_fold_change_gap_upreg_3: nan
# test_combo_seen2_fold_change_gap_downreg_0.33: nan
# test_combo_seen2_fold_change_gap_downreg_0.1: nan
# test_combo_seen2_fold_change_gap_upreg_10: nan
# test_combo_seen2_pearson_top200_hvg: nan
# test_combo_seen2_pearson_top200_de: nan
# test_combo_seen2_pearson_top20_de: nan
# test_combo_seen2_pearson_delta_top200_de: nan
# test_combo_seen2_pearson_top100_de: nan
# test_combo_seen2_pearson_delta_top100_de: nan
# test_combo_seen2_pearson_delta_top50_de: nan
# test_combo_seen2_pearson_top50_de: nan
# test_combo_seen2_pearson_delta_top20_de: nan
# test_combo_seen2_mse_top200_hvg: nan
# test_combo_seen2_mse_top100_de: nan
# test_combo_seen2_mse_top200_de: nan
# test_combo_seen2_mse_top50_de: nan
# test_combo_seen2_mse_top20_de: nan
# test_unseen_single_frac_in_range: 0.9818181818181819
# test_unseen_single_frac_in_range_45_55: 0.07206937799043062
# test_unseen_single_frac_in_range_40_60: 0.16970693779904306
# test_unseen_single_frac_in_range_25_75: 0.5435705741626794
# test_unseen_single_mean_sigma: 0.82425696
# test_unseen_single_std_sigma: 0.55020154
# test_unseen_single_frac_sigma_below_1: 0.8400717703349282
# test_unseen_single_frac_sigma_below_2: 0.9105562200956938
# test_unseen_single_pearson_delta: 0.4740731531024538
# test_unseen_single_pearson_delta_de: 0.7236298568664418
# test_unseen_single_fold_change_gap_all: 0.1349863
# test_unseen_single_pearson_delta_top200_hvg: 0.5810780460871713
# test_unseen_single_fold_change_gap_upreg_3: 0.76231337
# test_unseen_single_fold_change_gap_downreg_0.33: 0.57844156
# test_unseen_single_fold_change_gap_downreg_0.1: nan
# test_unseen_single_fold_change_gap_upreg_10: 0.7609062
# test_unseen_single_pearson_top200_hvg: 0.9614200711602175
# test_unseen_single_pearson_top200_de: 0.9837441290442848
# test_unseen_single_pearson_top20_de: 0.9720348610822331
# test_unseen_single_pearson_delta_top200_de: 0.7026851371952918
# test_unseen_single_pearson_top100_de: 0.9817779262219481
# test_unseen_single_pearson_delta_top100_de: 0.7241444276359313
# test_unseen_single_pearson_delta_top50_de: 0.7271730956642126
# test_unseen_single_pearson_top50_de: 0.9781954628429179
# test_unseen_single_pearson_delta_top20_de: 0.7236298568664418
# test_unseen_single_mse_top200_hvg: 0.07325966
# test_unseen_single_mse_top100_de: 0.07866145
# test_unseen_single_mse_top200_de: 0.05704222
# test_unseen_single_mse_top50_de: 0.11116132
# test_unseen_single_mse_top20_de: 0.14892001
# Done!
#
# wandb: Waiting for W&B process to finish, PID 35640
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_211306-e1hq3fxk/logs/debug.log
# wandb: Find internal logs for this run at: /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211108_211306-e1hq3fxk/logs/debug-internal.log
# wandb: Run summary:
# wandb:              test_combo_seen0_fold_change_gap_all nan
# wandb:      test_combo_seen0_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen0_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen0_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen0_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen0_frac_in_range nan
# wandb:              test_combo_seen0_frac_in_range_25_75 nan
# wandb:              test_combo_seen0_frac_in_range_40_60 nan
# wandb:              test_combo_seen0_frac_in_range_45_55 nan
# wandb:               test_combo_seen0_frac_sigma_below_1 nan
# wandb:               test_combo_seen0_frac_sigma_below_2 nan
# wandb:                              test_combo_seen0_mae nan
# wandb:                           test_combo_seen0_mae_de nan
# wandb:                       test_combo_seen0_mean_sigma nan
# wandb:                              test_combo_seen0_mse nan
# wandb:                           test_combo_seen0_mse_de nan
# wandb:                    test_combo_seen0_mse_top100_de nan
# wandb:                    test_combo_seen0_mse_top200_de nan
# wandb:                   test_combo_seen0_mse_top200_hvg nan
# wandb:                     test_combo_seen0_mse_top20_de nan
# wandb:                     test_combo_seen0_mse_top50_de nan
# wandb:                          test_combo_seen0_pearson nan
# wandb:                       test_combo_seen0_pearson_de nan
# wandb:                    test_combo_seen0_pearson_delta nan
# wandb:                 test_combo_seen0_pearson_delta_de nan
# wandb:          test_combo_seen0_pearson_delta_top100_de nan
# wandb:          test_combo_seen0_pearson_delta_top200_de nan
# wandb:         test_combo_seen0_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen0_pearson_delta_top20_de nan
# wandb:           test_combo_seen0_pearson_delta_top50_de nan
# wandb:                test_combo_seen0_pearson_top100_de nan
# wandb:                test_combo_seen0_pearson_top200_de nan
# wandb:               test_combo_seen0_pearson_top200_hvg nan
# wandb:                 test_combo_seen0_pearson_top20_de nan
# wandb:                 test_combo_seen0_pearson_top50_de nan
# wandb:                               test_combo_seen0_r2 nan
# wandb:                            test_combo_seen0_r2_de nan
# wandb:                         test_combo_seen0_spearman nan
# wandb:                      test_combo_seen0_spearman_de nan
# wandb:                        test_combo_seen0_std_sigma nan
# wandb:              test_combo_seen1_fold_change_gap_all nan
# wandb:      test_combo_seen1_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen1_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen1_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen1_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen1_frac_in_range nan
# wandb:              test_combo_seen1_frac_in_range_25_75 nan
# wandb:              test_combo_seen1_frac_in_range_40_60 nan
# wandb:              test_combo_seen1_frac_in_range_45_55 nan
# wandb:               test_combo_seen1_frac_sigma_below_1 nan
# wandb:               test_combo_seen1_frac_sigma_below_2 nan
# wandb:                              test_combo_seen1_mae nan
# wandb:                           test_combo_seen1_mae_de nan
# wandb:                       test_combo_seen1_mean_sigma nan
# wandb:                              test_combo_seen1_mse nan
# wandb:                           test_combo_seen1_mse_de nan
# wandb:                    test_combo_seen1_mse_top100_de nan
# wandb:                    test_combo_seen1_mse_top200_de nan
# wandb:                   test_combo_seen1_mse_top200_hvg nan
# wandb:                     test_combo_seen1_mse_top20_de nan
# wandb:                     test_combo_seen1_mse_top50_de nan
# wandb:                          test_combo_seen1_pearson nan
# wandb:                       test_combo_seen1_pearson_de nan
# wandb:                    test_combo_seen1_pearson_delta nan
# wandb:                 test_combo_seen1_pearson_delta_de nan
# wandb:          test_combo_seen1_pearson_delta_top100_de nan
# wandb:          test_combo_seen1_pearson_delta_top200_de nan
# wandb:         test_combo_seen1_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen1_pearson_delta_top20_de nan
# wandb:           test_combo_seen1_pearson_delta_top50_de nan
# wandb:                test_combo_seen1_pearson_top100_de nan
# wandb:                test_combo_seen1_pearson_top200_de nan
# wandb:               test_combo_seen1_pearson_top200_hvg nan
# wandb:                 test_combo_seen1_pearson_top20_de nan
# wandb:                 test_combo_seen1_pearson_top50_de nan
# wandb:                               test_combo_seen1_r2 nan
# wandb:                            test_combo_seen1_r2_de nan
# wandb:                         test_combo_seen1_spearman nan
# wandb:                      test_combo_seen1_spearman_de nan
# wandb:                        test_combo_seen1_std_sigma nan
# wandb:              test_combo_seen2_fold_change_gap_all nan
# wandb:      test_combo_seen2_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen2_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen2_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen2_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen2_frac_in_range nan
# wandb:              test_combo_seen2_frac_in_range_25_75 nan
# wandb:              test_combo_seen2_frac_in_range_40_60 nan
# wandb:              test_combo_seen2_frac_in_range_45_55 nan
# wandb:               test_combo_seen2_frac_sigma_below_1 nan
# wandb:               test_combo_seen2_frac_sigma_below_2 nan
# wandb:                              test_combo_seen2_mae nan
# wandb:                           test_combo_seen2_mae_de nan
# wandb:                       test_combo_seen2_mean_sigma nan
# wandb:                              test_combo_seen2_mse nan
# wandb:                           test_combo_seen2_mse_de nan
# wandb:                    test_combo_seen2_mse_top100_de nan
# wandb:                    test_combo_seen2_mse_top200_de nan
# wandb:                   test_combo_seen2_mse_top200_hvg nan
# wandb:                     test_combo_seen2_mse_top20_de nan
# wandb:                     test_combo_seen2_mse_top50_de nan
# wandb:                          test_combo_seen2_pearson nan
# wandb:                       test_combo_seen2_pearson_de nan
# wandb:                    test_combo_seen2_pearson_delta nan
# wandb:                 test_combo_seen2_pearson_delta_de nan
# wandb:          test_combo_seen2_pearson_delta_top100_de nan
# wandb:          test_combo_seen2_pearson_delta_top200_de nan
# wandb:         test_combo_seen2_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen2_pearson_delta_top20_de nan
# wandb:           test_combo_seen2_pearson_delta_top50_de nan
# wandb:                test_combo_seen2_pearson_top100_de nan
# wandb:                test_combo_seen2_pearson_top200_de nan
# wandb:               test_combo_seen2_pearson_top200_hvg nan
# wandb:                 test_combo_seen2_pearson_top20_de nan
# wandb:                 test_combo_seen2_pearson_top50_de nan
# wandb:                               test_combo_seen2_r2 nan
# wandb:                            test_combo_seen2_r2_de nan
# wandb:                         test_combo_seen2_spearman nan
# wandb:                      test_combo_seen2_spearman_de nan
# wandb:                        test_combo_seen2_std_sigma nan
# wandb:                                       test_de_mae 0.26755
# wandb:                                       test_de_mse 0.14892
# wandb:                                   test_de_pearson 0.97203
# wandb:                                        test_de_r2 0.9137
# wandb:                                  test_de_spearman 0.95794
# wandb:                          test_fold_change_gap_all 0.13499
# wandb:                  test_fold_change_gap_downreg_0.1 nan
# wandb:                 test_fold_change_gap_downreg_0.33 0.57844
# wandb:                     test_fold_change_gap_upreg_10 0.76091
# wandb:                      test_fold_change_gap_upreg_3 0.76231
# wandb:                                test_frac_in_range 0.98182
# wandb:                          test_frac_in_range_25_75 0.54357
# wandb:                          test_frac_in_range_40_60 0.16971
# wandb:                          test_frac_in_range_45_55 0.07207
# wandb:                           test_frac_sigma_below_1 0.84007
# wandb:                           test_frac_sigma_below_2 0.91056
# wandb:                                          test_mae 0.15298
# wandb:                                   test_mean_sigma 0.82426
# wandb:                                          test_mse 0.02919
# wandb:                                test_mse_top100_de 0.07866
# wandb:                                test_mse_top200_de 0.05704
# wandb:                               test_mse_top200_hvg 0.07326
# wandb:                                 test_mse_top20_de 0.14892
# wandb:                                 test_mse_top50_de 0.11116
# wandb:                                      test_pearson 0.98358
# wandb:                                test_pearson_delta 0.47407
# wandb:                             test_pearson_delta_de 0.72363
# wandb:                      test_pearson_delta_top100_de 0.72414
# wandb:                      test_pearson_delta_top200_de 0.70269
# wandb:                     test_pearson_delta_top200_hvg 0.58108
# wandb:                       test_pearson_delta_top20_de 0.72363
# wandb:                       test_pearson_delta_top50_de 0.72717
# wandb:                            test_pearson_top100_de 0.98178
# wandb:                            test_pearson_top200_de 0.98374
# wandb:                           test_pearson_top200_hvg 0.96142
# wandb:                             test_pearson_top20_de 0.97203
# wandb:                             test_pearson_top50_de 0.9782
# wandb:                                           test_r2 0.87739
# wandb:                                     test_spearman 0.97319
# wandb:                                    test_std_sigma 0.5502
# wandb:            test_unseen_single_fold_change_gap_all 0.13499
# wandb:    test_unseen_single_fold_change_gap_downreg_0.1 nan
# wandb:   test_unseen_single_fold_change_gap_downreg_0.33 0.57844
# wandb:       test_unseen_single_fold_change_gap_upreg_10 0.76091
# wandb:        test_unseen_single_fold_change_gap_upreg_3 0.76231
# wandb:                  test_unseen_single_frac_in_range 0.98182
# wandb:            test_unseen_single_frac_in_range_25_75 0.54357
# wandb:            test_unseen_single_frac_in_range_40_60 0.16971
# wandb:            test_unseen_single_frac_in_range_45_55 0.07207
# wandb:             test_unseen_single_frac_sigma_below_1 0.84007
# wandb:             test_unseen_single_frac_sigma_below_2 0.91056
# wandb:                            test_unseen_single_mae 0.15298
# wandb:                         test_unseen_single_mae_de 0.26755
# wandb:                     test_unseen_single_mean_sigma 0.82426
# wandb:                            test_unseen_single_mse 0.02919
# wandb:                         test_unseen_single_mse_de 0.14892
# wandb:                  test_unseen_single_mse_top100_de 0.07866
# wandb:                  test_unseen_single_mse_top200_de 0.05704
# wandb:                 test_unseen_single_mse_top200_hvg 0.07326
# wandb:                   test_unseen_single_mse_top20_de 0.14892
# wandb:                   test_unseen_single_mse_top50_de 0.11116
# wandb:                        test_unseen_single_pearson 0.98358
# wandb:                     test_unseen_single_pearson_de 0.97203
# wandb:                  test_unseen_single_pearson_delta 0.47407
# wandb:               test_unseen_single_pearson_delta_de 0.72363
# wandb:        test_unseen_single_pearson_delta_top100_de 0.72414
# wandb:        test_unseen_single_pearson_delta_top200_de 0.70269
# wandb:       test_unseen_single_pearson_delta_top200_hvg 0.58108
# wandb:         test_unseen_single_pearson_delta_top20_de 0.72363
# wandb:         test_unseen_single_pearson_delta_top50_de 0.72717
# wandb:              test_unseen_single_pearson_top100_de 0.98178
# wandb:              test_unseen_single_pearson_top200_de 0.98374
# wandb:             test_unseen_single_pearson_top200_hvg 0.96142
# wandb:               test_unseen_single_pearson_top20_de 0.97203
# wandb:               test_unseen_single_pearson_top50_de 0.9782
# wandb:                             test_unseen_single_r2 0.87739
# wandb:                          test_unseen_single_r2_de 0.9137
# wandb:                       test_unseen_single_spearman 0.97319
# wandb:                    test_unseen_single_spearman_de 0.95794
# wandb:                      test_unseen_single_std_sigma 0.5502
# wandb:                                      train_de_mae 0.2277
# wandb:                                      train_de_mse 0.11916
# wandb:                                  train_de_pearson 0.97185
# wandb:                                       train_de_r2 0.91027
# wandb:                                 train_de_spearman 0.94203
# wandb:                                         train_mae 0.14107
# wandb:                                         train_mse 0.02489
# wandb:                                     train_pearson 0.98565
# wandb:                                          train_r2 0.88783
# wandb:                                    train_spearman 0.97849
# wandb:                                     training_loss 0.05528
# wandb:                                        val_de_mae 0.33059
# wandb:                                        val_de_mse 0.19944
# wandb:                                    val_de_pearson 0.9576
# wandb:                                         val_de_r2 0.85175
# wandb:                                   val_de_spearman 0.93083
# wandb:                                           val_mae 0.13329
# wandb:                                           val_mse 0.02242
# wandb:                                       val_pearson 0.98621
# wandb:                                            val_r2 0.89757
# wandb:                                      val_spearman 0.97612
# wandb: Run history:
# wandb:              test_combo_seen0_fold_change_gap_all
# wandb:      test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen0_fold_change_gap_upreg_10
# wandb:          test_combo_seen0_fold_change_gap_upreg_3
# wandb:                    test_combo_seen0_frac_in_range
# wandb:              test_combo_seen0_frac_in_range_25_75
# wandb:              test_combo_seen0_frac_in_range_40_60
# wandb:              test_combo_seen0_frac_in_range_45_55
# wandb:               test_combo_seen0_frac_sigma_below_1
# wandb:               test_combo_seen0_frac_sigma_below_2
# wandb:                              test_combo_seen0_mae
# wandb:                           test_combo_seen0_mae_de
# wandb:                       test_combo_seen0_mean_sigma
# wandb:                              test_combo_seen0_mse
# wandb:                           test_combo_seen0_mse_de
# wandb:                    test_combo_seen0_mse_top100_de
# wandb:                    test_combo_seen0_mse_top200_de
# wandb:                   test_combo_seen0_mse_top200_hvg
# wandb:                     test_combo_seen0_mse_top20_de
# wandb:                     test_combo_seen0_mse_top50_de
# wandb:                          test_combo_seen0_pearson
# wandb:                       test_combo_seen0_pearson_de
# wandb:                    test_combo_seen0_pearson_delta
# wandb:                 test_combo_seen0_pearson_delta_de
# wandb:          test_combo_seen0_pearson_delta_top100_de
# wandb:          test_combo_seen0_pearson_delta_top200_de
# wandb:         test_combo_seen0_pearson_delta_top200_hvg
# wandb:           test_combo_seen0_pearson_delta_top20_de
# wandb:           test_combo_seen0_pearson_delta_top50_de
# wandb:                test_combo_seen0_pearson_top100_de
# wandb:                test_combo_seen0_pearson_top200_de
# wandb:               test_combo_seen0_pearson_top200_hvg
# wandb:                 test_combo_seen0_pearson_top20_de
# wandb:                 test_combo_seen0_pearson_top50_de
# wandb:                               test_combo_seen0_r2
# wandb:                            test_combo_seen0_r2_de
# wandb:                         test_combo_seen0_spearman
# wandb:                      test_combo_seen0_spearman_de
# wandb:                        test_combo_seen0_std_sigma
# wandb:              test_combo_seen1_fold_change_gap_all
# wandb:      test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen1_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen1_fold_change_gap_upreg_10
# wandb:          test_combo_seen1_fold_change_gap_upreg_3
# wandb:                    test_combo_seen1_frac_in_range
# wandb:              test_combo_seen1_frac_in_range_25_75
# wandb:              test_combo_seen1_frac_in_range_40_60
# wandb:              test_combo_seen1_frac_in_range_45_55
# wandb:               test_combo_seen1_frac_sigma_below_1
# wandb:               test_combo_seen1_frac_sigma_below_2
# wandb:                              test_combo_seen1_mae
# wandb:                           test_combo_seen1_mae_de
# wandb:                       test_combo_seen1_mean_sigma
# wandb:                              test_combo_seen1_mse
# wandb:                           test_combo_seen1_mse_de
# wandb:                    test_combo_seen1_mse_top100_de
# wandb:                    test_combo_seen1_mse_top200_de
# wandb:                   test_combo_seen1_mse_top200_hvg
# wandb:                     test_combo_seen1_mse_top20_de
# wandb:                     test_combo_seen1_mse_top50_de
# wandb:                          test_combo_seen1_pearson
# wandb:                       test_combo_seen1_pearson_de
# wandb:                    test_combo_seen1_pearson_delta
# wandb:                 test_combo_seen1_pearson_delta_de
# wandb:          test_combo_seen1_pearson_delta_top100_de
# wandb:          test_combo_seen1_pearson_delta_top200_de
# wandb:         test_combo_seen1_pearson_delta_top200_hvg
# wandb:           test_combo_seen1_pearson_delta_top20_de
# wandb:           test_combo_seen1_pearson_delta_top50_de
# wandb:                test_combo_seen1_pearson_top100_de
# wandb:                test_combo_seen1_pearson_top200_de
# wandb:               test_combo_seen1_pearson_top200_hvg
# wandb:                 test_combo_seen1_pearson_top20_de
# wandb:                 test_combo_seen1_pearson_top50_de
# wandb:                               test_combo_seen1_r2
# wandb:                            test_combo_seen1_r2_de
# wandb:                         test_combo_seen1_spearman
# wandb:                      test_combo_seen1_spearman_de
# wandb:                        test_combo_seen1_std_sigma
# wandb:              test_combo_seen2_fold_change_gap_all
# wandb:      test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen2_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen2_fold_change_gap_upreg_10
# wandb:          test_combo_seen2_fold_change_gap_upreg_3
# wandb:                    test_combo_seen2_frac_in_range
# wandb:              test_combo_seen2_frac_in_range_25_75
# wandb:              test_combo_seen2_frac_in_range_40_60
# wandb:              test_combo_seen2_frac_in_range_45_55
# wandb:               test_combo_seen2_frac_sigma_below_1
# wandb:               test_combo_seen2_frac_sigma_below_2
# wandb:                              test_combo_seen2_mae
# wandb:                           test_combo_seen2_mae_de
# wandb:                       test_combo_seen2_mean_sigma
# wandb:                              test_combo_seen2_mse
# wandb:                           test_combo_seen2_mse_de
# wandb:                    test_combo_seen2_mse_top100_de
# wandb:                    test_combo_seen2_mse_top200_de
# wandb:                   test_combo_seen2_mse_top200_hvg
# wandb:                     test_combo_seen2_mse_top20_de
# wandb:                     test_combo_seen2_mse_top50_de
# wandb:                          test_combo_seen2_pearson
# wandb:                       test_combo_seen2_pearson_de
# wandb:                    test_combo_seen2_pearson_delta
# wandb:                 test_combo_seen2_pearson_delta_de
# wandb:          test_combo_seen2_pearson_delta_top100_de
# wandb:          test_combo_seen2_pearson_delta_top200_de
# wandb:         test_combo_seen2_pearson_delta_top200_hvg
# wandb:           test_combo_seen2_pearson_delta_top20_de
# wandb:           test_combo_seen2_pearson_delta_top50_de
# wandb:                test_combo_seen2_pearson_top100_de
# wandb:                test_combo_seen2_pearson_top200_de
# wandb:               test_combo_seen2_pearson_top200_hvg
# wandb:                 test_combo_seen2_pearson_top20_de
# wandb:                 test_combo_seen2_pearson_top50_de
# wandb:                               test_combo_seen2_r2
# wandb:                            test_combo_seen2_r2_de
# wandb:                         test_combo_seen2_spearman
# wandb:                      test_combo_seen2_spearman_de
# wandb:                        test_combo_seen2_std_sigma
# wandb:                                       test_de_mae ▁
# wandb:                                       test_de_mse ▁
# wandb:                                   test_de_pearson ▁
# wandb:                                        test_de_r2 ▁
# wandb:                                  test_de_spearman ▁
# wandb:                          test_fold_change_gap_all ▁
# wandb:                  test_fold_change_gap_downreg_0.1
# wandb:                 test_fold_change_gap_downreg_0.33 ▁
# wandb:                     test_fold_change_gap_upreg_10 ▁
# wandb:                      test_fold_change_gap_upreg_3 ▁
# wandb:                                test_frac_in_range ▁
# wandb:                          test_frac_in_range_25_75 ▁
# wandb:                          test_frac_in_range_40_60 ▁
# wandb:                          test_frac_in_range_45_55 ▁
# wandb:                           test_frac_sigma_below_1 ▁
# wandb:                           test_frac_sigma_below_2 ▁
# wandb:                                          test_mae ▁
# wandb:                                   test_mean_sigma ▁
# wandb:                                          test_mse ▁
# wandb:                                test_mse_top100_de ▁
# wandb:                                test_mse_top200_de ▁
# wandb:                               test_mse_top200_hvg ▁
# wandb:                                 test_mse_top20_de ▁
# wandb:                                 test_mse_top50_de ▁
# wandb:                                      test_pearson ▁
# wandb:                                test_pearson_delta ▁
# wandb:                             test_pearson_delta_de ▁
# wandb:                      test_pearson_delta_top100_de ▁
# wandb:                      test_pearson_delta_top200_de ▁
# wandb:                     test_pearson_delta_top200_hvg ▁
# wandb:                       test_pearson_delta_top20_de ▁
# wandb:                       test_pearson_delta_top50_de ▁
# wandb:                            test_pearson_top100_de ▁
# wandb:                            test_pearson_top200_de ▁
# wandb:                           test_pearson_top200_hvg ▁
# wandb:                             test_pearson_top20_de ▁
# wandb:                             test_pearson_top50_de ▁
# wandb:                                           test_r2 ▁
# wandb:                                     test_spearman ▁
# wandb:                                    test_std_sigma ▁
# wandb:            test_unseen_single_fold_change_gap_all ▁
# wandb:    test_unseen_single_fold_change_gap_downreg_0.1
# wandb:   test_unseen_single_fold_change_gap_downreg_0.33 ▁
# wandb:       test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:        test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                  test_unseen_single_frac_in_range ▁
# wandb:            test_unseen_single_frac_in_range_25_75 ▁
# wandb:            test_unseen_single_frac_in_range_40_60 ▁
# wandb:            test_unseen_single_frac_in_range_45_55 ▁
# wandb:             test_unseen_single_frac_sigma_below_1 ▁
# wandb:             test_unseen_single_frac_sigma_below_2 ▁
# wandb:                            test_unseen_single_mae ▁
# wandb:                         test_unseen_single_mae_de ▁
# wandb:                     test_unseen_single_mean_sigma ▁
# wandb:                            test_unseen_single_mse ▁
# wandb:                         test_unseen_single_mse_de ▁
# wandb:                  test_unseen_single_mse_top100_de ▁
# wandb:                  test_unseen_single_mse_top200_de ▁
# wandb:                 test_unseen_single_mse_top200_hvg ▁
# wandb:                   test_unseen_single_mse_top20_de ▁
# wandb:                   test_unseen_single_mse_top50_de ▁
# wandb:                        test_unseen_single_pearson ▁
# wandb:                     test_unseen_single_pearson_de ▁
# wandb:                  test_unseen_single_pearson_delta ▁
# wandb:               test_unseen_single_pearson_delta_de ▁
# wandb:        test_unseen_single_pearson_delta_top100_de ▁
# wandb:        test_unseen_single_pearson_delta_top200_de ▁
# wandb:       test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:         test_unseen_single_pearson_delta_top20_de ▁
# wandb:         test_unseen_single_pearson_delta_top50_de ▁
# wandb:              test_unseen_single_pearson_top100_de ▁
# wandb:              test_unseen_single_pearson_top200_de ▁
# wandb:             test_unseen_single_pearson_top200_hvg ▁
# wandb:               test_unseen_single_pearson_top20_de ▁
# wandb:               test_unseen_single_pearson_top50_de ▁
# wandb:                             test_unseen_single_r2 ▁
# wandb:                          test_unseen_single_r2_de ▁
# wandb:                       test_unseen_single_spearman ▁
# wandb:                    test_unseen_single_spearman_de ▁
# wandb:                      test_unseen_single_std_sigma ▁
# wandb:                                      train_de_mae ▅▂▂█▄▁▁▁▁▁
# wandb:                                      train_de_mse ▄▂▁█▃▁▁▁▁▁
# wandb:                                  train_de_pearson ▅▁▇████▇██
# wandb:                                       train_de_r2 ▆██▁▇█████
# wandb:                                 train_de_spearman ▅▁▆██▇▇▇▇▇
# wandb:                                         train_mae ▁█▂▃▁▃▁▁▂▂
# wandb:                                         train_mse ▃█▂▆▂▂▁▁▁▁
# wandb:                                     train_pearson ▁▄▆▁▆▇███▇
# wandb:                                          train_r2 ▆▆▇▁▇▇████
# wandb:                                    train_spearman ▁▃▅▅▇▇████
# wandb:                                     training_loss ▃▅█▃▃▂▃▂▂▄▅▃▄▁▄▄▄▃▂▄▂▂▅▁▁▄▁▃▁▃▄▁▂▂▃▂▆▂▃▂
# wandb:                                        val_de_mae ▆▂▂█▄▁▁▁▁▁
# wandb:                                        val_de_mse ▅▂▂█▃▁▁▁▁▁
# wandb:                                    val_de_pearson ▅▁▅▇█▇▆▆▆▆
# wandb:                                         val_de_r2 ▅██▁▇█████
# wandb:                                   val_de_spearman ▆▁▆▆█▇▆▇▇▇
# wandb:                                           val_mae ▂█▂▃▁▃▁▁▂▂
# wandb:                                           val_mse ▃█▂▅▂▂▁▁▁▁
# wandb:                                       val_pearson ▁▃▆▂▇▇███▇
# wandb:                                            val_r2 ▆▆▇▁▇▇████
# wandb:                                      val_spearman ▁▃▅▅▇█████
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced no_gnn_uncertainty: https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016/runs/e1hq3fxk

# %%
# !python train.py --dataset Adamson2016 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3 \
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:2 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --no_gnn \
                 --exp_name no_gnn_no_pert_emb \
                 --wandb \
                 --no_pert_emb
# Out:
# ---- Printing Arguments ----
# dataset: Adamson2016
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:2
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: False
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: True
# no_pert_emb: True
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: no_gnn_no_pert_emb
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run no_gnn_no_pert_emb
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016/runs/3tydgazh
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211109_191503-3tydgazh
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_co-expression_100.0_64_2_l3_Adamson2016_gamma2_gene_emb_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 7054 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:22
# Creating dataloaders....
# Dataloaders created...
# Epoch 5 Step 1501 Train Loss: 0.0787
# Epoch 5 Step 1551 Train Loss: 0.1218
# Epoch 5 Step 1601 Train Loss: 0.1205
# Epoch 5 Step 1651 Train Loss: 0.1459
# Epoch 5: Train: 0.0273, R2 0.8880 Validation: 0.0273. R2 0.8874 Loss: 0.0839
# DE_Train: 0.1742, R2 0.8748 DE_Validation: 0.2178. R2 0.8560
# Epoch 6 Step 1 Train Loss: 0.0852
# Epoch 6 Step 51 Train Loss: 0.0806
# Epoch 6 Step 101 Train Loss: 0.0839
# Epoch 6 Step 151 Train Loss: 0.0742
# Epoch 6 Step 201 Train Loss: 0.0746
# Epoch 6 Step 251 Train Loss: 0.0898
# Epoch 6 Step 301 Train Loss: 0.0795
# Epoch 6 Step 351 Train Loss: 0.0835
# Epoch 6 Step 401 Train Loss: 0.0922
# Epoch 6 Step 451 Train Loss: 0.1058
# Epoch 6 Step 501 Train Loss: 0.0838
# Epoch 6 Step 551 Train Loss: 0.0950
# Epoch 6 Step 601 Train Loss: 0.1003
# Epoch 6 Step 651 Train Loss: 0.0915
# Epoch 6 Step 701 Train Loss: 0.0855
# Epoch 6 Step 751 Train Loss: 0.0575
# Epoch 6 Step 801 Train Loss: 0.0877
# Epoch 6 Step 851 Train Loss: 0.0891
# Epoch 6 Step 901 Train Loss: 0.0837
# Epoch 6 Step 951 Train Loss: 0.0942
# Epoch 6 Step 1001 Train Loss: 0.0612
# Epoch 6 Step 1051 Train Loss: 0.0699
# Epoch 6 Step 1101 Train Loss: 0.0729
# Epoch 6 Step 1151 Train Loss: 0.0910
# Epoch 6 Step 1201 Train Loss: 0.0782
# Epoch 6 Step 1251 Train Loss: 0.0741
# Epoch 6 Step 1301 Train Loss: 0.0837
# Epoch 6 Step 1351 Train Loss: 0.0717
# Epoch 6 Step 1401 Train Loss: 0.0801
# Epoch 6 Step 1451 Train Loss: 0.0961
# Epoch 6 Step 1501 Train Loss: 0.0818
# Epoch 6 Step 1551 Train Loss: 0.0860
# Epoch 6 Step 1601 Train Loss: 0.0619
# Epoch 6 Step 1651 Train Loss: 0.0841
# Epoch 6: Train: 0.0312, R2 0.8299 Validation: 0.0316. R2 0.8268 Loss: 0.0836
# DE_Train: 0.3183, R2 0.6517 DE_Validation: 0.4023. R2 0.6150
# Epoch 7 Step 1 Train Loss: 0.1087
# Epoch 7 Step 51 Train Loss: 0.0727
# Epoch 7 Step 101 Train Loss: 0.0669
# Epoch 7 Step 151 Train Loss: 0.0819
# Epoch 7 Step 201 Train Loss: 0.0667
# Epoch 7 Step 251 Train Loss: 0.1123
# Epoch 7 Step 301 Train Loss: 0.0730
# Epoch 7 Step 351 Train Loss: 0.0741
# Epoch 7 Step 401 Train Loss: 0.0875
# Epoch 7 Step 451 Train Loss: 0.0739
# Epoch 7 Step 501 Train Loss: 0.0943
# Epoch 7 Step 551 Train Loss: 0.0634
# Epoch 7 Step 601 Train Loss: 0.0734
# Epoch 7 Step 651 Train Loss: 0.0836
# Epoch 7 Step 701 Train Loss: 0.0906
# Epoch 7 Step 751 Train Loss: 0.0878
# Epoch 7 Step 801 Train Loss: 0.0688
# Epoch 7 Step 851 Train Loss: 0.0888
# Epoch 7 Step 901 Train Loss: 0.0814
# Epoch 7 Step 951 Train Loss: 0.0912
# Epoch 7 Step 1001 Train Loss: 0.0884
# Epoch 7 Step 1051 Train Loss: 0.0812
# Epoch 7 Step 1101 Train Loss: 0.0719
# Epoch 7 Step 1151 Train Loss: 0.0792
# Epoch 7 Step 1201 Train Loss: 0.0719
# Epoch 7 Step 1251 Train Loss: 0.0607
# Epoch 7 Step 1301 Train Loss: 0.0796
# Epoch 7 Step 1351 Train Loss: 0.0962
# Epoch 7 Step 1401 Train Loss: 0.1019
# Epoch 7 Step 1451 Train Loss: 0.0713
# Epoch 7 Step 1501 Train Loss: 0.1205
# Epoch 7 Step 1551 Train Loss: 0.0667
# Epoch 7 Step 1601 Train Loss: 0.0751
# Epoch 7 Step 1651 Train Loss: 0.1227
# Epoch 7: Train: 0.0320, R2 0.8158 Validation: 0.0323. R2 0.8138 Loss: 0.0839
# DE_Train: 0.3751, R2 0.5543 DE_Validation: 0.4567. R2 0.5194
# Epoch 8 Step 1 Train Loss: 0.0698
# Epoch 8 Step 51 Train Loss: 0.1300
# Epoch 8 Step 101 Train Loss: 0.0751
# Epoch 8 Step 151 Train Loss: 0.0766
# Epoch 8 Step 201 Train Loss: 0.0814
# Epoch 8 Step 251 Train Loss: 0.0807
# Epoch 8 Step 301 Train Loss: 0.0746
# Epoch 8 Step 351 Train Loss: 0.0777
# Epoch 8 Step 401 Train Loss: 0.0635
# Epoch 8 Step 451 Train Loss: 0.0705
# Epoch 8 Step 501 Train Loss: 0.0735
# Epoch 8 Step 551 Train Loss: 0.1108
# Epoch 8 Step 601 Train Loss: 0.0844
# Epoch 8 Step 651 Train Loss: 0.0893
# Epoch 8 Step 701 Train Loss: 0.0838
# Epoch 8 Step 751 Train Loss: 0.1028
# Epoch 8 Step 801 Train Loss: 0.1038
# Epoch 8 Step 851 Train Loss: 0.0607
# Epoch 8 Step 901 Train Loss: 0.0727
# Epoch 8 Step 951 Train Loss: 0.0831
# Epoch 8 Step 1001 Train Loss: 0.1020
# Epoch 8 Step 1051 Train Loss: 0.0924
# Epoch 8 Step 1101 Train Loss: 0.0774
# Epoch 8 Step 1151 Train Loss: 0.1035
# Epoch 8 Step 1201 Train Loss: 0.0597
# Epoch 8 Step 1251 Train Loss: 0.0751
# Epoch 8 Step 1301 Train Loss: 0.1003
# Epoch 8 Step 1351 Train Loss: 0.0787
# Epoch 8 Step 1401 Train Loss: 0.1026
# Epoch 8 Step 1451 Train Loss: 0.0994
# Epoch 8 Step 1501 Train Loss: 0.1623
# Epoch 8 Step 1551 Train Loss: 0.0833
# Epoch 8 Step 1601 Train Loss: 0.0701
# Epoch 8 Step 1651 Train Loss: 0.0692
# Epoch 8: Train: 0.0256, R2 0.8882 Validation: 0.0257. R2 0.8871 Loss: 0.0838
# DE_Train: 0.1663, R2 0.8724 DE_Validation: 0.2303. R2 0.8350
# Epoch 10 Step 1151 Train Loss: 0.0885
# Epoch 10 Step 1201 Train Loss: 0.0830
# Epoch 10 Step 1251 Train Loss: 0.0795
# Epoch 10 Step 1301 Train Loss: 0.0828
# Epoch 10 Step 1351 Train Loss: 0.1009
# Epoch 10 Step 1401 Train Loss: 0.0802
# Epoch 10 Step 1451 Train Loss: 0.0753
# Epoch 10 Step 1501 Train Loss: 0.0688
# Epoch 10 Step 1551 Train Loss: 0.0654
# Epoch 10 Step 1601 Train Loss: 0.0926
# Epoch 10 Step 1651 Train Loss: 0.0747
# Epoch 10: Train: 0.0247, R2 0.8927 Validation: 0.0247. R2 0.8921 Loss: 0.0837
# DE_Train: 0.1620, R2 0.8755 DE_Validation: 0.2233. R2 0.8396
# Saving model....
# Start testing....
# Final best performing model: Test_DE: 0.1694, R2 0.8945
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# test_combo_seen0_mse: nan
# test_combo_seen0_mae: nan
# test_combo_seen0_spearman: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_r2: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_mae_de: nan
# test_combo_seen0_spearman_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen0_r2_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_mae: nan
# test_combo_seen1_spearman: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_r2: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_mae_de: nan
# test_combo_seen1_spearman_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen1_r2_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_mae: nan
# test_combo_seen2_spearman: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_r2: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_mae_de: nan
# test_combo_seen2_spearman_de: nan
# test_combo_seen2_pearson_de: nan
# test_combo_seen2_r2_de: nan
# test_unseen_single_mse: 0.027680589
# test_unseen_single_mae: 0.14941394
# test_unseen_single_spearman: 0.971127798475645
# test_unseen_single_pearson: 0.9844900465017363
# test_unseen_single_r2: 0.8877356918341696
# test_unseen_single_mse_de: 0.1694245
# test_unseen_single_mae_de: 0.3062528
# test_unseen_single_spearman_de: 0.9563655028613712
# test_unseen_single_pearson_de: 0.9654265352105191
# test_unseen_single_r2_de: 0.8944780683476079
# test_combo_seen0_frac_in_range: nan
# test_combo_seen0_frac_in_range_45_55: nan
# test_combo_seen0_frac_in_range_40_60: nan
# test_combo_seen0_frac_in_range_25_75: nan
# test_combo_seen0_mean_sigma: nan
# test_combo_seen0_std_sigma: nan
# test_combo_seen0_frac_sigma_below_1: nan
# test_combo_seen0_frac_sigma_below_2: nan
# test_combo_seen0_pearson_delta: nan
# test_combo_seen0_pearson_delta_de: nan
# test_combo_seen0_fold_change_gap_all: nan
# test_combo_seen0_pearson_delta_top200_hvg: nan
# test_combo_seen0_fold_change_gap_upreg_3: nan
# test_combo_seen0_fold_change_gap_downreg_0.33: nan
# test_combo_seen0_fold_change_gap_downreg_0.1: nan
# test_combo_seen0_fold_change_gap_upreg_10: nan
# test_combo_seen0_pearson_top200_hvg: nan
# test_combo_seen0_pearson_top200_de: nan
# test_combo_seen0_pearson_top20_de: nan
# test_combo_seen0_pearson_delta_top200_de: nan
# test_combo_seen0_pearson_top100_de: nan
# test_combo_seen0_pearson_delta_top100_de: nan
# test_combo_seen0_pearson_delta_top50_de: nan
# test_combo_seen0_pearson_top50_de: nan
# test_combo_seen0_pearson_delta_top20_de: nan
# test_combo_seen0_mse_top200_hvg: nan
# test_combo_seen0_mse_top100_de: nan
# test_combo_seen0_mse_top200_de: nan
# test_combo_seen0_mse_top50_de: nan
# test_combo_seen0_mse_top20_de: nan
# test_combo_seen1_frac_in_range: nan
# test_combo_seen1_frac_in_range_45_55: nan
# test_combo_seen1_frac_in_range_40_60: nan
# test_combo_seen1_frac_in_range_25_75: nan
# test_combo_seen1_mean_sigma: nan
# test_combo_seen1_std_sigma: nan
# test_combo_seen1_frac_sigma_below_1: nan
# test_combo_seen1_frac_sigma_below_2: nan
# test_combo_seen1_pearson_delta: nan
# test_combo_seen1_pearson_delta_de: nan
# test_combo_seen1_fold_change_gap_all: nan
# test_combo_seen1_pearson_delta_top200_hvg: nan
# test_combo_seen1_fold_change_gap_upreg_3: nan
# test_combo_seen1_fold_change_gap_downreg_0.33: nan
# test_combo_seen1_fold_change_gap_downreg_0.1: nan
# test_combo_seen1_fold_change_gap_upreg_10: nan
# test_combo_seen1_pearson_top200_hvg: nan
# test_combo_seen1_pearson_top200_de: nan
# test_combo_seen1_pearson_top20_de: nan
# test_combo_seen1_pearson_delta_top200_de: nan
# test_combo_seen1_pearson_top100_de: nan
# test_combo_seen1_pearson_delta_top100_de: nan
# test_combo_seen1_pearson_delta_top50_de: nan
# test_combo_seen1_pearson_top50_de: nan
# test_combo_seen1_pearson_delta_top20_de: nan
# test_combo_seen1_mse_top200_hvg: nan
# test_combo_seen1_mse_top100_de: nan
# test_combo_seen1_mse_top200_de: nan
# test_combo_seen1_mse_top50_de: nan
# test_combo_seen1_mse_top20_de: nan
# test_combo_seen2_frac_in_range: nan
# test_combo_seen2_frac_in_range_45_55: nan
# test_combo_seen2_frac_in_range_40_60: nan
# test_combo_seen2_frac_in_range_25_75: nan
# test_combo_seen2_mean_sigma: nan
# test_combo_seen2_std_sigma: nan
# test_combo_seen2_frac_sigma_below_1: nan
# test_combo_seen2_frac_sigma_below_2: nan
# test_combo_seen2_pearson_delta: nan
# test_combo_seen2_pearson_delta_de: nan
# test_combo_seen2_fold_change_gap_all: nan
# test_combo_seen2_pearson_delta_top200_hvg: nan
# test_combo_seen2_fold_change_gap_upreg_3: nan
# test_combo_seen2_fold_change_gap_downreg_0.33: nan
# test_combo_seen2_fold_change_gap_downreg_0.1: nan
# test_combo_seen2_fold_change_gap_upreg_10: nan
# test_combo_seen2_pearson_top200_hvg: nan
# test_combo_seen2_pearson_top200_de: nan
# test_combo_seen2_pearson_top20_de: nan
# test_combo_seen2_pearson_delta_top200_de: nan
# test_combo_seen2_pearson_top100_de: nan
# test_combo_seen2_pearson_delta_top100_de: nan
# test_combo_seen2_pearson_delta_top50_de: nan
# test_combo_seen2_pearson_top50_de: nan
# test_combo_seen2_pearson_delta_top20_de: nan
# test_combo_seen2_mse_top200_hvg: nan
# test_combo_seen2_mse_top100_de: nan
# test_combo_seen2_mse_top200_de: nan
# test_combo_seen2_mse_top50_de: nan
# test_combo_seen2_mse_top20_de: nan
# test_unseen_single_frac_in_range: 0.984090909090909
# test_unseen_single_frac_in_range_45_55: 0.0882177033492823
# test_unseen_single_frac_in_range_40_60: 0.181549043062201
# test_unseen_single_frac_in_range_25_75: 0.44808612440191387
# test_unseen_single_mean_sigma: 0.9742356
# test_unseen_single_std_sigma: 0.7522259
# test_unseen_single_frac_sigma_below_1: 0.6968301435406699
# test_unseen_single_frac_sigma_below_2: 0.8948564593301435
# test_unseen_single_pearson_delta: 0.45556333086718054
# test_unseen_single_pearson_delta_de: 0.7005581669516412
# test_unseen_single_fold_change_gap_all: 0.11906921
# test_unseen_single_pearson_delta_top200_hvg: 0.5933318911191651
# test_unseen_single_fold_change_gap_upreg_3: 0.71991444
# test_unseen_single_fold_change_gap_downreg_0.33: 0.659301
# test_unseen_single_fold_change_gap_downreg_0.1: nan
# test_unseen_single_fold_change_gap_upreg_10: 2.0133934
# test_unseen_single_pearson_top200_hvg: 0.9647436062753324
# test_unseen_single_pearson_top200_de: 0.9828747680475348
# test_unseen_single_pearson_top20_de: 0.9654265352105191
# test_unseen_single_pearson_delta_top200_de: 0.6950881040437528
# test_unseen_single_pearson_top100_de: 0.9802085367970332
# test_unseen_single_pearson_delta_top100_de: 0.7124774538126667
# test_unseen_single_pearson_delta_top50_de: 0.7137746938618723
# test_unseen_single_pearson_top50_de: 0.9754466693928779
# test_unseen_single_pearson_delta_top20_de: 0.7005581669516412
# test_unseen_single_mse_top200_hvg: 0.06616245
# test_unseen_single_mse_top100_de: 0.08420767
# test_unseen_single_mse_top200_de: 0.059186794
# test_unseen_single_mse_top50_de: 0.120259784
# test_unseen_single_mse_top20_de: 0.16942449
# Done!
#
# wandb: Waiting for W&B process to finish, PID 51535
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211109_191503-3tydgazh/logs/debug.log
# wandb: Find internal logs for this run at: /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211109_191503-3tydgazh/logs/debug-internal.log
# wandb: Run summary:
# wandb:              test_combo_seen0_fold_change_gap_all nan
# wandb:      test_combo_seen0_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen0_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen0_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen0_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen0_frac_in_range nan
# wandb:              test_combo_seen0_frac_in_range_25_75 nan
# wandb:              test_combo_seen0_frac_in_range_40_60 nan
# wandb:              test_combo_seen0_frac_in_range_45_55 nan
# wandb:               test_combo_seen0_frac_sigma_below_1 nan
# wandb:               test_combo_seen0_frac_sigma_below_2 nan
# wandb:                              test_combo_seen0_mae nan
# wandb:                           test_combo_seen0_mae_de nan
# wandb:                       test_combo_seen0_mean_sigma nan
# wandb:                              test_combo_seen0_mse nan
# wandb:                           test_combo_seen0_mse_de nan
# wandb:                    test_combo_seen0_mse_top100_de nan
# wandb:                    test_combo_seen0_mse_top200_de nan
# wandb:                   test_combo_seen0_mse_top200_hvg nan
# wandb:                     test_combo_seen0_mse_top20_de nan
# wandb:                     test_combo_seen0_mse_top50_de nan
# wandb:                          test_combo_seen0_pearson nan
# wandb:                       test_combo_seen0_pearson_de nan
# wandb:                    test_combo_seen0_pearson_delta nan
# wandb:                 test_combo_seen0_pearson_delta_de nan
# wandb:          test_combo_seen0_pearson_delta_top100_de nan
# wandb:          test_combo_seen0_pearson_delta_top200_de nan
# wandb:         test_combo_seen0_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen0_pearson_delta_top20_de nan
# wandb:           test_combo_seen0_pearson_delta_top50_de nan
# wandb:                test_combo_seen0_pearson_top100_de nan
# wandb:                test_combo_seen0_pearson_top200_de nan
# wandb:               test_combo_seen0_pearson_top200_hvg nan
# wandb:                 test_combo_seen0_pearson_top20_de nan
# wandb:                 test_combo_seen0_pearson_top50_de nan
# wandb:                               test_combo_seen0_r2 nan
# wandb:                            test_combo_seen0_r2_de nan
# wandb:                         test_combo_seen0_spearman nan
# wandb:                      test_combo_seen0_spearman_de nan
# wandb:                        test_combo_seen0_std_sigma nan
# wandb:              test_combo_seen1_fold_change_gap_all nan
# wandb:      test_combo_seen1_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen1_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen1_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen1_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen1_frac_in_range nan
# wandb:              test_combo_seen1_frac_in_range_25_75 nan
# wandb:              test_combo_seen1_frac_in_range_40_60 nan
# wandb:              test_combo_seen1_frac_in_range_45_55 nan
# wandb:               test_combo_seen1_frac_sigma_below_1 nan
# wandb:               test_combo_seen1_frac_sigma_below_2 nan
# wandb:                              test_combo_seen1_mae nan
# wandb:                           test_combo_seen1_mae_de nan
# wandb:                       test_combo_seen1_mean_sigma nan
# wandb:                              test_combo_seen1_mse nan
# wandb:                           test_combo_seen1_mse_de nan
# wandb:                    test_combo_seen1_mse_top100_de nan
# wandb:                    test_combo_seen1_mse_top200_de nan
# wandb:                   test_combo_seen1_mse_top200_hvg nan
# wandb:                     test_combo_seen1_mse_top20_de nan
# wandb:                     test_combo_seen1_mse_top50_de nan
# wandb:                          test_combo_seen1_pearson nan
# wandb:                       test_combo_seen1_pearson_de nan
# wandb:                    test_combo_seen1_pearson_delta nan
# wandb:                 test_combo_seen1_pearson_delta_de nan
# wandb:          test_combo_seen1_pearson_delta_top100_de nan
# wandb:          test_combo_seen1_pearson_delta_top200_de nan
# wandb:         test_combo_seen1_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen1_pearson_delta_top20_de nan
# wandb:           test_combo_seen1_pearson_delta_top50_de nan
# wandb:                test_combo_seen1_pearson_top100_de nan
# wandb:                test_combo_seen1_pearson_top200_de nan
# wandb:               test_combo_seen1_pearson_top200_hvg nan
# wandb:                 test_combo_seen1_pearson_top20_de nan
# wandb:                 test_combo_seen1_pearson_top50_de nan
# wandb:                               test_combo_seen1_r2 nan
# wandb:                            test_combo_seen1_r2_de nan
# wandb:                         test_combo_seen1_spearman nan
# wandb:                      test_combo_seen1_spearman_de nan
# wandb:                        test_combo_seen1_std_sigma nan
# wandb:              test_combo_seen2_fold_change_gap_all nan
# wandb:      test_combo_seen2_fold_change_gap_downreg_0.1 nan
# wandb:     test_combo_seen2_fold_change_gap_downreg_0.33 nan
# wandb:         test_combo_seen2_fold_change_gap_upreg_10 nan
# wandb:          test_combo_seen2_fold_change_gap_upreg_3 nan
# wandb:                    test_combo_seen2_frac_in_range nan
# wandb:              test_combo_seen2_frac_in_range_25_75 nan
# wandb:              test_combo_seen2_frac_in_range_40_60 nan
# wandb:              test_combo_seen2_frac_in_range_45_55 nan
# wandb:               test_combo_seen2_frac_sigma_below_1 nan
# wandb:               test_combo_seen2_frac_sigma_below_2 nan
# wandb:                              test_combo_seen2_mae nan
# wandb:                           test_combo_seen2_mae_de nan
# wandb:                       test_combo_seen2_mean_sigma nan
# wandb:                              test_combo_seen2_mse nan
# wandb:                           test_combo_seen2_mse_de nan
# wandb:                    test_combo_seen2_mse_top100_de nan
# wandb:                    test_combo_seen2_mse_top200_de nan
# wandb:                   test_combo_seen2_mse_top200_hvg nan
# wandb:                     test_combo_seen2_mse_top20_de nan
# wandb:                     test_combo_seen2_mse_top50_de nan
# wandb:                          test_combo_seen2_pearson nan
# wandb:                       test_combo_seen2_pearson_de nan
# wandb:                    test_combo_seen2_pearson_delta nan
# wandb:                 test_combo_seen2_pearson_delta_de nan
# wandb:          test_combo_seen2_pearson_delta_top100_de nan
# wandb:          test_combo_seen2_pearson_delta_top200_de nan
# wandb:         test_combo_seen2_pearson_delta_top200_hvg nan
# wandb:           test_combo_seen2_pearson_delta_top20_de nan
# wandb:           test_combo_seen2_pearson_delta_top50_de nan
# wandb:                test_combo_seen2_pearson_top100_de nan
# wandb:                test_combo_seen2_pearson_top200_de nan
# wandb:               test_combo_seen2_pearson_top200_hvg nan
# wandb:                 test_combo_seen2_pearson_top20_de nan
# wandb:                 test_combo_seen2_pearson_top50_de nan
# wandb:                               test_combo_seen2_r2 nan
# wandb:                            test_combo_seen2_r2_de nan
# wandb:                         test_combo_seen2_spearman nan
# wandb:                      test_combo_seen2_spearman_de nan
# wandb:                        test_combo_seen2_std_sigma nan
# wandb:                                       test_de_mae 0.30625
# wandb:                                       test_de_mse 0.16942
# wandb:                                   test_de_pearson 0.96543
# wandb:                                        test_de_r2 0.89448
# wandb:                                  test_de_spearman 0.95637
# wandb:                          test_fold_change_gap_all 0.11907
# wandb:                  test_fold_change_gap_downreg_0.1 nan
# wandb:                 test_fold_change_gap_downreg_0.33 0.6593
# wandb:                     test_fold_change_gap_upreg_10 2.01339
# wandb:                      test_fold_change_gap_upreg_3 0.71991
# wandb:                                test_frac_in_range 0.98409
# wandb:                          test_frac_in_range_25_75 0.44809
# wandb:                          test_frac_in_range_40_60 0.18155
# wandb:                          test_frac_in_range_45_55 0.08822
# wandb:                           test_frac_sigma_below_1 0.69683
# wandb:                           test_frac_sigma_below_2 0.89486
# wandb:                                          test_mae 0.14941
# wandb:                                   test_mean_sigma 0.97424
# wandb:                                          test_mse 0.02768
# wandb:                                test_mse_top100_de 0.08421
# wandb:                                test_mse_top200_de 0.05919
# wandb:                               test_mse_top200_hvg 0.06616
# wandb:                                 test_mse_top20_de 0.16942
# wandb:                                 test_mse_top50_de 0.12026
# wandb:                                      test_pearson 0.98449
# wandb:                                test_pearson_delta 0.45556
# wandb:                             test_pearson_delta_de 0.70056
# wandb:                      test_pearson_delta_top100_de 0.71248
# wandb:                      test_pearson_delta_top200_de 0.69509
# wandb:                     test_pearson_delta_top200_hvg 0.59333
# wandb:                       test_pearson_delta_top20_de 0.70056
# wandb:                       test_pearson_delta_top50_de 0.71377
# wandb:                            test_pearson_top100_de 0.98021
# wandb:                            test_pearson_top200_de 0.98287
# wandb:                           test_pearson_top200_hvg 0.96474
# wandb:                             test_pearson_top20_de 0.96543
# wandb:                             test_pearson_top50_de 0.97545
# wandb:                                           test_r2 0.88774
# wandb:                                     test_spearman 0.97113
# wandb:                                    test_std_sigma 0.75223
# wandb:            test_unseen_single_fold_change_gap_all 0.11907
# wandb:    test_unseen_single_fold_change_gap_downreg_0.1 nan
# wandb:   test_unseen_single_fold_change_gap_downreg_0.33 0.6593
# wandb:       test_unseen_single_fold_change_gap_upreg_10 2.01339
# wandb:        test_unseen_single_fold_change_gap_upreg_3 0.71991
# wandb:                  test_unseen_single_frac_in_range 0.98409
# wandb:            test_unseen_single_frac_in_range_25_75 0.44809
# wandb:            test_unseen_single_frac_in_range_40_60 0.18155
# wandb:            test_unseen_single_frac_in_range_45_55 0.08822
# wandb:             test_unseen_single_frac_sigma_below_1 0.69683
# wandb:             test_unseen_single_frac_sigma_below_2 0.89486
# wandb:                            test_unseen_single_mae 0.14941
# wandb:                         test_unseen_single_mae_de 0.30625
# wandb:                     test_unseen_single_mean_sigma 0.97424
# wandb:                            test_unseen_single_mse 0.02768
# wandb:                         test_unseen_single_mse_de 0.16942
# wandb:                  test_unseen_single_mse_top100_de 0.08421
# wandb:                  test_unseen_single_mse_top200_de 0.05919
# wandb:                 test_unseen_single_mse_top200_hvg 0.06616
# wandb:                   test_unseen_single_mse_top20_de 0.16942
# wandb:                   test_unseen_single_mse_top50_de 0.12026
# wandb:                        test_unseen_single_pearson 0.98449
# wandb:                     test_unseen_single_pearson_de 0.96543
# wandb:                  test_unseen_single_pearson_delta 0.45556
# wandb:               test_unseen_single_pearson_delta_de 0.70056
# wandb:        test_unseen_single_pearson_delta_top100_de 0.71248
# wandb:        test_unseen_single_pearson_delta_top200_de 0.69509
# wandb:       test_unseen_single_pearson_delta_top200_hvg 0.59333
# wandb:         test_unseen_single_pearson_delta_top20_de 0.70056
# wandb:         test_unseen_single_pearson_delta_top50_de 0.71377
# wandb:              test_unseen_single_pearson_top100_de 0.98021
# wandb:              test_unseen_single_pearson_top200_de 0.98287
# wandb:             test_unseen_single_pearson_top200_hvg 0.96474
# wandb:               test_unseen_single_pearson_top20_de 0.96543
# wandb:               test_unseen_single_pearson_top50_de 0.97545
# wandb:                             test_unseen_single_r2 0.88774
# wandb:                          test_unseen_single_r2_de 0.89448
# wandb:                       test_unseen_single_spearman 0.97113
# wandb:                    test_unseen_single_spearman_de 0.95637
# wandb:                      test_unseen_single_std_sigma 0.75223
# wandb:                                      train_de_mae 0.27654
# wandb:                                      train_de_mse 0.16198
# wandb:                                  train_de_pearson 0.95269
# wandb:                                       train_de_r2 0.87552
# wandb:                                 train_de_spearman 0.93308
# wandb:                                         train_mae 0.13984
# wandb:                                         train_mse 0.02472
# wandb:                                     train_pearson 0.98477
# wandb:                                          train_r2 0.89272
# wandb:                                    train_spearman 0.97828
# wandb:                                     training_loss 0.07644
# wandb:                                        val_de_mae 0.35512
# wandb:                                        val_de_mse 0.22329
# wandb:                                    val_de_pearson 0.94555
# wandb:                                         val_de_r2 0.83964
# wandb:                                   val_de_spearman 0.92159
# wandb:                                           val_mae 0.1409
# wandb:                                           val_mse 0.02473
# wandb:                                       val_pearson 0.98497
# wandb:                                            val_r2 0.89212
# wandb:                                      val_spearman 0.97618
# wandb: Run history:
# wandb:              test_combo_seen0_fold_change_gap_all
# wandb:      test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen0_fold_change_gap_upreg_10
# wandb:          test_combo_seen0_fold_change_gap_upreg_3
# wandb:                    test_combo_seen0_frac_in_range
# wandb:              test_combo_seen0_frac_in_range_25_75
# wandb:              test_combo_seen0_frac_in_range_40_60
# wandb:              test_combo_seen0_frac_in_range_45_55
# wandb:               test_combo_seen0_frac_sigma_below_1
# wandb:               test_combo_seen0_frac_sigma_below_2
# wandb:                              test_combo_seen0_mae
# wandb:                           test_combo_seen0_mae_de
# wandb:                       test_combo_seen0_mean_sigma
# wandb:                              test_combo_seen0_mse
# wandb:                           test_combo_seen0_mse_de
# wandb:                    test_combo_seen0_mse_top100_de
# wandb:                    test_combo_seen0_mse_top200_de
# wandb:                   test_combo_seen0_mse_top200_hvg
# wandb:                     test_combo_seen0_mse_top20_de
# wandb:                     test_combo_seen0_mse_top50_de
# wandb:                          test_combo_seen0_pearson
# wandb:                       test_combo_seen0_pearson_de
# wandb:                    test_combo_seen0_pearson_delta
# wandb:                 test_combo_seen0_pearson_delta_de
# wandb:          test_combo_seen0_pearson_delta_top100_de
# wandb:          test_combo_seen0_pearson_delta_top200_de
# wandb:         test_combo_seen0_pearson_delta_top200_hvg
# wandb:           test_combo_seen0_pearson_delta_top20_de
# wandb:           test_combo_seen0_pearson_delta_top50_de
# wandb:                test_combo_seen0_pearson_top100_de
# wandb:                test_combo_seen0_pearson_top200_de
# wandb:               test_combo_seen0_pearson_top200_hvg
# wandb:                 test_combo_seen0_pearson_top20_de
# wandb:                 test_combo_seen0_pearson_top50_de
# wandb:                               test_combo_seen0_r2
# wandb:                            test_combo_seen0_r2_de
# wandb:                         test_combo_seen0_spearman
# wandb:                      test_combo_seen0_spearman_de
# wandb:                        test_combo_seen0_std_sigma
# wandb:              test_combo_seen1_fold_change_gap_all
# wandb:      test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen1_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen1_fold_change_gap_upreg_10
# wandb:          test_combo_seen1_fold_change_gap_upreg_3
# wandb:                    test_combo_seen1_frac_in_range
# wandb:              test_combo_seen1_frac_in_range_25_75
# wandb:              test_combo_seen1_frac_in_range_40_60
# wandb:              test_combo_seen1_frac_in_range_45_55
# wandb:               test_combo_seen1_frac_sigma_below_1
# wandb:               test_combo_seen1_frac_sigma_below_2
# wandb:                              test_combo_seen1_mae
# wandb:                           test_combo_seen1_mae_de
# wandb:                       test_combo_seen1_mean_sigma
# wandb:                              test_combo_seen1_mse
# wandb:                           test_combo_seen1_mse_de
# wandb:                    test_combo_seen1_mse_top100_de
# wandb:                    test_combo_seen1_mse_top200_de
# wandb:                   test_combo_seen1_mse_top200_hvg
# wandb:                     test_combo_seen1_mse_top20_de
# wandb:                     test_combo_seen1_mse_top50_de
# wandb:                          test_combo_seen1_pearson
# wandb:                       test_combo_seen1_pearson_de
# wandb:                    test_combo_seen1_pearson_delta
# wandb:                 test_combo_seen1_pearson_delta_de
# wandb:          test_combo_seen1_pearson_delta_top100_de
# wandb:          test_combo_seen1_pearson_delta_top200_de
# wandb:         test_combo_seen1_pearson_delta_top200_hvg
# wandb:           test_combo_seen1_pearson_delta_top20_de
# wandb:           test_combo_seen1_pearson_delta_top50_de
# wandb:                test_combo_seen1_pearson_top100_de
# wandb:                test_combo_seen1_pearson_top200_de
# wandb:               test_combo_seen1_pearson_top200_hvg
# wandb:                 test_combo_seen1_pearson_top20_de
# wandb:                 test_combo_seen1_pearson_top50_de
# wandb:                               test_combo_seen1_r2
# wandb:                            test_combo_seen1_r2_de
# wandb:                         test_combo_seen1_spearman
# wandb:                      test_combo_seen1_spearman_de
# wandb:                        test_combo_seen1_std_sigma
# wandb:              test_combo_seen2_fold_change_gap_all
# wandb:      test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:     test_combo_seen2_fold_change_gap_downreg_0.33
# wandb:         test_combo_seen2_fold_change_gap_upreg_10
# wandb:          test_combo_seen2_fold_change_gap_upreg_3
# wandb:                    test_combo_seen2_frac_in_range
# wandb:              test_combo_seen2_frac_in_range_25_75
# wandb:              test_combo_seen2_frac_in_range_40_60
# wandb:              test_combo_seen2_frac_in_range_45_55
# wandb:               test_combo_seen2_frac_sigma_below_1
# wandb:               test_combo_seen2_frac_sigma_below_2
# wandb:                              test_combo_seen2_mae
# wandb:                           test_combo_seen2_mae_de
# wandb:                       test_combo_seen2_mean_sigma
# wandb:                              test_combo_seen2_mse
# wandb:                           test_combo_seen2_mse_de
# wandb:                    test_combo_seen2_mse_top100_de
# wandb:                    test_combo_seen2_mse_top200_de
# wandb:                   test_combo_seen2_mse_top200_hvg
# wandb:                     test_combo_seen2_mse_top20_de
# wandb:                     test_combo_seen2_mse_top50_de
# wandb:                          test_combo_seen2_pearson
# wandb:                       test_combo_seen2_pearson_de
# wandb:                    test_combo_seen2_pearson_delta
# wandb:                 test_combo_seen2_pearson_delta_de
# wandb:          test_combo_seen2_pearson_delta_top100_de
# wandb:          test_combo_seen2_pearson_delta_top200_de
# wandb:         test_combo_seen2_pearson_delta_top200_hvg
# wandb:           test_combo_seen2_pearson_delta_top20_de
# wandb:           test_combo_seen2_pearson_delta_top50_de
# wandb:                test_combo_seen2_pearson_top100_de
# wandb:                test_combo_seen2_pearson_top200_de
# wandb:               test_combo_seen2_pearson_top200_hvg
# wandb:                 test_combo_seen2_pearson_top20_de
# wandb:                 test_combo_seen2_pearson_top50_de
# wandb:                               test_combo_seen2_r2
# wandb:                            test_combo_seen2_r2_de
# wandb:                         test_combo_seen2_spearman
# wandb:                      test_combo_seen2_spearman_de
# wandb:                        test_combo_seen2_std_sigma
# wandb:                                       test_de_mae ▁
# wandb:                                       test_de_mse ▁
# wandb:                                   test_de_pearson ▁
# wandb:                                        test_de_r2 ▁
# wandb:                                  test_de_spearman ▁
# wandb:                          test_fold_change_gap_all ▁
# wandb:                  test_fold_change_gap_downreg_0.1
# wandb:                 test_fold_change_gap_downreg_0.33 ▁
# wandb:                     test_fold_change_gap_upreg_10 ▁
# wandb:                      test_fold_change_gap_upreg_3 ▁
# wandb:                                test_frac_in_range ▁
# wandb:                          test_frac_in_range_25_75 ▁
# wandb:                          test_frac_in_range_40_60 ▁
# wandb:                          test_frac_in_range_45_55 ▁
# wandb:                           test_frac_sigma_below_1 ▁
# wandb:                           test_frac_sigma_below_2 ▁
# wandb:                                          test_mae ▁
# wandb:                                   test_mean_sigma ▁
# wandb:                                          test_mse ▁
# wandb:                                test_mse_top100_de ▁
# wandb:                                test_mse_top200_de ▁
# wandb:                               test_mse_top200_hvg ▁
# wandb:                                 test_mse_top20_de ▁
# wandb:                                 test_mse_top50_de ▁
# wandb:                                      test_pearson ▁
# wandb:                                test_pearson_delta ▁
# wandb:                             test_pearson_delta_de ▁
# wandb:                      test_pearson_delta_top100_de ▁
# wandb:                      test_pearson_delta_top200_de ▁
# wandb:                     test_pearson_delta_top200_hvg ▁
# wandb:                       test_pearson_delta_top20_de ▁
# wandb:                       test_pearson_delta_top50_de ▁
# wandb:                            test_pearson_top100_de ▁
# wandb:                            test_pearson_top200_de ▁
# wandb:                           test_pearson_top200_hvg ▁
# wandb:                             test_pearson_top20_de ▁
# wandb:                             test_pearson_top50_de ▁
# wandb:                                           test_r2 ▁
# wandb:                                     test_spearman ▁
# wandb:                                    test_std_sigma ▁
# wandb:            test_unseen_single_fold_change_gap_all ▁
# wandb:    test_unseen_single_fold_change_gap_downreg_0.1
# wandb:   test_unseen_single_fold_change_gap_downreg_0.33 ▁
# wandb:       test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:        test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                  test_unseen_single_frac_in_range ▁
# wandb:            test_unseen_single_frac_in_range_25_75 ▁
# wandb:            test_unseen_single_frac_in_range_40_60 ▁
# wandb:            test_unseen_single_frac_in_range_45_55 ▁
# wandb:             test_unseen_single_frac_sigma_below_1 ▁
# wandb:             test_unseen_single_frac_sigma_below_2 ▁
# wandb:                            test_unseen_single_mae ▁
# wandb:                         test_unseen_single_mae_de ▁
# wandb:                     test_unseen_single_mean_sigma ▁
# wandb:                            test_unseen_single_mse ▁
# wandb:                         test_unseen_single_mse_de ▁
# wandb:                  test_unseen_single_mse_top100_de ▁
# wandb:                  test_unseen_single_mse_top200_de ▁
# wandb:                 test_unseen_single_mse_top200_hvg ▁
# wandb:                   test_unseen_single_mse_top20_de ▁
# wandb:                   test_unseen_single_mse_top50_de ▁
# wandb:                        test_unseen_single_pearson ▁
# wandb:                     test_unseen_single_pearson_de ▁
# wandb:                  test_unseen_single_pearson_delta ▁
# wandb:               test_unseen_single_pearson_delta_de ▁
# wandb:        test_unseen_single_pearson_delta_top100_de ▁
# wandb:        test_unseen_single_pearson_delta_top200_de ▁
# wandb:       test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:         test_unseen_single_pearson_delta_top20_de ▁
# wandb:         test_unseen_single_pearson_delta_top50_de ▁
# wandb:              test_unseen_single_pearson_top100_de ▁
# wandb:              test_unseen_single_pearson_top200_de ▁
# wandb:             test_unseen_single_pearson_top200_hvg ▁
# wandb:               test_unseen_single_pearson_top20_de ▁
# wandb:               test_unseen_single_pearson_top50_de ▁
# wandb:                             test_unseen_single_r2 ▁
# wandb:                          test_unseen_single_r2_de ▁
# wandb:                       test_unseen_single_spearman ▁
# wandb:                    test_unseen_single_spearman_de ▁
# wandb:                      test_unseen_single_std_sigma ▁
# wandb:                                      train_de_mae ▂▂█▄▁▃▃▁▁▁
# wandb:                                      train_de_mse ▁▁█▃▁▂▂▁▁▁
# wandb:                                  train_de_pearson █▇▁▇█▇████
# wandb:                                       train_de_r2 ██▁▇██████
# wandb:                                 train_de_spearman ▇▆▁█▇▇█▇▇▇
# wandb:                                         train_mae ▆▇█▄▂▂▂▁▁▁
# wandb:                                         train_mse ▃▄█▃▁▂▂▁▁▁
# wandb:                                     train_pearson ▇█▁▇█▇▇███
# wandb:                                          train_r2 ▇▇▁▇█▇▇███
# wandb:                                    train_spearman ▁▃▆▆▇▇████
# wandb:                                     training_loss ▅▆▃▁▇▄▅▃▂▇▃▅▂▃▄▃▃▄▇█▂▄▂▂▃▃▆▅▄▅▅▂▂▇▆▄▆▅▇▄
# wandb:                                        val_de_mae ▂▂█▄▁▃▃▁▁▁
# wandb:                                        val_de_mse ▁▁█▃▁▂▂▁▁▁
# wandb:                                    val_de_pearson █▇▁▇█▇█▇██
# wandb:                                         val_de_r2 ██▁▇██████
# wandb:                                   val_de_spearman ▇▆▁▇▇▆█▇▇▇
# wandb:                                           val_mae ▆▇█▄▂▂▂▁▁▁
# wandb:                                           val_mse ▃▄█▃▁▂▂▁▁▁
# wandb:                                       val_pearson ▇█▁▇█▇▇███
# wandb:                                            val_r2 ▇▇▁▇█▇▇███
# wandb:                                      val_spearman ▁▃▆▆▇▇████
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced no_gnn_no_pert_emb: https://wandb.ai/kexinhuang/pert_gnn_simulation_Adamson2016/runs/3tydgazh

# %%
# !python train.py --dataset Norman2019 \
                 --split simulation \
                 --seed 1 \
                 --network_name string \
                 --top_edge_percent 10 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GCN \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3\
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:4 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --exp_name gcn_string \
                 --wandb
# Out:
# ---- Printing Arguments ----
# dataset: Norman2019
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: string
# top_edge_percent: 10.0
# randomize_network: False
# device: cuda:4
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GCN
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: False
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: False
# mlp_mixer: False
# mlp_mixer_num_layers: 2
# mlp_mixer_dropout: 0.3
# gene_sim_pos_emb: False
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: gcn_string
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run gcn_string
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/2mm4q9wk
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211111_155613-2mm4q9wk
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GCN_string_10.0_64_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 50506 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:9
# combo_seen1:52
# combo_seen2:18
# unseen_single:37
# Creating dataloaders....
# Dataloaders created...
# Finished data setup, in total takes 1.033 min
# Initializing model...
# Start Training...
# Epoch 1 Step 1 Train Loss: 3.1694
# Epoch 1 Step 51 Train Loss: 0.0637
# Epoch 1 Step 101 Train Loss: 0.0758
# Epoch 1 Step 151 Train Loss: 0.0429
# Epoch 1 Step 201 Train Loss: 0.0535
# Epoch 1 Step 251 Train Loss: 0.0374
# Epoch 1 Step 301 Train Loss: 0.0348
# Epoch 1 Step 351 Train Loss: 0.0353
# Epoch 1 Step 401 Train Loss: 0.0441
# Epoch 1 Step 451 Train Loss: 0.0352
# Epoch 1 Step 501 Train Loss: 0.0362
# Epoch 1 Step 551 Train Loss: 0.0395
# Epoch 1 Step 601 Train Loss: 0.0511
# Epoch 1 Step 651 Train Loss: 0.0348
# Epoch 1 Step 701 Train Loss: 0.0329
# Epoch 1 Step 751 Train Loss: 0.0329
# Epoch 1 Step 801 Train Loss: 0.0526
# Epoch 1 Step 851 Train Loss: 0.0502
# Epoch 1 Step 901 Train Loss: 0.0342
# Epoch 1 Step 951 Train Loss: 0.0332
# Epoch 1 Step 1001 Train Loss: 0.0456
# Epoch 1 Step 1051 Train Loss: 0.0502
# Epoch 1 Step 1101 Train Loss: 0.0444
# Epoch 1 Step 1151 Train Loss: 0.0421
# Epoch 1 Step 1201 Train Loss: 0.0607
# Epoch 1 Step 1251 Train Loss: 0.0493
# Epoch 1 Step 1301 Train Loss: 0.0337
# Epoch 1 Step 1351 Train Loss: 0.0387
# Epoch 1 Step 1401 Train Loss: 0.0248
# Epoch 1 Step 1451 Train Loss: 0.0641
# Epoch 1 Step 1501 Train Loss: 0.0382
# Epoch 1 Step 1551 Train Loss: 0.0481
# Epoch 1 Step 1601 Train Loss: 0.0535
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 1: Train: 0.0225, R2 0.8534 Validation: 0.0209. R2 0.8659 Loss: 0.0505
# DE_Train: 0.2479, R2 -0.1408 DE_Validation: 0.2480. R2 0.2270
# Epoch 2 Step 1 Train Loss: 0.0326
# Epoch 2 Step 51 Train Loss: 0.0300
# Epoch 2 Step 101 Train Loss: 0.0271
# Epoch 2 Step 151 Train Loss: 0.0464
# Epoch 2 Step 201 Train Loss: 0.0394
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 6: Train: 0.0194, R2 0.8630 Validation: 0.0205. R2 0.8532 Loss: 0.0378
# DE_Train: 0.1351, R2 -0.6235 DE_Validation: 0.1867. R2 -1.6218
# Epoch 7 Step 1 Train Loss: 0.0261
# Epoch 7 Step 51 Train Loss: 0.0547
# Epoch 7 Step 101 Train Loss: 0.0273
# Epoch 7 Step 151 Train Loss: 0.0368
# Epoch 7 Step 201 Train Loss: 0.0377
# Epoch 7 Step 251 Train Loss: 0.0328
# Epoch 7 Step 301 Train Loss: 0.0516
# Epoch 7 Step 351 Train Loss: 0.0437
# Epoch 7 Step 401 Train Loss: 0.0415
# Epoch 7 Step 451 Train Loss: 0.0399
# Epoch 7 Step 501 Train Loss: 0.0342
# Epoch 7 Step 551 Train Loss: 0.0280
# Epoch 7 Step 601 Train Loss: 0.0558
# Epoch 7 Step 651 Train Loss: 0.0383
# Epoch 7 Step 701 Train Loss: 0.0364
# Epoch 7 Step 751 Train Loss: 0.0460
# Epoch 7 Step 801 Train Loss: 0.0469
# Epoch 7 Step 851 Train Loss: 0.0275
# Epoch 7 Step 901 Train Loss: 0.0347
# Epoch 7 Step 951 Train Loss: 0.0490
# Epoch 7 Step 1001 Train Loss: 0.0436
# Epoch 7 Step 1051 Train Loss: 0.0349
# Epoch 7 Step 1101 Train Loss: 0.0359
# Epoch 7 Step 1151 Train Loss: 0.0345
# Epoch 7 Step 1201 Train Loss: 0.0427
# Epoch 7 Step 1251 Train Loss: 0.0368
# Epoch 7 Step 1301 Train Loss: 0.0436
# Epoch 7 Step 1351 Train Loss: 0.0289
# Epoch 7 Step 1401 Train Loss: 0.0413
# Epoch 7 Step 1451 Train Loss: 0.0399
# Epoch 7 Step 1501 Train Loss: 0.0258
# Epoch 7 Step 1551 Train Loss: 0.0397
# Epoch 7 Step 1601 Train Loss: 0.0370
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 7: Train: 0.0147, R2 0.8992 Validation: 0.0140. R2 0.9042 Loss: 0.0375
# DE_Train: 0.1226, R2 -0.1645 DE_Validation: 0.1657. R2 -0.5088
# Epoch 8 Step 1 Train Loss: 0.0355
# Epoch 8 Step 51 Train Loss: 0.0396
# Epoch 8 Step 101 Train Loss: 0.0476
# Epoch 8 Step 151 Train Loss: 0.0331
# Epoch 8 Step 201 Train Loss: 0.0491
# Epoch 8 Step 251 Train Loss: 0.0270
# Epoch 8 Step 301 Train Loss: 0.0304
# Epoch 8 Step 351 Train Loss: 0.0807
# Epoch 8 Step 401 Train Loss: 0.0436
# Epoch 8 Step 451 Train Loss: 0.0471
# Epoch 8 Step 501 Train Loss: 0.0296
# Epoch 8 Step 551 Train Loss: 0.0253
# Epoch 8 Step 601 Train Loss: 0.0562
# Epoch 8 Step 651 Train Loss: 0.0486
# Epoch 8 Step 701 Train Loss: 0.0383
# Epoch 8 Step 751 Train Loss: 0.0412
# Epoch 8 Step 801 Train Loss: 0.0443
# Epoch 8 Step 851 Train Loss: 0.0246
# Epoch 8 Step 901 Train Loss: 0.0541
# Epoch 8 Step 951 Train Loss: 0.0375
# Epoch 8 Step 1001 Train Loss: 0.0340
# Epoch 8 Step 1051 Train Loss: 0.0309
# Epoch 8 Step 1101 Train Loss: 0.0318
# Epoch 8 Step 1151 Train Loss: 0.0317
# Epoch 8 Step 1201 Train Loss: 0.0345
# Epoch 8 Step 1251 Train Loss: 0.0439
# Epoch 8 Step 1301 Train Loss: 0.0345
# Epoch 8 Step 1351 Train Loss: 0.0313
# Epoch 8 Step 1401 Train Loss: 0.0474
# Epoch 8 Step 1451 Train Loss: 0.0308
# Epoch 8 Step 1501 Train Loss: 0.0226
# Epoch 8 Step 1551 Train Loss: 0.0423
# Epoch 8 Step 1601 Train Loss: 0.0467
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 10 Step 701 Train Loss: 0.0215
# Epoch 10 Step 751 Train Loss: 0.0326
# Epoch 10 Step 801 Train Loss: 0.0413
# Epoch 10 Step 851 Train Loss: 0.0459
# Epoch 10 Step 901 Train Loss: 0.0567
# Epoch 10 Step 951 Train Loss: 0.0434
# Epoch 10 Step 1001 Train Loss: 0.0319
# Epoch 10 Step 1051 Train Loss: 0.0333
# Epoch 10 Step 1101 Train Loss: 0.0225
# Epoch 10 Step 1151 Train Loss: 0.0334
# Epoch 10 Step 1201 Train Loss: 0.0344
# Epoch 10 Step 1251 Train Loss: 0.0307
# Epoch 10 Step 1301 Train Loss: 0.0253
# Epoch 10 Step 1351 Train Loss: 0.0395
# Epoch 10 Step 1401 Train Loss: 0.0379
# Epoch 10 Step 1451 Train Loss: 0.0379
# Epoch 10 Step 1501 Train Loss: 0.0415
# Epoch 10 Step 1551 Train Loss: 0.0395
# Epoch 10 Step 1601 Train Loss: 0.0459
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 10: Train: 0.0160, R2 0.8866 Validation: 0.0158. R2 0.8872 Loss: 0.0371
# DE_Train: 0.1228, R2 -0.4371 DE_Validation: 0.1608. R2 -0.6011
# Saving model....
# Start testing....
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Final best performing model: Test_DE: 0.1933, R2 -1.0951
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:264: RuntimeWarning: invalid value encountered in true_divide
# ...
# wandb:              test_SYNERGY_DISSIMILAR_PHENO_mse_top50_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_fold_change_gap_all ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_40_60 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_45_55 ▁
# wandb:                   test_SYNERGY_SIMILAR_PHENO_mean_sigma ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top100_de ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top200_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top20_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top50_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:                    test_combo_seen0_fold_change_gap_all ▁
# wandb:            test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:               test_combo_seen0_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen0_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen0_frac_in_range ▁
# wandb:                    test_combo_seen0_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen0_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen0_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen0_mae ▁
# wandb:                                 test_combo_seen0_mae_de ▁
# wandb:                             test_combo_seen0_mean_sigma ▁
# wandb:                                    test_combo_seen0_mse ▁
# wandb:                                 test_combo_seen0_mse_de ▁
# wandb:                          test_combo_seen0_mse_top100_de ▁
# wandb:                          test_combo_seen0_mse_top200_de ▁
# wandb:                         test_combo_seen0_mse_top200_hvg ▁
# wandb:                           test_combo_seen0_mse_top20_de ▁
# wandb:                           test_combo_seen0_mse_top50_de ▁
# wandb:                                test_combo_seen0_pearson ▁
# wandb:                             test_combo_seen0_pearson_de ▁
# wandb:                          test_combo_seen0_pearson_delta ▁
# wandb:                       test_combo_seen0_pearson_delta_de ▁
# wandb:                test_combo_seen0_pearson_delta_top100_de ▁
# wandb:                test_combo_seen0_pearson_delta_top200_de ▁
# wandb:               test_combo_seen0_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen0_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen0_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen0_pearson_top100_de ▁
# wandb:                      test_combo_seen0_pearson_top200_de ▁
# wandb:                     test_combo_seen0_pearson_top200_hvg ▁
# wandb:                       test_combo_seen0_pearson_top20_de ▁
# wandb:                       test_combo_seen0_pearson_top50_de ▁
# wandb:                                     test_combo_seen0_r2 ▁
# wandb:                                  test_combo_seen0_r2_de ▁
# wandb:                               test_combo_seen0_spearman ▁
# wandb:                            test_combo_seen0_spearman_de ▁
# wandb:                              test_combo_seen0_std_sigma ▁
# wandb:                    test_combo_seen1_fold_change_gap_all ▁
# wandb:            test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen1_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen1_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen1_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen1_frac_in_range ▁
# wandb:                    test_combo_seen1_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen1_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen1_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen1_mae ▁
# wandb:                                 test_combo_seen1_mae_de ▁
# wandb:                             test_combo_seen1_mean_sigma ▁
# wandb:                                    test_combo_seen1_mse ▁
# wandb:                                 test_combo_seen1_mse_de ▁
# wandb:                          test_combo_seen1_mse_top100_de ▁
# wandb:                          test_combo_seen1_mse_top200_de ▁
# wandb:                         test_combo_seen1_mse_top200_hvg ▁
# wandb:                           test_combo_seen1_mse_top20_de ▁
# wandb:                           test_combo_seen1_mse_top50_de ▁
# wandb:                                test_combo_seen1_pearson ▁
# wandb:                             test_combo_seen1_pearson_de ▁
# wandb:                          test_combo_seen1_pearson_delta ▁
# wandb:                       test_combo_seen1_pearson_delta_de ▁
# wandb:                test_combo_seen1_pearson_delta_top100_de ▁
# wandb:                test_combo_seen1_pearson_delta_top200_de ▁
# wandb:               test_combo_seen1_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen1_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen1_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen1_pearson_top100_de ▁
# wandb:                      test_combo_seen1_pearson_top200_de ▁
# wandb:                     test_combo_seen1_pearson_top200_hvg ▁
# wandb:                       test_combo_seen1_pearson_top20_de ▁
# wandb:                       test_combo_seen1_pearson_top50_de ▁
# wandb:                                     test_combo_seen1_r2 ▁
# wandb:                                  test_combo_seen1_r2_de ▁
# wandb:                               test_combo_seen1_spearman ▁
# wandb:                            test_combo_seen1_spearman_de ▁
# wandb:                              test_combo_seen1_std_sigma ▁
# wandb:                    test_combo_seen2_fold_change_gap_all ▁
# wandb:            test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen2_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen2_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen2_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen2_frac_in_range ▁
# wandb:                    test_combo_seen2_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen2_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen2_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen2_mae ▁
# wandb:                                 test_combo_seen2_mae_de ▁
# wandb:                             test_combo_seen2_mean_sigma ▁
# wandb:                                    test_combo_seen2_mse ▁
# wandb:                                 test_combo_seen2_mse_de ▁
# wandb:                          test_combo_seen2_mse_top100_de ▁
# wandb:                          test_combo_seen2_mse_top200_de ▁
# wandb:                         test_combo_seen2_mse_top200_hvg ▁
# wandb:                           test_combo_seen2_mse_top20_de ▁
# wandb:                           test_combo_seen2_mse_top50_de ▁
# wandb:                                test_combo_seen2_pearson ▁
# wandb:                             test_combo_seen2_pearson_de ▁
# wandb:                          test_combo_seen2_pearson_delta ▁
# wandb:                       test_combo_seen2_pearson_delta_de ▁
# wandb:                test_combo_seen2_pearson_delta_top100_de ▁
# wandb:                test_combo_seen2_pearson_delta_top200_de ▁
# wandb:               test_combo_seen2_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen2_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen2_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen2_pearson_top100_de ▁
# wandb:                      test_combo_seen2_pearson_top200_de ▁
# wandb:                     test_combo_seen2_pearson_top200_hvg ▁
# wandb:                       test_combo_seen2_pearson_top20_de ▁
# wandb:                       test_combo_seen2_pearson_top50_de ▁
# wandb:                                     test_combo_seen2_r2 ▁
# wandb:                                  test_combo_seen2_r2_de ▁
# wandb:                               test_combo_seen2_spearman ▁
# wandb:                            test_combo_seen2_spearman_de ▁
# wandb:                              test_combo_seen2_std_sigma ▁
# wandb:                                             test_de_mae ▁
# wandb:                                             test_de_mse ▁
# wandb:                                         test_de_pearson ▁
# wandb:                                              test_de_r2 ▁
# wandb:                                        test_de_spearman ▁
# wandb:                                test_fold_change_gap_all ▁
# wandb:                        test_fold_change_gap_downreg_0.1
# wandb:                       test_fold_change_gap_downreg_0.33 ▁
# wandb:                           test_fold_change_gap_upreg_10 ▁
# wandb:                            test_fold_change_gap_upreg_3 ▁
# wandb:                                      test_frac_in_range ▁
# wandb:                                test_frac_in_range_25_75 ▁
# wandb:                                test_frac_in_range_40_60 ▁
# wandb:                                test_frac_in_range_45_55 ▁
# wandb:                                 test_frac_sigma_below_1 ▁
# wandb:                                 test_frac_sigma_below_2 ▁
# wandb:                                                test_mae ▁
# wandb:                                         test_mean_sigma ▁
# wandb:                                                test_mse ▁
# wandb:                                      test_mse_top100_de ▁
# wandb:                                      test_mse_top200_de ▁
# wandb:                                     test_mse_top200_hvg ▁
# wandb:                                       test_mse_top20_de ▁
# wandb:                                       test_mse_top50_de ▁
# wandb:                                            test_pearson ▁
# wandb:                                      test_pearson_delta ▁
# wandb:                                   test_pearson_delta_de ▁
# wandb:                            test_pearson_delta_top100_de ▁
# wandb:                            test_pearson_delta_top200_de ▁
# wandb:                           test_pearson_delta_top200_hvg ▁
# wandb:                             test_pearson_delta_top20_de ▁
# wandb:                             test_pearson_delta_top50_de ▁
# wandb:                                  test_pearson_top100_de ▁
# wandb:                                  test_pearson_top200_de ▁
# wandb:                                 test_pearson_top200_hvg ▁
# wandb:                                   test_pearson_top20_de ▁
# wandb:                                   test_pearson_top50_de ▁
# wandb:                                                 test_r2 ▁
# wandb:                                           test_spearman ▁
# wandb:                                          test_std_sigma ▁
# wandb:                  test_unseen_single_fold_change_gap_all ▁
# wandb:          test_unseen_single_fold_change_gap_downreg_0.1
# wandb:         test_unseen_single_fold_change_gap_downreg_0.33
# wandb:             test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:              test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                        test_unseen_single_frac_in_range ▁
# wandb:                  test_unseen_single_frac_in_range_25_75 ▁
# wandb:                  test_unseen_single_frac_in_range_40_60 ▁
# wandb:                  test_unseen_single_frac_in_range_45_55 ▁
# wandb:                   test_unseen_single_frac_sigma_below_1 ▁
# wandb:                   test_unseen_single_frac_sigma_below_2 ▁
# wandb:                                  test_unseen_single_mae ▁
# wandb:                               test_unseen_single_mae_de ▁
# wandb:                           test_unseen_single_mean_sigma ▁
# wandb:                                  test_unseen_single_mse ▁
# wandb:                               test_unseen_single_mse_de ▁
# wandb:                        test_unseen_single_mse_top100_de ▁
# wandb:                        test_unseen_single_mse_top200_de ▁
# wandb:                       test_unseen_single_mse_top200_hvg ▁
# wandb:                         test_unseen_single_mse_top20_de ▁
# wandb:                         test_unseen_single_mse_top50_de ▁
# wandb:                              test_unseen_single_pearson ▁
# wandb:                           test_unseen_single_pearson_de ▁
# wandb:                        test_unseen_single_pearson_delta ▁
# wandb:                     test_unseen_single_pearson_delta_de ▁
# wandb:              test_unseen_single_pearson_delta_top100_de ▁
# wandb:              test_unseen_single_pearson_delta_top200_de ▁
# wandb:             test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:               test_unseen_single_pearson_delta_top20_de ▁
# wandb:               test_unseen_single_pearson_delta_top50_de ▁
# wandb:                    test_unseen_single_pearson_top100_de ▁
# wandb:                    test_unseen_single_pearson_top200_de ▁
# wandb:                   test_unseen_single_pearson_top200_hvg ▁
# wandb:                     test_unseen_single_pearson_top20_de ▁
# wandb:                     test_unseen_single_pearson_top50_de ▁
# wandb:                                   test_unseen_single_r2 ▁
# wandb:                                test_unseen_single_r2_de ▁
# wandb:                             test_unseen_single_spearman ▁
# wandb:                          test_unseen_single_spearman_de ▁
# wandb:                            test_unseen_single_std_sigma ▁
# wandb:                                            train_de_mae ██▆▄▂▂▁▃▂▁
# wandb:                                            train_de_mse ▇█▅▄▃▂▁▂▂▁
# wandb:                                        train_de_pearson ▁▁▄▄▇▇▇▇██
# wandb:                                             train_de_r2 ▄▇▁▅█▁▄▃▃▂
# wandb:                                       train_de_spearman ▁▁▅▄▇▇▇███
# wandb:                                               train_mae █▆█▄▁▆▄▅▄▅
# wandb:                                               train_mse ▇██▄▁▆▄▄▄▄
# wandb:                                           train_pearson █▅▄▆▃▂▅▁▂▁
# wandb:                                                train_r2 ▄▆▁▇█▄▆▅▆▆
# wandb:                                          train_spearman ▁▆▆▇▇█████
# wandb:                                           training_loss ▇▆▆▅▇▆▆▆▃▃▇▇▂▄▆▅▄▆▄▂▆▂▂▅▄▄▁▄▅▂▄▃▆▃▅▄▃▃█▄
# wandb:                                              val_de_mae ▆█▅▅▁▃▂▂▂▂
# wandb:                                              val_de_mse ▅█▄▄▂▂▁▂▁▁
# wandb:                                          val_de_pearson ▁▁▃▂▆▅▇███
# wandb:                                               val_de_r2 ▇█▆▅█▁▅▄▅▄
# wandb:                                         val_de_spearman ▂▁▄▄▇▆▇██▇
# wandb:                                                 val_mae ▇▆█▄▁▆▄▅▄▅
# wandb:                                                 val_mse ▆█▇▄▁▅▃▄▃▄
# wandb:                                             val_pearson █▅▃▅▄▂▄▁▁▁
# wandb:                                                  val_r2 ▄▅▁▇█▄▆▅▆▅
# wandb:                                            val_spearman ▁▆▇▇▇█████
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced gcn_string: https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/2mm4q9wk

# %%
_
