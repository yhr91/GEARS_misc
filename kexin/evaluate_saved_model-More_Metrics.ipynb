# %%
import numpy as np
import torch
import scanpy as sc
from data import PertDataloader, Network


name2path = {
    'GNN_Disentangle-L2': 'GNN_Disentangle_GAT_string_20.0_64_2_l2_Norman2019_gene_emb_pert_emb_constant_sim_gnn',
    'GNN_Disentangle_Sim': 'GNN_Disentangle_GAT_string_20.0_64_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_sim_gnn',
    'No-Perturb': 'No_Perturb_GAT_string_20.0_64_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_sim_gnn'
}

name = 'No-Perturb'

model_name = name2path[name]
args = np.load('./saved_args/'+model_name+'.npy', allow_pickle = True).item()
args['device'] = 'cuda:3'

# %%
#import wandb
#wandb.init(project='pert_gnn_simulation', entity='kexinhuang', name=name)

# %%
if args['network_name'] == 'string':
    args['network_path'] = '/dfs/project/perturb-gnn/graphs/STRING_full_9606.csv'

if args['dataset'] == 'Norman2019':
    data_path = '/dfs/project/perturb-gnn/datasets/Norman2019_hvg+perts_more_de.h5ad'

adata = sc.read_h5ad(data_path)
if 'gene_symbols' not in adata.var.columns.values:
    adata.var['gene_symbols'] = adata.var['gene_name']
gene_list = [f for f in adata.var.gene_symbols.values]
# Set up message passing network
network = Network(fname=args['network_path'], gene_list=args['gene_list'],
                  percentile=args['top_edge_percent'])

# Pertrubation dataloader
pertdl = PertDataloader(adata, network.G, network.weights, args)
# Out:
# There are 101013 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:9
# combo_seen1:52
# combo_seen2:18
# unseen_single:37
# Creating dataloaders....
# Dataloaders created...

# %%
model = torch.load('./saved_models/' + model_name)
#model.pert_emb_agg = 'constant'
#model.lambda_emission = False
#model.sim_gnn = False
#model.args = args
from inference import evaluate, compute_metrics, deeper_analysis, GI_subgroup

test_res = evaluate(pertdl.loaders['test_loader'],
                        pertdl.loaders['edge_index'],
                        pertdl.loaders['edge_attr'], model, args)

test_metrics, test_pert_res = compute_metrics(test_res)
# Out:
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
import pickle
metrics = ['mse', 'mae', 'spearman', 'pearson', 'r2']
for m in metrics:
    wandb.log({'test_' + m: test_metrics[m],
               'test_de_'+m: test_metrics[m + '_de']                     
              })
subgroup_path = './splits/Norman2019_simulation_1_0.1_subgroup.pkl'
subgroup = pickle.load(open(subgroup_path, "rb"))
        
subgroup_analysis = {}
for name in subgroup['test_subgroup'].keys():
    subgroup_analysis[name] = {}
    for m in list(list(test_pert_res.values())[0].keys()):
        subgroup_analysis[name][m] = []

for name, pert_list in subgroup['test_subgroup'].items():
    for pert in pert_list:
        for m, res in test_pert_res[pert].items():
            subgroup_analysis[name][m].append(res)

for name, result in subgroup_analysis.items():
    for m in result.keys():
        subgroup_analysis[name][m] = np.mean(subgroup_analysis[name][m])
        wandb.log({'test_' + name + '_' + m: subgroup_analysis[name][m]})

        print('test_' + name + '_' + m + ': ' + str(subgroup_analysis[name][m]))
# Out:
# test_combo_seen0_mse: 0.006539415
# test_combo_seen0_mae: 0.024473794
# test_combo_seen0_spearman: 0.8554495607638996
# test_combo_seen0_pearson: 0.9798589015861244
# test_combo_seen0_r2: 0.9598484850494818
# test_combo_seen0_mse_de: 0.38452822
# test_combo_seen0_mae_de: 0.4249717
# test_combo_seen0_spearman_de: 0.6664525191936057
# test_combo_seen0_pearson_de: 0.7978656813909297
# test_combo_seen0_r2_de: 0.21557548380438085
# test_combo_seen1_mse: 0.008615982
# test_combo_seen1_mae: 0.026082836
# test_combo_seen1_spearman: 0.8544749063877007
# test_combo_seen1_pearson: 0.9739889917017668
# test_combo_seen1_r2: 0.9473155717003212
# test_combo_seen1_mse_de: 0.5381686
# test_combo_seen1_mae_de: 0.5313102
# test_combo_seen1_spearman_de: 0.670112338770854
# test_combo_seen1_pearson_de: 0.7268227974597503
# test_combo_seen1_r2_de: -0.1511186308570229
# test_combo_seen2_mse: 0.005411647
# test_combo_seen2_mae: 0.019519575
# test_combo_seen2_spearman: 0.8663311193796182
# test_combo_seen2_pearson: 0.9836433716631533
# test_combo_seen2_r2: 0.9668846735822161
# test_combo_seen2_mse_de: 0.588709
# test_combo_seen2_mae_de: 0.62251323
# test_combo_seen2_spearman_de: 0.7456547852860187
# test_combo_seen2_pearson_de: 0.8498174383142749
# test_combo_seen2_r2_de: 0.4279393265362378
# test_unseen_single_mse: 0.0035281905
# test_unseen_single_mae: 0.016654558
# test_unseen_single_spearman: 0.8650083619645049
# test_unseen_single_pearson: 0.9892103826245933
# test_unseen_single_r2: 0.9784071656042123
# test_unseen_single_mse_de: 0.26654512
# test_unseen_single_mae_de: 0.36403838
# test_unseen_single_spearman_de: 0.7087268424274717
# test_unseen_single_pearson_de: 0.8517585455298485
# test_unseen_single_r2_de: 0.5171722046499674

# %%
out = deeper_analysis(adata, test_res)
GI_out = GI_subgroup(out)
# Out:
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:240: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/perturb_GNN/kexin/inference.py:240: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
metrics = ['frac_in_range', 'mean_sigma', 'std_sigma', 'frac_sigma_below_1', 'frac_sigma_below_2', 
          'spearman_delta', 'spearman_delta_de', 'pearson_delta', 'pearson_delta_de', 'fold_change_gap_all', 
          'spearman_delta_top200_hvg', 'pearson_delta_top200_hvg', 'fold_change_gap_upreg_3', 'fold_change_gap_downreg_0.33',
          'fold_change_gap_downreg_0.1', 'fold_change_gap_upreg_10', 'spearman_top200_hvg', 'pearson_top200_hvg', 
          'pearson_top200_de', 'spearman_top200_de', 'pearson_delta_top200_de', 'spearman_delta_top200_de',
          'pearson_top100_de', 'spearman_top100_de', 'pearson_delta_top100_de', 'spearman_delta_top100_de']

for m in metrics:
    wandb.log({'test_' + m: np.mean([j[m] for i,j in out.items() if m in j])})
# Out:
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
subgroup_path = './splits/Norman2019_simulation_1_0.1_subgroup.pkl'
subgroup = pickle.load(open(subgroup_path, "rb"))
        
subgroup_analysis = {}
for name in subgroup['test_subgroup'].keys():
    subgroup_analysis[name] = {}
    for m in metrics:
        subgroup_analysis[name][m] = []

for name, pert_list in subgroup['test_subgroup'].items():
    for pert in pert_list:
        for m, res in out[pert].items():
            subgroup_analysis[name][m].append(res)

for name, result in subgroup_analysis.items():
    for m in result.keys():
        subgroup_analysis[name][m] = np.mean(subgroup_analysis[name][m])
        wandb.log({'test_' + name + '_' + m: subgroup_analysis[name][m]})

        print('test_' + name + '_' + m + ': ' + str(subgroup_analysis[name][m]))
# Out:
# test_combo_seen0_frac_in_range: 1.0
# test_combo_seen0_mean_sigma: 1.1593934
# test_combo_seen0_std_sigma: 0.183148
# test_combo_seen0_frac_sigma_below_1: 0.2971749226006192
# test_combo_seen0_frac_sigma_below_2: 0.9875
# test_combo_seen0_spearman_delta: 0.12472215133661285
# test_combo_seen0_spearman_delta_de: 0.8058479532163743
# test_combo_seen0_pearson_delta: 0.004367435041405094
# test_combo_seen0_pearson_delta_de: 0.8607025363597248
# test_combo_seen0_fold_change_gap_all: 0.972206
# test_combo_seen0_spearman_delta_top200_hvg: 0.0019227147345350336
# test_combo_seen0_pearson_delta_top200_hvg: -0.0227856575276294
# test_combo_seen0_fold_change_gap_upreg_3: 71.17499
# test_combo_seen0_fold_change_gap_downreg_0.33: nan
# test_combo_seen0_fold_change_gap_downreg_0.1: nan
# test_combo_seen0_fold_change_gap_upreg_10: 265.04575
# test_combo_seen0_spearman_top200_hvg: 0.9271347596043279
# test_combo_seen0_pearson_top200_hvg: 0.9379116568866616
# test_combo_seen0_pearson_top200_de: 0.8966080945853451
# test_combo_seen0_spearman_top200_de: 0.8102510233335458
# test_combo_seen0_pearson_delta_top200_de: -0.017971585938636007
# test_combo_seen0_spearman_delta_top200_de: 0.0499719159645658
# test_combo_seen0_pearson_top100_de: 0.8838514579435837
# test_combo_seen0_spearman_top100_de: 0.8040836495454191
# test_combo_seen0_pearson_delta_top100_de: -0.06342358089253836
# test_combo_seen0_spearman_delta_top100_de: -0.0013961396139613909
# test_combo_seen1_frac_in_range: 1.0
# test_combo_seen1_mean_sigma: 1.1773084
# test_combo_seen1_std_sigma: 0.27377796
# test_combo_seen1_frac_sigma_below_1: 0.3815648440442591
# test_combo_seen1_frac_sigma_below_2: 0.9611422172452408
# test_combo_seen1_spearman_delta: 0.10144844122043112
# test_combo_seen1_spearman_delta_de: 0.7906304222093694
# test_combo_seen1_pearson_delta: -0.009093892327667804
# test_combo_seen1_pearson_delta_de: 0.8469010116797266
# test_combo_seen1_fold_change_gap_all: 1.0816191
# test_combo_seen1_spearman_delta_top200_hvg: -0.02366150589920895
# test_combo_seen1_pearson_delta_top200_hvg: -0.013692007396147747
# test_combo_seen1_fold_change_gap_upreg_3: 20.727541
# test_combo_seen1_fold_change_gap_downreg_0.33: 0.7030594
# test_combo_seen1_fold_change_gap_downreg_0.1: nan
# test_combo_seen1_fold_change_gap_upreg_10: 100.97231
# test_combo_seen1_spearman_top200_hvg: 0.8823879332185803
# test_combo_seen1_pearson_top200_hvg: 0.9137566310450739
# test_combo_seen1_pearson_top200_de: 0.9292587399135397
# test_combo_seen1_spearman_top200_de: 0.8522103582577625
# test_combo_seen1_pearson_delta_top200_de: -0.008704777571292815
# test_combo_seen1_spearman_delta_top200_de: -0.010566927634729332
# test_combo_seen1_pearson_top100_de: 0.8757261346006017
# test_combo_seen1_spearman_top100_de: 0.8138627490574699
# test_combo_seen1_pearson_delta_top100_de: -0.00281858971416304
# test_combo_seen1_spearman_delta_top100_de: -0.012895751113572895
# test_combo_seen2_frac_in_range: 1.0
# test_combo_seen2_mean_sigma: 0.99540913
# test_combo_seen2_std_sigma: 0.26722825
# test_combo_seen2_frac_sigma_below_1: 0.6011511622192738
# test_combo_seen2_frac_sigma_below_2: 0.9722222222222222
# test_combo_seen2_spearman_delta: 0.08548681933064854
# test_combo_seen2_spearman_delta_de: 0.8724310776942354
# test_combo_seen2_pearson_delta: 0.035721373129989076
# test_combo_seen2_pearson_delta_de: 0.908462826042427
# test_combo_seen2_fold_change_gap_all: 0.43334973
# test_combo_seen2_spearman_delta_top200_hvg: 0.05540038500962525
# test_combo_seen2_pearson_delta_top200_hvg: 0.04510444298556607
# test_combo_seen2_fold_change_gap_upreg_3: 24.30939
# test_combo_seen2_fold_change_gap_downreg_0.33: 0.67261326
# test_combo_seen2_fold_change_gap_downreg_0.1: nan
# test_combo_seen2_fold_change_gap_upreg_10: 76.90252
# test_combo_seen2_spearman_top200_hvg: 0.9298137370978176
# test_combo_seen2_pearson_top200_hvg: 0.9432519426807047
# test_combo_seen2_pearson_top200_de: 0.9522914817012048
# test_combo_seen2_spearman_top200_de: 0.9234772939044374
# test_combo_seen2_pearson_delta_top200_de: 0.04498458047394417
# test_combo_seen2_spearman_delta_top200_de: 0.05011950298757469
# test_combo_seen2_pearson_top100_de: 0.9261160990282293
# test_combo_seen2_spearman_top100_de: 0.8902247214236465
# test_combo_seen2_pearson_delta_top100_de: 0.04724484520967887
# test_combo_seen2_spearman_delta_top100_de: 0.05108377504417108
# test_unseen_single_frac_in_range: 1.0
# test_unseen_single_mean_sigma: 0.90992606
# test_unseen_single_std_sigma: 0.21415508
# test_unseen_single_frac_sigma_below_1: 0.6788914432169629
# test_unseen_single_frac_sigma_below_2: 0.988421052631579
# test_unseen_single_spearman_delta: 0.10182568396184434
# test_unseen_single_spearman_delta_de: 0.8373907742328794
# test_unseen_single_pearson_delta: 0.012167871102326703
# test_unseen_single_pearson_delta_de: 0.9184448013601767
# test_unseen_single_fold_change_gap_all: 0.5124445
# test_unseen_single_spearman_delta_top200_hvg: 0.01802878855755178
# test_unseen_single_pearson_delta_top200_hvg: 0.0064637177776410695
# test_unseen_single_fold_change_gap_upreg_3: 16.218458
# test_unseen_single_fold_change_gap_downreg_0.33: nan
# test_unseen_single_fold_change_gap_downreg_0.1: nan
# test_unseen_single_fold_change_gap_upreg_10: 106.558754
# test_unseen_single_spearman_top200_hvg: 0.952602859935388
# test_unseen_single_pearson_top200_hvg: 0.9657329768931207
# test_unseen_single_pearson_top200_de: 0.9686795922045425
# test_unseen_single_spearman_top200_de: 0.8388164334753235
# test_unseen_single_pearson_delta_top200_de: 0.011934130635387657
# test_unseen_single_spearman_delta_top200_de: 0.03711031964988315
# test_unseen_single_pearson_top100_de: 0.9308877639883038
# test_unseen_single_spearman_top100_de: 0.8141277977879074
# test_unseen_single_pearson_delta_top100_de: -0.009602469198177014
# test_unseen_single_spearman_delta_top100_de: 0.025067263483105073

# %%
for i,j in GI_out.items():
    for m in ['mean_sigma', 'std_sigma', 'fold_change_gap_all', 'pearson_delta_top200_de', 
              'spearman_delta_top200_hvg', 'pearson_delta_top200_hvg', 
              'spearman_delta_top200_de', 'pearson_delta_top100_de', 'spearman_delta_top100_de']:
        wandb.log({'test_' + i + '_' + m: j[m]})

# %%
for i,j in  GI_subgroup(test_pert_res).items():
    for m in ['mse_de']:
        wandb.log({'test_' + i + '_' + m: j[m]})

# %%
np.quantile(test_res['truth_de'][pert_idx], 0.25, axis = 0)
# Out:
# array([1.98486948, 0.        , 0.        , 0.62915419, 1.09004056,
#        1.97734478, 0.        , 0.67672339, 0.5912282 , 0.52250315,
#        0.        , 0.        , 5.06873918, 0.        , 0.        ,
#        0.99365979, 1.06806734, 0.        , 0.        , 2.5388093 ])

# %%
from scipy.stats import pearsonr, spearmanr
from sklearn.metrics import mean_squared_error as mse

metric2fct = {
       #'spearman': spearmanr, # not meaningful
       'pearson': pearsonr,
       'mse': mse
}

pert_metric = {}

## in silico modeling and upperbounding
pert2pert_full_id = dict(adata.obs[['condition', 'cov_drug_dose_name']].values)
geneid2name = dict(zip(adata.var.index.values, adata.var['gene_name']))
geneid2idx = dict(zip(adata.var.index.values, range(len(adata.var.index.values))))

# calculate mean expression for each condition
unique_conditions = adata.obs.condition.unique()
conditions2index = {}
for i in unique_conditions:
    conditions2index[i] = np.where(adata.obs.condition == i)[0]

condition2mean_expression = {}
for i, j in conditions2index.items():
    condition2mean_expression[i] = np.mean(adata.X[j], axis = 0)
pert_list = np.array(list(condition2mean_expression.keys()))
mean_expression = np.array(list(condition2mean_expression.values())).reshape(len(adata.obs.condition.unique()), adata.X.toarray().shape[1])
ctrl = mean_expression[np.where(pert_list == 'ctrl')[0]]
most_variable_genes = np.argsort(np.std(mean_expression, axis = 0))[-200:]
gene_list = adata.var['gene_name'].values

for pert in np.unique(test_res['pert_cat']):
    pert_metric[pert] = {}
    #de_names = [geneid2name[i] for i in adata.uns['rank_genes_groups_cov'][pert2pert_full_id[pert]]]
    de_idx = [geneid2idx[i] for i in adata.uns['rank_genes_groups_cov'][pert2pert_full_id[pert]]]
    de_idx_200 = [geneid2idx[i] for i in adata.uns['rank_genes_groups_cov_top200'][pert2pert_full_id[pert]]]
    de_idx_100 = [geneid2idx[i] for i in adata.uns['rank_genes_groups_cov_top100'][pert2pert_full_id[pert]]]
    de_idx_50 = [geneid2idx[i] for i in adata.uns['rank_genes_groups_cov_top50'][pert2pert_full_id[pert]]]

    pert_idx = np.where(test_res['pert_cat'] == pert)[0]    
    pred_mean = np.mean(test_res['pred_de'][pert_idx], axis = 0).reshape(-1,)
    true_mean = np.mean(test_res['truth_de'][pert_idx], axis = 0).reshape(-1,)

    mean = np.mean(test_res['truth_de'][pert_idx], axis = 0)
    std = np.std(test_res['truth_de'][pert_idx], axis = 0)
    min_ = np.min(test_res['truth_de'][pert_idx], axis = 0)
    max_ = np.max(test_res['truth_de'][pert_idx], axis = 0)
    q25 = np.quantile(test_res['truth_de'][pert_idx], 0.25, axis = 0)
    q75 = np.quantile(test_res['truth_de'][pert_idx], 0.75, axis = 0)
    q55 = np.quantile(test_res['truth_de'][pert_idx], 0.55, axis = 0)
    q45 = np.quantile(test_res['truth_de'][pert_idx], 0.45, axis = 0)
    q40 = np.quantile(test_res['truth_de'][pert_idx], 0.4, axis = 0)
    q60 = np.quantile(test_res['truth_de'][pert_idx], 0.6, axis = 0)
    
    zero_des = np.intersect1d(np.where(min_ == 0)[0], np.where(max_ == 0)[0])
    nonzero_des = np.setdiff1d(list(range(20)), zero_des)
    if len(nonzero_des) == 0:
        pass
        # pert that all de genes are 0...
    else:
        in_range = (pred_mean[nonzero_des] >= min_[nonzero_des]) & (pred_mean[nonzero_des] <= max_[nonzero_des])
        frac_in_range = sum(in_range)/len(nonzero_des)
        pert_metric[pert]['frac_in_range'] = frac_in_range
        
        in_range_5 = (pred_mean[nonzero_des] >= q45[nonzero_des]) & (pred_mean[nonzero_des] <= q55[nonzero_des])
        frac_in_range_45_55 = sum(in_range_5)/len(nonzero_des)
        pert_metric[pert]['frac_in_range_45_55'] = frac_in_range_45_55
        
        in_range_10 = (pred_mean[nonzero_des] >= q40[nonzero_des]) & (pred_mean[nonzero_des] <= q60[nonzero_des])
        frac_in_range_40_60 = sum(in_range_10)/len(nonzero_des)
        pert_metric[pert]['frac_in_range_40_60'] = frac_in_range_40_60
        
        in_range_25 = (pred_mean[nonzero_des] >= q25[nonzero_des]) & (pred_mean[nonzero_des] <= q75[nonzero_des])
        frac_in_range_25_75 = sum(in_range_25)/len(nonzero_des)
        pert_metric[pert]['frac_in_range_25_75'] = frac_in_range_25_75
        
        zero_idx = np.where(std > 0)[0]
        sigma = (np.abs(pred_mean[zero_idx] - mean[zero_idx]))/(std[zero_idx])
        pert_metric[pert]['mean_sigma'] = np.mean(sigma)
        pert_metric[pert]['std_sigma'] = np.std(sigma)
        pert_metric[pert]['frac_sigma_below_1'] = 1 - len(np.where(sigma > 1)[0])/len(zero_idx)
        pert_metric[pert]['frac_sigma_below_2'] = 1 - len(np.where(sigma > 2)[0])/len(zero_idx)

    ## correlation on delta
    p_idx = np.where(test_res['pert_cat'] == pert)[0]

    for m, fct in metric2fct.items():
        if m != 'mse':
            val = fct(test_res['pred'][p_idx].mean(0)- ctrl[0], test_res['truth'][p_idx].mean(0)-ctrl[0])[0]
            if np.isnan(val):
                val = 0

            pert_metric[pert][m + '_delta'] = val

            val = fct(test_res['pred_de'][p_idx].mean(0)- ctrl[0][de_idx], test_res['truth_de'][p_idx].mean(0)-ctrl[0][de_idx])[0]
            if np.isnan(val):
                val = 0

            pert_metric[pert][m + '_delta_de'] = val

    ## up fold changes > 10?
    pert_mean = np.mean(test_res['truth'][p_idx], axis = 0).reshape(-1,)

    fold_change = pert_mean/ctrl
    fold_change[np.isnan(fold_change)] = 0
    fold_change[np.isinf(fold_change)] = 0
    ## this is to remove the ones that are super low and the fold change becomes unmeaningful
    fold_change[0][np.where(pert_mean < 0.5)[0]] = 0

    o =  np.where(fold_change[0] > 0)[0]

    pred_fc = test_res['pred'][p_idx].mean(0)[o]
    true_fc = test_res['truth'][p_idx].mean(0)[o]
    ctrl_fc = ctrl[0][o]

    if len(o) > 0:
        pert_metric[pert]['fold_change_gap_all'] = np.mean(np.abs(pred_fc/ctrl_fc - true_fc/ctrl_fc))


    o = np.intersect1d(np.where(fold_change[0] <0.333)[0], np.where(fold_change[0] > 0)[0])

    pred_fc = test_res['pred'][p_idx].mean(0)[o]
    true_fc = test_res['truth'][p_idx].mean(0)[o]
    ctrl_fc = ctrl[0][o]

    if len(o) > 0:
        pert_metric[pert]['fold_change_gap_downreg_0.33'] = np.mean(np.abs(pred_fc/ctrl_fc - true_fc/ctrl_fc))


    o = np.intersect1d(np.where(fold_change[0] <0.1)[0], np.where(fold_change[0] > 0)[0])

    pred_fc = test_res['pred'][p_idx].mean(0)[o]
    true_fc = test_res['truth'][p_idx].mean(0)[o]
    ctrl_fc = ctrl[0][o]

    if len(o) > 0:
        pert_metric[pert]['fold_change_gap_downreg_0.1'] = np.mean(np.abs(pred_fc/ctrl_fc - true_fc/ctrl_fc))

    o = np.where(fold_change[0] > 3)[0]

    pred_fc = test_res['pred'][p_idx].mean(0)[o]
    true_fc = test_res['truth'][p_idx].mean(0)[o]
    ctrl_fc = ctrl[0][o]

    if len(o) > 0:
        pert_metric[pert]['fold_change_gap_upreg_3'] = np.mean(np.abs(pred_fc/ctrl_fc - true_fc/ctrl_fc))

    o = np.where(fold_change[0] > 10)[0]

    pred_fc = test_res['pred'][p_idx].mean(0)[o]
    true_fc = test_res['truth'][p_idx].mean(0)[o]
    ctrl_fc = ctrl[0][o]

    if len(o) > 0:
        pert_metric[pert]['fold_change_gap_upreg_10'] = np.mean(np.abs(pred_fc/ctrl_fc - true_fc/ctrl_fc))

    ## most variable genes
    for m, fct in metric2fct.items():
        if m != 'mse':
            val = fct(test_res['pred'][p_idx].mean(0)[most_variable_genes] - ctrl[0][most_variable_genes], test_res['truth'][p_idx].mean(0)[most_variable_genes]-ctrl[0][most_variable_genes])[0]
            if np.isnan(val):
                val = 0
            pert_metric[pert][m + '_delta_top200_hvg'] = val


            val = fct(test_res['pred'][p_idx].mean(0)[most_variable_genes], test_res['truth'][p_idx].mean(0)[most_variable_genes])[0]
            if np.isnan(val):
                val = 0
            pert_metric[pert][m + '_top200_hvg'] = val
        else:
            val = fct(test_res['pred'][p_idx].mean(0)[most_variable_genes], test_res['truth'][p_idx].mean(0)[most_variable_genes])
            pert_metric[pert][m + '_top200_hvg'] = val


    ## top 50/100/200 DEs
    for m, fct in metric2fct.items():
        if m != 'mse':
            val = fct(test_res['pred'][p_idx].mean(0)[de_idx_200] - ctrl[0][de_idx_200], test_res['truth'][p_idx].mean(0)[de_idx_200]-ctrl[0][de_idx_200])[0]
            if np.isnan(val):
                val = 0
            pert_metric[pert][m + '_delta_top200_de'] = val


            val = fct(test_res['pred'][p_idx].mean(0)[de_idx_200], test_res['truth'][p_idx].mean(0)[de_idx_200])[0]
            if np.isnan(val):
                val = 0
            pert_metric[pert][m + '_top200_de'] = val
        else:
            val = fct(test_res['pred'][p_idx].mean(0)[de_idx_200] - ctrl[0][de_idx_200], test_res['truth'][p_idx].mean(0)[de_idx_200]-ctrl[0][de_idx_200])
            pert_metric[pert][m + '_top200_de'] = val

    for m, fct in metric2fct.items():
        if m != 'mse':
        
            val = fct(test_res['pred'][p_idx].mean(0)[de_idx_100] - ctrl[0][de_idx_100], test_res['truth'][p_idx].mean(0)[de_idx_100]-ctrl[0][de_idx_100])[0]
            if np.isnan(val):
                val = 0
            pert_metric[pert][m + '_delta_top100_de'] = val


            val = fct(test_res['pred'][p_idx].mean(0)[de_idx_100], test_res['truth'][p_idx].mean(0)[de_idx_100])[0]
            if np.isnan(val):
                val = 0
            pert_metric[pert][m + '_top100_de'] = val
        else:
            val = fct(test_res['pred'][p_idx].mean(0)[de_idx_100] - ctrl[0][de_idx_100], test_res['truth'][p_idx].mean(0)[de_idx_100]-ctrl[0][de_idx_100])
            pert_metric[pert][m + '_top100_de'] = val
            
    for m, fct in metric2fct.items():
        if m != 'mse':
        
            val = fct(test_res['pred'][p_idx].mean(0)[de_idx_50] - ctrl[0][de_idx_50], test_res['truth'][p_idx].mean(0)[de_idx_50]-ctrl[0][de_idx_50])[0]
            if np.isnan(val):
                val = 0
            pert_metric[pert][m + '_delta_top50_de'] = val


            val = fct(test_res['pred'][p_idx].mean(0)[de_idx_50], test_res['truth'][p_idx].mean(0)[de_idx_50])[0]
            if np.isnan(val):
                val = 0
            pert_metric[pert][m + '_top50_de'] = val
        else:
            val = fct(test_res['pred'][p_idx].mean(0)[de_idx_50] - ctrl[0][de_idx_50], test_res['truth'][p_idx].mean(0)[de_idx_50]-ctrl[0][de_idx_50])
            pert_metric[pert][m + '_top50_de'] = val
# Out:
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   fold_change = pert_mean/ctrl
# /tmp/ipykernel_75960/3415215313.py:104: RuntimeWarning: invalid value encountered in true_divide
#   fold_change = pert_mean/ctrl

# %%
pert_metric
# Out:
# {'AHR+KLF1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.15,
#   'mean_sigma': 1.1150635,
#   'std_sigma': 0.40569043,
#   'frac_sigma_below_1': 0.4,
#   'frac_sigma_below_2': 0.95,
#   'pearson_delta': 0.022298707646802935,
#   'pearson_delta_de': 0.960052268454196,
#   'fold_change_gap_all': 0.1878515,
#   'fold_change_gap_upreg_3': 2.952547,
#   'pearson_delta_top200_hvg': 0.10723303505101547,
#   'pearson_top200_hvg': 0.9595004643472538,
#   'mse_top200_hvg': 0.08491335,
#   'pearson_delta_top200_de': 0.09362745184777875,
#   'pearson_top200_de': 0.9622425492148956,
#   'mse_top200_de': 0.09853176,
#   'pearson_delta_top100_de': 0.1683593718888371,
#   'pearson_top100_de': 0.9381953503523631,
#   'mse_top100_de': 0.17942572,
#   'pearson_delta_top50_de': 0.23618640501101235,
#   'pearson_top50_de': 0.9026560662482132,
#   'mse_top50_de': 0.3203701},
#  'ARID1A+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 0.9705367,
#   'std_sigma': 0.13936608,
#   'frac_sigma_below_1': 0.6428571428571428,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.06760065988011515,
#   'pearson_delta_de': 0.9658282560858839,
#   'fold_change_gap_all': 0.29212376,
#   'fold_change_gap_upreg_3': 5.252758,
#   'fold_change_gap_upreg_10': 12.614851,
#   'pearson_delta_top200_hvg': 0.06254972094466027,
#   'pearson_top200_hvg': 0.9511945641127643,
#   'mse_top200_hvg': 0.08724433,
#   'pearson_delta_top200_de': 0.10820206316378854,
#   'pearson_top200_de': 0.961899690284611,
#   'mse_top200_de': 0.09674344,
#   'pearson_delta_top100_de': 0.1615033917722868,
#   'pearson_top100_de': 0.9515755841730842,
#   'mse_top100_de': 0.14649175,
#   'pearson_delta_top50_de': 0.2996884392839073,
#   'pearson_top50_de': 0.9335681341303943,
#   'mse_top50_de': 0.21822995},
#  'BCL2L11+BAK1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.1737152,
#   'std_sigma': 0.0,
#   'frac_sigma_below_1': 0.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.09775830153148118,
#   'pearson_delta_de': 0.9157423271610349,
#   'fold_change_gap_all': 0.064227425,
#   'pearson_delta_top200_hvg': -0.20168493679170052,
#   'pearson_top200_hvg': 0.9952318266193024,
#   'mse_top200_hvg': 0.00867463,
#   'pearson_delta_top200_de': -0.38130915261388654,
#   'pearson_top200_de': 0.9895104945435496,
#   'mse_top200_de': 0.0024188086,
#   'pearson_delta_top100_de': -0.5904899875339549,
#   'pearson_top100_de': 0.7158200219955047,
#   'mse_top100_de': 0.0033669448,
#   'pearson_delta_top50_de': -0.6561279111021504,
#   'pearson_top50_de': 0.7112680993342445,
#   'mse_top50_de': 0.006638172},
#  'BCL2L11+TGFBR2': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.125,
#   'frac_in_range_40_60': 0.125,
#   'frac_in_range_25_75': 0.625,
#   'mean_sigma': 0.58160543,
#   'std_sigma': 0.15678075,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.035057977192246154,
#   'pearson_delta_de': 0.9569534579359441,
#   'fold_change_gap_all': 0.06706601,
#   'fold_change_gap_upreg_3': 2.2522125,
#   'pearson_delta_top200_hvg': 0.01746540168844862,
#   'pearson_top200_hvg': 0.991088256599009,
#   'mse_top200_hvg': 0.01560688,
#   'pearson_delta_top200_de': 0.042028522437312456,
#   'pearson_top200_de': 0.9832115745651285,
#   'mse_top200_de': 0.015765155,
#   'pearson_delta_top100_de': 0.059018601593542636,
#   'pearson_top100_de': 0.9715816978944464,
#   'mse_top100_de': 0.029614735,
#   'pearson_delta_top50_de': 0.003080347002715824,
#   'pearson_top50_de': 0.9533002122510594,
#   'mse_top50_de': 0.054764494},
#  'BCL2L11+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.5,
#   'mean_sigma': 0.67949295,
#   'std_sigma': 0.19802514,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.1192348550704026,
#   'pearson_delta_de': 0.9781545585907025,
#   'fold_change_gap_all': 0.041400995,
#   'fold_change_gap_upreg_3': 2.3385363,
#   'pearson_delta_top200_hvg': -0.3009044749790267,
#   'pearson_top200_hvg': 0.9984711168827803,
#   'mse_top200_hvg': 0.0027261302,
#   'pearson_delta_top200_de': -0.4708504984930218,
#   'pearson_top200_de': 0.9895632150257275,
#   'mse_top200_de': 0.0025040894,
#   'pearson_delta_top100_de': -0.4821115770882877,
#   'pearson_top100_de': 0.9869808819470423,
#   'mse_top100_de': 0.0041854037,
#   'pearson_delta_top50_de': -0.480481050239552,
#   'pearson_top50_de': 0.9828961780813111,
#   'mse_top50_de': 0.0070927143},
#  'BCORL1+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.08333333333333333,
#   'frac_in_range_40_60': 0.16666666666666666,
#   'frac_in_range_25_75': 0.5,
#   'mean_sigma': 0.6430037,
#   'std_sigma': 0.2350718,
#   'frac_sigma_below_1': 0.9166666666666666,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.0015454345950639918,
#   'pearson_delta_de': 0.9842516038624607,
#   'fold_change_gap_all': 0.06536299,
#   'pearson_delta_top200_hvg': -0.07933282053747148,
#   'pearson_top200_hvg': 0.993133403820107,
#   'mse_top200_hvg': 0.011814464,
#   'pearson_delta_top200_de': -0.12532941587455756,
#   'pearson_top200_de': 0.9895946213593729,
#   'mse_top200_de': 0.0129051395,
#   'pearson_delta_top100_de': -0.10012980095972374,
#   'pearson_top100_de': 0.9878817661564643,
#   'mse_top100_de': 0.022248881,
#   'pearson_delta_top50_de': -0.14653331088958646,
#   'pearson_top50_de': 0.9674157310068187,
#   'mse_top50_de': 0.038872637},
#  'BPGM+SAMD1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.25,
#   'mean_sigma': 1.0954022,
#   'std_sigma': 0.4031992,
#   'frac_sigma_below_1': 0.5,
#   'frac_sigma_below_2': 0.95,
#   'pearson_delta': 0.17435868690714712,
#   'pearson_delta_de': 0.9290321111219952,
#   'fold_change_gap_all': 0.25626928,
#   'fold_change_gap_upreg_3': 3.5347698,
#   'pearson_delta_top200_hvg': 0.3229635003862163,
#   'pearson_top200_hvg': 0.9360856237868076,
#   'mse_top200_hvg': 0.112264164,
#   'pearson_delta_top200_de': 0.3347646401402943,
#   'pearson_top200_de': 0.9557797390746705,
#   'mse_top200_de': 0.12737489,
#   'pearson_delta_top100_de': 0.420862882034877,
#   'pearson_top100_de': 0.929411547097055,
#   'mse_top100_de': 0.22464126,
#   'pearson_delta_top50_de': 0.4227564306233151,
#   'pearson_top50_de': 0.9045656512460598,
#   'mse_top50_de': 0.37268117},
#  'BPGM+ZBTB1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.05,
#   'frac_in_range_40_60': 0.05,
#   'frac_in_range_25_75': 0.15,
#   'mean_sigma': 1.1398805,
#   'std_sigma': 0.3423165,
#   'frac_sigma_below_1': 0.44999999999999996,
#   'frac_sigma_below_2': 0.95,
#   'pearson_delta': -0.044808153623558236,
#   'pearson_delta_de': 0.8693265597009838,
#   'fold_change_gap_all': 0.36757708,
#   'fold_change_gap_upreg_3': 8.185869,
#   'fold_change_gap_upreg_10': 13.338219,
#   'pearson_delta_top200_hvg': -0.1103807394760262,
#   'pearson_top200_hvg': 0.9346778432019271,
#   'mse_top200_hvg': 0.11677075,
#   'pearson_delta_top200_de': -0.11046274972518404,
#   'pearson_top200_de': 0.9472738835188924,
#   'mse_top200_de': 0.13015744,
#   'pearson_delta_top100_de': -0.15629791199657544,
#   'pearson_top100_de': 0.9171853079917092,
#   'mse_top100_de': 0.23722126,
#   'pearson_delta_top50_de': -0.1280080825766227,
#   'pearson_top50_de': 0.8978972031320721,
#   'mse_top50_de': 0.40843382},
#  'BPGM+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.45,
#   'mean_sigma': 0.78855956,
#   'std_sigma': 0.26054785,
#   'frac_sigma_below_1': 0.85,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.004939928685267911,
#   'pearson_delta_de': 0.963911097520785,
#   'fold_change_gap_all': 0.15960841,
#   'fold_change_gap_upreg_3': 3.655535,
#   'pearson_delta_top200_hvg': 0.009320113558646901,
#   'pearson_top200_hvg': 0.9712363431204014,
#   'mse_top200_hvg': 0.05083976,
#   'pearson_delta_top200_de': 0.06723642663094574,
#   'pearson_top200_de': 0.9761627377374108,
#   'mse_top200_de': 0.05844608,
#   'pearson_delta_top100_de': 0.09217486647701634,
#   'pearson_top100_de': 0.9654074994224506,
#   'mse_top100_de': 0.10732781,
#   'pearson_delta_top50_de': 0.21934978341856948,
#   'pearson_top50_de': 0.9522551896333316,
#   'mse_top50_de': 0.18417467},
#  'C3orf72+FOXL2': {'pearson_delta': -0.07033837555331432,
#   'pearson_delta_de': 0.2847568849052279,
#   'fold_change_gap_all': 0.28824687,
#   'fold_change_gap_upreg_3': 2.6570146,
#   'pearson_delta_top200_hvg': -0.029552555271621792,
#   'pearson_top200_hvg': 0.9508894237054015,
#   'mse_top200_hvg': 0.08547408,
#   'pearson_delta_top200_de': 0.09557168937443515,
#   'pearson_top200_de': 0.5593845994551623,
#   'mse_top200_de': 0.0005805913,
#   'pearson_delta_top100_de': 0.09347906588674147,
#   'pearson_top100_de': 0.5932157990770904,
#   'mse_top100_de': 0.0010285967,
#   'pearson_delta_top50_de': -0.08717532114284748,
#   'pearson_top50_de': 0.5633545016030668,
#   'mse_top50_de': 0.0015828933},
#  'C3orf72+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.46153846153846156,
#   'mean_sigma': 0.8309911,
#   'std_sigma': 0.1770217,
#   'frac_sigma_below_1': 0.7692307692307692,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.009768328412409107,
#   'pearson_delta_de': 0.9906168099498719,
#   'fold_change_gap_all': 0.19899495,
#   'fold_change_gap_upreg_3': 2.7259903,
#   'pearson_delta_top200_hvg': -0.08464305312518663,
#   'pearson_top200_hvg': 0.9678683068080493,
#   'mse_top200_hvg': 0.05491003,
#   'pearson_delta_top200_de': -0.052853962607103906,
#   'pearson_top200_de': 0.9742632189819972,
#   'mse_top200_de': 0.05385419,
#   'pearson_delta_top100_de': 0.046072516060895206,
#   'pearson_top100_de': 0.9730866035281525,
#   'mse_top100_de': 0.07947178,
#   'pearson_delta_top50_de': 0.1562914321254411,
#   'pearson_top50_de': 0.9718201126144381,
#   'mse_top50_de': 0.114593394},
#  'CBL+CNN1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.4155513,
#   'std_sigma': 0.34608772,
#   'frac_sigma_below_1': 0.09999999999999998,
#   'frac_sigma_below_2': 0.95,
#   'pearson_delta': -0.018586411906620547,
#   'pearson_delta_de': 0.6737957957448215,
#   'fold_change_gap_all': 0.50164586,
#   'fold_change_gap_upreg_3': 7.709429,
#   'fold_change_gap_upreg_10': 18.273636,
#   'pearson_delta_top200_hvg': -0.036689617275990925,
#   'pearson_top200_hvg': 0.8629444406023304,
#   'mse_top200_hvg': 0.25987616,
#   'pearson_delta_top200_de': -0.0713504505510572,
#   'pearson_top200_de': 0.8810974531352935,
#   'mse_top200_de': 0.2781316,
#   'pearson_delta_top100_de': -0.11100958265018177,
#   'pearson_top100_de': 0.827695979483223,
#   'mse_top100_de': 0.4870122,
#   'pearson_delta_top50_de': -0.11433696507876936,
#   'pearson_top50_de': 0.6830629706150471,
#   'mse_top50_de': 0.8425698},
#  'CBL+PTPN12': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.05,
#   'mean_sigma': 1.2425215,
#   'std_sigma': 0.388975,
#   'frac_sigma_below_1': 0.30000000000000004,
#   'frac_sigma_below_2': 0.95,
#   'pearson_delta': -0.03406889269471002,
#   'pearson_delta_de': 0.8227962892794214,
#   'fold_change_gap_all': 0.29469052,
#   'fold_change_gap_upreg_3': 6.048545,
#   'fold_change_gap_upreg_10': 11.571286,
#   'pearson_delta_top200_hvg': -0.05894103807343091,
#   'pearson_top200_hvg': 0.9174475872877638,
#   'mse_top200_hvg': 0.15585653,
#   'pearson_delta_top200_de': -0.05312472888081999,
#   'pearson_top200_de': 0.9171197696988057,
#   'mse_top200_de': 0.16440275,
#   'pearson_delta_top100_de': -0.06606574192374758,
#   'pearson_top100_de': 0.8782093970552396,
#   'mse_top100_de': 0.2834482,
#   'pearson_delta_top50_de': -0.09900137915489197,
#   'pearson_top50_de': 0.818306431063828,
#   'mse_top50_de': 0.491591},
#  'CBL+PTPN9': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.15,
#   'mean_sigma': 1.0177538,
#   'std_sigma': 0.270223,
#   'frac_sigma_below_1': 0.7,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.21481632552144223,
#   'pearson_delta_de': 0.9154553814079581,
#   'fold_change_gap_all': 0.24161932,
#   'fold_change_gap_upreg_3': 4.1724133,
#   'pearson_delta_top200_hvg': -0.2985261732657365,
#   'pearson_top200_hvg': 0.9327292634248333,
#   'mse_top200_hvg': 0.12275789,
#   'pearson_delta_top200_de': -0.377906262268057,
#   'pearson_top200_de': 0.9497706963585167,
#   'mse_top200_de': 0.1279267,
#   'pearson_delta_top100_de': -0.42640709857949294,
#   'pearson_top100_de': 0.9220703024332398,
#   'mse_top100_de': 0.2129025,
#   'pearson_delta_top50_de': -0.44760587267957735,
#   'pearson_top50_de': 0.8692518175688679,
#   'mse_top50_de': 0.35181415},
#  'CBL+TGFBR2': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.1991212,
#   'std_sigma': 0.35478437,
#   'frac_sigma_below_1': 0.4444444444444444,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.0278802084596687,
#   'pearson_delta_de': 0.9129441041378883,
#   'fold_change_gap_all': 0.15472198,
#   'fold_change_gap_upreg_3': 4.100296,
#   'pearson_delta_top200_hvg': 0.03224004609391092,
#   'pearson_top200_hvg': 0.9537340194301828,
#   'mse_top200_hvg': 0.08130972,
#   'pearson_delta_top200_de': -0.11400654571053762,
#   'pearson_top200_de': 0.9332877837033929,
#   'mse_top200_de': 0.0682822,
#   'pearson_delta_top100_de': -0.13433638477567297,
#   'pearson_top100_de': 0.900258220299865,
#   'mse_top100_de': 0.119666375,
#   'pearson_delta_top50_de': -0.21849903235930748,
#   'pearson_top50_de': 0.8847055033121543,
#   'mse_top50_de': 0.2214532},
#  'CBL+UBASH3A': {'pearson_delta': -0.08431510555180527,
#   'pearson_delta_de': 0.4583515834062745,
#   'fold_change_gap_all': 0.25400758,
#   'fold_change_gap_upreg_3': 4.861645,
#   'pearson_delta_top200_hvg': -0.08796922136998359,
#   'pearson_top200_hvg': 0.9357806890535127,
#   'mse_top200_hvg': 0.11541358,
#   'pearson_delta_top200_de': 0.1974126453575786,
#   'pearson_top200_de': 0.9933282463149123,
#   'mse_top200_de': 0.03273693,
#   'pearson_delta_top100_de': -0.1588348630605827,
#   'pearson_top100_de': 0,
#   'mse_top100_de': 0.00092554017,
#   'pearson_delta_top50_de': -0.11485242408534671,
#   'pearson_top50_de': 0,
#   'mse_top50_de': 0.0016461536},
#  'CBL+UBASH3B': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.3294954,
#   'std_sigma': 0.42628455,
#   'frac_sigma_below_1': 0.1578947368421053,
#   'frac_sigma_below_2': 0.8947368421052632,
#   'pearson_delta': 0.11310992672146933,
#   'pearson_delta_de': 0.787521013494482,
#   'fold_change_gap_all': 0.3474251,
#   'fold_change_gap_upreg_3': 6.1336417,
#   'fold_change_gap_upreg_10': 9.579042,
#   'pearson_delta_top200_hvg': 0.19998516364403043,
#   'pearson_top200_hvg': 0.8890815147160968,
#   'mse_top200_hvg': 0.20502383,
#   'pearson_delta_top200_de': 0.180635329219374,
#   'pearson_top200_de': 0.9146128309377726,
#   'mse_top200_de': 0.22194844,
#   'pearson_delta_top100_de': 0.1970437818306687,
#   'pearson_top100_de': 0.8604296264547967,
#   'mse_top100_de': 0.38618827,
#   'pearson_delta_top50_de': 0.3254611233861407,
#   'pearson_top50_de': 0.8023769517211339,
#   'mse_top50_de': 0.6282353},
#  'CBL+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.05,
#   'frac_in_range_40_60': 0.15,
#   'frac_in_range_25_75': 0.6,
#   'mean_sigma': 0.68112457,
#   'std_sigma': 0.34528083,
#   'frac_sigma_below_1': 0.9,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.08836596988944548,
#   'pearson_delta_de': 0.8132288724436697,
#   'fold_change_gap_all': 0.10850863,
#   'fold_change_gap_upreg_3': 2.560476,
#   'pearson_delta_top200_hvg': 0.10002640113014818,
#   'pearson_top200_hvg': 0.9778280324078886,
#   'mse_top200_hvg': 0.038540095,
#   'pearson_delta_top200_de': 0.1203405185193631,
#   'pearson_top200_de': 0.9818143815310376,
#   'mse_top200_de': 0.040645532,
#   'pearson_delta_top100_de': 0.15204036862179224,
#   'pearson_top100_de': 0.9745980273118711,
#   'mse_top100_de': 0.0722066,
#   'pearson_delta_top50_de': 0.1588647942061057,
#   'pearson_top50_de': 0.9556710033397667,
#   'mse_top50_de': 0.12474441},
#  'CDKN1A+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.25,
#   'mean_sigma': 0.94837517,
#   'std_sigma': 0.085157335,
#   'frac_sigma_below_1': 0.5,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.04716088037142192,
#   'pearson_delta_de': 0.9751978467130946,
#   'fold_change_gap_all': 0.5156805,
#   'fold_change_gap_upreg_3': 53.641956,
#   'fold_change_gap_upreg_10': 103.79105,
#   'pearson_delta_top200_hvg': 0.046838474574439085,
#   'pearson_top200_hvg': 0.9691874887224072,
#   'mse_top200_hvg': 0.054777905,
#   'pearson_delta_top200_de': 0.04134461580913302,
#   'pearson_top200_de': 0.975615335707152,
#   'mse_top200_de': 0.05322051,
#   'pearson_delta_top100_de': -0.015869679445925117,
#   'pearson_top100_de': 0.9662238459698376,
#   'mse_top100_de': 0.08632292,
#   'pearson_delta_top50_de': -0.1946965007144347,
#   'pearson_top50_de': 0.9575371352487148,
#   'mse_top50_de': 0.11709749},
#  'CDKN1B+CDKN1A': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.1510419,
#   'std_sigma': 0.046067555,
#   'frac_sigma_below_1': 0.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.22128050785818415,
#   'pearson_delta_de': 0.9621101410531752,
#   'fold_change_gap_all': 0.62415713,
#   'fold_change_gap_upreg_3': 25.619446,
#   'fold_change_gap_upreg_10': 116.052124,
#   'pearson_delta_top200_hvg': 0.21787993274703887,
#   'pearson_top200_hvg': 0.9451765303311961,
#   'mse_top200_hvg': 0.09279671,
#   'pearson_delta_top200_de': 0.3636903223399186,
#   'pearson_top200_de': 0.9553251219042036,
#   'mse_top200_de': 0.093523405,
#   'pearson_delta_top100_de': 0.30209985393019406,
#   'pearson_top100_de': 0.9434716849441221,
#   'mse_top100_de': 0.1482442,
#   'pearson_delta_top50_de': 0.018166875603365235,
#   'pearson_top50_de': 0.930679018525236,
#   'mse_top50_de': 0.16299824},
#  'CDKN1B+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0625,
#   'frac_in_range_40_60': 0.1875,
#   'frac_in_range_25_75': 0.9375,
#   'mean_sigma': 0.5988986,
#   'std_sigma': 0.06793094,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.07011807587205372,
#   'pearson_delta_de': 0.9684567488085516,
#   'fold_change_gap_all': 0.17444298,
#   'fold_change_gap_upreg_3': 4.796601,
#   'pearson_delta_top200_hvg': 0.022175261341874614,
#   'pearson_top200_hvg': 0.9759697650272081,
#   'mse_top200_hvg': 0.04388421,
#   'pearson_delta_top200_de': -0.0897601937131003,
#   'pearson_top200_de': 0.9795564410320505,
#   'mse_top200_de': 0.0530688,
#   'pearson_delta_top100_de': -0.0817955821324435,
#   'pearson_top100_de': 0.9727272123889149,
#   'mse_top100_de': 0.085523665,
#   'pearson_delta_top50_de': 0.01236741330523565,
#   'pearson_top50_de': 0.9484687630255194,
#   'mse_top50_de': 0.13515452},
#  'CDKN1C+CDKN1A': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.4432176,
#   'std_sigma': 0.10074245,
#   'frac_sigma_below_1': 0.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.0009568469577057046,
#   'pearson_delta_de': 0.9443868004392533,
#   'fold_change_gap_all': 0.63165826,
#   'fold_change_gap_upreg_3': 30.510885,
#   'fold_change_gap_upreg_10': 110.610886,
#   'pearson_delta_top200_hvg': -0.11432161953341267,
#   'pearson_top200_hvg': 0.9325170192826937,
#   'mse_top200_hvg': 0.1129245,
#   'pearson_delta_top200_de': -0.129667795596267,
#   'pearson_top200_de': 0.9383223666384716,
#   'mse_top200_de': 0.1090498,
#   'pearson_delta_top100_de': -0.3017397992342604,
#   'pearson_top100_de': 0.9100637561732864,
#   'mse_top100_de': 0.17080788,
#   'pearson_delta_top50_de': -0.54083712613515,
#   'pearson_top50_de': 0.9141286253575058,
#   'mse_top50_de': 0.21200332},
#  'CDKN1C+CDKN1B': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.2021115,
#   'std_sigma': 0.024034519,
#   'frac_sigma_below_1': 0.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.031844596552290425,
#   'pearson_delta_de': 0.9584312388874916,
#   'fold_change_gap_all': 0.2550558,
#   'fold_change_gap_upreg_3': 6.2026105,
#   'pearson_delta_top200_hvg': -0.07961081729799833,
#   'pearson_top200_hvg': 0.9459117968777055,
#   'mse_top200_hvg': 0.092032395,
#   'pearson_delta_top200_de': -0.18342211024828833,
#   'pearson_top200_de': 0.9408911986616739,
#   'mse_top200_de': 0.084878504,
#   'pearson_delta_top100_de': -0.3754399312708573,
#   'pearson_top100_de': 0.9242369290166614,
#   'mse_top100_de': 0.12730855,
#   'pearson_delta_top50_de': -0.4437477001046426,
#   'pearson_top50_de': 0.9300948888370142,
#   'mse_top50_de': 0.11528963},
#  'CDKN1C+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.3888888888888889,
#   'mean_sigma': 0.7712645,
#   'std_sigma': 0.09875058,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.06448825612851634,
#   'pearson_delta_de': 0.9718761592914799,
#   'fold_change_gap_all': 0.18195496,
#   'fold_change_gap_upreg_3': 4.024134,
#   'pearson_delta_top200_hvg': -0.17110610347709282,
#   'pearson_top200_hvg': 0.9649609891124539,
#   'mse_top200_hvg': 0.06017026,
#   'pearson_delta_top200_de': -0.18884075743903433,
#   'pearson_top200_de': 0.9723692364004738,
#   'mse_top200_de': 0.070511654,
#   'pearson_delta_top100_de': -0.3350544092150583,
#   'pearson_top100_de': 0.96074321957469,
#   'mse_top100_de': 0.122299284,
#   'pearson_delta_top50_de': -0.3634674761104032,
#   'pearson_top50_de': 0.9579874808022943,
#   'mse_top50_de': 0.1785519},
#  'CEBPB+CEBPA': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.6284161,
#   'std_sigma': 0.1580948,
#   'frac_sigma_below_1': 0.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.03368116857668563,
#   'pearson_delta_de': 0.38667390291770803,
#   'fold_change_gap_all': 13.662387,
#   'fold_change_gap_upreg_3': 72.69431,
#   'fold_change_gap_upreg_10': 190.16483,
#   'pearson_delta_top200_hvg': -0.10061766317754921,
#   'pearson_top200_hvg': 0.670908774812034,
#   'mse_top200_hvg': 0.5950995,
#   'pearson_delta_top200_de': -0.2448605827137607,
#   'pearson_top200_de': 0.7757096534814096,
#   'mse_top200_de': 0.4445887,
#   'pearson_delta_top100_de': -0.1991444177579555,
#   'pearson_top100_de': 0.7156213194227816,
#   'mse_top100_de': 0.5330877,
#   'pearson_delta_top50_de': -0.14657695916174776,
#   'pearson_top50_de': 0.7266255753363408,
#   'mse_top50_de': 0.39279887},
#  'CEBPB+MAPK1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.15,
#   'mean_sigma': 1.4908026,
#   'std_sigma': 0.37172428,
#   'frac_sigma_below_1': 0.0,
#   'frac_sigma_below_2': 0.9,
#   'pearson_delta': -0.0952840650224675,
#   'pearson_delta_de': 0.8143739522922935,
#   'fold_change_gap_all': 0.50724906,
#   'fold_change_gap_downreg_0.33': 0.72009265,
#   'fold_change_gap_upreg_3': 5.7701507,
#   'fold_change_gap_upreg_10': 11.765443,
#   'pearson_delta_top200_hvg': -0.1996913112381662,
#   'pearson_top200_hvg': 0.9036675229131323,
#   'mse_top200_hvg': 0.16516499,
#   'pearson_delta_top200_de': -0.21908776194360471,
#   'pearson_top200_de': 0.9078730369848055,
#   'mse_top200_de': 0.18340458,
#   'pearson_delta_top100_de': -0.19873633788539527,
#   'pearson_top100_de': 0.8725267159704659,
#   'mse_top100_de': 0.30873886,
#   'pearson_delta_top50_de': -0.3300258246265905,
#   'pearson_top50_de': 0.8197219317021467,
#   'mse_top50_de': 0.49318752},
#  'CEBPB+OSR2': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.17647058823529413,
#   'mean_sigma': 1.1183734,
#   'std_sigma': 0.12919374,
#   'frac_sigma_below_1': 0.11764705882352944,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.021721906100065733,
#   'pearson_delta_de': 0.8858782469325867,
#   'fold_change_gap_all': 0.6802015,
#   'fold_change_gap_upreg_3': 6.556555,
#   'fold_change_gap_upreg_10': 13.641894,
#   'pearson_delta_top200_hvg': 0.04538326558048564,
#   'pearson_top200_hvg': 0.8833810679760613,
#   'mse_top200_hvg': 0.19681923,
#   'pearson_delta_top200_de': 0.030422210620853554,
#   'pearson_top200_de': 0.9051586425214325,
#   'mse_top200_de': 0.20726867,
#   'pearson_delta_top100_de': 0.0027269334603800747,
#   'pearson_top100_de': 0.8631037174440152,
#   'mse_top100_de': 0.32969594,
#   'pearson_delta_top50_de': 0.12584866681624368,
#   'pearson_top50_de': 0.8056848882908929,
#   'mse_top50_de': 0.49692926},
#  'CEBPB+PTPN12': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.05263157894736842,
#   'frac_in_range_40_60': 0.05263157894736842,
#   'frac_in_range_25_75': 0.47368421052631576,
#   'mean_sigma': 0.86119574,
#   'std_sigma': 0.21214926,
#   'frac_sigma_below_1': 0.8421052631578947,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.11465994942990633,
#   'pearson_delta_de': 0.9655804443765093,
#   'fold_change_gap_all': 5.373087,
#   'fold_change_gap_upreg_3': 517.7497,
#   'fold_change_gap_upreg_10': 1543.3842,
#   'pearson_delta_top200_hvg': -0.19265296057690784,
#   'pearson_top200_hvg': 0.9584148975666855,
#   'mse_top200_hvg': 0.070480645,
#   'pearson_delta_top200_de': -0.23294118907072403,
#   'pearson_top200_de': 0.9597598322011814,
#   'mse_top200_de': 0.076719195,
#   'pearson_delta_top100_de': -0.2464105400668254,
#   'pearson_top100_de': 0.9410447106787989,
#   'mse_top100_de': 0.1337056,
#   'pearson_delta_top50_de': -0.3135780634896508,
#   'pearson_top50_de': 0.9228397527565114,
#   'mse_top50_de': 0.21278806},
#  'CEBPB+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.1,
#   'frac_in_range_40_60': 0.15,
#   'frac_in_range_25_75': 0.35,
#   'mean_sigma': 0.9894993,
#   'std_sigma': 0.16890374,
#   'frac_sigma_below_1': 0.55,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.0589325355753263,
#   'pearson_delta_de': 0.9240113987691351,
#   'fold_change_gap_all': 5.469675,
#   'fold_change_gap_upreg_3': 117.99323,
#   'fold_change_gap_upreg_10': 533.20685,
#   'pearson_delta_top200_hvg': 0.07684196979810358,
#   'pearson_top200_hvg': 0.9188530078014621,
#   'mse_top200_hvg': 0.13530125,
#   'pearson_delta_top200_de': 0.0835203042445002,
#   'pearson_top200_de': 0.9248056055008173,
#   'mse_top200_de': 0.14679499,
#   'pearson_delta_top100_de': 0.003985432779434974,
#   'pearson_top100_de': 0.8768769373093654,
#   'mse_top100_de': 0.24014549,
#   'pearson_delta_top50_de': -0.022809609411919646,
#   'pearson_top50_de': 0.8637713353217995,
#   'mse_top50_de': 0.35995373},
#  'CEBPE+CEBPB': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.4835086,
#   'std_sigma': 0.19553274,
#   'frac_sigma_below_1': 0.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.022183324749565757,
#   'pearson_delta_de': 0.30326980706714457,
#   'fold_change_gap_all': 2.7833989,
#   'fold_change_gap_upreg_3': 20.13887,
#   'fold_change_gap_upreg_10': 53.190025,
#   'pearson_delta_top200_hvg': -0.04494382826710679,
#   'pearson_top200_hvg': 0.768822676360036,
#   'mse_top200_hvg': 0.3881852,
#   'pearson_delta_top200_de': -0.1302432583051938,
#   'pearson_top200_de': 0.8427277386205236,
#   'mse_top200_de': 0.35057434,
#   'pearson_delta_top100_de': -0.07540651195736793,
#   'pearson_top100_de': 0.7811348716381527,
#   'mse_top100_de': 0.5021149,
#   'pearson_delta_top50_de': 0.002927816879065064,
#   'pearson_top50_de': 0.7193423248302748,
#   'mse_top50_de': 0.6544244},
#  'CEBPE+PTPN12': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.05,
#   'frac_in_range_40_60': 0.2,
#   'frac_in_range_25_75': 0.7,
#   'mean_sigma': 0.7197536,
#   'std_sigma': 0.23819372,
#   'frac_sigma_below_1': 0.95,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.03708591400463163,
#   'pearson_delta_de': 0.9721808191328806,
#   'fold_change_gap_all': 0.40458956,
#   'fold_change_gap_upreg_3': 40.06523,
#   'fold_change_gap_upreg_10': 74.9691,
#   'pearson_delta_top200_hvg': -0.10595718960955348,
#   'pearson_top200_hvg': 0.9733664200840375,
#   'mse_top200_hvg': 0.045343112,
#   'pearson_delta_top200_de': -0.04472610371746663,
#   'pearson_top200_de': 0.9788680955809028,
#   'mse_top200_de': 0.046954654,
#   'pearson_delta_top100_de': -0.05503174831647137,
#   'pearson_top100_de': 0.9673682200394171,
#   'mse_top100_de': 0.08015748,
#   'pearson_delta_top50_de': 0.005849321562876839,
#   'pearson_top50_de': 0.9615078107486477,
#   'mse_top50_de': 0.1270443},
#  'CEBPE+RUNX1T1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.05,
#   'frac_in_range_40_60': 0.1,
#   'frac_in_range_25_75': 0.25,
#   'mean_sigma': 0.85669154,
#   'std_sigma': 0.19415261,
#   'frac_sigma_below_1': 0.85,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.013895107435054318,
#   'pearson_delta_de': 0.9294725918103164,
#   'fold_change_gap_all': 0.464644,
#   'fold_change_gap_upreg_3': 23.497538,
#   'fold_change_gap_upreg_10': 76.24621,
#   'pearson_delta_top200_hvg': 0.05049425265379021,
#   'pearson_top200_hvg': 0.9591313325786897,
#   'mse_top200_hvg': 0.069885805,
#   'pearson_delta_top200_de': 0.009284515983761558,
#   'pearson_top200_de': 0.9619954153663474,
#   'mse_top200_de': 0.07592927,
#   'pearson_delta_top100_de': -0.011659143348358011,
#   'pearson_top100_de': 0.9345590246269299,
#   'mse_top100_de': 0.1299098,
#   'pearson_delta_top50_de': -0.15210755994930972,
#   'pearson_top50_de': 0.8975020342520129,
#   'mse_top50_de': 0.20795254},
#  'CEBPE+SPI1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.7907249,
#   'std_sigma': 0.3923845,
#   'frac_sigma_below_1': 0.0,
#   'frac_sigma_below_2': 0.8421052631578947,
#   'pearson_delta': -0.08662440958304382,
#   'pearson_delta_de': 0.5878472072030849,
#   'fold_change_gap_all': 7.844966,
#   'fold_change_gap_downreg_0.33': 0.6860262,
#   'fold_change_gap_upreg_3': 57.3746,
#   'fold_change_gap_upreg_10': 153.69293,
#   'pearson_delta_top200_hvg': -0.14506517117437384,
#   'pearson_top200_hvg': 0.7117989742116081,
#   'mse_top200_hvg': 0.49722308,
#   'pearson_delta_top200_de': -0.20441770378663676,
#   'pearson_top200_de': 0.7532777161170252,
#   'mse_top200_de': 0.528661,
#   'pearson_delta_top100_de': -0.18588036251197781,
#   'pearson_top100_de': 0.7030356579097174,
#   'mse_top100_de': 0.7977431,
#   'pearson_delta_top50_de': -0.23811460639916524,
#   'pearson_top50_de': 0.6640400691218064,
#   'mse_top50_de': 1.0733839},
#  'CELF2+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.15789473684210525,
#   'frac_in_range_25_75': 0.8947368421052632,
#   'mean_sigma': 0.5607717,
#   'std_sigma': 0.38738427,
#   'frac_sigma_below_1': 0.9473684210526316,
#   'frac_sigma_below_2': 0.9473684210526316,
#   'pearson_delta': 0.05367530035532033,
#   'pearson_delta_de': 0.9763534849484967,
#   'fold_change_gap_all': 0.10655648,
#   'fold_change_gap_upreg_3': 4.5325546,
#   'pearson_delta_top200_hvg': 0.16257864701326044,
#   'pearson_top200_hvg': 0.9895146739108849,
#   'mse_top200_hvg': 0.018565962,
#   'pearson_delta_top200_de': 0.21396832832902404,
#   'pearson_top200_de': 0.9841782947188934,
#   'mse_top200_de': 0.023552468,
#   'pearson_delta_top100_de': 0.21286905617982554,
#   'pearson_top100_de': 0.9782132501523951,
#   'mse_top100_de': 0.042161714,
#   'pearson_delta_top50_de': 0.18445474275619403,
#   'pearson_top50_de': 0.9679382742820832,
#   'mse_top50_de': 0.07153234},
#  'CKS1B+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.06666666666666667,
#   'frac_in_range_40_60': 0.13333333333333333,
#   'frac_in_range_25_75': 0.26666666666666666,
#   'mean_sigma': 0.96964085,
#   'std_sigma': 0.2586459,
#   'frac_sigma_below_1': 0.6666666666666667,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.014407083543251265,
#   'pearson_delta_de': 0.9588727780351238,
#   'fold_change_gap_all': 0.28443313,
#   'fold_change_gap_upreg_3': 5.1322684,
#   'fold_change_gap_upreg_10': 15.264192,
#   'pearson_delta_top200_hvg': 0.06728528559269337,
#   'pearson_top200_hvg': 0.9689642933037568,
#   'mse_top200_hvg': 0.05487196,
#   'pearson_delta_top200_de': 0.04150231970483644,
#   'pearson_top200_de': 0.966274631475108,
#   'mse_top200_de': 0.07236916,
#   'pearson_delta_top100_de': 0.1298550826479159,
#   'pearson_top100_de': 0.9595948502305135,
#   'mse_top100_de': 0.11611306,
#   'pearson_delta_top50_de': 0.34677865854162937,
#   'pearson_top50_de': 0.9583440581726429,
#   'mse_top50_de': 0.17337894},
#  'CNN1+MAPK1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.1,
#   'frac_in_range_40_60': 0.15,
#   'frac_in_range_25_75': 0.3,
#   'mean_sigma': 0.80725014,
#   'std_sigma': 0.18231414,
#   'frac_sigma_below_1': 0.85,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.031215952718442963,
#   'pearson_delta_de': 0.9191989366688195,
#   'fold_change_gap_all': 0.21748646,
#   'fold_change_gap_upreg_3': 7.557795,
#   'fold_change_gap_upreg_10': 14.191942,
#   'pearson_delta_top200_hvg': -0.03567342837390627,
#   'pearson_top200_hvg': 0.9728314973962507,
#   'mse_top200_hvg': 0.046111144,
#   'pearson_delta_top200_de': 0.0335156418456804,
#   'pearson_top200_de': 0.9672153933342491,
#   'mse_top200_de': 0.05360713,
#   'pearson_delta_top100_de': -0.016350196367663522,
#   'pearson_top100_de': 0.950382075759052,
#   'mse_top100_de': 0.09224753,
#   'pearson_delta_top50_de': -0.022095613422159925,
#   'pearson_top50_de': 0.9248068688937063,
#   'mse_top50_de': 0.14621529},
#  'CNN1+UBASH3A': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.2572662,
#   'std_sigma': 0.22232988,
#   'frac_sigma_below_1': 0.1428571428571429,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.09180672905734064,
#   'pearson_delta_de': 0.9194705243520218,
#   'fold_change_gap_all': 0.47098333,
#   'fold_change_gap_upreg_3': 7.5675473,
#   'fold_change_gap_upreg_10': 14.288805,
#   'pearson_delta_top200_hvg': -0.15247811988576968,
#   'pearson_top200_hvg': 0.8670370906451462,
#   'mse_top200_hvg': 0.24873036,
#   'pearson_delta_top200_de': -0.1495831439682842,
#   'pearson_top200_de': 0.9034406946768602,
#   'mse_top200_de': 0.24552917,
#   'pearson_delta_top100_de': -0.2500564214443559,
#   'pearson_top100_de': 0.8511382619235724,
#   'mse_top100_de': 0.42228854,
#   'pearson_delta_top50_de': -0.2149533099155428,
#   'pearson_top50_de': 0.7491798975842122,
#   'mse_top50_de': 0.70306814},
#  'COL2A1+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.1,
#   'frac_in_range_25_75': 0.15,
#   'mean_sigma': 1.0047721,
#   'std_sigma': 0.46310154,
#   'frac_sigma_below_1': 0.8,
#   'frac_sigma_below_2': 0.95,
#   'pearson_delta': -0.10929849437373608,
#   'pearson_delta_de': 0.7357629531711699,
#   'fold_change_gap_all': 0.28411004,
#   'fold_change_gap_upreg_3': 5.576633,
#   'pearson_delta_top200_hvg': -0.14739524930111417,
#   'pearson_top200_hvg': 0.9482914592782958,
#   'mse_top200_hvg': 0.08784339,
#   'pearson_delta_top200_de': -0.20029168177174403,
#   'pearson_top200_de': 0.9546303392433318,
#   'mse_top200_de': 0.10555319,
#   'pearson_delta_top100_de': -0.18054280768028907,
#   'pearson_top100_de': 0.9423376300545561,
#   'mse_top100_de': 0.1798787,
#   'pearson_delta_top50_de': -0.28480142997872315,
#   'pearson_top50_de': 0.8830994178523696,
#   'mse_top50_de': 0.30292213},
#  'DUSP9+ETS2': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.05,
#   'frac_in_range_40_60': 0.05,
#   'frac_in_range_25_75': 0.15,
#   'mean_sigma': 0.98595726,
#   'std_sigma': 0.31633654,
#   'frac_sigma_below_1': 0.65,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.06711767774777223,
#   'pearson_delta_de': 0.9330681318230383,
#   'fold_change_gap_all': 0.26679808,
#   'fold_change_gap_upreg_3': 14.380399,
#   'fold_change_gap_upreg_10': 23.966026,
#   'pearson_delta_top200_hvg': -0.07756545771281852,
#   'pearson_top200_hvg': 0.953355317574747,
#   'mse_top200_hvg': 0.08131432,
#   'pearson_delta_top200_de': -0.12609535353087262,
#   'pearson_top200_de': 0.9631791266719992,
#   'mse_top200_de': 0.09542622,
#   'pearson_delta_top100_de': -0.1612452434876551,
#   'pearson_top100_de': 0.9376344519743627,
#   'mse_top100_de': 0.16691908,
#   'pearson_delta_top50_de': -0.21717638897705357,
#   'pearson_top50_de': 0.9128138535796251,
#   'mse_top50_de': 0.2734734},
#  'DUSP9+IGDCC3': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.408221,
#   'std_sigma': 0.3964353,
#   'frac_sigma_below_1': 0.19999999999999996,
#   'frac_sigma_below_2': 0.9,
#   'pearson_delta': 0.0782763825403151,
#   'pearson_delta_de': 0.8585412894557538,
#   'fold_change_gap_all': 0.551672,
#   'fold_change_gap_upreg_3': 12.945669,
#   'fold_change_gap_upreg_10': 24.856527,
#   'pearson_delta_top200_hvg': 0.08026078155657015,
#   'pearson_top200_hvg': 0.8988429976587006,
#   'mse_top200_hvg': 0.17542669,
#   'pearson_delta_top200_de': 0.07594110715382325,
#   'pearson_top200_de': 0.913644372254256,
#   'mse_top200_de': 0.19772926,
#   'pearson_delta_top100_de': 0.1110165098535781,
#   'pearson_top100_de': 0.8682110932828548,
#   'mse_top100_de': 0.33937064,
#   'pearson_delta_top50_de': 0.1270440570504291,
#   'pearson_top50_de': 0.7376092699757972,
#   'mse_top50_de': 0.5469174},
#  'DUSP9+KLF1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.8362343,
#   'std_sigma': 0.5565357,
#   'frac_sigma_below_1': 0.0,
#   'frac_sigma_below_2': 0.7,
#   'pearson_delta': -0.013430003061161691,
#   'pearson_delta_de': 0.8212974548349504,
#   'fold_change_gap_all': 0.6012358,
#   'fold_change_gap_upreg_3': 10.004989,
#   'fold_change_gap_upreg_10': 25.788424,
#   'pearson_delta_top200_hvg': -0.08581279545339883,
#   'pearson_top200_hvg': 0.888221879184989,
#   'mse_top200_hvg': 0.21161596,
#   'pearson_delta_top200_de': 0.017686572197156185,
#   'pearson_top200_de': 0.9133919453730751,
#   'mse_top200_de': 0.23994233,
#   'pearson_delta_top100_de': -0.024665209903372592,
#   'pearson_top100_de': 0.8678605437655431,
#   'mse_top100_de': 0.44071522,
#   'pearson_delta_top50_de': -0.06625866608739371,
#   'pearson_top50_de': 0.7841038326082466,
#   'mse_top50_de': 0.7527839},
#  'DUSP9+MAPK1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0625,
#   'frac_in_range_25_75': 0.4375,
#   'mean_sigma': 0.8501344,
#   'std_sigma': 0.3335089,
#   'frac_sigma_below_1': 0.875,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.04785242674659013,
#   'pearson_delta_de': 0.9229511322257486,
#   'fold_change_gap_all': 0.21403125,
#   'fold_change_gap_upreg_3': 14.716495,
#   'fold_change_gap_upreg_10': 23.325987,
#   'pearson_delta_top200_hvg': -0.13325278823203102,
#   'pearson_top200_hvg': 0.9804038765530101,
#   'mse_top200_hvg': 0.034009885,
#   'pearson_delta_top200_de': -0.08642806264280738,
#   'pearson_top200_de': 0.9814315166960754,
#   'mse_top200_de': 0.03490664,
#   'pearson_delta_top100_de': -0.02497404283462389,
#   'pearson_top100_de': 0.9771281021508821,
#   'mse_top100_de': 0.05998011,
#   'pearson_delta_top50_de': 0.09223029667905719,
#   'pearson_top50_de': 0.9553649648120859,
#   'mse_top50_de': 0.10374243},
#  'DUSP9+PRTG': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.711072,
#   'std_sigma': 0.55225694,
#   'frac_sigma_below_1': 0.052631578947368474,
#   'frac_sigma_below_2': 0.7894736842105263,
#   'pearson_delta': -0.041153390658625555,
#   'pearson_delta_de': 0.8130769785271367,
#   'fold_change_gap_all': 0.45721772,
#   'fold_change_gap_upreg_3': 8.174527,
#   'fold_change_gap_upreg_10': 15.753649,
#   'pearson_delta_top200_hvg': -0.07680692943962207,
#   'pearson_top200_hvg': 0.8912537683216105,
#   'mse_top200_hvg': 0.19272749,
#   'pearson_delta_top200_de': -0.07897288595924556,
#   'pearson_top200_de': 0.9112071840261594,
#   'mse_top200_de': 0.21847849,
#   'pearson_delta_top100_de': -0.11393144384479247,
#   'pearson_top100_de': 0.8499935172180032,
#   'mse_top100_de': 0.37462953,
#   'pearson_delta_top50_de': -0.1169611923961647,
#   'pearson_top50_de': 0.7267251089791946,
#   'mse_top50_de': 0.60323834},
#  'DUSP9+SNAI1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.05555555555555555,
#   'mean_sigma': 1.3203386,
#   'std_sigma': 0.20441696,
#   'frac_sigma_below_1': 0.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.113017236864006,
#   'pearson_delta_de': 0.9415172581884015,
#   'fold_change_gap_all': 0.6516583,
#   'fold_change_gap_upreg_3': 7.042428,
#   'fold_change_gap_upreg_10': 24.413708,
#   'pearson_delta_top200_hvg': -0.1821359537388221,
#   'pearson_top200_hvg': 0.8790872017257595,
#   'mse_top200_hvg': 0.20653798,
#   'pearson_delta_top200_de': -0.23122620411475603,
#   'pearson_top200_de': 0.8945279564811891,
#   'mse_top200_de': 0.24234863,
#   'pearson_delta_top100_de': -0.28135138012962324,
#   'pearson_top100_de': 0.8698351890449575,
#   'mse_top100_de': 0.37807408,
#   'pearson_delta_top50_de': -0.2000229390542522,
#   'pearson_top50_de': 0.8499201796878161,
#   'mse_top50_de': 0.49670732},
#  'DUSP9+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.2143056,
#   'std_sigma': 0.38379258,
#   'frac_sigma_below_1': 0.4,
#   'frac_sigma_below_2': 0.9,
#   'pearson_delta': -0.004735500413429033,
#   'pearson_delta_de': 0.8649665680524523,
#   'fold_change_gap_all': 0.31586727,
#   'fold_change_gap_upreg_3': 16.193165,
#   'fold_change_gap_upreg_10': 26.728735,
#   'pearson_delta_top200_hvg': 0.026653344413654675,
#   'pearson_top200_hvg': 0.935223079514012,
#   'mse_top200_hvg': 0.11451861,
#   'pearson_delta_top200_de': -0.011600937818498818,
#   'pearson_top200_de': 0.9450175781682879,
#   'mse_top200_de': 0.13379933,
#   'pearson_delta_top100_de': -0.06877194528736363,
#   'pearson_top100_de': 0.9057317511967582,
#   'mse_top100_de': 0.23251337,
#   'pearson_delta_top50_de': -0.09006396496816124,
#   'pearson_top50_de': 0.8457300575524208,
#   'mse_top50_de': 0.39405197},
#  'EGR1+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.6153846153846154,
#   'mean_sigma': 0.6351712,
#   'std_sigma': 0.11336764,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.022915177659206976,
#   'pearson_delta_de': 0.9759838580970706,
#   'fold_change_gap_all': 0.09777378,
#   'pearson_delta_top200_hvg': 0.0021424074688393088,
#   'pearson_top200_hvg': 0.9843595259166411,
#   'mse_top200_hvg': 0.026775517,
#   'pearson_delta_top200_de': 0.10994435363498598,
#   'pearson_top200_de': 0.9906686820996411,
#   'mse_top200_de': 0.023614755,
#   'pearson_delta_top100_de': 0.11534202716534903,
#   'pearson_top100_de': 0.989064618880255,
#   'mse_top100_de': 0.04014142,
#   'pearson_delta_top50_de': 0.12822120036035634,
#   'pearson_top50_de': 0.9831234822009248,
#   'mse_top50_de': 0.06597336},
#  'ETS2+CNN1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.1,
#   'frac_in_range_40_60': 0.1,
#   'frac_in_range_25_75': 0.6,
#   'mean_sigma': 0.6956858,
#   'std_sigma': 0.26999152,
#   'frac_sigma_below_1': 0.9,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.0012949718040162778,
#   'pearson_delta_de': 0.9472322613344636,
#   'fold_change_gap_all': 0.16319546,
#   'fold_change_gap_upreg_3': 16.700474,
#   'fold_change_gap_upreg_10': 16.700474,
#   'pearson_delta_top200_hvg': 0.047069846308481655,
#   'pearson_top200_hvg': 0.9793510950295661,
#   'mse_top200_hvg': 0.035408042,
#   'pearson_delta_top200_de': 0.0001654845014246505,
#   'pearson_top200_de': 0.9803957419160355,
#   'mse_top200_de': 0.041773092,
#   'pearson_delta_top100_de': 0.05512424620743982,
#   'pearson_top100_de': 0.9674402641801673,
#   'mse_top100_de': 0.073640734,
#   'pearson_delta_top50_de': -0.012389044328871664,
#   'pearson_top50_de': 0.925552436650295,
#   'mse_top50_de': 0.12517273},
#  'ETS2+IKZF3': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.1,
#   'mean_sigma': 1.3089765,
#   'std_sigma': 0.2977747,
#   'frac_sigma_below_1': 0.09999999999999998,
#   'frac_sigma_below_2': 0.95,
#   'pearson_delta': 0.1978573953664961,
#   'pearson_delta_de': 0.9073273011808174,
#   'fold_change_gap_all': 0.47772542,
#   'fold_change_gap_upreg_3': 7.841397,
#   'fold_change_gap_upreg_10': 23.94416,
#   'pearson_delta_top200_hvg': 0.2542623960340406,
#   'pearson_top200_hvg': 0.8824636230393494,
#   'mse_top200_hvg': 0.22097282,
#   'pearson_delta_top200_de': 0.3052408545659492,
#   'pearson_top200_de': 0.9062646955134669,
#   'mse_top200_de': 0.24501942,
#   'pearson_delta_top100_de': 0.30136235771488823,
#   'pearson_top100_de': 0.860212224194095,
#   'mse_top100_de': 0.43387803,
#   'pearson_delta_top50_de': 0.4363630703696526,
#   'pearson_top50_de': 0.8064606874129459,
#   'mse_top50_de': 0.75083053},
#  'ETS2+MAP7D1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.05,
#   'mean_sigma': 1.0580854,
#   'std_sigma': 0.18792634,
#   'frac_sigma_below_1': 0.5,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.03645618701744196,
#   'pearson_delta_de': 0.9154555858180072,
#   'fold_change_gap_all': 0.26549128,
#   'fold_change_gap_upreg_3': 4.255249,
#   'pearson_delta_top200_hvg': 0.025750304422981776,
#   'pearson_top200_hvg': 0.9571270341793972,
#   'mse_top200_hvg': 0.07709826,
#   'pearson_delta_top200_de': 0.0019177627882741215,
#   'pearson_top200_de': 0.9609311340304502,
#   'mse_top200_de': 0.0964448,
#   'pearson_delta_top100_de': 0.053131083651447655,
#   'pearson_top100_de': 0.9543183274321323,
#   'mse_top100_de': 0.16544156,
#   'pearson_delta_top50_de': 0.23973776187213885,
#   'pearson_top50_de': 0.9520733429039646,
#   'mse_top50_de': 0.25335518},
#  'ETS2+MAPK1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.05,
#   'mean_sigma': 1.6452742,
#   'std_sigma': 0.39675722,
#   'frac_sigma_below_1': 0.0,
#   'frac_sigma_below_2': 0.8,
#   'pearson_delta': -0.0524610193790298,
#   'pearson_delta_de': 0.7332974798598887,
#   'fold_change_gap_all': 0.67058057,
#   'fold_change_gap_downreg_0.33': 0.672613,
#   'fold_change_gap_upreg_3': 7.419425,
#   'fold_change_gap_upreg_10': 16.24274,
#   'pearson_delta_top200_hvg': -0.0430255379970991,
#   'pearson_top200_hvg': 0.8937293378075548,
#   'mse_top200_hvg': 0.1862916,
#   'pearson_delta_top200_de': -0.10433193010663173,
#   'pearson_top200_de': 0.9045557169976739,
#   'mse_top200_de': 0.22779213,
#   'pearson_delta_top100_de': -0.09024043739172952,
#   'pearson_top100_de': 0.8469230714999222,
#   'mse_top100_de': 0.39025798,
#   'pearson_delta_top50_de': -0.04941249990518682,
#   'pearson_top50_de': 0.6855013133818062,
#   'mse_top50_de': 0.63783455},
#  'FEV+ISL2': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.05,
#   'mean_sigma': 1.419039,
#   'std_sigma': 0.32892773,
#   'frac_sigma_below_1': 0.0,
#   'frac_sigma_below_2': 0.95,
#   'pearson_delta': 0.11261078545089946,
#   'pearson_delta_de': 0.9013454622584331,
#   'fold_change_gap_all': 0.56508774,
#   'fold_change_gap_upreg_3': 7.8342133,
#   'fold_change_gap_upreg_10': 28.12091,
#   'pearson_delta_top200_hvg': 0.1929172843112176,
#   'pearson_top200_hvg': 0.912975223241642,
#   'mse_top200_hvg': 0.15689604,
#   'pearson_delta_top200_de': 0.18868636638594033,
#   'pearson_top200_de': 0.9243088989176593,
#   'mse_top200_de': 0.20431438,
#   'pearson_delta_top100_de': 0.2028067200633578,
#   'pearson_top100_de': 0.8966049686403021,
#   'mse_top100_de': 0.33803108,
#   'pearson_delta_top50_de': 0.2362437888771587,
#   'pearson_top50_de': 0.8885795417340113,
#   'mse_top50_de': 0.49898627},
#  'FEV+MAP7D1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.05555555555555555,
#   'mean_sigma': 1.2597399,
#   'std_sigma': 0.25349775,
#   'frac_sigma_below_1': 0.11111111111111116,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.005826258908745098,
#   'pearson_delta_de': 0.6199991682433561,
#   'fold_change_gap_all': 0.37000257,
#   'fold_change_gap_upreg_3': 6.6501775,
#   'fold_change_gap_upreg_10': 21.287949,
#   'pearson_delta_top200_hvg': -0.005312919668212522,
#   'pearson_top200_hvg': 0.9325188753829114,
#   'mse_top200_hvg': 0.12639314,
#   'pearson_delta_top200_de': 0.06292813633665194,
#   'pearson_top200_de': 0.9478205672185094,
#   'mse_top200_de': 0.15331315,
#   'pearson_delta_top100_de': 0.08637354815232927,
# ...
#   'fold_change_gap_all': 1.4508226,
#   'fold_change_gap_upreg_3': 12.041975,
#   'fold_change_gap_upreg_10': 40.49998,
#   'pearson_delta_top200_hvg': 0.04201183654778113,
#   'pearson_top200_hvg': 0.8241292799989314,
#   'mse_top200_hvg': 0.29724845,
#   'pearson_delta_top200_de': 0.05050529231473601,
#   'pearson_top200_de': 0.8467156316989374,
#   'mse_top200_de': 0.27014527,
#   'pearson_delta_top100_de': -0.021225564924112046,
#   'pearson_top100_de': 0.8548170701958762,
#   'mse_top100_de': 0.30807403,
#   'pearson_delta_top50_de': 0.08806255521326341,
#   'pearson_top50_de': 0.6976142345818956,
#   'mse_top50_de': 0.1192078},
#  'ZBTB10+ELMSAN1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.058823529411764705,
#   'mean_sigma': 0.9928992,
#   'std_sigma': 0.14929345,
#   'frac_sigma_below_1': 0.6470588235294117,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.03327804428741809,
#   'pearson_delta_de': 0.954608926724157,
#   'fold_change_gap_all': 0.3970171,
#   'fold_change_gap_upreg_3': 5.0713525,
#   'pearson_delta_top200_hvg': -0.029541730375073058,
#   'pearson_top200_hvg': 0.9167462519343965,
#   'mse_top200_hvg': 0.14130478,
#   'pearson_delta_top200_de': -0.076143233457605,
#   'pearson_top200_de': 0.9252461411319026,
#   'mse_top200_de': 0.15861009,
#   'pearson_delta_top100_de': 0.05807802977987657,
#   'pearson_top100_de': 0.9177419508138471,
#   'mse_top100_de': 0.23231947,
#   'pearson_delta_top50_de': 0.10840955445397187,
#   'pearson_top50_de': 0.9057107303665229,
#   'mse_top50_de': 0.30709854},
#  'ZBTB10+PTPN12': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.058823529411764705,
#   'frac_in_range_25_75': 0.058823529411764705,
#   'mean_sigma': 1.1659653,
#   'std_sigma': 0.22930157,
#   'frac_sigma_below_1': 0.23529411764705888,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.02071337003061066,
#   'pearson_delta_de': 0.9456189063630865,
#   'fold_change_gap_all': 0.38762072,
#   'fold_change_gap_upreg_3': 40.36953,
#   'fold_change_gap_upreg_10': 40.36953,
#   'pearson_delta_top200_hvg': -0.04512753312362997,
#   'pearson_top200_hvg': 0.9423085922170744,
#   'mse_top200_hvg': 0.10092659,
#   'pearson_delta_top200_de': -0.06208701111015563,
#   'pearson_top200_de': 0.9540108612500323,
#   'mse_top200_de': 0.11495645,
#   'pearson_delta_top100_de': -0.05631337982532434,
#   'pearson_top100_de': 0.9440583880101419,
#   'mse_top100_de': 0.17230536,
#   'pearson_delta_top50_de': -0.1521093855973864,
#   'pearson_top50_de': 0.948104343053801,
#   'mse_top50_de': 0.2410257},
#  'ZBTB10+SNAI1': {'pearson_delta': 0.06066012015645367,
#   'pearson_delta_de': 0.5974458445611649,
#   'fold_change_gap_all': 0.68604183,
#   'fold_change_gap_upreg_3': 4.8501306,
#   'fold_change_gap_upreg_10': 11.418644,
#   'pearson_delta_top200_hvg': 0.11461847288652313,
#   'pearson_top200_hvg': 0.8557133769879992,
#   'mse_top200_hvg': 0.24472958,
#   'pearson_delta_top200_de': 0.12969124431417553,
#   'pearson_top200_de': 0.8719486404388824,
#   'mse_top200_de': 0.21590668,
#   'pearson_delta_top100_de': 0.40918627434001037,
#   'pearson_top100_de': 0.8903138442453028,
#   'mse_top100_de': 0.25059667,
#   'pearson_delta_top50_de': 0.03439638947393581,
#   'pearson_top50_de': 0.8925753154532398,
#   'mse_top50_de': 0.2005699},
#  'ZBTB10+ctrl': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.1,
#   'mean_sigma': 1.0097616,
#   'std_sigma': 0.1485596,
#   'frac_sigma_below_1': 0.6,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.007238525025694741,
#   'pearson_delta_de': 0.9868088442468947,
#   'fold_change_gap_all': 0.2986478,
#   'fold_change_gap_upreg_3': 4.4664373,
#   'pearson_delta_top200_hvg': -0.00999703845191779,
#   'pearson_top200_hvg': 0.9318616803520838,
#   'mse_top200_hvg': 0.11526196,
#   'pearson_delta_top200_de': -0.051619372334554846,
#   'pearson_top200_de': 0.9421735224667492,
#   'mse_top200_de': 0.11386114,
#   'pearson_delta_top100_de': -0.07988259170102939,
#   'pearson_top100_de': 0.9428885185749111,
#   'mse_top100_de': 0.16241044,
#   'pearson_delta_top50_de': -0.18868633307220573,
#   'pearson_top50_de': 0.9414124062140535,
#   'mse_top50_de': 0.20351242},
#  'ZC3HAV1+CEBPE': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.05263157894736842,
#   'frac_in_range_40_60': 0.05263157894736842,
#   'frac_in_range_25_75': 0.47368421052631576,
#   'mean_sigma': 0.7333856,
#   'std_sigma': 0.2377549,
#   'frac_sigma_below_1': 0.8421052631578947,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.02483584200013809,
#   'pearson_delta_de': 0.9353970270689022,
#   'fold_change_gap_all': 0.33484328,
#   'fold_change_gap_upreg_3': 33.305733,
#   'fold_change_gap_upreg_10': 61.268795,
#   'pearson_delta_top200_hvg': 0.024630959596988137,
#   'pearson_top200_hvg': 0.9806120913835928,
#   'mse_top200_hvg': 0.033760596,
#   'pearson_delta_top200_de': 0.015154031477330332,
#   'pearson_top200_de': 0.9835683058061078,
#   'mse_top200_de': 0.03730777,
#   'pearson_delta_top100_de': 0.1257764258838269,
#   'pearson_top100_de': 0.9793579618007368,
#   'mse_top100_de': 0.06442362,
#   'pearson_delta_top50_de': 0.19656518176682572,
#   'pearson_top50_de': 0.9604365441600038,
#   'mse_top50_de': 0.10576266},
#  'ZC3HAV1+HOXC13': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.05,
#   'frac_in_range_40_60': 0.05,
#   'frac_in_range_25_75': 0.5,
#   'mean_sigma': 0.7070878,
#   'std_sigma': 0.19829896,
#   'frac_sigma_below_1': 0.9,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.16615011721782755,
#   'pearson_delta_de': 0.9643959629543022,
#   'fold_change_gap_all': 0.1393789,
#   'pearson_delta_top200_hvg': 0.2623067672752907,
#   'pearson_top200_hvg': 0.9759589074881372,
#   'mse_top200_hvg': 0.041332435,
#   'pearson_delta_top200_de': 0.23865348735523995,
#   'pearson_top200_de': 0.9787151622764801,
#   'mse_top200_de': 0.0548909,
#   'pearson_delta_top100_de': 0.23946446549002792,
#   'pearson_top100_de': 0.9647941026110803,
#   'mse_top100_de': 0.09223166,
#   'pearson_delta_top50_de': 0.325969758433218,
#   'pearson_top50_de': 0.9559549321953791,
#   'mse_top50_de': 0.14043441},
#  'ZNF318+FOXL2': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.07692307692307693,
#   'frac_in_range_25_75': 0.46153846153846156,
#   'mean_sigma': 0.7874507,
#   'std_sigma': 0.12359283,
#   'frac_sigma_below_1': 0.9230769230769231,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.042864707452513424,
#   'pearson_delta_de': 0.9901681001906478,
#   'fold_change_gap_all': 0.15450402,
#   'fold_change_gap_upreg_3': 2.3784976,
#   'pearson_delta_top200_hvg': 0.059127684779106106,
#   'pearson_top200_hvg': 0.9758712077230097,
#   'mse_top200_hvg': 0.0437735,
#   'pearson_delta_top200_de': 0.05387300973632886,
#   'pearson_top200_de': 0.9825868792041527,
#   'mse_top200_de': 0.043807715,
#   'pearson_delta_top100_de': 0.23248931753471533,
#   'pearson_top100_de': 0.9822129679482084,
#   'mse_top100_de': 0.061722122,
#   'pearson_delta_top50_de': 0.42828264633767976,
#   'pearson_top50_de': 0.9793800016572554,
#   'mse_top50_de': 0.08477037},
#  'ctrl+CDKN1A': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.25,
#   'mean_sigma': 0.92737603,
#   'std_sigma': 0.14661904,
#   'frac_sigma_below_1': 0.75,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.09585699654195451,
#   'pearson_delta_de': 0.9366873553120789,
#   'fold_change_gap_all': 0.62546104,
#   'fold_change_gap_upreg_3': 63.60102,
#   'fold_change_gap_upreg_10': 123.440475,
#   'pearson_delta_top200_hvg': 0.0702989870031778,
#   'pearson_top200_hvg': 0.9641810709779114,
#   'mse_top200_hvg': 0.06299641,
#   'pearson_delta_top200_de': 0.14220776953977785,
#   'pearson_top200_de': 0.9750717481124892,
#   'mse_top200_de': 0.06787367,
#   'pearson_delta_top100_de': 0.1362459719511192,
#   'pearson_top100_de': 0.9644508659676541,
#   'mse_top100_de': 0.10820535,
#   'pearson_delta_top50_de': 0.13347993747636216,
#   'pearson_top50_de': 0.9447026718037239,
#   'mse_top50_de': 0.15326661},
#  'ctrl+CDKN1B': {'pearson_delta': 0.050615601861548044,
#   'pearson_delta_de': 0.6048785480724594,
#   'fold_change_gap_all': 0.12493102,
#   'fold_change_gap_upreg_3': 2.0865932,
#   'pearson_delta_top200_hvg': -0.03241816298952656,
#   'pearson_top200_hvg': 0.9842736704664979,
#   'mse_top200_hvg': 0.02916678,
#   'pearson_delta_top200_de': 0.1297121440085446,
#   'pearson_top200_de': 0.9876634381481356,
#   'mse_top200_de': 0.019517042,
#   'pearson_delta_top100_de': -0.013208453383956278,
#   'pearson_top100_de': 0.9829267805535831,
#   'mse_top100_de': 0.022158418,
#   'pearson_delta_top50_de': -0.6991416793666831,
#   'pearson_top50_de': 0.9693087569404344,
#   'mse_top50_de': 0.025116332},
#  'ctrl+CEBPB': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.05,
#   'frac_in_range_40_60': 0.1,
#   'frac_in_range_25_75': 0.25,
#   'mean_sigma': 1.0377121,
#   'std_sigma': 0.17228355,
#   'frac_sigma_below_1': 0.44999999999999996,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.09374610745611985,
#   'pearson_delta_de': 0.9000303718345456,
#   'fold_change_gap_all': 5.5001435,
#   'fold_change_gap_upreg_3': 94.67006,
#   'fold_change_gap_upreg_10': 329.80753,
#   'pearson_delta_top200_hvg': -0.1624490410267197,
#   'pearson_top200_hvg': 0.8996062010061255,
#   'mse_top200_hvg': 0.16864307,
#   'pearson_delta_top200_de': -0.18532422999890033,
#   'pearson_top200_de': 0.9100695415375143,
#   'mse_top200_de': 0.17091763,
#   'pearson_delta_top100_de': -0.13124051573385792,
#   'pearson_top100_de': 0.8701247127964279,
#   'mse_top100_de': 0.26492116,
#   'pearson_delta_top50_de': -0.061885450062165684,
#   'pearson_top50_de': 0.8339221479566769,
#   'mse_top50_de': 0.41161087},
#  'ctrl+COL2A1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.05263157894736842,
#   'frac_in_range_40_60': 0.10526315789473684,
#   'frac_in_range_25_75': 0.21052631578947367,
#   'mean_sigma': 1.0124837,
#   'std_sigma': 0.36063728,
#   'frac_sigma_below_1': 0.631578947368421,
#   'frac_sigma_below_2': 0.9473684210526316,
#   'pearson_delta': -0.06824765623734572,
#   'pearson_delta_de': 0.8342200810030457,
#   'fold_change_gap_all': 0.28568387,
#   'fold_change_gap_upreg_3': 5.0798707,
#   'pearson_delta_top200_hvg': -0.11152138552327033,
#   'pearson_top200_hvg': 0.9496479593151086,
#   'mse_top200_hvg': 0.08560334,
#   'pearson_delta_top200_de': -0.12376594296525281,
#   'pearson_top200_de': 0.9585209147327717,
#   'mse_top200_de': 0.10113892,
#   'pearson_delta_top100_de': -0.15692916522879657,
#   'pearson_top100_de': 0.939005362386138,
#   'mse_top100_de': 0.1758843,
#   'pearson_delta_top50_de': -0.14773070892431636,
#   'pearson_top50_de': 0.925221220677368,
#   'mse_top50_de': 0.29420462},
#  'ctrl+FOXL2': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.15384615384615385,
#   'frac_in_range_40_60': 0.15384615384615385,
#   'frac_in_range_25_75': 0.6153846153846154,
#   'mean_sigma': 0.702207,
#   'std_sigma': 0.1668092,
#   'frac_sigma_below_1': 0.9230769230769231,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.04998995868174866,
#   'pearson_delta_de': 0.9841909777739708,
#   'fold_change_gap_all': 0.16791297,
#   'fold_change_gap_upreg_3': 2.5572798,
#   'pearson_delta_top200_hvg': -0.07387783687477781,
#   'pearson_top200_hvg': 0.9777051051813599,
#   'mse_top200_hvg': 0.03786459,
#   'pearson_delta_top200_de': -0.16394922862581596,
#   'pearson_top200_de': 0.9804292890789318,
#   'mse_top200_de': 0.03696085,
#   'pearson_delta_top100_de': -0.21547786314278777,
#   'pearson_top100_de': 0.9747014923773577,
#   'mse_top100_de': 0.055417296,
#   'pearson_delta_top50_de': -0.24501624814118048,
#   'pearson_top50_de': 0.9709007503983351,
#   'mse_top50_de': 0.07716072},
#  'ctrl+ISL2': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.5,
#   'mean_sigma': 0.56561726,
#   'std_sigma': 0.04373324,
#   'frac_sigma_below_1': 1.0,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': 0.07102283603636633,
#   'pearson_delta_de': 0.9812081131555888,
#   'fold_change_gap_all': 0.0663364,
#   'pearson_delta_top200_hvg': 0.05076164986668523,
#   'pearson_top200_hvg': 0.994889922395664,
#   'mse_top200_hvg': 0.008932613,
#   'pearson_delta_top200_de': 0.07997483136466699,
#   'pearson_top200_de': 0.988655074923764,
#   'mse_top200_de': 0.0044927537,
#   'pearson_delta_top100_de': 0.3695680715162841,
#   'pearson_top100_de': 0.9815573764213054,
#   'mse_top100_de': 0.005961991,
#   'pearson_delta_top50_de': 0.0754320188754559,
#   'pearson_top50_de': 0.9740540717408455,
#   'mse_top50_de': 0.009566482},
#  'ctrl+MAP7D1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.6,
#   'mean_sigma': 0.6814632,
#   'std_sigma': 0.55943346,
#   'frac_sigma_below_1': 0.8,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.02876053828293048,
#   'pearson_delta_de': 0.9877100557557545,
#   'fold_change_gap_all': 0.05937452,
#   'fold_change_gap_upreg_3': 2.3033805,
#   'pearson_delta_top200_hvg': 0.021309951499424416,
#   'pearson_top200_hvg': 0.9978887554702182,
#   'mse_top200_hvg': 0.0043636523,
#   'pearson_delta_top200_de': -0.19189527595968586,
#   'pearson_top200_de': 0.9957420902551746,
#   'mse_top200_de': 0.009431891,
#   'pearson_delta_top100_de': -0.3262541855085968,
#   'pearson_top100_de': 0.993981225390503,
#   'mse_top100_de': 0.016028564,
#   'pearson_delta_top50_de': -0.271844215657574,
#   'pearson_top50_de': 0.9919991010809123,
#   'mse_top50_de': 0.028011577},
#  'ctrl+PTPN12': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.0,
#   'mean_sigma': 1.164915,
#   'std_sigma': 0.24864215,
#   'frac_sigma_below_1': 0.2857142857142857,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.06478146648808335,
#   'pearson_delta_de': 0.9645419155693511,
#   'fold_change_gap_all': 0.12305335,
#   'pearson_delta_top200_hvg': -0.02515380729061892,
#   'pearson_top200_hvg': 0.9754156502210704,
#   'mse_top200_hvg': 0.044785876,
#   'pearson_delta_top200_de': -0.03605248325105809,
#   'pearson_top200_de': 0.9747354666043736,
#   'mse_top200_de': 0.037989177,
#   'pearson_delta_top100_de': 0.03756419581538911,
#   'pearson_top100_de': 0.9617839142171437,
#   'mse_top100_de': 0.06067729,
#   'pearson_delta_top50_de': 0.1830529423638645,
#   'pearson_top50_de': 0.9602810319931208,
#   'mse_top50_de': 0.099284895},
#  'ctrl+SET': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.25,
#   'mean_sigma': 1.0660412,
#   'std_sigma': 0.28142083,
#   'frac_sigma_below_1': 0.5,
#   'frac_sigma_below_2': 0.95,
#   'pearson_delta': 0.027275910655408592,
#   'pearson_delta_de': 0.9497910579676095,
#   'fold_change_gap_all': 0.4369855,
#   'fold_change_gap_upreg_3': 11.5686455,
#   'fold_change_gap_upreg_10': 19.559477,
#   'pearson_delta_top200_hvg': -0.011766103551390437,
#   'pearson_top200_hvg': 0.950947909926551,
#   'mse_top200_hvg': 0.086221546,
#   'pearson_delta_top200_de': 0.0780497508363335,
#   'pearson_top200_de': 0.9535608832328232,
#   'mse_top200_de': 0.108363174,
#   'pearson_delta_top100_de': 0.10552347687618117,
#   'pearson_top100_de': 0.9298337697142547,
#   'mse_top100_de': 0.1815245,
#   'pearson_delta_top50_de': 0.07320755109557843,
#   'pearson_top50_de': 0.9186043122219227,
#   'mse_top50_de': 0.27884495},
#  'ctrl+SPI1': {'frac_in_range': 1.0,
#   'frac_in_range_45_55': 0.0,
#   'frac_in_range_40_60': 0.0,
#   'frac_in_range_25_75': 0.15,
#   'mean_sigma': 0.98718053,
#   'std_sigma': 0.1703776,
#   'frac_sigma_below_1': 0.6,
#   'frac_sigma_below_2': 1.0,
#   'pearson_delta': -0.005573777121230665,
#   'pearson_delta_de': 0.8891383274850574,
#   'fold_change_gap_all': 0.37749305,
#   'fold_change_gap_upreg_3': 5.6243143,
#   'fold_change_gap_upreg_10': 12.162699,
#   'pearson_delta_top200_hvg': -0.05317429117095012,
#   'pearson_top200_hvg': 0.9298157433754048,
#   'mse_top200_hvg': 0.11732767,
#   'pearson_delta_top200_de': -0.016467372511189477,
#   'pearson_top200_de': 0.9448440348054435,
#   'mse_top200_de': 0.13698286,
#   'pearson_delta_top100_de': 0.01257565537690595,
#   'pearson_top100_de': 0.9279729691127963,
#   'mse_top100_de': 0.21678047,
#   'pearson_delta_top50_de': 0.03604720358668637,
#   'pearson_top50_de': 0.8970288433849432,
#   'mse_top50_de': 0.3112692}}

# %%
fold_change
# Out:
# array([[0.       , 0.       , 0.       , ..., 0.9791699, 0.       ,
#         0.       ]], dtype=float32)

# %%
fold_change_gap_downreg_num = 0
fold_change_gap_upreg_num = 0

for i,j in pert_metric.items():
    if 'fold_change_gap_downreg_0.33' in j:
        fold_change_gap_downreg_num += 1
    elif 'fold_change_gap_upreg_3' in j:
        fold_change_gap_upreg_num += 1

# %%
fold_change_gap_upreg_num
# Out:
# 102

# %%
fold_change_gap_downreg_num
# Out:
# 3
