# %%
# !python train.py --dataset Norman2019_Adamson2016 \
                 --split simulation \
                 --seed 1 \
                 --network_name co-expression \
                 --top_edge_percent 100 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3\
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:3 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --no_gnn \
                 --exp_name pertnet \
                 --train_gene_set_size 0.9 \
                 --combo_seen2_train_frac 0.9 \
                 --wandb \
                 --uncertainty \
                 --delta_predict
# Out:
# ---- Printing Arguments ----
# dataset: Norman2019_Adamson2016
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.9
# combo_seen2_train_frac: 0.9
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: co-expression
# top_edge_percent: 100.0
# randomize_network: False
# device: cuda:3
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: True
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: False
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: True
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: True
# mlp_mixer: False
# mlp_mixer_num_layers: 2
# mlp_mixer_dropout: 0.3
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: pertnet
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run pertnet
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_Norman2019_Adamson2016
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_Norman2019_Adamson2016/runs/3j2bmpg8
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211110_143754-3j2bmpg8
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_co-expression_100.0_64_2_l3_Norman2019_Adamson2016_gamma2_gene_emb_delta_predict_pert_emb_constant_sim_gnn_uncertainty_1_1
# Building cell graph...
# There are 9595 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:1
# combo_seen1:25
# combo_seen2:10
# unseen_single:14
# Creating dataloaders....
# Dataloaders created...
# Finished data setup, in total takes 0.740 min
# Initializing model...
# Start Training...
# Epoch 1 Step 1 Train Loss: 0.5440
# Epoch 1 Step 51 Train Loss: 0.3434
# Epoch 1 Step 101 Train Loss: 0.2231
# Epoch 1 Step 151 Train Loss: 0.2050
# Epoch 1 Step 201 Train Loss: 0.2032
# Epoch 1 Step 251 Train Loss: 0.1942
# Epoch 1 Step 301 Train Loss: 0.1704
# Epoch 1 Step 351 Train Loss: 0.2323
# Epoch 1 Step 401 Train Loss: 0.3366
# Epoch 1 Step 451 Train Loss: 0.2993
# Epoch 1 Step 501 Train Loss: 0.2005
# Epoch 1 Step 551 Train Loss: 0.1905
# Epoch 1 Step 601 Train Loss: 0.2106
# Epoch 1 Step 651 Train Loss: 0.2257
# Epoch 1 Step 701 Train Loss: 0.2659
# Epoch 1 Step 751 Train Loss: 0.2064
# Epoch 1 Step 801 Train Loss: 0.2121
# Epoch 1 Step 851 Train Loss: 0.2209
# Epoch 1 Step 901 Train Loss: 0.2467
# Epoch 1 Step 951 Train Loss: 0.1708
# Epoch 1 Step 1001 Train Loss: 0.1978
# Epoch 1 Step 1051 Train Loss: 0.1717
# Epoch 1 Step 1101 Train Loss: 0.2298
# Epoch 1 Step 1151 Train Loss: 0.1936
# Epoch 1 Step 1201 Train Loss: 0.2080
# Epoch 1 Step 1251 Train Loss: 0.2000
# Epoch 1 Step 1301 Train Loss: 0.1885
# Epoch 1 Step 1351 Train Loss: 0.1934
# Epoch 1 Step 1401 Train Loss: 0.1428
# Epoch 1 Step 1451 Train Loss: 0.2419
# Epoch 1 Step 1501 Train Loss: 0.1740
# Epoch 1 Step 1551 Train Loss: 0.1769
# Epoch 1 Step 1601 Train Loss: 0.1880
# Epoch 1 Step 1651 Train Loss: 0.2123
# Epoch 1 Step 1701 Train Loss: 0.1706
# Epoch 1 Step 1751 Train Loss: 0.1823
# Epoch 1 Step 1801 Train Loss: 0.2230
# Epoch 1 Step 1851 Train Loss: 0.2064
# Epoch 1 Step 1901 Train Loss: 0.1979
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 3 Step 901 Train Loss: 0.2083
# Epoch 3 Step 951 Train Loss: 0.2025
# Epoch 3 Step 1001 Train Loss: 0.1993
# Epoch 3 Step 1051 Train Loss: 0.2439
# Epoch 3 Step 1101 Train Loss: 0.2036
# Epoch 3 Step 1151 Train Loss: 0.2637
# Epoch 3 Step 1201 Train Loss: 0.2070
# Epoch 3 Step 1251 Train Loss: 0.1555
# Epoch 3 Step 1301 Train Loss: 0.2187
# Epoch 3 Step 1351 Train Loss: 0.2214
# Epoch 3 Step 1401 Train Loss: 0.2045
# Epoch 3 Step 1451 Train Loss: 0.1816
# Epoch 3 Step 1501 Train Loss: 0.2217
# Epoch 3 Step 1551 Train Loss: 0.1746
# Epoch 3 Step 1601 Train Loss: 0.2064
# Epoch 3 Step 1651 Train Loss: 0.1852
# Epoch 3 Step 1701 Train Loss: 0.2425
# Epoch 3 Step 1751 Train Loss: 0.1699
# Epoch 3 Step 1801 Train Loss: 0.1929
# Epoch 3 Step 1851 Train Loss: 0.1982
# Epoch 3 Step 1901 Train Loss: 0.2184
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 3: Train: 0.0111, R2 0.9476 Validation: 0.0130. R2 0.9385 Loss: 0.2046
# DE_Train: 0.1730, R2 0.6444 DE_Validation: 0.3065. R2 0.2039
# Epoch 4 Step 1 Train Loss: 0.2107
# Epoch 4 Step 51 Train Loss: 0.2072
# Epoch 4 Step 101 Train Loss: 0.1937
# Epoch 4 Step 151 Train Loss: 0.1855
# Epoch 4 Step 201 Train Loss: 0.2485
# Epoch 4 Step 251 Train Loss: 0.1677
# Epoch 4 Step 301 Train Loss: 0.2144
# Epoch 4 Step 351 Train Loss: 0.1866
# Epoch 4 Step 401 Train Loss: 0.1758
# Epoch 4 Step 451 Train Loss: 0.2211
# Epoch 4 Step 501 Train Loss: 0.2831
# Epoch 4 Step 551 Train Loss: 0.1822
# Epoch 4 Step 601 Train Loss: 0.1875
# Epoch 4 Step 651 Train Loss: 0.2061
# Epoch 4 Step 701 Train Loss: 0.1894
# Epoch 4 Step 751 Train Loss: 0.1851
# Epoch 4 Step 801 Train Loss: 0.1929
# Epoch 4 Step 851 Train Loss: 0.2032
# Epoch 4 Step 901 Train Loss: 0.1760
# Epoch 4 Step 951 Train Loss: 0.1935
# Epoch 4 Step 1001 Train Loss: 0.1963
# Epoch 4 Step 1051 Train Loss: 0.2376
# Epoch 4 Step 1101 Train Loss: 0.1772
# Epoch 4 Step 1151 Train Loss: 0.2107
# Epoch 4 Step 1201 Train Loss: 0.1712
# Epoch 4 Step 1251 Train Loss: 0.2240
# Epoch 4 Step 1301 Train Loss: 0.1594
# Epoch 4 Step 1351 Train Loss: 0.2785
# Epoch 4 Step 1401 Train Loss: 0.2070
# Epoch 4 Step 1451 Train Loss: 0.1705
# Epoch 4 Step 1501 Train Loss: 0.2120
# Epoch 4 Step 1551 Train Loss: 0.2227
# Epoch 4 Step 1601 Train Loss: 0.1812
# Epoch 4 Step 1651 Train Loss: 0.2021
# Epoch 4 Step 1701 Train Loss: 0.2460
# Epoch 4 Step 1751 Train Loss: 0.2141
# Epoch 4 Step 1801 Train Loss: 0.1831
# Epoch 4 Step 1851 Train Loss: 0.1788
# Epoch 4 Step 1901 Train Loss: 0.2021
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 6 Step 401 Train Loss: 0.2007
# Epoch 6 Step 451 Train Loss: 0.1793
# Epoch 6 Step 501 Train Loss: 0.2154
# Epoch 6 Step 551 Train Loss: 0.2072
# Epoch 6 Step 601 Train Loss: 0.2095
# Epoch 6 Step 651 Train Loss: 0.2091
# Epoch 6 Step 701 Train Loss: 0.2301
# Epoch 6 Step 751 Train Loss: 0.1921
# Epoch 6 Step 801 Train Loss: 0.2633
# Epoch 6 Step 851 Train Loss: 0.1718
# Epoch 6 Step 901 Train Loss: 0.1982
# Epoch 6 Step 951 Train Loss: 0.2090
# Epoch 6 Step 1001 Train Loss: 0.1758
# Epoch 6 Step 1051 Train Loss: 0.2123
# Epoch 6 Step 1101 Train Loss: 0.1670
# Epoch 6 Step 1151 Train Loss: 0.2216
# Epoch 6 Step 1201 Train Loss: 0.1535
# Epoch 6 Step 1251 Train Loss: 0.1703
# Epoch 6 Step 1301 Train Loss: 0.1655
# Epoch 6 Step 1351 Train Loss: 0.2238
# Epoch 6 Step 1401 Train Loss: 0.1979
# Epoch 6 Step 1451 Train Loss: 0.2000
# Epoch 6 Step 1501 Train Loss: 0.1695
# Epoch 6 Step 1551 Train Loss: 0.1964
# Epoch 6 Step 1601 Train Loss: 0.1820
# Epoch 6 Step 1651 Train Loss: 0.1712
# Epoch 6 Step 1701 Train Loss: 0.2349
# Epoch 6 Step 1751 Train Loss: 0.1409
# Epoch 6 Step 1801 Train Loss: 0.1845
# Epoch 6 Step 1851 Train Loss: 0.1951
# Epoch 6 Step 1901 Train Loss: 0.2163
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# ...
# wandb:              test_SYNERGY_DISSIMILAR_PHENO_mse_top50_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:   test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:    test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_fold_change_gap_all ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_40_60 ▁
# wandb:          test_SYNERGY_SIMILAR_PHENO_frac_in_range_45_55 ▁
# wandb:                   test_SYNERGY_SIMILAR_PHENO_mean_sigma ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top100_de ▁
# wandb:                test_SYNERGY_SIMILAR_PHENO_mse_top200_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top20_de ▁
# wandb:                 test_SYNERGY_SIMILAR_PHENO_mse_top50_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top100_de ▁
# wandb:      test_SYNERGY_SIMILAR_PHENO_pearson_delta_top200_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de ▁
# wandb:       test_SYNERGY_SIMILAR_PHENO_pearson_delta_top50_de ▁
# wandb:                    test_combo_seen0_fold_change_gap_all ▁
# wandb:            test_combo_seen0_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen0_fold_change_gap_downreg_0.33
# wandb:               test_combo_seen0_fold_change_gap_upreg_10
# wandb:                test_combo_seen0_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen0_frac_in_range ▁
# wandb:                    test_combo_seen0_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen0_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen0_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen0_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen0_mae ▁
# wandb:                                 test_combo_seen0_mae_de ▁
# wandb:                             test_combo_seen0_mean_sigma ▁
# wandb:                                    test_combo_seen0_mse ▁
# wandb:                                 test_combo_seen0_mse_de ▁
# wandb:                          test_combo_seen0_mse_top100_de ▁
# wandb:                          test_combo_seen0_mse_top200_de ▁
# wandb:                         test_combo_seen0_mse_top200_hvg ▁
# wandb:                           test_combo_seen0_mse_top20_de ▁
# wandb:                           test_combo_seen0_mse_top50_de ▁
# wandb:                                test_combo_seen0_pearson ▁
# wandb:                             test_combo_seen0_pearson_de ▁
# wandb:                          test_combo_seen0_pearson_delta ▁
# wandb:                       test_combo_seen0_pearson_delta_de ▁
# wandb:                test_combo_seen0_pearson_delta_top100_de ▁
# wandb:                test_combo_seen0_pearson_delta_top200_de ▁
# wandb:               test_combo_seen0_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen0_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen0_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen0_pearson_top100_de ▁
# wandb:                      test_combo_seen0_pearson_top200_de ▁
# wandb:                     test_combo_seen0_pearson_top200_hvg ▁
# wandb:                       test_combo_seen0_pearson_top20_de ▁
# wandb:                       test_combo_seen0_pearson_top50_de ▁
# wandb:                                     test_combo_seen0_r2 ▁
# wandb:                                  test_combo_seen0_r2_de ▁
# wandb:                               test_combo_seen0_spearman ▁
# wandb:                            test_combo_seen0_spearman_de ▁
# wandb:                              test_combo_seen0_std_sigma ▁
# wandb:                    test_combo_seen1_fold_change_gap_all ▁
# wandb:            test_combo_seen1_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen1_fold_change_gap_downreg_0.33 ▁
# wandb:               test_combo_seen1_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen1_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen1_frac_in_range ▁
# wandb:                    test_combo_seen1_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen1_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen1_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen1_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen1_mae ▁
# wandb:                                 test_combo_seen1_mae_de ▁
# wandb:                             test_combo_seen1_mean_sigma ▁
# wandb:                                    test_combo_seen1_mse ▁
# wandb:                                 test_combo_seen1_mse_de ▁
# wandb:                          test_combo_seen1_mse_top100_de ▁
# wandb:                          test_combo_seen1_mse_top200_de ▁
# wandb:                         test_combo_seen1_mse_top200_hvg ▁
# wandb:                           test_combo_seen1_mse_top20_de ▁
# wandb:                           test_combo_seen1_mse_top50_de ▁
# wandb:                                test_combo_seen1_pearson ▁
# wandb:                             test_combo_seen1_pearson_de ▁
# wandb:                          test_combo_seen1_pearson_delta ▁
# wandb:                       test_combo_seen1_pearson_delta_de ▁
# wandb:                test_combo_seen1_pearson_delta_top100_de ▁
# wandb:                test_combo_seen1_pearson_delta_top200_de ▁
# wandb:               test_combo_seen1_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen1_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen1_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen1_pearson_top100_de ▁
# wandb:                      test_combo_seen1_pearson_top200_de ▁
# wandb:                     test_combo_seen1_pearson_top200_hvg ▁
# wandb:                       test_combo_seen1_pearson_top20_de ▁
# wandb:                       test_combo_seen1_pearson_top50_de ▁
# wandb:                                     test_combo_seen1_r2 ▁
# wandb:                                  test_combo_seen1_r2_de ▁
# wandb:                               test_combo_seen1_spearman ▁
# wandb:                            test_combo_seen1_spearman_de ▁
# wandb:                              test_combo_seen1_std_sigma ▁
# wandb:                    test_combo_seen2_fold_change_gap_all ▁
# wandb:            test_combo_seen2_fold_change_gap_downreg_0.1
# wandb:           test_combo_seen2_fold_change_gap_downreg_0.33
# wandb:               test_combo_seen2_fold_change_gap_upreg_10 ▁
# wandb:                test_combo_seen2_fold_change_gap_upreg_3 ▁
# wandb:                          test_combo_seen2_frac_in_range ▁
# wandb:                    test_combo_seen2_frac_in_range_25_75 ▁
# wandb:                    test_combo_seen2_frac_in_range_40_60 ▁
# wandb:                    test_combo_seen2_frac_in_range_45_55 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_1 ▁
# wandb:                     test_combo_seen2_frac_sigma_below_2 ▁
# wandb:                                    test_combo_seen2_mae ▁
# wandb:                                 test_combo_seen2_mae_de ▁
# wandb:                             test_combo_seen2_mean_sigma ▁
# wandb:                                    test_combo_seen2_mse ▁
# wandb:                                 test_combo_seen2_mse_de ▁
# wandb:                          test_combo_seen2_mse_top100_de ▁
# wandb:                          test_combo_seen2_mse_top200_de ▁
# wandb:                         test_combo_seen2_mse_top200_hvg ▁
# wandb:                           test_combo_seen2_mse_top20_de ▁
# wandb:                           test_combo_seen2_mse_top50_de ▁
# wandb:                                test_combo_seen2_pearson ▁
# wandb:                             test_combo_seen2_pearson_de ▁
# wandb:                          test_combo_seen2_pearson_delta ▁
# wandb:                       test_combo_seen2_pearson_delta_de ▁
# wandb:                test_combo_seen2_pearson_delta_top100_de ▁
# wandb:                test_combo_seen2_pearson_delta_top200_de ▁
# wandb:               test_combo_seen2_pearson_delta_top200_hvg ▁
# wandb:                 test_combo_seen2_pearson_delta_top20_de ▁
# wandb:                 test_combo_seen2_pearson_delta_top50_de ▁
# wandb:                      test_combo_seen2_pearson_top100_de ▁
# wandb:                      test_combo_seen2_pearson_top200_de ▁
# wandb:                     test_combo_seen2_pearson_top200_hvg ▁
# wandb:                       test_combo_seen2_pearson_top20_de ▁
# wandb:                       test_combo_seen2_pearson_top50_de ▁
# wandb:                                     test_combo_seen2_r2 ▁
# wandb:                                  test_combo_seen2_r2_de ▁
# wandb:                               test_combo_seen2_spearman ▁
# wandb:                            test_combo_seen2_spearman_de ▁
# wandb:                              test_combo_seen2_std_sigma ▁
# wandb:                                             test_de_mae ▁
# wandb:                                             test_de_mse ▁
# wandb:                                         test_de_pearson ▁
# wandb:                                              test_de_r2 ▁
# wandb:                                        test_de_spearman ▁
# wandb:                                test_fold_change_gap_all ▁
# wandb:                        test_fold_change_gap_downreg_0.1
# wandb:                       test_fold_change_gap_downreg_0.33 ▁
# wandb:                           test_fold_change_gap_upreg_10 ▁
# wandb:                            test_fold_change_gap_upreg_3 ▁
# wandb:                                      test_frac_in_range ▁
# wandb:                                test_frac_in_range_25_75 ▁
# wandb:                                test_frac_in_range_40_60 ▁
# wandb:                                test_frac_in_range_45_55 ▁
# wandb:                                 test_frac_sigma_below_1 ▁
# wandb:                                 test_frac_sigma_below_2 ▁
# wandb:                                                test_mae ▁
# wandb:                                         test_mean_sigma ▁
# wandb:                                                test_mse ▁
# wandb:                                      test_mse_top100_de ▁
# wandb:                                      test_mse_top200_de ▁
# wandb:                                     test_mse_top200_hvg ▁
# wandb:                                       test_mse_top20_de ▁
# wandb:                                       test_mse_top50_de ▁
# wandb:                                            test_pearson ▁
# wandb:                                      test_pearson_delta ▁
# wandb:                                   test_pearson_delta_de ▁
# wandb:                            test_pearson_delta_top100_de ▁
# wandb:                            test_pearson_delta_top200_de ▁
# wandb:                           test_pearson_delta_top200_hvg ▁
# wandb:                             test_pearson_delta_top20_de ▁
# wandb:                             test_pearson_delta_top50_de ▁
# wandb:                                  test_pearson_top100_de ▁
# wandb:                                  test_pearson_top200_de ▁
# wandb:                                 test_pearson_top200_hvg ▁
# wandb:                                   test_pearson_top20_de ▁
# wandb:                                   test_pearson_top50_de ▁
# wandb:                                                 test_r2 ▁
# wandb:                                           test_spearman ▁
# wandb:                                          test_std_sigma ▁
# wandb:                  test_unseen_single_fold_change_gap_all ▁
# wandb:          test_unseen_single_fold_change_gap_downreg_0.1
# wandb:         test_unseen_single_fold_change_gap_downreg_0.33
# wandb:             test_unseen_single_fold_change_gap_upreg_10 ▁
# wandb:              test_unseen_single_fold_change_gap_upreg_3 ▁
# wandb:                        test_unseen_single_frac_in_range ▁
# wandb:                  test_unseen_single_frac_in_range_25_75 ▁
# wandb:                  test_unseen_single_frac_in_range_40_60 ▁
# wandb:                  test_unseen_single_frac_in_range_45_55 ▁
# wandb:                   test_unseen_single_frac_sigma_below_1 ▁
# wandb:                   test_unseen_single_frac_sigma_below_2 ▁
# wandb:                                  test_unseen_single_mae ▁
# wandb:                               test_unseen_single_mae_de ▁
# wandb:                           test_unseen_single_mean_sigma ▁
# wandb:                                  test_unseen_single_mse ▁
# wandb:                               test_unseen_single_mse_de ▁
# wandb:                        test_unseen_single_mse_top100_de ▁
# wandb:                        test_unseen_single_mse_top200_de ▁
# wandb:                       test_unseen_single_mse_top200_hvg ▁
# wandb:                         test_unseen_single_mse_top20_de ▁
# wandb:                         test_unseen_single_mse_top50_de ▁
# wandb:                              test_unseen_single_pearson ▁
# wandb:                           test_unseen_single_pearson_de ▁
# wandb:                        test_unseen_single_pearson_delta ▁
# wandb:                     test_unseen_single_pearson_delta_de ▁
# wandb:              test_unseen_single_pearson_delta_top100_de ▁
# wandb:              test_unseen_single_pearson_delta_top200_de ▁
# wandb:             test_unseen_single_pearson_delta_top200_hvg ▁
# wandb:               test_unseen_single_pearson_delta_top20_de ▁
# wandb:               test_unseen_single_pearson_delta_top50_de ▁
# wandb:                    test_unseen_single_pearson_top100_de ▁
# wandb:                    test_unseen_single_pearson_top200_de ▁
# wandb:                   test_unseen_single_pearson_top200_hvg ▁
# wandb:                     test_unseen_single_pearson_top20_de ▁
# wandb:                     test_unseen_single_pearson_top50_de ▁
# wandb:                                   test_unseen_single_r2 ▁
# wandb:                                test_unseen_single_r2_de ▁
# wandb:                             test_unseen_single_spearman ▁
# wandb:                          test_unseen_single_spearman_de ▁
# wandb:                            test_unseen_single_std_sigma ▁
# wandb:                                            train_de_mae █▆▆▇▃▃▁▁▁▁
# wandb:                                            train_de_mse █▅▅▆▂▃▁▁▁▁
# wandb:                                        train_de_pearson ▁▃▃▂▇▇████
# wandb:                                             train_de_r2 ▄▄█▃▆▁▃▂▄▅
# wandb:                                       train_de_spearman ▁▂▂▁▆▇████
# wandb:                                               train_mae ▁▅▂█▃▁▂▂▁▁
# wandb:                                               train_mse ▁▄▂█▂▁▁▁▁▁
# wandb:                                           train_pearson ▇▄▅▁▆█████
# wandb:                                                train_r2 █▆█▁▇█████
# wandb:                                          train_spearman ▇▄▆▁▆▇████
# wandb:                                           training_loss ▃▅▆▆▃▇▄▅▅▄█▃▇▅▂▁▃▁▃▃▂▄▄▃▂▄▃▄▂▃▂▄▁▅▁▃▂▄▃▂
# wandb:                                              val_de_mae █▄██▄▄▁▁▁▁
# wandb:                                              val_de_mse █▅▇▆▃▄▁▁▁▁
# wandb:                                          val_de_pearson ▂▁▂▃▅▆▇███
# wandb:                                               val_de_r2 ▇██▁▆▅▅▃▄▅
# wandb:                                         val_de_spearman ▁▄▂▄▆▇▇█▇█
# wandb:                                                 val_mae ▁▆▁█▃▁▂▂▁▁
# wandb:                                                 val_mse ▂▅▂█▂▁▁▂▁▁
# wandb:                                             val_pearson ▇▂▅▁▆█████
# wandb:                                                  val_r2 ▇▅█▁▇██▇██
# wandb:                                            val_spearman ▆▄▆▁▆█████
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced pertnet: https://wandb.ai/kexinhuang/pert_gnn_simulation_Norman2019_Adamson2016/runs/3j2bmpg8

# %%
# !python train.py --dataset Norman2019 \
                 --split simulation \
                 --seed 1 \
                 --network_name string \
                 --top_edge_percent 10 \
                 --max_epochs 10 \
                 --batch_size 32 \
                 --lr 1e-3 \
                 --lr_decay_step_size 1 \
                 --lr_decay_factor 0.5 \
                 --weight_decay 5e-4 \
                 --model GNN_Disentangle \
                 --model_backend GAT \
                 --node_hidden_size 64 \
                 --gnn_num_layers 2 \
                 --loss_mode l3\
                 --focal_gamma 2 \
                 --print_progress_steps 50 \
                 --device cuda:3 \
                 --gene_emb \
                 --pert_emb \
                 --sim_gnn \
                 --pert_emb_lambda 0.2 \
                 --exp_name gat_string \
                 --wandb
# Out:
# ---- Printing Arguments ----
# dataset: Norman2019
# split: simulation
# seed: 1
# test_set_fraction: 0.1
# train_gene_set_size: 0.75
# combo_seen2_train_frac: 0.75
# test_perts: N/A
# only_test_set_perts: False
# perturbation_key: condition
# species: human
# binary_pert: True
# edge_attr: False
# ctrl_remove_train: False
# edge_weights: False
# pert_feats: True
# pert_delta: False
# edge_filter: False
# network_name: string
# top_edge_percent: 10.0
# randomize_network: False
# device: cuda:3
# max_epochs: 10
# lr: 0.001
# lr_decay_step_size: 1
# lr_decay_factor: 0.5
# weight_decay: 0.0005
# batch_size: 32
# print_progress_steps: 50
# node_hidden_size: 64
# node_embed_size: 1
# ae_hidden_size: 512
# gnn_num_layers: 2
# ae_num_layers: 2
# model: GNN_Disentangle
# model_backend: GAT
# shared_weights: False
# gene_specific: False
# gene_emb: True
# pert_emb: True
# gene_pert_agg: sum
# delta_predict: False
# delta_predict_with_gene: False
# pert_emb_lambda: 0.2
# pert_emb_agg: constant
# lambda_emission: False
# sim_gnn: True
# sim_gnn_gene: False
# sim_gnn_gene_k: 10
# sim_gnn_gene_threshold: 0.4
# sim_graph: knn_go_pathway
# gat_num_heads: 1
# dropout: 0.0
# batchnorm: False
# bn_eps: 1e-05
# bn_mom: 0.1
# activation: relu
# skipsum: False
# uncertainty: False
# uncertainty_reg: 1
# uncertainty_reg_core: 1
# no_gnn: False
# mlp_mixer: False
# mlp_mixer_num_layers: 2
# mlp_mixer_dropout: 0.3
# gene_sim_pos_emb: False
# no_pert_emb: False
# no_disentangle: False
# pert_loss_wt: 1
# loss_type: macro
# loss_mode: l3
# focal_gamma: 2
# wandb: True
# wandb_sweep: False
# project_name: pert_gnn
# entity_name: kexinhuang
# exp_name: gat_string
# ----------------------------
# wandb: Currently logged in as: kexinhuang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.2
# wandb: Syncing run gat_string
# wandb:  View project at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019
# wandb:  View run at https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/2b4jdawr
# wandb: Run data is saved locally in /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211111_153757-2b4jdawr
# wandb: Run `wandb offline` to turn off syncing.
#
# Training GNN_Disentangle_GAT_string_10.0_64_2_l3_Norman2019_gamma2_gene_emb_pert_emb_constant_sim_gnn
# Building cell graph...
# There are 50506 edges in the PPI.
# Creating pyg object for each cell in the data...
# Local copy of pyg dataset is detected. Loading...
# Loading splits...
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:9
# combo_seen1:52
# combo_seen2:18
# unseen_single:37
# Creating dataloaders....
# Dataloaders created...
# Finished data setup, in total takes 1.038 min
# Initializing model...
# Start Training...
# Epoch 1 Step 1 Train Loss: 10.9897
# Epoch 1 Step 51 Train Loss: 0.0855
# Epoch 1 Step 101 Train Loss: 0.0843
# Epoch 1 Step 151 Train Loss: 0.0706
# Epoch 1 Step 201 Train Loss: 0.1005
# Epoch 1 Step 251 Train Loss: 0.0694
# Epoch 1 Step 301 Train Loss: 0.0455
# Epoch 1 Step 351 Train Loss: 0.0657
# Epoch 1 Step 401 Train Loss: 0.0587
# Epoch 1 Step 451 Train Loss: 0.0367
# Epoch 1 Step 501 Train Loss: 0.0478
# Epoch 1 Step 551 Train Loss: 0.0513
# Epoch 1 Step 601 Train Loss: 0.0486
# Epoch 1 Step 651 Train Loss: 0.0384
# Epoch 1 Step 701 Train Loss: 0.0436
# Epoch 1 Step 751 Train Loss: 0.0391
# Epoch 1 Step 801 Train Loss: 0.0330
# Epoch 1 Step 851 Train Loss: 0.0415
# Epoch 1 Step 901 Train Loss: 0.0496
# Epoch 1 Step 951 Train Loss: 0.0542
# Epoch 1 Step 1001 Train Loss: 0.0683
# Epoch 1 Step 1051 Train Loss: 0.0385
# Epoch 1 Step 1101 Train Loss: 0.0394
# Epoch 1 Step 1151 Train Loss: 0.0385
# Epoch 1 Step 1201 Train Loss: 0.0424
# Epoch 1 Step 1251 Train Loss: 0.0442
# Epoch 1 Step 1301 Train Loss: 0.0470
# Epoch 1 Step 1351 Train Loss: 0.0559
# Epoch 1 Step 1401 Train Loss: 0.0351
# Epoch 1 Step 1451 Train Loss: 0.0453
# Epoch 1 Step 1501 Train Loss: 0.0395
# Epoch 1 Step 1551 Train Loss: 0.0235
# Epoch 1 Step 1601 Train Loss: 0.0501
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Epoch 1: Train: 0.0357, R2 0.6824 Validation: 0.0349. R2 0.6899 Loss: 0.0578
# DE_Train: 0.2622, R2 -0.1457 DE_Validation: 0.2670. R2 -0.0253
# Epoch 2 Step 1 Train Loss: 0.0539
# Epoch 2 Step 51 Train Loss: 0.0578
# Epoch 2 Step 101 Train Loss: 0.0308
# Epoch 2 Step 151 Train Loss: 0.0384
# Epoch 2 Step 201 Train Loss: 0.0401
# Epoch 2 Step 251 Train Loss: 0.0361
# Epoch 3 Step 1451 Train Loss: 0.0293
# Epoch 3 Step 1501 Train Loss: 0.0291
# Epoch 3 Step 1551 Train Loss: 0.0300
# Epoch 3 Step 1601 Train Loss: 0.0291
# Traceback (most recent call last):
#   File "train.py", line 621, in <module>
#     trainer(parse_arguments())
#   File "train.py", line 345, in trainer
#     best_model = train(model, pertdl.loaders['train_loader'],
#   File "train.py", line 79, in train
#     train_res = evaluate(train_loader, graph, weights, model, args, gene_idx=gene_idx)
#   File "/dfs/user/kexinh/perturb_GNN/kexin/inference.py", line 61, in evaluate
#     truth = torch.stack(truth)
# RuntimeError: [enforce fail at CPUAllocator.cpp:71] . DefaultCPUAllocator: can't allocate memory: you tried to allocate 1034890940 bytes. Error code 12 (Cannot allocate memory)
#
# wandb: Waiting for W&B process to finish, PID 8560
# wandb: Program failed with code 1.  Press ctrl-c to abort syncing.
# wandb:
# wandb: Find user logs for this run at: /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211111_153757-2b4jdawr/logs/debug.log
# wandb: Find internal logs for this run at: /dfs/user/kexinh/perturb_GNN/kexin/wandb/run-20211111_153757-2b4jdawr/logs/debug-internal.log
# wandb: Run summary:
# wandb:        train_de_mae 0.45746
# wandb:        train_de_mse 0.39408
# wandb:    train_de_pearson 0.89423
# wandb:         train_de_r2 -0.56812
# wandb:   train_de_spearman 0.82083
# wandb:           train_mae 0.15785
# wandb:           train_mse 0.03677
# wandb:       train_pearson 0.96222
# wandb:            train_r2 0.56724
# wandb:      train_spearman 0.79102
# wandb:       training_loss 0.03336
# wandb:          val_de_mae 0.45048
# wandb:          val_de_mse 0.36558
# wandb:      val_de_pearson 0.85522
# wandb:           val_de_r2 -1.01689
# wandb:     val_de_spearman 0.76559
# wandb:             val_mae 0.15461
# wandb:             val_mse 0.03571
# wandb:         val_pearson 0.95895
# wandb:              val_r2 0.57518
# wandb:        val_spearman 0.78606
# wandb: Run history:
# wandb:        train_de_mae ▁█
# wandb:        train_de_mse ▁█
# wandb:    train_de_pearson █▁
# wandb:         train_de_r2 █▁
# wandb:   train_de_spearman █▁
# wandb:           train_mae █▁
# wandb:           train_mse ▁█
# wandb:       train_pearson █▁
# wandb:            train_r2 █▁
# wandb:      train_spearman ▁█
# wandb:       training_loss ▇█▇▅▃▄▂▃▂▅▆▅▅▃▄▂▃▁▂▃▃▄▃▆▄▃▂▃▃▁▃▁▃▂▄▃▂▂▅▃
# wandb:          val_de_mae ▁█
# wandb:          val_de_mse ▁█
# wandb:      val_de_pearson █▁
# wandb:           val_de_r2 █▁
# wandb:     val_de_spearman █▁
# wandb:             val_mae █▁
# wandb:             val_mse ▁█
# wandb:         val_pearson █▁
# wandb:              val_r2 █▁
# wandb:        val_spearman ▁█
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced gat_string: https://wandb.ai/kexinhuang/pert_gnn_simulation_norman2019/runs/2b4jdawr
