# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import wandb
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import font_manager

font_dirs = ["./"]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    font_manager.fontManager.addfont(font_file)
    
sns.set( font = "Helvetica" )

api = wandb.Api()

data_name = 'adamson2016'

# Project is specified by <entity/project-name> please replace it with your project name here:
runs = api.runs("ekernf01/adamson" + data_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_68216/3624178759.py in <module>
#      25
#      26 summary_list, config_list, name_list = [], [], []
# ---> 27 for run in runs:
#      28     # .summary contains the output keys/values for metrics like accuracy.
#      29     #  We call ._json_dict to omit large files
#
# /dfs/user/yhr/deepsnap/lib/python3.7/site-packages/wandb/apis/public.py in __next__(self)
#     867         self.index += 1
#     868         if len(self.objects) <= self.index:
# --> 869             if not self._load_page():
#     870                 raise StopIteration
#     871             if len(self.objects) <= self.index:
#
# /dfs/user/yhr/deepsnap/lib/python3.7/site-packages/wandb/apis/public.py in _load_page(self)
#     855             self.QUERY, variable_values=self.variables
#     856         )
# --> 857         self.objects.extend(self.convert_objects())
#     858         return True
#     859
#
# /dfs/user/yhr/deepsnap/lib/python3.7/site-packages/wandb/apis/public.py in convert_objects(self)
#    1358         objs = []
#    1359         if self.last_response is None or self.last_response.get("project") is None:
# -> 1360             raise ValueError("Could not find project %s" % self.project)
#    1361         for run_response in self.last_response["project"]["runs"]["edges"]:
#    1362             run = Run(
#
# ValueError: Could not find project adamsonadamson2016

# %%
summary_list, config_list, name_list = [], [], []
for run in runs: 
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files 
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append(
        {k: v for k,v in run.config.items()
          if not k.startswith('_')})

    # .name is the human-readable name of the run.
    name_list.append(run.name)

runs_df = pd.DataFrame({
    "summary": summary_list,
    "config": config_list,
    "name": name_list
    })

# %%
run = 2
cpa_runs = ['CPA_' + str(i) for i in range(1, run)]
pertnet_runs = ['gears_seed' + str(i) for i in range(1, run)]
no_perturb_runs = ['No_Perturb_' + str(i) for i in range(1, run)]
linear_runs = ['Linear_' + str(i) for i in range(1, run)]

# %%
# Out:
# 0.4471116960048675

# %%
res_df = runs_df[runs_df.name.isin(cpa_runs + pertnet_runs + no_perturb_runs + linear_runs)]

# %%
summary_list
# Out:
# [{'_step': 12202,
#   'test_de_mse': 0.4471116960048675,
#   'test_pearson': 0.9843188870896952,
#   'train_pearson': 0.9669008838768184,
#   'test_combo_seen1_pearson': 'NaN',
#   'test_combo_seen0_frac_sigma_below_1_non_dropout': 'NaN',
#   'test_unseen_single_frac_sigma_below_1_non_dropout': 0.75,
#   'val_de_pearson': 0.9824422586623004,
#   'test_combo_seen1_pearson_delta': 'NaN',
#   'test_pearson_delta': 0.5136011148216236,
#   'test_combo_seen2_frac_opposite_direction_top20_non_dropout': 'NaN',
#   'test_unseen_single_frac_opposite_direction_top20_non_dropout': 0.075,
#   'train_de_pearson': 0.916376442327872,
#   'test_combo_seen1_mse': 'NaN',
#   'test_unseen_single_pearson': 0.9843188870896952,
#   'train_de_mse': 0.5465984344482422,
#   'test_combo_seen1_mse_top20_de_non_dropout': 'NaN',
#   'test_combo_seen2_mse_top20_de_non_dropout': 'NaN',
#   'test_unseen_single_mse_top20_de_non_dropout': 0.4471116960048675,
#   '_runtime': 6728.786139965057,
#   'test_combo_seen2_mse': 'NaN',
#   'test_combo_seen0_pearson': 'NaN',
#   'test_combo_seen0_pearson_de': 'NaN',
#   'test_combo_seen0_frac_opposite_direction_top20_non_dropout': 'NaN',
#   'val_mse': 0.006117343436926603,
#   'test_combo_seen0_mse': 'NaN',
#   'test_combo_seen1_frac_opposite_direction_top20_non_dropout': 'NaN',
#   'val_pearson': 0.990551468839931,
#   'test_combo_seen1_mse_de': 'NaN',
#   'test_combo_seen2_mse_de': 'NaN',
#   'test_unseen_single_pearson_de': 0.8569221663089421,
#   'test_combo_seen2_pearson_delta': 'NaN',
#   'training_loss': 0.31305673718452454,
#   'test_unseen_single_mse_de': 0.4471116960048675,
#   'test_combo_seen0_mse_top20_de_non_dropout': 'NaN',
#   'test_combo_seen1_frac_sigma_below_1_non_dropout': 'NaN',
#   'test_mse': 0.009209095500409605,
#   'train_mse': 0.024649448692798615,
#   'test_de_pearson': 0.8569221663089421,
#   'test_combo_seen0_mse_de': 'NaN',
#   'test_combo_seen0_pearson_delta': 'NaN',
#   'test_frac_sigma_below_1_non_dropout': 0.75,
#   '_timestamp': 1683602144.3668349,
#   'val_de_mse': 0.0470951609313488,
#   'test_unseen_single_pearson_delta': 0.5136011148216236,
#   'test_combo_seen2_frac_sigma_below_1_non_dropout': 'NaN',
#   '_wandb': {'runtime': 6728},
#   'test_unseen_single_mse': 0.009209095500409605,
#   'test_combo_seen1_pearson_de': 'NaN',
#   'test_combo_seen2_pearson_de': 'NaN',
#   'test_combo_seen2_pearson': 'NaN',
#   'test_mse_top20_de_non_dropout': 0.4471116960048675,
#   'test_frac_opposite_direction_top20_non_dropout': 0.075},
#  {'_runtime': 559.3605077266693,
#   '_timestamp': 1683592765.5404897,
#   'training_loss': 0.5066736340522766,
#   '_step': 808,
#   '_wandb': {'runtime': 558}},
#  {'_wandb': {'runtime': 547},
#   '_runtime': 547.5334088802338,
#   '_timestamp': 1683592680.037613,
#   'training_loss': 0.5066735744476318,
#   '_step': 808},
#  {'_wandb': {'runtime': 5}},
#  {'_wandb': {'runtime': 9}},
#  {'_wandb': {'runtime': 2}},
#  {'_wandb': {'runtime': 3}}]

# %%
res_df
# Out:
#                                              summary  \
# 0  {'_step': 12202, 'test_de_mse': 0.447111696004...
# 1  {'_runtime': 559.3605077266693, '_timestamp': ...
# 2  {'_wandb': {'runtime': 547}, '_runtime': 547.5...
# 3                         {'_wandb': {'runtime': 5}}
# 4                         {'_wandb': {'runtime': 9}}
# 5                         {'_wandb': {'runtime': 2}}
# 6                         {'_wandb': {'runtime': 3}}
#
#                                               config         name
# 0  {'G_go': None, 'device': 'cuda:0', 'num_genes'...  gears_seed1
# 1  {'G_go': None, 'device': 'cuda:0', 'num_genes'...  gears_seed1
# 2  {'G_go': None, 'device': 'cuda:0', 'num_genes'...  gears_seed1
# 3  {'G_go': None, 'device': 'cuda:0', 'num_genes'...  gears_seed1
# 4  {'G_go': None, 'device': 'cuda:0', 'num_genes'...  gears_seed1
# 5                                                 {}  gears_seed1
# 6                                                 {}  gears_seed1

# %%
def normalize_name(x):
    if x in cpa_runs:
        return 'CPA'
    elif x in pertnet_runs:
        return 'GEARS'
    elif x in linear_runs:
        return 'Linear'
    else:
        return 'No-Perturb'

# %%
metrics_name_map
# Out:
# {'test_mse_top20_de_non_dropout': 'Top 20 DE MSE',
#  'test_pearson_delta': 'Pearson Correlation Across All Genes'}

# %%
res_df
# Out:
#                                              summary  \
# 0  {'_step': 12202, 'test_de_mse': 0.447111696004...
# 1  {'_runtime': 559.3605077266693, '_timestamp': ...
# 2  {'_wandb': {'runtime': 547}, '_runtime': 547.5...
# 3                         {'_wandb': {'runtime': 5}}
# 4                         {'_wandb': {'runtime': 9}}
# 5                         {'_wandb': {'runtime': 2}}
# 6                         {'_wandb': {'runtime': 3}}
#
#                                               config         name
# 0  {'G_go': None, 'device': 'cuda:0', 'num_genes'...  gears_seed1
# 1  {'G_go': None, 'device': 'cuda:0', 'num_genes'...  gears_seed1
# 2  {'G_go': None, 'device': 'cuda:0', 'num_genes'...  gears_seed1
# 3  {'G_go': None, 'device': 'cuda:0', 'num_genes'...  gears_seed1
# 4  {'G_go': None, 'device': 'cuda:0', 'num_genes'...  gears_seed1
# 5                                                 {}  gears_seed1
# 6                                                 {}  gears_seed1

# %%
metrics = ['test_mse_top20_de_non_dropout', 'test_pearson_delta']
metrics_name_map = {'test_mse_top20_de_non_dropout': 'Top 20 DE MSE',
                   'test_pearson_delta': 'Pearson Correlation Across All Genes'}
out = {}
out['method'] = [normalize_name(i) for i in res_df.name.values]
for m in metrics:
    out[metrics_name_map[m]] = res_df.summary.apply(lambda x: x[m])
out = pd.DataFrame(out)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_68216/2979541465.py in <module>
#       5 out['method'] = [normalize_name(i) for i in res_df.name.values]
#       6 for m in metrics:
# ----> 7     out[metrics_name_map[m]] = res_df.summary.apply(lambda x: x[m])
#       8 out = pd.DataFrame(out)
#
# /dfs/user/yhr/deepsnap/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4354         dtype: float64
#    4355         """
# -> 4356         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4357
#    4358     def _reduce(
#
# /dfs/user/yhr/deepsnap/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#    1034             return self.apply_str()
#    1035
# -> 1036         return self.apply_standard()
#    1037
#    1038     def agg(self):
#
# /dfs/user/yhr/deepsnap/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#    1093                     values,
#    1094                     f,  # type: ignore[arg-type]
# -> 1095                     convert=self.convert_dtype,
#    1096                 )
#    1097
#
# /dfs/user/yhr/deepsnap/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_68216/2979541465.py in <lambda>(x)
#       5 out['method'] = [normalize_name(i) for i in res_df.name.values]
#       6 for m in metrics:
# ----> 7     out[metrics_name_map[m]] = res_df.summary.apply(lambda x: x[m])
#       8 out = pd.DataFrame(out)
#
# KeyError: 'test_mse_top20_de_non_dropout'

# %%
color_pal = {
'Linear': (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
'CPA': (0.4, 0.7607843137254902, 0.6470588235294118),
'GEARS': (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
'No-Perturb': (0.7019607843137254, 0.7019607843137254, 0.7019607843137254)}

# %%
pal_order = [color_pal[i] for i in pd.DataFrame(out).method.unique()]

# %%
import numpy as np
normalize = np.mean(out[out.method == 'No-Perturb']['Top 20 DE MSE'])
out['Normalized MSE of Top 20 DE Genes'] = out['Top 20 DE MSE'].values/normalize

# %%
sns.set(rc={'figure.figsize':(3.5,6)})
sns.set_theme(style="ticks", rc={"axes.facecolor": (0, 0, 0, 0)}, font = "Helvetica", font_scale=1.8)

g = sns.pointplot('method', 'Normalized MSE of Top 20 DE Genes', 
    data=pd.DataFrame(out), 
    order = ['Linear','CPA', 'GEARS'], 
    hue = 'method',
    palette=[color_pal['Linear'], color_pal['CPA'], color_pal['GEARS']],              
    dodge=True, 
    join=False,
    hue_order = ['Linear', 'CPA', 'GEARS'])
sns.despine()
g.legend_.remove()
g.set(xlabel=None)
g.axhline(1, linestyle="dashed")

plt.ylabel("Normalized MSE of Top 20 DE Genes",labelpad=10)
plt.tick_params(axis='x', which='major', pad=10)
plt.tick_params(axis='y', which='major', pad=5)
#g.spines['left'].set_linewidth(0.8)
#g.spines['bottom'].set_linewidth(0.8)
plt.savefig('output_' + data_name + '.pdf', bbox_inches='tight')
