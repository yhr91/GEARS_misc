# %%
import pandas as pd
import seaborn as sns

import pandas as pd 
import wandb
api = wandb.Api()

data_name = 'norman2019'

# Project is specified by <entity/project-name>
runs = api.runs("kexinhuang/pert_gnn_simulation_" + data_name)

summary_list, config_list, name_list = [], [], []
for run in runs: 
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files 
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append(
        {k: v for k,v in run.config.items()
          if not k.startswith('_')})

    # .name is the human-readable name of the run.
    name_list.append(run.name)

runs_df = pd.DataFrame({
    "summary": summary_list,
    "config": config_list,
    "name": name_list
    })

# %%
run = 6
pertnet_runs = ['pertnet_baseline_' + str(i) for i in range(1, run)]
no_graph_runs = ['pertnet_no_graph_' + str(i) for i in range(1, run)]
no_perturb_graph_runs = ['pertnet_no_perturb_graph_' + str(i) for i in range(1, run)]
no_gene_graph_runs = ['pertnet_no_gene_graph_' + str(i) for i in range(1, run)]
no_cross_gene_runs = ['pertnet_no_cross_gene_' + str(i) for i in range(1, run)]
no_gene_specific_runs = ['pertnet_no_gene_specific_' + str(i) for i in range(1, run)]
no_l2_runs = ['pertnet_l2_' + str(i) for i in range(1, run)]

# %%
res_df = runs_df[runs_df.name.isin(pertnet_runs + no_graph_runs + no_perturb_graph_runs + \
                                   no_gene_graph_runs + no_cross_gene_runs + no_gene_specific_runs + no_l2_runs)]

# %%
def normalize_name(x):
    if x in pertnet_runs:
        return 'GEARS'
    elif x in no_graph_runs:
        return 'No Graph'
    elif x in no_perturb_graph_runs:
        return 'No GO Graph'
    elif x in no_gene_graph_runs:
        return 'No Co-Express Graph'
    elif x in no_cross_gene_runs:
        return 'No Cross-gene'
    elif x in no_gene_specific_runs:
        return 'No Gene-specific Decoder'
    elif x in no_l2_runs:
        return 'MSE Loss'

# %%
res_df.summary.values[0]
# Out:
# {'test_ADDITIVE_pearson_delta_top50_de': 0.6279977182768589,
#  'test_SYNERGY_DISSIMILAR_PHENO_mse_top100_de': 0.11062490195035934,
#  'test_SUPPRESSOR_frac_correct_direction_top20_non_zero': 0.73,
#  'train_de_pearson': 0.8954752759921105,
#  'test_unseen_single_r2': 0.9747313505914598,
#  'test_EPISTASIS_mse_top50_de': 0.41957393288612366,
#  'test_unseen_single_pearson_top20_de': 0.8804940928316451,
#  'test_combo_seen1_pearson_top20_de_non_dropout': 0.8649247988879932,
#  'test_combo_seen1_frac_0/1_direction_top20_non_dropout': 0,
#  'test_pearson_delta_top20_de': 0.5752528778172994,
#  'test_SUPPRESSOR_mse_top100_de': 0.06869688630104065,
#  'test_combo_seen1_frac_correct_direction_all': 0.3970882744950616,
#  'test_combo_seen1_frac_in_range_40_60_non_zero': 0.10603448275862072,
#  'test_combo_seen1_pearson_top20_de': 0.7837690786555281,
#  'test_SYNERGY_SIMILAR_PHENO_mse_top50_de': 0.2624592185020447,
#  'test_combo_seen2_fold_change_gap_downreg_0.1': 'NaN',
#  'test_frac_correct_direction_20_nonzero': 0.8511990993688316,
#  'test_ADDITIVE_frac_sigma_below_1_non_dropout': 0.6681818181818182,
#  'test_POTENTIATION_mse_top200_de': 0.12275496125221252,
#  'test_SUPPRESSOR_pearson_delta_top20_de_non_dropout': 0.5136985958313621,
#  'test_SUPPRESSOR_mse_top50_de': 0.11171432584524156,
#  'test_combo_seen1_pearson_delta_top100_de': 0.6393881167296394,
#  'test_unseen_single_pearson_delta_top50_de': 0.45071592699131846,
#  'test_frac_in_range_45_55_non_dropout': 0.05887096774193548,
#  'test_combo_seen0_pearson_delta_top200_hvg': 0.4929242307330333,
#  'test_pearson_delta': 0.4990040138341951,
#  'test_combo_seen2_mse_de': 0.2834175229072571,
#  'test_combo_seen1_mse_top200_de': 0.09569526463747025,
#  'test_combo_seen2_mse_top200_de': 0.06900431215763092,
#  'test_unseen_single_pearson_top20_de_non_zero': 0.8878689251894951,
#  'test_NEOMORPHIC_mse_top20_de': 0.11421175301074982,
#  'test_NEOMORPHIC_pearson_delta_top200_de': 0.6270479589386636,
#  'test_unseen_single_pearson_delta_top100_de': 0.45125662166704233,
#  'train_spearman': 0.8363179525432944,
#  'val_de_pearson': 0.9050419444561956,
#  'test_unseen_single_mse': 0.004085385240614414,
#  'test_mean_sigma_non_dropout': 0.7787137031555176,
#  'test_POTENTIATION_frac_in_range_25_75_non_dropout': 0.15,
#  'train_de_mse': 0.13248975574970245,
#  'test_combo_seen0_pearson_top200_hvg': 0.9310565845596156,
#  'test_combo_seen1_fold_change_gap_upreg_10': 104.79866790771484,
#  'test_SYNERGY_DISSIMILAR_PHENO_mse_top20_de': 0.2272799164056778,
#  'test_combo_seen0_mse': 0.006538876798003912,
#  'test_EPISTASIS_mse_top100_de': 0.28679075837135315,
#  'test_SYNERGY_SIMILAR_PHENO_mean_sigma': 0.9013165235519408,
#  'test_unseen_single_frac_correct_direction_non_dropout': 0.3605782712612414,
#  'test_frac_in_range': 0.9986731534719152,
#  'test_pearson_top200_hvg': 0.9492205671240403,
#  'test_ADDITIVE_pearson_delta_top20_de_non_dropout': 0.666307582959888,
#  'test_combo_seen1_mse_top200_hvg': 0.10105560719966888,
#  'test_unseen_single_frac_in_range': 1,
#  'test_NEOMORPHIC_mse_top20_de_non_zero': 0.16946013271808624,
#  'test_EPISTASIS_pearson_delta_top100_de': 0.32378747630273985,
#  'test_combo_seen2_spearman': 0.8049909954322645,
#  'test_POTENTIATION_mse_top20_de': 0.6228667497634888,
#  'test_pearson_delta_top20_de_non_zero': 0.6276057376583044,
#  'test_unseen_single_std_sigma_non_zero': 0.238092377781868,
#  'test_ADDITIVE_frac_in_range_25_75_non_zero': 0.3136363636363636,
#  'test_EPISTASIS_pearson_delta_top20_de_non_zero': 0.23767577185958677,
#  'test_SUPPRESSOR_mse_top200_de': 0.040638361126184464,
#  'test_pearson_delta_top20_de_non_dropout': 0.6276057376583044,
#  'test_SUPPRESSOR_mse_top20_de_non_dropout': 0.2055789977312088,
#  'test_combo_seen0_frac_in_range_non_dropout': 0.995,
#  'test_unseen_single_frac_opposite_direction_non_dropout': 0.25892447327844187,
#  'test_unseen_single_pearson': 0.9877864141751144,
#  'test_combo_seen1_mse_top50_de': 0.21242859959602356,
#  'test_combo_seen2_mse_top200_hvg': 0.05892555043101311,
#  'test_combo_seen1_fold_change_gap_all': 0.9757758975028992,
#  'test_REDUNDANT_frac_correct_direction_top20_non_zero': 0.8928571428571429,
#  'test_combo_seen2_frac_in_range_25_75': 0.4399606907540344,
#  'test_combo_seen0_frac_in_range_45_55_non_zero': 0.015000000000000005,
#  'test_SYNERGY_SIMILAR_PHENO_fold_change_gap_all': 0.25579965114593506,
#  'test_combo_seen1_frac_in_range_40_60_non_dropout': 0.10603448275862072,
#  'test_std_sigma': 0.3003862500190735,
#  'test_combo_seen0_frac_0/1_direction_top20_non_zero': 0,
#  'test_combo_seen0_pearson_delta_top20_de_non_dropout': 0.6014812451748055,
#  'test_combo_seen2_mean_sigma': 0.7684167623519897,
#  'test_combo_seen0_std_sigma_non_zero': 0.26262402534484863,
#  'test_combo_seen1_mean_sigma_non_dropout': 0.8235363364219666,
#  'test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de': 0.9194940621057808,
#  'test_frac_correct_direction_non_dropout': 0.3970934263439567,
#  'test_combo_seen0_frac_correct_direction_20_nonzero': 0.8207309941520468,
#  'test_combo_seen2_mse_top20_de': 0.2834175229072571,
#  'test_combo_seen1_pearson_top50_de': 0.8516761676907051,
#  'test_combo_seen0_frac_sigma_below_2': 0.9233333333333336,
#  'test_combo_seen1_std_sigma_non_zero': 0.3439846932888031,
#  'test_EPISTASIS_pearson_delta_top20_de': 0.21045835070739485,
#  'test_frac_opposite_direction_non_zero': 0.35299749793109325,
#  'test_combo_seen1_fold_change_gap_downreg_0.1': 'NaN',
#  'test_combo_seen0_frac_in_range_45_55_non_dropout': 0.015000000000000005,
#  'test_frac_sigma_below_2': 0.9712352742954768,
#  'test_std_sigma_non_zero': 0.300123393535614,
#  'test_EPISTASIS_frac_in_range_40_60': 0.17943469785575047,
#  'test_combo_seen1_frac_sigma_below_2': 0.964011884131342,
#  'test_SYNERGY_SIMILAR_PHENO_pearson_delta_top200_de': 0.8310402211070639,
#  'test_NEOMORPHIC_frac_correct_direction_top20_non_zero': 0.8214285714285715,
#  'test_frac_correct_direction_200': 0.6387903225806454,
#  'test_frac_sigma_below_2_non_zero': 0.9826612903225806,
#  'test_unseen_single_frac_opposite_direction_top20_non_zero': 0.27875,
#  'test_combo_seen2_frac_opposite_direction_top20_non_dropout': 0.04375,
#  'test_combo_seen2_pearson_top100_de': 0.9540251008201276,
#  'test_combo_seen0_mean_sigma_non_dropout': 0.9567400813102722,
#  'test_unseen_single_frac_in_range_45_55_non_zero': 0.08374999999999999,
#  'test_combo_seen0_frac_opposite_direction_top20_non_zero': 0.26000000000000006,
#  'test_pearson_top50_de': 0.8934825346618825,
#  'test_frac_in_range_40_60': 0.1097809406369518,
#  'test_EPISTASIS_frac_sigma_below_1_non_zero': 0.4916666666666667,
#  'test_unseen_single_frac_correct_direction_100': 0.5832499999999999,
#  'test_combo_seen1_frac_sigma_below_1': 0.6740925681758965,
#  'test_combo_seen2_frac_in_range_45_55_non_dropout': 0.05,
#  'test_combo_seen2_frac_correct_direction_20_nonzero': 0.8425548221987851,
#  'test_pearson_delta_de': 0.5752528778172994,
#  'test_frac_in_range_25_75': 0.4396103355354858,
#  'test_ADDITIVE_frac_in_range_25_75': 0.298373440285205,
#  'test_EPISTASIS_frac_in_range_45_55': 0.0851364522417154,
#  'test_combo_seen2_frac_0/1_direction_top20_non_zero': 0,
#  'test_NEOMORPHIC_mse_top100_de': 0.03559774532914162,
#  'test_unseen_single_mse_top20_de': 0.3217999339103699,
#  'test_unseen_single_frac_sigma_below_2': 0.98781223893066,
#  'test_unseen_single_frac_correct_direction_50': 0.61,
#  'test_unseen_single_pearson_top50_de': 0.9323068208940664,
#  'test_SYNERGY_DISSIMILAR_PHENO_frac_in_range_25_75': 0.32222222222222224,
#  'test_combo_seen1_spearman': 0.8006086247525345,
#  'test_frac_sigma_below_1_non_zero': 0.7495967741935483,
#  'test_ADDITIVE_fold_change_gap_all': 0.3679104149341583,
#  'test_combo_seen2_pearson_top200_de': 0.9670053824217892,
#  'test_combo_seen1_pearson_delta': 0.5842608728868749,
#  'test_unseen_single_pearson_top200_hvg': 0.9587420967658604,
#  'test_unseen_single_mean_sigma_non_zero': 0.6832159757614136,
#  'test_combo_seen2_mse': 0.003885038662701845,
#  'test_unseen_single_mse_top20_de_non_zero': 0.33809953927993774,
#  'test_combo_seen1_pearson_delta_top20_de_non_zero': 0.6900456008509643,
#  'test_POTENTIATION_frac_correct_direction_top20_non_dropout': 0.875,
#  'test_fold_change_gap_upreg_3': 27.967363357543945,
#  'test_frac_correct_direction_20': 0.7173387096774194,
#  'test_combo_seen1_frac_sigma_below_1_non_zero': 0.7181034482758621,
#  'test_SYNERGY_SIMILAR_PHENO_frac_correct_direction_top20_non_zero': 0.9555555555555556,
#  'test_pearson_top100_de': 0.92751837506539,
#  'test_frac_0/1_direction_non_zero': 0,
#  'test_EPISTASIS_frac_in_range_25_75': 0.4160406357774779,
#  'test_ADDITIVE_pearson_delta_top20_de': 0.6585934860086198,
#  'test_combo_seen0_frac_sigma_below_1': 0.6290935672514619,
#  'test_SYNERGY_SIMILAR_PHENO_pearson_delta_top100_de': 0.8560099902990053,
#  'test_combo_seen0_frac_0/1_direction_top20_non_dropout': 0,
#  'val_mae': 0.01585116609930992,
#  'test_combo_seen1_mae': 0.021196149289608,
#  'test_combo_seen2_frac_in_range': 0.9967105263157896,
#  'test_SYNERGY_DISSIMILAR_PHENO_frac_in_range_40_60': 0.023809523809523808,
#  'test_combo_seen2_frac_in_range_45_55': 0.031479965467968565,
#  'test_combo_seen1_pearson_delta_top200_hvg': 0.6300468035929797,
#  'test_ADDITIVE_frac_correct_direction_top20_non_dropout': 0.8363636363636363,
#  'test_combo_seen0_pearson_delta_top100_de': 0.544948473305164,
#  'test_combo_seen2_frac_sigma_below_2_non_dropout': 0.984375,
#  'test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de_non_dropout': 0.9086970925265032,
#  'test_combo_seen1_r2_de': 0.21180472261484143,
#  'test_combo_seen2_spearman_de': 0.8312748779959163,
#  'test_ADDITIVE_pearson_delta_top200_de': 0.6025731462382343,
#  'test_unseen_single_frac_0/1_direction_non_dropout': 0.3804972554603167,
#  'test_unseen_single_mae': 0.015823017805814743,
#  'test_SUPPRESSOR_pearson_delta_top20_de': 0.4907789002165647,
#  'test_unseen_single_frac_sigma_below_2_non_zero': 0.98875,
#  'test_unseen_single_mse_de': 0.3217999339103699,
#  'test_combo_seen1_pearson_delta_top20_de': 0.5799845339697971,
#  'test_combo_seen2_pearson_delta_top50_de': 0.8434950630184249,
#  'test_SUPPRESSOR_frac_sigma_below_1_non_zero': 0.8550000000000001,
#  'test_combo_seen0_frac_opposite_direction_non_dropout': 0.2247562024087654,
#  'test_SUPPRESSOR_mean_sigma': 0.6959630250930786,
#  'test_combo_seen1_pearson_top100_de': 0.9089593703163628,
#  'test_SUPPRESSOR_pearson_delta_top50_de': 0.47208028816548697,
#  'test_SUPPRESSOR_pearson_delta_top100_de': 0.49071075373232514,
#  'test_REDUNDANT_frac_correct_direction_top20_non_dropout': 0.8928571428571429,
#  'test_SYNERGY_SIMILAR_PHENO_frac_sigma_below_1_non_dropout': 0.7388888888888889,
#  'test_combo_seen1_mse': 0.005728675983846188,
#  'test_combo_seen1_mse_de': 0.3220635652542114,
#  'test_combo_seen1_fold_change_gap_downreg_0.33': 0.5251582264900208,
#  'test_unseen_single_pearson_delta_top20_de_non_dropout': 0.4537723798855028,
#  'test_unseen_single_pearson_top200_de': 0.9610825610435172,
#  'test_NEOMORPHIC_mse_top20_de_non_dropout': 0.16946013271808624,
#  'test_combo_seen2_pearson_delta_top100_de': 0.835057991440082,
#  'test_combo_seen2_frac_correct_direction_100': 0.8075,
#  'test_EPISTASIS_mean_sigma': 0.8911371827125549,
#  'test_combo_seen1_std_sigma': 0.3405933678150177,
#  'test_ADDITIVE_mse_top200_de': 0.10208411514759064,
#  'test_pearson_delta_top200_hvg': 0.5539905496096246,
#  'test_combo_seen0_frac_0/1_direction_non_dropout': 0.3844456540216816,
#  'test_unseen_single_frac_correct_direction_20_nonzero': 0.8464420248224428,
#  'test_combo_seen2_frac_sigma_below_1_non_dropout': 0.7843749999999999,
#  'val_pearson': 0.9909505253594856,
#  'test_combo_seen0_r2_de': 0.10281664724101616,
#  'test_combo_seen1_frac_0/1_direction_non_zero': 0,
#  'test_combo_seen2_frac_sigma_below_1_non_zero': 0.7843749999999999,
#  'test_combo_seen0_frac_sigma_below_1_non_zero': 0.6399999999999999,
#  'test_combo_seen2_frac_0/1_direction_non_zero': 0,
#  'test_mse_top20_de_non_zero': 0.38758260011672974,
#  'test_NEOMORPHIC_mse_top200_de': 0.02318967878818512,
#  'test_combo_seen1_pearson_top200_de': 0.9459946804800738,
#  'test_REDUNDANT_pearson_delta_top20_de': 0.780274785377138,
#  'test_SYNERGY_DISSIMILAR_PHENO_frac_sigma_below_1_non_dropout': 0.7928571428571429,
#  'test_mse_top200_de': 0.08829515427350998,
#  'test_unseen_single_mae_de': 0.36750656366348267,
#  'test_combo_seen1_frac_correct_direction_200': 0.6599999999999999,
#  'test_combo_seen2_frac_opposite_direction_top20_non_zero': 0.04375,
#  'test_POTENTIATION_pearson_delta_top200_de': 0.8246274078341803,
#  'test_combo_seen2_pearson_delta_top200_hvg': 0.7531510877903111,
#  'test_combo_seen1_frac_in_range_non_dropout': 0.9982758620689656,
#  'test_combo_seen0_mse_top50_de': 0.24155882000923157,
#  'test_combo_seen0_frac_in_range_40_60': 0.05631578947368421,
#  'test_combo_seen2_fold_change_gap_all': 1.1043416261672974,
#  'test_combo_seen0_pearson_delta_top50_de': 0.5352442356841156,
#  'val_spearman': 0.826707702811462,
#  'test_ADDITIVE_mse_top20_de': 0.4780726134777069,
#  'test_NEOMORPHIC_pearson_delta_top20_de': 0.5189681268413046,
#  'test_unseen_single_frac_in_range_45_55': 0.06690212049732173,
#  'test_combo_seen0_mse_top100_de': 0.1740058809518814,
#  'test_combo_seen0_mse_top200_de': 0.11352714151144028,
#  'test_frac_sigma_below_1_non_dropout': 0.7495967741935483,
#  'test_SUPPRESSOR_mse_top20_de_non_zero': 0.2055789977312088,
#  'test_NEOMORPHIC_pearson_delta_top50_de': 0.5135683527155643,
#  'test_combo_seen2_frac_in_range_40_60_non_zero': 0.096875,
#  'test_SYNERGY_DISSIMILAR_PHENO_frac_in_range_25_75_non_dropout': 0.3857142857142858,
#  'test_pearson_top200_de': 0.9534913414910258,
#  'test_NEOMORPHIC_mean_sigma': 0.5896876454353333,
#  'test_combo_seen2_std_sigma': 0.3331954777240753,
#  'test_pearson_delta_top50_de': 0.5796919936894325,
#  'test_unseen_single_frac_correct_direction_all': 0.371798810703667,
#  'test_frac_opposite_direction_top20_non_dropout': 0.18991935483870973,
#  'test_combo_seen0_frac_in_range_40_60_non_dropout': 0.05500000000000001,
#  'test_combo_seen2_pearson_delta_top20_de_non_zero': 0.8521724358191032,
#  '_runtime': 12993,
#  'test_mse_top20_de': 0.3230784833431244,
#  'test_unseen_single_mse_top200_de': 0.07897331565618515,
#  'test_ADDITIVE_frac_in_range_40_60': 0.01868686868686869,
#  'test_unseen_single_pearson_top20_de_non_dropout': 0.8878689251894951,
#  'test_unseen_single_frac_in_range_25_75_non_dropout': 0.59375,
#  'test_combo_seen2_frac_correct_direction_top20_non_zero': 0.95625,
#  'test_std_sigma_non_dropout': 0.300123393535614,
#  'test_combo_seen1_mse_top20_de_non_zero': 0.42145729064941406,
#  'test_ADDITIVE_pearson_delta_top20_de_non_zero': 0.666307582959888,
#  'test_combo_seen0_frac_in_range_25_75_non_zero': 0.31999999999999995,
#  'test_unseen_single_frac_correct_direction_non_zero': 0.5817206191830249,
#  'train_mse': 0.0015801728004589677,
#  'test_ADDITIVE_mse_top20_de_non_zero': 0.48755601048469543,
#  'test_combo_seen0_mse_top20_de_non_zero': 0.5222398042678833,
#  'test_combo_seen0_pearson_top20_de_non_zero': 0.8284648213776933,
#  'test_frac_0/1_direction_top20_non_dropout': 0,
#  'test_EPISTASIS_frac_sigma_below_1_non_dropout': 0.4916666666666667,
#  'test_combo_seen1_frac_in_range_45_55_non_dropout': 0.05172413793103448,
#  'test_POTENTIATION_pearson_delta_top100_de': 0.8420339311145698,
#  'test_SYNERGY_DISSIMILAR_PHENO_mse_top50_de': 0.15274207293987274,
#  'test_SUPPRESSOR_pearson_delta_top20_de_non_zero': 0.5136985958313621,
#  'test_SYNERGY_DISSIMILAR_PHENO_frac_in_range_45_55': 0.007936507936507936,
#  'test_unseen_single_frac_opposite_direction_non_zero': 0.418279380816975,
#  'train_de_spearman': 0.8011091340744192,
#  'test_combo_seen0_r2': 0.9593450287920572,
#  'test_combo_seen0_frac_in_range': 0.9947368421052633,
#  'test_EPISTASIS_pearson_delta_top200_de': 0.3583791159372178,
#  'test_combo_seen0_frac_correct_direction_100': 0.651,
#  'test_SYNERGY_SIMILAR_PHENO_mse_top20_de_non_dropout': 0.5205959677696228,
#  'test_frac_in_range_45_55': 0.04831806224117018,
#  'test_EPISTASIS_mse_top200_de': 0.1845841407775879,
#  'test_combo_seen1_frac_in_range_40_60': 0.1058532267590916,
#  'test_combo_seen0_pearson_delta_top20_de': 0.5790441076781883,
#  'test_SYNERGY_SIMILAR_PHENO_mse_top100_de': 0.16331423819065094,
#  'test_combo_seen2_fold_change_gap_upreg_3': 28.140113830566406,
#  'test_unseen_single_pearson_de': 0.8804940928316451,
#  'test_combo_seen1_pearson_delta_de': 0.5799845339697971,
#  'test_combo_seen2_pearson_top200_hvg': 0.965473541659206,
#  'test_POTENTIATION_frac_in_range_25_75_non_zero': 0.15,
#  'test_combo_seen1_pearson_delta_top20_de_non_dropout': 0.6900456008509643,
#  'test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75_non_zero': 0.27222222222222225,
#  'test_de_mse': 0.3230784833431244,
#  'test_frac_sigma_below_1': 0.7159549078026067,
#  'test_combo_seen0_mse_top200_hvg': 0.12171614170074464,
#  'test_frac_correct_direction_top20_non_zero': 0.8100806451612904,
#  'test_SYNERGY_DISSIMILAR_PHENO_mse_top20_de_non_zero': 0.2876996397972107,
#  'test_ADDITIVE_mse_top50_de': 0.27896848320961,
#  'test_NEOMORPHIC_fold_change_gap_all': 0.15047971904277802,
#  'test_combo_seen0_fold_change_gap_upreg_3': 69.73634338378906,
#  'test_ADDITIVE_frac_sigma_below_1_non_zero': 0.6681818181818182,
#  'test_combo_seen2_frac_in_range_40_60_non_dropout': 0.096875,
#  'test_SUPPRESSOR_frac_correct_direction_top20_non_dropout': 0.73,
#  'test_SYNERGY_SIMILAR_PHENO_pearson_delta_top20_de_non_zero': 0.9086970925265032,
#  'test_EPISTASIS_mse_top20_de': 0.568484365940094,
#  'test_frac_correct_direction_non_zero': 0.6470025020689069,
#  'test_unseen_single_frac_in_range_non_dropout': 1,
#  'test_combo_seen0_pearson_delta_top20_de_non_zero': 0.6014812451748055,
#  'test_REDUNDANT_pearson_delta_top20_de_non_dropout': 0.8049387874379877,
#  'test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75_non_dropout': 0.27222222222222225,
#  'test_unseen_single_mse_top50_de': 0.19251389801502228,
#  'test_POTENTIATION_frac_in_range_25_75': 0.1349206349206349,
#  'test_combo_seen2_pearson_delta_top20_de': 0.8539836557785255,
#  'test_SUPPRESSOR_frac_in_range_25_75_non_dropout': 0.5850000000000001,
#  'test_combo_seen0_mae': 0.021312426775693893,
#  'test_combo_seen1_pearson_delta_top50_de': 0.6035311512534643,
#  'test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top100_de': 0.8376196500297098,
#  'test_NEOMORPHIC_frac_correct_direction_top20_non_dropout': 0.8214285714285715,
#  'test_unseen_single_mse_top20_de_non_dropout': 0.33809953927993774,
#  'test_combo_seen2_frac_correct_direction_non_dropout': 0.4444609969740844,
#  'test_combo_seen1_frac_correct_direction_top20_non_zero': 0.8431034482758621,
#  'test_SYNERGY_DISSIMILAR_PHENO_frac_correct_direction_top20_non_dropout': 0.9142857142857144,
#  'test_r2': 0.9687568153501626,
#  'test_SUPPRESSOR_fold_change_gap_all': 1.5225075483322144,
#  'test_unseen_single_frac_in_range_40_60': 0.14934344486782566,
#  'test_frac_opposite_direction_top20_non_zero': 0.18991935483870973,
#  'test_fold_change_gap_upreg_10': 153.25885009765625,
#  'test_combo_seen1_mean_sigma_non_zero': 0.8235363364219666,
#  'test_combo_seen2_frac_in_range_25_75_non_zero': 0.45,
#  'test_SYNERGY_SIMILAR_PHENO_frac_in_range_25_75': 0.2087719298245614,
#  'test_combo_seen0_pearson_de': 0.8141010835706396,
#  'test_combo_seen1_pearson_de': 0.783769078655528,
#  'test_fold_change_gap_downreg_0.33': 0.5704732537269592,
#  'test_combo_seen0_std_sigma_non_dropout': 0.26262402534484863,
#  'test_NEOMORPHIC_frac_in_range_25_75_non_zero': 0.6428571428571429,
#  'test_SYNERGY_DISSIMILAR_PHENO_frac_correct_direction_top20_non_zero': 0.9142857142857144,
#  'test_mse': 0.005026032216846943,
#  'test_mse_top100_de': 0.1394944190979004,
#  'test_frac_correct_direction_100': 0.6658870967741934,
#  'test_unseen_single_pearson_delta_top200_de': 0.44014389461867953,
#  'test_combo_seen0_frac_in_range_45_55': 0.015526315789473683,
#  'test_frac_0/1_direction_top20_non_zero': 0,
#  'test_frac_opposite_direction_non_dropout': 0.21672030584666835,
#  'test_EPISTASIS_mse_top20_de_non_zero': 0.6299260258674622,
#  'test_combo_seen2_pearson_top20_de_non_dropout': 0.920901222191675,
#  'test_SYNERGY_DISSIMILAR_PHENO_fold_change_gap_all': 0.3526208698749542,
#  'test_combo_seen0_pearson_top200_de': 0.9449846316553612,
#  'test_unseen_single_pearson_top100_de': 0.9454141742042196,
#  'test_combo_seen1_frac_correct_direction_100': 0.6863793103448276,
#  'test_combo_seen0_frac_sigma_below_2_non_zero': 0.98,
#  'test_combo_seen2_frac_sigma_below_2_non_zero': 0.984375,
#  'test_POTENTIATION_pearson_delta_top20_de_non_dropout': 0.8540215726391154,
#  '_step': 31838,
#  'test_unseen_single_spearman_de': 0.7603865458836433,
#  'test_combo_seen2_frac_correct_direction_200': 0.7575000000000001,
#  'test_combo_seen0_fold_change_gap_downreg_0.1': 'NaN',
#  'test_unseen_single_mse_top100_de': 0.12877744436264038,
#  'test_SUPPRESSOR_frac_in_range_25_75_non_zero': 0.5850000000000001,
#  'test_combo_seen2_frac_opposite_direction_non_zero': 0.2850931698160088,
#  'test_unseen_single_frac_0/1_direction_top20_non_zero': 0,
#  'test_fold_change_gap_downreg_0.1': 'NaN',
#  'test_unseen_single_mse_top200_hvg': 0.07265029102563858,
#  'test_ADDITIVE_pearson_delta_top100_de': 0.618709879557064,
#  'test_SYNERGY_DISSIMILAR_PHENO_mean_sigma': 1.004655838012695,
#  'test_combo_seen2_mae': 0.0188205037266016,
#  'test_combo_seen0_mean_sigma': 1.0263773202896118,
#  'test_combo_seen0_pearson_top100_de': 0.9211666448468512,
#  'test_EPISTASIS_mse_top20_de_non_dropout': 0.6299260258674622,
#  'test_combo_seen1_frac_correct_direction_non_zero': 0.6753949373613779,
#  'test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de': 0.8274428852173376,
#  'test_combo_seen1_mse_top20_de': 0.3220635652542114,
#  'test_combo_seen0_pearson_top50_de': 0.8994729833928765,
#  'test_frac_in_range_45_55_non_zero': 0.05887096774193548,
#  'test_combo_seen2_mse_top20_de_non_zero': 0.30433374643325806,
#  'test_frac_correct_direction_top20_non_dropout': 0.8100806451612904,
#  'test_unseen_single_fold_change_gap_downreg_0.33': 0.6731727719306946,
#  'test_unseen_single_frac_sigma_below_2_non_dropout': 0.98875,
#  'test_SYNERGY_DISSIMILAR_PHENO_frac_in_range_25_75_non_zero': 0.3857142857142858,
#  'val_de_mse': 0.2344214469194412,
#  'test_pearson': 0.9848578588445802,
#  'test_combo_seen0_pearson': 0.9803875286619292,
#  'test_combo_seen0_std_sigma': 0.26929590106010437,
#  'test_combo_seen2_frac_in_range_non_dropout': 0.996875,
#  'test_NEOMORPHIC_pearson_delta_top100_de': 0.5083328414688665,
#  'test_REDUNDANT_frac_sigma_below_1_non_zero': 0.5285714285714286,
#  'test_combo_seen1_frac_in_range_45_55_non_zero': 0.05172413793103448,
#  'train_pearson': 0.9951663082159016,
#  'test_ADDITIVE_mse_top100_de': 0.17262393236160278,
#  'test_NEOMORPHIC_frac_in_range_40_60': 0.22048995036611133,
#  'test_frac_0/1_direction_non_dropout': 0.38618626780937504,
#  'test_combo_seen2_frac_in_range_40_60': 0.0573009517572211,
#  'test_combo_seen1_pearson_top20_de_non_zero': 0.8649247988879932,
#  'test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de_non_zero': 0.844278416954663,
#  'test_NEOMORPHIC_frac_in_range_25_75': 0.6826656101036906,
#  'test_combo_seen0_fold_change_gap_downreg_0.33': 0.8219857811927795,
#  'test_combo_seen1_frac_0/1_direction_non_dropout': 0.3925547359185781,
#  'test_REDUNDANT_mse_top20_de': 0.45379209518432617,
#  'test_REDUNDANT_frac_sigma_below_1_non_dropout': 0.5285714285714286,
#  'test_combo_seen1_frac_correct_direction_20_nonzero': 0.8631476365149477,
#  'test_combo_seen0_frac_opposite_direction_top20_non_dropout': 0.26000000000000006,
#  'test_ADDITIVE_mse_top20_de_non_dropout': 0.48755601048469543,
#  'test_combo_seen1_frac_0/1_direction_top20_non_zero': 0,
#  'test_unseen_single_frac_in_range_40_60_non_zero': 0.16125000000000003,
#  'test_combo_seen2_frac_sigma_below_1': 0.7696663061310894,
#  'test_unseen_single_fold_change_gap_upreg_10': 157.00827026367188,
#  'test_combo_seen0_frac_sigma_below_2_non_dropout': 0.98,
#  'test_combo_seen1_frac_sigma_below_2_non_dropout': 0.978448275862069,
#  'test_mse_top50_de': 0.20269572734832764,
#  'test_unseen_single_std_sigma': 0.24176082015037537,
#  'test_combo_seen2_mse_top100_de': 0.11177705973386765,
#  'test_unseen_single_mean_sigma': 0.7615264654159546,
#  'test_EPISTASIS_frac_correct_direction_top20_non_dropout': 0.6749999999999999,
#  'test_combo_seen1_mse_top20_de_non_dropout': 0.42145729064941406,
#  'test_SYNERGY_SIMILAR_PHENO_frac_correct_direction_top20_non_dropout': 0.9555555555555556,
#  'test_combo_seen2_pearson': 0.9881847943430008,
#  'test_combo_seen0_pearson_top20_de_non_dropout': 0.8284648213776933,
#  'test_combo_seen2_frac_in_range_25_75_non_dropout': 0.45,
#  'test_unseen_single_frac_opposite_direction_top20_non_dropout': 0.27875,
#  'test_NEOMORPHIC_frac_in_range_45_55': 0.07577614379084967,
#  'test_unseen_single_frac_0/1_direction_non_zero': 0,
#  'test_SYNERGY_DISSIMILAR_PHENO_frac_sigma_below_1_non_zero': 0.7928571428571429,
#  'test_combo_seen0_pearson_top20_de': 0.8141010835706396,
#  'test_pearson_top20_de_non_dropout': 0.8766085734832835,
#  'test_unseen_single_pearson_delta_de': 0.45595185774646546,
#  'test_combo_seen1_frac_in_range_45_55': 0.045562678894795254,
#  'test_combo_seen0_frac_sigma_below_1_non_dropout': 0.6399999999999999,
#  'test_combo_seen1_frac_sigma_below_1_non_dropout': 0.7181034482758621,
#  'test_unseen_single_frac_in_range_25_75_non_zero': 0.59375,
#  'test_combo_seen0_frac_correct_direction_top20_non_zero': 0.74,
#  'test_combo_seen1_spearman_de': 0.7296786170126441,
#  'test_combo_seen1_pearson_top200_hvg': 0.9413021369069507,
#  'test_combo_seen0_frac_correct_direction_200': 0.631,
#  'test_combo_seen2_fold_change_gap_downreg_0.33': 0.35220640897750854,
#  'test_NEOMORPHIC_frac_sigma_below_1_non_zero': 0.9214285714285716,
#  'test_combo_seen0_frac_in_range_25_75_non_dropout': 0.31999999999999995,
#  'test_NEOMORPHIC_pearson_delta_top20_de_non_dropout': 0.6329878993538521,
#  'test_combo_seen2_pearson_top20_de_non_zero': 0.920901222191675,
#  'test_NEOMORPHIC_frac_sigma_below_1_non_dropout': 0.9214285714285716,
#  'test_SUPPRESSOR_frac_sigma_below_1_non_dropout': 0.8550000000000001,
#  'test_combo_seen0_frac_correct_direction_non_dropout': 0.390798143569553,
#  'test_frac_in_range_25_75_non_zero': 0.4685483870967742,
#  'test_REDUNDANT_pearson_delta_top50_de': 0.7484296168717697,
#  'test_combo_seen0_frac_in_range_non_zero': 0.995,
#  'test_combo_seen1_pearson_delta_top200_de': 0.6595083329913649,
#  'test_POTENTIATION_pearson_delta_top20_de': 0.8487076653616056,
#  'test_combo_seen0_frac_correct_direction_top20_non_dropout': 0.74,
#  'test_mean_sigma_non_zero': 0.7787137031555176,
#  'test_combo_seen0_spearman': 0.8152099703032587,
#  'test_POTENTIATION_mse_top50_de': 0.34899580478668213,
#  'test_combo_seen2_mean_sigma_non_zero': 0.7437098026275635,
#  'test_combo_seen0_frac_in_range_40_60_non_zero': 0.05500000000000001,
#  'test_combo_seen2_frac_0/1_direction_top20_non_dropout': 0,
#  'test_unseen_single_frac_correct_direction_top20_non_zero': 0.7212500000000001,
#  'training_loss': 0.29894545674324036,
#  'test_combo_seen0_spearman_de': 0.7925978177666289,
#  'test_frac_in_range_40_60_non_dropout': 0.1185483870967742,
#  'test_SYNERGY_SIMILAR_PHENO_mse_top200_de': 0.0986057072877884,
#  'test_de_pearson': 0.8364856572992745,
#  'test_combo_seen2_frac_sigma_below_2': 0.9836590557275542,
#  'test_REDUNDANT_pearson_delta_top100_de': 0.7852663567304586,
#  'test_unseen_single_frac_correct_direction_20': 0.625,
#  'test_EPISTASIS_frac_in_range_25_75_non_zero': 0.4083333333333334,
#  'test_POTENTIATION_pearson_delta_top20_de_non_zero': 0.8540215726391154,
#  'test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top50_de': 0.8171577240610131,
#  'test_unseen_single_frac_0/1_direction_top20_non_dropout': 0,
#  'train_de_mae': 0.24088650941848755,
#  'test_combo_seen2_r2_de': 0.7523584976389831,
#  'test_combo_seen2_pearson_delta_de': 0.8539836557785255,
#  'test_POTENTIATION_pearson_delta_top50_de': 0.8547579166803615,
#  'test_combo_seen0_pearson_delta_de': 0.5790441076781883,
#  'test_POTENTIATION_frac_in_range_45_55': 0,
#  'test_ADDITIVE_frac_in_range_25_75_non_dropout': 0.3136363636363636,
#  'test_combo_seen1_frac_opposite_direction_non_zero': 0.3246050626386222,
#  'test_ADDITIVE_frac_correct_direction_top20_non_zero': 0.8363636363636363,
#  'test_combo_seen2_frac_in_range_45_55_non_zero': 0.05,
#  'test_REDUNDANT_mse_top20_de_non_zero': 0.6472263932228088,
#  'test_combo_seen2_mean_sigma_non_dropout': 0.7437098026275635,
#  'test_combo_seen0_fold_change_gap_upreg_10': 299.2756652832031,
#  'test_combo_seen0_frac_0/1_direction_non_zero': 0,
#  'test_ADDITIVE_frac_in_range_45_55': 0.009595959595959595,
#  'test_combo_seen2_fold_change_gap_upreg_10': 224.39642333984375,
#  'test_REDUNDANT_frac_in_range_25_75_non_zero': 0.3428571428571429,
#  'test_NEOMORPHIC_frac_in_range_25_75_non_dropout': 0.6428571428571429,
#  'test_combo_seen0_mse_de': 0.3975368142127991,
#  'test_REDUNDANT_pearson_delta_top200_de': 0.7414206603573003,
#  'test_combo_seen1_frac_correct_direction_top20_non_dropout': 0.8431034482758621,
#  '_wandb': {'runtime': 12993},
#  'test_mae': 0.019165726378560063,
#  'test_EPISTASIS_pearson_delta_top50_de': 0.2929170106250049,
#  'test_combo_seen2_frac_in_range_non_zero': 0.996875,
#  'test_REDUNDANT_mse_top200_de': 0.1755075603723526,
#  'test_REDUNDANT_fold_change_gap_all': 4.7901692390441895,
#  'test_combo_seen2_frac_correct_direction_non_zero': 0.7149068301839911,
#  'test_combo_seen2_frac_correct_direction_20': 0.871875,
#  'test_combo_seen2_mse_top50_de': 0.16857916116714478,
#  'test_pearson_top20_de_non_zero': 0.8766085734832835,
#  'test_combo_seen2_pearson_top20_de': 0.9315525246323266,
#  'test_combo_seen2_std_sigma_non_dropout': 0.3196406364440918,
#  'test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top20_de_non_dropout': 0.844278416954663,
#  'test_EPISTASIS_fold_change_gap_all': 2.295149087905884,
#  'test_unseen_single_fold_change_gap_all': 1.3011844158172607,
#  'test_combo_seen2_mse_top20_de_non_dropout': 0.30433374643325806,
#  'test_unseen_single_pearson_delta_top20_de_non_zero': 0.4537723798855028,
#  'test_combo_seen1_frac_in_range_25_75': 0.37107167695841103,
#  'test_combo_seen1_std_sigma_non_dropout': 0.3439846932888031,
#  'test_combo_seen2_frac_correct_direction_top20_non_dropout': 0.95625,
#  'val_mse': 0.0029513800982385874,
#  'test_SUPPRESSOR_mse_top20_de': 0.1978531777858734,
#  'test_POTENTIATION_mse_top100_de': 0.21112939715385437,
#  'test_SUPPRESSOR_frac_in_range_25_75': 0.5505025998253552,
#  'test_SYNERGY_SIMILAR_PHENO_mse_top20_de': 0.4862009286880493,
#  'test_POTENTIATION_frac_sigma_below_1_non_dropout': 0.675,
#  'test_combo_seen0_frac_correct_direction_non_zero': 0.6348069839319663,
#  'test_SYNERGY_DISSIMILAR_PHENO_pearson_delta_top200_de': 0.8340581815959048,
#  '_timestamp': 1648767579,
#  'test_combo_seen2_r2': 0.9757969429354014,
#  'test_REDUNDANT_mean_sigma': 1.085826754570007,
#  'test_unseen_single_pearson_delta': 0.30586260820343075,
#  'test_SUPPRESSOR_frac_in_range_40_60': 0.2190070056362626,
#  'test_unseen_single_frac_in_range_non_zero': 1,
#  'test_combo_seen2_frac_correct_direction_50': 0.8424999999999999,
#  'test_NEOMORPHIC_pearson_delta_top20_de_non_zero': 0.6329878993538521,
#  'test_de_spearman': 0.757767724578065,
#  'test_fold_change_gap_all': 1.1856095790863037,
#  'test_combo_seen2_pearson_de': 0.9315525246323269,
#  'test_combo_seen1_mse_top100_de': 0.1485813558101654,
#  'test_combo_seen0_frac_opposite_direction_non_zero': 0.3651930160680336,
#  'test_unseen_single_fold_change_gap_upreg_3': 23.100805282592773,
#  'test_REDUNDANT_pearson_delta_top20_de_non_zero': 0.8049387874379877,
#  'test_POTENTIATION_frac_correct_direction_top20_non_zero': 0.875,
#  'test_de_r2': 0.4009829140592718,
#  'test_frac_in_range_non_zero': 0.9983870967741936,
#  'test_POTENTIATION_frac_in_range_40_60': 0,
#  'test_SUPPRESSOR_pearson_delta_top200_de': 0.5080336210490113,
#  'test_combo_seen2_frac_opposite_direction_non_dropout': 0.177128017622448,
#  'test_pearson_top20_de': 0.8364856572992745,
#  'test_combo_seen1_mae_de': 0.3942877948284149,
#  'test_frac_correct_direction_50': 0.6880645161290323,
#  'test_combo_seen2_frac_correct_direction_all': 0.41995787908820614,
#  'test_frac_in_range_25_75_non_dropout': 0.4685483870967742,
#  'test_POTENTIATION_mse_top20_de_non_dropout': 0.6697788238525391,
#  'test_EPISTASIS_frac_in_range_25_75_non_dropout': 0.4083333333333334,
#  'test_REDUNDANT_mse_top50_de': 0.30707916617393494,
#  'test_pearson_delta_top100_de': 0.5963321631701107,
#  'test_combo_seen1_frac_in_range': 0.9990069513406156,
#  'test_combo_seen2_std_sigma_non_zero': 0.3196406364440918,
#  'test_combo_seen1_fold_change_gap_upreg_3': 23.02746963500977,
#  'test_unseen_single_mean_sigma_non_dropout': 0.6832159757614136,
#  'test_combo_seen1_frac_in_range_25_75_non_zero': 0.4129310344827586,
#  'test_combo_seen2_mae_de': 0.4126339554786682,
#  'test_unseen_single_r2_de': 0.6092826249263754,
#  'test_combo_seen0_mse_top20_de': 0.3975367546081543,
#  'test_POTENTIATION_mse_top20_de_non_zero': 0.6697788238525391,
#  'test_NEOMORPHIC_mse_top50_de': 0.06033046171069145,
#  'test_REDUNDANT_frac_in_range_45_55': 0.008403361344537815,
#  'test_unseen_single_frac_correct_direction_200': 0.5625,
#  'test_SYNERGY_SIMILAR_PHENO_frac_sigma_below_1_non_zero': 0.7388888888888889,
#  'test_unseen_single_frac_sigma_below_1': 0.7716532836143903,
#  'test_unseen_single_std_sigma_non_dropout': 0.238092377781868,
#  'test_unseen_single_fold_change_gap_downreg_0.1': 'NaN',
#  'test_spearman': 0.8103765548672957,
#  'test_ADDITIVE_mean_sigma': 0.9605359435081482,
#  'test_unseen_single_spearman': 0.825485923448721,
#  'test_SUPPRESSOR_frac_in_range_45_55': 0.11213265063110264,
#  'test_combo_seen1_frac_sigma_below_2_non_zero': 0.978448275862069,
#  'test_REDUNDANT_frac_in_range_25_75_non_dropout': 0.3428571428571429,
#  'test_unseen_single_frac_in_range_40_60_non_dropout': 0.16125000000000003,
#  'test_EPISTASIS_frac_correct_direction_top20_non_zero': 0.6749999999999999,
#  'test_combo_seen2_pearson_delta': 0.7054591254068333,
#  'test_combo_seen0_frac_in_range_25_75': 0.3165497076023392,
#  'test_combo_seen0_frac_correct_direction_20': 0.72,
#  'test_combo_seen0_frac_correct_direction_all': 0.37078295341922696,
#  'test_combo_seen1_frac_correct_direction_non_dropout': 0.4102947694641395,
#  'test_mean_sigma': 0.8414417505264282,
#  'test_combo_seen1_r2': 0.9643170638771514,
#  'test_unseen_single_frac_in_range_25_75': 0.5610490730459771,
#  'test_SYNERGY_SIMILAR_PHENO_frac_in_range_40_60': 0.005847953216374269,
#  'test_combo_seen1_mean_sigma': 0.8889070153236389,
#  'test_POTENTIATION_mean_sigma': 0.9708249568939208,
#  'test_SYNERGY_DISSIMILAR_PHENO_mse_top20_de_non_dropout': 0.2876996397972107,
#  'test_combo_seen1_frac_correct_direction_20': 0.7379310344827585,
#  'test_unseen_single_frac_sigma_below_1_non_zero': 0.8087500000000001,
#  'test_combo_seen2_frac_0/1_direction_non_dropout': 0.3784109854034676,
#  'train_mae': 0.011765745468437672,
#  'test_combo_seen0_mae_de': 0.489118754863739,
#  'test_combo_seen2_pearson_top50_de': 0.9442258688950712,
#  'test_combo_seen0_fold_change_gap_all': 2.070375680923462,
#  'test_combo_seen1_frac_in_range_non_zero': 0.9982758620689656,
#  'test_SYNERGY_SIMILAR_PHENO_mse_top20_de_non_zero': 0.5205959677696228,
#  'test_combo_seen2_pearson_delta_top20_de_non_dropout': 0.8521724358191032,
#  'test_pearson_delta_top200_de': 0.5986786571336902,
#  'test_REDUNDANT_frac_in_range_25_75': 0.3615877930119416,
#  'test_combo_seen0_mean_sigma_non_zero': 0.9567400813102722,
#  'test_POTENTIATION_fold_change_gap_all': 0.2994500398635864,
#  'test_combo_seen1_pearson': 0.9826911367864838,
#  'test_mse_top20_de_non_dropout': 0.38758260011672974,
#  'test_combo_seen2_pearson_delta_top200_de': 0.8203385149241578,
#  'test_frac_sigma_below_2_non_dropout': 0.9826612903225806,
#  'test_combo_seen0_mse_top20_de_non_dropout': 0.5222398042678833,
#  'test_SYNERGY_SIMILAR_PHENO_frac_in_range_45_55': 0,
#  'test_unseen_single_frac_correct_direction_top20_non_dropout': 0.7212500000000001,
#  'test_combo_seen1_frac_correct_direction_50': 0.7037931034482758,
#  'test_SYNERGY_DISSIMILAR_PHENO_mse_top200_de': 0.07273715734481812,
#  'test_EPISTASIS_pearson_delta_top20_de_non_dropout': 0.23767577185958677,
#  'test_combo_seen1_frac_opposite_direction_non_dropout': 0.19715049461728237,
#  'test_REDUNDANT_mse_top20_de_non_dropout': 0.6472263932228088,
#  'test_combo_seen1_frac_in_range_25_75_non_dropout': 0.4129310344827586,
#  'test_unseen_single_pearson_delta_top20_de': 0.45595185774646546,
#  'test_unseen_single_pearson_delta_top200_hvg': 0.37931134578063275,
#  'test_unseen_single_frac_sigma_below_1_non_dropout': 0.8087500000000001,
#  'test_de_mae': 0.39566361904144287,
#  'val_de_spearman': 0.8148022886686549,
#  'test_frac_correct_direction_all': 0.3897599028101922,
#  'test_frac_in_range_40_60_non_zero': 0.1185483870967742,
#  'test_mse_top200_hvg': 0.08812263607978821,
#  'test_combo_seen0_pearson_delta': 0.4467516753354883,
#  'test_REDUNDANT_frac_in_range_40_60': 0.03184431667403804,
#  'test_combo_seen1_frac_opposite_direction_top20_non_zero': 0.15689655172413797,
#  'test_frac_in_range_non_dropout': 0.9983870967741936,
#  'test_combo_seen0_pearson_delta_top200_de': 0.5253498147544737,
#  'test_SYNERGY_SIMILAR_PHENO_pearson_delta_top50_de': 0.8735677810034966,
#  'test_unseen_single_frac_in_range_45_55_non_dropout': 0.08374999999999999,
#  'test_combo_seen1_frac_opposite_direction_top20_non_dropout': 0.15689655172413797,
#  'val_de_mae': 0.3530658185482025,
#  'test_REDUNDANT_mse_top100_de': 0.2570265233516693,
#  'test_combo_seen0_frac_correct_direction_50': 0.662,
#  'test_POTENTIATION_frac_sigma_below_1_non_zero': 0.675}

# %%
metrics = [
           'test_frac_sigma_below_1_non_dropout', 
           'test_frac_opposite_direction_top20_non_dropout',
           'test_mse_top20_de_non_dropout', 
           'test_pearson_delta'
          ]
metrics_name_map = {
                    'test_frac_opposite_direction_top20_non_dropout': '% of Top 20 DE Genes with Opposite Direction',
                   'test_frac_sigma_below_1_non_dropout': '% of STD <1',
                   'test_mse_top20_de_non_dropout': 'Top 20 DE MSE',
                   'test_pearson_delta': 'Pearson Correlation Across All Genes'}
out = {}
out['method'] = [normalize_name(i) for i in res_df.name.values]
for m in metrics:
    out[metrics_name_map[m]] = res_df.summary.apply(lambda x: x[m])

# %%
metrics = ['test_combo_seen2_mse_top20_de_non_dropout',
          'test_combo_seen1_mse_top20_de_non_dropout',
          'test_unseen_single_mse_top20_de_non_dropout',
          'test_combo_seen0_mse_top20_de_non_dropout'
          ]
metrics_name_map = {'test_combo_seen2_mse_top20_de_non_dropout': '2/2 Seen',
                   'test_combo_seen1_mse_top20_de_non_dropout': '1/2 Seen',
                   'test_combo_seen0_mse_top20_de_non_dropout': '0/2 Seen',
                   'test_unseen_single_mse_top20_de_non_dropout': '0/1 Seen'}
out = {}
out['method'] = [normalize_name(i) for i in res_df.name.values]
for m in metrics:
    out[metrics_name_map[m]] = res_df.summary.apply(lambda x: x[m])

# %%
import seaborn as sns
from matplotlib import font_manager
import matplotlib.pyplot as plt

font_dirs = ["./"]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    font_manager.fontManager.addfont(font_file)
    
sns.set( font = "Helvetica" )

sns.set(rc={'figure.figsize':(10,6)})
sns.set_theme(style="ticks", rc={"axes.facecolor": (0, 0, 0, 0)}, font = "Helvetica", font_scale=1.5)

color_pal = {
'PertNet': (0.9882352941176471, 0.5529411764705883, 0.3843137254901961)
}

# %%
import matplotlib.pyplot as plt

# %%
category = '2/2 Seen'
g = sns.pointplot('method', category, 
    data=pd.DataFrame(out), 
    order = ['GEARS', 'No Graph', 'No GO Graph', 'No Co-Express Graph', 'No Cross-gene', 'No Gene-specific Decoder', 'MSE Loss'], 
    color = (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
    #hue = 'method',
    #palette=pal_order,              
    dodge=True, 
    join=False)
sns.despine()
#g.legend_.remove()
g.set(xlabel=None, title = category)

plt.ylabel("Top 20 DE MSE",labelpad=10)
plt.tick_params(axis='x', which='major', pad=10)
plt.tick_params(axis='y', which='major', pad=5)
g.spines['left'].set_linewidth(0.8)
g.spines['bottom'].set_linewidth(0.8)
plt.xticks(
    rotation=30, 
    horizontalalignment='right'
)
plt.savefig('ablation_mse_'+category.replace('/','_')+'.svg', bbox_inches='tight')
# Out:
# /dfs/user/yhr/deepamp/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g = sns.pointplot('method', 'Top 20 DE MSE', 
    data=pd.DataFrame(out), 
    order = ['GEARS', 'No Graph', 'No GO Graph', 'No Co-Express Graph', 'No Cross-gene', 'No Gene-specific Decoder', 'MSE Loss'], 
    color = (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
    #hue = 'method',
    #palette=pal_order,              
    dodge=True, 
    join=False)
sns.despine()
#g.legend_.remove()
g.set(xlabel=None)

plt.ylabel("Top 20 DE MSE",labelpad=10)
plt.tick_params(axis='x', which='major', pad=10)
plt.tick_params(axis='y', which='major', pad=5)
g.spines['left'].set_linewidth(0.8)
g.spines['bottom'].set_linewidth(0.8)
plt.xticks(
    rotation=30, 
    horizontalalignment='right'
)
plt.savefig('ablation_mse_unseen_single.pdf', bbox_inches='tight')
# Out:
# /dfs/user/kexinh/miniconda3/envs/a100_env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g = sns.pointplot('method', 'Pearson Correlation Across All Genes', 
    data=pd.DataFrame(out), 
    order = ['GEARS', 'No Graph', 'No GO Graph', 'No Co-Express Graph', 'No Cross-gene', 'No Gene-specific Decoder', 'MSE Loss'], 
    color = (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
    #hue = 'method',
    #palette=pal_order,              
    dodge=True, 
    join=False)
sns.despine()
#g.legend_.remove()
g.set(xlabel=None)

plt.ylabel("Pearson Correlation with True Delta \n Expression Across All Genes",labelpad=10)
plt.tick_params(axis='x', which='major', pad=10)
plt.tick_params(axis='y', which='major', pad=5)
g.spines['left'].set_linewidth(0.8)
g.spines['bottom'].set_linewidth(0.8)
plt.xticks(
    rotation=30, 
    horizontalalignment='right'
)
plt.savefig('ablation_pearson.pdf', bbox_inches='tight')
# Out:
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g = sns.pointplot('method', '% of Top 20 DE Genes with Opposite Direction', 
    data=pd.DataFrame(out), 
    order = ['GEARS', 'No Graph', 'No GO Graph', 'No Co-Express Graph', 'No Cross-gene', 'No Gene-specific Decoder', 'MSE Loss'], 
    color = (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
    #hue = 'method',
    #palette=pal_order,              
    dodge=True, 
    join=False)
sns.despine()
#g.legend_.remove()
g.set(xlabel=None)

plt.tick_params(axis='x', which='major', pad=10)
plt.tick_params(axis='y', which='major', pad=5)
g.spines['left'].set_linewidth(0.8)
g.spines['bottom'].set_linewidth(0.8)
plt.xticks(
    rotation=30, 
    horizontalalignment='right'
)
plt.savefig('ablation_direction.pdf', bbox_inches='tight')
# Out:
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g = sns.pointplot('method', '% of STD <1', 
    data=pd.DataFrame(out), 
    order = ['GEARS', 'No Graph', 'No GO Graph', 'No Co-Express Graph', 'No Cross-gene', 'No Gene-specific Decoder', 'MSE Loss'], 
    color = (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
    #hue = 'method',
    #palette=pal_order,              
    dodge=True, 
    join=False)
sns.despine()
#g.legend_.remove()
g.set(xlabel=None)

plt.tick_params(axis='x', which='major', pad=10)
plt.tick_params(axis='y', which='major', pad=5)
g.spines['left'].set_linewidth(0.8)
g.spines['bottom'].set_linewidth(0.8)
plt.xticks(
    rotation=30, 
    horizontalalignment='right'
)
plt.savefig('ablation_std.pdf', bbox_inches='tight')
# Out:
# /dfs/user/kexinh/miniconda3/envs/eee/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
